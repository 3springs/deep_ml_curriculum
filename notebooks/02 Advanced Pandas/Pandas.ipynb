# %% [markdown]
# # Pandas

# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
import warnings

warnings.simplefilter("ignore")

# %% [markdown]
# ## Read Data

# %% [markdown]
# Pandas has the ability to read data from various formats, including:
# - CSV
# - Excel
# - Html
# - Json
# - Feather
# - Parquet

# %% [markdown]
# Let's start by reading a table from a csv file. Pandas puts the data in an object known as a `DataFrame`.<br>
# The data we are using here is air emissions from industrial facilities in Queensland for the 2005/2006 inventory year taken from [data.gov.au](http://data.gov.au).

# %%
# !head -n 3 "../../data/processed/Emission/npi-2006-qld-air-total-emissions.csv"
# Out:
# jurisdiction,Year,data_start_date,data_end_date,first_published_date,last_updated_date,sub_threshold,jurisdiction_facility_id,registered_business_name,facility_name,site_address_street,site_address_suburb,site_address_state,site_address_postcode,site_latitude,site_longitude,main_activities,ANZSIC code,ANZSIC name,substance,destination,quantity_in_kg
# QLD,2006,1/07/2005,30/06/2006,31/01/2007,31/03/2010,N,Q001BOR001,BORAL BRICKS P/L,DARRA,Harcourt Road,Darra,QLD,4076,-27.565416,152.958722,Manufacture and sale of clay bricks and pavers,2021,Clay Brick Manufacturing,Arsenic & compounds,Air Total,6.31
# QLD,2006,1/07/2005,30/06/2006,31/01/2007,31/03/2010,N,Q001BOR001,BORAL BRICKS P/L,DARRA,Harcourt Road,Darra,QLD,4076,-27.565416,152.958722,Manufacture and sale of clay bricks and pavers,2021,Clay Brick Manufacturing,Beryllium & compounds,Air Total,0.52

# %%
df = pd.read_csv("../../data/processed/Emission/npi-2006-qld-air-total-emissions2.csv", index_col='index')

# %% [markdown]
# The `DataFrame` is now stored in variable `df`. We can print it:

# %%
df
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q001BOR001-S14          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S0           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S69          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S1           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S52          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q086ILE042-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE043-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE044-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE045-S53          QLD  2006       1/07/2005    30/06/2006
# Q086SLI001-S53          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q001BOR001-S14           31/01/2007        31/03/2010             N
# Q001BOR001-S0            31/01/2007        31/03/2010             N
# Q001BOR001-S69           31/01/2007        31/03/2010             N
# Q001BOR001-S1            31/01/2007        31/03/2010             N
# Q001BOR001-S52           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q086ILE042-S53           31/01/2007        31/03/2010             N
# Q086ILE043-S53           31/01/2007        31/03/2010             N
# Q086ILE044-S53           31/01/2007        31/03/2010             N
# Q086ILE045-S53           31/01/2007        31/03/2010             N
# Q086SLI001-S53           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id     registered_business_name  \
# index
# Q001BOR001-S14               Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S0                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S69               Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S1                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S52               Q001BOR001             BORAL BRICKS P/L
# ...                                 ...                          ...
# Q086ILE042-S53               Q086ILE042  BARTTER ENTERPRISES PTY LTD
# Q086ILE043-S53               Q086ILE043  BARTTER ENTERPRISES PTY LTD
# Q086ILE044-S53               Q086ILE044      PAUL & CHARMAINE SCALIA
# Q086ILE045-S53               Q086ILE045  BARTTER ENTERPRISES PTY LTD
# Q086SLI001-S53               Q086SLI001   SLALOM INVESTMENTS PTY LTD
#
#                               facility_name  ... site_address_postcode  \
# index                                        ...
# Q001BOR001-S14                        DARRA  ...                  4076
# Q001BOR001-S0                         DARRA  ...                  4076
# Q001BOR001-S69                        DARRA  ...                  4076
# Q001BOR001-S1                         DARRA  ...                  4076
# Q001BOR001-S52                        DARRA  ...                  4076
# ...                                     ...  ...                   ...
# Q086ILE042-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE043-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE044-S53                       Scalia  ...                  4341
# Q086ILE045-S53  BARTTER ENTERPRISES PTY LTD  ...                  4343
# Q086SLI001-S53   SLALOM INVESTMENTS PTY LTD  ...                  4356
#
#                site_latitude site_longitude  \
# index
# Q001BOR001-S14    -27.565416     152.958722
# Q001BOR001-S0     -27.565416     152.958722
# Q001BOR001-S69    -27.565416     152.958722
# Q001BOR001-S1     -27.565416     152.958722
# Q001BOR001-S52    -27.565416     152.958722
# ...                      ...            ...
# Q086ILE042-S53    -27.374167     152.463889
# Q086ILE043-S53    -27.384722     152.470556
# Q086ILE044-S53    -27.622222     152.470833
# Q086ILE045-S53    -27.458349     152.367415
# Q086SLI001-S53    -27.759444     151.539444
#
#                                                main_activities  ANZSIC code  \
# index
# Q001BOR001-S14  Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S0   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S69  Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S1   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S52  Manufacture and sale of clay bricks and pavers         2021
# ...                                                        ...          ...
# Q086ILE042-S53                   Meat Breeder Rearing Facility          171
# Q086ILE043-S53                   Meat Breeder Rearing Facility          171
# Q086ILE044-S53                           Meat Chicken Facility          172
# Q086ILE045-S53                          Poultry - fertile Eggs          172
# Q086SLI001-S53                                  Egg Production          172
#
#                              ANZSIC name                 substance  \
# index
# Q001BOR001-S14  Clay Brick Manufacturing       Arsenic & compounds
# Q001BOR001-S0   Clay Brick Manufacturing     Beryllium & compounds
# Q001BOR001-S69  Clay Brick Manufacturing       Cadmium & compounds
# Q001BOR001-S1   Clay Brick Manufacturing           Carbon monoxide
# Q001BOR001-S52  Clay Brick Manufacturing  Chromium (III) compounds
# ...                                  ...                       ...
# Q086ILE042-S53    Poultry Farming (Meat)           Ammonia (total)
# Q086ILE043-S53    Poultry Farming (Meat)           Ammonia (total)
# Q086ILE044-S53    Poultry Farming (Eggs)           Ammonia (total)
# Q086ILE045-S53    Poultry Farming (Eggs)           Ammonia (total)
# Q086SLI001-S53    Poultry Farming (Eggs)           Ammonia (total)
#
#                 destination quantity_in_kg substance_code
# index
# Q001BOR001-S14    Air Total           6.31            S14
# Q001BOR001-S0     Air Total           0.52             S0
# Q001BOR001-S69    Air Total           2.12            S69
# Q001BOR001-S1     Air Total      170743.00             S1
# Q001BOR001-S52    Air Total          18.80            S52
# ...                     ...            ...            ...
# Q086ILE042-S53    Air Total       13450.00            S53
# Q086ILE043-S53    Air Total       17754.00            S53
# Q086ILE044-S53    Air Total       13610.00            S53
# Q086ILE045-S53    Air Total       34205.00            S53
# Q086SLI001-S53    Air Total       11362.00            S53
#
# [9375 rows x 23 columns]

# %% [markdown]
# Similarly, using the respective read method you can read the tables from other file formats supported by Pandas. <br>
# e.g. `pd.read_excel()`

# %% [markdown]
# Pandas can also read the data from SQL database and put them directly into a pandas data frame. To do that, we need to pass in the query and the connection object.

# %%
import sqlite3

# create a connection to database
conn = sqlite3.connect("../01 SQL/Sales.db")

# write a query
query = """
SELECT * from Customers
LIMIT 5
"""

pd.read_sql(query, conn)
# Out:
#    CustomerID Title Firstname Surname PhoneNumber      Mobile       Fax  \
# 0           1   Mr.     Jorge    Dunn        None  0429937146  48585127
# 1           2  Mrs.     Debra    Wall    56978970  0470205559      None
# 2           3   Dr.   Cynthia   Ellis        None  0469055029  82096582
# 3           4   Mr.      John  Harris        None  0475137980      None
# 4           5   Mr.      Kyle   Jones    21424091  0404892875  24628569
#
#                                Email                        Address  \
# 0                sbrooks@hotmail.com            99098 Rachael Cliff
# 1  colleenalexander@taylor-brown.net     9716 Andrea Place Apt. 808
# 2                 vstewart@gmail.com              21014 Jared Mount
# 3             yarmstrong@hotmail.com             54725 Todd Corners
# 4                  cindy97@yahoo.com  97603 Joseph Terrace Apt. 079
#
#                City    Country  CreditCardNumber CreditCardExpiry  SignupDate
# 0  New Jasonborough     Poland   341571816096695            12/20  2019-06-17
# 1        Harrisberg   Portugal  4846279439697392            02/24  2015-01-02
# 2        Lopezmouth    Germany   213179187652107            01/30  2014-07-21
# 3       New Timothy    Bahrain  3567765520251007            02/22  2011-07-26
# 4        Sherryland  Hong Kong  4290875996151482            07/29  2013-09-26

# %% [markdown]
# __Tip:__ Sometimes you just want to quickly copy a portion of a dataset from a webpage or excel into a notebook. An easy way to do that is to copy the data from the source and then use `pd.read_clipboard()`. This method will create a pandas data frame from the data you copied. Note that this method only works if the notebook is running on your local machine (not on an external server).

# %% [markdown]
# ## Basic Analysis
# - info
# - describe
# - pandas profiling
# - value_counts()

# %%
df = pd.read_csv("../../data/processed/Emission/npi-2006-qld-air-total-emissions2.csv", index_col='index')
df
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q001BOR001-S14          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S0           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S69          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S1           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S52          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q086ILE042-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE043-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE044-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE045-S53          QLD  2006       1/07/2005    30/06/2006
# Q086SLI001-S53          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q001BOR001-S14           31/01/2007        31/03/2010             N
# Q001BOR001-S0            31/01/2007        31/03/2010             N
# Q001BOR001-S69           31/01/2007        31/03/2010             N
# Q001BOR001-S1            31/01/2007        31/03/2010             N
# Q001BOR001-S52           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q086ILE042-S53           31/01/2007        31/03/2010             N
# Q086ILE043-S53           31/01/2007        31/03/2010             N
# Q086ILE044-S53           31/01/2007        31/03/2010             N
# Q086ILE045-S53           31/01/2007        31/03/2010             N
# Q086SLI001-S53           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id     registered_business_name  \
# index
# Q001BOR001-S14               Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S0                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S69               Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S1                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S52               Q001BOR001             BORAL BRICKS P/L
# ...                                 ...                          ...
# Q086ILE042-S53               Q086ILE042  BARTTER ENTERPRISES PTY LTD
# Q086ILE043-S53               Q086ILE043  BARTTER ENTERPRISES PTY LTD
# Q086ILE044-S53               Q086ILE044      PAUL & CHARMAINE SCALIA
# Q086ILE045-S53               Q086ILE045  BARTTER ENTERPRISES PTY LTD
# Q086SLI001-S53               Q086SLI001   SLALOM INVESTMENTS PTY LTD
#
#                               facility_name  ... site_address_postcode  \
# index                                        ...
# Q001BOR001-S14                        DARRA  ...                  4076
# Q001BOR001-S0                         DARRA  ...                  4076
# Q001BOR001-S69                        DARRA  ...                  4076
# Q001BOR001-S1                         DARRA  ...                  4076
# Q001BOR001-S52                        DARRA  ...                  4076
# ...                                     ...  ...                   ...
# Q086ILE042-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE043-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE044-S53                       Scalia  ...                  4341
# Q086ILE045-S53  BARTTER ENTERPRISES PTY LTD  ...                  4343
# Q086SLI001-S53   SLALOM INVESTMENTS PTY LTD  ...                  4356
#
#                site_latitude site_longitude  \
# index
# Q001BOR001-S14    -27.565416     152.958722
# Q001BOR001-S0     -27.565416     152.958722
# Q001BOR001-S69    -27.565416     152.958722
# Q001BOR001-S1     -27.565416     152.958722
# Q001BOR001-S52    -27.565416     152.958722
# ...                      ...            ...
# Q086ILE042-S53    -27.374167     152.463889
# Q086ILE043-S53    -27.384722     152.470556
# Q086ILE044-S53    -27.622222     152.470833
# Q086ILE045-S53    -27.458349     152.367415
# Q086SLI001-S53    -27.759444     151.539444
#
#                                                main_activities  ANZSIC code  \
# index
# Q001BOR001-S14  Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S0   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S69  Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S1   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S52  Manufacture and sale of clay bricks and pavers         2021
# ...                                                        ...          ...
# Q086ILE042-S53                   Meat Breeder Rearing Facility          171
# Q086ILE043-S53                   Meat Breeder Rearing Facility          171
# Q086ILE044-S53                           Meat Chicken Facility          172
# Q086ILE045-S53                          Poultry - fertile Eggs          172
# Q086SLI001-S53                                  Egg Production          172
#
#                              ANZSIC name                 substance  \
# index
# Q001BOR001-S14  Clay Brick Manufacturing       Arsenic & compounds
# Q001BOR001-S0   Clay Brick Manufacturing     Beryllium & compounds
# Q001BOR001-S69  Clay Brick Manufacturing       Cadmium & compounds
# Q001BOR001-S1   Clay Brick Manufacturing           Carbon monoxide
# Q001BOR001-S52  Clay Brick Manufacturing  Chromium (III) compounds
# ...                                  ...                       ...
# Q086ILE042-S53    Poultry Farming (Meat)           Ammonia (total)
# Q086ILE043-S53    Poultry Farming (Meat)           Ammonia (total)
# Q086ILE044-S53    Poultry Farming (Eggs)           Ammonia (total)
# Q086ILE045-S53    Poultry Farming (Eggs)           Ammonia (total)
# Q086SLI001-S53    Poultry Farming (Eggs)           Ammonia (total)
#
#                 destination quantity_in_kg substance_code
# index
# Q001BOR001-S14    Air Total           6.31            S14
# Q001BOR001-S0     Air Total           0.52             S0
# Q001BOR001-S69    Air Total           2.12            S69
# Q001BOR001-S1     Air Total      170743.00             S1
# Q001BOR001-S52    Air Total          18.80            S52
# ...                     ...            ...            ...
# Q086ILE042-S53    Air Total       13450.00            S53
# Q086ILE043-S53    Air Total       17754.00            S53
# Q086ILE044-S53    Air Total       13610.00            S53
# Q086ILE045-S53    Air Total       34205.00            S53
# Q086SLI001-S53    Air Total       11362.00            S53
#
# [9375 rows x 23 columns]

# %% [markdown]
# We can use `.head()` and `.tail()` to view only top or bottom rows of the table.

# %%
# top rows
df.head()
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q001BOR001-S14          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S0           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S69          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S1           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S52          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q001BOR001-S14           31/01/2007        31/03/2010             N
# Q001BOR001-S0            31/01/2007        31/03/2010             N
# Q001BOR001-S69           31/01/2007        31/03/2010             N
# Q001BOR001-S1            31/01/2007        31/03/2010             N
# Q001BOR001-S52           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id registered_business_name  \
# index
# Q001BOR001-S14               Q001BOR001         BORAL BRICKS P/L
# Q001BOR001-S0                Q001BOR001         BORAL BRICKS P/L
# Q001BOR001-S69               Q001BOR001         BORAL BRICKS P/L
# Q001BOR001-S1                Q001BOR001         BORAL BRICKS P/L
# Q001BOR001-S52               Q001BOR001         BORAL BRICKS P/L
#
#                facility_name  ... site_address_postcode site_latitude  \
# index                         ...
# Q001BOR001-S14         DARRA  ...                  4076    -27.565416
# Q001BOR001-S0          DARRA  ...                  4076    -27.565416
# Q001BOR001-S69         DARRA  ...                  4076    -27.565416
# Q001BOR001-S1          DARRA  ...                  4076    -27.565416
# Q001BOR001-S52         DARRA  ...                  4076    -27.565416
#
#                site_longitude                                 main_activities  \
# index
# Q001BOR001-S14     152.958722  Manufacture and sale of clay bricks and pavers
# Q001BOR001-S0      152.958722  Manufacture and sale of clay bricks and pavers
# Q001BOR001-S69     152.958722  Manufacture and sale of clay bricks and pavers
# Q001BOR001-S1      152.958722  Manufacture and sale of clay bricks and pavers
# Q001BOR001-S52     152.958722  Manufacture and sale of clay bricks and pavers
#
#                 ANZSIC code               ANZSIC name  \
# index
# Q001BOR001-S14         2021  Clay Brick Manufacturing
# Q001BOR001-S0          2021  Clay Brick Manufacturing
# Q001BOR001-S69         2021  Clay Brick Manufacturing
# Q001BOR001-S1          2021  Clay Brick Manufacturing
# Q001BOR001-S52         2021  Clay Brick Manufacturing
#
#                                substance  destination quantity_in_kg  \
# index
# Q001BOR001-S14       Arsenic & compounds    Air Total           6.31
# Q001BOR001-S0      Beryllium & compounds    Air Total           0.52
# Q001BOR001-S69       Cadmium & compounds    Air Total           2.12
# Q001BOR001-S1            Carbon monoxide    Air Total      170743.00
# Q001BOR001-S52  Chromium (III) compounds    Air Total          18.80
#
#                substance_code
# index
# Q001BOR001-S14            S14
# Q001BOR001-S0              S0
# Q001BOR001-S69            S69
# Q001BOR001-S1              S1
# Q001BOR001-S52            S52
#
# [5 rows x 23 columns]

# %%
# bottom rows
df.tail()
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q086ILE042-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE043-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE044-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE045-S53          QLD  2006       1/07/2005    30/06/2006
# Q086SLI001-S53          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q086ILE042-S53           31/01/2007        31/03/2010             N
# Q086ILE043-S53           31/01/2007        31/03/2010             N
# Q086ILE044-S53           31/01/2007        31/03/2010             N
# Q086ILE045-S53           31/01/2007        31/03/2010             N
# Q086SLI001-S53           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id     registered_business_name  \
# index
# Q086ILE042-S53               Q086ILE042  BARTTER ENTERPRISES PTY LTD
# Q086ILE043-S53               Q086ILE043  BARTTER ENTERPRISES PTY LTD
# Q086ILE044-S53               Q086ILE044      PAUL & CHARMAINE SCALIA
# Q086ILE045-S53               Q086ILE045  BARTTER ENTERPRISES PTY LTD
# Q086SLI001-S53               Q086SLI001   SLALOM INVESTMENTS PTY LTD
#
#                               facility_name  ... site_address_postcode  \
# index                                        ...
# Q086ILE042-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE043-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE044-S53                       Scalia  ...                  4341
# Q086ILE045-S53  BARTTER ENTERPRISES PTY LTD  ...                  4343
# Q086SLI001-S53   SLALOM INVESTMENTS PTY LTD  ...                  4356
#
#                site_latitude site_longitude                main_activities  \
# index
# Q086ILE042-S53    -27.374167     152.463889  Meat Breeder Rearing Facility
# Q086ILE043-S53    -27.384722     152.470556  Meat Breeder Rearing Facility
# Q086ILE044-S53    -27.622222     152.470833          Meat Chicken Facility
# Q086ILE045-S53    -27.458349     152.367415         Poultry - fertile Eggs
# Q086SLI001-S53    -27.759444     151.539444                 Egg Production
#
#                 ANZSIC code             ANZSIC name        substance  \
# index
# Q086ILE042-S53          171  Poultry Farming (Meat)  Ammonia (total)
# Q086ILE043-S53          171  Poultry Farming (Meat)  Ammonia (total)
# Q086ILE044-S53          172  Poultry Farming (Eggs)  Ammonia (total)
# Q086ILE045-S53          172  Poultry Farming (Eggs)  Ammonia (total)
# Q086SLI001-S53          172  Poultry Farming (Eggs)  Ammonia (total)
#
#                 destination quantity_in_kg substance_code
# index
# Q086ILE042-S53    Air Total        13450.0            S53
# Q086ILE043-S53    Air Total        17754.0            S53
# Q086ILE044-S53    Air Total        13610.0            S53
# Q086ILE045-S53    Air Total        34205.0            S53
# Q086SLI001-S53    Air Total        11362.0            S53
#
# [5 rows x 23 columns]

# %% [markdown]
# __Note:__ You can specify how many rows from the top or bottom of the table you want by passing in a number.<br>
# e.g. `df.head(10)` or `df.tail(3)`

# %% [markdown]
# We can use `.columns` to get a list of column names.

# %%
df.columns
# Out:
# Index(['jurisdiction', 'Year', 'data_start_date', 'data_end_date',
#        'first_published_date', 'last_updated_date', 'sub_threshold',
#        'jurisdiction_facility_id', 'registered_business_name', 'facility_name',
#        'site_address_street', 'site_address_suburb', 'site_address_state',
#        'site_address_postcode', 'site_latitude', 'site_longitude',
#        'main_activities', 'ANZSIC code', 'ANZSIC name', 'substance',
#        'destination', 'quantity_in_kg', 'substance_code'],
#       dtype='object')

# %% [markdown]
# Using `.info()` method you can get a list of the columns and the type of data stored in each.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9375 entries, Q001BOR001-S14 to Q086SLI001-S53
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   jurisdiction              9375 non-null   object
#  1   Year                      9375 non-null   int64
#  2   data_start_date           9375 non-null   object
#  3   data_end_date             9375 non-null   object
#  4   first_published_date      9375 non-null   object
#  5   last_updated_date         9375 non-null   object
#  6   sub_threshold             9375 non-null   object
#  7   jurisdiction_facility_id  9375 non-null   object
#  8   registered_business_name  9375 non-null   object
#  9   facility_name             9375 non-null   object
#  10  site_address_street       9375 non-null   object
#  11  site_address_suburb       9375 non-null   object
#  12  site_address_state        9375 non-null   object
#  13  site_address_postcode     9375 non-null   int64
#  14  site_latitude             9375 non-null   float64
#  15  site_longitude            9375 non-null   float64
#  16  main_activities           9375 non-null   object
#  17  ANZSIC code               9375 non-null   int64
#  18  ANZSIC name               9375 non-null   object
#  19  substance                 9375 non-null   object
#  20  destination               9375 non-null   object
#  21  quantity_in_kg            9375 non-null   float64
#  22  substance_code            9375 non-null   object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 1.7+ MB

# %% [markdown]
# You can also get some basic statistical analysis of the data using `.describe()` method.

# %%
df.describe()
# Out:
#          Year  site_address_postcode  site_latitude  site_longitude  \
# count  9375.0            9375.000000    9375.000000     9375.000000
# mean   2006.0            4541.100373     -24.034062      149.625650
# std       0.0             267.957741       4.200536        3.838858
# min    2006.0            4006.000000     -28.913000      138.123778
# 25%    2006.0            4340.000000     -27.466667      147.867500
# 50%    2006.0            4650.000000     -25.395083      151.120704
# 75%    2006.0            4742.000000     -21.762662      152.928364
# max    2006.0            4895.000000      -9.232500      153.512054
#
#        ANZSIC code  quantity_in_kg
# count  9375.000000    9.375000e+03
# mean   1987.567893    1.205184e+05
# std    1237.421112    2.803064e+06
# min     143.000000    0.000000e+00
# 25%    1111.000000    2.600000e-01
# 50%    1841.000000    1.210000e+01
# 75%    2921.000000    7.310000e+02
# max    9531.000000    2.385545e+08

# %% [markdown]
# To get a more detailed analysis of the data in the table we can use a package called `pandas-profiling`. This package extends Pandas and adds detailed reports of the data.
#
# <a href="./profile_qld-air-emissions.html">If you get an error use this pre-made report</a>

# %%
# profile = pp.ProfileReport(df, title='Pandas Profiling Report')
# profile.to_file("profile_qld-air-emissions.html")
# profile

# %% [markdown]
# ## Subsetting and indexing

# %% [markdown]
# There are multiple ways to get a subset of the data. `loc` is used when we want to specify the names of columns and `iloc` when we want to use the index of the columns.<br>

# %% [markdown]
# We can use `loc` by specifying the rows and columns we want by name. e.g. `df.loc[{row(s)}, {column(s) name}]`

# %% [markdown]
# we can get a subset of a single column:

# %%
df.loc[:'Q001BOR001-S52', "jurisdiction"]

# Notice we used :NAME for rows which means give me the rows up to NAME
# Out:
# index
# Q001BOR001-S14    QLD
# Q001BOR001-S0     QLD
# Q001BOR001-S69    QLD
# Q001BOR001-S1     QLD
# Q001BOR001-S52    QLD
# Name: jurisdiction, dtype: object

# %% [markdown]
# __Note:__ `loc` has a unique property. Since it is designed to work with names of columns and rows, when you want to get a subset of rows, the result it returns is inclusive. In other words when we passed in `:10` in almost every other python object that means `0` to `9`, but in `loc` it means `0` to `10`. Likewise, `10:20` in `loc` means rows `10` to `20`.

# %% [markdown]
# We can also get a subset of multiple columns by passing a list of columns we want.

# %%
df.loc['Q001BOR001-S14':'Q001BOR001-S52', ["Year", "facility_name", "substance", "quantity_in_kg"]]
# Out:
#                 Year facility_name                 substance  quantity_in_kg
# index
# Q001BOR001-S14  2006         DARRA       Arsenic & compounds            6.31
# Q001BOR001-S0   2006         DARRA     Beryllium & compounds            0.52
# Q001BOR001-S69  2006         DARRA       Cadmium & compounds            2.12
# Q001BOR001-S1   2006         DARRA           Carbon monoxide       170743.00
# Q001BOR001-S52  2006         DARRA  Chromium (III) compounds           18.80

# %% [markdown]
# `iloc` works similar to `loc`, but instead of names we pass in index of the rows or the columns we want.

# %%
# a single column
df.iloc[:10, 5]
# Out:
# index
# Q001BOR001-S14    31/03/2010
# Q001BOR001-S0     31/03/2010
# Q001BOR001-S69    31/03/2010
# Q001BOR001-S1     31/03/2010
# Q001BOR001-S52    31/03/2010
# Q001BOR001-S49    31/03/2010
# Q001BOR001-S36    31/03/2010
# Q001BOR001-S27    31/03/2010
# Q001BOR001-S5     31/03/2010
# Q001BOR001-S23    31/03/2010
# Name: last_updated_date, dtype: object

# %% [markdown]
# __Note:__ Notice the number of rows here, and compare it with when we used `loc`.

# %%
# You can see the number corresponding to a column name here
list(enumerate(df.columns))
# Out:
# [(0, 'jurisdiction'),
#  (1, 'Year'),
#  (2, 'data_start_date'),
#  (3, 'data_end_date'),
#  (4, 'first_published_date'),
#  (5, 'last_updated_date'),
#  (6, 'sub_threshold'),
#  (7, 'jurisdiction_facility_id'),
#  (8, 'registered_business_name'),
#  (9, 'facility_name'),
#  (10, 'site_address_street'),
#  (11, 'site_address_suburb'),
#  (12, 'site_address_state'),
#  (13, 'site_address_postcode'),
#  (14, 'site_latitude'),
#  (15, 'site_longitude'),
#  (16, 'main_activities'),
#  (17, 'ANZSIC code'),
#  (18, 'ANZSIC name'),
#  (19, 'substance'),
#  (20, 'destination'),
#  (21, 'quantity_in_kg'),
#  (22, 'substance_code')]

# %%
# multiple columns
df.iloc[10:20, [1, 9, -3, -1]]
# Out:
#                 Year facility_name destination substance_code
# index
# Q001BOR001-S45  2006         DARRA   Air Total            S45
# Q001BOR001-S29  2006         DARRA   Air Total            S29
# Q001BOR001-S8   2006         DARRA   Air Total             S8
# Q001BOR001-S12  2006         DARRA   Air Total            S12
# Q001BOR001-S46  2006         DARRA   Air Total            S46
# Q001BOR001-S55  2006         DARRA   Air Total            S55
# Q001BOR001-S72  2006         DARRA   Air Total            S72
# Q001BOR001-S40  2006         DARRA   Air Total            S40
# Q001BOR001-S6   2006         DARRA   Air Total             S6
# Q001BOR001-S60  2006         DARRA   Air Total            S60

# %% [markdown]
# Another useful method to get a subset of data is using boolean indexing. Booleans are either True or False. If we pass a list of booleans, pandas will return only the rows with True in the list.

# %%
mask = df["substance"] == "Oxides of Nitrogen"
mask
# Out:
# index
# Q001BOR001-S14    False
# Q001BOR001-S0     False
# Q001BOR001-S69    False
# Q001BOR001-S1     False
# Q001BOR001-S52    False
#                   ...
# Q086ILE042-S53    False
# Q086ILE043-S53    False
# Q086ILE044-S53    False
# Q086ILE045-S53    False
# Q086SLI001-S53    False
# Name: substance, Length: 9375, dtype: bool

# %% [markdown]
# The list above has the value true only on the rows where the substance is "Oxides of Nitrogen". <br>
# __Note:__ you can only see a small portion of the data so the True values might not be visible.

# %% [markdown]
# Now if we pass this as an index into a data frame we only get the rows where substance is "Oxides of Nitrogen".

# %%
df[mask]
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q001BOR001-S72          QLD  2006       1/07/2005    30/06/2006
# Q001CPL001-S72          QLD  2006       1/07/2005    30/06/2006
# Q001PGH001-S72          QLD  2006       1/07/2005    30/06/2006
# Q001PGH002-S72          QLD  2006       1/07/2005    30/06/2006
# Q001PGH003-S72          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q080QBH001-S72          QLD  2006       1/07/2005    30/06/2006
# Q082BOR001-S72          QLD  2006       1/07/2005    30/06/2006
# Q085CRL001-S72          QLD  2006       1/07/2005    30/06/2006
# Q085CRL002-S72          QLD  2006       1/07/2005    30/06/2006
# Q085CRL003-S72          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q001BOR001-S72           31/01/2007        31/03/2010             N
# Q001CPL001-S72           31/01/2007        31/03/2010             N
# Q001PGH001-S72           31/01/2007        31/03/2010             N
# Q001PGH002-S72           31/01/2007        31/03/2010             N
# Q001PGH003-S72           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q080QBH001-S72           31/01/2007        31/03/2010             N
# Q082BOR001-S72           31/01/2007        31/03/2010             N
# Q085CRL001-S72           31/01/2007        31/03/2010             N
# Q085CRL002-S72           31/01/2007        31/03/2010             N
# Q085CRL003-S72           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id          registered_business_name  \
# index
# Q001BOR001-S72               Q001BOR001                  BORAL BRICKS P/L
# Q001CPL001-S72               Q001CPL001                  CLAYPAVE PTY LTD
# Q001PGH001-S72               Q001PGH001         CSR BUILDING PRODUCTS LTD
# Q001PGH002-S72               Q001PGH002         CSR BUILDING PRODUCTS LTD
# Q001PGH003-S72               Q001PGH003         CSR BUILDING PRODUCTS LTD
# ...                                 ...                               ...
# Q080QBH001-S72               Q080QBH001  QUEENSLAND BULK HANDLING PTY LTD
# Q082BOR001-S72               Q082BOR001             BORAL AUST GYPSUM LTD
# Q085CRL001-S72               Q085CRL001           CONSOLIDATED RUTILE LTD
# Q085CRL002-S72               Q085CRL002           CONSOLIDATED RUTILE LTD
# Q085CRL003-S72               Q085CRL003           CONSOLIDATED RUTILE LTD
#
#                                    facility_name  ... site_address_postcode  \
# index                                             ...
# Q001BOR001-S72                             DARRA  ...                  4076
# Q001CPL001-S72                  CLAYPAVE PTY LTD  ...                  4303
# Q001PGH001-S72               PGH Bricks & Pavers  ...                  4500
# Q001PGH002-S72             PGH Bricks and Pavers  ...                  4563
# Q001PGH003-S72             PGH Bricks and Pavers  ...                  4077
# ...                                          ...  ...                   ...
# Q080QBH001-S72  QUEENSLAND BULK HANDLING PTY LTD  ...                  4178
# Q082BOR001-S72      Boral Plasterboard Northgate  ...                  4013
# Q085CRL001-S72         Pinkenba Processing Plant  ...                  4008
# Q085CRL002-S72                     Ibis Minesite  ...                  4163
# Q085CRL003-S72                 Yarraman Minesite  ...                  4163
#
#                site_latitude site_longitude  \
# index
# Q001BOR001-S72    -27.565416     152.958722
# Q001CPL001-S72    -27.605638     152.832185
# Q001PGH001-S72    -27.317025     152.996906
# Q001PGH002-S72    -26.392025     152.925239
# Q001PGH003-S72    -27.572250     152.969800
# ...                      ...            ...
# Q080QBH001-S72    -27.388333     153.162222
# Q082BOR001-S72    -27.392803     153.071054
# Q085CRL001-S72    -27.436507     153.103643
# Q085CRL002-S72    -27.591667     153.458330
# Q085CRL003-S72    -27.466667     153.500000
#
#                                                   main_activities  \
# index
# Q001BOR001-S72     Manufacture and sale of clay bricks and pavers
# Q001CPL001-S72  Manufacture of clay pavers, bricks and refract...
# Q001PGH001-S72               Manufacture of Clay Brick and Pavers
# Q001PGH002-S72      Manufacture of clay bricks, blocks and pavers
# Q001PGH003-S72                         Manufacture of clay bricks
# ...                                                           ...
# Q080QBH001-S72  Coal unloading, stockpiling and loading to shi...
# Q082BOR001-S72            Manufacture of plasterboard and plaster
# Q085CRL001-S72                                 Rutile sand mining
# Q085CRL002-S72               Sand quarrying, washing or screening
# Q085CRL003-S72                                 Rutile sand mining
#
#                 ANZSIC code                                   ANZSIC name  \
# index
# Q001BOR001-S72         2021                      Clay Brick Manufacturing
# Q001CPL001-S72         2021                      Clay Brick Manufacturing
# Q001PGH001-S72         2021                      Clay Brick Manufacturing
# Q001PGH002-S72         2021                      Clay Brick Manufacturing
# Q001PGH003-S72         2021                      Clay Brick Manufacturing
# ...                     ...                                           ...
# Q080QBH001-S72         5212  Port and Water Transport Terminal Operations
# Q082BOR001-S72         2032                 Plaster Product Manufacturing
# Q085CRL001-S72          805                           Mineral Sand Mining
# Q085CRL002-S72          805                           Mineral Sand Mining
# Q085CRL003-S72          805                           Mineral Sand Mining
#
#                          substance  destination quantity_in_kg substance_code
# index
# Q001BOR001-S72  Oxides of Nitrogen    Air Total       108967.0            S72
# Q001CPL001-S72  Oxides of Nitrogen    Air Total        17900.0            S72
# Q001PGH001-S72  Oxides of Nitrogen    Air Total        12792.0            S72
# Q001PGH002-S72  Oxides of Nitrogen    Air Total        17682.0            S72
# Q001PGH003-S72  Oxides of Nitrogen    Air Total         2613.0            S72
# ...                            ...          ...            ...            ...
# Q080QBH001-S72  Oxides of Nitrogen    Air Total        11651.0            S72
# Q082BOR001-S72  Oxides of Nitrogen    Air Total        28841.0            S72
# Q085CRL001-S72  Oxides of Nitrogen    Air Total        10286.0            S72
# Q085CRL002-S72  Oxides of Nitrogen    Air Total       130881.0            S72
# Q085CRL003-S72  Oxides of Nitrogen    Air Total        85680.0            S72
#
# [394 rows x 23 columns]

# %% [markdown]
# This method can also be used with `loc` and `iloc`.

# %%
df.loc[
    df["substance"] == "Oxides of Nitrogen",
    ["facility_name", "substance", "quantity_in_kg"],
]
# Out:
#                                    facility_name           substance  \
# index
# Q001BOR001-S72                             DARRA  Oxides of Nitrogen
# Q001CPL001-S72                  CLAYPAVE PTY LTD  Oxides of Nitrogen
# Q001PGH001-S72               PGH Bricks & Pavers  Oxides of Nitrogen
# Q001PGH002-S72             PGH Bricks and Pavers  Oxides of Nitrogen
# Q001PGH003-S72             PGH Bricks and Pavers  Oxides of Nitrogen
# ...                                          ...                 ...
# Q080QBH001-S72  QUEENSLAND BULK HANDLING PTY LTD  Oxides of Nitrogen
# Q082BOR001-S72      Boral Plasterboard Northgate  Oxides of Nitrogen
# Q085CRL001-S72         Pinkenba Processing Plant  Oxides of Nitrogen
# Q085CRL002-S72                     Ibis Minesite  Oxides of Nitrogen
# Q085CRL003-S72                 Yarraman Minesite  Oxides of Nitrogen
#
#                 quantity_in_kg
# index
# Q001BOR001-S72        108967.0
# Q001CPL001-S72         17900.0
# Q001PGH001-S72         12792.0
# Q001PGH002-S72         17682.0
# Q001PGH003-S72          2613.0
# ...                        ...
# Q080QBH001-S72         11651.0
# Q082BOR001-S72         28841.0
# Q085CRL001-S72         10286.0
# Q085CRL002-S72        130881.0
# Q085CRL003-S72         85680.0
#
# [394 rows x 3 columns]

# %% [markdown]
# ## Sorting
# To sort the data in the table based on a certain column we can use the `.sort_values` method. When sorting we need to specify which column we want to sort and whether we want to sort in ascending order or descending order.

# %%
df2 = df.sort_values(by="jurisdiction_facility_id", ascending=False)
df2
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q086SLI001-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE045-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE044-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE043-S53          QLD  2006       1/07/2005    30/06/2006
# Q086ILE042-S53          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q001BOR001-S6           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S60          QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S2           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S9           QLD  2006       1/07/2005    30/06/2006
# Q001BOR001-S14          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q086SLI001-S53           31/01/2007        31/03/2010             N
# Q086ILE045-S53           31/01/2007        31/03/2010             N
# Q086ILE044-S53           31/01/2007        31/03/2010             N
# Q086ILE043-S53           31/01/2007        31/03/2010             N
# Q086ILE042-S53           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q001BOR001-S6            31/01/2007        31/03/2010             N
# Q001BOR001-S60           31/01/2007        31/03/2010             N
# Q001BOR001-S2            31/01/2007        31/03/2010             N
# Q001BOR001-S9            31/01/2007        31/03/2010             N
# Q001BOR001-S14           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id     registered_business_name  \
# index
# Q086SLI001-S53               Q086SLI001   SLALOM INVESTMENTS PTY LTD
# Q086ILE045-S53               Q086ILE045  BARTTER ENTERPRISES PTY LTD
# Q086ILE044-S53               Q086ILE044      PAUL & CHARMAINE SCALIA
# Q086ILE043-S53               Q086ILE043  BARTTER ENTERPRISES PTY LTD
# Q086ILE042-S53               Q086ILE042  BARTTER ENTERPRISES PTY LTD
# ...                                 ...                          ...
# Q001BOR001-S6                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S60               Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S2                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S9                Q001BOR001             BORAL BRICKS P/L
# Q001BOR001-S14               Q001BOR001             BORAL BRICKS P/L
#
#                               facility_name  ... site_address_postcode  \
# index                                        ...
# Q086SLI001-S53   SLALOM INVESTMENTS PTY LTD  ...                  4356
# Q086ILE045-S53  BARTTER ENTERPRISES PTY LTD  ...                  4343
# Q086ILE044-S53                       Scalia  ...                  4341
# Q086ILE043-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# Q086ILE042-S53  BARTTER ENTERPRISES PTY LTD  ...                  4311
# ...                                     ...  ...                   ...
# Q001BOR001-S6                         DARRA  ...                  4076
# Q001BOR001-S60                        DARRA  ...                  4076
# Q001BOR001-S2                         DARRA  ...                  4076
# Q001BOR001-S9                         DARRA  ...                  4076
# Q001BOR001-S14                        DARRA  ...                  4076
#
#                site_latitude site_longitude  \
# index
# Q086SLI001-S53    -27.759444     151.539444
# Q086ILE045-S53    -27.458349     152.367415
# Q086ILE044-S53    -27.622222     152.470833
# Q086ILE043-S53    -27.384722     152.470556
# Q086ILE042-S53    -27.374167     152.463889
# ...                      ...            ...
# Q001BOR001-S6     -27.565416     152.958722
# Q001BOR001-S60    -27.565416     152.958722
# Q001BOR001-S2     -27.565416     152.958722
# Q001BOR001-S9     -27.565416     152.958722
# Q001BOR001-S14    -27.565416     152.958722
#
#                                                main_activities  ANZSIC code  \
# index
# Q086SLI001-S53                                  Egg Production          172
# Q086ILE045-S53                          Poultry - fertile Eggs          172
# Q086ILE044-S53                           Meat Chicken Facility          172
# Q086ILE043-S53                   Meat Breeder Rearing Facility          171
# Q086ILE042-S53                   Meat Breeder Rearing Facility          171
# ...                                                        ...          ...
# Q001BOR001-S6   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S60  Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S2   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S9   Manufacture and sale of clay bricks and pavers         2021
# Q001BOR001-S14  Manufacture and sale of clay bricks and pavers         2021
#
#                              ANZSIC name  \
# index
# Q086SLI001-S53    Poultry Farming (Eggs)
# Q086ILE045-S53    Poultry Farming (Eggs)
# Q086ILE044-S53    Poultry Farming (Eggs)
# Q086ILE043-S53    Poultry Farming (Meat)
# Q086ILE042-S53    Poultry Farming (Meat)
# ...                                  ...
# Q001BOR001-S6   Clay Brick Manufacturing
# Q001BOR001-S60  Clay Brick Manufacturing
# Q001BOR001-S2   Clay Brick Manufacturing
# Q001BOR001-S9   Clay Brick Manufacturing
# Q001BOR001-S14  Clay Brick Manufacturing
#
#                                                  substance  destination  \
# index
# Q086SLI001-S53                             Ammonia (total)    Air Total
# Q086ILE045-S53                             Ammonia (total)    Air Total
# Q086ILE044-S53                             Ammonia (total)    Air Total
# Q086ILE043-S53                             Ammonia (total)    Air Total
# Q086ILE042-S53                             Ammonia (total)    Air Total
# ...                                                    ...          ...
# Q001BOR001-S6     Polychlorinated dioxins and furans (TEQ)    Air Total
# Q001BOR001-S60  Polycyclic aromatic hydrocarbons (B[a]Peq)    Air Total
# Q001BOR001-S2                               Sulfur dioxide    Air Total
# Q001BOR001-S9             Total Volatile Organic Compounds    Air Total
# Q001BOR001-S14                         Arsenic & compounds    Air Total
#
#                quantity_in_kg substance_code
# index
# Q086SLI001-S53       11362.00            S53
# Q086ILE045-S53       34205.00            S53
# Q086ILE044-S53       13610.00            S53
# Q086ILE043-S53       17754.00            S53
# Q086ILE042-S53       13450.00            S53
# ...                       ...            ...
# Q001BOR001-S6            0.00             S6
# Q001BOR001-S60           0.00            S60
# Q001BOR001-S2       109293.00             S2
# Q001BOR001-S9         8656.00             S9
# Q001BOR001-S14           6.31            S14
#
# [9375 rows x 23 columns]

# %% [markdown]
# __Note:__ many methods return the result as a data frame as well. This allows us to chain these operations to make the code shorter and easier to read.<br>

# %% [markdown]
# Let's sort the table based on the amount of Oxides of Nitrogen only.

# %%
df.loc[df["substance"] == "Oxides of Nitrogen"].sort_values(
    by="quantity_in_kg", ascending=False
)
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q019TAR001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019NRG001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019SCL001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019CSE001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019MIL001-S72          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q080BHP001-S72          QLD  2006       1/07/2005    30/06/2006
# Q031BCC001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019ERG037-S72          QLD  2006       1/07/2005    30/06/2006
# Q019ERG038-S72          QLD  2006       1/07/2005    30/06/2006
# Q019ERG036-S72          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q019TAR001-S72           31/01/2007        31/03/2010             N
# Q019NRG001-S72           31/01/2007        31/03/2010             N
# Q019SCL001-S72           31/01/2007        31/03/2010             N
# Q019CSE001-S72           31/01/2007        31/03/2010             N
# Q019MIL001-S72           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q080BHP001-S72           31/01/2007        31/03/2010             N
# Q031BCC001-S72           31/01/2007        31/03/2010             N
# Q019ERG037-S72           31/01/2007        31/03/2010             N
# Q019ERG038-S72           31/01/2007        31/03/2010             N
# Q019ERG036-S72           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id              registered_business_name  \
# index
# Q019TAR001-S72               Q019TAR001                TARONG ENERGY CORP LTD
# Q019NRG001-S72               Q019NRG001  NRG GLADSTONE OPERATING SERVICES P/L
# Q019SCL001-S72               Q019SCL001                     STANWELL CORP LTD
# Q019CSE001-S72               Q019CSE001                         CS ENERGY LTD
# Q019MIL001-S72               Q019MIL001           MILLMERRAN OPERATING CO P/L
# ...                                 ...                                   ...
# Q080BHP001-S72               Q080BHP001                               BHP LTD
# Q031BCC001-S72               Q031BCC001                 BRISBANE CITY COUNCIL
# Q019ERG037-S72               Q019ERG037                 ERGON ENERGY CORP LTD
# Q019ERG038-S72               Q019ERG038                 ERGON ENERGY CORP LTD
# Q019ERG036-S72               Q019ERG036     ERGON ENERGY UTILITY SERVICES P/L
#
#                                   facility_name  ... site_address_postcode  \
# index                                            ...
# Q019TAR001-S72             Tarong Power Station  ...                  4615
# Q019NRG001-S72          Gladstone Power Station  ...                  4680
# Q019SCL001-S72           Stanwell Power Station  ...                  4702
# Q019CSE001-S72    Callide Power Station (A & B)  ...                  4715
# Q019MIL001-S72                 Millmerran Power  ...                  4357
# ...                                         ...  ...                   ...
# Q080BHP001-S72         Cannington Port Facility  ...                  4810
# Q031BCC001-S72         Eagle Farm Asphalt Plant  ...                  4009
# Q019ERG037-S72                          Dajarra  ...                  4825
# Q019ERG038-S72                           Winton  ...                  4735
# Q019ERG036-S72  Sun Coast Gold Macadamia Gympie  ...                  4570
#
#                site_latitude site_longitude  \
# index
# Q019TAR001-S72    -26.786480     151.914128
# Q019NRG001-S72    -23.856484     151.218582
# Q019SCL001-S72    -23.508888     150.317777
# Q019CSE001-S72    -24.345000     150.618900
# Q019MIL001-S72    -27.962800     151.278200
# ...                      ...            ...
# Q080BHP001-S72    -19.253466     146.832201
# Q031BCC001-S72    -27.439268     153.084179
# Q019ERG037-S72    -21.683333     139.500000
# Q019ERG038-S72    -22.383333     143.033333
# Q019ERG036-S72    -26.225830     152.698610
#
#                                                   main_activities  \
# index
# Q019TAR001-S72  Electricity generation using coal or coal deri...
# Q019NRG001-S72  Electricity generation using coal or coal deri...
# Q019SCL001-S72  Combustion of fossil fuels to produce electricity
# Q019CSE001-S72  Combustion of fossil fuels to produce electricity
# Q019MIL001-S72       Power Generation from Fossil fuel combustion
# ...                                                           ...
# Q080BHP001-S72  Storage and Loading of Lead and Zinc Concentrates
# Q031BCC001-S72                                Asphalt Manufacture
# Q019ERG037-S72  Isolated power station, Diesel Internal Combus...
# Q019ERG038-S72  Isolated power station, Diesel Internal Combus...
# Q019ERG036-S72  Burning Macadamia Nut Shells to produce electr...
#
#                 ANZSIC code                                     ANZSIC name  \
# index
# Q019TAR001-S72         2611              Fossil Fuel Electricity Generation
# Q019NRG001-S72         2611              Fossil Fuel Electricity Generation
# Q019SCL001-S72         2611              Fossil Fuel Electricity Generation
# Q019CSE001-S72         2611              Fossil Fuel Electricity Generation
# Q019MIL001-S72         2611              Fossil Fuel Electricity Generation
# ...                     ...                                             ...
# Q080BHP001-S72         5212    Port and Water Transport Terminal Operations
# Q031BCC001-S72         1709  Other Petroleum and Coal Product Manufacturing
# Q019ERG037-S72         2611              Fossil Fuel Electricity Generation
# Q019ERG038-S72         2611              Fossil Fuel Electricity Generation
# Q019ERG036-S72         2619                    Other Electricity Generation
#
#                          substance  destination quantity_in_kg substance_code
# index
# Q019TAR001-S72  Oxides of Nitrogen    Air Total     48428084.0            S72
# Q019NRG001-S72  Oxides of Nitrogen    Air Total     41248832.0            S72
# Q019SCL001-S72  Oxides of Nitrogen    Air Total     37912188.0            S72
# Q019CSE001-S72  Oxides of Nitrogen    Air Total     19416120.0            S72
# Q019MIL001-S72  Oxides of Nitrogen    Air Total     12500000.0            S72
# ...                            ...          ...            ...            ...
# Q080BHP001-S72  Oxides of Nitrogen    Air Total          110.0            S72
# Q031BCC001-S72  Oxides of Nitrogen    Air Total           97.0            S72
# Q019ERG037-S72  Oxides of Nitrogen    Air Total           86.6            S72
# Q019ERG038-S72  Oxides of Nitrogen    Air Total           16.0            S72
# Q019ERG036-S72  Oxides of Nitrogen    Air Total            5.6            S72
#
# [394 rows x 23 columns]

# %% [markdown]
# We can also sort based on multiple columns. To do so we need to pass in the name of the column in a list (in the order we want them to be used for sorting) and also a list to specify whether each column should be ascending or descending.

# %%
df.loc[df["substance"] == "Oxides of Nitrogen"].sort_values(
    by=["site_address_postcode", "facility_name"], ascending=[True, False]
)
# Out:
#                jurisdiction  Year data_start_date data_end_date  \
# index
# Q031BOR002-S72          QLD  2006       1/07/2005    30/06/2006
# Q022SHE017-S72          QLD  2006       1/01/2005    31/12/2005
# Q085CRL001-S72          QLD  2006       1/07/2005    30/06/2006
# Q023BCC004-S72          QLD  2006       1/07/2005    30/06/2006
# Q040IGC001-S72          QLD  2006       1/07/2005    30/06/2006
# ...                     ...   ...             ...           ...
# Q028CLT001-S72          QLD  2006       1/07/2005    30/06/2006
# Q026MDL001-S72          QLD  2006       1/07/2005    30/06/2006
# Q080PAS001-S72          QLD  2006       1/07/2005    30/06/2006
# Q019END003-S72          QLD  2006       1/07/2005    30/06/2006
# Q019ERG034-S72          QLD  2006       1/07/2005    30/06/2006
#
#                first_published_date last_updated_date sub_threshold  \
# index
# Q031BOR002-S72           31/01/2007        31/03/2010             N
# Q022SHE017-S72           31/01/2007        31/03/2010             N
# Q085CRL001-S72           31/01/2007        31/03/2010             N
# Q023BCC004-S72           31/01/2007        31/03/2010             N
# Q040IGC001-S72           31/01/2007        31/03/2010             N
# ...                             ...               ...           ...
# Q028CLT001-S72           31/01/2007        31/03/2010             N
# Q026MDL001-S72           31/01/2007        31/03/2010             N
# Q080PAS001-S72           31/01/2007        31/03/2010             N
# Q019END003-S72           31/01/2007        31/03/2010             N
# Q019ERG034-S72           31/01/2007        31/03/2010             N
#
#                jurisdiction_facility_id  \
# index
# Q031BOR002-S72               Q031BOR002
# Q022SHE017-S72               Q022SHE017
# Q085CRL001-S72               Q085CRL001
# Q023BCC004-S72               Q023BCC004
# Q040IGC001-S72               Q040IGC001
# ...                                 ...
# Q028CLT001-S72               Q028CLT001
# Q026MDL001-S72               Q026MDL001
# Q080PAS001-S72               Q080PAS001
# Q019END003-S72               Q019END003
# Q019ERG034-S72               Q019ERG034
#
#                               registered_business_name  \
# index
# Q031BOR002-S72               BORAL RESOURCES (QLD) P/L
# Q022SHE017-S72                THE SHELL CO OF AUST LTD
# Q085CRL001-S72                 CONSOLIDATED RUTILE LTD
# Q023BCC004-S72  BRISBANE CITY COUNCIL - BRISBANE WATER
# Q040IGC001-S72         INDUSTRIAL GALVANIZERS CORP P/L
# ...                                                ...
# Q028CLT001-S72              NERADA TEA ESTATES PTY LTD
# Q026MDL001-S72                  MALANDA DAIRYFOODS LTD
# Q080PAS001-S72                     ZINIFEX CENTURY LTD
# Q019END003-S72                       EDL NGD (QLD) P/L
# Q019ERG034-S72                   ERGON ENERGY CORP LTD
#
#                                      facility_name  ... site_address_postcode  \
# index                                               ...
# Q031BOR002-S72                       Boral Asphalt  ...                  4007
# Q022SHE017-S72                    PinkenbaTerminal  ...                  4008
# Q085CRL001-S72           Pinkenba Processing Plant  ...                  4008
# Q023BCC004-S72                  Luggage Point WWTP  ...                  4008
# Q040IGC001-S72     Industrial Galvanizers Brisbane  ...                  4008
# ...                                            ...  ...                   ...
# Q028CLT001-S72               Glen Allyn Tea Estate  ...                  4885
# Q026MDL001-S72               Dairy Farmers Malanda  ...                  4885
# Q080PAS001-S72  Zinifex Century Mine- Karumba Port  ...                  4891
# Q019END003-S72     Karumba Port Site Power Station  ...                  4891
# Q019ERG034-S72                            Cooktown  ...                  4895
#
#                site_latitude site_longitude  \
# index
# Q031BOR002-S72    -27.438436     153.078419
# Q022SHE017-S72    -27.418691     153.128295
# Q085CRL001-S72    -27.436507     153.103643
# Q023BCC004-S72    -27.380596     153.150174
# Q040IGC001-S72    -27.438421     153.101186
# ...                      ...            ...
# Q028CLT001-S72    -17.383500     145.667000
# Q026MDL001-S72    -17.351912     145.595819
# Q080PAS001-S72    -17.498056     140.836944
# Q019END003-S72    -17.495816     140.830708
# Q019ERG034-S72    -15.478060     145.249690
#
#                                                   main_activities  \
# index
# Q031BOR002-S72                              Asphalt Manufacturing
# Q022SHE017-S72  Hydrocarbon Storage / Distribution & Bitumen P...
# Q085CRL001-S72                                 Rutile sand mining
# Q023BCC004-S72                  Sewerage and Wastewater Treatment
# Q040IGC001-S72                       Hot Dip Galvanizing of Steel
# ...                                                           ...
# Q028CLT001-S72  Nerada grows tea and processes the G/Leaf in t...
# Q026MDL001-S72                                    Milk Processing
# Q080PAS001-S72  Filtering and Drying of lead and zinc concentr...
# Q019END003-S72                                   Power Generation
# Q019ERG034-S72  Isolated power station, Diesel Internal Combus...
#
#                 ANZSIC code                                     ANZSIC name  \
# index
# Q031BOR002-S72         1709  Other Petroleum and Coal Product Manufacturing
# Q022SHE017-S72         3321                   Petroleum Product Wholesaling
# Q085CRL001-S72          805                             Mineral Sand Mining
# Q023BCC004-S72         2812                  Sewerage and Drainage Services
# Q040IGC001-S72         2293                     Metal Coating and Finishing
# ...                     ...                                             ...
# Q028CLT001-S72         1199         Other Food Product Manufacturing n.e.c.
# Q026MDL001-S72         1131                       Milk and Cream Processing
# Q080PAS001-S72          807                     Silver-Lead-Zinc Ore Mining
# Q019END003-S72         2611              Fossil Fuel Electricity Generation
# Q019ERG034-S72         2611              Fossil Fuel Electricity Generation
#
#                          substance  destination quantity_in_kg substance_code
# index
# Q031BOR002-S72  Oxides of Nitrogen    Air Total         9823.0            S72
# Q022SHE017-S72  Oxides of Nitrogen    Air Total         3504.0            S72
# Q085CRL001-S72  Oxides of Nitrogen    Air Total        10286.0            S72
# Q023BCC004-S72  Oxides of Nitrogen    Air Total         5100.0            S72
# Q040IGC001-S72  Oxides of Nitrogen    Air Total         2525.0            S72
# ...                            ...          ...            ...            ...
# Q028CLT001-S72  Oxides of Nitrogen    Air Total         9672.0            S72
# Q026MDL001-S72  Oxides of Nitrogen    Air Total         4063.0            S72
# Q080PAS001-S72  Oxides of Nitrogen    Air Total        19871.0            S72
# Q019END003-S72  Oxides of Nitrogen    Air Total       276732.0            S72
# Q019ERG034-S72  Oxides of Nitrogen    Air Total         4280.0            S72
#
# [394 rows x 23 columns]

# %% [markdown]
# ## Data operations
# -merge
# -groupby
# -pivot_table
# -crosstab

# %% [markdown]
# __Groupby:__ It aggregates the data into groups (similar to groupby in SQL). For instance, what if we wanted an average emission of each substance across all the sites? To calculate that we use `.groupby()` method.

# %% [markdown]
# Since we want the average amount of substances, the columns we need will be __substance__ and __quantity_in_kg__.

# %%
groups = df[["substance", "quantity_in_kg"]].groupby(by="substance")
groups

# %%
name, group = list(groups)[0]
print(name)
group
# Out:
# 1,1,1,2-Tetrachloroethane
#                                 substance  quantity_in_kg
# index
# Q001PGH001-S48  1,1,1,2-Tetrachloroethane          0.0724
# Q001PGH002-S48  1,1,1,2-Tetrachloroethane          0.0966
# Q001PGH003-S48  1,1,1,2-Tetrachloroethane          0.1700
# Q020BHP002-S48  1,1,1,2-Tetrachloroethane          0.0000
# Q080BHP001-S48  1,1,1,2-Tetrachloroethane          0.0000

# %% [markdown]
# But it doesn't show us any tables. The reason is pandas has grouped the data into `DataFrameGroupBy` object and now we need to specify how the values should be aggregated. In this case since we want the average we use `.mean()`.

# %%
df[["substance", "quantity_in_kg"]].groupby(by="substance").mean()
# Out:
#                                        quantity_in_kg
# substance
# 1,1,1,2-Tetrachloroethane                    0.067800
# 1,1,2-Trichloroethane                        1.028285
# 1,2-Dibromoethane                           50.000000
# 1,2-Dichloroethane                           3.100041
# 1,3-Butadiene (vinyl ethylene)               1.802580
# ...                                               ...
# Trichloroethylene                         5584.750000
# Vinyl Chloride Monomer                      34.237040
# Xylenes (individual or mixed isomers)      715.616385
# Zinc and compounds                        6358.184715
# n-Hexane                                  1025.188222
#
# [74 rows x 1 columns]

# %% [markdown]
# There are other useful aggregation functions such as `.std()` for standard deviation, `.median()` for median, `.count()` for the number of rows in each group, `.sum()` for sum, etc. You can also define your own aggregation function.

# %%
agg_func = lambda x: np.sqrt((x ** 2).mean())  # root mean of squares
df[["substance", "quantity_in_kg"]].groupby(by="substance").apply(agg_func)
# Out:
#                                        quantity_in_kg
# substance
# 1,1,1,2-Tetrachloroethane                    0.093245
# 1,1,2-Trichloroethane                        2.589484
# 1,2-Dibromoethane                           50.000000
# 1,2-Dichloroethane                           7.830007
# 1,3-Butadiene (vinyl ethylene)               8.022719
# ...                                               ...
# Trichloroethylene                        11159.504480
# Vinyl Chloride Monomer                      87.487409
# Xylenes (individual or mixed isomers)     5012.507739
# Zinc and compounds                       49315.912982
# n-Hexane                                  9230.839169
#
# [74 rows x 1 columns]

# %% [markdown]
# <font color='green'>Do you know how to use *__lambda__* functions? If not check out <a href = 'https://www.w3schools.com/python/python_lambda.asp'>this page</a> to learn about them.</font>

# %% [markdown]
# ### Pivot Table
# Another way to represent the data is using pivot tables. You might be familiar with pivot tables in Excel. You can perform the same operations here as well.

# %% [markdown]
# Let's create a pivot table that shows the amount of each substance in every postcode in the dataset.

# %%
df.pivot_table(
    index="site_address_postcode",
    columns="substance",
    values="quantity_in_kg",
    aggfunc="mean",
)
# Out:
# substance              1,1,1,2-Tetrachloroethane  1,1,2-Trichloroethane  \
# site_address_postcode
# 4006                                         NaN                    NaN
# 4007                                         NaN                    NaN
# 4008                                         NaN                    NaN
# 4009                                         NaN                    NaN
# 4013                                         NaN                    NaN
# ...                                          ...                    ...
# 4882                                         NaN                    NaN
# 4885                                         NaN                    NaN
# 4890                                         NaN                    NaN
# 4891                                         NaN                    NaN
# 4895                                         NaN                    NaN
#
# substance              1,2-Dibromoethane  1,2-Dichloroethane  \
# site_address_postcode
# 4006                                 NaN                 NaN
# 4007                                 NaN                 NaN
# 4008                                 NaN                 NaN
# 4009                                 NaN                 NaN
# 4013                                 NaN                 NaN
# ...                                  ...                 ...
# 4882                                 NaN                 NaN
# 4885                                 NaN                 NaN
# 4890                                 NaN                 NaN
# 4891                                 NaN                 NaN
# 4895                                 NaN                 NaN
#
# substance              1,3-Butadiene (vinyl ethylene)  Acetaldehyde  \
# site_address_postcode
# 4006                                              NaN           NaN
# 4007                                              NaN           NaN
# 4008                                              NaN         65.80
# 4009                                              NaN           NaN
# 4013                                              NaN           NaN
# ...                                               ...           ...
# 4882                                              NaN           NaN
# 4885                                              NaN           NaN
# 4890                                              NaN           NaN
# 4891                                              NaN           NaN
# 4895                                             0.05          0.03
#
# substance              Acetic acid (ethanoic acid)  Acetone  Acetonitrile  \
# site_address_postcode
# 4006                                           NaN      NaN           NaN
# 4007                                           NaN      NaN           NaN
# 4008                                           NaN      NaN           NaN
# 4009                                           NaN      NaN           NaN
# 4013                                           NaN      NaN           NaN
# ...                                            ...      ...           ...
# 4882                                           NaN      NaN           NaN
# 4885                                           NaN      NaN           NaN
# 4890                                           NaN      NaN           NaN
# 4891                                           NaN      NaN           NaN
# 4895                                           NaN      NaN           NaN
#
# substance              Acrylamide  ...  Sulfuric acid  Tetrachloroethylene  \
# site_address_postcode              ...
# 4006                          NaN  ...            NaN                  NaN
# 4007                          NaN  ...         0.0014                  NaN
# 4008                          NaN  ...       520.0000                  NaN
# 4009                          NaN  ...            NaN                  NaN
# 4013                          NaN  ...            NaN                  NaN
# ...                           ...  ...            ...                  ...
# 4882                          NaN  ...            NaN                  NaN
# 4885                          NaN  ...            NaN                  NaN
# 4890                          NaN  ...            NaN                  NaN
# 4891                          NaN  ...            NaN                  NaN
# 4895                          NaN  ...            NaN                  NaN
#
# substance              Toluene (methylbenzene)  Toluene-2,4-diisocyanate  \
# site_address_postcode
# 4006                                       NaN                       NaN
# 4007                               1436.000000                       NaN
# 4008                              30384.966667                       NaN
# 4009                               3158.750000                       NaN
# 4013                                       NaN                       NaN
# ...                                        ...                       ...
# 4882                                       NaN                       NaN
# 4885                                       NaN                       NaN
# 4890                                       NaN                       NaN
# 4891                                  2.162000                       NaN
# 4895                                  0.380000                       NaN
#
# substance              Total Volatile Organic Compounds  Trichloroethylene  \
# site_address_postcode
# 4006                                          11.765000                NaN
# 4007                                       46156.000000                NaN
# 4008                                      502521.650000                NaN
# 4009                                       89518.775000                NaN
# 4013                                        3209.000000                NaN
# ...                                                 ...                ...
# 4882                                         409.000000                NaN
# 4885                                         347.500000                NaN
# 4890                                         191.000000                NaN
# 4891                                        3058.333333                NaN
# 4895                                         107.000000                NaN
#
# substance              Vinyl Chloride Monomer  \
# site_address_postcode
# 4006                                      NaN
# 4007                                      NaN
# 4008                                      NaN
# 4009                                      NaN
# 4013                                      NaN
# ...                                       ...
# 4882                                      NaN
# 4885                                      NaN
# 4890                                      NaN
# 4891                                      NaN
# 4895                                      NaN
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4006                                                     NaN
# 4007                                                 753.000
# 4008                                               20189.075
# 4009                                                 873.650
# 4013                                                     NaN
# ...                                                      ...
# 4882                                                     NaN
# 4885                                                     NaN
# 4890                                                   1.020
# 4891                                                   0.780
# 4895                                                   0.260
#
# substance              Zinc and compounds  n-Hexane
# site_address_postcode
# 4006                                  NaN       NaN
# 4007                                  NaN     881.0
# 4008                                 87.2   46679.7
# 4009                                  NaN    4200.0
# 4013                                 95.0       NaN
# ...                                   ...       ...
# 4882                                  NaN       NaN
# 4885                                  NaN       NaN
# 4890                                  NaN       NaN
# 4891                                432.0       NaN
# 4895                                  NaN       NaN
#
# [266 rows x 74 columns]

# %% [markdown]
# __Note:__ `NaN` stands for Not a Number. In this case it means there was no value available for that cell. This means where you see `NaN` in the table there was no emission recorded for that substance in that specific postcode. This probably means that we can assume the emission was zero. We could let pandas know by passing in `fill_value = 0`. Then, where no value is available pandas put zero instead.

# %%
df.pivot_table(
    index="site_address_postcode",
    columns="substance",
    values="quantity_in_kg",
    aggfunc="mean",
    fill_value=0,
)
# Out:
# substance              1,1,1,2-Tetrachloroethane  1,1,2-Trichloroethane  \
# site_address_postcode
# 4006                                         0.0                    0.0
# 4007                                         0.0                    0.0
# 4008                                         0.0                    0.0
# 4009                                         0.0                    0.0
# 4013                                         0.0                    0.0
# ...                                          ...                    ...
# 4882                                         0.0                    0.0
# 4885                                         0.0                    0.0
# 4890                                         0.0                    0.0
# 4891                                         0.0                    0.0
# 4895                                         0.0                    0.0
#
# substance              1,2-Dibromoethane  1,2-Dichloroethane  \
# site_address_postcode
# 4006                                   0                 0.0
# 4007                                   0                 0.0
# 4008                                   0                 0.0
# 4009                                   0                 0.0
# 4013                                   0                 0.0
# ...                                  ...                 ...
# 4882                                   0                 0.0
# 4885                                   0                 0.0
# 4890                                   0                 0.0
# 4891                                   0                 0.0
# 4895                                   0                 0.0
#
# substance              1,3-Butadiene (vinyl ethylene)  Acetaldehyde  \
# site_address_postcode
# 4006                                             0.00          0.00
# 4007                                             0.00          0.00
# 4008                                             0.00         65.80
# 4009                                             0.00          0.00
# 4013                                             0.00          0.00
# ...                                               ...           ...
# 4882                                             0.00          0.00
# 4885                                             0.00          0.00
# 4890                                             0.00          0.00
# 4891                                             0.00          0.00
# 4895                                             0.05          0.03
#
# substance              Acetic acid (ethanoic acid)  Acetone  Acetonitrile  \
# site_address_postcode
# 4006                                           0.0      0.0             0
# 4007                                           0.0      0.0             0
# 4008                                           0.0      0.0             0
# 4009                                           0.0      0.0             0
# 4013                                           0.0      0.0             0
# ...                                            ...      ...           ...
# 4882                                           0.0      0.0             0
# 4885                                           0.0      0.0             0
# 4890                                           0.0      0.0             0
# 4891                                           0.0      0.0             0
# 4895                                           0.0      0.0             0
#
# substance              Acrylamide  ...  Sulfuric acid  Tetrachloroethylene  \
# site_address_postcode              ...
# 4006                          0.0  ...         0.0000                  0.0
# 4007                          0.0  ...         0.0014                  0.0
# 4008                          0.0  ...       520.0000                  0.0
# 4009                          0.0  ...         0.0000                  0.0
# 4013                          0.0  ...         0.0000                  0.0
# ...                           ...  ...            ...                  ...
# 4882                          0.0  ...         0.0000                  0.0
# 4885                          0.0  ...         0.0000                  0.0
# 4890                          0.0  ...         0.0000                  0.0
# 4891                          0.0  ...         0.0000                  0.0
# 4895                          0.0  ...         0.0000                  0.0
#
# substance              Toluene (methylbenzene)  Toluene-2,4-diisocyanate  \
# site_address_postcode
# 4006                                  0.000000                       0.0
# 4007                               1436.000000                       0.0
# 4008                              30384.966667                       0.0
# 4009                               3158.750000                       0.0
# 4013                                  0.000000                       0.0
# ...                                        ...                       ...
# 4882                                  0.000000                       0.0
# 4885                                  0.000000                       0.0
# 4890                                  0.000000                       0.0
# 4891                                  2.162000                       0.0
# 4895                                  0.380000                       0.0
#
# substance              Total Volatile Organic Compounds  Trichloroethylene  \
# site_address_postcode
# 4006                                          11.765000                  0
# 4007                                       46156.000000                  0
# 4008                                      502521.650000                  0
# 4009                                       89518.775000                  0
# 4013                                        3209.000000                  0
# ...                                                 ...                ...
# 4882                                         409.000000                  0
# 4885                                         347.500000                  0
# 4890                                         191.000000                  0
# 4891                                        3058.333333                  0
# 4895                                         107.000000                  0
#
# substance              Vinyl Chloride Monomer  \
# site_address_postcode
# 4006                                      0.0
# 4007                                      0.0
# 4008                                      0.0
# 4009                                      0.0
# 4013                                      0.0
# ...                                       ...
# 4882                                      0.0
# 4885                                      0.0
# 4890                                      0.0
# 4891                                      0.0
# 4895                                      0.0
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4006                                                   0.000
# 4007                                                 753.000
# 4008                                               20189.075
# 4009                                                 873.650
# 4013                                                   0.000
# ...                                                      ...
# 4882                                                   0.000
# 4885                                                   0.000
# 4890                                                   1.020
# 4891                                                   0.780
# 4895                                                   0.260
#
# substance              Zinc and compounds  n-Hexane
# site_address_postcode
# 4006                                  0.0       0.0
# 4007                                  0.0     881.0
# 4008                                 87.2   46679.7
# 4009                                  0.0    4200.0
# 4013                                 95.0       0.0
# ...                                   ...       ...
# 4882                                  0.0       0.0
# 4885                                  0.0       0.0
# 4890                                  0.0       0.0
# 4891                                432.0       0.0
# 4895                                  0.0       0.0
#
# [266 rows x 74 columns]

# %% [markdown]
# #### Exercise
#
# <div class="alert alert-success" style="font-size:100%">
# Now to practice what we have learned so far, let's create a table of the total emissions (quantity in kg) of the top 10 substances (most commonly recorded substances in the dataset) for each postcode.<br>
#
# 1. Find how many times each substance occurs `substance_count`
# 2. Sort `substance_count` and find 10 most common substance `top10`
# 3. Create a seperate dataframe that shows the total weight of each substance per postcode `weight_by_postcode`
# 4. Combine `weight_by_postcode` and `top10` to get the weight by postcode of the top 10 substances
#
# <details><summary>Hints</summary>
#
# 1. use groupby then count
# 2. use .sort_values() then get the first 10 rows
# 3. A pivot table will do this easily
# 4. `weight_by_postcode[top10.index]`
#
# </details>
# <div>

# %%
# 1. Find how many times each substance has been recorded (this has been done for you)
# substance_count = df[["site_address_postcode", "substance"]].??

# 2. Sort it and find the substances that have been recorded the most (this has been done for you)
# top10 = substance_count.??

# 3. Create a seperate table that shows the total weight of each substance per postcode (hint: pivot table or groupby)
# pivot = ??

# 4. Combine the tables, to get a subset which only includes the top 10 substances
# pivot_top10 = ??

# %% [markdown]
# #### Solution:

# %% [markdown]
# <details>
# <summary>
#     <font size="4" color="darkblue"><b>See the solution for Exercise</b></font>
# </summary>
#
# ```python
# # you can replace site_address_postcode by any other column. Since we are only counting it doesn't matter which column use.
# substance_count = df[["site_address_postcode", "substance"]].groupby(by="substance").count()
#
# # Now sort it, and take the first 10 results
# substance_count.columns = ["Count"] # rename column
# top10 = substance_count.sort_values(by="Count", ascending=False)[:10]
#
# # Create the pivot table
# pivot = df.pivot_table(
#     index="site_address_postcode",
#     columns="substance",
#     values="quantity_in_kg",
#     aggfunc="sum",
# )
#
# # get only the columns for top 10 substances
# pivot_top10 = pivot[top10.index]
# pivot_top10
# ```
# </details>

# %% [markdown]
# Now it's a good time to discuss dealing with missing values in a table.

# %% [markdown]
# ## Missing Values
# There might be missing data in a table. Having `NaN` in the table can cause trouble in the analysis so we need to decide how we are going to deal with it. A few common scenarios are:
# 1. filling the missing values with a number e.g. zero
# 2. removing rows with missing values
# 3. removeing rows with multiple missing values and filling the remaining with a new value

# %%
# you can replace site_address_postcode by any other column. Since we are only counting it doesn't matter which column use.
substance_count = df[["site_address_postcode", "substance"]].groupby(by="substance").count()

# Now sort it, and take the first 10 results
substance_count.columns = ["Count"] # rename column
top10 = substance_count.sort_values(by="Count", ascending=False)[:10]

# Create the pivot table
pivot = df.pivot_table(
    index="site_address_postcode",
    columns="substance",
    values="quantity_in_kg",
    aggfunc="sum",
)

# get only the columns for top 10 substances
pivot_top10 = pivot[top10.index]
pivot_top10
# Out:
# substance              Total Volatile Organic Compounds  Carbon monoxide  \
# site_address_postcode
# 4006                                              23.53              NaN
# 4007                                          138468.00           4092.0
# 4008                                         5025216.50         534408.0
# 4009                                          358075.10           6864.0
# 4013                                            6418.00         199808.0
# ...                                                 ...              ...
# 4882                                             409.00              NaN
# 4885                                             695.00           5205.0
# 4890                                             191.00              NaN
# 4891                                            9175.00          40002.0
# 4895                                             107.00           1139.0
#
# substance              Sulfur dioxide  Oxides of Nitrogen  \
# site_address_postcode
# 4006                              NaN                 NaN
# 4007                         1870.000              9823.0
# 4008                      2316025.600            681944.0
# 4009                            4.001               862.0
# 4013                        40916.000             46024.0
# ...                               ...                 ...
# 4882                              NaN                 NaN
# 4885                         9680.400             13735.0
# 4890                              NaN                 NaN
# 4891                        60694.000            296603.0
# 4895                           65.300              4280.0
#
# substance              Particulate Matter 10.0 um  \
# site_address_postcode
# 4006                                          NaN
# 4007                                       2572.0
# 4008                                     249500.1
# 4009                                        322.2
# 4013                                      27880.0
# ...                                           ...
# 4882                                          NaN
# 4885                                      64444.0
# 4890                                          NaN
# 4891                                       1955.0
# 4895                                        133.0
#
# substance              Polycyclic aromatic hydrocarbons (B[a]Peq)  \
# site_address_postcode
# 4006                                                          NaN
# 4007                                                      11.7000
# 4008                                                      13.7888
# 4009                                                      21.9050
# 4013                                                      14.2000
# ...                                                           ...
# 4882                                                          NaN
# 4885                                                       0.0682
# 4890                                                          NaN
# 4891                                                       1.5500
# 4895                                                       0.2200
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4006                                                     NaN
# 4007                                                  753.00
# 4008                                                80756.30
# 4009                                                 1747.30
# 4013                                                     NaN
# ...                                                      ...
# 4882                                                     NaN
# 4885                                                     NaN
# 4890                                                    1.02
# 4891                                                    0.78
# 4895                                                    0.26
#
# substance              Toluene (methylbenzene)   Benzene  Mercury & compounds
# site_address_postcode
# 4006                                       NaN       NaN                  NaN
# 4007                                  1436.000    378.00                  NaN
# 4008                                 91154.900  37018.40              13.0244
# 4009                                  6317.500   6437.80                  NaN
# 4013                                       NaN       NaN               0.6000
# ...                                        ...       ...                  ...
# 4882                                       NaN       NaN                  NaN
# 4885                                       NaN       NaN                  NaN
# 4890                                       NaN       NaN                  NaN
# 4891                                     4.324       NaN               0.7310
# 4895                                     0.380      1.04                  NaN
#
# [266 rows x 10 columns]

# %% [markdown]
# To replace the missing value with a fixed number we can use `.fillna()` method.

# %%
dfnew = pivot_top10.fillna(value=0)
dfnew
# Out:
# substance              Total Volatile Organic Compounds  Carbon monoxide  \
# site_address_postcode
# 4006                                              23.53              0.0
# 4007                                          138468.00           4092.0
# 4008                                         5025216.50         534408.0
# 4009                                          358075.10           6864.0
# 4013                                            6418.00         199808.0
# ...                                                 ...              ...
# 4882                                             409.00              0.0
# 4885                                             695.00           5205.0
# 4890                                             191.00              0.0
# 4891                                            9175.00          40002.0
# 4895                                             107.00           1139.0
#
# substance              Sulfur dioxide  Oxides of Nitrogen  \
# site_address_postcode
# 4006                            0.000                 0.0
# 4007                         1870.000              9823.0
# 4008                      2316025.600            681944.0
# 4009                            4.001               862.0
# 4013                        40916.000             46024.0
# ...                               ...                 ...
# 4882                            0.000                 0.0
# 4885                         9680.400             13735.0
# 4890                            0.000                 0.0
# 4891                        60694.000            296603.0
# 4895                           65.300              4280.0
#
# substance              Particulate Matter 10.0 um  \
# site_address_postcode
# 4006                                          0.0
# 4007                                       2572.0
# 4008                                     249500.1
# 4009                                        322.2
# 4013                                      27880.0
# ...                                           ...
# 4882                                          0.0
# 4885                                      64444.0
# 4890                                          0.0
# 4891                                       1955.0
# 4895                                        133.0
#
# substance              Polycyclic aromatic hydrocarbons (B[a]Peq)  \
# site_address_postcode
# 4006                                                       0.0000
# 4007                                                      11.7000
# 4008                                                      13.7888
# 4009                                                      21.9050
# 4013                                                      14.2000
# ...                                                           ...
# 4882                                                       0.0000
# 4885                                                       0.0682
# 4890                                                       0.0000
# 4891                                                       1.5500
# 4895                                                       0.2200
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4006                                                    0.00
# 4007                                                  753.00
# 4008                                                80756.30
# 4009                                                 1747.30
# 4013                                                    0.00
# ...                                                      ...
# 4882                                                    0.00
# 4885                                                    0.00
# 4890                                                    1.02
# 4891                                                    0.78
# 4895                                                    0.26
#
# substance              Toluene (methylbenzene)   Benzene  Mercury & compounds
# site_address_postcode
# 4006                                     0.000      0.00               0.0000
# 4007                                  1436.000    378.00               0.0000
# 4008                                 91154.900  37018.40              13.0244
# 4009                                  6317.500   6437.80               0.0000
# 4013                                     0.000      0.00               0.6000
# ...                                        ...       ...                  ...
# 4882                                     0.000      0.00               0.0000
# 4885                                     0.000      0.00               0.0000
# 4890                                     0.000      0.00               0.0000
# 4891                                     4.324      0.00               0.7310
# 4895                                     0.380      1.04               0.0000
#
# [266 rows x 10 columns]

# %% [markdown]
# __Note:__ When using `fillna` the changes are not saved in the data frame. The default settings only returns the result and keeps the original data frame intact. If you want to save the changes in the same data frame you can pass in `inplace = True`.

# %% [markdown]
# There are other ways to fill the missing values. In some cases you might want to use different values for each column. A common example is using mean or median of a column for the missing values.

# %%
fill_values = pivot_top10.mean()
dfnew = pivot_top10.fillna(value=fill_values)
dfnew
# Out:
# substance              Total Volatile Organic Compounds  Carbon monoxide  \
# site_address_postcode
# 4006                                              23.53    793603.077641
# 4007                                          138468.00      4092.000000
# 4008                                         5025216.50    534408.000000
# 4009                                          358075.10      6864.000000
# 4013                                            6418.00    199808.000000
# ...                                                 ...              ...
# 4882                                             409.00    793603.077641
# 4885                                             695.00      5205.000000
# 4890                                             191.00    793603.077641
# 4891                                            9175.00     40002.000000
# 4895                                             107.00      1139.000000
#
# substance              Sulfur dioxide  Oxides of Nitrogen  \
# site_address_postcode
# 4006                     2.565225e+06        1.568823e+06
# 4007                     1.870000e+03        9.823000e+03
# 4008                     2.316026e+06        6.819440e+05
# 4009                     4.001000e+00        8.620000e+02
# 4013                     4.091600e+04        4.602400e+04
# ...                               ...                 ...
# 4882                     2.565225e+06        1.568823e+06
# 4885                     9.680400e+03        1.373500e+04
# 4890                     2.565225e+06        1.568823e+06
# 4891                     6.069400e+04        2.966030e+05
# 4895                     6.530000e+01        4.280000e+03
#
# substance              Particulate Matter 10.0 um  \
# site_address_postcode
# 4006                                 1.112755e+06
# 4007                                 2.572000e+03
# 4008                                 2.495001e+05
# 4009                                 3.222000e+02
# 4013                                 2.788000e+04
# ...                                           ...
# 4882                                 1.112755e+06
# 4885                                 6.444400e+04
# 4890                                 1.112755e+06
# 4891                                 1.955000e+03
# 4895                                 1.330000e+02
#
# substance              Polycyclic aromatic hydrocarbons (B[a]Peq)  \
# site_address_postcode
# 4006                                                   274.356493
# 4007                                                    11.700000
# 4008                                                    13.788800
# 4009                                                    21.905000
# 4013                                                    14.200000
# ...                                                           ...
# 4882                                                   274.356493
# 4885                                                     0.068200
# 4890                                                   274.356493
# 4891                                                     1.550000
# 4895                                                     0.220000
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4006                                             1664.903427
# 4007                                              753.000000
# 4008                                            80756.300000
# 4009                                             1747.300000
# 4013                                             1664.903427
# ...                                                      ...
# 4882                                             1664.903427
# 4885                                             1664.903427
# 4890                                                1.020000
# 4891                                                0.780000
# 4895                                                0.260000
#
# substance              Toluene (methylbenzene)       Benzene  \
# site_address_postcode
# 4006                                2376.34755    857.583106
# 4007                                1436.00000    378.000000
# 4008                               91154.90000  37018.400000
# 4009                                6317.50000   6437.800000
# 4013                                2376.34755    857.583106
# ...                                        ...           ...
# 4882                                2376.34755    857.583106
# 4885                                2376.34755    857.583106
# 4890                                2376.34755    857.583106
# 4891                                   4.32400    857.583106
# 4895                                   0.38000      1.040000
#
# substance              Mercury & compounds
# site_address_postcode
# 4006                              12.48791
# 4007                              12.48791
# 4008                              13.02440
# 4009                              12.48791
# 4013                               0.60000
# ...                                    ...
# 4882                              12.48791
# 4885                              12.48791
# 4890                              12.48791
# 4891                               0.73100
# 4895                              12.48791
#
# [266 rows x 10 columns]

# %% [markdown]
# Pandas has other methods for filling the missing values including forward and backward filling. Forward filling replaces the missing values by the last valid value in the table and backward filling replaces the missing values by next valid value. These techniques are useful for sequential data such as time series and wouldn't make sense to be applied to tabular data.<br>
# To use these methods, when using `fillna` instead of passing in a value, you can pass a method. For forward filling pass in `method = "ffill"` and for backward filling pass in `method = "bfill"`.

# %% [markdown]
# If you simply want to get rid of rows with missing values you can use `.dropna()`

# %%
dfnew = pivot_top10.dropna()
dfnew
# Out:
# substance              Total Volatile Organic Compounds  Carbon monoxide  \
# site_address_postcode
# 4008                                         5025216.50       534408.000
# 4014                                           11456.58        15428.000
# 4055                                            9202.00         8860.000
# 4076                                           76197.00       193463.000
# 4077                                            3714.25        92469.000
# ...                                                 ...              ...
# 4871                                           34075.70       138996.881
# 4874                                          181508.00      1790146.000
# 4875                                           38340.00       172116.000
# 4876                                            4583.70        48610.000
# 4880                                            4534.93       466631.000
#
# substance              Sulfur dioxide  Oxides of Nitrogen  \
# site_address_postcode
# 4008                        2316025.6            681944.0
# 4014                            208.0              4109.0
# 4055                           1909.0             17076.0
# 4076                         109363.3            115413.0
# 4077                          47747.0              5643.0
# ...                               ...                 ...
# 4871                          23559.0            361559.0
# 4874                         985114.0           1321686.0
# 4875                         225041.0            719426.0
# 4876                           2787.0            182636.0
# 4880                          52845.0            125618.0
#
# substance              Particulate Matter 10.0 um  \
# site_address_postcode
# 4008                                     249500.1
# 4014                                        312.0
# 4055                                      22353.0
# 4076                                     184617.0
# 4077                                      85636.0
# ...                                           ...
# 4871                                      13275.0
# 4874                                    4323917.0
# 4875                                      37307.0
# 4876                                       5694.0
# 4880                                      33296.0
#
# substance              Polycyclic aromatic hydrocarbons (B[a]Peq)  \
# site_address_postcode
# 4008                                                      13.7888
# 4014                                                       0.0300
# 4055                                                       0.8900
# 4076                                                       0.1805
# 4077                                                       0.0150
# ...                                                           ...
# 4871                                                      14.3900
# 4874                                                      23.8800
# 4875                                                      32.2500
# 4876                                                       9.5800
# 4880                                                     177.0000
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4008                                               80756.300
# 4014                                                 187.000
# 4055                                                 215.700
# 4076                                                 304.900
# 4077                                                   7.611
# ...                                                      ...
# 4871                                                  28.019
# 4874                                                7315.190
# 4875                                                  54.200
# 4876                                                  11.200
# 4880                                                  38.700
#
# substance              Toluene (methylbenzene)    Benzene  Mercury & compounds
# site_address_postcode
# 4008                                 91154.900  37018.400            13.024400
# 4014                                   527.140     21.790             0.022100
# 4055                                   607.000     25.011             0.013900
# 4076                                   488.700    162.861             1.081300
# 4077                                    97.400    177.000             0.457000
# ...                                        ...        ...                  ...
# 4871                                    63.579     74.559             0.057121
# 4874                                  4160.230    572.850             3.045000
# 4875                                    83.570    176.170             0.000000
# 4876                                    16.000     44.400             0.000000
# 4880                                   104.800     58.100             0.000800
#
# [66 rows x 10 columns]

# %% [markdown]
# __Note:__ Notice the number of rows are much less in the table above compared to the original table.

# %% [markdown]
# If we remove any row that contains missing values we might lose a significant portion of the data. Alternatively, we can only remove rows which have more than a certain number of missing values. To do so, we can set a threshold.

# %%
# remove the rows with at least 3 missing values
dfnew = pivot_top10.dropna(thresh=3)
dfnew
# Out:
# substance              Total Volatile Organic Compounds  Carbon monoxide  \
# site_address_postcode
# 4007                                          138468.00           4092.0
# 4008                                         5025216.50         534408.0
# 4009                                          358075.10           6864.0
# 4013                                            6418.00         199808.0
# 4014                                           11456.58          15428.0
# ...                                                 ...              ...
# 4876                                            4583.70          48610.0
# 4880                                            4534.93         466631.0
# 4885                                             695.00           5205.0
# 4891                                            9175.00          40002.0
# 4895                                             107.00           1139.0
#
# substance              Sulfur dioxide  Oxides of Nitrogen  \
# site_address_postcode
# 4007                         1870.000              9823.0
# 4008                      2316025.600            681944.0
# 4009                            4.001               862.0
# 4013                        40916.000             46024.0
# 4014                          208.000              4109.0
# ...                               ...                 ...
# 4876                         2787.000            182636.0
# 4880                        52845.000            125618.0
# 4885                         9680.400             13735.0
# 4891                        60694.000            296603.0
# 4895                           65.300              4280.0
#
# substance              Particulate Matter 10.0 um  \
# site_address_postcode
# 4007                                       2572.0
# 4008                                     249500.1
# 4009                                        322.2
# 4013                                      27880.0
# 4014                                        312.0
# ...                                           ...
# 4876                                       5694.0
# 4880                                      33296.0
# 4885                                      64444.0
# 4891                                       1955.0
# 4895                                        133.0
#
# substance              Polycyclic aromatic hydrocarbons (B[a]Peq)  \
# site_address_postcode
# 4007                                                      11.7000
# 4008                                                      13.7888
# 4009                                                      21.9050
# 4013                                                      14.2000
# 4014                                                       0.0300
# ...                                                           ...
# 4876                                                       9.5800
# 4880                                                     177.0000
# 4885                                                       0.0682
# 4891                                                       1.5500
# 4895                                                       0.2200
#
# substance              Xylenes (individual or mixed isomers)  \
# site_address_postcode
# 4007                                                  753.00
# 4008                                                80756.30
# 4009                                                 1747.30
# 4013                                                     NaN
# 4014                                                  187.00
# ...                                                      ...
# 4876                                                   11.20
# 4880                                                   38.70
# 4885                                                     NaN
# 4891                                                    0.78
# 4895                                                    0.26
#
# substance              Toluene (methylbenzene)   Benzene  Mercury & compounds
# site_address_postcode
# 4007                                  1436.000    378.00                  NaN
# 4008                                 91154.900  37018.40              13.0244
# 4009                                  6317.500   6437.80                  NaN
# 4013                                       NaN       NaN               0.6000
# 4014                                   527.140     21.79               0.0221
# ...                                        ...       ...                  ...
# 4876                                    16.000     44.40               0.0000
# 4880                                   104.800     58.10               0.0008
# 4885                                       NaN       NaN                  NaN
# 4891                                     4.324       NaN               0.7310
# 4895                                     0.380      1.04                  NaN
#
# [209 rows x 10 columns]

# %% [markdown]
# Now we have more rows compared to when we removed all missing values.<br>
# Next step is to replace the missing values using the techniques discussed above.

# %% [markdown]
# ## Saving Data
# After analysis and reshaping the data you might want to save the results in a file. Similar to reading files, pandas supports multiple file formats to save the tables.

# %%
pivot_top10.to_csv("final_table.csv")

# %% [markdown]
# ## Pandas Plotting
# Pandas dataframes have plotting methods which help to visualise the data. The following plots are supported in pandas:
# - 'line' : line plot (default)
# - 'bar' : vertical bar plot
# - 'barh' : horizontal bar plot
# - 'hist' : histogram
# - 'box' : boxplot
# - 'kde' : Kernel Density Estimation plot
# - 'density' : same as 'kde'
# - 'area' : area plot
# - 'pie' : pie plot
# - 'scatter' : scatter plot
# - 'hexbin' : hexbin plot.
#
# You can select which plot you want to use by setting `kind` to the string for the plot.<br>
# There are a few other useful options you can set:
# - xlim, ylim: to set limits of axes
# - logx, logy, loglog: to set whether an axis should be displayed in logarithmic scale]
# - title: to set the title of the plot
# - figsize: to set the size of the plot
# <br><br>Let's try a few types of charts and graphs.

# %%
# Top 10 postcodes with largest carbon monoxide emission
pivot_top10.sort_values(by="Carbon monoxide", ascending=False)[:10].plot(
    kind="barh", y="Carbon monoxide"
)

# %%
# histogram of benzene emission
pivot_top10.plot(kind="hist", y="Benzene", bins=50)

# %%
# kernel density estimation plot of benzene emission

pivot_top10.plot(kind="kde", y=["Benzene", "Toluene (methylbenzene)"], logx=True)

# %%
# histogram of benzene emission in each postcode
pivot_top10.plot(kind="box", logy=True, rot=90)

# %%
pivot_top10.plot(kind="scatter", x="Toluene (methylbenzene)", y="Benzene", loglog=True)

# %%
# pie chart of emission of the substances in postcode 4008
pivot_top10.loc[4008, :].plot(kind="pie", subplots=True, figsize=(10, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5897cbbcc0>],
#       dtype=object)

# %% [markdown]
# We will discuss producing more advanced plots in the next notebooks where we learn about various plotting packages in python.

# %% [markdown]
# ## Further reading
# - [Pandas documentation](https://pandas.pydata.org/)
# - [Pandas in 10 minutes](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
# - https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf
# - https://www.kaggle.com/learn/pandas
# - https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas
# - https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS
