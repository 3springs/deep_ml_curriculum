# %% [markdown]
# # SQLite Basics
# This notebook includes basic instructions about how to access a database, and read/write data from/to it.<br>
# Here, we are using **SQLite** which is light-weight database management system. To communicate with a database in SQLite we use Structured Query Language a.k.a **SQL**. We use SQL to send a querry to the database manager. Then the database manager processes the query and sends the result back. The query is the instructions that tells database manager what to do.
# In python we can use the **sqlite3** package for this putpose.

# %%
import sqlite3

# %% [markdown]
# ## Connecting to a database
# Let's start by connecting to a database. We can do that using `sqlite.connect` which returns a connection object.

# %%
# create a database connection to the SQLite database specified by the db_file
db_file = 'Sales.db'
conn = sqlite3.connect(db_file)

# %% [markdown]
# If you didn't get any error, it means you have successfully connected to the database. <br>
# **Note:** If the file doesn't exist sqlite will create an empty database with the given name.<br><br>
# Now we can start executing a query. Let's start by the simplest query:<br>
# <code>
#     SELECT * FROM {name of table}
# </code>
# <br>
# This query returns all the rows and columns of a specific table in the database. To use this query first we need to know the names of the tables in the database and in general the structure of the database.
# <img src="DB.PNG" alt="Image not found" width="50%">
# Let's get a list of all the customers

# %%
query = '''
SELECT * FROM Customers;

'''

# %% [markdown]
# **Note:** It is customary to use SQL key word all in caps but that is not necessary. "SELECT" and "select" do the same job.<br>
# <br>Now that we have the query, let's send it to the database manager. To do that, we need to create a cursor object and ask the cursor to execute the query and return all the information.

# %%
cur = conn.cursor()
cur.execute(query)
output = cur.fetchall()
print(output)
# Out:
# [(1, 'Mr.', 'Jorge', 'Dunn', None, '0429937146', '48585127', 'sbrooks@hotmail.com', '99098 Rachael Cliff', 'New Jasonborough', 'Poland', '341571816096695', '12/20', '2019-06-17'), (2, 'Mrs.', 'Debra', 'Wall', '56978970', '0470205559', None, 'colleenalexander@taylor-brown.net', '9716 Andrea Place Apt. 808', 'Harrisberg', 'Portugal', '4846279439697392', '02/24', '2015-01-02'), (3, 'Dr.', 'Cynthia', 'Ellis', None, '0469055029', '82096582', 'vstewart@gmail.com', '21014 Jared Mount', 'Lopezmouth', 'Germany', '213179187652107', '01/30', '2014-07-21'), (4, 'Mr.', 'John', 'Harris', None, '0475137980', None, 'yarmstrong@hotmail.com', '54725 Todd Corners', 'New Timothy', 'Bahrain', '3567765520251007', '02/22', '2011-07-26'), (5, 'Mr.', 'Kyle', 'Jones', '21424091', '0404892875', '24628569', 'cindy97@yahoo.com', '97603 Joseph Terrace Apt. 079', 'Sherryland', 'Hong Kong', '4290875996151482', '07/29', '2013-09-26'), (6, 'Mrs.', 'Pamela', 'Dennis', '41586619', '0490981941', None, 'ljohnston@hotmail.com', '692 Gail Route', 'East Terrihaven', 'Poland', '4784984219676979', '05/23', '2015-05-12'), (7, 'Dr.', 'Elizabeth', 'Carpenter', '61314681', '0484870663', None, 'ericataylor@yahoo.com', '7288 Clifford Mountains', 'Alexanderbury', 'Poland', '4680997957479922', '06/23', '2012-03-12'), (8, 'Mr.', 'Brett', 'Floyd', '75886944', '0471999583', '69674149', 'gouldheidi@armstrong.info', '5195 Patrick Bypass', 'Alexandraville', 'Belgium', '6594288087620670', '08/24', '2014-05-24'), (9, 'Mr.', 'Christopher', 'Liu', None, '0435243908', None, 'jenniferbailey@gmail.com', '3166 Hill Course Suite 470', 'South Bradleyland', 'Lithuania', '3575462440401660', '10/25', '2017-03-14'), (10, 'Mrs.', 'Christine', 'Bell', '50115528', '0454069943', None, 'hsimmons@hotmail.com', '47333 Lauren Lake Suite 545', 'Lake Mary', 'Australia', '372161087962692', '03/26', '2013-05-05'), (11, 'Dr.', 'Donna', 'Lucas', None, '0429723903', '26520476', 'nielsenjohn@johnson.com', '986 Evans Dam Apt. 893', 'Livingstonville', 'Norway', '630443232040', '04/23', '2016-08-10'), (12, 'Dr.', 'Nicole', 'Byrd', '78064697', '0482566551', None, 'kchandler@gmail.com', '78988 Dennis Roads Apt. 146', 'South Kathryn', 'Italy', '4705048024720449655', '08/25', '2014-08-13'), (13, 'Mr.', 'Alex', 'Harris', '77589619', '0439469581', '21696629', 'knorton@russell.com', '1927 Morris Springs Suite 104', 'New Meganborough', 'Denmark', '30161189238672', '10/26', '2011-01-10'), (14, 'Miss', 'Diane', 'Mueller', None, '0415615310', '37528952', 'nicole79@ortiz.biz', '709 Rebecca Lodge', 'Port Eric', 'Bahrain', '4156835771853085', '07/27', '2013-07-23'), (15, 'Mr.', 'Douglas', 'Torres', None, '0468381852', None, 'leahgonzales@ramos-soto.com', '1354 Rojas Fields Apt. 602', 'Jamiestad', 'Norway', '4622553185858576', '11/29', '2014-08-14'), (16, 'Dr.', 'Amy', 'Torres', None, '0442872201', None, 'vchristensen@hotmail.com', '1514 Megan Burgs', 'East Nathan', 'Iceland', '6557509432339772', '02/23', '2010-11-20'), (17, 'Mr.', 'Christopher', 'Anthony', None, '0488889973', None, 'eburns@hotmail.com', '91033 Cook Lake Suite 452', 'Christopherside', 'Bahrain', '30451729173541', '04/26', '2014-11-14'), (18, 'Mr.', 'Jacob', 'Thomas', '30156822', '0440493559', None, 'crobinson@craig.net', '2107 Ryan Bypass Apt. 047', 'Port Samuelstad', 'Sweden', '3561892898182113', '05/25', '2020-01-31'), (19, 'Mrs.', 'Abigail', 'Merritt', None, '0455995991', None, 'stephaniemclean@chavez.biz', '98828 Weber Junctions Suite 457', 'North Francisco', 'Cyprus', '4651640219412', '12/23', '2013-03-06'), (20, 'Mr.', 'Kenneth', 'Martinez', '74020749', '0411396556', '49646559', 'singhjeremy@gmail.com', '2205 Amanda Canyon Suite 931', 'Port Sherrimouth', 'Iceland', '4998391678167', '09/21', '2012-03-20'), (21, 'Dr.', 'Kevin', 'Dominguez', None, '0426794392', '56884366', 'amber37@yahoo.com', '943 Carlos Mission Suite 364', 'New Joshuaton', 'Australia', '4353038274955777', '02/25', '2010-09-27'), (22, 'Mr.', 'Christopher', 'Miller', '50902242', '0409805339',  ...

# %% [markdown]
# The output is a list of rows in the table. Each row is returned in form of a tuple. Let's have a look at the first row:

# %%
output[0]
# Out:
# (1,
#  'Mr.',
#  'Jorge',
#  'Dunn',
#  None,
#  '0429937146',
#  '48585127',
#  'sbrooks@hotmail.com',
#  '99098 Rachael Cliff',
#  'New Jasonborough',
#  'Poland',
#  '341571816096695',
#  '12/20',
#  '2019-06-17')

# %% [markdown]
# Let's turn it into a function to avoid writing the same lines of code over and over.

# %%
# This function executes a query and prints all the rows
def execute_query(conn, query):
    cur = conn.cursor()
    cur.execute(query)
    rows = cur.fetchall()
    for i,row in enumerate(rows):
        print(f'{i+1}. {row}')

# %% [markdown]
# ## SQL clauses
# ### SELECT
# SELECT is the most common clause in SQL. Using SELECT you can specify which columns should be returned.

# %%
# Returns a list of first and last names of all customers
query = '''
SELECT FirstName, Surname FROM Customers;
'''
execute_query(conn,query)
# Out:
# 1. ('Jorge', 'Dunn')
# 2. ('Debra', 'Wall')
# 3. ('Cynthia', 'Ellis')
# 4. ('John', 'Harris')
# 5. ('Kyle', 'Jones')
# 6. ('Pamela', 'Dennis')
# 7. ('Elizabeth', 'Carpenter')
# 8. ('Brett', 'Floyd')
# 9. ('Christopher', 'Liu')
# 10. ('Christine', 'Bell')
# 11. ('Donna', 'Lucas')
# 12. ('Nicole', 'Byrd')
# 13. ('Alex', 'Harris')
# 14. ('Diane', 'Mueller')
# 15. ('Douglas', 'Torres')
# 16. ('Amy', 'Torres')
# 17. ('Christopher', 'Anthony')
# 18. ('Jacob', 'Thomas')
# 19. ('Abigail', 'Merritt')
# 20. ('Kenneth', 'Martinez')
# 21. ('Kevin', 'Dominguez')
# 22. ('Christopher', 'Miller')
# 23. ('Drew', 'Spencer')
# 24. ('Shane', 'Henry')
# 25. ('Stephanie', 'Mccullough')
# 26. ('Jeffrey', 'Perez')
# 27. ('Timothy', 'Garrett')
# 28. ('Kelly', 'Smith')
# 29. ('Alec', 'Martinez')
# 30. ('Holly', 'Boyer')
# 31. ('Sean', 'Munoz')
# 32. ('Robert', 'Morris')
# 33. ('Michael', 'Moore')
# 34. ('Jennifer', 'Oliver')
# 35. ('Claudia', 'Clark')
# 36. ('Lisa', 'Collins')
# 37. ('John', 'Gonzalez')
# 38. ('Tracey', 'Williams')
# 39. ('Matthew', 'Bond')
# 40. ('Daniel', 'Jackson')
# 41. ('Kyle', 'Johnson')
# 42. ('Ellen', 'Bauer')
# 43. ('James', 'Garcia')
# 44. ('Kelly', 'Parker')
# 45. ('Katelyn', 'Garrett')
# 46. ('Jason', 'Cruz')
# 47. ('Joseph', 'Graves')
# 48. ('Patricia', 'Thomas')
# 49. ('Amber', 'Morales')
# 50. ('Diane', 'Summers')
# 51. ('Devin', 'Bailey')
# 52. ('Laurie', 'Davis')
# 53. ('Jennifer', 'Bullock')
# 54. ('Leslie', 'Bishop')
# 55. ('Paul', 'Flores')
# 56. ('Daisy', 'Franco')
# 57. ('Diana', 'Fernandez')
# 58. ('Raymond', 'Adams')
# 59. ('Lisa', 'Parker')
# 60. ('Trevor', 'Lyons')
# 61. ('Angela', 'Simpson')
# 62. ('Krystal', 'Hall')
# 63. ('Jennifer', 'Cooper')
# 64. ('Steven', 'Simon')
# 65. ('Martha', 'Erickson')
# 66. ('Christopher', 'Davis')
# 67. ('Kathleen', 'Reyes')
# 68. ('Julie', 'Hood')
# 69. ('Betty', 'Johnson')
# 70. ('Robert', 'Moore')
# 71. ('Brenda', 'Walker')
# 72. ('Christopher', 'Vargas')
# 73. ('Mark', 'Riley')
# 74. ('Sara', 'Johnson')
# 75. ('Amy', 'Griffin')
# 76. ('Robert', 'White')
# 77. ('Brett', 'Gonzales')
# 78. ('Caroline', 'Jones')
# 79. ('Angel', 'Villarreal')
# 80. ('Doris', 'Long')
# 81. ('Monica', 'Garcia')
# 82. ('Regina', 'Atkinson')
# 83. ('Timothy', 'Barrera')
# 84. ('Patricia', 'Morris')
# 85. ('Samuel', 'Snyder')
# 86. ('John', 'Dominguez')
# 87. ('Angela', 'Lang')
# 88. ('Gabriel', 'Smith')
# 89. ('Tiffany', 'Walker')
# 90. ('Jessica', 'Owen')
# 91. ('Tanya', 'Wise')
# 92. ('Amy', 'Cooke')
# 93. ('Julie', 'Sexton')
# 94. ('Christopher', 'Oliver')
# 95. ('Kristen', 'Andrews')
# 96. ('William', 'Carr')
# 97. ('Abigail', 'Lang')
# 98. ('Brittney', 'Edwards')
# 99. ('James', 'Burch')
# 100. ('Elizabeth', 'Payne')
# 101. ('Zachary', 'Davidson')
# 102. ('Brenda', 'Payne')
# 103. ('Brandon', 'Wright')
# 104. ('Christopher', 'Chaney')
# 105. ('Jim', 'Jones')
# 106. ('Maria', 'Woodard')
# 107. ('Stephanie', 'Schmidt')
# 108. ('Lori', 'Martin')
# 109. ('Stephen', 'Evans')
# 110. ('Steven', 'Sanders')
# 111. ('Laura', 'Davis')
# 112. ('Renee', 'Wilkins')
# 113. ('Monica', 'Torres')
# 114. ('Dalton', 'Patton')
# 115. ('Jose', 'Lowe')
# 116. ('Ryan', 'Harvey')
# 117. ('Stephanie', 'Gonzalez')
# 118. ('Jeffrey', 'Brown')
# 119. ('Robert', 'Jacobs')
# 120. ('Richard', 'Harrison')
# 121. ('Jackie', 'Martinez')
# 122. ('Tiffany', 'Fernandez')
# 123. ('Kayla', 'Mueller')
# 124. ('Felicia', 'Williams')
# 125. ('William', 'Burton')
# 126. ('Tyler', 'Wright')
# 127. ('Jennifer', 'Edwards')
# 128. ('David', 'Randall')
# 129. ('Kevin', 'Wright')
# 130. ('Kenneth', 'Benson')
# 131. ('Ray', 'Larson')
# 132. ('Mikayla', 'Hicks')
# 133. ('William', 'Randall')
# 134. ('Kaitlyn', 'Oliver')
# 135. ('Angela', 'Arellano')
# 136. ('Beth', 'Bradley')
# 137. ('John', 'Marshall')
# 138. ('Joseph', 'Morgan')
# 139. ('Julie', 'Brown')
# 140. ('Dana', 'Tate')
# 141. ('Elizabeth', 'Williams')
# 142. ('Danielle', 'Cruz')
# 143. ('Angela', 'Preston')
# 144. ('Tiffany', 'Gomez')
# 145. ('Tiffany', 'Rodriguez')
# 146. ('Michele', 'Carter')
# 147. ('Jonathon', 'Frye')
# 148. ('Nancy', 'Scott')
# 149. ('April', 'Bolton')
# 150. ('Matthew', 'Savage')
# 151. ('Shawn', 'Diaz')
# 152. ('Amber', 'Jordan')
# 153. ('Molly', 'Jones')
# 154. ('Abigail', 'Smith')
# 155. ('Rebekah', 'Beck')
# 156. ('Lori', 'Nelson')
# 157. ('Pamela', 'Wilson')
# 158. ('Andrew', 'Melendez')
# 159. ('Nancy', 'Stone')
# 160. ('Meredith', 'Perry')
# 161. ('Erica', 'Rodriguez')
# 162. ('Danielle', 'Martinez')
# 163. ('James', 'Robinson')
# 164. ('Mallory', 'Obrien')
# 165. ('Amanda', 'Finley')
# 166. ('Kelly', 'Miles')
# 167. ('Preston', 'Molina')
# 168. ('Melissa', 'Burns')
# 169. ('David', 'Moore')
# 170. ('Michele', 'Beck')
# 171. ('Wendy', 'Johnson')
# 172. ('Melissa', 'Morris')
# 173. ('Kenneth', 'Benjamin')
# 174. ('Mark', 'Greene')
# 175. ('Olivia', 'Lee')
# 176. ('Katie', 'Thompson')
# 177. ('Jennifer', 'Sullivan')
# 178. ('Douglas', 'Davis')
# 179. ('Patricia', 'Brown')
# 180. ('Mark', 'Hansen')
# 181. ('Andrew', 'Ryan')
# 182. ('Connie', 'Lopez')
# 183. ('Howard', 'Young')
# 184. ('Taylor', 'Byrd')
# 185. ('Joseph', 'Evans')
# 186. ('Debra', 'Watson')
# 187. ('Anthony', 'Palmer')
# 188. ('Deborah', 'Gordon')
# 189. ('Peter', 'Diaz')
# 190. ('Kimberly', 'Smith')
# 191. ('Gerald', 'Lambert')
# 192. ('Connor', 'Murphy')
# 193. ('Gabrielle', 'Cooper')
# 194. ('Rebecca', 'Werner')
# 195. ('Mark', 'Boyle')
# 196. ('Sandra', 'Lucas')
# 197. ('Justin', 'Huff')
# 198. ('Linda', 'Jones')
# 199. ('Lynn', 'Castillo')
# 200. ('Bernard', 'Cook')
# 201. ('Andrew', 'Nguyen')
# 202. ('Nicole', 'Monroe')
# 203. ('Edward', 'Goodman')
# 204. ('Isaiah', 'Phillips')
# 205. ('Christopher', 'Porter')
# 206. ('Scott', 'Benton')
# 207. ('Adam', 'Pierce')
# 208. ('Gary', 'Andrade')
# 209. ('Julia', 'King')
# 210. ('James', 'Hamilton')
# 211. ('Amanda', 'Cain')
# 212. ('Matthew', 'Miranda')
# 213. ('Courtney', 'Davenport')
# 214. ('Katie', 'Johnson')
# 215. ('Ryan', 'Sharp')
# 216. ('Anna', 'Ward')
# 217. ('Robert', 'Miller')
# 218. ('James', 'Brown')
# 219. ('Heidi', 'Kramer')
# 220. ('Tanner', 'Griffith')
# 221. ('Kyle', 'Hart')
# 222. ('Alice', 'Clay')
# 223. ('Michael', 'Nelson')
# 224. ('Amber', 'Morales')
# 225. ('Jennifer', 'Barr')
# 226. ('Curtis', 'Gallegos')
# 227. ('Keith', 'Griffin')
# 228. ('William', 'Bell')
# 229. ('Daniel', 'Roberts')
# 230. ('Alicia', 'Anderson')
# 231. ('Keith', 'Diaz')
# 232. ('Corey', 'Neal')
# 233. ('Frank', 'Wells')
# 234. ('Sharon', 'Johnson')
# 235. ('James', 'Quinn')
# 236. ('Michael', 'Sutton')
# 237. ('Paul', 'Jordan')
# 238. ('Sara', 'Tucker')
# 239. ('Aaron', 'Patel')
# 240. ('Amanda', 'Sullivan')
# 241. ('Logan', 'Marshall')
# 242. ('Shane', 'Green')
# 243. ('Aimee', 'Carlson')
# 244. ('Tiffany', 'Moore')
# 245. ('Catherine', 'Martin')
# 246. ('Matthew', 'Greene')
# 247. ('Linda', 'Hughes')
# 248. ('Jennifer', 'Schwartz')
# 249. ('Stephanie', 'Nelson')
# 250. ('Scott', 'Ho')
# 251. ('Stanley', 'Gardner')
# 252. ('Kyle', 'White')
# 253. ('Jay', 'Griffith')
# 254. ('Barry', 'Diaz')
# 255. ('Ryan', 'Pineda')
# 256. ('Brandon', 'Brown')
# 257. ('Jeremy', 'Tucker')
# 258. ('William', 'Tran')
# 259. ('Barbara', 'Tran')
# 260. ('Ashley', 'Johnson')
# 261. ('Dwayne', 'Velez')
# 262. ('Craig', 'Stevens')
# 263. ('John', 'Jackson')
# 264. ('Sarah', 'Lewis')
# 265. ('Lisa', 'Patrick')
# 266. ('Selena', 'Graves')
# 267. ('Ashley', 'Barnett')
# 268. ('Jason', 'Johnson')
# 269. ('Kayla', 'Bauer')
# 270. ('Jenny', 'Reed')
# 271. ('Kelly', 'Cardenas')
# 272. ('Dylan', 'Johnson')
# 273. ('Donna', 'Sampson')
# 274. ('Joanna', 'Hardy')
# 275. ('Monique', 'Baldwin')
# 276. ('Lauren', 'Whitney')
# 277. ('Laura', 'Pollard')
# 278. ('Kelly', 'Strong')
# 279. ('Rebecca', 'Tate')
# 280. ('Courtney', 'Myers')
# 281. ('Morgan', 'Poole')
# 282. ('Nicole', 'Scott')
# 283. ('Gabriel', 'Herrera')
# 284. ('Jonathan', 'Espinoza')
# 285. ('Benjamin', 'Long')
# 286. ('Christina', 'Bailey')
# 287. ('Carrie', 'Gonzalez')
# 288. ('Theresa', 'Molina')
# 289. ('Denise', 'Vargas')
# 290. ('Austin', 'Ramirez')
# 291. ('Connor', 'Rocha')
# 292. ('Jillian', 'Pratt')
# 293. ('Cindy', 'Russell')
# 294. ('Edward', 'Ball')
# 295. ('John', 'Morrison')
# 296. ('Anthony', 'Ponce')
# 297. ('Tim', 'Gamble')
# 298. ('Ashley', 'Hughes')
# 299. ('Dave', 'Hall')
# 300. ('Larry', 'Jones')
# 301. ('Elizabeth', 'Evans')
# 302. ('Erik', 'Kim')
# 303. ('Brianna', 'Hamilton')
# 304. ('Christopher', 'Weber')
# 305. ('Andrea', 'Dawson')
# 306. ('Michele', 'Garcia')
# 307. ('Jennifer', 'Simon')
# 308. ('Shari', 'Wilson')
# 309. ('Sandra', 'Ramos')
# 310. ('Kaitlin', 'Johnson')
# 311. ('David', 'Petersen')
# 312. ('Aaron', 'Harris')
# 313. ('Kevin', 'Dixon')
# 314. ('Suzanne', 'Cox')
# 315. ('Cheryl', 'Rios')
# 316. ('Richard', 'Davis')
# 317. ('John', 'Robles')
# 318. ('Brandon', 'Roth')
# 319. ('Jeffrey', 'Soto')
# 320. ('Charles', 'Bishop')
# 321. ('Barry', 'Cox')
# 322. ('Dorothy', 'Jimenez')
# 323. ('Monica', 'Hill')
# 324. ('Scott', 'Harris')
# 325. ('Ronald', 'Carter')
# 326. ('Benjamin', 'Holden')
# 327. ('Deborah', 'Martinez')
# 328. ('Tina', 'Huerta')
# 329. ('Ann', 'Gardner')
# 330. ('Maureen', 'Carroll')
# 331. ('Madison', 'Russell')
# 332. ('Mark', 'Watson')
# 333. ('Lisa', 'Duffy')
# 334. ('Kevin', 'Owens')
# 335. ('Melissa', 'Hill')
# 336. ('Linda', 'Bentley')
# 337. ('Cheryl', 'Barrett')
# 338. ('Shelly', 'Riley')
# 339. ('Sarah', 'Evans')
# 340. ('Christy', 'Washington')
# 341. ('Adam', 'Lopez')
# 342. ('Daniel', 'Harmon')
# 343. ('Gerald', 'Andrews')
# 344. ('Carla', 'Williamson')
# 345. ('Jerry', 'Clark')
# 346. ('Sharon', 'Diaz')
# 347. ('Crystal', 'Hall')
# 348. ('Jessica', 'Thomas')
# 349. ('Steven', 'Swanson')
# 350. ('Richard', 'Sheppard')
# 351. ('Michael', 'Jones')
# 352. ('Brian', 'Mcclure')
# 353. ('Victor', 'Phelps')
# 354. ('Cynthia', 'Cameron')
# 355. ('James', 'Wagner')
# 356. ('Scott', 'Patterson')
# 357. ('Joseph', 'Singh')
# 358. ('Crystal', 'Williams')
# 359. ('Justin', 'Price')
# 360. ('Jacob', 'Romero')
# 361. ('Holly', 'Carroll')
# 362. ('Thomas', 'Yang')
# 363. ('Katherine', 'Norman')
# 364. ('Scott', 'Mcdonald')
# 365. ('Nicholas', 'Gray')
# 366. ('Peter', 'Wade')
# 367. ('Victoria', 'Bradley')
# 368. ('Nicholas', 'Hinton')
# 369. ('Stephanie', 'Bennett')
# 370. ('Jeremy', 'Saunders')
# 371. ('Mike', 'Lynch')
# 372. ('Kenneth', 'Livingston')
# 373. ('Karen', 'Thomas')
# 374. ('Joseph', 'Walker')
# 375. ('Jeffrey', 'Hall')
# 376. ('Victoria', 'Wright')
# 377. ('Mark', 'York')
# 378. ('Katherine', 'Price')
# 379. ('Martin', 'Smith')
# 380. ('Timothy', 'Campbell')
# 381. ('Patricia', 'Prince')
# 382. ('Tyler', 'Clark')
# 383. ('Joseph', 'Perez')
# 384. ('James', 'Friedman')
# 385. ('Krista', 'Nichols')
# 386. ('Mark', 'Bradley')
# 387. ('Julie', 'Graves')
# 388. ('Jesse', 'Wallace')
# 389. ('Austin', 'Shelton')
# 390. ('Stacey', 'Anderson')
# 391. ('Dawn', 'Young')
# 392. ('Latoya', 'Barrera')
# 393. ('Sean', 'Bennett')
# 394. ('Rodney', 'Lynn')
# 395. ('Christian', 'Moore')
# 396. ('John', 'Andrews')
# 397. ('Dominique', 'Sullivan')
# 398. ('Matthew', 'Smith')
# 399. ('Karen', 'Sanders')
# 400. ('Christopher', 'Schaefer')
# 401. ('Lynn', 'Holmes')
# 402. ('Dan', 'Wilson')
# 403. ('Daniel', 'Welch')
# 404. ('Rhonda', 'Adams')
# 405. ('John', 'Young')
# 406. ('Sarah', 'Frost')
# 407. ('Christopher', 'Rios')
# 408. ('Beverly', 'Walker')
# 409. ('Mary', 'Oconnell')
# 410. ('Regina', 'Bell')
# 411. ('John', 'Torres')
# 412. ('Kristen', 'Gaines')
# 413. ('Brett', 'Lyons')
# 414. ('Steven', 'Weiss')
# 415. ('Kristie', 'Cross')
# 416. ('Nicholas', 'Allen')
# 417. ('John', 'Hernandez')
# 418. ('Laura', 'Larsen')
# 419. ('Adam', 'Gonzalez')
# 420. ('Jordan', 'Russo')
# 421. ('Robert', 'Case')
# 422. ('Andrea', 'Mclean')
# 423. ('Jacob', 'Arnold')
# 424. ('Mary', 'Compton')
# 425. ('Karen', 'Hanson')
# 426. ('Melissa', 'Hernandez')
# 427. ('Jose', 'Evans')
# 428. ('Alan', 'Lawson')
# 429. ('Bonnie', 'Bright')
# 430. ('Brad', 'Barton')
# 431. ('Janice', 'Peters')
# 432. ('Kristopher', 'Miller')
# 433. ('Catherine', 'Haas')
# 434. ('Mary', 'Ellis')
# 435. ('Melissa', 'Barnett')
# 436. ('Megan', 'Smith')
# 437. ('Jennifer', 'Cruz')
# 438. ('Alexander', 'Robinson')
# 439. ('Haley', 'Phillips')
# 440. ('Kristina', 'Howell')
# 441. ('Julie', 'Morales')
# 442. ('Amanda', 'Bennett')
# 443. ('Donald', 'Mejia')
# 444. ('Margaret', 'Perez')
# 445. ('Jason', 'Taylor')
# 446. ('Alyssa', 'Simmons')
# 447. ('Valerie', 'Garcia')
# 448. ('Dana', 'Kelly')
# 449. ('Michael', 'Dixon')
# 450. ('Clinton', 'Saunders')
# 451. ('Kayla', 'Simmons')
# 452. ('Jo', 'Davis')
# 453. ('Jack', 'Bailey')
# 454. ('Rachel', 'Harris')
# 455. ('Deanna', 'Stewart')
# 456. ('Robert', 'Soto')
# 457. ('Anthony', 'Olson')
# 458. ('Justin', 'Barry')
# 459. ('Robert', 'David')
# 460. ('Christopher', 'Neal')
# 461. ('Mitchell', 'Wagner')
# 462. ('Carolyn', 'Mccullough')
# 463. ('Brittany', 'Velez')
# 464. ('Rhonda', 'Ortiz')
# 465. ('Shane', 'Arnold')
# 466. ('Crystal', 'Jackson')
# 467. ('James', 'Bush')
# 468. ('Kelly', 'Smith')
# 469. ('Susan', 'Moore')
# 470. ('Steven', 'Robinson')
# 471. ('Mackenzie', 'Owens')
# 472. ('Amy', 'Walker')
# 473. ('Kelsey', 'Schneider')
# 474. ('David', 'Vargas')
# 475. ('Lauren', 'Rose')
# 476. ('Jasmine', 'Stuart')
# 477. ('Travis', 'Harris')
# 478. ('Ashley', 'Mack')
# 479. ('Mary', 'Price')
# 480. ('Melissa', 'Holloway')
# 481. ('David', 'Garcia')
# 482. ('Gloria', 'Stafford')
# 483. ('Roberto', 'Young')
# 484. ('Curtis', 'Gonzalez')
# 485. ('Sabrina', 'Vang')
# 486. ('Erica', 'Macdonald')
# 487. ('Robert', 'Mendoza')
# 488. ('Sharon', 'Martinez')
# 489. ('Leslie', 'Miller')
# 490. ('Oscar', 'Brown')
# 491. ('Matthew', 'Rowe')
# 492. ('Shawn', 'Huff')
# 493. ('Brandon', 'Sanchez')
# 494. ('Stacey', 'Page')
# 495. ('Tammy', 'Phillips')
# 496. ('Gabriela', 'Cummings')
# 497. ('Terry', 'Sexton')
# 498. ('Danny', 'Green')
# 499. ('Keith', 'Nichols')
# 500. ('Tommy', 'Hughes')
# 501. ('Jonathan', 'Smith')
# 502. ('Anthony', 'Green')
# 503. ('Paul', 'Collins')
# 504. ('Natasha', 'Wolf')
# 505. ('Jacqueline', 'Clark')
# 506. ('Edward', 'Mack')
# 507. ('Heidi', 'Alexander')
# 508. ('Shirley', 'Bell')
# 509. ('Kelsey', 'Griffith')
# 510. ('Michael', 'Martin')
# 511. ('Richard', 'Garner')
# 512. ('Matthew', 'Ramos')
# 513. ('Matthew', 'Werner')
# 514. ('Timothy', 'Campbell')
# 515. ('Morgan', 'Stewart')
# 516. ('Vernon', 'Simpson')
# 517. ('Marilyn', 'Rodriguez')
# 518. ('Joseph', 'Stephens')
# 519. ('Megan', 'Davis')
# 520. ('Justin', 'Copeland')
# 521. ('David', 'Holmes')
# 522. ('Gabrielle', 'Combs')
# 523. ('Michelle', 'Stevens')
# 524. ('Ryan', 'Hatfield')
# 525. ('Craig', 'Martin')
# 526. ('Jasmine', 'Garza')
# 527. ('Alexandra', 'Gibbs')
# 528. ('Emily', 'Brown')
# 529. ('Jenna', 'Hernandez')
# 530. ('Brandon', 'Butler')
# 531. ('Blake', 'Pace')
# 532. ('Justin', 'Herrera')
# 533. ('Sandra', 'Sims')
# 534. ('David', 'Owens')
# 535. ('Richard', 'Mullen')
# 536. ('Susan', 'Fowler')
# 537. ('Sherri', 'Russo')
# 538. ('Anthony', 'Mcdonald')
# 539. ('Mark', 'Mitchell')
# 540. ('Charles', 'Martin')
# 541. ('Francis', 'Mercado')
# 542. ('Phillip', 'Brown')
# 543. ('Terri', 'Savage')
# 544. ('Michael', 'Rowland')
# 545. ('Kevin', 'Smith')
# 546. ('Matthew', 'Robertson')
# 547. ('Danielle', 'Thomas')
# 548. ('Elizabeth', 'Villarreal')
# 549. ('Phillip', 'Rios')
# 550. ('Maria', 'Wilson')
# 551. ('Patricia', 'Savage')
# 552. ('Devin', 'Mitchell')
# 553. ('Samantha', 'Garcia')
# 554. ('Derrick', 'Taylor')
# 555. ('Lauren', 'Allen')
# 556. ('Carlos', 'Lawson')
# 557. ('Zachary', 'Davis')
# 558. ('Michael', 'Gonzales')
# 559. ('Mary', 'Mccoy')
# 560. ('Matthew', 'Smith')
# 561. ('Steven', 'Wilson')
# 562. ('Thomas', 'Barrett')
# 563. ('William', 'James')
# 564. ('Denise', 'Hahn')
# 565. ('Steven', 'Hicks')
# 566. ('Austin', 'Osborn')
# 567. ('Heather', 'Davila')
# 568. ('Sarah', 'Adams')
# 569. ('Leslie', 'Rush')
# 570. ('Kevin', 'Cantrell')
# 571. ('Adrian', 'Gamble')
# 572. ('Richard', 'Saunders')
# 573. ('Ashley', 'Wade')
# 574. ('Nathaniel', 'Gutierrez')
# 575. ('Andrea', 'Nixon')
# 576. ('Margaret', 'Franco')
# 577. ('Randy', 'Howard')
# 578. ('Brandon', 'Hernandez')
# 579. ('Deborah', 'Perry')
# 580. ('Jennifer', 'Livingston')
# 581. ('Tracy', 'Spencer')
# 582. ('Monica', 'Lopez')
# 583. ('Julie', 'Martinez')
# 584. ('Christopher', 'Griffith')
# 585. ('Shannon', 'Mcconnell')
# 586. ('Mary', 'Hogan')
# 587. ('Joseph', 'Johnson')
# 588. ('Annette', 'Miller')
# 589. ('Theodore', 'Norman')
# 590. ('Kimberly', 'Morris')
# 591. ('Christopher', 'Bradley')
# 592. ('Mariah', 'Davis')
# 593. ('Tanner', 'Gross')
# 594. ('Jared', 'Kramer')
# 595. ('Samuel', 'Strickland')
# 596. ('Stephanie', 'Rice')
# 597. ('Eric', 'Scott')
# 598. ('Carlos', 'Frank')
# 599. ('Lauren', 'Smith')
# 600. ('Kristina', 'Carlson')
# 601. ('Michael', 'Andrews')
# 602. ('Amy', 'Johnson')
# 603. ('Christopher', 'Jones')
# 604. ('Shannon', 'Boyle')
# 605. ('David', 'Bradley')
# 606. ('Amanda', 'Fitzpatrick')
# 607. ('Alexis', 'Hawkins')
# 608. ('Isaac', 'Price')
# 609. ('Robin', 'Carpenter')
# 610. ('Michael', 'Brewer')
# 611. ('Justin', 'Johns')
# 612. ('Angel', 'Anderson')
# 613. ('Heather', 'Perez')
# 614. ('Michael', 'Phelps')
# 615. ('James', 'Bailey')
# 616. ('Dominique', 'Trujillo')
# 617. ('Jeffrey', 'Lee')
# 618. ('Daniel', 'Donovan')
# 619. ('Christopher', 'Horton')
# 620. ('Erin', 'Murray')
# 621. ('Sandra', 'Mccarthy')
# 622. ('Daisy', 'Moore')
# 623. ('George', 'Brewer')
# 624. ('Erin', 'James')
# 625. ('Brittany', 'Dalton')
# 626. ('Hannah', 'Harrison')
# 627. ('Joshua', 'Montoya')
# 628. ('Robin', 'Fleming')
# 629. ('Raymond', 'Bennett')
# 630. ('Kelly', 'Buckley')
# 631. ('Courtney', 'Meza')
# 632. ('Adam', 'Smith')
# 633. ('Richard', 'Phillips')
# 634. ('Michele', 'Ali')
# 635. ('Ann', 'Neal')
# 636. ('Brittany', 'Huff')
# 637. ('Erin', 'Charles')
# 638. ('Nicholas', 'Carroll')
# 639. ('Jonathan', 'Miller')
# 640. ('George', 'Miller')
# 641. ('Holly', 'Lee')
# 642. ('Ryan', 'Wilkins')
# 643. ('Mary', 'Eaton')
# 644. ('Victoria', 'Savage')
# 645. ('Troy', 'Lee')
# 646. ('Theresa', 'Matthews')
# 647. ('Anthony', 'Wright')
# 648. ('Judith', 'Kim')
# 649. ('Jeffrey', 'Gonzalez')
# 650. ('Adam', 'Lambert')
# 651. ('Paula', 'Beck')
# 652. ('Robert', 'Collins')
# 653. ('Kimberly', 'Clark')
# 654. ('Jennifer', 'Hamilton')
# 655. ('Bruce', 'Casey')
# 656. ('Timothy', 'Waters')
# 657. ('Kelly', 'Warren')
# 658. ('David', 'Hughes')
# 659. ('Tim', 'Robinson')
# 660. ('Maria', 'Smith')
# 661. ('Michael', 'Hardin')
# 662. ('Mathew', 'Hart')
# 663. ('Amy', 'Evans')
# 664. ('Kenneth', 'Holder')
# 665. ('Hunter', 'Moore')
# 666. ('Brian', 'Gutierrez')
# 667. ('Michael', 'Edwards')
# 668. ('Gregory', 'Gibson')
# 669. ('Melinda', 'Shea')
# 670. ('Elizabeth', 'Kirk')
# 671. ('Christopher', 'Knapp')
# 672. ('Elizabeth', 'Hansen')
# 673. ('Erin', 'Waters')
# 674. ('Daniel', 'Richardson')
# 675. ('Mary', 'Davis')
# 676. ('Cynthia', 'Mcfarland')
# 677. ('Jennifer', 'Wilson')
# 678. ('Christian', 'Meyer')
# 679. ('Kevin', 'Wright')
# 680. ('Ashley', 'Hampton')
# 681. ('Richard', 'Hernandez')
# 682. ('Elizabeth', 'Rodriguez')
# 683. ('Lynn', 'Tucker')
# 684. ('Alicia', 'Hudson')
# 685. ('David', 'Holt')
# 686. ('Bianca', 'Webster')
# 687. ('Hannah', 'Vasquez')
# 688. ('Jennifer', 'Phillips')
# 689. ('Joseph', 'Norton')
# 690. ('Donna', 'Jackson')
# 691. ('Edwin', 'Smith')
# 692. ('Brian', 'Johnson')
# 693. ('Brandon', 'Clark')
# 694. ('Seth', 'Stevens')
# 695. ('Calvin', 'Stewart')
# 696. ('Jennifer', 'Gregory')
# 697. ('Andrea', 'Beltran')
# 698. ('Michael', 'Miller')
# 699. ('Megan', 'Williams')
# 700. ('Brian', 'Henry')
# 701. ('Dominique', 'Jones')
# 702. ('Michelle', 'Gaines')
# 703. ('Kendra', 'Hayden')
# 704. ('Allison', 'Hodge')
# 705. ('David', 'Gray')
# 706. ('Jesse', 'Villarreal')
# 707. ('Gregory', 'Hanson')
# 708. ('Andrea', 'Casey')
# 709. ('Susan', 'Fisher')
# 710. ('Mason', 'Zavala')
# 711. ('George', 'Henderson')
# 712. ('Lynn', 'Murray')
# 713. ('Kayla', 'Green')
# 714. ('Calvin', 'Knight')
# 715. ('Michael', 'Stark')
# 716. ('Barbara', 'Williams')
# 717. ('Jason', 'Grant')
# 718. ('Maria', 'Gutierrez')
# 719. ('Angela', 'Vincent')
# 720. ('Eric', 'Ortiz')
# 721. ('Diane', 'Moon')
# 722. ('Charlene', 'Hayden')
# 723. ('Brian', 'White')
# 724. ('Michael', 'Jones')
# 725. ('Jason', 'White')
# 726. ('Bobby', 'Morgan')
# 727. ('Brian', 'Solis')
# 728. ('Joseph', 'Gonzalez')
# 729. ('Hayden', 'Romero')
# 730. ('Jasmine', 'Wilson')
# 731. ('Anthony', 'Reese')
# 732. ('John', 'Johnson')
# 733. ('Maria', 'Lee')
# 734. ('Katherine', 'Zhang')
# 735. ('Bryan', 'Hale')
# 736. ('Megan', 'Gordon')
# 737. ('Danielle', 'Carr')
# 738. ('Christina', 'Hill')
# 739. ('Melissa', 'Kennedy')
# 740. ('Angel', 'Gillespie')
# 741. ('Jessica', 'Tucker')
# 742. ('Steven', 'Graham')
# 743. ('Jennifer', 'Nash')
# 744. ('Jennifer', 'Gould')
# 745. ('Clinton', 'Craig')
# 746. ('Nancy', 'Luna')
# 747. ('Sharon', 'Barajas')
# 748. ('Cindy', 'Bowman')
# 749. ('James', 'Diaz')
# 750. ('Donald', 'Miller')
# 751. ('Michael', 'Wilson')
# 752. ('Dillon', 'Malone')
# 753. ('Cynthia', 'Collier')
# 754. ('Robin', 'Barnett')
# 755. ('Nathan', 'Houston')
# 756. ('Rebecca', 'Cisneros')
# 757. ('Sara', 'Grant')
# 758. ('Omar', 'Edwards')
# 759. ('Janice', 'Martin')
# 760. ('Jack', 'Snyder')
# 761. ('Susan', 'Andersen')
# 762. ('Pamela', 'Elliott')
# 763. ('Jennifer', 'Olson')
# 764. ('Charles', 'Velasquez')
# 765. ('Donna', 'Coffey')
# 766. ('Corey', 'Peterson')
# 767. ('Natasha', 'Evans')
# 768. ('Jesus', 'Tapia')
# 769. ('Austin', 'Callahan')
# 770. ('David', 'Gould')
# 771. ('Emma', 'Reyes')
# 772. ('Kimberly', 'Cannon')
# 773. ('Timothy', 'Carlson')
# 774. ('Ryan', 'Sharp')
# 775. ('Thomas', 'Shelton')
# 776. ('David', 'Brennan')
# 777. ('Debra', 'Stewart')
# 778. ('Sarah', 'Moore')
# 779. ('Alexandria', 'Garcia')
# 780. ('Juan', 'Mendoza')
# 781. ('Sarah', 'Williams')
# 782. ('Terry', 'Brown')
# 783. ('Tiffany', 'Evans')
# 784. ('Lauren', 'Stephens')
# 785. ('Jean', 'Ramirez')
# 786. ('Jennifer', 'Ray')
# 787. ('Ashley', 'Meyers')
# 788. ('Bethany', 'Rodriguez')
# 789. ('Aaron', 'Gates')
# 790. ('Jason', 'Sharp')
# 791. ('Carolyn', 'Smith')
# 792. ('Megan', 'Smith')
# 793. ('Steven', 'Keith')
# 794. ('Troy', 'Garcia')
# 795. ('Rachel', 'Perez')
# 796. ('Tracy', 'Griffith')
# 797. ('Nicole', 'Wiley')
# 798. ('Jessica', 'Pierce')
# 799. ('Kristina', 'Thompson')
# 800. ('Maria', 'Perry')
# 801. ('William', 'Mcdonald')
# 802. ('Lisa', 'Terrell')
# 803. ('Tristan', 'Bell')
# 804. ('Erica', 'Moss')
# 805. ('Angela', 'Hernandez')
# 806. ('Nathan', 'Tyler')
# 807. ('Michael', 'Collins')
# 808. ('Wendy', 'Greene')
# 809. ('John', 'Stout')
# 810. ('Bianca', 'Stark')
# 811. ('William', 'Hayes')
# 812. ('Daniel', 'Foster')
# 813. ('Sarah', 'Mueller')
# 814. ('Travis', 'Chavez')
# 815. ('Michael', 'Gutierrez')
# 816. ('Stephanie', 'Snyder')
# 817. ('Jacqueline', 'Robinson')
# 818. ('Duane', 'Padilla')
# 819. ('Jasmine', 'Coleman')
# 820. ('William', 'Hanna')
# 821. ('Alicia', 'Ibarra')
# 822. ('Lauren', 'Craig')
# 823. ('Patricia', 'Mcdonald')
# 824. ('Michael', 'Shaw')
# 825. ('Christopher', 'Bradley')
# 826. ('Melissa', 'Wilson')
# 827. ('Douglas', 'Lewis')
# 828. ('Samantha', 'Sanchez')
# 829. ('Gregory', 'Nielsen')
# 830. ('Anthony', 'Fletcher')
# 831. ('Kenneth', 'Haley')
# 832. ('Darrell', 'Alexander')
# 833. ('Roy', 'Melendez')
# 834. ('Jermaine', 'Rojas')
# 835. ('Brian', 'Lozano')
# 836. ('Glen', 'Reyes')
# 837. ('Deborah', 'Garcia')
# 838. ('Jeffrey', 'Wong')
# 839. ('Terri', 'Keller')
# 840. ('Charles', 'Gonzalez')
# 841. ('Connie', 'Norris')
# 842. ('Carl', 'Scott')
# 843. ('Ashley', 'Koch')
# 844. ('Richard', 'Larsen')
# 845. ('Laura', 'Sutton')
# 846. ('Eric', 'Roth')
# 847. ('Timothy', 'Mcclure')
# 848. ('Gabrielle', 'Ward')
# 849. ('Michael', 'Cabrera')
# 850. ('Christine', 'Williams')
# 851. ('Angela', 'Wang')
# 852. ('Jennifer', 'Sandoval')
# 853. ('Betty', 'Decker')
# 854. ('Sarah', 'Obrien')
# 855. ('George', 'Brady')
# 856. ('Susan', 'Stephens')
# 857. ('Dwayne', 'Juarez')
# 858. ('Anna', 'Harris')
# 859. ('Kyle', 'Taylor')
# 860. ('Austin', 'Peters')
# 861. ('Devin', 'Barnes')
# 862. ('Frank', 'Smith')
# 863. ('Theresa', 'Peck')
# 864. ('Tammy', 'Potter')
# 865. ('Dennis', 'Gardner')
# 866. ('Casey', 'Pugh')
# 867. ('Jessica', 'Estrada')
# 868. ('Bethany', 'Rodriguez')
# 869. ('Timothy', 'Garza')
# 870. ('Tanya', 'Paul')
# 871. ('Marie', 'Ward')
# 872. ('Danielle', 'Valencia')
# 873. ('Alicia', 'Padilla')
# 874. ('Anne', 'Fowler')
# 875. ('Jennifer', 'Martin')
# 876. ('Stephanie', 'Nelson')
# 877. ('Jeffrey', 'Patterson')
# 878. ('Jacob', 'Dalton')
# 879. ('Jeffrey', 'Best')
# 880. ('Tamara', 'Walker')
# 881. ('Evelyn', 'Hernandez')
# 882. ('Michele', 'Reid')
# 883. ('Christopher', 'Hill')
# 884. ('Robert', 'Sullivan')
# 885. ('Sherry', 'Meyer')
# 886. ('Cheyenne', 'Fletcher')
# 887. ('Rachel', 'Williams')
# 888. ('Allen', 'Morales')
# 889. ('Luis', 'George')
# 890. ('Kristin', 'Acosta')
# 891. ('Ashley', 'Robles')
# 892. ('Mark', 'Duran')
# 893. ('Jose', 'Jackson')
# 894. ('Joseph', 'Hodge')
# 895. ('Julie', 'Jennings')
# 896. ('Cynthia', 'Holt')
# 897. ('Mercedes', 'Byrd')
# 898. ('Jason', 'Goodwin')
# 899. ('Daniel', 'Taylor')
# 900. ('Joshua', 'Sanders')
# 901. ('Lucas', 'West')
# 902. ('Michelle', 'Lewis')
# 903. ('Christopher', 'Frye')
# 904. ('Sarah', 'Salas')
# 905. ('Philip', 'Walsh')
# 906. ('April', 'Herman')
# 907. ('Stephanie', 'Ross')
# 908. ('Sharon', 'Bush')
# 909. ('Brandon', 'Reyes')
# 910. ('Diana', 'Mccormick')
# 911. ('Kevin', 'Macias')
# 912. ('Kelly', 'Martin')
# 913. ('Taylor', 'Perez')
# 914. ('Arthur', 'Clark')
# 915. ('Melissa', 'Cook')
# 916. ('Evan', 'Powell')
# 917. ('Kimberly', 'Elliott')
# 918. ('Patrick', 'Haynes')
# 919. ('Dana', 'Nunez')
# 920. ('Gerald', 'Smith')
# 921. ('Scott', 'Ware')
# 922. ('Robert', 'Moody')
# 923. ('Christy', 'Mitchell')
# 924. ('Christopher', 'Adams')
# 925. ('Heather', 'Bradley')
# 926. ('Erika', 'Ellis')
# 927. ('Cameron', 'Carlson')
# 928. ('Jesus', 'Baker')
# 929. ('John', 'Anderson')
# 930. ('Aaron', 'Russell')
# 931. ('Ronnie', 'Hill')
# 932. ('Brittany', 'Nash')
# 933. ('Rodney', 'Smith')
# 934. ('Cathy', 'Mack')
# 935. ('John', 'Aguirre')
# 936. ('Jill', 'Lee')
# 937. ('Joseph', 'Cruz')
# 938. ('Clifford', 'Heath')
# 939. ('Jennifer', 'Matthews')
# 940. ('Anthony', 'Mason')
# 941. ('Holly', 'Martinez')
# 942. ('Perry', 'Branch')
# 943. ('Christopher', 'Hall')
# 944. ('Alicia', 'Schneider')
# 945. ('Susan', 'Richardson')
# 946. ('Nathan', 'Hughes')
# 947. ('Jesus', 'Camacho')
# 948. ('Melinda', 'Smith')
# 949. ('Bobby', 'Calhoun')
# 950. ('James', 'Lopez')
# 951. ('Brett', 'Mcdonald')
# 952. ('Brianna', 'Duncan')
# 953. ('Benjamin', 'Harris')
# 954. ('Christopher', 'Woods')
# 955. ('Deborah', 'Hill')
# 956. ('Shawn', 'Ramirez')
# 957. ('Michael', 'Reed')
# 958. ('Steven', 'Fuller')
# 959. ('Richard', 'Cummings')
# 960. ('Robert', 'Alvarez')
# 961. ('Joshua', 'Martinez')
# 962. ('Jack', 'Wright')
# 963. ('Penny', 'Paul')
# 964. ('Lori', 'Anderson')
# 965. ('Richard', 'Young')
# 966. ('Steven', 'Murphy')
# 967. ('Sara', 'Brooks')
# 968. ('Kelly', 'Murray')
# 969. ('Jaime', 'Romero')
# 970. ('Rachel', 'Anthony')
# 971. ('Lisa', 'Taylor')
# 972. ('Andrew', 'Thompson')
# 973. ('Benjamin', 'Oneal')
# 974. ('Lauren', 'Hensley')
# 975. ('Mitchell', 'Stanley')
# 976. ('Nathan', 'Gentry')
# 977. ('Laura', 'Brown')
# 978. ('Lauren', 'Barrera')
# 979. ('Kathy', 'Proctor')
# 980. ('Christina', 'Hernandez')
# 981. ('Dakota', 'Monroe')
# 982. ('Patricia', 'Andrews')
# 983. ('John', 'Smith')
# 984. ('Willie', 'Perez')
# 985. ('Derek', 'Jimenez')
# 986. ('Laura', 'Moore')
# 987. ('Noah', 'Hayes')
# 988. ('John', 'Neal')
# 989. ('Richard', 'Wood')
# 990. ('Andrew', 'Wilcox')
# 991. ('Lauren', 'Dickerson')
# 992. ('Anthony', 'Chambers')
# 993. ('Mary', 'Morgan')
# 994. ('Sean', 'Estrada')
# 995. ('Lauren', 'Hansen')
# 996. ('Joshua', 'Thomas')
# 997. ('Tyler', 'Sawyer')
# 998. ('Johnny', 'Clark')
# 999. ('Monica', 'Stewart')
# 1000. ('David', 'Williams')
# 1001. ('Elizabeth', 'Payne')
# 1002. ('Michelle', 'Jackson')
# 1003. ('Steven', 'Mccarthy')
# 1004. ('Carrie', 'Adams')
# 1005. ('Susan', 'Yang')
# 1006. ('Brittany', 'Powers')
# 1007. ('Anthony', 'Johnson')
# 1008. ('Daniel', 'Perez')
# 1009. ('Patricia', 'Gonzalez')
# 1010. ('Jennifer', 'Mathis')
# 1011. ('Cole', 'Patel')
# 1012. ('Phillip', 'Fields')
# 1013. ('Charles', 'Cox')
# 1014. ('Ashley', 'Mcclure')
# 1015. ('Rita', 'Holmes')
# 1016. ('Christina', 'Hughes')
# 1017. ('Tracy', 'Kim')
# 1018. ('Susan', 'Adkins')
# 1019. ('Dustin', 'Nicholson')
# 1020. ('Danielle', 'Morris')
# 1021. ('Jonathon', 'Davis')
# 1022. ('Jared', 'Allen')
# 1023. ('Melissa', 'Harris')
# 1024. ('Belinda', 'Duncan')
# 1025. ('Karen', 'Taylor')
# 1026. ('Brandon', 'Carter')
# 1027. ('Rodney', 'Lee')
# 1028. ('Connor', 'Knight')
# 1029. ('David', 'Berger')
# 1030. ('Tara', 'Benson')
# 1031. ('Kelly', 'Dunn')
# 1032. ('Stacey', 'Ramsey')
# 1033. ('Todd', 'Williamson')
# 1034. ('Joseph', 'Thomas')

# %%
# Returns a list of first name, last name, and email for all customers
query = '''
SELECT FirstName, Surname, Email FROM Customers;
'''
execute_query(conn,query)
# Out:
# 1. ('Jorge', 'Dunn', 'sbrooks@hotmail.com')
# 2. ('Debra', 'Wall', 'colleenalexander@taylor-brown.net')
# 3. ('Cynthia', 'Ellis', 'vstewart@gmail.com')
# 4. ('John', 'Harris', 'yarmstrong@hotmail.com')
# 5. ('Kyle', 'Jones', 'cindy97@yahoo.com')
# 6. ('Pamela', 'Dennis', 'ljohnston@hotmail.com')
# 7. ('Elizabeth', 'Carpenter', 'ericataylor@yahoo.com')
# 8. ('Brett', 'Floyd', 'gouldheidi@armstrong.info')
# 9. ('Christopher', 'Liu', 'jenniferbailey@gmail.com')
# 10. ('Christine', 'Bell', 'hsimmons@hotmail.com')
# 11. ('Donna', 'Lucas', 'nielsenjohn@johnson.com')
# 12. ('Nicole', 'Byrd', 'kchandler@gmail.com')
# 13. ('Alex', 'Harris', 'knorton@russell.com')
# 14. ('Diane', 'Mueller', 'nicole79@ortiz.biz')
# 15. ('Douglas', 'Torres', 'leahgonzales@ramos-soto.com')
# 16. ('Amy', 'Torres', 'vchristensen@hotmail.com')
# 17. ('Christopher', 'Anthony', 'eburns@hotmail.com')
# 18. ('Jacob', 'Thomas', 'crobinson@craig.net')
# 19. ('Abigail', 'Merritt', 'stephaniemclean@chavez.biz')
# 20. ('Kenneth', 'Martinez', 'singhjeremy@gmail.com')
# 21. ('Kevin', 'Dominguez', 'amber37@yahoo.com')
# 22. ('Christopher', 'Miller', 'samantha44@anderson-alexander.org')
# 23. ('Drew', 'Spencer', 'jeffthompson@johnson-lopez.com')
# 24. ('Shane', 'Henry', 'april30@yahoo.com')
# 25. ('Stephanie', 'Mccullough', 'jessicagrimes@gonzales.info')
# 26. ('Jeffrey', 'Perez', 'mark60@hotmail.com')
# 27. ('Timothy', 'Garrett', 'stephaniediaz@douglas-pineda.com')
# 28. ('Kelly', 'Smith', 'oliviarogers@yahoo.com')
# 29. ('Alec', 'Martinez', 'floresdavid@king-jackson.com')
# 30. ('Holly', 'Boyer', 'judyhamilton@gmail.com')
# 31. ('Sean', 'Munoz', 'ashleysteele@yahoo.com')
# 32. ('Robert', 'Morris', 'pabbott@gmail.com')
# 33. ('Michael', 'Moore', 'tkaufman@hotmail.com')
# 34. ('Jennifer', 'Oliver', 'larry90@cunningham.com')
# 35. ('Claudia', 'Clark', 'lawsonmelody@johnson.info')
# 36. ('Lisa', 'Collins', 'ewilliams@gmail.com')
# 37. ('John', 'Gonzalez', 'sanchezjoel@hotmail.com')
# 38. ('Tracey', 'Williams', 'jefferynguyen@hotmail.com')
# 39. ('Matthew', 'Bond', 'garciatanya@steele.com')
# 40. ('Daniel', 'Jackson', 'scott87@burns.org')
# 41. ('Kyle', 'Johnson', 'tammy71@gmail.com')
# 42. ('Ellen', 'Bauer', 'rlee@hotmail.com')
# 43. ('James', 'Garcia', 'robinsonshane@yahoo.com')
# 44. ('Kelly', 'Parker', 'wilsonclaudia@bradley.net')
# 45. ('Katelyn', 'Garrett', 'jacquelineporter@hotmail.com')
# 46. ('Jason', 'Cruz', 'williamsdeanna@yahoo.com')
# 47. ('Joseph', 'Graves', 'anna73@miller-matthews.org')
# 48. ('Patricia', 'Thomas', 'maria02@gmail.com')
# 49. ('Amber', 'Morales', 'summersrachel@martin.com')
# 50. ('Diane', 'Summers', 'williamstodd@fields.com')
# 51. ('Devin', 'Bailey', 'maureen76@reynolds.info')
# 52. ('Laurie', 'Davis', 'michael10@yahoo.com')
# 53. ('Jennifer', 'Bullock', 'katie07@whitaker-sweeney.com')
# 54. ('Leslie', 'Bishop', 'sbrown@hotmail.com')
# 55. ('Paul', 'Flores', 'paige75@gay-gilbert.com')
# 56. ('Daisy', 'Franco', 'jaredestrada@yahoo.com')
# 57. ('Diana', 'Fernandez', 'jfarrell@yahoo.com')
# 58. ('Raymond', 'Adams', 'andrew61@brady.com')
# 59. ('Lisa', 'Parker', 'christopher99@gmail.com')
# 60. ('Trevor', 'Lyons', 'jacqueline43@brown.com')
# 61. ('Angela', 'Simpson', 'barnettmadison@harding-ray.com')
# 62. ('Krystal', 'Hall', 'owensgabriel@yahoo.com')
# 63. ('Jennifer', 'Cooper', 'karen20@watson.com')
# 64. ('Steven', 'Simon', 'richardschristopher@jacobs.org')
# 65. ('Martha', 'Erickson', 'jasmine27@hotmail.com')
# 66. ('Christopher', 'Davis', 'alexander50@clayton.org')
# 67. ('Kathleen', 'Reyes', 'chelseagutierrez@carrillo.com')
# 68. ('Julie', 'Hood', 'justin78@cox.com')
# 69. ('Betty', 'Johnson', 'robertzavala@yahoo.com')
# 70. ('Robert', 'Moore', 'stephanie49@hotmail.com')
# 71. ('Brenda', 'Walker', 'davisronald@gmail.com')
# 72. ('Christopher', 'Vargas', 'vsanford@fisher.biz')
# 73. ('Mark', 'Riley', 'jamiegarza@hotmail.com')
# 74. ('Sara', 'Johnson', 'ehood@hotmail.com')
# 75. ('Amy', 'Griffin', 'mitchellhansen@molina.org')
# 76. ('Robert', 'White', 'hollowaykelly@gmail.com')
# 77. ('Brett', 'Gonzales', 'joecohen@farmer.com')
# 78. ('Caroline', 'Jones', 'martinbryan@blackburn-jones.com')
# 79. ('Angel', 'Villarreal', 'sbrown@collins-shaw.com')
# 80. ('Doris', 'Long', 'jessicamartin@hotmail.com')
# 81. ('Monica', 'Garcia', 'amyconrad@williams.com')
# 82. ('Regina', 'Atkinson', 'sjenkins@gentry.com')
# 83. ('Timothy', 'Barrera', 'anthony20@wilson.info')
# 84. ('Patricia', 'Morris', 'kimberly77@hotmail.com')
# 85. ('Samuel', 'Snyder', 'mark66@vance-edwards.net')
# 86. ('John', 'Dominguez', 'julie50@yahoo.com')
# 87. ('Angela', 'Lang', 'jeffrey51@davila-case.biz')
# 88. ('Gabriel', 'Smith', 'andrew21@hotmail.com')
# 89. ('Tiffany', 'Walker', 'elizabeth61@yahoo.com')
# 90. ('Jessica', 'Owen', 'mitchellkimberly@hotmail.com')
# 91. ('Tanya', 'Wise', 'gerald45@hotmail.com')
# 92. ('Amy', 'Cooke', 'jlevy@gmail.com')
# 93. ('Julie', 'Sexton', 'david22@carr-miller.com')
# 94. ('Christopher', 'Oliver', 'samuel11@hotmail.com')
# 95. ('Kristen', 'Andrews', 'thomas58@freeman-evans.com')
# 96. ('William', 'Carr', 'liuraymond@carter.com')
# 97. ('Abigail', 'Lang', 'jgray@yahoo.com')
# 98. ('Brittney', 'Edwards', 'anthonyhickman@gmail.com')
# 99. ('James', 'Burch', 'garcialisa@gmail.com')
# 100. ('Elizabeth', 'Payne', 'reeddavid@alvarez.com')
# 101. ('Zachary', 'Davidson', 'bethanyhoward@hotmail.com')
# 102. ('Brenda', 'Payne', 'bcontreras@hotmail.com')
# 103. ('Brandon', 'Wright', 'william18@yahoo.com')
# 104. ('Christopher', 'Chaney', 'pamelaallen@yahoo.com')
# 105. ('Jim', 'Jones', 'zgardner@moreno.com')
# 106. ('Maria', 'Woodard', 'jamesbowman@gmail.com')
# 107. ('Stephanie', 'Schmidt', 'brandondouglas@rodgers.com')
# 108. ('Lori', 'Martin', 'astout@yahoo.com')
# 109. ('Stephen', 'Evans', 'katelynsmith@mccullough.org')
# 110. ('Steven', 'Sanders', 'robertschristian@hotmail.com')
# 111. ('Laura', 'Davis', 'rgomez@michael-barnett.com')
# 112. ('Renee', 'Wilkins', 'jodyespinoza@gmail.com')
# 113. ('Monica', 'Torres', 'rmyers@morrow.com')
# 114. ('Dalton', 'Patton', 'qthomas@hotmail.com')
# 115. ('Jose', 'Lowe', 'matthew05@yoder.com')
# 116. ('Ryan', 'Harvey', 'fnewton@wallace-cochran.biz')
# 117. ('Stephanie', 'Gonzalez', 'sharijenkins@coleman.com')
# 118. ('Jeffrey', 'Brown', 'gherman@yahoo.com')
# 119. ('Robert', 'Jacobs', 'tchen@morales.org')
# 120. ('Richard', 'Harrison', 'david40@yahoo.com')
# 121. ('Jackie', 'Martinez', 'thomas52@garcia.info')
# 122. ('Tiffany', 'Fernandez', 'lopezjames@kennedy-boyd.com')
# 123. ('Kayla', 'Mueller', 'efrancis@yahoo.com')
# 124. ('Felicia', 'Williams', 'sandralindsey@rojas.com')
# 125. ('William', 'Burton', 'jameslisa@trevino.com')
# 126. ('Tyler', 'Wright', 'davidevans@hotmail.com')
# 127. ('Jennifer', 'Edwards', 'david13@foley.net')
# 128. ('David', 'Randall', 'harmonmichael@gmail.com')
# 129. ('Kevin', 'Wright', 'nicoledavis@hodges-martin.org')
# 130. ('Kenneth', 'Benson', 'drodriguez@yahoo.com')
# 131. ('Ray', 'Larson', 'roy50@collins.com')
# 132. ('Mikayla', 'Hicks', 'pjohnson@gmail.com')
# 133. ('William', 'Randall', 'wilsonderek@gmail.com')
# 134. ('Kaitlyn', 'Oliver', 'fernandezbrooke@hotmail.com')
# 135. ('Angela', 'Arellano', 'timothy08@yahoo.com')
# 136. ('Beth', 'Bradley', 'kirbyjacqueline@yahoo.com')
# 137. ('John', 'Marshall', 'slutz@yahoo.com')
# 138. ('Joseph', 'Morgan', 'michelle07@hotmail.com')
# 139. ('Julie', 'Brown', 'robinsonhector@preston-mcguire.net')
# 140. ('Dana', 'Tate', 'donald22@hotmail.com')
# 141. ('Elizabeth', 'Williams', 'claytonjustin@gmail.com')
# 142. ('Danielle', 'Cruz', 'lopezmichael@cooper.com')
# 143. ('Angela', 'Preston', 'saundersjulie@hotmail.com')
# 144. ('Tiffany', 'Gomez', 'lisadavis@gmail.com')
# 145. ('Tiffany', 'Rodriguez', 'myoung@yahoo.com')
# 146. ('Michele', 'Carter', 'jeffersoncatherine@gmail.com')
# 147. ('Jonathon', 'Frye', 'billy83@hotmail.com')
# 148. ('Nancy', 'Scott', 'colleenthompson@hotmail.com')
# 149. ('April', 'Bolton', 'dmiller@zamora.com')
# 150. ('Matthew', 'Savage', 'alejandro47@yahoo.com')
# 151. ('Shawn', 'Diaz', 'austinlevine@santos.com')
# 152. ('Amber', 'Jordan', 'larrynovak@yahoo.com')
# 153. ('Molly', 'Jones', 'russell94@johnson-haynes.com')
# 154. ('Abigail', 'Smith', 'sandovalwilliam@mitchell.org')
# 155. ('Rebekah', 'Beck', 'annamathews@davidson-archer.biz')
# 156. ('Lori', 'Nelson', 'robin41@nguyen.com')
# 157. ('Pamela', 'Wilson', 'pedrocox@gmail.com')
# 158. ('Andrew', 'Melendez', 'aimeehaney@lopez-webb.com')
# 159. ('Nancy', 'Stone', 'nwhite@jordan-lopez.info')
# 160. ('Meredith', 'Perry', 'khernandez@hotmail.com')
# 161. ('Erica', 'Rodriguez', 'brian17@wood.info')
# 162. ('Danielle', 'Martinez', 'rangeltina@johns.com')
# 163. ('James', 'Robinson', 'kristin10@stevens-fleming.com')
# 164. ('Mallory', 'Obrien', 'davidsongabrielle@hotmail.com')
# 165. ('Amanda', 'Finley', 'timothychen@yahoo.com')
# 166. ('Kelly', 'Miles', 'ynelson@hotmail.com')
# 167. ('Preston', 'Molina', 'jessica62@yahoo.com')
# 168. ('Melissa', 'Burns', 'robert86@gmail.com')
# 169. ('David', 'Moore', 'greeneshawn@sanders.com')
# 170. ('Michele', 'Beck', 'mary98@hotmail.com')
# 171. ('Wendy', 'Johnson', 'vegaalexandra@taylor.net')
# 172. ('Melissa', 'Morris', 'tamaragross@hotmail.com')
# 173. ('Kenneth', 'Benjamin', 'slane@yahoo.com')
# 174. ('Mark', 'Greene', 'wchavez@brandt.com')
# 175. ('Olivia', 'Lee', 'nicole62@brown.com')
# 176. ('Katie', 'Thompson', 'mcmillanrebecca@gmail.com')
# 177. ('Jennifer', 'Sullivan', 'thomaskristin@mcbride-lane.com')
# 178. ('Douglas', 'Davis', 'emiller@munoz.org')
# 179. ('Patricia', 'Brown', 'bernardhawkins@henry.com')
# 180. ('Mark', 'Hansen', 'caitlin84@yahoo.com')
# 181. ('Andrew', 'Ryan', 'carl07@hotmail.com')
# 182. ('Connie', 'Lopez', 'stephanie53@evans-cruz.com')
# 183. ('Howard', 'Young', 'amanda72@hotmail.com')
# 184. ('Taylor', 'Byrd', 'rfleming@gmail.com')
# 185. ('Joseph', 'Evans', 'nstevens@hotmail.com')
# 186. ('Debra', 'Watson', 'alisonjones@hotmail.com')
# 187. ('Anthony', 'Palmer', 'sydneythomas@harris.biz')
# 188. ('Deborah', 'Gordon', 'mark21@gmail.com')
# 189. ('Peter', 'Diaz', 'steven00@pace.com')
# 190. ('Kimberly', 'Smith', 'philip32@yahoo.com')
# 191. ('Gerald', 'Lambert', 'andrewsrhonda@hotmail.com')
# 192. ('Connor', 'Murphy', 'maureencamacho@yahoo.com')
# 193. ('Gabrielle', 'Cooper', 'hamiltonwanda@yahoo.com')
# 194. ('Rebecca', 'Werner', 'arichardson@hotmail.com')
# 195. ('Mark', 'Boyle', 'morrisjanet@rodriguez.com')
# 196. ('Sandra', 'Lucas', 'samuelhoward@drake.com')
# 197. ('Justin', 'Huff', 'jackjordan@yahoo.com')
# 198. ('Linda', 'Jones', 'toniperez@yahoo.com')
# 199. ('Lynn', 'Castillo', 'stephanie57@salazar-sweeney.com')
# 200. ('Bernard', 'Cook', 'bryan99@hotmail.com')
# 201. ('Andrew', 'Nguyen', 'gregory15@garcia-smith.com')
# 202. ('Nicole', 'Monroe', 'troythompson@lang.info')
# 203. ('Edward', 'Goodman', 'guydudley@bennett-harris.com')
# 204. ('Isaiah', 'Phillips', 'smithjulie@yahoo.com')
# 205. ('Christopher', 'Porter', 'mcintoshwendy@brown.com')
# 206. ('Scott', 'Benton', 'timothy74@velasquez.com')
# 207. ('Adam', 'Pierce', 'sarahpatterson@hernandez.info')
# 208. ('Gary', 'Andrade', 'davismary@hotmail.com')
# 209. ('Julia', 'King', 'xcarter@yahoo.com')
# 210. ('James', 'Hamilton', 'camposnicole@yahoo.com')
# 211. ('Amanda', 'Cain', 'andrewcruz@snyder.com')
# 212. ('Matthew', 'Miranda', 'cgiles@gmail.com')
# 213. ('Courtney', 'Davenport', 'gibsonandrea@thomas.com')
# 214. ('Katie', 'Johnson', 'belindacruz@strickland.biz')
# 215. ('Ryan', 'Sharp', 'justin87@hotmail.com')
# 216. ('Anna', 'Ward', 'sarah91@gmail.com')
# 217. ('Robert', 'Miller', 'bewing@steele.org')
# 218. ('James', 'Brown', 'allentricia@smith.com')
# 219. ('Heidi', 'Kramer', 'debra72@yahoo.com')
# 220. ('Tanner', 'Griffith', 'shawngonzalez@hotmail.com')
# 221. ('Kyle', 'Hart', 'oliviasalazar@gmail.com')
# 222. ('Alice', 'Clay', 'alawson@murphy.com')
# 223. ('Michael', 'Nelson', 'croberson@wagner-dunlap.com')
# 224. ('Amber', 'Morales', 'montgomerymatthew@yahoo.com')
# 225. ('Jennifer', 'Barr', 'russellwade@hotmail.com')
# 226. ('Curtis', 'Gallegos', 'chaddeleon@yahoo.com')
# 227. ('Keith', 'Griffin', 'xtaylor@yahoo.com')
# 228. ('William', 'Bell', 'michael51@hotmail.com')
# 229. ('Daniel', 'Roberts', 'wellsgilbert@yahoo.com')
# 230. ('Alicia', 'Anderson', 'katelynramsey@marquez.biz')
# 231. ('Keith', 'Diaz', 'andrew67@austin-reynolds.biz')
# 232. ('Corey', 'Neal', 'kellycampbell@yahoo.com')
# 233. ('Frank', 'Wells', 'agarcia@reyes.com')
# 234. ('Sharon', 'Johnson', 'sanfordpaul@yahoo.com')
# 235. ('James', 'Quinn', 'uferguson@hess.com')
# 236. ('Michael', 'Sutton', 'nathansalinas@hotmail.com')
# 237. ('Paul', 'Jordan', 'ramosmathew@brown.biz')
# 238. ('Sara', 'Tucker', 'cchavez@hotmail.com')
# 239. ('Aaron', 'Patel', 'brandon20@nunez.com')
# 240. ('Amanda', 'Sullivan', 'jpowell@christian.info')
# 241. ('Logan', 'Marshall', 'kylelarson@rivera.com')
# 242. ('Shane', 'Green', 'sheltonkristopher@gmail.com')
# 243. ('Aimee', 'Carlson', 'smithchristy@hotmail.com')
# 244. ('Tiffany', 'Moore', 'wallacemarcus@nelson.com')
# 245. ('Catherine', 'Martin', 'daviswendy@gallagher.com')
# 246. ('Matthew', 'Greene', 'teresa39@gmail.com')
# 247. ('Linda', 'Hughes', 'whernandez@hotmail.com')
# 248. ('Jennifer', 'Schwartz', 'richardparks@hotmail.com')
# 249. ('Stephanie', 'Nelson', 'ortizbryan@hotmail.com')
# 250. ('Scott', 'Ho', 'ralph59@scott-smith.net')
# 251. ('Stanley', 'Gardner', 'dale33@smith.com')
# 252. ('Kyle', 'White', 'parnold@carpenter.com')
# 253. ('Jay', 'Griffith', 'wford@hotmail.com')
# 254. ('Barry', 'Diaz', 'christopher02@lopez.org')
# 255. ('Ryan', 'Pineda', 'nicholasvargas@hotmail.com')
# 256. ('Brandon', 'Brown', 'leslie20@yahoo.com')
# 257. ('Jeremy', 'Tucker', 'ohines@yahoo.com')
# 258. ('William', 'Tran', 'igolden@yahoo.com')
# 259. ('Barbara', 'Tran', 'greencynthia@gmail.com')
# 260. ('Ashley', 'Johnson', 'ojohnson@gray.biz')
# 261. ('Dwayne', 'Velez', 'evansbrian@king.com')
# 262. ('Craig', 'Stevens', 'kennethhorn@hotmail.com')
# 263. ('John', 'Jackson', 'derrick13@gmail.com')
# 264. ('Sarah', 'Lewis', 'crystalbarnett@crawford.com')
# 265. ('Lisa', 'Patrick', 'skemp@fuentes-johnson.biz')
# 266. ('Selena', 'Graves', 'heathercastillo@maldonado-lyons.net')
# 267. ('Ashley', 'Barnett', 'mballard@gmail.com')
# 268. ('Jason', 'Johnson', 'rosedeborah@herrera.net')
# 269. ('Kayla', 'Bauer', 'victoria45@gmail.com')
# 270. ('Jenny', 'Reed', 'vwong@lewis-hull.com')
# 271. ('Kelly', 'Cardenas', 'xwillis@johnson.com')
# 272. ('Dylan', 'Johnson', 'danielle21@hotmail.com')
# 273. ('Donna', 'Sampson', 'istone@bell.com')
# 274. ('Joanna', 'Hardy', 'lyonslori@yahoo.com')
# 275. ('Monique', 'Baldwin', 'xmelendez@foster.biz')
# 276. ('Lauren', 'Whitney', 'clarkgavin@trevino.com')
# 277. ('Laura', 'Pollard', 'katherinerichardson@yahoo.com')
# 278. ('Kelly', 'Strong', 'hernandezbrooke@black-price.com')
# 279. ('Rebecca', 'Tate', 'melendezchristopher@hotmail.com')
# 280. ('Courtney', 'Myers', 'martinezrachael@yahoo.com')
# 281. ('Morgan', 'Poole', 'jamesadams@clark.com')
# 282. ('Nicole', 'Scott', 'johnsonmelissa@hotmail.com')
# 283. ('Gabriel', 'Herrera', 'howardrobert@yahoo.com')
# 284. ('Jonathan', 'Espinoza', 'kimberlyrivera@patterson.com')
# 285. ('Benjamin', 'Long', 'hendersonkathy@hotmail.com')
# 286. ('Christina', 'Bailey', 'zwilliams@brown.com')
# 287. ('Carrie', 'Gonzalez', 'vreed@coleman.biz')
# 288. ('Theresa', 'Molina', 'brittany14@hotmail.com')
# 289. ('Denise', 'Vargas', 'shelby03@farley.info')
# 290. ('Austin', 'Ramirez', 'megan25@powell.com')
# 291. ('Connor', 'Rocha', 'maylaura@caldwell.biz')
# 292. ('Jillian', 'Pratt', 'jordanmiranda@yahoo.com')
# 293. ('Cindy', 'Russell', 'colleen11@hotmail.com')
# 294. ('Edward', 'Ball', 'mcclainstephen@yahoo.com')
# 295. ('John', 'Morrison', 'weeksdonna@spencer-crawford.net')
# 296. ('Anthony', 'Ponce', 'garciamonica@lopez-burnett.biz')
# 297. ('Tim', 'Gamble', 'john43@hotmail.com')
# 298. ('Ashley', 'Hughes', 'jason19@gmail.com')
# 299. ('Dave', 'Hall', 'brandonjones@hotmail.com')
# 300. ('Larry', 'Jones', 'thorntonmaureen@lewis-hernandez.org')
# 301. ('Elizabeth', 'Evans', 'raymond28@chavez-terrell.com')
# 302. ('Erik', 'Kim', 'jeffbeard@myers.info')
# 303. ('Brianna', 'Hamilton', 'leejames@hotmail.com')
# 304. ('Christopher', 'Weber', 'andrew87@yahoo.com')
# 305. ('Andrea', 'Dawson', 'livingstoncarly@hotmail.com')
# 306. ('Michele', 'Garcia', 'nmay@moody.com')
# 307. ('Jennifer', 'Simon', 'hortonjessica@gmail.com')
# 308. ('Shari', 'Wilson', 'montoyaana@smith.info')
# 309. ('Sandra', 'Ramos', 'rhondajones@gardner-kelly.com')
# 310. ('Kaitlin', 'Johnson', 'sarah87@hotmail.com')
# 311. ('David', 'Petersen', 'moniquepetersen@durham.com')
# 312. ('Aaron', 'Harris', 'justin10@hotmail.com')
# 313. ('Kevin', 'Dixon', 'bmiller@gmail.com')
# 314. ('Suzanne', 'Cox', 'jessica08@gmail.com')
# 315. ('Cheryl', 'Rios', 'varroyo@hotmail.com')
# 316. ('Richard', 'Davis', 'krausewilliam@martinez.biz')
# 317. ('John', 'Robles', 'fmcdaniel@yahoo.com')
# 318. ('Brandon', 'Roth', 'xfischer@gmail.com')
# 319. ('Jeffrey', 'Soto', 'robinwatts@porter.net')
# 320. ('Charles', 'Bishop', 'joshualewis@gmail.com')
# 321. ('Barry', 'Cox', 'donald51@yahoo.com')
# 322. ('Dorothy', 'Jimenez', 'omarclark@hotmail.com')
# 323. ('Monica', 'Hill', 'kevin39@yahoo.com')
# 324. ('Scott', 'Harris', 'kbrown@hotmail.com')
# 325. ('Ronald', 'Carter', 'walkerjulie@hotmail.com')
# 326. ('Benjamin', 'Holden', 'monicasmith@johnson.com')
# 327. ('Deborah', 'Martinez', 'jasonorozco@gmail.com')
# 328. ('Tina', 'Huerta', 'scottjohnson@yahoo.com')
# 329. ('Ann', 'Gardner', 'michelle69@lewis.com')
# 330. ('Maureen', 'Carroll', 'evargas@dalton.info')
# 331. ('Madison', 'Russell', 'tyler55@yahoo.com')
# 332. ('Mark', 'Watson', 'samuelgardner@gmail.com')
# 333. ('Lisa', 'Duffy', 'hterry@robinson.com')
# 334. ('Kevin', 'Owens', 'jason31@bryan-martin.biz')
# 335. ('Melissa', 'Hill', 'wspencer@rivas.com')
# 336. ('Linda', 'Bentley', 'ybaker@hernandez.info')
# 337. ('Cheryl', 'Barrett', 'msimpson@clark.com')
# 338. ('Shelly', 'Riley', 'brent68@gmail.com')
# 339. ('Sarah', 'Evans', 'gmills@gmail.com')
# 340. ('Christy', 'Washington', 'alex83@hotmail.com')
# 341. ('Adam', 'Lopez', 'shortkathleen@booker.com')
# 342. ('Daniel', 'Harmon', 'macdonalddanielle@gmail.com')
# 343. ('Gerald', 'Andrews', 'gonzalezmatthew@gmail.com')
# 344. ('Carla', 'Williamson', 'jennifer77@gmail.com')
# 345. ('Jerry', 'Clark', 'matthew49@avila.org')
# 346. ('Sharon', 'Diaz', 'ugomez@yahoo.com')
# 347. ('Crystal', 'Hall', 'bruce17@hotmail.com')
# 348. ('Jessica', 'Thomas', 'cbailey@gmail.com')
# 349. ('Steven', 'Swanson', 'dawnsmall@yahoo.com')
# 350. ('Richard', 'Sheppard', 'awilliams@yahoo.com')
# 351. ('Michael', 'Jones', 'dphillips@hotmail.com')
# 352. ('Brian', 'Mcclure', 'dthomas@wood.info')
# 353. ('Victor', 'Phelps', 'ricky93@gmail.com')
# 354. ('Cynthia', 'Cameron', 'osteele@taylor-greene.com')
# 355. ('James', 'Wagner', 'dwilliamson@clark.biz')
# 356. ('Scott', 'Patterson', 'lopezryan@hotmail.com')
# 357. ('Joseph', 'Singh', 'michael35@wilson.com')
# 358. ('Crystal', 'Williams', 'mariamiller@yahoo.com')
# 359. ('Justin', 'Price', 'hrusso@davis.com')
# 360. ('Jacob', 'Romero', 'rosswilliam@hotmail.com')
# 361. ('Holly', 'Carroll', 'fbutler@torres.net')
# 362. ('Thomas', 'Yang', 'robinsonmargaret@meyer.net')
# 363. ('Katherine', 'Norman', 'franklin63@yahoo.com')
# 364. ('Scott', 'Mcdonald', 'millernancy@gmail.com')
# 365. ('Nicholas', 'Gray', 'jasonryan@yahoo.com')
# 366. ('Peter', 'Wade', 'lopezjoseph@yahoo.com')
# 367. ('Victoria', 'Bradley', 'lcortez@turner.org')
# 368. ('Nicholas', 'Hinton', 'christian37@ward.org')
# 369. ('Stephanie', 'Bennett', 'tylerross@odom.com')
# 370. ('Jeremy', 'Saunders', 'randy11@reese.com')
# 371. ('Mike', 'Lynch', 'jamesgreen@yahoo.com')
# 372. ('Kenneth', 'Livingston', 'robert38@carter-young.com')
# 373. ('Karen', 'Thomas', 'melissabishop@davis.com')
# 374. ('Joseph', 'Walker', 'bradymichael@vaughan.com')
# 375. ('Jeffrey', 'Hall', 'whill@hotmail.com')
# 376. ('Victoria', 'Wright', 'vincenttaylor@gmail.com')
# 377. ('Mark', 'York', 'emily54@gmail.com')
# 378. ('Katherine', 'Price', 'coleerica@hotmail.com')
# 379. ('Martin', 'Smith', 'blackburnrichard@reynolds.org')
# 380. ('Timothy', 'Campbell', 'msanders@gmail.com')
# 381. ('Patricia', 'Prince', 'romananna@nguyen-armstrong.com')
# 382. ('Tyler', 'Clark', 'brownsara@gmail.com')
# 383. ('Joseph', 'Perez', 'jeremysmith@yahoo.com')
# 384. ('James', 'Friedman', 'grios@eaton.com')
# 385. ('Krista', 'Nichols', 'lisa63@hotmail.com')
# 386. ('Mark', 'Bradley', 'brownrobin@hotmail.com')
# 387. ('Julie', 'Graves', 'jeffrey93@keller.org')
# 388. ('Jesse', 'Wallace', 'joseph47@yahoo.com')
# 389. ('Austin', 'Shelton', 'ctate@hotmail.com')
# 390. ('Stacey', 'Anderson', 'patricia72@yahoo.com')
# 391. ('Dawn', 'Young', 'hallsherri@gmail.com')
# 392. ('Latoya', 'Barrera', 'garciahelen@yahoo.com')
# 393. ('Sean', 'Bennett', 'imcclure@gmail.com')
# 394. ('Rodney', 'Lynn', 'christopher14@yahoo.com')
# 395. ('Christian', 'Moore', 'brenda18@hotmail.com')
# 396. ('John', 'Andrews', 'suzanneshields@willis.biz')
# 397. ('Dominique', 'Sullivan', 'ebryant@reed-wallace.com')
# 398. ('Matthew', 'Smith', 'dawnstewart@robinson.com')
# 399. ('Karen', 'Sanders', 'pbaldwin@gmail.com')
# 400. ('Christopher', 'Schaefer', 'lmiller@yahoo.com')
# 401. ('Lynn', 'Holmes', 'yarnold@yahoo.com')
# 402. ('Dan', 'Wilson', 'beverlyfields@rosales.com')
# 403. ('Daniel', 'Welch', 'kimberlyroberson@kline.com')
# 404. ('Rhonda', 'Adams', 'davidmontoya@hoffman.com')
# 405. ('John', 'Young', 'ashleywood@hotmail.com')
# 406. ('Sarah', 'Frost', 'oosborne@jordan.com')
# 407. ('Christopher', 'Rios', 'msmith@smith.com')
# 408. ('Beverly', 'Walker', 'brittanyli@clark-martin.biz')
# 409. ('Mary', 'Oconnell', 'ashlee44@yahoo.com')
# 410. ('Regina', 'Bell', 'david45@gutierrez.biz')
# 411. ('John', 'Torres', 'hector44@manning.com')
# 412. ('Kristen', 'Gaines', 'orice@hotmail.com')
# 413. ('Brett', 'Lyons', 'jacqueline24@yahoo.com')
# 414. ('Steven', 'Weiss', 'allennicole@wright-brown.com')
# 415. ('Kristie', 'Cross', 'zachary29@lambert-martinez.com')
# 416. ('Nicholas', 'Allen', 'tammy92@hotmail.com')
# 417. ('John', 'Hernandez', 'hayleymarks@yahoo.com')
# 418. ('Laura', 'Larsen', 'michaelgreen@hotmail.com')
# 419. ('Adam', 'Gonzalez', 'barbara75@adams.info')
# 420. ('Jordan', 'Russo', 'chavezdavid@stevens-cook.com')
# 421. ('Robert', 'Case', 'christinahancock@hudson-smith.net')
# 422. ('Andrea', 'Mclean', 'uguzman@kidd-morgan.net')
# 423. ('Jacob', 'Arnold', 'sanderson@johnson.info')
# 424. ('Mary', 'Compton', 'ngregory@hotmail.com')
# 425. ('Karen', 'Hanson', 'eayers@gmail.com')
# 426. ('Melissa', 'Hernandez', 'dhanna@lucas.biz')
# 427. ('Jose', 'Evans', 'michealhoward@yahoo.com')
# 428. ('Alan', 'Lawson', 'lisaflores@hotmail.com')
# 429. ('Bonnie', 'Bright', 'laurie25@garcia.biz')
# 430. ('Brad', 'Barton', 'matthew76@wade.com')
# 431. ('Janice', 'Peters', 'pglenn@gmail.com')
# 432. ('Kristopher', 'Miller', 'williamsmelinda@reynolds.com')
# 433. ('Catherine', 'Haas', 'usmith@juarez.com')
# 434. ('Mary', 'Ellis', 'kbell@moore-archer.com')
# 435. ('Melissa', 'Barnett', 'bvang@johnson.com')
# 436. ('Megan', 'Smith', 'xsanders@yahoo.com')
# 437. ('Jennifer', 'Cruz', 'danielwalton@hotmail.com')
# 438. ('Alexander', 'Robinson', 'tyler03@lewis.net')
# 439. ('Haley', 'Phillips', 'hernandezvictor@harvey.net')
# 440. ('Kristina', 'Howell', 'jonathan82@yahoo.com')
# 441. ('Julie', 'Morales', 'reyesyvonne@hotmail.com')
# 442. ('Amanda', 'Bennett', 'ahughes@maldonado.info')
# 443. ('Donald', 'Mejia', 'christopher46@chavez-cooper.com')
# 444. ('Margaret', 'Perez', 'phillip15@yahoo.com')
# 445. ('Jason', 'Taylor', 'carlbishop@simpson.com')
# 446. ('Alyssa', 'Simmons', 'dharris@gmail.com')
# 447. ('Valerie', 'Garcia', 'mathew39@elliott.info')
# 448. ('Dana', 'Kelly', 'lindsey03@clark-cohen.org')
# 449. ('Michael', 'Dixon', 'martinezjennifer@smith.com')
# 450. ('Clinton', 'Saunders', 'gregoryjohnson@mcdaniel.com')
# 451. ('Kayla', 'Simmons', 'jennifer71@hotmail.com')
# 452. ('Jo', 'Davis', 'awilliams@martinez-lee.info')
# 453. ('Jack', 'Bailey', 'carrkeith@hotmail.com')
# 454. ('Rachel', 'Harris', 'sarahwilliams@calderon-patel.com')
# 455. ('Deanna', 'Stewart', 'lmiller@bryant.com')
# 456. ('Robert', 'Soto', 'edward63@lopez.biz')
# 457. ('Anthony', 'Olson', 'kbauer@sharp.org')
# 458. ('Justin', 'Barry', 'susanruiz@hotmail.com')
# 459. ('Robert', 'David', 'barbara34@hotmail.com')
# 460. ('Christopher', 'Neal', 'patricia81@gmail.com')
# 461. ('Mitchell', 'Wagner', 'clarkchristina@hotmail.com')
# 462. ('Carolyn', 'Mccullough', 'johnsonkara@gmail.com')
# 463. ('Brittany', 'Velez', 'katherine01@hotmail.com')
# 464. ('Rhonda', 'Ortiz', 'madisonortiz@kirby.biz')
# 465. ('Shane', 'Arnold', 'ymorton@gmail.com')
# 466. ('Crystal', 'Jackson', 'larryhampton@yahoo.com')
# 467. ('James', 'Bush', 'oterry@brown.com')
# 468. ('Kelly', 'Smith', 'lewisjennifer@sparks-cox.info')
# 469. ('Susan', 'Moore', 'amy74@hotmail.com')
# 470. ('Steven', 'Robinson', 'deborah90@reed-smith.net')
# 471. ('Mackenzie', 'Owens', 'hhenry@gmail.com')
# 472. ('Amy', 'Walker', 'richard61@yahoo.com')
# 473. ('Kelsey', 'Schneider', 'cwood@freeman.info')
# 474. ('David', 'Vargas', 'alexis73@hotmail.com')
# 475. ('Lauren', 'Rose', 'littlecameron@kelly.com')
# 476. ('Jasmine', 'Stuart', 'ballrenee@jones.com')
# 477. ('Travis', 'Harris', 'rodneyshannon@pierce.biz')
# 478. ('Ashley', 'Mack', 'smithtimothy@gmail.com')
# 479. ('Mary', 'Price', 'toddjoseph@montes-robinson.org')
# 480. ('Melissa', 'Holloway', 'gregorytracy@lopez.biz')
# 481. ('David', 'Garcia', 'xhall@barton.com')
# 482. ('Gloria', 'Stafford', 'amandaobrien@hotmail.com')
# 483. ('Roberto', 'Young', 'erika59@boone.biz')
# 484. ('Curtis', 'Gonzalez', 'ygallagher@yahoo.com')
# 485. ('Sabrina', 'Vang', 'joe78@williams-sanders.net')
# 486. ('Erica', 'Macdonald', 'donaldbrown@booker.net')
# 487. ('Robert', 'Mendoza', 'bkey@yahoo.com')
# 488. ('Sharon', 'Martinez', 'maxwellwilliam@gmail.com')
# 489. ('Leslie', 'Miller', 'gbell@riley.biz')
# 490. ('Oscar', 'Brown', 'crystal00@haas.com')
# 491. ('Matthew', 'Rowe', 'angelasmith@adams.com')
# 492. ('Shawn', 'Huff', 'christopher96@johnson.com')
# 493. ('Brandon', 'Sanchez', 'leslie03@marquez.info')
# 494. ('Stacey', 'Page', 'rjones@gmail.com')
# 495. ('Tammy', 'Phillips', 'charlessharon@yahoo.com')
# 496. ('Gabriela', 'Cummings', 'sanderschristine@harrison.com')
# 497. ('Terry', 'Sexton', 'katherineburns@oliver.biz')
# 498. ('Danny', 'Green', 'james59@gordon.com')
# 499. ('Keith', 'Nichols', 'christy07@hughes.com')
# 500. ('Tommy', 'Hughes', 'fshaffer@gmail.com')
# 501. ('Jonathan', 'Smith', 'kelseydyer@rodriguez-rodriguez.com')
# 502. ('Anthony', 'Green', 'matthewvelasquez@smith.info')
# 503. ('Paul', 'Collins', 'hstout@hotmail.com')
# 504. ('Natasha', 'Wolf', 'ireid@gmail.com')
# 505. ('Jacqueline', 'Clark', 'jeremymarks@gmail.com')
# 506. ('Edward', 'Mack', 'lauraavery@walker.com')
# 507. ('Heidi', 'Alexander', 'cherylleonard@riggs.com')
# 508. ('Shirley', 'Bell', 'bradley78@coleman.net')
# 509. ('Kelsey', 'Griffith', 'jenkinsmelissa@gmail.com')
# 510. ('Michael', 'Martin', 'tammybullock@king-brown.com')
# 511. ('Richard', 'Garner', 'joshua37@yahoo.com')
# 512. ('Matthew', 'Ramos', 'gallagherrandy@hotmail.com')
# 513. ('Matthew', 'Werner', 'scottdustin@hotmail.com')
# 514. ('Timothy', 'Campbell', 'jordanandrea@rodriguez.net')
# 515. ('Morgan', 'Stewart', 'andrewschmidt@burton.com')
# 516. ('Vernon', 'Simpson', 'tallen@thompson.com')
# 517. ('Marilyn', 'Rodriguez', 'michelle94@morales-robinson.com')
# 518. ('Joseph', 'Stephens', 'jessica31@yahoo.com')
# 519. ('Megan', 'Davis', 'whitesara@johnson.info')
# 520. ('Justin', 'Copeland', 'jillmorales@carlson.com')
# 521. ('David', 'Holmes', 'michaeljohnson@medina.net')
# 522. ('Gabrielle', 'Combs', 'elizabethbrooks@ramos.org')
# 523. ('Michelle', 'Stevens', 'butlerjade@gmail.com')
# 524. ('Ryan', 'Hatfield', 'alvarezstacy@stevenson.org')
# 525. ('Craig', 'Martin', 'tramirez@hotmail.com')
# 526. ('Jasmine', 'Garza', 'juliadiaz@smith.biz')
# 527. ('Alexandra', 'Gibbs', 'chawkins@kaiser.com')
# 528. ('Emily', 'Brown', 'zschwartz@gmail.com')
# 529. ('Jenna', 'Hernandez', 'hendrickslori@hotmail.com')
# 530. ('Brandon', 'Butler', 'reynoldsdeanna@maxwell.com')
# 531. ('Blake', 'Pace', 'laurenjohnson@mata-brown.com')
# 532. ('Justin', 'Herrera', 'alexandermartin@gmail.com')
# 533. ('Sandra', 'Sims', 'erinchapman@peterson.com')
# 534. ('David', 'Owens', 'scottbrandon@hotmail.com')
# 535. ('Richard', 'Mullen', 'joannawalter@gmail.com')
# 536. ('Susan', 'Fowler', 'barkerlinda@dominguez.com')
# 537. ('Sherri', 'Russo', 'reesesteven@yahoo.com')
# 538. ('Anthony', 'Mcdonald', 'hdoyle@gmail.com')
# 539. ('Mark', 'Mitchell', 'brookepugh@hotmail.com')
# 540. ('Charles', 'Martin', 'tschultz@hotmail.com')
# 541. ('Francis', 'Mercado', 'hendersonkimberly@hotmail.com')
# 542. ('Phillip', 'Brown', 'ulindsey@young.com')
# 543. ('Terri', 'Savage', 'donaldgonzalez@ellis-johnson.com')
# 544. ('Michael', 'Rowland', 'wkirby@henderson.com')
# 545. ('Kevin', 'Smith', 'elizabethday@branch.com')
# 546. ('Matthew', 'Robertson', 'stevenho@yahoo.com')
# 547. ('Danielle', 'Thomas', 'coxbrett@golden.com')
# 548. ('Elizabeth', 'Villarreal', 'mendozacharles@gmail.com')
# 549. ('Phillip', 'Rios', 'dclarke@gmail.com')
# 550. ('Maria', 'Wilson', 'sbush@yahoo.com')
# 551. ('Patricia', 'Savage', 'jamesgarcia@richardson-pierce.com')
# 552. ('Devin', 'Mitchell', 'jennyjohnston@hanna.biz')
# 553. ('Samantha', 'Garcia', 'jamessmith@jenkins-smith.com')
# 554. ('Derrick', 'Taylor', 'lewismegan@richards-gutierrez.net')
# 555. ('Lauren', 'Allen', 'hlindsey@morales.com')
# 556. ('Carlos', 'Lawson', 'khenderson@green.info')
# 557. ('Zachary', 'Davis', 'patrick18@gmail.com')
# 558. ('Michael', 'Gonzales', 'melaniejohnson@rivera.com')
# 559. ('Mary', 'Mccoy', 'anna94@yahoo.com')
# 560. ('Matthew', 'Smith', 'stephaniepearson@parker-beck.com')
# 561. ('Steven', 'Wilson', 'hmorris@yahoo.com')
# 562. ('Thomas', 'Barrett', 'sydneyshort@yahoo.com')
# 563. ('William', 'James', 'ufields@aguirre-holmes.com')
# 564. ('Denise', 'Hahn', 'srodriguez@reyes.com')
# 565. ('Steven', 'Hicks', 'jennifer30@gmail.com')
# 566. ('Austin', 'Osborn', 'johnleblanc@gmail.com')
# 567. ('Heather', 'Davila', 'kellygary@yahoo.com')
# 568. ('Sarah', 'Adams', 'donald85@yahoo.com')
# 569. ('Leslie', 'Rush', 'joshua06@hotmail.com')
# 570. ('Kevin', 'Cantrell', 'cmoore@hotmail.com')
# 571. ('Adrian', 'Gamble', 'kimberlyjames@gmail.com')
# 572. ('Richard', 'Saunders', 'simsmary@carlson.com')
# 573. ('Ashley', 'Wade', 'garyhanson@cooper-franklin.com')
# 574. ('Nathaniel', 'Gutierrez', 'nicole73@yahoo.com')
# 575. ('Andrea', 'Nixon', 'louisdaniels@copeland-porter.com')
# 576. ('Margaret', 'Franco', 'kyle85@howell-barr.biz')
# 577. ('Randy', 'Howard', 'palmerjennifer@mendez-allen.org')
# 578. ('Brandon', 'Hernandez', 'patelmichelle@cooper-reyes.com')
# 579. ('Deborah', 'Perry', 'hortonshelia@yahoo.com')
# 580. ('Jennifer', 'Livingston', 'opowell@hotmail.com')
# 581. ('Tracy', 'Spencer', 'matthew92@gmail.com')
# 582. ('Monica', 'Lopez', 'lopezkayla@gmail.com')
# 583. ('Julie', 'Martinez', 'yvettemartinez@howell.com')
# 584. ('Christopher', 'Griffith', 'ysalinas@hotmail.com')
# 585. ('Shannon', 'Mcconnell', 'katrinasullivan@soto-davis.biz')
# 586. ('Mary', 'Hogan', 'deandavid@gmail.com')
# 587. ('Joseph', 'Johnson', 'graymary@yahoo.com')
# 588. ('Annette', 'Miller', 'butlerphilip@gmail.com')
# 589. ('Theodore', 'Norman', 'john07@smith.biz')
# 590. ('Kimberly', 'Morris', 'katie20@hotmail.com')
# 591. ('Christopher', 'Bradley', 'vthomas@king-shah.com')
# 592. ('Mariah', 'Davis', 'thickman@hotmail.com')
# 593. ('Tanner', 'Gross', 'wisekenneth@raymond.info')
# 594. ('Jared', 'Kramer', 'douglas33@fitzpatrick-clark.com')
# 595. ('Samuel', 'Strickland', 'qcastillo@gmail.com')
# 596. ('Stephanie', 'Rice', 'martinezjames@parker.com')
# 597. ('Eric', 'Scott', 'jenny44@hotmail.com')
# 598. ('Carlos', 'Frank', 'jeffreyrodriguez@hotmail.com')
# 599. ('Lauren', 'Smith', 'rlewis@barrett.com')
# 600. ('Kristina', 'Carlson', 'tmartin@kirk.com')
# 601. ('Michael', 'Andrews', 'coreytaylor@gmail.com')
# 602. ('Amy', 'Johnson', 'awilliams@hotmail.com')
# 603. ('Christopher', 'Jones', 'stacey14@gmail.com')
# 604. ('Shannon', 'Boyle', 'meghannoble@gmail.com')
# 605. ('David', 'Bradley', 'heather76@lester.info')
# 606. ('Amanda', 'Fitzpatrick', 'danielsjustin@yahoo.com')
# 607. ('Alexis', 'Hawkins', 'anthony74@melendez.com')
# 608. ('Isaac', 'Price', 'tanderson@rush-davis.com')
# 609. ('Robin', 'Carpenter', 'tamara19@yahoo.com')
# 610. ('Michael', 'Brewer', 'estradatracy@pugh.org')
# 611. ('Justin', 'Johns', 'christinawalker@boyd.info')
# 612. ('Angel', 'Anderson', 'jamielewis@hotmail.com')
# 613. ('Heather', 'Perez', 'ericlara@hill-wells.net')
# 614. ('Michael', 'Phelps', 'zthompson@gmail.com')
# 615. ('James', 'Bailey', 'eramirez@yahoo.com')
# 616. ('Dominique', 'Trujillo', 'patrickhall@perez.com')
# 617. ('Jeffrey', 'Lee', 'donna52@ortiz-davis.com')
# 618. ('Daniel', 'Donovan', 'marcusguerrero@gmail.com')
# 619. ('Christopher', 'Horton', 'donnabarnes@lynn-schmidt.com')
# 620. ('Erin', 'Murray', 'lpotter@gmail.com')
# 621. ('Sandra', 'Mccarthy', 'amandaochoa@yahoo.com')
# 622. ('Daisy', 'Moore', 'raymondmichelle@gmail.com')
# 623. ('George', 'Brewer', 'wbright@hotmail.com')
# 624. ('Erin', 'James', 'chloe40@fry.com')
# 625. ('Brittany', 'Dalton', 'qtorres@yahoo.com')
# 626. ('Hannah', 'Harrison', 'madisongarcia@carpenter-reed.com')
# 627. ('Joshua', 'Montoya', 'carmenwhite@gomez.com')
# 628. ('Robin', 'Fleming', 'kconley@hotmail.com')
# 629. ('Raymond', 'Bennett', 'nashanna@yahoo.com')
# 630. ('Kelly', 'Buckley', 'fergusonkatherine@riley.org')
# 631. ('Courtney', 'Meza', 'sarah08@gmail.com')
# 632. ('Adam', 'Smith', 'james97@hudson.biz')
# 633. ('Richard', 'Phillips', 'williamscott@yahoo.com')
# 634. ('Michele', 'Ali', 'jgriffith@gmail.com')
# 635. ('Ann', 'Neal', 'jenkinstaylor@jenkins-key.com')
# 636. ('Brittany', 'Huff', 'ejohnson@yahoo.com')
# 637. ('Erin', 'Charles', 'david27@yahoo.com')
# 638. ('Nicholas', 'Carroll', 'masondonaldson@young-perez.org')
# 639. ('Jonathan', 'Miller', 'oanderson@yahoo.com')
# 640. ('George', 'Miller', 'robinsonandrea@espinoza.info')
# 641. ('Holly', 'Lee', 'doylelisa@yahoo.com')
# 642. ('Ryan', 'Wilkins', 'hudsonmatthew@powell.info')
# 643. ('Mary', 'Eaton', 'nathanhart@gmail.com')
# 644. ('Victoria', 'Savage', 'ambersingh@bright-freeman.com')
# 645. ('Troy', 'Lee', 'jeffery97@gmail.com')
# 646. ('Theresa', 'Matthews', 'stevenscott@lewis.com')
# 647. ('Anthony', 'Wright', 'elizabeth20@smith.com')
# 648. ('Judith', 'Kim', 'stacey67@gmail.com')
# 649. ('Jeffrey', 'Gonzalez', 'kjennings@yahoo.com')
# 650. ('Adam', 'Lambert', 'smitheugene@yahoo.com')
# 651. ('Paula', 'Beck', 'dan82@mejia-lopez.com')
# 652. ('Robert', 'Collins', 'vincentcindy@marks-arnold.info')
# 653. ('Kimberly', 'Clark', 'miguelbryant@gmail.com')
# 654. ('Jennifer', 'Hamilton', 'sjones@rose.com')
# 655. ('Bruce', 'Casey', 'harrisamanda@yahoo.com')
# 656. ('Timothy', 'Waters', 'russelljacqueline@hotmail.com')
# 657. ('Kelly', 'Warren', 'kathleenmarshall@porter.com')
# 658. ('David', 'Hughes', 'jasonadams@hotmail.com')
# 659. ('Tim', 'Robinson', 'xelliott@morris.info')
# 660. ('Maria', 'Smith', 'francispaul@simmons.com')
# 661. ('Michael', 'Hardin', 'rebecca90@dominguez.com')
# 662. ('Mathew', 'Hart', 'holmescynthia@gmail.com')
# 663. ('Amy', 'Evans', 'melissa74@yahoo.com')
# 664. ('Kenneth', 'Holder', 'lanechristopher@yahoo.com')
# 665. ('Hunter', 'Moore', 'micheallong@smith.info')
# 666. ('Brian', 'Gutierrez', 'paul37@yahoo.com')
# 667. ('Michael', 'Edwards', 'lisa17@richards-watts.com')
# 668. ('Gregory', 'Gibson', 'johnjones@fuller-mckinney.com')
# 669. ('Melinda', 'Shea', 'jason27@hotmail.com')
# 670. ('Elizabeth', 'Kirk', 'apitts@gmail.com')
# 671. ('Christopher', 'Knapp', 'samanthasoto@gmail.com')
# 672. ('Elizabeth', 'Hansen', 'lmiller@phelps.info')
# 673. ('Erin', 'Waters', 'vsharp@hotmail.com')
# 674. ('Daniel', 'Richardson', 'lsmith@mendoza.com')
# 675. ('Mary', 'Davis', 'trevororozco@rojas.com')
# 676. ('Cynthia', 'Mcfarland', 'oliveramanda@hotmail.com')
# 677. ('Jennifer', 'Wilson', 'henrykevin@yahoo.com')
# 678. ('Christian', 'Meyer', 'kristopher20@brown.com')
# 679. ('Kevin', 'Wright', 'smithcheryl@hotmail.com')
# 680. ('Ashley', 'Hampton', 'petersonpaula@gmail.com')
# 681. ('Richard', 'Hernandez', 'benjamin22@gmail.com')
# 682. ('Elizabeth', 'Rodriguez', 'howeclaire@yahoo.com')
# 683. ('Lynn', 'Tucker', 'ibarracourtney@smith.com')
# 684. ('Alicia', 'Hudson', 'rebecca05@pratt.org')
# 685. ('David', 'Holt', 'sergioduarte@rodriguez.info')
# 686. ('Bianca', 'Webster', 'anthonymeyer@yahoo.com')
# 687. ('Hannah', 'Vasquez', 'hannahperez@clark-morris.com')
# 688. ('Jennifer', 'Phillips', 'margaret50@mason.com')
# 689. ('Joseph', 'Norton', 'znicholson@gray-holland.org')
# 690. ('Donna', 'Jackson', 'deanna60@harper.net')
# 691. ('Edwin', 'Smith', 'stephanie54@pope.org')
# 692. ('Brian', 'Johnson', 'kayla03@yahoo.com')
# 693. ('Brandon', 'Clark', 'carrollbilly@hotmail.com')
# 694. ('Seth', 'Stevens', 'kathleengomez@hotmail.com')
# 695. ('Calvin', 'Stewart', 'david15@valenzuela.com')
# 696. ('Jennifer', 'Gregory', 'ucasey@reed.net')
# 697. ('Andrea', 'Beltran', 'deleoncarol@gmail.com')
# 698. ('Michael', 'Miller', 'amanda24@brady.com')
# 699. ('Megan', 'Williams', 'ewingcarla@price.biz')
# 700. ('Brian', 'Henry', 'dianefoley@sanchez.com')
# 701. ('Dominique', 'Jones', 'aprilsmith@daniels.net')
# 702. ('Michelle', 'Gaines', 'robinsonelizabeth@heath.com')
# 703. ('Kendra', 'Hayden', 'moodyvictoria@gmail.com')
# 704. ('Allison', 'Hodge', 'carrsherry@anderson.net')
# 705. ('David', 'Gray', 'jamesfarmer@mendoza.com')
# 706. ('Jesse', 'Villarreal', 'christiankatherine@franklin.com')
# 707. ('Gregory', 'Hanson', 'stephaniewood@yahoo.com')
# 708. ('Andrea', 'Casey', 'timothyfoster@hotmail.com')
# 709. ('Susan', 'Fisher', 'amanda17@gmail.com')
# 710. ('Mason', 'Zavala', 'davidlindsey@gmail.com')
# 711. ('George', 'Henderson', 'teresaorozco@taylor.com')
# 712. ('Lynn', 'Murray', 'markwhite@gmail.com')
# 713. ('Kayla', 'Green', 'anitanguyen@odonnell.com')
# 714. ('Calvin', 'Knight', 'brittanyking@gmail.com')
# 715. ('Michael', 'Stark', 'john82@yahoo.com')
# 716. ('Barbara', 'Williams', 'ojohnson@jackson.info')
# 717. ('Jason', 'Grant', 'marshnathan@gmail.com')
# 718. ('Maria', 'Gutierrez', 'alexandracurtis@park-moore.com')
# 719. ('Angela', 'Vincent', 'ngarcia@gmail.com')
# 720. ('Eric', 'Ortiz', 'benjamin99@yahoo.com')
# 721. ('Diane', 'Moon', 'nhooper@gmail.com')
# 722. ('Charlene', 'Hayden', 'justinmiller@elliott.com')
# 723. ('Brian', 'White', 'paynevincent@gmail.com')
# 724. ('Michael', 'Jones', 'uconley@hines.biz')
# 725. ('Jason', 'White', 'bjoseph@watkins.com')
# 726. ('Bobby', 'Morgan', 'williamssamantha@hotmail.com')
# 727. ('Brian', 'Solis', 'stevenfry@hotmail.com')
# 728. ('Joseph', 'Gonzalez', 'vwilliams@dean.com')
# 729. ('Hayden', 'Romero', 'trankimberly@hotmail.com')
# 730. ('Jasmine', 'Wilson', 'vlawrence@garrett.com')
# 731. ('Anthony', 'Reese', 'vhuang@hotmail.com')
# 732. ('John', 'Johnson', 'lauren93@gmail.com')
# 733. ('Maria', 'Lee', 'jasonrobertson@rios-torres.com')
# 734. ('Katherine', 'Zhang', 'dominguezrobert@smith-calhoun.com')
# 735. ('Bryan', 'Hale', 'duartemichelle@christensen.net')
# 736. ('Megan', 'Gordon', 'dalvarez@gmail.com')
# 737. ('Danielle', 'Carr', 'mkaiser@yahoo.com')
# 738. ('Christina', 'Hill', 'browntiffany@hotmail.com')
# 739. ('Melissa', 'Kennedy', 'michaelgallegos@yahoo.com')
# 740. ('Angel', 'Gillespie', 'qowens@doyle-erickson.com')
# 741. ('Jessica', 'Tucker', 'bryantsharon@haynes-hanson.com')
# 742. ('Steven', 'Graham', 'denise06@yahoo.com')
# 743. ('Jennifer', 'Nash', 'boltonelizabeth@yahoo.com')
# 744. ('Jennifer', 'Gould', 'jeffreyestrada@hotmail.com')
# 745. ('Clinton', 'Craig', 'dennisholland@yang-lozano.com')
# 746. ('Nancy', 'Luna', 'amydavis@fisher-gentry.org')
# 747. ('Sharon', 'Barajas', 'frenchjamie@yahoo.com')
# 748. ('Cindy', 'Bowman', 'reyesryan@gmail.com')
# 749. ('James', 'Diaz', 'nfrench@gmail.com')
# 750. ('Donald', 'Miller', 'carrolldana@jarvis.com')
# 751. ('Michael', 'Wilson', 'brenda91@kennedy-daniels.com')
# 752. ('Dillon', 'Malone', 'hannahrodriguez@yahoo.com')
# 753. ('Cynthia', 'Collier', 'lawrence25@yahoo.com')
# 754. ('Robin', 'Barnett', 'jacob08@jones.org')
# 755. ('Nathan', 'Houston', 'heather95@copeland-woodard.net')
# 756. ('Rebecca', 'Cisneros', 'cassandragreene@campbell.com')
# 757. ('Sara', 'Grant', 'robertsmith@gmail.com')
# 758. ('Omar', 'Edwards', 'christieproctor@cole.info')
# 759. ('Janice', 'Martin', 'amanda82@little.com')
# 760. ('Jack', 'Snyder', 'seanwarren@lucas.com')
# 761. ('Susan', 'Andersen', 'villajennifer@hudson.info')
# 762. ('Pamela', 'Elliott', 'wscott@yahoo.com')
# 763. ('Jennifer', 'Olson', 'coconnell@mason.com')
# 764. ('Charles', 'Velasquez', 'josephmason@hampton.com')
# 765. ('Donna', 'Coffey', 'charles02@rodriguez.com')
# 766. ('Corey', 'Peterson', 'victoria69@yahoo.com')
# 767. ('Natasha', 'Evans', 'edaugherty@yahoo.com')
# 768. ('Jesus', 'Tapia', 'cainevelyn@hotmail.com')
# 769. ('Austin', 'Callahan', 'elizabethknox@yahoo.com')
# 770. ('David', 'Gould', 'julieanderson@gmail.com')
# 771. ('Emma', 'Reyes', 'awatson@moore.com')
# 772. ('Kimberly', 'Cannon', 'michelehall@yahoo.com')
# 773. ('Timothy', 'Carlson', 'mossdylan@terrell.com')
# 774. ('Ryan', 'Sharp', 'matthew40@smith.com')
# 775. ('Thomas', 'Shelton', 'paul95@hotmail.com')
# 776. ('David', 'Brennan', 'justin65@lane.com')
# 777. ('Debra', 'Stewart', 'tristansmith@hotmail.com')
# 778. ('Sarah', 'Moore', 'abarron@garcia-johnson.org')
# 779. ('Alexandria', 'Garcia', 'guzmantrevor@anderson.biz')
# 780. ('Juan', 'Mendoza', 'afleming@kennedy.info')
# 781. ('Sarah', 'Williams', 'kmarsh@mitchell-reyes.com')
# 782. ('Terry', 'Brown', 'bmorris@hotmail.com')
# 783. ('Tiffany', 'Evans', 'clayton03@williams.com')
# 784. ('Lauren', 'Stephens', 'nlynch@hotmail.com')
# 785. ('Jean', 'Ramirez', 'vargassandra@sexton.com')
# 786. ('Jennifer', 'Ray', 'greencrystal@yahoo.com')
# 787. ('Ashley', 'Meyers', 'jamieclark@gmail.com')
# 788. ('Bethany', 'Rodriguez', 'ogonzalez@camacho-robinson.com')
# 789. ('Aaron', 'Gates', 'alex62@gmail.com')
# 790. ('Jason', 'Sharp', 'hrandall@smith.com')
# 791. ('Carolyn', 'Smith', 'bradley35@gmail.com')
# 792. ('Megan', 'Smith', 'potterdavid@smith-hernandez.com')
# 793. ('Steven', 'Keith', 'wwallace@murray-davila.org')
# 794. ('Troy', 'Garcia', 'nchandler@yahoo.com')
# 795. ('Rachel', 'Perez', 'james86@keith-knapp.com')
# 796. ('Tracy', 'Griffith', 'jessica84@garcia.com')
# 797. ('Nicole', 'Wiley', 'morganedwards@owens-kennedy.com')
# 798. ('Jessica', 'Pierce', 'justinjackson@hotmail.com')
# 799. ('Kristina', 'Thompson', 'gregoryreyes@yahoo.com')
# 800. ('Maria', 'Perry', 'carpenterlouis@hotmail.com')
# 801. ('William', 'Mcdonald', 'nicholasbauer@yahoo.com')
# 802. ('Lisa', 'Terrell', 'agolden@hotmail.com')
# 803. ('Tristan', 'Bell', 'rthompson@hotmail.com')
# 804. ('Erica', 'Moss', 'bevans@hotmail.com')
# 805. ('Angela', 'Hernandez', 'samanthamanning@gmail.com')
# 806. ('Nathan', 'Tyler', 'oharris@dunn.info')
# 807. ('Michael', 'Collins', 'floreschristopher@shelton.net')
# 808. ('Wendy', 'Greene', 'brianblanchard@herring.com')
# 809. ('John', 'Stout', 'poncebrett@ramirez-robinson.com')
# 810. ('Bianca', 'Stark', 'ericcruz@yahoo.com')
# 811. ('William', 'Hayes', 'nbarker@yahoo.com')
# 812. ('Daniel', 'Foster', 'ryanmichelle@myers.com')
# 813. ('Sarah', 'Mueller', 'adkinstracy@duran.com')
# 814. ('Travis', 'Chavez', 'masseysteven@yahoo.com')
# 815. ('Michael', 'Gutierrez', 'pattersondaniel@weber-murphy.net')
# 816. ('Stephanie', 'Snyder', 'knightmark@ball-li.info')
# 817. ('Jacqueline', 'Robinson', 'leepatricia@yahoo.com')
# 818. ('Duane', 'Padilla', 'duranamanda@hotmail.com')
# 819. ('Jasmine', 'Coleman', 'phillipsmisty@smith.biz')
# 820. ('William', 'Hanna', 'fhodge@lynch-white.com')
# 821. ('Alicia', 'Ibarra', 'martinanthony@gmail.com')
# 822. ('Lauren', 'Craig', 'harriscynthia@gmail.com')
# 823. ('Patricia', 'Mcdonald', 'michelelewis@gmail.com')
# 824. ('Michael', 'Shaw', 'tammyvaughn@henson.com')
# 825. ('Christopher', 'Bradley', 'mwong@hansen.net')
# 826. ('Melissa', 'Wilson', 'jwoods@gmail.com')
# 827. ('Douglas', 'Lewis', 'bbrown@hotmail.com')
# 828. ('Samantha', 'Sanchez', 'dillonjessica@barrera.org')
# 829. ('Gregory', 'Nielsen', 'susan50@smith.net')
# 830. ('Anthony', 'Fletcher', 'darren07@gmail.com')
# 831. ('Kenneth', 'Haley', 'steven88@cantrell.biz')
# 832. ('Darrell', 'Alexander', 'paulbrown@woods.org')
# 833. ('Roy', 'Melendez', 'owilliams@hotmail.com')
# 834. ('Jermaine', 'Rojas', 'vicki65@mcclure.com')
# 835. ('Brian', 'Lozano', 'carolyn42@meyer.com')
# 836. ('Glen', 'Reyes', 'martinezrebecca@gmail.com')
# 837. ('Deborah', 'Garcia', 'shepardkelli@gmail.com')
# 838. ('Jeffrey', 'Wong', 'kwong@dorsey.com')
# 839. ('Terri', 'Keller', 'beverly31@gmail.com')
# 840. ('Charles', 'Gonzalez', 'debrahess@gmail.com')
# 841. ('Connie', 'Norris', 'johnsonmichael@gmail.com')
# 842. ('Carl', 'Scott', 'eric91@hotmail.com')
# 843. ('Ashley', 'Koch', 'mbrooks@nelson.info')
# 844. ('Richard', 'Larsen', 'rdunn@andrade.com')
# 845. ('Laura', 'Sutton', 'adamhines@yahoo.com')
# 846. ('Eric', 'Roth', 'rwilson@hotmail.com')
# 847. ('Timothy', 'Mcclure', 'nina62@yahoo.com')
# 848. ('Gabrielle', 'Ward', 'vmoore@gmail.com')
# 849. ('Michael', 'Cabrera', 'angela99@kerr-valdez.com')
# 850. ('Christine', 'Williams', 'sanfordjessica@smith.org')
# 851. ('Angela', 'Wang', 'patriciagoodwin@hotmail.com')
# 852. ('Jennifer', 'Sandoval', 'ycarter@evans.com')
# 853. ('Betty', 'Decker', 'hspencer@hotmail.com')
# 854. ('Sarah', 'Obrien', 'johnsondavid@yahoo.com')
# 855. ('George', 'Brady', 'riveramichael@yahoo.com')
# 856. ('Susan', 'Stephens', 'xburke@hotmail.com')
# 857. ('Dwayne', 'Juarez', 'johnsondennis@acosta.com')
# 858. ('Anna', 'Harris', 'meaganharper@hotmail.com')
# 859. ('Kyle', 'Taylor', 'williamskimberly@gmail.com')
# 860. ('Austin', 'Peters', 'perezstephanie@gmail.com')
# 861. ('Devin', 'Barnes', 'tanya05@gmail.com')
# 862. ('Frank', 'Smith', 'weberemily@gmail.com')
# 863. ('Theresa', 'Peck', 'thodges@moreno.com')
# 864. ('Tammy', 'Potter', 'ehall@elliott.org')
# 865. ('Dennis', 'Gardner', 'justin10@hotmail.com')
# 866. ('Casey', 'Pugh', 'tammiepark@hotmail.com')
# 867. ('Jessica', 'Estrada', 'jsanchez@yahoo.com')
# 868. ('Bethany', 'Rodriguez', 'zmurphy@wilson.biz')
# 869. ('Timothy', 'Garza', 'russellcarter@gmail.com')
# 870. ('Tanya', 'Paul', 'ebarrera@hotmail.com')
# 871. ('Marie', 'Ward', 'davidgutierrez@gmail.com')
# 872. ('Danielle', 'Valencia', 'pinedaphilip@gmail.com')
# 873. ('Alicia', 'Padilla', 'qcox@fischer-townsend.net')
# 874. ('Anne', 'Fowler', 'lfernandez@gmail.com')
# 875. ('Jennifer', 'Martin', 'mtanner@hotmail.com')
# 876. ('Stephanie', 'Nelson', 'scottmathew@hansen.org')
# 877. ('Jeffrey', 'Patterson', 'saraedwards@nichols.com')
# 878. ('Jacob', 'Dalton', 'campbellnicholas@yahoo.com')
# 879. ('Jeffrey', 'Best', 'christina67@king.net')
# 880. ('Tamara', 'Walker', 'meredithelliott@yahoo.com')
# 881. ('Evelyn', 'Hernandez', 'bjohns@yahoo.com')
# 882. ('Michele', 'Reid', 'james54@gmail.com')
# 883. ('Christopher', 'Hill', 'arthurli@hotmail.com')
# 884. ('Robert', 'Sullivan', 'xholmes@gmail.com')
# 885. ('Sherry', 'Meyer', 'jillandrews@yahoo.com')
# 886. ('Cheyenne', 'Fletcher', 'emilygarner@yahoo.com')
# 887. ('Rachel', 'Williams', 'laurenwhite@hotmail.com')
# 888. ('Allen', 'Morales', 'ylee@moore.com')
# 889. ('Luis', 'George', 'jalvarado@gmail.com')
# 890. ('Kristin', 'Acosta', 'carpentertonya@yahoo.com')
# 891. ('Ashley', 'Robles', 'victor63@yahoo.com')
# 892. ('Mark', 'Duran', 'wendyshelton@gmail.com')
# 893. ('Jose', 'Jackson', 'gonzalezmaria@yahoo.com')
# 894. ('Joseph', 'Hodge', 'pacemichelle@yahoo.com')
# 895. ('Julie', 'Jennings', 'edward74@rogers-hill.info')
# 896. ('Cynthia', 'Holt', 'michelleskinner@hunter.com')
# 897. ('Mercedes', 'Byrd', 'lawrence94@cruz-conley.info')
# 898. ('Jason', 'Goodwin', 'pjackson@hotmail.com')
# 899. ('Daniel', 'Taylor', 'deborah69@hotmail.com')
# 900. ('Joshua', 'Sanders', 'eroberts@anderson-carter.com')
# 901. ('Lucas', 'West', 'smithelizabeth@williams.org')
# 902. ('Michelle', 'Lewis', 'kimjenkins@gmail.com')
# 903. ('Christopher', 'Frye', 'rosalesmiguel@hotmail.com')
# 904. ('Sarah', 'Salas', 'jonesterri@gmail.com')
# 905. ('Philip', 'Walsh', 'murrayannette@hotmail.com')
# 906. ('April', 'Herman', 'pattersonroger@yu.com')
# 907. ('Stephanie', 'Ross', 'njones@yahoo.com')
# 908. ('Sharon', 'Bush', 'deborahwest@gmail.com')
# 909. ('Brandon', 'Reyes', 'smithalan@williams-hoffman.org')
# 910. ('Diana', 'Mccormick', 'peterturner@hotmail.com')
# 911. ('Kevin', 'Macias', 'hartmanhelen@gmail.com')
# 912. ('Kelly', 'Martin', 'harold32@gmail.com')
# 913. ('Taylor', 'Perez', 'wayneanderson@yahoo.com')
# 914. ('Arthur', 'Clark', 'helenware@hotmail.com')
# 915. ('Melissa', 'Cook', 'eevans@yahoo.com')
# 916. ('Evan', 'Powell', 'wwhite@kemp.com')
# 917. ('Kimberly', 'Elliott', 'carlsonjuan@holden.com')
# 918. ('Patrick', 'Haynes', 'olynch@hotmail.com')
# 919. ('Dana', 'Nunez', 'michael00@washington-castillo.com')
# 920. ('Gerald', 'Smith', 'johnsonbrandon@yahoo.com')
# 921. ('Scott', 'Ware', 'onoble@carroll.com')
# 922. ('Robert', 'Moody', 'elizabeth29@gmail.com')
# 923. ('Christy', 'Mitchell', 'kaitlin69@rodriguez-hill.com')
# 924. ('Christopher', 'Adams', 'barronshane@lewis.biz')
# 925. ('Heather', 'Bradley', 'stephanie03@morales.org')
# 926. ('Erika', 'Ellis', 'icarter@yahoo.com')
# 927. ('Cameron', 'Carlson', 'smithjennifer@gmail.com')
# 928. ('Jesus', 'Baker', 'michaellewis@moss-pennington.com')
# 929. ('John', 'Anderson', 'melanie43@gmail.com')
# 930. ('Aaron', 'Russell', 'david44@guzman.com')
# 931. ('Ronnie', 'Hill', 'paulcox@gmail.com')
# 932. ('Brittany', 'Nash', 'stephencrawford@gmail.com')
# 933. ('Rodney', 'Smith', 'gallowayaaron@gmail.com')
# 934. ('Cathy', 'Mack', 'jamesthompson@hotmail.com')
# 935. ('John', 'Aguirre', 'ricky01@yahoo.com')
# 936. ('Jill', 'Lee', 'kjimenez@alexander.com')
# 937. ('Joseph', 'Cruz', 'ballardtiffany@bauer-wallace.biz')
# 938. ('Clifford', 'Heath', 'vhahn@yahoo.com')
# 939. ('Jennifer', 'Matthews', 'brianwilliams@yahoo.com')
# 940. ('Anthony', 'Mason', 'alexissimpson@hotmail.com')
# 941. ('Holly', 'Martinez', 'danieljohnson@stokes.com')
# 942. ('Perry', 'Branch', 'butlertammy@parker-cook.com')
# 943. ('Christopher', 'Hall', 'natasharivera@hotmail.com')
# 944. ('Alicia', 'Schneider', 'jackparks@marshall-thomas.biz')
# 945. ('Susan', 'Richardson', 'rogersjoshua@mendez-fletcher.com')
# 946. ('Nathan', 'Hughes', 'jasonboyle@hotmail.com')
# 947. ('Jesus', 'Camacho', 'jenniferwalters@liu-henderson.biz')
# 948. ('Melinda', 'Smith', 'campbelljordan@cobb-smith.com')
# 949. ('Bobby', 'Calhoun', 'ryan15@reid.com')
# 950. ('James', 'Lopez', 'jeffrey58@gmail.com')
# 951. ('Brett', 'Mcdonald', 'jeffreysheppard@morrison.info')
# 952. ('Brianna', 'Duncan', 'sophiamartin@armstrong-price.com')
# 953. ('Benjamin', 'Harris', 'yrhodes@hart.com')
# 954. ('Christopher', 'Woods', 'romanbonnie@welch.com')
# 955. ('Deborah', 'Hill', 'christinajohnson@payne.net')
# 956. ('Shawn', 'Ramirez', 'dianakerr@burgess-murphy.biz')
# 957. ('Michael', 'Reed', 'williamsmichelle@dickson.com')
# 958. ('Steven', 'Fuller', 'chadgilbert@yahoo.com')
# 959. ('Richard', 'Cummings', 'amy84@kennedy.net')
# 960. ('Robert', 'Alvarez', 'susanyoung@williams.org')
# 961. ('Joshua', 'Martinez', 'jenningsmegan@blackburn-porter.net')
# 962. ('Jack', 'Wright', 'msosa@gmail.com')
# 963. ('Penny', 'Paul', 'angelascott@andrews-trevino.com')
# 964. ('Lori', 'Anderson', 'mwarner@love-villanueva.com')
# 965. ('Richard', 'Young', 'melissavaldez@yahoo.com')
# 966. ('Steven', 'Murphy', 'bennettchristopher@benitez.com')
# 967. ('Sara', 'Brooks', 'william10@gmail.com')
# 968. ('Kelly', 'Murray', 'fhebert@manning-gutierrez.biz')
# 969. ('Jaime', 'Romero', 'kmaxwell@brown-henry.com')
# 970. ('Rachel', 'Anthony', 'hayleywang@garcia-middleton.com')
# 971. ('Lisa', 'Taylor', 'mjones@alvarez.biz')
# 972. ('Andrew', 'Thompson', 'ssmall@strong.com')
# 973. ('Benjamin', 'Oneal', 'julie02@perez.com')
# 974. ('Lauren', 'Hensley', 'aliciapatterson@gonzalez-sullivan.info')
# 975. ('Mitchell', 'Stanley', 'dmoore@gmail.com')
# 976. ('Nathan', 'Gentry', 'vweaver@hotmail.com')
# 977. ('Laura', 'Brown', 'jamiehoward@drake.com')
# 978. ('Lauren', 'Barrera', 'rrose@gmail.com')
# 979. ('Kathy', 'Proctor', 'fordmonica@rivera.org')
# 980. ('Christina', 'Hernandez', 'dansnow@yahoo.com')
# 981. ('Dakota', 'Monroe', 'susanfloyd@hotmail.com')
# 982. ('Patricia', 'Andrews', 'dalewright@yahoo.com')
# 983. ('John', 'Smith', 'jeffreyolson@gmail.com')
# 984. ('Willie', 'Perez', 'kevin40@yahoo.com')
# 985. ('Derek', 'Jimenez', 'harperholly@gmail.com')
# 986. ('Laura', 'Moore', 'howardkristin@hotmail.com')
# 987. ('Noah', 'Hayes', 'hkline@yahoo.com')
# 988. ('John', 'Neal', 'ibutler@hotmail.com')
# 989. ('Richard', 'Wood', 'elizabethgarcia@jackson.com')
# 990. ('Andrew', 'Wilcox', 'brittany32@lee.com')
# 991. ('Lauren', 'Dickerson', 'dustin85@gmail.com')
# 992. ('Anthony', 'Chambers', 'jameshughes@blackburn.biz')
# 993. ('Mary', 'Morgan', 'davidholmes@yahoo.com')
# 994. ('Sean', 'Estrada', 'scottrobert@hotmail.com')
# 995. ('Lauren', 'Hansen', 'brandyanderson@patel.info')
# 996. ('Joshua', 'Thomas', 'tdickerson@yahoo.com')
# 997. ('Tyler', 'Sawyer', 'grobinson@lopez.com')
# 998. ('Johnny', 'Clark', 'james41@hotmail.com')
# 999. ('Monica', 'Stewart', 'christopherhernandez@taylor.net')
# 1000. ('David', 'Williams', 'odouglas@logan.com')
# 1001. ('Elizabeth', 'Payne', 'conwaymary@yahoo.com')
# 1002. ('Michelle', 'Jackson', 'moniquemiller@hotmail.com')
# 1003. ('Steven', 'Mccarthy', 'harriskaren@foster.com')
# 1004. ('Carrie', 'Adams', 'torresdavid@yahoo.com')
# 1005. ('Susan', 'Yang', 'mterry@snow.info')
# 1006. ('Brittany', 'Powers', 'jackbailey@hotmail.com')
# 1007. ('Anthony', 'Johnson', 'matajacob@hotmail.com')
# 1008. ('Daniel', 'Perez', 'carlosmcpherson@perry-ball.com')
# 1009. ('Patricia', 'Gonzalez', 'heatherjames@hotmail.com')
# 1010. ('Jennifer', 'Mathis', 'turnermichael@rogers-sanchez.net')
# 1011. ('Cole', 'Patel', 'cookamy@jackson.com')
# 1012. ('Phillip', 'Fields', 'jberry@yahoo.com')
# 1013. ('Charles', 'Cox', 'tfoster@gmail.com')
# 1014. ('Ashley', 'Mcclure', 'tamaragarcia@hotmail.com')
# 1015. ('Rita', 'Holmes', 'matthew26@yahoo.com')
# 1016. ('Christina', 'Hughes', 'foleymarisa@yahoo.com')
# 1017. ('Tracy', 'Kim', 'kellyspence@brown.net')
# 1018. ('Susan', 'Adkins', 'ahumphrey@hotmail.com')
# 1019. ('Dustin', 'Nicholson', 'daltonmorgan@taylor.info')
# 1020. ('Danielle', 'Morris', 'denisedillon@yahoo.com')
# 1021. ('Jonathon', 'Davis', 'christopherclark@walsh-hudson.org')
# 1022. ('Jared', 'Allen', 'vrichardson@maldonado.com')
# 1023. ('Melissa', 'Harris', 'bkelley@yahoo.com')
# 1024. ('Belinda', 'Duncan', 'sheenawu@nelson-evans.com')
# 1025. ('Karen', 'Taylor', 'joshuascott@hotmail.com')
# 1026. ('Brandon', 'Carter', 'leesara@gmail.com')
# 1027. ('Rodney', 'Lee', 'beverly76@gmail.com')
# 1028. ('Connor', 'Knight', 'kylejohnson@liu-russell.com')
# 1029. ('David', 'Berger', 'cynthiacunningham@hotmail.com')
# 1030. ('Tara', 'Benson', 'brian00@gomez.com')
# 1031. ('Kelly', 'Dunn', 'kyle86@yahoo.com')
# 1032. ('Stacey', 'Ramsey', 'jonathan09@gmail.com')
# 1033. ('Todd', 'Williamson', 'twalton@ross-hobbs.com')
# 1034. ('Joseph', 'Thomas', 'loridelgado@gmail.com')

# %% [markdown]
# We need to specify which columns we want to be returned. If we need all the columns we use `*`.

# %% [markdown]
# One issue you might have is not knowing what the names of the columns are. So how do we get the names of the columns? There are a few ways to do that. Probably, the simplest one is using the `.description` property of the cursor. When you execute a query you can find the names of the columns in `.description` property of the cursor. To have a full list of columns, use `SELECT *`.

# %%
query = '''
SELECT * from Customers
'''

# %%
cur = conn.cursor()
cur.execute(query)
cur.description
# Out:
# (('CustomerID', None, None, None, None, None, None),
#  ('Title', None, None, None, None, None, None),
#  ('Firstname', None, None, None, None, None, None),
#  ('Surname', None, None, None, None, None, None),
#  ('PhoneNumber', None, None, None, None, None, None),
#  ('Mobile', None, None, None, None, None, None),
#  ('Fax', None, None, None, None, None, None),
#  ('Email', None, None, None, None, None, None),
#  ('Address', None, None, None, None, None, None),
#  ('City', None, None, None, None, None, None),
#  ('Country', None, None, None, None, None, None),
#  ('CreditCardNumber', None, None, None, None, None, None),
#  ('CreditCardExpiry', None, None, None, None, None, None),
#  ('SignupDate', None, None, None, None, None, None))

# %% [markdown]
# **Note:** you don't need to use `.fetchall()` method. Just executing the query will give the names of the columns.

# %% [markdown]
# Another way is using the query below which will return names of all the tables, names of columns in each table, and the type of data in each column.

# %%
query= "SELECT * FROM sqlite_master WHERE type = 'table'"
cur = conn.cursor()
cur.execute(query)
output = cur.fetchall()
for row in output:
    for c in row: print(c)
    print('-'*50)
# Out:
# table
# Customers
# Customers
# 2
# CREATE TABLE Customers(
#     CustomerID INTEGER PRIMARY KEY,
#     Title NVARCHARS(5),
#     Firstname NVARCHAR(30),
#     Surname NVARCHAR(30),
#     PhoneNumber NVARCHAR(15),
#     Mobile NVARCHAR(15),
#     Fax NVARCHAR(15),
#     Email NVARCHAR(50),
#     Address NVARCHAR(50),
#     City  NVARCHAR(20),
#     Country  NVARCHAR(30),
#     CreditCardNumber NVARCHAR(25),
#     CreditCardExpiry NVARCHAR(5),
#     SignupDate NVARCHAR(15)
#     )
# --------------------------------------------------
# table
# Products
# Products
# 42
# CREATE TABLE Products(
#     ProductID INTEGER PRIMARY KEY,
#     StockCode NVARCHARS(15),
#     Category NVARCHAR(20),
#     Color NVARCHAR(30),
#     Weight SMALLINT,
#     UnitPrice FLOAT
#     )
# --------------------------------------------------
# table
# Sales
# Sales
# 47
# CREATE TABLE Sales(
#     SaleID INTEGER PRIMARY KEY,
#     InvoiceNumber NVARCHARS(15),
#     ProductID INTEGER,
#     Quantity INTEGER,
#     CustomerID INTEGER,
#     PurchaseDate NVARCHAR(15),
#     ShippedDate NVARCHAR(15),
#     FOREIGN KEY(ProductID) REFERENCES Products(ProductID),
#     FOREIGN KEY(CustomerID) REFERENCES Customers(CustomerID)
#     )
# --------------------------------------------------

# %% [markdown]
# ### ORDER BY
# By default the output of a query has no specific order. `ORDER BY` clause is used to sort data in the output. You can sort the data based on one or more columns. We can also specify whether we want the sorted output to be ascending or descending. This can be achieved by adding the following code to the query:<br>
# `ORDER BY {name of column} {ASC or DESC}`<br>
# ASC: Ascending<br>
# DESC: Descending

# %%
# Returns a list of first name, last name, Country and email for all customers
query = '''
SELECT FirstName, Surname, Country, Email FROM Customers
ORDER BY Country ASC,Surname ASC, FirstName ASC;
'''
execute_query(conn,query)
# Out:
# 1. ('Edward', 'Ball', 'Australia', 'mcclainstephen@yahoo.com')
# 2. ('Christine', 'Bell', 'Australia', 'hsimmons@hotmail.com')
# 3. ('Stephanie', 'Bennett', 'Australia', 'tylerross@odom.com')
# 4. ('James', 'Brown', 'Australia', 'allentricia@smith.com')
# 5. ('Rebecca', 'Cisneros', 'Australia', 'cassandragreene@campbell.com')
# 6. ('Mary', 'Compton', 'Australia', 'ngregory@hotmail.com')
# 7. ('Kevin', 'Dominguez', 'Australia', 'amber37@yahoo.com')
# 8. ('Samantha', 'Garcia', 'Australia', 'jamessmith@jenkins-smith.com')
# 9. ('Matthew', 'Greene', 'Australia', 'teresa39@gmail.com')
# 10. ('Wendy', 'Greene', 'Australia', 'brianblanchard@herring.com')
# 11. ('Michael', 'Gutierrez', 'Australia', 'pattersondaniel@weber-murphy.net')
# 12. ('Elizabeth', 'Hansen', 'Australia', 'lmiller@phelps.info')
# 13. ('William', 'Hayes', 'Australia', 'nbarker@yahoo.com')
# 14. ('Angela', 'Hernandez', 'Australia', 'samanthamanning@gmail.com')
# 15. ('Amy', 'Johnson', 'Australia', 'awilliams@hotmail.com')
# 16. ('Sara', 'Johnson', 'Australia', 'ehood@hotmail.com')
# 17. ('Wendy', 'Johnson', 'Australia', 'vegaalexandra@taylor.net')
# 18. ('Heidi', 'Kramer', 'Australia', 'debra72@yahoo.com')
# 19. ('Kenneth', 'Livingston', 'Australia', 'robert38@carter-young.com')
# 20. ('Deborah', 'Martinez', 'Australia', 'jasonorozco@gmail.com')
# 21. ('Shannon', 'Mcconnell', 'Australia', 'katrinasullivan@soto-davis.biz')
# 22. ('Amber', 'Morales', 'Australia', 'montgomerymatthew@yahoo.com')
# 23. ('Julie', 'Morales', 'Australia', 'reyesyvonne@hotmail.com')
# 24. ('Stephanie', 'Nelson', 'Australia', 'scottmathew@hansen.org')
# 25. ('Mackenzie', 'Owens', 'Australia', 'hhenry@gmail.com')
# 26. ('Theresa', 'Peck', 'Australia', 'thodges@moreno.com')
# 27. ('Michele', 'Reid', 'Australia', 'james54@gmail.com')
# 28. ('Steven', 'Robinson', 'Australia', 'deborah90@reed-smith.net')
# 29. ('Cindy', 'Russell', 'Australia', 'colleen11@hotmail.com')
# 30. ('Michael', 'Shaw', 'Australia', 'tammyvaughn@henson.com')
# 31. ('Jonathan', 'Smith', 'Australia', 'kelseydyer@rodriguez-rodriguez.com')
# 32. ('Drew', 'Spencer', 'Australia', 'jeffthompson@johnson-lopez.com')
# 33. ('Craig', 'Stevens', 'Australia', 'kennethhorn@hotmail.com')
# 34. ('Mitchell', 'Wagner', 'Australia', 'clarkchristina@hotmail.com')
# 35. ('Philip', 'Walsh', 'Australia', 'murrayannette@hotmail.com')
# 36. ('Heidi', 'Alexander', 'Austria', 'cherylleonard@riggs.com')
# 37. ('Rebekah', 'Beck', 'Austria', 'annamathews@davidson-archer.biz')
# 38. ('Shirley', 'Bell', 'Austria', 'bradley78@coleman.net')
# 39. ('Oscar', 'Brown', 'Austria', 'crystal00@haas.com')
# 40. ('Brandon', 'Carter', 'Austria', 'leesara@gmail.com')
# 41. ('Laurie', 'Davis', 'Austria', 'michael10@yahoo.com')
# 42. ('Andrea', 'Dawson', 'Austria', 'livingstoncarly@hotmail.com')
# 43. ('Anne', 'Fowler', 'Austria', 'lfernandez@gmail.com')
# 44. ('David', 'Gould', 'Austria', 'julieanderson@gmail.com')
# 45. ('Sara', 'Grant', 'Austria', 'robertsmith@gmail.com')
# 46. ('Christopher', 'Griffith', 'Austria', 'ysalinas@hotmail.com')
# 47. ('Krystal', 'Hall', 'Austria', 'owensgabriel@yahoo.com')
# 48. ('Erin', 'James', 'Austria', 'chloe40@fry.com')
# 49. ('Brian', 'Mcclure', 'Austria', 'dthomas@wood.info')
# 50. ('Mary', 'Mccoy', 'Austria', 'anna94@yahoo.com')
# 51. ('Robert', 'Moore', 'Austria', 'stephanie49@hotmail.com')
# 52. ('Melissa', 'Morris', 'Austria', 'tamaragross@hotmail.com')
# 53. ('Joseph', 'Norton', 'Austria', 'znicholson@gray-holland.org')
# 54. ('David', 'Randall', 'Austria', 'harmonmichael@gmail.com')
# 55. ('Bethany', 'Rodriguez', 'Austria', 'zmurphy@wilson.biz')
# 56. ('Leslie', 'Rush', 'Austria', 'joshua06@hotmail.com')
# 57. ('Samantha', 'Sanchez', 'Austria', 'dillonjessica@barrera.org')
# 58. ('Tyler', 'Sawyer', 'Austria', 'grobinson@lopez.com')
# 59. ('Sandra', 'Sims', 'Austria', 'erinchapman@peterson.com')
# 60. ('Morgan', 'Stewart', 'Austria', 'andrewschmidt@burton.com')
# 61. ('Robert', 'Sullivan', 'Austria', 'xholmes@gmail.com')
# 62. ('Diane', 'Summers', 'Austria', 'williamstodd@fields.com')
# 63. ('Timothy', 'Waters', 'Austria', 'russelljacqueline@hotmail.com')
# 64. ('Dan', 'Wilson', 'Austria', 'beverlyfields@rosales.com')
# 65. ('Pamela', 'Wilson', 'Austria', 'pedrocox@gmail.com')
# 66. ('Howard', 'Young', 'Austria', 'amanda72@hotmail.com')
# 67. ('Christopher', 'Anthony', 'Bahrain', 'eburns@hotmail.com')
# 68. ('Timothy', 'Barrera', 'Bahrain', 'anthony20@wilson.info')
# 69. ('Mark', 'Boyle', 'Bahrain', 'morrisjanet@rodriguez.com')
# 70. ('Sharon', 'Bush', 'Bahrain', 'deborahwest@gmail.com')
# 71. ('Suzanne', 'Cox', 'Bahrain', 'jessica08@gmail.com')
# 72. ('Joseph', 'Cruz', 'Bahrain', 'ballardtiffany@bauer-wallace.biz')
# 73. ('Courtney', 'Davenport', 'Bahrain', 'gibsonandrea@thomas.com')
# 74. ('Zachary', 'Davis', 'Bahrain', 'patrick18@gmail.com')
# 75. ('Kevin', 'Dixon', 'Bahrain', 'bmiller@gmail.com')
# 76. ('Adrian', 'Gamble', 'Bahrain', 'kimberlyjames@gmail.com')
# 77. ('Deborah', 'Garcia', 'Bahrain', 'shepardkelli@gmail.com')
# 78. ('Monica', 'Garcia', 'Bahrain', 'amyconrad@williams.com')
# 79. ('Troy', 'Garcia', 'Bahrain', 'nchandler@yahoo.com')
# 80. ('Ann', 'Gardner', 'Bahrain', 'michelle69@lewis.com')
# 81. ('Nathan', 'Gentry', 'Bahrain', 'vweaver@hotmail.com')
# 82. ('Angel', 'Gillespie', 'Bahrain', 'qowens@doyle-erickson.com')
# 83. ('James', 'Hamilton', 'Bahrain', 'camposnicole@yahoo.com')
# 84. ('Jennifer', 'Hamilton', 'Bahrain', 'sjones@rose.com')
# 85. ('John', 'Harris', 'Bahrain', 'yarmstrong@hotmail.com')
# 86. ('Richard', 'Harrison', 'Bahrain', 'david40@yahoo.com')
# 87. ('Alexis', 'Hawkins', 'Bahrain', 'anthony74@melendez.com')
# 88. ('Christina', 'Hill', 'Bahrain', 'browntiffany@hotmail.com')
# 89. ('Joseph', 'Hodge', 'Bahrain', 'pacemichelle@yahoo.com')
# 90. ('Rita', 'Holmes', 'Bahrain', 'matthew26@yahoo.com')
# 91. ('Betty', 'Johnson', 'Bahrain', 'robertzavala@yahoo.com')
# 92. ('Paul', 'Jordan', 'Bahrain', 'ramosmathew@brown.biz')
# 93. ('Gerald', 'Lambert', 'Bahrain', 'andrewsrhonda@hotmail.com')
# 94. ('Jeffrey', 'Lee', 'Bahrain', 'donna52@ortiz-davis.com')
# 95. ('Ashley', 'Mack', 'Bahrain', 'smithtimothy@gmail.com')
# 96. ('Logan', 'Marshall', 'Bahrain', 'kylelarson@rivera.com')
# 97. ('Brett', 'Mcdonald', 'Bahrain', 'jeffreysheppard@morrison.info')
# 98. ('Donald', 'Mejia', 'Bahrain', 'christopher46@chavez-cooper.com')
# 99. ('Robert', 'Miller', 'Bahrain', 'bewing@steele.org')
# 100. ('Christian', 'Moore', 'Bahrain', 'brenda18@hotmail.com')
# 101. ('Mary', 'Morgan', 'Bahrain', 'davidholmes@yahoo.com')
# 102. ('Diane', 'Mueller', 'Bahrain', 'nicole79@ortiz.biz')
# 103. ('Connie', 'Norris', 'Bahrain', 'johnsonmichael@gmail.com')
# 104. ('Lisa', 'Patrick', 'Bahrain', 'skemp@fuentes-johnson.biz')
# 105. ('Tanya', 'Paul', 'Bahrain', 'ebarrera@hotmail.com')
# 106. ('Margaret', 'Perez', 'Bahrain', 'phillip15@yahoo.com')
# 107. ('James', 'Quinn', 'Bahrain', 'uferguson@hess.com')
# 108. ('Michael', 'Reed', 'Bahrain', 'williamsmichelle@dickson.com')
# 109. ('Ashley', 'Robles', 'Bahrain', 'victor63@yahoo.com')
# 110. ('Andrew', 'Ryan', 'Bahrain', 'carl07@hotmail.com')
# 111. ('Patricia', 'Savage', 'Bahrain', 'jamesgarcia@richardson-pierce.com')
# 112. ('Jennifer', 'Simon', 'Bahrain', 'hortonjessica@gmail.com')
# 113. ('Kevin', 'Smith', 'Bahrain', 'elizabethday@branch.com')
# 114. ('Tracy', 'Spencer', 'Bahrain', 'matthew92@gmail.com')
# 115. ('Calvin', 'Stewart', 'Bahrain', 'david15@valenzuela.com')
# 116. ('Kelly', 'Strong', 'Bahrain', 'hernandezbrooke@black-price.com')
# 117. ('Christopher', 'Vargas', 'Bahrain', 'vsanford@fisher.biz')
# 118. ('Amy', 'Walker', 'Bahrain', 'richard61@yahoo.com')
# 119. ('Katherine', 'Zhang', 'Bahrain', 'dominguezrobert@smith-calhoun.com')
# 120. ('Lauren', 'Barrera', 'Belgium', 'rrose@gmail.com')
# 121. ('Sara', 'Brooks', 'Belgium', 'william10@gmail.com')
# 122. ('Kimberly', 'Cannon', 'Belgium', 'michelehall@yahoo.com')
# 123. ('Sharon', 'Diaz', 'Belgium', 'ugomez@yahoo.com')
# 124. ('Brett', 'Floyd', 'Belgium', 'gouldheidi@armstrong.info')
# 125. ('Jennifer', 'Gregory', 'Belgium', 'ucasey@reed.net')
# 126. ('Joanna', 'Hardy', 'Belgium', 'lyonslori@yahoo.com')
# 127. ('Scott', 'Harris', 'Belgium', 'kbrown@hotmail.com')
# 128. ('Ryan', 'Harvey', 'Belgium', 'fnewton@wallace-cochran.biz')
# 129. ('Cynthia', 'Holt', 'Belgium', 'michelleskinner@hunter.com')
# 130. ('Molly', 'Jones', 'Belgium', 'russell94@johnson-haynes.com')
# 131. ('Erik', 'Kim', 'Belgium', 'jeffbeard@myers.info')
# 132. ('Alan', 'Lawson', 'Belgium', 'lisaflores@hotmail.com')
# 133. ('Jose', 'Lowe', 'Belgium', 'matthew05@yoder.com')
# 134. ('Anthony', 'Mason', 'Belgium', 'alexissimpson@hotmail.com')
# 135. ('Andrew', 'Melendez', 'Belgium', 'aimeehaney@lopez-webb.com')
# 136. ('Katherine', 'Norman', 'Belgium', 'franklin63@yahoo.com')
# 137. ('Theodore', 'Norman', 'Belgium', 'john07@smith.biz')
# 138. ('Sarah', 'Obrien', 'Belgium', 'johnsondavid@yahoo.com')
# 139. ('Taylor', 'Perez', 'Belgium', 'wayneanderson@yahoo.com')
# 140. ('Janice', 'Peters', 'Belgium', 'pglenn@gmail.com')
# 141. ('Corey', 'Peterson', 'Belgium', 'victoria69@yahoo.com')
# 142. ('Brittany', 'Powers', 'Belgium', 'jackbailey@hotmail.com')
# 143. ('Isaac', 'Price', 'Belgium', 'tanderson@rush-davis.com')
# 144. ('Jordan', 'Russo', 'Belgium', 'chavezdavid@stevens-cook.com')
# 145. ('Terry', 'Sexton', 'Belgium', 'katherineburns@oliver.biz')
# 146. ('Andrew', 'Thompson', 'Belgium', 'ssmall@strong.com')
# 147. ('Gabrielle', 'Ward', 'Belgium', 'vmoore@gmail.com')
# 148. ('Nicole', 'Wiley', 'Belgium', 'morganedwards@owens-kennedy.com')
# 149. ('Patricia', 'Andrews', 'Brazil', 'dalewright@yahoo.com')
# 150. ('Tristan', 'Bell', 'Brazil', 'rthompson@hotmail.com')
# 151. ('David', 'Berger', 'Brazil', 'cynthiacunningham@hotmail.com')
# 152. ('Ronald', 'Carter', 'Brazil', 'walkerjulie@hotmail.com')
# 153. ('Anthony', 'Chambers', 'Brazil', 'jameshughes@blackburn.biz')
# 154. ('Jerry', 'Clark', 'Brazil', 'matthew49@avila.org')
# 155. ('Laura', 'Davis', 'Brazil', 'rgomez@michael-barnett.com')
# 156. ('Mariah', 'Davis', 'Brazil', 'thickman@hotmail.com')
# 157. ('Michael', 'Dixon', 'Brazil', 'martinezjennifer@smith.com')
# 158. ('Daniel', 'Foster', 'Brazil', 'ryanmichelle@myers.com')
# 159. ('Kristen', 'Gaines', 'Brazil', 'orice@hotmail.com')
# 160. ('Michelle', 'Gaines', 'Brazil', 'robinsonelizabeth@heath.com')
# 161. ('Michele', 'Garcia', 'Brazil', 'nmay@moody.com')
# 162. ('Brett', 'Gonzales', 'Brazil', 'joecohen@farmer.com')
# 163. ('William', 'Hanna', 'Brazil', 'fhodge@lynch-white.com')
# 164. ('Christopher', 'Hill', 'Brazil', 'arthurli@hotmail.com')
# 165. ('Melissa', 'Hill', 'Brazil', 'wspencer@rivas.com')
# 166. ('Monica', 'Hill', 'Brazil', 'kevin39@yahoo.com')
# 167. ('Derek', 'Jimenez', 'Brazil', 'harperholly@gmail.com')
# 168. ('Brian', 'Johnson', 'Brazil', 'kayla03@yahoo.com')
# 169. ('Dana', 'Kelly', 'Brazil', 'lindsey03@clark-cohen.org')
# 170. ('Melissa', 'Kennedy', 'Brazil', 'michaelgallegos@yahoo.com')
# 171. ('Connie', 'Lopez', 'Brazil', 'stephanie53@evans-cruz.com')
# 172. ('Danielle', 'Martinez', 'Brazil', 'rangeltina@johns.com')
# 173. ('David', 'Moore', 'Brazil', 'greeneshawn@sanders.com')
# 174. ('Bobby', 'Morgan', 'Brazil', 'williamssamantha@hotmail.com')
# 175. ('Erica', 'Moss', 'Brazil', 'bevans@hotmail.com')
# 176. ('Erin', 'Murray', 'Brazil', 'lpotter@gmail.com')
# 177. ('Jennifer', 'Oliver', 'Brazil', 'larry90@cunningham.com')
# 178. ('Anthony', 'Palmer', 'Brazil', 'sydneythomas@harris.biz')
# 179. ('Kathleen', 'Reyes', 'Brazil', 'chelseagutierrez@carrillo.com')
# 180. ('Karen', 'Sanders', 'Brazil', 'pbaldwin@gmail.com')
# 181. ('Terri', 'Savage', 'Brazil', 'donaldgonzalez@ellis-johnson.com')
# 182. ('Angela', 'Simpson', 'Brazil', 'barnettmadison@harding-ray.com')
# 183. ('Matthew', 'Smith', 'Brazil', 'stephaniepearson@parker-beck.com')
# 184. ('Gloria', 'Stafford', 'Brazil', 'amandaobrien@hotmail.com')
# 185. ('Michael', 'Stark', 'Brazil', 'john82@yahoo.com')
# 186. ('Amanda', 'Sullivan', 'Brazil', 'jpowell@christian.info')
# 187. ('Daniel', 'Taylor', 'Brazil', 'deborah69@hotmail.com')
# 188. ('Jeffrey', 'Wong', 'Brazil', 'kwong@dorsey.com')
# 189. ('Tyler', 'Wright', 'Brazil', 'davidevans@hotmail.com')
# 190. ('Thomas', 'Yang', 'Brazil', 'robinsonmargaret@meyer.net')
# 191. ('Susan', 'Adkins', 'Canada', 'ahumphrey@hotmail.com')
# 192. ('Angela', 'Arellano', 'Canada', 'timothy08@yahoo.com')
# 193. ('Jennifer', 'Barr', 'Canada', 'russellwade@hotmail.com')
# 194. ('Tara', 'Benson', 'Canada', 'brian00@gomez.com')
# 195. ('David', 'Bradley', 'Canada', 'heather76@lester.info')
# 196. ('Michael', 'Brewer', 'Canada', 'estradatracy@pugh.org')
# 197. ('Richard', 'Cummings', 'Canada', 'amy84@kennedy.net')
# 198. ('Belinda', 'Duncan', 'Canada', 'sheenawu@nelson-evans.com')
# 199. ('Kimberly', 'Elliott', 'Canada', 'carlsonjuan@holden.com')
# 200. ('Dennis', 'Gardner', 'Canada', 'justin10@hotmail.com')
# 201. ('Luis', 'George', 'Canada', 'jalvarado@gmail.com')
# 202. ('George', 'Henderson', 'Canada', 'teresaorozco@taylor.com')
# 203. ('Gabriel', 'Herrera', 'Canada', 'howardrobert@yahoo.com')
# 204. ('Mary', 'Hogan', 'Canada', 'deandavid@gmail.com')
# 205. ('Linda', 'Hughes', 'Canada', 'whernandez@hotmail.com')
# 206. ('Tommy', 'Hughes', 'Canada', 'fshaffer@gmail.com')
# 207. ('John', 'Johnson', 'Canada', 'lauren93@gmail.com')
# 208. ('Sharon', 'Johnson', 'Canada', 'sanfordpaul@yahoo.com')
# 209. ('Janice', 'Martin', 'Canada', 'amanda82@little.com')
# 210. ('Jennifer', 'Mathis', 'Canada', 'turnermichael@rogers-sanchez.net')
# 211. ('Mark', 'Mitchell', 'Canada', 'brookepugh@hotmail.com')
# 212. ('Robert', 'Moody', 'Canada', 'elizabeth29@gmail.com')
# 213. ('Laura', 'Moore', 'Canada', 'howardkristin@hotmail.com')
# 214. ('John', 'Morrison', 'Canada', 'weeksdonna@spencer-crawford.net')
# 215. ('Jennifer', 'Olson', 'Canada', 'coconnell@mason.com')
# 216. ('Daniel', 'Richardson', 'Canada', 'lsmith@mendoza.com')
# 217. ('Jaime', 'Romero', 'Canada', 'kmaxwell@brown-henry.com')
# 218. ('Aaron', 'Russell', 'Canada', 'david44@guzman.com')
# 219. ('Jennifer', 'Sandoval', 'Canada', 'ycarter@evans.com')
# 220. ('Brian', 'White', 'Canada', 'paynevincent@gmail.com')
# 221. ('Robert', 'White', 'Canada', 'hollowaykelly@gmail.com')
# 222. ('Shari', 'Wilson', 'Canada', 'montoyaana@smith.info')
# 223. ('Alicia', 'Anderson', 'Cyprus', 'katelynramsey@marquez.biz')
# 224. ('Christina', 'Bailey', 'Cyprus', 'zwilliams@brown.com')
# 225. ('Andrea', 'Beltran', 'Cyprus', 'deleoncarol@gmail.com')
# 226. ('Sean', 'Bennett', 'Cyprus', 'imcclure@gmail.com')
# 227. ('Kelly', 'Buckley', 'Cyprus', 'fergusonkatherine@riley.org')
# 228. ('James', 'Bush', 'Cyprus', 'oterry@brown.com')
# 229. ('Brandon', 'Butler', 'Cyprus', 'reynoldsdeanna@maxwell.com')
# 230. ('Michael', 'Cabrera', 'Cyprus', 'angela99@kerr-valdez.com')
# 231. ('Robert', 'Case', 'Cyprus', 'christinahancock@hudson-smith.net')
# 232. ('Jacqueline', 'Clark', 'Cyprus', 'jeremymarks@gmail.com')
# 233. ('Barry', 'Diaz', 'Cyprus', 'christopher02@lopez.org')
# 234. ('Lauren', 'Dickerson', 'Cyprus', 'dustin85@gmail.com')
# 235. ('Erika', 'Ellis', 'Cyprus', 'icarter@yahoo.com')
# 236. ('Deborah', 'Gordon', 'Cyprus', 'mark21@gmail.com')
# 237. ('Mark', 'Greene', 'Cyprus', 'wchavez@brandt.com')
# 238. ('Nathaniel', 'Gutierrez', 'Cyprus', 'nicole73@yahoo.com')
# 239. ('Bryan', 'Hale', 'Cyprus', 'duartemichelle@christensen.net')
# 240. ('Christina', 'Hernandez', 'Cyprus', 'dansnow@yahoo.com')
# 241. ('David', 'Holmes', 'Cyprus', 'michaeljohnson@medina.net')
# 242. ('Nathan', 'Hughes', 'Cyprus', 'jasonboyle@hotmail.com')
# 243. ('Daniel', 'Jackson', 'Cyprus', 'scott87@burns.org')
# 244. ('Dwayne', 'Juarez', 'Cyprus', 'johnsondennis@acosta.com')
# 245. ('Carlos', 'Lawson', 'Cyprus', 'khenderson@green.info')
# 246. ('Jackie', 'Martinez', 'Cyprus', 'thomas52@garcia.info')
# 247. ('Abigail', 'Merritt', 'Cyprus', 'stephaniemclean@chavez.biz')
# 248. ('Diane', 'Moon', 'Cyprus', 'nhooper@gmail.com')
# 249. ('Allen', 'Morales', 'Cyprus', 'ylee@moore.com')
# 250. ('Michael', 'Nelson', 'Cyprus', 'croberson@wagner-dunlap.com')
# 251. ('Dustin', 'Nicholson', 'Cyprus', 'daltonmorgan@taylor.info')
# 252. ('Brandon', 'Reyes', 'Cyprus', 'smithalan@williams-hoffman.org')
# 253. ('Tim', 'Robinson', 'Cyprus', 'xelliott@morris.info')
# 254. ('Stephanie', 'Ross', 'Cyprus', 'njones@yahoo.com')
# 255. ('Christopher', 'Schaefer', 'Cyprus', 'lmiller@yahoo.com')
# 256. ('Carl', 'Scott', 'Cyprus', 'eric91@hotmail.com')
# 257. ('Ryan', 'Sharp', 'Cyprus', 'justin87@hotmail.com')
# 258. ('Laura', 'Sutton', 'Cyprus', 'adamhines@yahoo.com')
# 259. ('Joshua', 'Thomas', 'Cyprus', 'tdickerson@yahoo.com')
# 260. ('Christine', 'Williams', 'Cyprus', 'sanfordjessica@smith.org')
# 261. ('Felicia', 'Williams', 'Cyprus', 'sandralindsey@rojas.com')
# 262. ('Steven', 'Wilson', 'Cyprus', 'hmorris@yahoo.com')
# 263. ('Jack', 'Wright', 'Cyprus', 'msosa@gmail.com')
# 264. ('Victoria', 'Bradley', 'Denmark', 'lcortez@turner.org')
# 265. ('Emily', 'Brown', 'Denmark', 'zschwartz@gmail.com')
# 266. ('Timothy', 'Campbell', 'Denmark', 'jordanandrea@rodriguez.net')
# 267. ('Robin', 'Carpenter', 'Denmark', 'tamara19@yahoo.com')
# 268. ('Michele', 'Carter', 'Denmark', 'jeffersoncatherine@gmail.com')
# 269. ('Jonathon', 'Davis', 'Denmark', 'christopherclark@walsh-hudson.org')
# 270. ('Keith', 'Diaz', 'Denmark', 'andrew67@austin-reynolds.biz')
# 271. ('Aaron', 'Gates', 'Denmark', 'alex62@gmail.com')
# 272. ('Amy', 'Griffin', 'Denmark', 'mitchellhansen@molina.org')
# 273. ('Alex', 'Harris', 'Denmark', 'knorton@russell.com')
# 274. ('Hannah', 'Harrison', 'Denmark', 'madisongarcia@carpenter-reed.com')
# 275. ('Brandon', 'Hernandez', 'Denmark', 'patelmichelle@cooper-reyes.com')
# 276. ('John', 'Hernandez', 'Denmark', 'hayleymarks@yahoo.com')
# 277. ('Christopher', 'Jones', 'Denmark', 'stacey14@gmail.com')
# 278. ('Jim', 'Jones', 'Denmark', 'zgardner@moreno.com')
# 279. ('Abigail', 'Lang', 'Denmark', 'jgray@yahoo.com')
# 280. ('Angela', 'Lang', 'Denmark', 'jeffrey51@davila-case.biz')
# 281. ('Rodney', 'Lee', 'Denmark', 'beverly76@gmail.com')
# 282. ('Mike', 'Lynch', 'Denmark', 'jamesgreen@yahoo.com')
# 283. ('Scott', 'Mcdonald', 'Denmark', 'millernancy@gmail.com')
# 284. ('Francis', 'Mercado', 'Denmark', 'hendersonkimberly@hotmail.com')
# 285. ('Annette', 'Miller', 'Denmark', 'butlerphilip@gmail.com')
# 286. ('Michael', 'Moore', 'Denmark', 'tkaufman@hotmail.com')
# 287. ('Susan', 'Moore', 'Denmark', 'amy74@hotmail.com')
# 288. ('Benjamin', 'Oneal', 'Denmark', 'julie02@perez.com')
# 289. ('Anthony', 'Reese', 'Denmark', 'vhuang@hotmail.com')
# 290. ('Donna', 'Sampson', 'Denmark', 'istone@bell.com')
# 291. ('Thomas', 'Shelton', 'Denmark', 'paul95@hotmail.com')
# 292. ('Samuel', 'Snyder', 'Denmark', 'mark66@vance-edwards.net')
# 293. ('Jesus', 'Tapia', 'Denmark', 'cainevelyn@hotmail.com')
# 294. ('Monica', 'Torres', 'Denmark', 'rmyers@morrow.com')
# 295. ('Barbara', 'Tran', 'Denmark', 'greencynthia@gmail.com')
# 296. ('Hannah', 'Vasquez', 'Denmark', 'hannahperez@clark-morris.com')
# 297. ('Elizabeth', 'Villarreal', 'Denmark', 'mendozacharles@gmail.com')
# 298. ('Ryan', 'Wilkins', 'Denmark', 'hudsonmatthew@powell.info')
# 299. ('Todd', 'Williamson', 'Denmark', 'twalton@ross-hobbs.com')
# 300. ('Jennifer', 'Wilson', 'Denmark', 'henrykevin@yahoo.com')
# 301. ('Brandon', 'Wright', 'Denmark', 'william18@yahoo.com')
# 302. ('Kristen', 'Andrews', 'Finland', 'thomas58@freeman-evans.com')
# 303. ('Kayla', 'Bauer', 'Finland', 'victoria45@gmail.com')
# 304. ('Paula', 'Beck', 'Finland', 'dan82@mejia-lopez.com')
# 305. ('Regina', 'Bell', 'Finland', 'david45@gutierrez.biz')
# 306. ('Jeffrey', 'Best', 'Finland', 'christina67@king.net')
# 307. ('Beth', 'Bradley', 'Finland', 'kirbyjacqueline@yahoo.com')
# 308. ('Jeffrey', 'Brown', 'Finland', 'gherman@yahoo.com')
# 309. ('Melissa', 'Burns', 'Finland', 'robert86@gmail.com')
# 310. ('Timothy', 'Campbell', 'Finland', 'msanders@gmail.com')
# 311. ('Maureen', 'Carroll', 'Finland', 'evargas@dalton.info')
# 312. ('Erin', 'Charles', 'Finland', 'david27@yahoo.com')
# 313. ('Alice', 'Clay', 'Finland', 'alawson@murphy.com')
# 314. ('Jasmine', 'Coleman', 'Finland', 'phillipsmisty@smith.biz')
# 315. ('Justin', 'Copeland', 'Finland', 'jillmorales@carlson.com')
# 316. ('Douglas', 'Davis', 'Finland', 'emiller@munoz.org')
# 317. ('Stephen', 'Evans', 'Finland', 'katelynsmith@mccullough.org')
# 318. ('Joseph', 'Gonzalez', 'Finland', 'vwilliams@dean.com')
# 319. ('Megan', 'Gordon', 'Finland', 'dalvarez@gmail.com')
# 320. ('Kelsey', 'Griffith', 'Finland', 'jenkinsmelissa@gmail.com')
# 321. ('Kyle', 'Hart', 'Finland', 'oliviasalazar@gmail.com')
# 322. ('Patrick', 'Haynes', 'Finland', 'olynch@hotmail.com')
# 323. ('Christina', 'Hughes', 'Finland', 'foleymarisa@yahoo.com')
# 324. ('Donna', 'Jackson', 'Finland', 'deanna60@harper.net')
# 325. ('Tracy', 'Kim', 'Finland', 'kellyspence@brown.net')
# 326. ('Benjamin', 'Long', 'Finland', 'hendersonkathy@hotmail.com')
# 327. ('Trevor', 'Lyons', 'Finland', 'jacqueline43@brown.com')
# 328. ('Sharon', 'Martinez', 'Finland', 'maxwellwilliam@gmail.com')
# 329. ('Patricia', 'Mcdonald', 'Finland', 'michelelewis@gmail.com')
# 330. ('Juan', 'Mendoza', 'Finland', 'afleming@kennedy.info')
# 331. ('Amber', 'Morales', 'Finland', 'summersrachel@martin.com')
# 332. ('Danielle', 'Morris', 'Finland', 'denisedillon@yahoo.com')
# 333. ('Kayla', 'Mueller', 'Finland', 'efrancis@yahoo.com')
# 334. ('Stacey', 'Page', 'Finland', 'rjones@gmail.com')
# 335. ('Dalton', 'Patton', 'Finland', 'qthomas@hotmail.com')
# 336. ('Isaiah', 'Phillips', 'Finland', 'smithjulie@yahoo.com')
# 337. ('Cheryl', 'Rios', 'Finland', 'varroyo@hotmail.com')
# 338. ('Nicole', 'Scott', 'Finland', 'johnsonmelissa@hotmail.com')
# 339. ('Joseph', 'Singh', 'Finland', 'michael35@wilson.com')
# 340. ('Robert', 'Soto', 'Finland', 'edward63@lopez.biz')
# 341. ('Deanna', 'Stewart', 'Finland', 'lmiller@bryant.com')
# 342. ('Lisa', 'Taylor', 'Finland', 'mjones@alvarez.biz')
# 343. ('Lynn', 'Tucker', 'Finland', 'ibarracourtney@smith.com')
# 344. ('Marie', 'Ward', 'Finland', 'davidgutierrez@gmail.com')
# 345. ('Barbara', 'Williams', 'Finland', 'ojohnson@jackson.info')
# 346. ('Rhonda', 'Adams', 'France', 'davidmontoya@hoffman.com')
# 347. ('Michele', 'Ali', 'France', 'jgriffith@gmail.com')
# 348. ('Monique', 'Baldwin', 'France', 'xmelendez@foster.biz')
# 349. ('Raymond', 'Bennett', 'France', 'nashanna@yahoo.com')
# 350. ('Shannon', 'Boyle', 'France', 'meghannoble@gmail.com')
# 351. ('Perry', 'Branch', 'France', 'butlertammy@parker-cook.com')
# 352. ('Phillip', 'Brown', 'France', 'ulindsey@young.com')
# 353. ('Jennifer', 'Bullock', 'France', 'katie07@whitaker-sweeney.com')
# 354. ('Robert', 'Collins', 'France', 'vincentcindy@marks-arnold.info')
# 355. ('Gabrielle', 'Combs', 'France', 'elizabethbrooks@ramos.org')
# 356. ('Jonathan', 'Espinoza', 'France', 'kimberlyrivera@patterson.com')
# 357. ('Gregory', 'Gibson', 'France', 'johnjones@fuller-mckinney.com')
# 358. ('Adam', 'Gonzalez', 'France', 'barbara75@adams.info')
# 359. ('Steven', 'Graham', 'France', 'denise06@yahoo.com')
# 360. ('Tina', 'Huerta', 'France', 'scottjohnson@yahoo.com')
# 361. ('Caroline', 'Jones', 'France', 'martinbryan@blackburn-jones.com')
# 362. ('Julia', 'King', 'France', 'xcarter@yahoo.com')
# 363. ('Elizabeth', 'Kirk', 'France', 'apitts@gmail.com')
# 364. ('Christopher', 'Knapp', 'France', 'samanthasoto@gmail.com')
# 365. ('Sarah', 'Lewis', 'France', 'crystalbarnett@crawford.com')
# 366. ('Theresa', 'Matthews', 'France', 'stevenscott@lewis.com')
# 367. ('Kimberly', 'Morris', 'France', 'katie20@hotmail.com')
# 368. ('Connor', 'Murphy', 'France', 'maureencamacho@yahoo.com')
# 369. ('Courtney', 'Myers', 'France', 'martinezrachael@yahoo.com')
# 370. ('Ann', 'Neal', 'France', 'jenkinstaylor@jenkins-key.com')
# 371. ('Gregory', 'Nielsen', 'France', 'susan50@smith.net')
# 372. ('Maria', 'Perry', 'France', 'carpenterlouis@hotmail.com')
# 373. ('Haley', 'Phillips', 'France', 'hernandezvictor@harvey.net')
# 374. ('Richard', 'Phillips', 'France', 'williamscott@yahoo.com')
# 375. ('Shawn', 'Ramirez', 'France', 'dianakerr@burgess-murphy.biz')
# 376. ('Emma', 'Reyes', 'France', 'awatson@moore.com')
# 377. ('John', 'Robles', 'France', 'fmcdaniel@yahoo.com')
# 378. ('Hayden', 'Romero', 'France', 'trankimberly@hotmail.com')
# 379. ('Nancy', 'Scott', 'France', 'colleenthompson@hotmail.com')
# 380. ('Alyssa', 'Simmons', 'France', 'dharris@gmail.com')
# 381. ('Mitchell', 'Stanley', 'France', 'dmoore@gmail.com')
# 382. ('Michael', 'Sutton', 'France', 'nathansalinas@hotmail.com')
# 383. ('Jeremy', 'Tucker', 'France', 'ohines@yahoo.com')
# 384. ('Brittany', 'Velez', 'France', 'katherine01@hotmail.com')
# 385. ('Jesse', 'Villarreal', 'France', 'christiankatherine@franklin.com')
# 386. ('Steven', 'Weiss', 'France', 'allennicole@wright-brown.com')
# 387. ('Daniel', 'Welch', 'France', 'kimberlyroberson@kline.com')
# 388. ('David', 'Williams', 'France', 'odouglas@logan.com')
# 389. ('Carla', 'Williamson', 'France', 'jennifer77@gmail.com')
# 390. ('John', 'Andrews', 'Germany', 'suzanneshields@willis.biz')
# 391. ('Brandon', 'Brown', 'Germany', 'leslie20@yahoo.com')
# 392. ('Jesus', 'Camacho', 'Germany', 'jenniferwalters@liu-henderson.biz')
# 393. ('Kevin', 'Cantrell', 'Germany', 'cmoore@hotmail.com')
# 394. ('Michael', 'Collins', 'Germany', 'floreschristopher@shelton.net')
# 395. ('Jason', 'Cruz', 'Germany', 'williamsdeanna@yahoo.com')
# 396. ('Gabriela', 'Cummings', 'Germany', 'sanderschristine@harrison.com')
# 397. ('Mary', 'Davis', 'Germany', 'trevororozco@rojas.com')
# 398. ('Richard', 'Davis', 'Germany', 'krausewilliam@martinez.biz')
# 399. ('John', 'Dominguez', 'Germany', 'julie50@yahoo.com')
# 400. ('Brianna', 'Duncan', 'Germany', 'sophiamartin@armstrong-price.com')
# 401. ('Omar', 'Edwards', 'Germany', 'christieproctor@cole.info')
# 402. ('Cynthia', 'Ellis', 'Germany', 'vstewart@gmail.com')
# 403. ('Martha', 'Erickson', 'Germany', 'jasmine27@hotmail.com')
# 404. ('Phillip', 'Fields', 'Germany', 'jberry@yahoo.com')
# 405. ('Carlos', 'Frank', 'Germany', 'jeffreyrodriguez@hotmail.com')
# 406. ('Timothy', 'Garza', 'Germany', 'russellcarter@gmail.com')
# 407. ('Joseph', 'Graves', 'Germany', 'anna73@miller-matthews.org')
# 408. ('Tanner', 'Griffith', 'Germany', 'shawngonzalez@hotmail.com')
# 409. ('Ashley', 'Hampton', 'Germany', 'petersonpaula@gmail.com')
# 410. ('Amber', 'Jordan', 'Germany', 'larrynovak@yahoo.com')
# 411. ('Connor', 'Knight', 'Germany', 'kylejohnson@liu-russell.com')
# 412. ('Troy', 'Lee', 'Germany', 'jeffery97@gmail.com')
# 413. ('Jennifer', 'Martin', 'Germany', 'mtanner@hotmail.com')
# 414. ('Timothy', 'Mcclure', 'Germany', 'nina62@yahoo.com')
# 415. ('William', 'Mcdonald', 'Germany', 'nicholasbauer@yahoo.com')
# 416. ('Preston', 'Molina', 'Germany', 'jessica62@yahoo.com')
# 417. ('Nicole', 'Monroe', 'Germany', 'troythompson@lang.info')
# 418. ('Cole', 'Patel', 'Germany', 'cookamy@jackson.com')
# 419. ('Meredith', 'Perry', 'Germany', 'khernandez@hotmail.com')
# 420. ('Austin', 'Peters', 'Germany', 'perezstephanie@gmail.com')
# 421. ('Casey', 'Pugh', 'Germany', 'tammiepark@hotmail.com')
# 422. ('Matthew', 'Ramos', 'Germany', 'gallagherrandy@hotmail.com')
# 423. ('Jennifer', 'Ray', 'Germany', 'greencrystal@yahoo.com')
# 424. ('Susan', 'Richardson', 'Germany', 'rogersjoshua@mendez-fletcher.com')
# 425. ('Connor', 'Rocha', 'Germany', 'maylaura@caldwell.biz')
# 426. ('Samuel', 'Strickland', 'Germany', 'qcastillo@gmail.com')
# 427. ('Jasmine', 'Stuart', 'Germany', 'ballrenee@jones.com')
# 428. ('Dominique', 'Sullivan', 'Germany', 'ebryant@reed-wallace.com')
# 429. ('Kyle', 'White', 'Germany', 'parnold@carpenter.com')
# 430. ('John', 'Young', 'Germany', 'ashleywood@hotmail.com')
# 431. ('Scott', 'Benton', 'Greece', 'timothy74@velasquez.com')
# 432. ('Mercedes', 'Byrd', 'Greece', 'lawrence94@cruz-conley.info')
# 433. ('Lynn', 'Castillo', 'Greece', 'stephanie57@salazar-sweeney.com')
# 434. ('Lisa', 'Collins', 'Greece', 'ewilliams@gmail.com')
# 435. ('Gabrielle', 'Cooper', 'Greece', 'hamiltonwanda@yahoo.com')
# 436. ('Clinton', 'Craig', 'Greece', 'dennisholland@yang-lozano.com')
# 437. ('Danielle', 'Cruz', 'Greece', 'lopezmichael@cooper.com')
# 438. ('Jennifer', 'Cruz', 'Greece', 'danielwalton@hotmail.com')
# 439. ('Betty', 'Decker', 'Greece', 'hspencer@hotmail.com')
# 440. ('Pamela', 'Elliott', 'Greece', 'wscott@yahoo.com')
# 441. ('Sean', 'Estrada', 'Greece', 'scottrobert@hotmail.com')
# 442. ('James', 'Garcia', 'Greece', 'robinsonshane@yahoo.com')
# 443. ('Kenneth', 'Haley', 'Greece', 'steven88@cantrell.biz')
# 444. ('Christopher', 'Hall', 'Greece', 'natasharivera@hotmail.com')
# 445. ('Anna', 'Harris', 'Greece', 'meaganharper@hotmail.com')
# 446. ('Steven', 'Hicks', 'Greece', 'jennifer30@gmail.com')
# 447. ('Kristina', 'Howell', 'Greece', 'jonathan82@yahoo.com')
# 448. ('Brittany', 'Huff', 'Greece', 'ejohnson@yahoo.com')
# 449. ('Terri', 'Keller', 'Greece', 'beverly31@gmail.com')
# 450. ('Jennifer', 'Matthews', 'Greece', 'brianwilliams@yahoo.com')
# 451. ('Michael', 'Miller', 'Greece', 'amanda24@brady.com')
# 452. ('Richard', 'Mullen', 'Greece', 'joannawalter@gmail.com')
# 453. ('Dana', 'Nunez', 'Greece', 'michael00@washington-castillo.com')
# 454. ('Blake', 'Pace', 'Greece', 'laurenjohnson@mata-brown.com')
# 455. ('Heather', 'Perez', 'Greece', 'ericlara@hill-wells.net')
# 456. ('Mary', 'Price', 'Greece', 'toddjoseph@montes-robinson.org')
# 457. ('Shelly', 'Riley', 'Greece', 'brent68@gmail.com')
# 458. ('Brandon', 'Roth', 'Greece', 'xfischer@gmail.com')
# 459. ('Alicia', 'Schneider', 'Greece', 'jackparks@marshall-thomas.biz')
# 460. ('Sabrina', 'Vang', 'Greece', 'joe78@williams-sanders.net')
# 461. ('Joseph', 'Walker', 'Greece', 'bradymichael@vaughan.com')
# 462. ('Christy', 'Washington', 'Greece', 'alex83@hotmail.com')
# 463. ('Matthew', 'Werner', 'Greece', 'scottdustin@hotmail.com')
# 464. ('Anthony', 'Wright', 'Greece', 'elizabeth20@smith.com')
# 465. ('Kevin', 'Wright', 'Greece', 'smithcheryl@hotmail.com')
# 466. ('Victoria', 'Wright', 'Greece', 'vincenttaylor@gmail.com')
# 467. ('Christopher', 'Bradley', 'Hong Kong', 'mwong@hansen.net')
# 468. ('Taylor', 'Byrd', 'Hong Kong', 'rfleming@gmail.com')
# 469. ('Claudia', 'Clark', 'Hong Kong', 'lawsonmelody@johnson.info')
# 470. ('Christopher', 'Davis', 'Hong Kong', 'alexander50@clayton.org')
# 471. ('Megan', 'Davis', 'Hong Kong', 'whitesara@johnson.info')
# 472. ('James', 'Diaz', 'Hong Kong', 'nfrench@gmail.com')
# 473. ('Jennifer', 'Edwards', 'Hong Kong', 'david13@foley.net')
# 474. ('Diana', 'Fernandez', 'Hong Kong', 'jfarrell@yahoo.com')
# 475. ('Curtis', 'Gallegos', 'Hong Kong', 'chaddeleon@yahoo.com')
# 476. ('Alexandria', 'Garcia', 'Hong Kong', 'guzmantrevor@anderson.biz')
# 477. ('David', 'Garcia', 'Hong Kong', 'xhall@barton.com')
# 478. ('Timothy', 'Garrett', 'Hong Kong', 'stephaniediaz@douglas-pineda.com')
# 479. ('David', 'Gray', 'Hong Kong', 'jamesfarmer@mendoza.com')
# 480. ('Mark', 'Hansen', 'Hong Kong', 'caitlin84@yahoo.com')
# 481. ('Daniel', 'Harmon', 'Hong Kong', 'macdonalddanielle@gmail.com')
# 482. ('Melissa', 'Holloway', 'Hong Kong', 'gregorytracy@lopez.biz')
# 483. ('Christopher', 'Horton', 'Hong Kong', 'donnabarnes@lynn-schmidt.com')
# 484. ('Kyle', 'Johnson', 'Hong Kong', 'tammy71@gmail.com')
# 485. ('Kyle', 'Jones', 'Hong Kong', 'cindy97@yahoo.com')
# 486. ('Michael', 'Jones', 'Hong Kong', 'dphillips@hotmail.com')
# 487. ('Jared', 'Kramer', 'Hong Kong', 'douglas33@fitzpatrick-clark.com')
# 488. ('Erica', 'Macdonald', 'Hong Kong', 'donaldbrown@booker.net')
# 489. ('Cathy', 'Mack', 'Hong Kong', 'jamesthompson@hotmail.com')
# 490. ('Charles', 'Martin', 'Hong Kong', 'tschultz@hotmail.com')
# 491. ('Diana', 'Mccormick', 'Hong Kong', 'peterturner@hotmail.com')
# 492. ('Sarah', 'Mueller', 'Hong Kong', 'adkinstracy@duran.com')
# 493. ('Mary', 'Oconnell', 'Hong Kong', 'ashlee44@yahoo.com')
# 494. ('Austin', 'Osborn', 'Hong Kong', 'johnleblanc@gmail.com')
# 495. ('Jeffrey', 'Patterson', 'Hong Kong', 'saraedwards@nichols.com')
# 496. ('Laura', 'Pollard', 'Hong Kong', 'katherinerichardson@yahoo.com')
# 497. ('Tammy', 'Potter', 'Hong Kong', 'ehall@elliott.org')
# 498. ('Matthew', 'Savage', 'Hong Kong', 'alejandro47@yahoo.com')
# 499. ('Victoria', 'Savage', 'Hong Kong', 'ambersingh@bright-freeman.com')
# 500. ('Eric', 'Scott', 'Hong Kong', 'jenny44@hotmail.com')
# 501. ('Richard', 'Sheppard', 'Hong Kong', 'awilliams@yahoo.com')
# 502. ('Megan', 'Smith', 'Hong Kong', 'xsanders@yahoo.com')
# 503. ('Rodney', 'Smith', 'Hong Kong', 'gallowayaaron@gmail.com')
# 504. ('Rebecca', 'Tate', 'Hong Kong', 'melendezchristopher@hotmail.com')
# 505. ('Tracey', 'Williams', 'Hong Kong', 'jefferynguyen@hotmail.com')
# 506. ('Richard', 'Wood', 'Hong Kong', 'elizabethgarcia@jackson.com')
# 507. ('Mark', 'York', 'Hong Kong', 'emily54@gmail.com')
# 508. ('Jesus', 'Baker', 'Iceland', 'michaellewis@moss-pennington.com')
# 509. ('Sharon', 'Barajas', 'Iceland', 'frenchjamie@yahoo.com')
# 510. ('Thomas', 'Barrett', 'Iceland', 'sydneyshort@yahoo.com')
# 511. ('William', 'Bell', 'Iceland', 'michael51@hotmail.com')
# 512. ('George', 'Brady', 'Iceland', 'riveramichael@yahoo.com')
# 513. ('Lauren', 'Craig', 'Iceland', 'harriscynthia@gmail.com')
# 514. ('Sarah', 'Evans', 'Iceland', 'gmills@gmail.com')
# 515. ('Tiffany', 'Evans', 'Iceland', 'clayton03@williams.com')
# 516. ('Amanda', 'Finley', 'Iceland', 'timothychen@yahoo.com')
# 517. ('Jasmine', 'Garza', 'Iceland', 'juliadiaz@smith.biz')
# 518. ('Kayla', 'Green', 'Iceland', 'anitanguyen@odonnell.com')
# 519. ('Lauren', 'Hansen', 'Iceland', 'brandyanderson@patel.info')
# 520. ('Justin', 'Huff', 'Iceland', 'jackjordan@yahoo.com')
# 521. ('John', 'Jackson', 'Iceland', 'derrick13@gmail.com')
# 522. ('Anthony', 'Johnson', 'Iceland', 'matajacob@hotmail.com')
# 523. ('Joshua', 'Martinez', 'Iceland', 'jenningsmegan@blackburn-porter.net')
# 524. ('Kenneth', 'Martinez', 'Iceland', 'singhjeremy@gmail.com')
# 525. ('Ashley', 'Mcclure', 'Iceland', 'tamaragarcia@hotmail.com')
# 526. ('Stephanie', 'Mccullough', 'Iceland', 'jessicagrimes@gonzales.info')
# 527. ('Robert', 'Morris', 'Iceland', 'pabbott@gmail.com')
# 528. ('Jeffrey', 'Perez', 'Iceland', 'mark60@hotmail.com')
# 529. ('Erica', 'Rodriguez', 'Iceland', 'brian17@wood.info')
# 530. ('Jermaine', 'Rojas', 'Iceland', 'vicki65@mcclure.com')
# 531. ('Jacob', 'Romero', 'Iceland', 'rosswilliam@hotmail.com')
# 532. ('Matthew', 'Rowe', 'Iceland', 'angelasmith@adams.com')
# 533. ('Kelsey', 'Schneider', 'Iceland', 'cwood@freeman.info')
# 534. ('Brian', 'Solis', 'Iceland', 'stevenfry@hotmail.com')
# 535. ('Amy', 'Torres', 'Iceland', 'vchristensen@hotmail.com')
# 536. ('Mark', 'Watson', 'Iceland', 'samuelgardner@gmail.com')
# 537. ('Crystal', 'Williams', 'Iceland', 'mariamiller@yahoo.com')
# 538. ('John', 'Aguirre', 'Israel', 'ricky01@yahoo.com')
# 539. ('Regina', 'Atkinson', 'Israel', 'sjenkins@gentry.com')
# 540. ('Brad', 'Barton', 'Israel', 'matthew76@wade.com')
# 541. ('George', 'Brewer', 'Israel', 'wbright@hotmail.com')
# 542. ('Austin', 'Callahan', 'Israel', 'elizabethknox@yahoo.com')
# 543. ('Christopher', 'Chaney', 'Israel', 'pamelaallen@yahoo.com')
# 544. ('Paul', 'Flores', 'Israel', 'paige75@gay-gilbert.com')
# 545. ('Michael', 'Gonzales', 'Israel', 'melaniejohnson@rivera.com')
# 546. ('Danny', 'Green', 'Israel', 'james59@gordon.com')
# 547. ('Karen', 'Hanson', 'Israel', 'eayers@gmail.com')
# 548. ('Mathew', 'Hart', 'Israel', 'holmescynthia@gmail.com')
# 549. ('Evelyn', 'Hernandez', 'Israel', 'bjohns@yahoo.com')
# 550. ('Ronnie', 'Hill', 'Israel', 'paulcox@gmail.com')
# 551. ('Kenneth', 'Holder', 'Israel', 'lanechristopher@yahoo.com')
# 552. ('Larry', 'Jones', 'Israel', 'thorntonmaureen@lewis-hernandez.org')
# 553. ('Steven', 'Keith', 'Israel', 'wwallace@murray-davila.org')
# 554. ('Sandra', 'Lucas', 'Israel', 'samuelhoward@drake.com')
# 555. ('Catherine', 'Martin', 'Israel', 'daviswendy@gallagher.com')
# 556. ('Kelly', 'Martin', 'Israel', 'harold32@gmail.com')
# 557. ('Robert', 'Mendoza', 'Israel', 'bkey@yahoo.com')
# 558. ('Sarah', 'Moore', 'Israel', 'abarron@garcia-johnson.org')
# 559. ('Sean', 'Munoz', 'Israel', 'ashleysteele@yahoo.com')
# 560. ('Elizabeth', 'Payne', 'Israel', 'conwaymary@yahoo.com')
# 561. ('Daniel', 'Perez', 'Israel', 'carlosmcpherson@perry-ball.com')
# 562. ('Christopher', 'Porter', 'Israel', 'mcintoshwendy@brown.com')
# 563. ('Elizabeth', 'Rodriguez', 'Israel', 'howeclaire@yahoo.com')
# 564. ('Sarah', 'Salas', 'Israel', 'jonesterri@gmail.com')
# 565. ('Joseph', 'Stephens', 'Israel', 'jessica31@yahoo.com')
# 566. ('Jennifer', 'Sullivan', 'Israel', 'thomaskristin@mcbride-lane.com')
# 567. ('Nathan', 'Tyler', 'Israel', 'oharris@dunn.info')
# 568. ('Charles', 'Velasquez', 'Israel', 'josephmason@hampton.com')
# 569. ('Lauren', 'Whitney', 'Israel', 'clarkgavin@trevino.com')
# 570. ('Maria', 'Woodard', 'Israel', 'jamesbowman@gmail.com')
# 571. ('Kevin', 'Wright', 'Israel', 'nicoledavis@hodges-martin.org')
# 572. ('Susan', 'Yang', 'Israel', 'mterry@snow.info')
# 573. ('Kristin', 'Acosta', 'Italy', 'carpentertonya@yahoo.com')
# 574. ('Gerald', 'Andrews', 'Italy', 'gonzalezmatthew@gmail.com')
# 575. ('Rachel', 'Anthony', 'Italy', 'hayleywang@garcia-middleton.com')
# 576. ('Ashley', 'Barnett', 'Italy', 'mballard@gmail.com')
# 577. ('Cheryl', 'Barrett', 'Italy', 'msimpson@clark.com')
# 578. ('Amanda', 'Bennett', 'Italy', 'ahughes@maldonado.info')
# 579. ('Christopher', 'Bradley', 'Italy', 'vthomas@king-shah.com')
# 580. ('Mark', 'Bradley', 'Italy', 'brownrobin@hotmail.com')
# 581. ('David', 'Brennan', 'Italy', 'justin65@lane.com')
# 582. ('Nicole', 'Byrd', 'Italy', 'kchandler@gmail.com')
# 583. ('Kristina', 'Carlson', 'Italy', 'tmartin@kirk.com')
# 584. ('Travis', 'Chavez', 'Italy', 'masseysteven@yahoo.com')
# 585. ('Arthur', 'Clark', 'Italy', 'helenware@hotmail.com')
# 586. ('Brittany', 'Dalton', 'Italy', 'qtorres@yahoo.com')
# 587. ('Shawn', 'Diaz', 'Italy', 'austinlevine@santos.com')
# 588. ('Tiffany', 'Fernandez', 'Italy', 'lopezjames@kennedy-boyd.com')
# 589. ('Alexandra', 'Gibbs', 'Italy', 'chawkins@kaiser.com')
# 590. ('Judith', 'Kim', 'Italy', 'stacey67@gmail.com')
# 591. ('Holly', 'Lee', 'Italy', 'doylelisa@yahoo.com')
# 592. ('Brett', 'Lyons', 'Italy', 'jacqueline24@yahoo.com')
# 593. ('Cynthia', 'Mcfarland', 'Italy', 'oliveramanda@hotmail.com')
# 594. ('Daisy', 'Moore', 'Italy', 'raymondmichelle@gmail.com')
# 595. ('Steven', 'Murphy', 'Italy', 'bennettchristopher@benitez.com')
# 596. ('Rhonda', 'Ortiz', 'Italy', 'madisonortiz@kirby.biz')
# 597. ('Jessica', 'Owen', 'Italy', 'mitchellkimberly@hotmail.com')
# 598. ('Scott', 'Patterson', 'Italy', 'lopezryan@hotmail.com')
# 599. ('Jessica', 'Pierce', 'Italy', 'justinjackson@hotmail.com')
# 600. ('Kathy', 'Proctor', 'Italy', 'fordmonica@rivera.org')
# 601. ('Glen', 'Reyes', 'Italy', 'martinezrebecca@gmail.com')
# 602. ('Jeremy', 'Saunders', 'Italy', 'randy11@reese.com')
# 603. ('Melinda', 'Smith', 'Italy', 'campbelljordan@cobb-smith.com')
# 604. ('Bianca', 'Stark', 'Italy', 'ericcruz@yahoo.com')
# 605. ('David', 'Vargas', 'Italy', 'alexis73@hotmail.com')
# 606. ('Angel', 'Villarreal', 'Italy', 'sbrown@collins-shaw.com')
# 607. ('Lauren', 'Allen', 'Japan', 'hlindsey@morales.com')
# 608. ('Shane', 'Arnold', 'Japan', 'ymorton@gmail.com')
# 609. ('Linda', 'Bentley', 'Japan', 'ybaker@hernandez.info')
# 610. ('Bonnie', 'Bright', 'Japan', 'laurie25@garcia.biz')
# 611. ('Terry', 'Brown', 'Japan', 'bmorris@hotmail.com')
# 612. ('Cameron', 'Carlson', 'Japan', 'smithjennifer@gmail.com')
# 613. ('Kimberly', 'Clark', 'Japan', 'miguelbryant@gmail.com')
# 614. ('Barry', 'Cox', 'Japan', 'donald51@yahoo.com')
# 615. ('Michael', 'Edwards', 'Japan', 'lisa17@richards-watts.com')
# 616. ('Sarah', 'Frost', 'Japan', 'oosborne@jordan.com')
# 617. ('Richard', 'Garner', 'Japan', 'joshua37@yahoo.com')
# 618. ('Curtis', 'Gonzalez', 'Japan', 'ygallagher@yahoo.com')
# 619. ('Shane', 'Green', 'Japan', 'sheltonkristopher@gmail.com')
# 620. ('Maria', 'Gutierrez', 'Japan', 'alexandracurtis@park-moore.com')
# 621. ('Benjamin', 'Harris', 'Japan', 'yrhodes@hart.com')
# 622. ('Melissa', 'Harris', 'Japan', 'bkelley@yahoo.com')
# 623. ('Charlene', 'Hayden', 'Japan', 'justinmiller@elliott.com')
# 624. ('Shane', 'Henry', 'Japan', 'april30@yahoo.com')
# 625. ('Nathan', 'Houston', 'Japan', 'heather95@copeland-woodard.net')
# 626. ('Randy', 'Howard', 'Japan', 'palmerjennifer@mendez-allen.org')
# 627. ('Shawn', 'Huff', 'Japan', 'christopher96@johnson.com')
# 628. ('Jason', 'Johnson', 'Japan', 'rosedeborah@herrera.net')
# 629. ('Maria', 'Lee', 'Japan', 'jasonrobertson@rios-torres.com')
# 630. ('Christopher', 'Miller', 'Japan', 'samantha44@anderson-alexander.org')
# 631. ('Devin', 'Mitchell', 'Japan', 'jennyjohnston@hanna.biz')
# 632. ('Keith', 'Nichols', 'Japan', 'christy07@hughes.com')
# 633. ('Andrea', 'Nixon', 'Japan', 'louisdaniels@copeland-porter.com')
# 634. ('Jennifer', 'Phillips', 'Japan', 'margaret50@mason.com')
# 635. ('Eric', 'Roth', 'Japan', 'rwilson@hotmail.com')
# 636. ('Richard', 'Saunders', 'Japan', 'simsmary@carlson.com')
# 637. ('Kelly', 'Smith', 'Japan', 'oliviarogers@yahoo.com')
# 638. ('Michelle', 'Stevens', 'Japan', 'butlerjade@gmail.com')
# 639. ('Frank', 'Wells', 'Japan', 'agarcia@reyes.com')
# 640. ('Jasmine', 'Wilson', 'Japan', 'vlawrence@garrett.com')
# 641. ('April', 'Bolton', 'Lithuania', 'dmiller@zamora.com')
# 642. ('Nicholas', 'Carroll', 'Lithuania', 'masondonaldson@young-perez.org')
# 643. ('Johnny', 'Clark', 'Lithuania', 'james41@hotmail.com')
# 644. ('Elizabeth', 'Evans', 'Lithuania', 'raymond28@chavez-terrell.com')
# 645. ('Jose', 'Evans', 'Lithuania', 'michealhoward@yahoo.com')
# 646. ('Susan', 'Fisher', 'Lithuania', 'amanda17@gmail.com')
# 647. ('Daisy', 'Franco', 'Lithuania', 'jaredestrada@yahoo.com')
# 648. ('Stanley', 'Gardner', 'Lithuania', 'dale33@smith.com')
# 649. ('Brian', 'Gutierrez', 'Lithuania', 'paul37@yahoo.com')
# 650. ('Catherine', 'Haas', 'Lithuania', 'usmith@juarez.com')
# 651. ('Jeffrey', 'Hall', 'Lithuania', 'whill@hotmail.com')
# 652. ('Lynn', 'Holmes', 'Lithuania', 'yarnold@yahoo.com')
# 653. ('David', 'Hughes', 'Lithuania', 'jasonadams@hotmail.com')
# 654. ('Adam', 'Lambert', 'Lithuania', 'smitheugene@yahoo.com')
# 655. ('Laura', 'Larsen', 'Lithuania', 'michaelgreen@hotmail.com')
# 656. ('Michelle', 'Lewis', 'Lithuania', 'kimjenkins@gmail.com')
# 657. ('Christopher', 'Liu', 'Lithuania', 'jenniferbailey@gmail.com')
# 658. ('John', 'Marshall', 'Lithuania', 'slutz@yahoo.com')
# 659. ('Patricia', 'Morris', 'Lithuania', 'kimberly77@hotmail.com')
# 660. ('Corey', 'Neal', 'Lithuania', 'kellycampbell@yahoo.com')
# 661. ('Jillian', 'Pratt', 'Lithuania', 'jordanmiranda@yahoo.com')
# 662. ('Justin', 'Price', 'Lithuania', 'hrusso@davis.com')
# 663. ('Katherine', 'Price', 'Lithuania', 'coleerica@hotmail.com')
# 664. ('Lauren', 'Stephens', 'Lithuania', 'nlynch@hotmail.com')
# 665. ('Debra', 'Stewart', 'Lithuania', 'tristansmith@hotmail.com')
# 666. ('Jessica', 'Tucker', 'Lithuania', 'bryantsharon@haynes-hanson.com')
# 667. ('Denise', 'Vargas', 'Lithuania', 'shelby03@farley.info')
# 668. ('Dwayne', 'Velez', 'Lithuania', 'evansbrian@king.com')
# 669. ('Ashley', 'Wade', 'Lithuania', 'garyhanson@cooper-franklin.com')
# 670. ('Andrew', 'Wilcox', 'Lithuania', 'brittany32@lee.com')
# 671. ('Renee', 'Wilkins', 'Lithuania', 'jodyespinoza@gmail.com')
# 672. ('Megan', 'Williams', 'Lithuania', 'ewingcarla@price.biz')
# 673. ('Natasha', 'Wolf', 'Lithuania', 'ireid@gmail.com')
# 674. ('Richard', 'Young', 'Lithuania', 'melissavaldez@yahoo.com')
# 675. ('Darrell', 'Alexander', 'Netherlands', 'paulbrown@woods.org')
# 676. ('Jared', 'Allen', 'Netherlands', 'vrichardson@maldonado.com')
# 677. ('Ellen', 'Bauer', 'Netherlands', 'rlee@hotmail.com')
# 678. ('Laura', 'Brown', 'Netherlands', 'jamiehoward@drake.com')
# 679. ('Cynthia', 'Cameron', 'Netherlands', 'osteele@taylor-greene.com')
# 680. ('Jacob', 'Dalton', 'Netherlands', 'campbellnicholas@yahoo.com')
# 681. ('Peter', 'Diaz', 'Netherlands', 'steven00@pace.com')
# 682. ('Amy', 'Evans', 'Netherlands', 'melissa74@yahoo.com')
# 683. ('Katelyn', 'Garrett', 'Netherlands', 'jacquelineporter@hotmail.com')
# 684. ('Lauren', 'Hensley', 'Netherlands', 'aliciapatterson@gonzalez-sullivan.info')
# 685. ('Mikayla', 'Hicks', 'Netherlands', 'pjohnson@gmail.com')
# 686. ('Allison', 'Hodge', 'Netherlands', 'carrsherry@anderson.net')
# 687. ('Alicia', 'Hudson', 'Netherlands', 'rebecca05@pratt.org')
# 688. ('Crystal', 'Jackson', 'Netherlands', 'larryhampton@yahoo.com')
# 689. ('Robert', 'Jacobs', 'Netherlands', 'tchen@morales.org')
# 690. ('Kaitlin', 'Johnson', 'Netherlands', 'sarah87@hotmail.com')
# 691. ('Calvin', 'Knight', 'Netherlands', 'brittanyking@gmail.com')
# 692. ('Olivia', 'Lee', 'Netherlands', 'nicole62@brown.com')
# 693. ('Kevin', 'Macias', 'Netherlands', 'hartmanhelen@gmail.com')
# 694. ('Alec', 'Martinez', 'Netherlands', 'floresdavid@king-jackson.com')
# 695. ('Julie', 'Martinez', 'Netherlands', 'yvettemartinez@howell.com')
# 696. ('Donald', 'Miller', 'Netherlands', 'carrolldana@jarvis.com')
# 697. ('Brittany', 'Nash', 'Netherlands', 'stephencrawford@gmail.com')
# 698. ('John', 'Neal', 'Netherlands', 'ibutler@hotmail.com')
# 699. ('Krista', 'Nichols', 'Netherlands', 'lisa63@hotmail.com')
# 700. ('Mallory', 'Obrien', 'Netherlands', 'davidsongabrielle@hotmail.com')
# 701. ('Jenny', 'Reed', 'Netherlands', 'vwong@lewis-hull.com')
# 702. ('Matthew', 'Robertson', 'Netherlands', 'stevenho@yahoo.com')
# 703. ('James', 'Robinson', 'Netherlands', 'kristin10@stevens-fleming.com')
# 704. ('Marilyn', 'Rodriguez', 'Netherlands', 'michelle94@morales-robinson.com')
# 705. ('Sherri', 'Russo', 'Netherlands', 'reesesteven@yahoo.com')
# 706. ('Brandon', 'Sanchez', 'Netherlands', 'leslie03@marquez.info')
# 707. ('Joshua', 'Sanders', 'Netherlands', 'eroberts@anderson-carter.com')
# 708. ('Stephanie', 'Schmidt', 'Netherlands', 'brandondouglas@rodgers.com')
# 709. ('Adam', 'Smith', 'Netherlands', 'james97@hudson.biz')
# 710. ('Frank', 'Smith', 'Netherlands', 'weberemily@gmail.com')
# 711. ('Gerald', 'Smith', 'Netherlands', 'johnsonbrandon@yahoo.com')
# 712. ('Dominique', 'Trujillo', 'Netherlands', 'patrickhall@perez.com')
# 713. ('Sara', 'Tucker', 'Netherlands', 'cchavez@hotmail.com')
# 714. ('Bianca', 'Webster', 'Netherlands', 'anthonymeyer@yahoo.com')
# 715. ('Rachel', 'Williams', 'Netherlands', 'laurenwhite@hotmail.com')
# 716. ('Roberto', 'Young', 'Netherlands', 'erika59@boone.biz')
# 717. ('Raymond', 'Adams', 'Norway', 'andrew61@brady.com')
# 718. ('Robin', 'Barnett', 'Norway', 'jacob08@jones.org')
# 719. ('Latoya', 'Barrera', 'Norway', 'garciahelen@yahoo.com')
# 720. ('Cindy', 'Bowman', 'Norway', 'reyesryan@gmail.com')
# 721. ('Julie', 'Brown', 'Norway', 'robinsonhector@preston-mcguire.net')
# 722. ('William', 'Burton', 'Norway', 'jameslisa@trevino.com')
# 723. ('Bobby', 'Calhoun', 'Norway', 'ryan15@reid.com')
# 724. ('Aimee', 'Carlson', 'Norway', 'smithchristy@hotmail.com')
# 725. ('Danielle', 'Carr', 'Norway', 'mkaiser@yahoo.com')
# 726. ('Jo', 'Davis', 'Norway', 'awilliams@martinez-lee.info')
# 727. ('Jessica', 'Estrada', 'Norway', 'jsanchez@yahoo.com')
# 728. ('Susan', 'Fowler', 'Norway', 'barkerlinda@dominguez.com')
# 729. ('Tiffany', 'Gomez', 'Norway', 'lisadavis@gmail.com')
# 730. ('Jay', 'Griffith', 'Norway', 'wford@hotmail.com')
# 731. ('Gregory', 'Hanson', 'Norway', 'stephaniewood@yahoo.com')
# 732. ('Kendra', 'Hayden', 'Norway', 'moodyvictoria@gmail.com')
# 733. ('Justin', 'Herrera', 'Norway', 'alexandermartin@gmail.com')
# 734. ('Nicholas', 'Hinton', 'Norway', 'christian37@ward.org')
# 735. ('Julie', 'Hood', 'Norway', 'justin78@cox.com')
# 736. ('Julie', 'Jennings', 'Norway', 'edward74@rogers-hill.info')
# 737. ('Adam', 'Lopez', 'Norway', 'shortkathleen@booker.com')
# 738. ('James', 'Lopez', 'Norway', 'jeffrey58@gmail.com')
# 739. ('Donna', 'Lucas', 'Norway', 'nielsenjohn@johnson.com')
# 740. ('Edward', 'Mack', 'Norway', 'lauraavery@walker.com')
# 741. ('Lori', 'Martin', 'Norway', 'astout@yahoo.com')
# 742. ('Sandra', 'Mccarthy', 'Norway', 'amandaochoa@yahoo.com')
# 743. ('Andrea', 'Mclean', 'Norway', 'uguzman@kidd-morgan.net')
# 744. ('Roy', 'Melendez', 'Norway', 'owilliams@hotmail.com')
# 745. ('Christian', 'Meyer', 'Norway', 'kristopher20@brown.com')
# 746. ('Tiffany', 'Moore', 'Norway', 'wallacemarcus@nelson.com')
# 747. ('Lynn', 'Murray', 'Norway', 'markwhite@gmail.com')
# 748. ('Lori', 'Nelson', 'Norway', 'robin41@nguyen.com')
# 749. ('Brenda', 'Payne', 'Norway', 'bcontreras@hotmail.com')
# 750. ('Rachel', 'Perez', 'Norway', 'james86@keith-knapp.com')
# 751. ('Willie', 'Perez', 'Norway', 'kevin40@yahoo.com')
# 752. ('Michael', 'Phelps', 'Norway', 'zthompson@gmail.com')
# 753. ('Patricia', 'Prince', 'Norway', 'romananna@nguyen-armstrong.com')
# 754. ('Stephanie', 'Rice', 'Norway', 'martinezjames@parker.com')
# 755. ('Daniel', 'Roberts', 'Norway', 'wellsgilbert@yahoo.com')
# 756. ('Madison', 'Russell', 'Norway', 'tyler55@yahoo.com')
# 757. ('Kimberly', 'Smith', 'Norway', 'philip32@yahoo.com')
# 758. ('Jessica', 'Thomas', 'Norway', 'cbailey@gmail.com')
# 759. ('Douglas', 'Torres', 'Norway', 'leahgonzales@ramos-soto.com')
# 760. ('Danielle', 'Valencia', 'Norway', 'pinedaphilip@gmail.com')
# 761. ('Tanya', 'Wise', 'Norway', 'gerald45@hotmail.com')
# 762. ('Carrie', 'Adams', 'Poland', 'torresdavid@yahoo.com')
# 763. ('Robert', 'Alvarez', 'Poland', 'susanyoung@williams.org')
# ...
# 791. ('Dakota', 'Monroe', 'Poland', 'susanfloyd@hotmail.com')
# 792. ('Kelly', 'Murray', 'Poland', 'fhebert@manning-gutierrez.biz')
# 793. ('Duane', 'Padilla', 'Poland', 'duranamanda@hotmail.com')
# 794. ('Jacqueline', 'Robinson', 'Poland', 'leepatricia@yahoo.com')
# 795. ('Melinda', 'Shea', 'Poland', 'jason27@hotmail.com')
# 796. ('Gabriel', 'Smith', 'Poland', 'andrew21@hotmail.com')
# 797. ('John', 'Smith', 'Poland', 'jeffreyolson@gmail.com')
# 798. ('Kelly', 'Smith', 'Poland', 'lewisjennifer@sparks-cox.info')
# 799. ('Maria', 'Smith', 'Poland', 'francispaul@simmons.com')
# 800. ('Megan', 'Smith', 'Poland', 'potterdavid@smith-hernandez.com')
# 801. ('Monica', 'Stewart', 'Poland', 'christopherhernandez@taylor.net')
# 802. ('Anna', 'Ward', 'Poland', 'sarah91@gmail.com')
# 803. ('Rebecca', 'Werner', 'Poland', 'arichardson@hotmail.com')
# 804. ('Christopher', 'Woods', 'Poland', 'romanbonnie@welch.com')
# 805. ('Angel', 'Anderson', 'Portugal', 'jamielewis@hotmail.com')
# 806. ('John', 'Anderson', 'Portugal', 'melanie43@gmail.com')
# 807. ('Bernard', 'Cook', 'Portugal', 'bryan99@hotmail.com')
# 808. ('Heather', 'Davila', 'Portugal', 'kellygary@yahoo.com')
# 809. ('Amanda', 'Fitzpatrick', 'Portugal', 'danielsjustin@yahoo.com')
# 810. ('Carrie', 'Gonzalez', 'Portugal', 'vreed@coleman.biz')
# 811. ('Jeffrey', 'Gonzalez', 'Portugal', 'kjennings@yahoo.com')
# 812. ('Jason', 'Goodwin', 'Portugal', 'pjackson@hotmail.com')
# 813. ('Anthony', 'Green', 'Portugal', 'matthewvelasquez@smith.info')
# 814. ('Jenna', 'Hernandez', 'Portugal', 'hendrickslori@hotmail.com')
# 815. ('David', 'Holt', 'Portugal', 'sergioduarte@rodriguez.info')
# 816. ('Katie', 'Johnson', 'Portugal', 'belindacruz@strickland.biz')
# 817. ('Ray', 'Larson', 'Portugal', 'roy50@collins.com')
# 818. ('Douglas', 'Lewis', 'Portugal', 'bbrown@hotmail.com')
# 819. ('Nancy', 'Luna', 'Portugal', 'amydavis@fisher-gentry.org')
# 820. ('Craig', 'Martin', 'Portugal', 'tramirez@hotmail.com')
# 821. ('Morgan', 'Poole', 'Portugal', 'jamesadams@clark.com')
# 822. ('Mark', 'Riley', 'Portugal', 'jamiegarza@hotmail.com')
# 823. ('Christopher', 'Rios', 'Portugal', 'msmith@smith.com')
# 824. ('Tiffany', 'Rodriguez', 'Portugal', 'myoung@yahoo.com')
# 825. ('John', 'Stout', 'Portugal', 'poncebrett@ramirez-robinson.com')
# 826. ('Dana', 'Tate', 'Portugal', 'donald22@hotmail.com')
# 827. ('Patricia', 'Thomas', 'Portugal', 'maria02@gmail.com')
# 828. ('Debra', 'Wall', 'Portugal', 'colleenalexander@taylor-brown.net')
# 829. ('Debra', 'Watson', 'Portugal', 'alisonjones@hotmail.com')
# 830. ('Christopher', 'Weber', 'Portugal', 'andrew87@yahoo.com')
# 831. ('Maria', 'Wilson', 'Portugal', 'sbush@yahoo.com')
# 832. ('Christopher', 'Adams', 'SingaporeCzech Republic', 'barronshane@lewis.biz')
# 833. ('Nicholas', 'Allen', 'SingaporeCzech Republic', 'tammy92@hotmail.com')
# 834. ('James', 'Burch', 'SingaporeCzech Republic', 'garcialisa@gmail.com')
# 835. ('Cynthia', 'Collier', 'SingaporeCzech Republic', 'lawrence25@yahoo.com')
# 836. ('Paul', 'Collins', 'SingaporeCzech Republic', 'hstout@hotmail.com')
# 837. ('Mary', 'Eaton', 'SingaporeCzech Republic', 'nathanhart@gmail.com')
# 838. ('Robin', 'Fleming', 'SingaporeCzech Republic', 'kconley@hotmail.com')
# 839. ('Jonathon', 'Frye', 'SingaporeCzech Republic', 'billy83@hotmail.com')
# 840. ('Crystal', 'Hall', 'SingaporeCzech Republic', 'bruce17@hotmail.com')
# 841. ('Rachel', 'Harris', 'SingaporeCzech Republic', 'sarahwilliams@calderon-patel.com')
# 842. ('Ryan', 'Hatfield', 'SingaporeCzech Republic', 'alvarezstacy@stevenson.org')
# 843. ('Melissa', 'Hernandez', 'SingaporeCzech Republic', 'dhanna@lucas.biz')
# 844. ('Scott', 'Ho', 'SingaporeCzech Republic', 'ralph59@scott-smith.net')
# 845. ('Ashley', 'Hughes', 'SingaporeCzech Republic', 'jason19@gmail.com')
# 846. ('Joseph', 'Johnson', 'SingaporeCzech Republic', 'graymary@yahoo.com')
# 847. ('Jennifer', 'Livingston', 'SingaporeCzech Republic', 'opowell@hotmail.com')
# 848. ('Dillon', 'Malone', 'SingaporeCzech Republic', 'hannahrodriguez@yahoo.com')
# 849. ('Jonathan', 'Miller', 'SingaporeCzech Republic', 'oanderson@yahoo.com')
# 850. ('Leslie', 'Miller', 'SingaporeCzech Republic', 'gbell@riley.biz')
# 851. ('David', 'Owens', 'SingaporeCzech Republic', 'scottbrandon@hotmail.com')
# 852. ('Kelly', 'Parker', 'SingaporeCzech Republic', 'wilsonclaudia@bradley.net')
# 853. ('Elizabeth', 'Payne', 'SingaporeCzech Republic', 'reeddavid@alvarez.com')
# 854. ('Deborah', 'Perry', 'SingaporeCzech Republic', 'hortonshelia@yahoo.com')
# 855. ('Sandra', 'Ramos', 'SingaporeCzech Republic', 'rhondajones@gardner-kelly.com')
# 856. ('Steven', 'Sanders', 'SingaporeCzech Republic', 'robertschristian@hotmail.com')
# 857. ('Matthew', 'Smith', 'SingaporeCzech Republic', 'dawnstewart@robinson.com')
# 858. ('Seth', 'Stevens', 'SingaporeCzech Republic', 'kathleengomez@hotmail.com')
# 859. ('Karen', 'Thomas', 'SingaporeCzech Republic', 'melissabishop@davis.com')
# 860. ('James', 'Wagner', 'SingaporeCzech Republic', 'dwilliamson@clark.biz')
# 861. ('Angela', 'Wang', 'SingaporeCzech Republic', 'patriciagoodwin@hotmail.com')
# 862. ('Scott', 'Ware', 'SingaporeCzech Republic', 'onoble@carroll.com')
# 863. ('Sarah', 'Adams', 'Spain', 'donald85@yahoo.com')
# 864. ('Gary', 'Andrade', 'Spain', 'davismary@hotmail.com')
# 865. ('Jacob', 'Arnold', 'Spain', 'sanderson@johnson.info')
# 866. ('Kenneth', 'Benson', 'Spain', 'drodriguez@yahoo.com')
# 867. ('Patricia', 'Brown', 'Spain', 'bernardhawkins@henry.com')
# 868. ('Timothy', 'Carlson', 'Spain', 'mossdylan@terrell.com')
# 869. ('Bruce', 'Casey', 'Spain', 'harrisamanda@yahoo.com')
# 870. ('Daniel', 'Donovan', 'Spain', 'marcusguerrero@gmail.com')
# 871. ('Brittney', 'Edwards', 'Spain', 'anthonyhickman@gmail.com')
# 872. ('Anthony', 'Fletcher', 'Spain', 'darren07@gmail.com')
# 873. ('Margaret', 'Franco', 'Spain', 'kyle85@howell-barr.biz')
# 874. ('Christopher', 'Frye', 'Spain', 'rosalesmiguel@hotmail.com')
# 875. ('John', 'Gonzalez', 'Spain', 'sanchezjoel@hotmail.com')
# 876. ('Jennifer', 'Gould', 'Spain', 'jeffreyestrada@hotmail.com')
# 877. ('Aaron', 'Harris', 'Spain', 'justin10@hotmail.com')
# 878. ('Clifford', 'Heath', 'Spain', 'vhahn@yahoo.com')
# 879. ('April', 'Herman', 'Spain', 'pattersonroger@yu.com')
# 880. ('Michelle', 'Jackson', 'Spain', 'moniquemiller@hotmail.com')
# 881. ('Dorothy', 'Jimenez', 'Spain', 'omarclark@hotmail.com')
# 882. ('Richard', 'Larsen', 'Spain', 'rdunn@andrade.com')
# 883. ('Anthony', 'Mcdonald', 'Spain', 'hdoyle@gmail.com')
# 884. ('Ashley', 'Meyers', 'Spain', 'jamieclark@gmail.com')
# 885. ('Theresa', 'Molina', 'Spain', 'brittany14@hotmail.com')
# 886. ('Christopher', 'Neal', 'Spain', 'patricia81@gmail.com')
# 887. ('Kaitlyn', 'Oliver', 'Spain', 'fernandezbrooke@hotmail.com')
# 888. ('Kevin', 'Owens', 'Spain', 'jason31@bryan-martin.biz')
# 889. ('Aaron', 'Patel', 'Spain', 'brandon20@nunez.com')
# 890. ('Adam', 'Pierce', 'Spain', 'sarahpatterson@hernandez.info')
# 891. ('Ryan', 'Pineda', 'Spain', 'nicholasvargas@hotmail.com')
# 892. ('Stacey', 'Ramsey', 'Spain', 'jonathan09@gmail.com')
# 893. ('Bethany', 'Rodriguez', 'Spain', 'ogonzalez@camacho-robinson.com')
# 894. ('Michael', 'Rowland', 'Spain', 'wkirby@henderson.com')
# 895. ('Clinton', 'Saunders', 'Spain', 'gregoryjohnson@mcdaniel.com')
# 896. ('Julie', 'Sexton', 'Spain', 'david22@carr-miller.com')
# 897. ('Steven', 'Simon', 'Spain', 'richardschristopher@jacobs.org')
# 898. ('Edwin', 'Smith', 'Spain', 'stephanie54@pope.org')
# 899. ('Jack', 'Snyder', 'Spain', 'seanwarren@lucas.com')
# 900. ('Kyle', 'Taylor', 'Spain', 'williamskimberly@gmail.com')
# 901. ('Joseph', 'Thomas', 'Spain', 'loridelgado@gmail.com')
# 902. ('Katie', 'Thompson', 'Spain', 'mcmillanrebecca@gmail.com')
# 903. ('Erin', 'Waters', 'Spain', 'vsharp@hotmail.com')
# 904. ('Elizabeth', 'Williams', 'Spain', 'claytonjustin@gmail.com')
# 905. ('Dawn', 'Young', 'Spain', 'hallsherri@gmail.com')
# 906. ('Mason', 'Zavala', 'Spain', 'davidlindsey@gmail.com')
# 907. ('Susan', 'Andersen', 'Sweden', 'villajennifer@hudson.info')
# 908. ('Lori', 'Anderson', 'Sweden', 'mwarner@love-villanueva.com')
# 909. ('Michael', 'Andrews', 'Sweden', 'coreytaylor@gmail.com')
# 910. ('James', 'Bailey', 'Sweden', 'eramirez@yahoo.com')
# 911. ('Devin', 'Barnes', 'Sweden', 'tanya05@gmail.com')
# 912. ('William', 'Carr', 'Sweden', 'liuraymond@carter.com')
# 913. ('Robert', 'David', 'Sweden', 'barbara34@hotmail.com')
# 914. ('Zachary', 'Davidson', 'Sweden', 'bethanyhoward@hotmail.com')
# 915. ('Lisa', 'Duffy', 'Sweden', 'hterry@robinson.com')
# 916. ('Steven', 'Fuller', 'Sweden', 'chadgilbert@yahoo.com')
# 917. ('Charles', 'Gonzalez', 'Sweden', 'debrahess@gmail.com')
# 918. ('Keith', 'Griffin', 'Sweden', 'xtaylor@yahoo.com')
# 919. ('Brianna', 'Hamilton', 'Sweden', 'leejames@hotmail.com')
# 920. ('Justin', 'Johns', 'Sweden', 'christinawalker@boyd.info')
# 921. ('Kelly', 'Miles', 'Sweden', 'ynelson@hotmail.com')
# 922. ('Kristopher', 'Miller', 'Sweden', 'williamsmelinda@reynolds.com')
# 923. ('Christy', 'Mitchell', 'Sweden', 'kaitlin69@rodriguez-hill.com')
# 924. ('Jennifer', 'Nash', 'Sweden', 'boltonelizabeth@yahoo.com')
# 925. ('Alicia', 'Padilla', 'Sweden', 'qcox@fischer-townsend.net')
# 926. ('Victor', 'Phelps', 'Sweden', 'ricky93@gmail.com')
# 927. ('Tammy', 'Phillips', 'Sweden', 'charlessharon@yahoo.com')
# 928. ('Anthony', 'Ponce', 'Sweden', 'garciamonica@lopez-burnett.biz')
# 929. ('Jennifer', 'Schwartz', 'Sweden', 'richardparks@hotmail.com')
# 930. ('Abigail', 'Smith', 'Sweden', 'sandovalwilliam@mitchell.org')
# 931. ('Stephanie', 'Snyder', 'Sweden', 'knightmark@ball-li.info')
# 932. ('Steven', 'Swanson', 'Sweden', 'dawnsmall@yahoo.com')
# 933. ('Jacob', 'Thomas', 'Sweden', 'crobinson@craig.net')
# 934. ('Beverly', 'Walker', 'Sweden', 'brittanyli@clark-martin.biz')
# 935. ('Brenda', 'Walker', 'Sweden', 'davisronald@gmail.com')
# 936. ('Kelly', 'Warren', 'Sweden', 'kathleenmarshall@porter.com')
# 937. ('Sarah', 'Williams', 'Sweden', 'kmarsh@mitchell-reyes.com')
# 938. ('Holly', 'Boyer', 'Switzerland', 'judyhamilton@gmail.com')
# 939. ('Kelly', 'Cardenas', 'Switzerland', 'xwillis@johnson.com')
# 940. ('Mary', 'Ellis', 'Switzerland', 'kbell@moore-archer.com')
# 941. ('Travis', 'Harris', 'Switzerland', 'rodneyshannon@pierce.biz')
# 942. ('Michael', 'Martin', 'Switzerland', 'tammybullock@king-brown.com')
# 943. ('Carolyn', 'Mccullough', 'Switzerland', 'johnsonkara@gmail.com')
# 944. ('Joshua', 'Montoya', 'Switzerland', 'carmenwhite@gomez.com')
# 945. ('Stephanie', 'Nelson', 'Switzerland', 'ortizbryan@hotmail.com')
# 946. ('Anthony', 'Olson', 'Switzerland', 'kbauer@sharp.org')
# 947. ('Lisa', 'Parker', 'Switzerland', 'christopher99@gmail.com')
# 948. ('Penny', 'Paul', 'Switzerland', 'angelascott@andrews-trevino.com')
# 949. ('Joseph', 'Perez', 'Switzerland', 'jeremysmith@yahoo.com')
# 950. ('Evan', 'Powell', 'Switzerland', 'wwhite@kemp.com')
# 951. ('Austin', 'Ramirez', 'Switzerland', 'megan25@powell.com')
# 952. ('Jason', 'Sharp', 'Switzerland', 'hrandall@smith.com')
# 953. ('Austin', 'Shelton', 'Switzerland', 'ctate@hotmail.com')
# 954. ('Carolyn', 'Smith', 'Switzerland', 'bradley35@gmail.com')
# 955. ('Lauren', 'Smith', 'Switzerland', 'rlewis@barrett.com')
# 956. ('Susan', 'Stephens', 'Switzerland', 'xburke@hotmail.com')
# 957. ('Danielle', 'Thomas', 'Switzerland', 'coxbrett@golden.com')
# 958. ('Kristina', 'Thompson', 'Switzerland', 'gregoryreyes@yahoo.com')
# 959. ('Angela', 'Vincent', 'Switzerland', 'ngarcia@gmail.com')
# 960. ('Melissa', 'Wilson', 'Switzerland', 'jwoods@gmail.com')
# 961. ('Michael', 'Wilson', 'Switzerland', 'brenda91@kennedy-daniels.com')
# 962. ('Michele', 'Beck', 'USA', 'mary98@hotmail.com')
# 963. ('Heather', 'Bradley', 'USA', 'stephanie03@morales.org')
# 964. ('Holly', 'Carroll', 'USA', 'fbutler@torres.net')
# 965. ('Jennifer', 'Cooper', 'USA', 'karen20@watson.com')
# 966. ('Kristie', 'Cross', 'USA', 'zachary29@lambert-martinez.com')
# 967. ('Kelly', 'Dunn', 'USA', 'kyle86@yahoo.com')
# 968. ('Natasha', 'Evans', 'USA', 'edaugherty@yahoo.com')
# 969. ('Cheyenne', 'Fletcher', 'USA', 'emilygarner@yahoo.com')
# 970. ('James', 'Friedman', 'USA', 'grios@eaton.com')
# 971. ('Edward', 'Goodman', 'USA', 'guydudley@bennett-harris.com')
# 972. ('Jason', 'Grant', 'USA', 'marshnathan@gmail.com')
# 973. ('Nicholas', 'Gray', 'USA', 'jasonryan@yahoo.com')
# 974. ('Deborah', 'Hill', 'USA', 'christinajohnson@payne.net')
# 975. ('Alicia', 'Ibarra', 'USA', 'martinanthony@gmail.com')
# 976. ('Dominique', 'Jones', 'USA', 'aprilsmith@daniels.net')
# 977. ('Linda', 'Jones', 'USA', 'toniperez@yahoo.com')
# 978. ('Ashley', 'Koch', 'USA', 'mbrooks@nelson.info')
# 979. ('Holly', 'Martinez', 'USA', 'danieljohnson@stokes.com')
# 980. ('Courtney', 'Meza', 'USA', 'sarah08@gmail.com')
# 981. ('Matthew', 'Miranda', 'USA', 'cgiles@gmail.com')
# 982. ('Hunter', 'Moore', 'USA', 'micheallong@smith.info')
# 983. ('Andrew', 'Nguyen', 'USA', 'gregory15@garcia-smith.com')
# 984. ('Angela', 'Preston', 'USA', 'saundersjulie@hotmail.com')
# 985. ('Jean', 'Ramirez', 'USA', 'vargassandra@sexton.com')
# 986. ('William', 'Randall', 'USA', 'wilsonderek@gmail.com')
# 987. ('Alexander', 'Robinson', 'USA', 'tyler03@lewis.net')
# 988. ('Vernon', 'Simpson', 'USA', 'tallen@thompson.com')
# 989. ('Martin', 'Smith', 'USA', 'blackburnrichard@reynolds.org')
# 990. ('Jeffrey', 'Soto', 'USA', 'robinwatts@porter.net')
# 991. ('Lisa', 'Terrell', 'USA', 'agolden@hotmail.com')
# 992. ('John', 'Torres', 'USA', 'hector44@manning.com')
# 993. ('William', 'Tran', 'USA', 'igolden@yahoo.com')
# 994. ('Peter', 'Wade', 'USA', 'lopezjoseph@yahoo.com')
# 995. ('Tiffany', 'Walker', 'USA', 'elizabeth61@yahoo.com')
# 996. ('Jesse', 'Wallace', 'USA', 'joseph47@yahoo.com')
# 997. ('Jason', 'White', 'USA', 'bjoseph@watkins.com')
# 998. ('Stacey', 'Anderson', 'United Kingdom', 'patricia72@yahoo.com')
# 999. ('Devin', 'Bailey', 'United Kingdom', 'maureen76@reynolds.info')
# 1000. ('Justin', 'Barry', 'United Kingdom', 'susanruiz@hotmail.com')
# 1001. ('Charles', 'Bishop', 'United Kingdom', 'joshualewis@gmail.com')
# 1002. ('Melissa', 'Cook', 'United Kingdom', 'eevans@yahoo.com')
# 1003. ('Mark', 'Duran', 'United Kingdom', 'wendyshelton@gmail.com')
# 1004. ('Tim', 'Gamble', 'United Kingdom', 'john43@hotmail.com')
# 1005. ('Valerie', 'Garcia', 'United Kingdom', 'mathew39@elliott.info')
# 1006. ('Julie', 'Graves', 'United Kingdom', 'jeffrey93@keller.org')
# 1007. ('Tracy', 'Griffith', 'United Kingdom', 'jessica84@garcia.com')
# 1008. ('Tanner', 'Gross', 'United Kingdom', 'wisekenneth@raymond.info')
# 1009. ('Denise', 'Hahn', 'United Kingdom', 'srodriguez@reyes.com')
# 1010. ('Noah', 'Hayes', 'United Kingdom', 'hkline@yahoo.com')
# 1011. ('Richard', 'Hernandez', 'United Kingdom', 'benjamin22@gmail.com')
# 1012. ('Benjamin', 'Holden', 'United Kingdom', 'monicasmith@johnson.com')
# 1013. ('Jose', 'Jackson', 'United Kingdom', 'gonzalezmaria@yahoo.com')
# 1014. ('William', 'James', 'United Kingdom', 'ufields@aguirre-holmes.com')
# 1015. ('Ashley', 'Johnson', 'United Kingdom', 'ojohnson@gray.biz')
# 1016. ('Michael', 'Jones', 'United Kingdom', 'uconley@hines.biz')
# 1017. ('Jill', 'Lee', 'United Kingdom', 'kjimenez@alexander.com')
# 1018. ('Doris', 'Long', 'United Kingdom', 'jessicamartin@hotmail.com')
# 1019. ('Brian', 'Lozano', 'United Kingdom', 'carolyn42@meyer.com')
# 1020. ('George', 'Miller', 'United Kingdom', 'robinsonandrea@espinoza.info')
# 1021. ('Joseph', 'Morgan', 'United Kingdom', 'michelle07@hotmail.com')
# 1022. ('Christopher', 'Oliver', 'United Kingdom', 'samuel11@hotmail.com')
# 1023. ('Eric', 'Ortiz', 'United Kingdom', 'benjamin99@yahoo.com')
# 1024. ('David', 'Petersen', 'United Kingdom', 'moniquepetersen@durham.com')
# 1025. ('Phillip', 'Rios', 'United Kingdom', 'dclarke@gmail.com')
# 1026. ('Lauren', 'Rose', 'United Kingdom', 'littlecameron@kelly.com')
# 1027. ('Ryan', 'Sharp', 'United Kingdom', 'matthew40@smith.com')
# 1028. ('Kayla', 'Simmons', 'United Kingdom', 'jennifer71@hotmail.com')
# 1029. ('Nancy', 'Stone', 'United Kingdom', 'nwhite@jordan-lopez.info')
# 1030. ('Derrick', 'Taylor', 'United Kingdom', 'lewismegan@richards-gutierrez.net')
# 1031. ('Jason', 'Taylor', 'United Kingdom', 'carlbishop@simpson.com')
# 1032. ('Karen', 'Taylor', 'United Kingdom', 'joshuascott@hotmail.com')
# 1033. ('Tamara', 'Walker', 'United Kingdom', 'meredithelliott@yahoo.com')
# 1034. ('Lucas', 'West', 'United Kingdom', 'smithelizabeth@williams.org')

# %% [markdown]
# **Note:** In the query above, the output is ordered by Country and then last and first name.

# %% [markdown]
# ### DISTINCT
# This clause is used to remove duplicates in the result. It appears immediately after `SELECT` followed by a column name or a list of columns. If only one column is specified only the values on that column is used to identify duplicates. If multiple columns are specified, the combination of them will be used to identify duplicates.
# <code>
# SELECT DISTINCT {column}
# FROM {table};
# </code>

# %%
query='''
SELECT DISTINCT City
FROM Customers
ORDER BY City;
'''
execute_query(conn,query)
# Out:
# 1. ('Adamberg',)
# 2. ('Adamport',)
# 3. ('Alexanderberg',)
# 4. ('Alexanderbury',)
# 5. ('Alexandraville',)
# 6. ('Aliciaton',)
# 7. ('Allenport',)
# 8. ('Allenview',)
# 9. ('Allisonfurt',)
# 10. ('Allisonview',)
# 11. ('Amandaside',)
# 12. ('Amandaville',)
# 13. ('Amymouth',)
# 14. ('Andersonfurt',)
# 15. ('Andreahaven',)
# 16. ('Andrewsmouth',)
# 17. ('Angelafurt',)
# 18. ('Angelamouth',)
# 19. ('Angelastad',)
# 20. ('Angelaview',)
# 21. ('Anitamouth',)
# 22. ('Anitaview',)
# 23. ('Anthonystad',)
# 24. ('Arellanotown',)
# 25. ('Arroyofort',)
# 26. ('Ashleyborough',)
# 27. ('Ashleymouth',)
# 28. ('Ashleytown',)
# 29. ('Atkinsontown',)
# 30. ('Austinhaven',)
# 31. ('Austinmouth',)
# 32. ('Ayalafort',)
# 33. ('Ayalatown',)
# 34. ('Baileybury',)
# 35. ('Bakerbury',)
# 36. ('Bakerhaven',)
# 37. ('Bakertown',)
# 38. ('Ballardville',)
# 39. ('Barberfort',)
# 40. ('Barnettberg',)
# 41. ('Barrystad',)
# 42. ('Bartlettborough',)
# 43. ('Bartlettmouth',)
# 44. ('Beasleyburgh',)
# 45. ('Beckville',)
# 46. ('Bellmouth',)
# 47. ('Benitezbury',)
# 48. ('Benjaminshire',)
# 49. ('Berryport',)
# 50. ('Bethanymouth',)
# 51. ('Blairville',)
# 52. ('Bobbyhaven',)
# 53. ('Bobbyland',)
# 54. ('Bonniehaven',)
# 55. ('Bowenmouth',)
# 56. ('Branchland',)
# 57. ('Brandyborough',)
# 58. ('Brayland',)
# 59. ('Brendaview',)
# 60. ('Brentburgh',)
# 61. ('Brettchester',)
# 62. ('Brianbury',)
# 63. ('Brianland',)
# 64. ('Brianmouth',)
# 65. ('Bridgetchester',)
# 66. ('Brooketon',)
# 67. ('Brownborough',)
# 68. ('Brownchester',)
# 69. ('Brownfurt',)
# 70. ('Brownton',)
# 71. ('Butlershire',)
# 72. ('Calderonbury',)
# 73. ('Calderonton',)
# 74. ('Campbellville',)
# 75. ('Candaceville',)
# 76. ('Carlosshire',)
# 77. ('Carlsonburgh',)
# 78. ('Carpenterborough',)
# 79. ('Carrland',)
# 80. ('Carrollchester',)
# 81. ('Carterfort',)
# 82. ('Cartermouth',)
# 83. ('Caseyfurt',)
# 84. ('Chadtown',)
# 85. ('Chanside',)
# 86. ('Charlesshire',)
# 87. ('Chasefurt',)
# 88. ('Cherylmouth',)
# 89. ('Christieshire',)
# 90. ('Christinamouth',)
# 91. ('Christineview',)
# 92. ('Christopherborough',)
# 93. ('Christopherland',)
# 94. ('Christopherside',)
# 95. ('Cindymouth',)
# 96. ('Clarkmouth',)
# 97. ('Cobbstad',)
# 98. ('Codyburgh',)
# 99. ('Coleberg',)
# 100. ('Colonton',)
# 101. ('Cooperside',)
# 102. ('Cooperstad',)
# 103. ('Cowanside',)
# 104. ('Crawfordtown',)
# 105. ('Crosbyport',)
# 106. ('Cruzchester',)
# 107. ('Cynthiastad',)
# 108. ('Danielburgh',)
# 109. ('Danielleburgh',)
# 110. ('Daniellestad',)
# 111. ('Danielport',)
# 112. ('Danielstad',)
# 113. ('Danielville',)
# 114. ('Dannyville',)
# 115. ('Davidmouth',)
# 116. ('Davidsonfort',)
# 117. ('Davidton',)
# 118. ('Davidview',)
# 119. ('Davisburgh',)
# 120. ('Davisfurt',)
# 121. ('Daviston',)
# 122. ('Davisville',)
# 123. ('Dawnfurt',)
# 124. ('Deleonbury',)
# 125. ('Deleonton',)
# 126. ('Delgadostad',)
# 127. ('Derekport',)
# 128. ('Desireefurt',)
# 129. ('Diamondside',)
# 130. ('Diazmouth',)
# 131. ('Dickersonside',)
# 132. ('Dodsonville',)
# 133. ('Dominguezstad',)
# 134. ('Donaldfort',)
# 135. ('Doyleside',)
# 136. ('Duncanburgh',)
# 137. ('Dyerfort',)
# 138. ('Dyermouth',)
# 139. ('East Adriennefort',)
# 140. ('East Alexandertown',)
# 141. ('East Aliciamouth',)
# 142. ('East Anthony',)
# 143. ('East Ashley',)
# 144. ('East Brendaton',)
# 145. ('East Chad',)
# 146. ('East Charles',)
# 147. ('East Charlesbury',)
# 148. ('East Christopher',)
# 149. ('East Christopherport',)
# 150. ('East Cynthiaview',)
# 151. ('East Daleport',)
# 152. ('East Daniel',)
# 153. ('East Danielle',)
# 154. ('East Elizabethport',)
# 155. ('East Emilyfurt',)
# 156. ('East Ericville',)
# 157. ('East Frederick',)
# 158. ('East Ian',)
# 159. ('East Jake',)
# 160. ('East James',)
# 161. ('East Jeffrey',)
# 162. ('East Jennifer',)
# 163. ('East Johnny',)
# 164. ('East Joycefurt',)
# 165. ('East Juanfort',)
# 166. ('East Justin',)
# 167. ('East Kathrynmouth',)
# 168. ('East Kellyview',)
# 169. ('East Kenneth',)
# 170. ('East Kevin',)
# 171. ('East Kevinburgh',)
# 172. ('East Lawrence',)
# 173. ('East Mario',)
# 174. ('East Martin',)
# 175. ('East Melissafurt',)
# 176. ('East Melissaland',)
# 177. ('East Michael',)
# 178. ('East Michaelton',)
# 179. ('East Natalie',)
# 180. ('East Nathan',)
# 181. ('East Nicolebury',)
# 182. ('East Phillipton',)
# 183. ('East Raymondport',)
# 184. ('East Reginald',)
# 185. ('East Robert',)
# 186. ('East Sharonborough',)
# 187. ('East Stephaniemouth',)
# 188. ('East Stevenmouth',)
# 189. ('East Terrihaven',)
# 190. ('East Theodore',)
# 191. ('East Thomasbury',)
# 192. ('East Timothy',)
# 193. ('East Tina',)
# 194. ('East Trevorside',)
# 195. ('East Tylershire',)
# 196. ('East Tyrone',)
# 197. ('East Wesleychester',)
# 198. ('Edwardsport',)
# 199. ('Eileenton',)
# 200. ('Elizabethborough',)
# 201. ('Elizabethside',)
# 202. ('Elliottfurt',)
# 203. ('Elliotthaven',)
# 204. ('Ellisport',)
# 205. ('Emmaborough',)
# 206. ('Ericport',)
# 207. ('Erikmouth',)
# 208. ('Evansborough',)
# 209. ('Fernandezstad',)
# 210. ('Fischerland',)
# 211. ('Fletcherhaven',)
# 212. ('Floresside',)
# 213. ('Florestown',)
# 214. ('Fordport',)
# 215. ('Francisfurt',)
# 216. ('Franklinborough',)
# 217. ('Frederickland',)
# 218. ('Frederickmouth',)
# 219. ('Freemantown',)
# 220. ('Fuenteschester',)
# 221. ('Garciashire',)
# 222. ('Garrettchester',)
# 223. ('Gilbertbury',)
# 224. ('Gonzalezburgh',)
# 225. ('Gonzalezchester',)
# 226. ('Gonzalezton',)
# 227. ('Gonzalezview',)
# 228. ('Grayburgh',)
# 229. ('Greeneview',)
# 230. ('Greerborough',)
# 231. ('Gregoryberg',)
# 232. ('Griffithville',)
# 233. ('Gutierrezhaven',)
# 234. ('Guzmanchester',)
# 235. ('Hahnborough',)
# 236. ('Hallfort',)
# 237. ('Hamiltonborough',)
# 238. ('Hansenmouth',)
# 239. ('Harmonton',)
# 240. ('Harperport',)
# 241. ('Harrisberg',)
# 242. ('Harrisburgh',)
# 243. ('Harrisonshire',)
# 244. ('Hayesbury',)
# 245. ('Heathborough',)
# 246. ('Heatherberg',)
# 247. ('Heatherfurt',)
# 248. ('Heathertown',)
# 249. ('Henrymouth',)
# 250. ('Hernandezbury',)
# 251. ('Hernandezport',)
# 252. ('Hernandezstad',)
# 253. ('Hessmouth',)
# 254. ('Hicksland',)
# 255. ('Hillstad',)
# 256. ('Hintonfurt',)
# 257. ('Hoborough',)
# 258. ('Hopkinsbury',)
# 259. ('Hopkinsside',)
# 260. ('Housebury',)
# 261. ('Houstonborough',)
# 262. ('Howardbury',)
# 263. ('Howardland',)
# 264. ('Huntertown',)
# 265. ('Huntton',)
# 266. ('Jacksonmouth',)
# 267. ('Jacobsonfort',)
# 268. ('Jamesland',)
# 269. ('Jamesmouth',)
# 270. ('Jamiechester',)
# 271. ('Jamiehaven',)
# 272. ('Jamieside',)
# 273. ('Jamiestad',)
# 274. ('Janetchester',)
# 275. ('Jasonmouth',)
# 276. ('Jasonview',)
# 277. ('Jayport',)
# 278. ('Jeffreyburgh',)
# 279. ('Jeffreyhaven',)
# 280. ('Jenkinsshire',)
# 281. ('Jenniferhaven',)
# 282. ('Jennifermouth',)
# 283. ('Jenniferstad',)
# 284. ('Jenniferton',)
# 285. ('Jensenburgh',)
# 286. ('Jensenbury',)
# 287. ('Jessicaberg',)
# 288. ('Jessicaburgh',)
# 289. ('Jimenezberg',)
# 290. ('Johnland',)
# 291. ('Johnmouth',)
# 292. ('Johnsonport',)
# 293. ('Johnstad',)
# 294. ('Johntown',)
# 295. ('Jonathanview',)
# 296. ('Joneshaven',)
# 297. ('Josephville',)
# 298. ('Joseview',)
# 299. ('Juanfort',)
# 300. ('Juliaport',)
# 301. ('Julieton',)
# 302. ('Justinhaven',)
# 303. ('Justinview',)
# 304. ('Kaitlynville',)
# 305. ('Kanemouth',)
# 306. ('Karenburgh',)
# 307. ('Katelynmouth',)
# 308. ('Katherineton',)
# 309. ('Katherineville',)
# 310. ('Kellyhaven',)
# 311. ('Kellymouth',)
# 312. ('Kempberg',)
# 313. ('Kendraside',)
# 314. ('Kennedymouth',)
# 315. ('Kennethstad',)
# 316. ('Kentside',)
# 317. ('Kevinberg',)
# 318. ('Kevinfort',)
# 319. ('Kevinland',)
# 320. ('Kevinmouth',)
# 321. ('Kevinstad',)
# 322. ('Kimberlyport',)
# 323. ('Kimberlyshire',)
# 324. ('Kingmouth',)
# 325. ('Kingview',)
# 326. ('Knighttown',)
# 327. ('Kramerborough',)
# 328. ('Kristaside',)
# 329. ('Kristyview',)
# 330. ('Kyleburgh',)
# 331. ('Lake Adrian',)
# 332. ('Lake Alan',)
# 333. ('Lake Albertview',)
# 334. ('Lake Alexandria',)
# 335. ('Lake Amber',)
# 336. ('Lake Amy',)
# 337. ('Lake Amychester',)
# 338. ('Lake Andrea',)
# 339. ('Lake Anneton',)
# 340. ('Lake Anthony',)
# 341. ('Lake April',)
# 342. ('Lake Becky',)
# 343. ('Lake Belindatown',)
# 344. ('Lake Brianland',)
# 345. ('Lake Carlos',)
# 346. ('Lake Chelseaberg',)
# 347. ('Lake Chris',)
# 348. ('Lake Christopher',)
# 349. ('Lake Danielhaven',)
# 350. ('Lake Danielside',)
# 351. ('Lake Danieltown',)
# 352. ('Lake David',)
# 353. ('Lake Davidmouth',)
# 354. ('Lake Davidport',)
# 355. ('Lake Erikaland',)
# 356. ('Lake Evan',)
# 357. ('Lake Evelynmouth',)
# 358. ('Lake Grant',)
# 359. ('Lake Hannahview',)
# 360. ('Lake Jamie',)
# 361. ('Lake Jasmineville',)
# 362. ('Lake Jenniferfurt',)
# 363. ('Lake Johntown',)
# 364. ('Lake Jonathan',)
# 365. ('Lake Joseph',)
# 366. ('Lake Josephstad',)
# 367. ('Lake Karen',)
# 368. ('Lake Kathleen',)
# 369. ('Lake Kathrynmouth',)
# 370. ('Lake Kenneth',)
# 371. ('Lake Kristin',)
# 372. ('Lake Leeton',)
# 373. ('Lake Marilyn',)
# 374. ('Lake Mary',)
# 375. ('Lake Maryberg',)
# 376. ('Lake Matthewhaven',)
# 377. ('Lake Melissa',)
# 378. ('Lake Melissaside',)
# 379. ('Lake Nancy',)
# 380. ('Lake Nicholas',)
# 381. ('Lake Patrick',)
# 382. ('Lake Rebeccafort',)
# 383. ('Lake Reginaport',)
# 384. ('Lake Reginaville',)
# 385. ('Lake Robert',)
# 386. ('Lake Roger',)
# 387. ('Lake Ronald',)
# 388. ('Lake Sarah',)
# 389. ('Lake Scottview',)
# 390. ('Lake Steven',)
# 391. ('Lake Stevenburgh',)
# 392. ('Lake Suzanne',)
# 393. ('Lake Teresabury',)
# 394. ('Lake Tiffany',)
# 395. ('Lake Timothyborough',)
# 396. ('Lake Timothyton',)
# 397. ('Lake Victoria',)
# 398. ('Lake Victorland',)
# 399. ('Lake Zacharyborough',)
# 400. ('Lake Zacharyhaven',)
# 401. ('Lancebury',)
# 402. ('Langchester',)
# 403. ('Laurastad',)
# 404. ('Lauraton',)
# 405. ('Lauratown',)
# 406. ('Lauraview',)
# 407. ('Laurieview',)
# 408. ('Lawrenceberg',)
# 409. ('Leblancmouth',)
# 410. ('Lebury',)
# 411. ('Lechester',)
# 412. ('Leebury',)
# 413. ('Leefurt',)
# 414. ('Lesliefort',)
# 415. ('Lewisport',)
# 416. ('Lisaburgh',)
# 417. ('Lisabury',)
# 418. ('Lisafurt',)
# 419. ('Lisastad',)
# 420. ('Livingstonville',)
# 421. ('Lopezmouth',)
# 422. ('Lopezshire',)
# 423. ('Lucasshire',)
# 424. ('Lyonsshire',)
# 425. ('Mackfurt',)
# 426. ('Macktown',)
# 427. ('Maddenstad',)
# 428. ('Manuelhaven',)
# 429. ('Markland',)
# 430. ('Markmouth',)
# 431. ('Markport',)
# 432. ('Markshaven',)
# 433. ('Marquezton',)
# 434. ('Marshallton',)
# 435. ('Martinezberg',)
# 436. ('Martinezburgh',)
# 437. ('Martinstad',)
# 438. ('Marvinbury',)
# 439. ('Masonmouth',)
# 440. ('Mathewhaven',)
# 441. ('Mathewstown',)
# 442. ('Matthewmouth',)
# 443. ('Matthewsshire',)
# 444. ('Maymouth',)
# 445. ('Mcdanielmouth',)
# 446. ('Mcintyretown',)
# 447. ('Mcintyreview',)
# 448. ('Mckeebury',)
# 449. ('Meadowsport',)
# 450. ('Melanieville',)
# 451. ('Melindafort',)
# 452. ('Melissaland',)
# 453. ('Melissamouth',)
# 454. ('Melissaside',)
# 455. ('Mendezside',)
# 456. ('Meyerston',)
# 457. ('Michaelborough',)
# 458. ('Michaelchester',)
# 459. ('Michaelmouth',)
# 460. ('Michaelside',)
# 461. ('Micheleberg',)
# 462. ('Michelleberg',)
# 463. ('Michelleport',)
# 464. ('Michelleshire',)
# 465. ('Michellestad',)
# 466. ('Michelleview',)
# 467. ('Miguelville',)
# 468. ('Millerburgh',)
# 469. ('Millerfort',)
# 470. ('Millsmouth',)
# 471. ('Mitchelltown',)
# 472. ('Montgomeryshire',)
# 473. ('Mooreland',)
# 474. ('Mooremouth',)
# 475. ('Morganville',)
# 476. ('Mosshaven',)
# 477. ('Muellertown',)
# 478. ('Murphyport',)
# 479. ('Murrayfort',)
# 480. ('Nathanielmouth',)
# 481. ('Nelsonland',)
# 482. ('New Amy',)
# 483. ('New Amyberg',)
# 484. ('New Andrew',)
# 485. ('New Anthonyburgh',)
# 486. ('New Anthonyshire',)
# 487. ('New April',)
# 488. ('New Audrey',)
# 489. ('New Bryanberg',)
# 490. ('New Caitlinbury',)
# 491. ('New Carolyn',)
# 492. ('New Christopher',)
# 493. ('New Cody',)
# 494. ('New Coreyfurt',)
# 495. ('New Crystalview',)
# 496. ('New Daniel',)
# 497. ('New Danielle',)
# 498. ('New Dannybury',)
# 499. ('New Dannyland',)
# 500. ('New David',)
# 501. ('New Davidfurt',)
# 502. ('New Davidhaven',)
# 503. ('New Eddie',)
# 504. ('New Edwardberg',)
# 505. ('New Elizabethbury',)
# 506. ('New Elizabethmouth',)
# 507. ('New Ellenmouth',)
# 508. ('New Erika',)
# 509. ('New Evelyn',)
# 510. ('New Jameshaven',)
# 511. ('New Jamesshire',)
# 512. ('New Jaredmouth',)
# 513. ('New Jasonborough',)
# 514. ('New Jeanneborough',)
# 515. ('New Jessicaburgh',)
# 516. ('New Jessicahaven',)
# 517. ('New Jillstad',)
# 518. ('New Johnstad',)
# 519. ('New Jose',)
# 520. ('New Joshuaton',)
# 521. ('New Joycefort',)
# 522. ('New Judytown',)
# 523. ('New Lauraside',)
# 524. ('New Lauraville',)
# 525. ('New Meganborough',)
# 526. ('New Melanie',)
# 527. ('New Michael',)
# 528. ('New Michelle',)
# 529. ('New Michellemouth',)
# 530. ('New Monica',)
# 531. ('New Natasha',)
# 532. ('New Paulhaven',)
# 533. ('New Reneeside',)
# 534. ('New Rodney',)
# 535. ('New Rodneyview',)
# 536. ('New Rogerstad',)
# 537. ('New Ryanstad',)
# 538. ('New Samanthaton',)
# 539. ('New Seanville',)
# 540. ('New Sharon',)
# 541. ('New Stephanie',)
# 542. ('New Stephen',)
# 543. ('New Tanya',)
# 544. ('New Theresa',)
# 545. ('New Thomas',)
# 546. ('New Tiffany',)
# 547. ('New Timothy',)
# 548. ('New Tracyberg',)
# 549. ('New Trevorfurt',)
# 550. ('New Vanessastad',)
# 551. ('Nguyenhaven',)
# 552. ('Nicolefurt',)
# 553. ('Nicolemouth',)
# 554. ('Normaville',)
# 555. ('Norrisview',)
# 556. ('North Aaronport',)
# 557. ('North Aaronside',)
# 558. ('North Alanland',)
# 559. ('North Alexandria',)
# 560. ('North Amberfurt',)
# 561. ('North Amy',)
# 562. ('North Amyton',)
# 563. ('North Annette',)
# 564. ('North Arthurview',)
# 565. ('North Ashley',)
# 566. ('North Austin',)
# 567. ('North Beth',)
# 568. ('North Brettfort',)
# 569. ('North Cassandrafurt',)
# 570. ('North Chelsea',)
# 571. ('North Christina',)
# 572. ('North Christopherstad',)
# 573. ('North Christopherville',)
# 574. ('North Danielbury',)
# 575. ('North Danielleborough',)
# 576. ('North David',)
# 577. ('North Davidberg',)
# 578. ('North Deborahshire',)
# 579. ('North Donna',)
# 580. ('North Emily',)
# 581. ('North Erinside',)
# 582. ('North Francisco',)
# 583. ('North Haley',)
# 584. ('North Helenfurt',)
# 585. ('North Hollystad',)
# 586. ('North Jamesfurt',)
# 587. ('North Janehaven',)
# 588. ('North Jaredfort',)
# 589. ('North Jason',)
# 590. ('North Jasonton',)
# 591. ('North Jenniferhaven',)
# 592. ('North Jerometown',)
# 593. ('North Jessica',)
# 594. ('North Johnville',)
# 595. ('North Jonathanfurt',)
# 596. ('North Jordanfurt',)
# 597. ('North Jorgeberg',)
# 598. ('North Karen',)
# 599. ('North Karenland',)
# 600. ('North Katelyn',)
# 601. ('North Kennethfurt',)
# 602. ('North Kevinville',)
# 603. ('North Laura',)
# 604. ('North Lawrencebury',)
# 605. ('North Linda',)
# 606. ('North Marcshire',)
# 607. ('North Marcus',)
# 608. ('North Mariahville',)
# 609. ('North Mark',)
# 610. ('North Matthew',)
# 611. ('North Megan',)
# 612. ('North Meganstad',)
# 613. ('North Melissastad',)
# 614. ('North Michael',)
# 615. ('North Michele',)
# 616. ('North Michellestad',)
# 617. ('North Migueltown',)
# 618. ('North Monicamouth',)
# 619. ('North Nicholasville',)
# 620. ('North Nicolehaven',)
# 621. ('North Raymondbury',)
# 622. ('North Richard',)
# 623. ('North Robert',)
# 624. ('North Robinview',)
# 625. ('North Ronald',)
# 626. ('North Sarahland',)
# 627. ('North Sarahport',)
# 628. ('North Scott',)
# 629. ('North Shannonmouth',)
# 630. ('North Sharon',)
# 631. ('North Stephanieville',)
# 632. ('North Stephen',)
# 633. ('North Tinashire',)
# 634. ('North William',)
# 635. ('Obrienberg',)
# 636. ('Obrienview',)
# 637. ('Oneillchester',)
# 638. ('Palmermouth',)
# 639. ('Pamelaton',)
# 640. ('Parkermouth',)
# 641. ('Parsonsmouth',)
# 642. ('Patrickfurt',)
# 643. ('Pattonhaven',)
# 644. ('Payneland',)
# 645. ('Penabury',)
# 646. ('Perezmouth',)
# 647. ('Perkinstown',)
# 648. ('Petersonside',)
# 649. ('Pettyhaven',)
# 650. ('Port Aaron',)
# 651. ('Port Amyview',)
# 652. ('Port Andrew',)
# 653. ('Port Andrewfort',)
# 654. ('Port Annberg',)
# 655. ('Port Anthonyville',)
# 656. ('Port Ashleemouth',)
# 657. ('Port Ashley',)
# 658. ('Port Brandon',)
# 659. ('Port Brucefort',)
# 660. ('Port Chadhaven',)
# 661. ('Port Cheryl',)
# 662. ('Port Christinefurt',)
# 663. ('Port Christopherburgh',)
# 664. ('Port Cynthia',)
# 665. ('Port Dakotafort',)
# 666. ('Port Dana',)
# 667. ('Port Daniel',)
# 668. ('Port Danielleborough',)
# 669. ('Port Danielville',)
# 670. ('Port Debbieland',)
# 671. ('Port Denisetown',)
# 672. ('Port Dillon',)
# 673. ('Port Donaldmouth',)
# 674. ('Port Edwardside',)
# 675. ('Port Edwin',)
# 676. ('Port Eric',)
# 677. ('Port Erik',)
# 678. ('Port Erin',)
# 679. ('Port Erintown',)
# 680. ('Port Ethanbury',)
# 681. ('Port Faithport',)
# 682. ('Port Gregoryport',)
# 683. ('Port Jenniferville',)
# 684. ('Port Jerry',)
# 685. ('Port Jessica',)
# 686. ('Port Jessicahaven',)
# 687. ('Port John',)
# 688. ('Port Johnbury',)
# 689. ('Port Jonathan',)
# 690. ('Port Julie',)
# 691. ('Port Karenbury',)
# 692. ('Port Kimberlychester',)
# 693. ('Port Kylefurt',)
# 694. ('Port Laurieborough',)
# 695. ('Port Lindabury',)
# 696. ('Port Lisaberg',)
# 697. ('Port Lisafort',)
# 698. ('Port Lisahaven',)
# 699. ('Port Lynnburgh',)
# 700. ('Port Manuel',)
# 701. ('Port Matthewstad',)
# 702. ('Port Melaniebury',)
# 703. ('Port Melissa',)
# 704. ('Port Michaelshire',)
# 705. ('Port Michaelview',)
# 706. ('Port Michealmouth',)
# 707. ('Port Nicholas',)
# 708. ('Port Nicholasport',)
# 709. ('Port Rebeccachester',)
# 710. ('Port Robin',)
# 711. ('Port Roger',)
# 712. ('Port Samantha',)
# 713. ('Port Samuelstad',)
# 714. ('Port Sarahview',)
# 715. ('Port Saramouth',)
# 716. ('Port Scott',)
# 717. ('Port Sherrimouth',)
# 718. ('Port Sierra',)
# 719. ('Port Taylor',)
# 720. ('Port Thomasstad',)
# 721. ('Port Travismouth',)
# 722. ('Port Vanessafurt',)
# 723. ('Port Victor',)
# 724. ('Port Williamhaven',)
# 725. ('Portermouth',)
# 726. ('Powellchester',)
# 727. ('Rayhaven',)
# 728. ('Raymondborough',)
# 729. ('Raymondmouth',)
# 730. ('Rebeccaburgh',)
# 731. ('Rebeccachester',)
# 732. ('Reedland',)
# 733. ('Reedville',)
# 734. ('Reyesmouth',)
# 735. ('Reynoldsfurt',)
# 736. ('Richardchester',)
# 737. ('Richardsonbury',)
# 738. ('Riveratown',)
# 739. ('Robertberg',)
# 740. ('Robertmouth',)
# 741. ('Robertport',)
# 742. ('Robertsbury',)
# 743. ('Robertside',)
# 744. ('Roberttown',)
# 745. ('Robinburgh',)
# 746. ('Robinmouth',)
# 747. ('Roblestown',)
# 748. ('Rogersview',)
# 749. ('Ronaldbury',)
# 750. ('Ronaldmouth',)
# 751. ('Royborough',)
# 752. ('Ryanchester',)
# 753. ('Ryanfort',)
# 754. ('Ryantown',)
# 755. ('Ryanview',)
# 756. ('Sabrinabury',)
# 757. ('Salazarbury',)
# 758. ('Sanchezmouth',)
# 759. ('Sanfordstad',)
# 760. ('Saraburgh',)
# 761. ('Sarahbury',)
# 762. ('Scottburgh',)
# 763. ('Scottstad',)
# 764. ('Seanfurt',)
# 765. ('Shafferville',)
# 766. ('Sharonport',)
# 767. ('Shawntown',)
# 768. ('Shellyfurt',)
# 769. ('Sherryland',)
# 770. ('Sherryview',)
# 771. ('Simmonstown',)
# 772. ('Smithborough',)
# 773. ('Smithfort',)
# 774. ('Smithland',)
# 775. ('Smithport',)
# 776. ('Smithside',)
# 777. ('Smithstad',)
# 778. ('Smithtown',)
# 779. ('Solisborough',)
# 780. ('South Alexandraland',)
# 781. ('South Amanda',)
# 782. ('South Amandamouth',)
# 783. ('South Andrea',)
# 784. ('South Anne',)
# 785. ('South Ashley',)
# 786. ('South Blakeberg',)
# 787. ('South Bradleyland',)
# 788. ('South Brandiport',)
# 789. ('South Brettville',)
# 790. ('South Brianberg',)
# 791. ('South Brianburgh',)
# 792. ('South Chadhaven',)
# 793. ('South Cheryl',)
# 794. ('South Christopher',)
# 795. ('South Craig',)
# 796. ('South Crystal',)
# 797. ('South Crystalmouth',)
# 798. ('South Daisy',)
# 799. ('South Dariusbury',)
# 800. ('South Davidfurt',)
# 801. ('South Davidmouth',)
# 802. ('South Erin',)
# 803. ('South Frank',)
# 804. ('South Gina',)
# 805. ('South Gloria',)
# 806. ('South Henry',)
# 807. ('South Jacobtown',)
# 808. ('South Jacqueline',)
# 809. ('South Jeffrey',)
# 810. ('South Jeffreyfurt',)
# 811. ('South Jeremyborough',)
# 812. ('South Jeremytown',)
# 813. ('South Jessica',)
# 814. ('South John',)
# 815. ('South Jordan',)
# 816. ('South Juanberg',)
# 817. ('South Judy',)
# 818. ('South Julie',)
# 819. ('South Kathryn',)
# 820. ('South Katieton',)
# 821. ('South Kerri',)
# 822. ('South Kim',)
# 823. ('South Kyle',)
# 824. ('South Kylestad',)
# 825. ('South Lawrenceton',)
# 826. ('South Lisa',)
# 827. ('South Marcusbury',)
# 828. ('South Mark',)
# 829. ('South Markburgh',)
# 830. ('South Markview',)
# 831. ('South Mary',)
# 832. ('South Mathewborough',)
# 833. ('South Michael',)
# 834. ('South Michaelchester',)
# 835. ('South Michaelfurt',)
# 836. ('South Nicholas',)
# 837. ('South Paul',)
# 838. ('South Raymondburgh',)
# 839. ('South Robertabury',)
# 840. ('South Russell',)
# 841. ('South Samanthafurt',)
# 842. ('South Samanthaton',)
# 843. ('South Sandra',)
# 844. ('South Sarah',)
# 845. ('South Sharonshire',)
# 846. ('South Stephanie',)
# 847. ('South Steven',)
# 848. ('South Tamara',)
# 849. ('South Tammy',)
# 850. ('South Teresafort',)
# 851. ('South Terri',)
# 852. ('South Vanessafort',)
# 853. ('South Williamland',)
# 854. ('South Zachary',)
# 855. ('Staceyfurt',)
# 856. ('Stanleychester',)
# 857. ('Stephanieside',)
# 858. ('Stephentown',)
# 859. ('Stephenville',)
# 860. ('Stevenhaven',)
# 861. ('Stevenland',)
# 862. ('Stevetown',)
# 863. ('Stoneburgh',)
# 864. ('Stoneville',)
# 865. ('Stricklandstad',)
# 866. ('Stuartmouth',)
# 867. ('Susanberg',)
# 868. ('Susanfurt',)
# 869. ('Susanmouth',)
# 870. ('Tamaraport',)
# 871. ('Tammieville',)
# 872. ('Tammybury',)
# 873. ('Tanyaburgh',)
# 874. ('Taylormouth',)
# 875. ('Taylorton',)
# 876. ('Terrihaven',)
# 877. ('Thomastown',)
# 878. ('Thompsonbury',)
# 879. ('Thompsonhaven',)
# 880. ('Thompsonmouth',)
# 881. ('Thompsonton',)
# 882. ('Thompsonview',)
# 883. ('Traceychester',)
# 884. ('Triciamouth',)
# 885. ('Troyport',)
# 886. ('Valenciabury',)
# 887. ('Vanessaberg',)
# 888. ('Vanessachester',)
# 889. ('Vaughanbury',)
# 890. ('Vaughanmouth',)
# 891. ('Velazquezburgh',)
# 892. ('Victoriaville',)
# 893. ('Victormouth',)
# 894. ('Virginiachester',)
# 895. ('Virginiamouth',)
# 896. ('Walkerport',)
# 897. ('Walkertown',)
# 898. ('Warrenhaven',)
# 899. ('Warrenmouth',)
# 900. ('Waynebury',)
# 901. ('West Adrian',)
# 902. ('West Alicebury',)
# 903. ('West Alyssa',)
# 904. ('West Amanda',)
# 905. ('West Amber',)
# 906. ('West Amberburgh',)
# 907. ('West Amy',)
# 908. ('West Autumn',)
# 909. ('West Benjaminshire',)
# 910. ('West Brentview',)
# 911. ('West Brian',)
# 912. ('West Carolinemouth',)
# 913. ('West Catherine',)
# 914. ('West Chelsea',)
# 915. ('West Cheyennetown',)
# 916. ('West Christina',)
# 917. ('West Christopher',)
# 918. ('West Christopherville',)
# 919. ('West Craigchester',)
# 920. ('West Davidport',)
# 921. ('West Debrachester',)
# 922. ('West Denise',)
# 923. ('West Diamondmouth',)
# 924. ('West Duane',)
# 925. ('West Edwardville',)
# 926. ('West Eric',)
# 927. ('West Ericton',)
# 928. ('West Frank',)
# 929. ('West Gilbert',)
# 930. ('West Ginashire',)
# 931. ('West Glenn',)
# 932. ('West James',)
# 933. ('West Jameshaven',)
# 934. ('West Jasonside',)
# 935. ('West Jeannehaven',)
# 936. ('West Jennifer',)
# 937. ('West Jessica',)
# 938. ('West John',)
# 939. ('West Jonathanmouth',)
# 940. ('West Jonathon',)
# 941. ('West Joshua',)
# 942. ('West Kelly',)
# 943. ('West Kenneth',)
# 944. ('West Kristy',)
# 945. ('West Laura',)
# 946. ('West Laurashire',)
# 947. ('West Lisaview',)
# 948. ('West Lorimouth',)
# 949. ('West Luis',)
# 950. ('West Lynn',)
# 951. ('West Meganhaven',)
# 952. ('West Melissashire',)
# 953. ('West Michael',)
# 954. ('West Michaelbury',)
# 955. ('West Michaelfort',)
# 956. ('West Michaelview',)
# 957. ('West Michelletown',)
# 958. ('West Nicole',)
# 959. ('West Pamelachester',)
# 960. ('West Philipmouth',)
# 961. ('West Royborough',)
# 962. ('West Ryan',)
# 963. ('West Sally',)
# 964. ('West Seanhaven',)
# 965. ('West Sharonside',)
# 966. ('West Sheena',)
# 967. ('West Stephanie',)
# 968. ('West Taylorchester',)
# 969. ('West Teresaport',)
# 970. ('West Terrifurt',)
# 971. ('West Terristad',)
# 972. ('West Vanessa',)
# 973. ('West Vanessamouth',)
# 974. ('West Zachary',)
# 975. ('Wheelerburgh',)
# 976. ('Whitakermouth',)
# 977. ('Whiteton',)
# 978. ('Whitneymouth',)
# 979. ('Williamfurt',)
# 980. ('Williamschester',)
# 981. ('Wilsonborough',)
# 982. ('Wilsonfort',)
# 983. ('Wilsonhaven',)
# 984. ('Wilsonview',)
# 985. ('Wolfshire',)
# 986. ('Woodland',)
# 987. ('Youngbury',)
# 988. ('Youngmouth',)
# 989. ('Youngshire',)
# 990. ('Zimmermanside',)
# 991. ('Zimmermanstad',)

# %% [markdown]
# ### WHERE
# We can add conditions to the query string using `WHERE` clause.<br>
# <code>
# SELECT column_list
# FROM table
# WHERE search_condition;
# </code>
# <br>
# SQLite uses the following steps:
# 1. Check the table in the FROM clause.
# 2. Evaluate the conditions in the WHERE clause to get the rows that met these conditions.
# 3. Make the final result set based on the rows in the previous step with columns in the SELECT clause.
#
# The search condition in the WHERE has the following form:<br>
# left_expression  COMPARISON_OPERATOR  right_expression<br><br>
# e.g.
# <code>
# WHERE column_1>5
#
# WHERE column_2 IN (1,2,3)
#
# </code>
# **List of comparison operators:**
# <table>
# <thead>
#   <tr>
#     <th>Operator</th>
#     <th>Meaning</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>=</td>
#     <td>Equal to</td>
#   </tr>
#   <tr>
#     <td>&lt;&gt; or !=</td>
#     <td>Not equal to</td>
#   </tr>
#   <tr>
#     <td>&lt;</td>
#     <td>Less than</td>
#   </tr>
#   <tr>
#     <td>&gt;</td>
#     <td>Greater than</td>
#
#   </tr>
#   <tr>
#     <td>&lt;=</td>
#     <td>Less than or equal to</td>
#
#   </tr>
#   <tr>
#     <td>&gt;=</td>
#     <td>Greater than or equal to</td>
#
#   </tr>
# </tbody>
# </table>
#
# **List of logical operators:**
# <table>
# <thead>
#   <tr>
#     <th>Operator</th>
#     <th>Meaning</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>ALL</td>
#     <td>returns 1 if all expressions are 1.</td>
#   </tr>
#   <tr>
#     <td>AND</td>
#     <td>returns 1 if both expressions are 1, and 0 if one of the expressions is 0.</td>
#   </tr>
#   <tr>
#     <td>ANY</td>
#     <td>returns 1 if any one of a set of comparisons is 1.</td>
#   </tr>
#   <tr>
#     <td>BETWEEN</td>
#     <td>returns 1 if a value is within a range.</td>
#   </tr>
#   <tr>
#     <td>EXISTS</td>
#     <td>returns 1 if a subquery contains any rows.</td>
#   </tr>
#   <tr>
#     <td>IN</td>
#     <td>returns 1 if a value is in a list of values.</td>
#   </tr>
#   <tr>
#     <td>LIKE</td>
#     <td>returns 1 if a value matches a pattern</td>
#   </tr>
#   <tr>
#     <td>NOT</td>
#     <td>reverses the value of other operators such as NOT EXISTS, NOT IN, NOT BETWEEN, etc.</td>
#   </tr>
#   <tr>
#     <td>OR</td>
#     <td>returns true if either expression is 1</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Let's create a list of all the Products having StockCode, Category, Weight, and UnitPrice in the result and sorted from high to low by the price.

# %%
query = '''
SELECT StockCode,Category,Weight, UnitPrice FROM Products
ORDER BY UnitPrice DESC;
'''
execute_query(conn,query)
# Out:
# 1. ('YJ878305', 'Beauty', 2657, 117.55)
# 2. ('GU312892', 'Home', 2042, 92.53)
# 3. ('ST643511', 'Appliances', 3555, 91.76)
# 4. ('PY014422', 'Home', 2275, 87.8)
# 5. ('CC424913', 'Technology', 2106, 78.7)
# 6. ('DR752339', 'Appliances', 115, 78.53)
# 7. ('JX993569', 'Furniture', 3237, 75.89)
# 8. ('LD272389', 'Furniture', 3346, 72.06)
# 9. ('UC279555', 'Furniture', 352, 71.91)
# 10. ('SJ372509', 'Stationary', 1707, 71.86)
# 11. ('DF577320', 'Stationary', 1361, 71.62)
# 12. ('TU924951', 'Furniture', 1841, 68.11)
# 13. ('NE964215', 'Home', 1322, 66.94)
# 14. ('DD186136', 'Clothing', 1581, 66.25)
# 15. ('QD294233', 'Furniture', 678, 65.15)
# 16. ('WV650733', 'Furniture', 462, 63.68)
# 17. ('AQ988179', 'Sports', 3787, 63.67)
# 18. ('KD402977', 'Home', 1840, 61.5)
# 19. ('YQ263581', 'Sports', 1271, 61.4)
# 20. ('VP150049', 'Furniture', 6730, 59.13)
# 21. ('HA328125', 'Furniture', 712, 56.15)
# 22. ('WV168813', 'Clothing', 567, 55.86)
# 23. ('GK060340', 'Clothing', 637, 55.28)
# 24. ('VT624907', 'Clothing', 642, 53.83)
# 25. ('FH047820', 'Beauty', 2033, 53.57)
# 26. ('YC734818', 'Technology', 670, 52.32)
# 27. ('AQ568530', 'Clothing', 4363, 52.29)
# 28. ('RM101832', 'Stationary', 1504, 51.85)
# 29. ('KA428279', 'Stationary', 2528, 51.29)
# 30. ('VB192908', 'Sports', 1457, 51.11)
# 31. ('SH230268', 'Sports', 2836, 50.0)
# 32. ('KV699707', 'Furniture', 1212, 49.79)
# 33. ('XJ792088', 'Clothing', 1075, 48.33)
# 34. ('PP034234', 'Home', 905, 47.77)
# 35. ('RB348133', 'Sports', 3445, 47.01)
# 36. ('FZ737978', 'Furniture', 1, 46.75)
# 37. ('AV611930', 'Appliances', 5528, 46.36)
# 38. ('ZI637174', 'Furniture', 982, 45.75)
# 39. ('BA037508', 'Beauty', 2511, 45.46)
# 40. ('CW933088', 'Home', 1204, 45.29)
# 41. ('EH407549', 'Appliances', 4810, 43.84)
# 42. ('OY272975', 'Appliances', 468, 43.44)
# 43. ('TN652481', 'Home', 1834, 43.29)
# 44. ('PV439970', 'Technology', 1476, 42.83)
# 45. ('TS648442', 'Sports', 1643, 42.39)
# 46. ('JK094728', 'Home', 612, 41.77)
# 47. ('LJ294158', 'Technology', 632, 41.37)
# 48. ('YD328076', 'Technology', 3467, 41.13)
# 49. ('JD727657', 'Clothing', 4827, 40.92)
# 50. ('RV409643', 'Stationary', 305, 40.46)
# 51. ('UQ424073', 'Technology', 81, 40.07)
# 52. ('ZI705132', 'Sports', 3450, 39.56)
# 53. ('UY926211', 'Home', 2814, 39.03)
# 54. ('VA564814', 'Stationary', 720, 38.79)
# 55. ('CS929072', 'Beauty', 417, 38.79)
# 56. ('ZQ867971', 'Beauty', 4642, 38.59)
# 57. ('WB045037', 'Technology', 2805, 38.25)
# 58. ('DD198600', 'Beauty', 2030, 38.19)
# 59. ('FS589147', 'Sports', 1585, 38.16)
# 60. ('YU673093', 'Beauty', 786, 36.96)
# 61. ('CG652842', 'Appliances', 594, 35.77)
# 62. ('FW407914', 'Beauty', 4347, 35.48)
# 63. ('TT401653', 'Technology', 919, 35.02)
# 64. ('LU401786', 'Furniture', 1790, 34.86)
# 65. ('AO469492', 'Sports', 1522, 34.53)
# 66. ('XW869039', 'Technology', 693, 34.07)
# 67. ('UQ607814', 'Home', 179, 32.85)
# 68. ('OL163945', 'Sports', 7988, 32.76)
# 69. ('VF775370', 'Appliances', 1115, 32.69)
# 70. ('TX377293', 'Technology', 800, 32.34)
# 71. ('HL156494', 'Home', 1052, 32.17)
# 72. ('KA323284', 'Technology', 108, 32.15)
# 73. ('JS961877', 'Technology', 4521, 31.65)
# 74. ('ZN199362', 'Beauty', 6748, 31.32)
# 75. ('VZ240168', 'Sports', 3708, 31.27)
# 76. ('KY392005', 'Furniture', 2820, 30.51)
# 77. ('YH733279', 'Appliances', 4149, 30.06)
# 78. ('EM133279', 'Beauty', 2427, 29.9)
# 79. ('OX204742', 'Technology', 1546, 29.47)
# 80. ('WQ703593', 'Home', 2598, 29.25)
# 81. ('OO406570', 'Technology', 1509, 28.87)
# 82. ('GV361474', 'Beauty', 17, 28.81)
# 83. ('HL053400', 'Beauty', 15451, 28.73)
# 84. ('GC440805', 'Sports', 1312, 28.6)
# 85. ('IK042267', 'Appliances', 2049, 28.23)
# 86. ('QJ965247', 'Beauty', 2532, 28.16)
# 87. ('JO827398', 'Beauty', 1046, 28.04)
# 88. ('MJ886801', 'Technology', 3617, 28.01)
# 89. ('JC512163', 'Technology', 1820, 27.67)
# 90. ('YO288069', 'Beauty', 153, 27.48)
# 91. ('LF434461', 'Furniture', 1606, 27.01)
# 92. ('KW929922', 'Clothing', 2029, 26.68)
# 93. ('YN760953', 'Furniture', 2436, 26.58)
# 94. ('JU170640', 'Home', 499, 26.52)
# 95. ('SY274303', 'Furniture', 3820, 26.33)
# 96. ('WE738312', 'Beauty', 1221, 26.31)
# 97. ('WD870963', 'Beauty', 4478, 26.16)
# 98. ('YH986713', 'Clothing', 1278, 25.69)
# 99. ('SH482670', 'Technology', 402, 25.68)
# 100. ('CJ333649', 'Appliances', 3834, 25.14)
# 101. ('FX037590', 'Beauty', 2140, 24.83)
# 102. ('JX098323', 'Furniture', 727, 24.57)
# 103. ('SI669053', 'Stationary', 1745, 24.3)
# 104. ('HR920743', 'Appliances', 2424, 24.09)
# 105. ('JP764375', 'Stationary', 305, 23.97)
# 106. ('UT900480', 'Furniture', 2361, 23.45)
# 107. ('QD658920', 'Technology', 454, 23.3)
# 108. ('ZO985810', 'Appliances', 715, 23.21)
# 109. ('VD494982', 'Sports', 2426, 22.91)
# 110. ('EW850027', 'Furniture', 3275, 22.77)
# 111. ('KT586465', 'Technology', 1385, 22.43)
# 112. ('EV462601', 'Stationary', 196, 22.4)
# 113. ('NM894102', 'Home', 6049, 22.39)
# 114. ('UY300722', 'Home', 1263, 22.31)
# 115. ('RC174600', 'Technology', 275, 22.25)
# 116. ('YR014674', 'Home', 1600, 22.11)
# 117. ('TF006345', 'Beauty', 1595, 21.97)
# 118. ('MK751094', 'Sports', 5841, 21.96)
# 119. ('VB511083', 'Home', 237, 21.88)
# 120. ('XG335214', 'Sports', 1747, 21.77)
# 121. ('OX806183', 'Clothing', 1590, 21.45)
# 122. ('NU857136', 'Home', 3202, 21.41)
# 123. ('CD076891', 'Home', 288, 21.27)
# 124. ('TL163767', 'Sports', 1504, 21.22)
# 125. ('HJ601860', 'Stationary', 1961, 20.54)
# 126. ('JA112745', 'Furniture', 6601, 20.51)
# 127. ('VA491621', 'Appliances', 1030, 20.23)
# 128. ('RI348263', 'Appliances', 415, 20.11)
# 129. ('AV205156', 'Beauty', 5618, 20.04)
# 130. ('EI167200', 'Furniture', 2355, 19.44)
# 131. ('NW176696', 'Beauty', 13926, 19.43)
# 132. ('SL591725', 'Furniture', 2571, 19.35)
# 133. ('FS143237', 'Home', 765, 19.03)
# 134. ('ZI822433', 'Clothing', 508, 18.94)
# 135. ('GX613685', 'Stationary', 2939, 18.43)
# 136. ('CE099815', 'Sports', 2325, 18.25)
# 137. ('XS324415', 'Beauty', 17, 17.99)
# 138. ('FO303231', 'Technology', 1290, 17.98)
# 139. ('NG216735', 'Furniture', 2879, 17.9)
# 140. ('KL971708', 'Clothing', 1570, 17.8)
# 141. ('TM009651', 'Beauty', 1374, 17.47)
# 142. ('DK720585', 'Sports', 460, 17.12)
# 143. ('KY358900', 'Stationary', 34, 16.86)
# 144. ('IQ035204', 'Technology', 431, 16.82)
# 145. ('UL776281', 'Home', 29, 16.75)
# 146. ('AV557076', 'Appliances', 4028, 16.48)
# 147. ('XX748942', 'Sports', 1028, 16.46)
# 148. ('LC099634', 'Technology', 79, 16.45)
# 149. ('GU248130', 'Appliances', 1629, 16.45)
# 150. ('HR412275', 'Sports', 4446, 16.32)
# 151. ('HQ425265', 'Stationary', 591, 16.26)
# 152. ('UJ972892', 'Stationary', 2377, 16.24)
# 153. ('WF819044', 'Furniture', 173, 16.09)
# 154. ('ED802859', 'Sports', 3967, 15.95)
# 155. ('SJ521162', 'Furniture', 810, 15.88)
# 156. ('DZ290862', 'Technology', 2678, 15.65)
# 157. ('GW633161', 'Appliances', 3195, 15.57)
# 158. ('JM653054', 'Appliances', 5, 15.57)
# 159. ('JG569755', 'Clothing', 4047, 15.2)
# 160. ('BO582054', 'Furniture', 92, 15.12)
# 161. ('RP922292', 'Sports', 355, 14.96)
# 162. ('DD010283', 'Appliances', 0, 14.84)
# 163. ('KG005760', 'Sports', 1945, 14.74)
# 164. ('RK693868', 'Appliances', 767, 14.56)
# 165. ('AL225388', 'Furniture', 494, 14.35)
# 166. ('TQ259905', 'Sports', 1710, 14.15)
# 167. ('EV047882', 'Home', 113, 14.1)
# 168. ('YU109630', 'Stationary', 1531, 14.06)
# 169. ('NE675700', 'Furniture', 459, 13.91)
# 170. ('AO024006', 'Home', 2365, 13.89)
# 171. ('AT619585', 'Clothing', 9025, 13.8)
# 172. ('GK840157', 'Home', 2889, 13.79)
# 173. ('NJ458404', 'Furniture', 2899, 13.53)
# 174. ('XO016727', 'Home', 903, 13.31)
# 175. ('OD552225', 'Technology', 1115, 13.14)
# 176. ('OL316261', 'Sports', 7198, 13.13)
# 177. ('LG977007', 'Stationary', 6375, 12.91)
# 178. ('YQ556750', 'Sports', 50, 12.84)
# 179. ('WU901868', 'Technology', 479, 12.84)
# 180. ('RE313887', 'Beauty', 2908, 12.78)
# 181. ('YG769767', 'Stationary', 2979, 12.62)
# 182. ('RL366039', 'Sports', 1692, 12.57)
# 183. ('NL501111', 'Clothing', 604, 12.5)
# 184. ('EA810505', 'Clothing', 455, 12.38)
# 185. ('EB831613', 'Stationary', 368, 12.31)
# 186. ('UP489523', 'Appliances', 141, 12.11)
# 187. ('XF963575', 'Home', 403, 12.03)
# 188. ('ZV140874', 'Home', 1751, 11.91)
# 189. ('HY171869', 'Beauty', 316, 11.9)
# 190. ('KD831181', 'Beauty', 5458, 11.84)
# 191. ('SP542412', 'Clothing', 633, 11.52)
# 192. ('QT761162', 'Sports', 1098, 11.42)
# 193. ('RD191959', 'Beauty', 1671, 11.31)
# 194. ('UX197382', 'Home', 211, 11.3)
# 195. ('AM850835', 'Appliances', 203, 11.24)
# 196. ('DU573649', 'Technology', 222, 11.1)
# 197. ('FK759406', 'Clothing', 9095, 11.04)
# 198. ('ZN588598', 'Technology', 451, 10.92)
# 199. ('UA292126', 'Sports', 6374, 10.9)
# 200. ('YL369550', 'Sports', 234, 10.7)
# 201. ('MO457479', 'Home', 2852, 10.68)
# 202. ('RV973139', 'Appliances', 2768, 10.58)
# 203. ('IY164524', 'Furniture', 7797, 10.48)
# 204. ('HQ925546', 'Beauty', 4452, 10.42)
# 205. ('KM304818', 'Furniture', 214, 10.33)
# 206. ('SP067749', 'Sports', 4061, 10.25)
# 207. ('TW629533', 'Home', 504, 10.22)
# 208. ('WC075791', 'Technology', 903, 10.13)
# 209. ('JN839604', 'Technology', 1006, 10.12)
# 210. ('JR035990', 'Clothing', 2508, 10.02)
# 211. ('DT834985', 'Furniture', 917, 9.52)
# 212. ('JB911266', 'Beauty', 1384, 9.51)
# 213. ('JJ883894', 'Stationary', 505, 9.17)
# 214. ('GS673129', 'Sports', 124, 9.1)
# 215. ('VH823219', 'Home', 3650, 9.0)
# 216. ('LA362026', 'Furniture', 3787, 8.76)
# 217. ('DK020939', 'Beauty', 3069, 8.66)
# 218. ('FF356985', 'Sports', 1266, 8.56)
# 219. ('DS853019', 'Stationary', 2799, 8.46)
# 220. ('OP424108', 'Beauty', 5584, 8.44)
# 221. ('OA710158', 'Sports', 5469, 8.36)
# 222. ('UT650293', 'Appliances', 726, 8.07)
# 223. ('IP543128', 'Furniture', 2100, 8.05)
# 224. ('TD604410', 'Clothing', 776, 8.04)
# 225. ('AD147234', 'Technology', 672, 7.96)
# 226. ('FQ556732', 'Clothing', 164, 7.95)
# 227. ('CP824418', 'Stationary', 75, 7.83)
# 228. ('LZ422758', 'Technology', 4131, 7.82)
# 229. ('WU831585', 'Sports', 1182, 7.71)
# 230. ('SW676612', 'Beauty', 2671, 7.64)
# 231. ('QI533440', 'Stationary', 228, 7.55)
# 232. ('OX788607', 'Stationary', 2908, 7.47)
# 233. ('QX191412', 'Appliances', 935, 7.27)
# 234. ('LC861690', 'Stationary', 831, 7.04)
# 235. ('NX789105', 'Technology', 320, 6.94)
# 236. ('OW060718', 'Home', 2410, 6.88)
# 237. ('RM419830', 'Clothing', 842, 6.81)
# 238. ('II226161', 'Clothing', 2065, 6.75)
# 239. ('WI150710', 'Furniture', 3646, 6.75)
# 240. ('DE471836', 'Beauty', 2322, 6.7)
# 241. ('EI482226', 'Clothing', 568, 6.67)
# 242. ('QM569197', 'Appliances', 4529, 6.65)
# 243. ('WF268546', 'Appliances', 4153, 6.64)
# 244. ('SX937912', 'Home', 1803, 6.61)
# 245. ('YT873595', 'Home', 2203, 6.56)
# 246. ('YR417075', 'Technology', 1940, 6.49)
# 247. ('QE695574', 'Furniture', 2140, 6.38)
# 248. ('EZ069281', 'Sports', 1355, 6.31)
# 249. ('CV483003', 'Clothing', 405, 6.17)
# 250. ('WY701424', 'Sports', 1270, 6.14)
# 251. ('BS032705', 'Home', 1696, 6.1)
# 252. ('RL679581', 'Home', 2056, 6.08)
# 253. ('FL206232', 'Appliances', 7558, 6.03)
# 254. ('ZQ525720', 'Furniture', 180, 5.99)
# 255. ('LG157704', 'Home', 1540, 5.92)
# 256. ('LF545577', 'Sports', 299, 5.86)
# 257. ('VY330668', 'Furniture', 5982, 5.84)
# 258. ('OP332924', 'Sports', 1678, 5.83)
# 259. ('IJ186457', 'Beauty', 380, 5.77)
# 260. ('WE981088', 'Appliances', 1129, 5.55)
# 261. ('GO630928', 'Appliances', 1768, 5.54)
# 262. ('KB827835', 'Stationary', 1410, 5.54)
# 263. ('JF918744', 'Beauty', 360, 5.51)
# 264. ('UJ199198', 'Beauty', 2103, 5.51)
# 265. ('YD272264', 'Technology', 359, 5.5)
# 266. ('RA538031', 'Sports', 6015, 5.4)
# 267. ('NP860944', 'Furniture', 2661, 5.38)
# 268. ('JF581322', 'Clothing', 118, 5.33)
# 269. ('FN667308', 'Sports', 1634, 5.14)
# 270. ('FZ085947', 'Appliances', 1288, 4.93)
# 271. ('AI615521', 'Stationary', 736, 4.84)
# 272. ('VX764028', 'Sports', 10594, 4.82)
# 273. ('HM219344', 'Furniture', 1017, 4.75)
# 274. ('PW885124', 'Furniture', 1649, 4.64)
# 275. ('CV338152', 'Clothing', 972, 4.48)
# 276. ('LB821460', 'Beauty', 5121, 4.4)
# 277. ('QG837765', 'Sports', 1297, 4.39)
# 278. ('CW815585', 'Clothing', 1386, 4.36)
# 279. ('ZH081916', 'Sports', 529, 4.32)
# 280. ('FK103182', 'Clothing', 2567, 4.32)
# 281. ('FT918550', 'Clothing', 4184, 4.32)
# 282. ('MQ184336', 'Appliances', 1061, 4.31)
# 283. ('YW570301', 'Sports', 2321, 4.17)
# 284. ('FT255177', 'Sports', 1112, 4.09)
# 285. ('LF083741', 'Sports', 262, 3.87)
# 286. ('UI299166', 'Beauty', 1378, 3.81)
# 287. ('CB183725', 'Stationary', 1814, 3.71)
# 288. ('CK640266', 'Home', 392, 3.64)
# 289. ('LG560010', 'Sports', 1313, 3.59)
# 290. ('ZO921517', 'Sports', 595, 3.29)
# 291. ('HJ467356', 'Beauty', 2771, 3.24)
# 292. ('HA066493', 'Appliances', 4181, 3.2)
# 293. ('UH907011', 'Stationary', 1677, 3.17)
# 294. ('GW631027', 'Appliances', 3346, 3.1)

# %% [markdown]
# Now, let's do the same thing but this time only the products with price above $15.

# %%
query = '''
SELECT StockCode,Category,Weight, UnitPrice FROM Products
WHERE UnitPrice>15
ORDER BY UnitPrice DESC;
'''
execute_query(conn,query)
# Out:
# 1. ('YJ878305', 'Beauty', 2657, 117.55)
# 2. ('GU312892', 'Home', 2042, 92.53)
# 3. ('ST643511', 'Appliances', 3555, 91.76)
# 4. ('PY014422', 'Home', 2275, 87.8)
# 5. ('CC424913', 'Technology', 2106, 78.7)
# 6. ('DR752339', 'Appliances', 115, 78.53)
# 7. ('JX993569', 'Furniture', 3237, 75.89)
# 8. ('LD272389', 'Furniture', 3346, 72.06)
# 9. ('UC279555', 'Furniture', 352, 71.91)
# 10. ('SJ372509', 'Stationary', 1707, 71.86)
# 11. ('DF577320', 'Stationary', 1361, 71.62)
# 12. ('TU924951', 'Furniture', 1841, 68.11)
# 13. ('NE964215', 'Home', 1322, 66.94)
# 14. ('DD186136', 'Clothing', 1581, 66.25)
# 15. ('QD294233', 'Furniture', 678, 65.15)
# 16. ('WV650733', 'Furniture', 462, 63.68)
# 17. ('AQ988179', 'Sports', 3787, 63.67)
# 18. ('KD402977', 'Home', 1840, 61.5)
# 19. ('YQ263581', 'Sports', 1271, 61.4)
# 20. ('VP150049', 'Furniture', 6730, 59.13)
# 21. ('HA328125', 'Furniture', 712, 56.15)
# 22. ('WV168813', 'Clothing', 567, 55.86)
# 23. ('GK060340', 'Clothing', 637, 55.28)
# 24. ('VT624907', 'Clothing', 642, 53.83)
# 25. ('FH047820', 'Beauty', 2033, 53.57)
# 26. ('YC734818', 'Technology', 670, 52.32)
# 27. ('AQ568530', 'Clothing', 4363, 52.29)
# 28. ('RM101832', 'Stationary', 1504, 51.85)
# 29. ('KA428279', 'Stationary', 2528, 51.29)
# 30. ('VB192908', 'Sports', 1457, 51.11)
# 31. ('SH230268', 'Sports', 2836, 50.0)
# 32. ('KV699707', 'Furniture', 1212, 49.79)
# 33. ('XJ792088', 'Clothing', 1075, 48.33)
# 34. ('PP034234', 'Home', 905, 47.77)
# 35. ('RB348133', 'Sports', 3445, 47.01)
# 36. ('FZ737978', 'Furniture', 1, 46.75)
# 37. ('AV611930', 'Appliances', 5528, 46.36)
# 38. ('ZI637174', 'Furniture', 982, 45.75)
# 39. ('BA037508', 'Beauty', 2511, 45.46)
# 40. ('CW933088', 'Home', 1204, 45.29)
# 41. ('EH407549', 'Appliances', 4810, 43.84)
# 42. ('OY272975', 'Appliances', 468, 43.44)
# 43. ('TN652481', 'Home', 1834, 43.29)
# 44. ('PV439970', 'Technology', 1476, 42.83)
# 45. ('TS648442', 'Sports', 1643, 42.39)
# 46. ('JK094728', 'Home', 612, 41.77)
# 47. ('LJ294158', 'Technology', 632, 41.37)
# 48. ('YD328076', 'Technology', 3467, 41.13)
# 49. ('JD727657', 'Clothing', 4827, 40.92)
# 50. ('RV409643', 'Stationary', 305, 40.46)
# 51. ('UQ424073', 'Technology', 81, 40.07)
# 52. ('ZI705132', 'Sports', 3450, 39.56)
# 53. ('UY926211', 'Home', 2814, 39.03)
# 54. ('VA564814', 'Stationary', 720, 38.79)
# 55. ('CS929072', 'Beauty', 417, 38.79)
# 56. ('ZQ867971', 'Beauty', 4642, 38.59)
# 57. ('WB045037', 'Technology', 2805, 38.25)
# 58. ('DD198600', 'Beauty', 2030, 38.19)
# 59. ('FS589147', 'Sports', 1585, 38.16)
# 60. ('YU673093', 'Beauty', 786, 36.96)
# 61. ('CG652842', 'Appliances', 594, 35.77)
# 62. ('FW407914', 'Beauty', 4347, 35.48)
# 63. ('TT401653', 'Technology', 919, 35.02)
# 64. ('LU401786', 'Furniture', 1790, 34.86)
# 65. ('AO469492', 'Sports', 1522, 34.53)
# 66. ('XW869039', 'Technology', 693, 34.07)
# 67. ('UQ607814', 'Home', 179, 32.85)
# 68. ('OL163945', 'Sports', 7988, 32.76)
# 69. ('VF775370', 'Appliances', 1115, 32.69)
# 70. ('TX377293', 'Technology', 800, 32.34)
# 71. ('HL156494', 'Home', 1052, 32.17)
# 72. ('KA323284', 'Technology', 108, 32.15)
# 73. ('JS961877', 'Technology', 4521, 31.65)
# 74. ('ZN199362', 'Beauty', 6748, 31.32)
# 75. ('VZ240168', 'Sports', 3708, 31.27)
# 76. ('KY392005', 'Furniture', 2820, 30.51)
# 77. ('YH733279', 'Appliances', 4149, 30.06)
# 78. ('EM133279', 'Beauty', 2427, 29.9)
# 79. ('OX204742', 'Technology', 1546, 29.47)
# 80. ('WQ703593', 'Home', 2598, 29.25)
# 81. ('OO406570', 'Technology', 1509, 28.87)
# 82. ('GV361474', 'Beauty', 17, 28.81)
# 83. ('HL053400', 'Beauty', 15451, 28.73)
# 84. ('GC440805', 'Sports', 1312, 28.6)
# 85. ('IK042267', 'Appliances', 2049, 28.23)
# 86. ('QJ965247', 'Beauty', 2532, 28.16)
# 87. ('JO827398', 'Beauty', 1046, 28.04)
# 88. ('MJ886801', 'Technology', 3617, 28.01)
# 89. ('JC512163', 'Technology', 1820, 27.67)
# 90. ('YO288069', 'Beauty', 153, 27.48)
# 91. ('LF434461', 'Furniture', 1606, 27.01)
# 92. ('KW929922', 'Clothing', 2029, 26.68)
# 93. ('YN760953', 'Furniture', 2436, 26.58)
# 94. ('JU170640', 'Home', 499, 26.52)
# 95. ('SY274303', 'Furniture', 3820, 26.33)
# 96. ('WE738312', 'Beauty', 1221, 26.31)
# 97. ('WD870963', 'Beauty', 4478, 26.16)
# 98. ('YH986713', 'Clothing', 1278, 25.69)
# 99. ('SH482670', 'Technology', 402, 25.68)
# 100. ('CJ333649', 'Appliances', 3834, 25.14)
# 101. ('FX037590', 'Beauty', 2140, 24.83)
# 102. ('JX098323', 'Furniture', 727, 24.57)
# 103. ('SI669053', 'Stationary', 1745, 24.3)
# 104. ('HR920743', 'Appliances', 2424, 24.09)
# 105. ('JP764375', 'Stationary', 305, 23.97)
# 106. ('UT900480', 'Furniture', 2361, 23.45)
# 107. ('QD658920', 'Technology', 454, 23.3)
# 108. ('ZO985810', 'Appliances', 715, 23.21)
# 109. ('VD494982', 'Sports', 2426, 22.91)
# 110. ('EW850027', 'Furniture', 3275, 22.77)
# 111. ('KT586465', 'Technology', 1385, 22.43)
# 112. ('EV462601', 'Stationary', 196, 22.4)
# 113. ('NM894102', 'Home', 6049, 22.39)
# 114. ('UY300722', 'Home', 1263, 22.31)
# 115. ('RC174600', 'Technology', 275, 22.25)
# 116. ('YR014674', 'Home', 1600, 22.11)
# 117. ('TF006345', 'Beauty', 1595, 21.97)
# 118. ('MK751094', 'Sports', 5841, 21.96)
# 119. ('VB511083', 'Home', 237, 21.88)
# 120. ('XG335214', 'Sports', 1747, 21.77)
# 121. ('OX806183', 'Clothing', 1590, 21.45)
# 122. ('NU857136', 'Home', 3202, 21.41)
# 123. ('CD076891', 'Home', 288, 21.27)
# 124. ('TL163767', 'Sports', 1504, 21.22)
# 125. ('HJ601860', 'Stationary', 1961, 20.54)
# 126. ('JA112745', 'Furniture', 6601, 20.51)
# 127. ('VA491621', 'Appliances', 1030, 20.23)
# 128. ('RI348263', 'Appliances', 415, 20.11)
# 129. ('AV205156', 'Beauty', 5618, 20.04)
# 130. ('EI167200', 'Furniture', 2355, 19.44)
# 131. ('NW176696', 'Beauty', 13926, 19.43)
# 132. ('SL591725', 'Furniture', 2571, 19.35)
# 133. ('FS143237', 'Home', 765, 19.03)
# 134. ('ZI822433', 'Clothing', 508, 18.94)
# 135. ('GX613685', 'Stationary', 2939, 18.43)
# 136. ('CE099815', 'Sports', 2325, 18.25)
# 137. ('XS324415', 'Beauty', 17, 17.99)
# 138. ('FO303231', 'Technology', 1290, 17.98)
# 139. ('NG216735', 'Furniture', 2879, 17.9)
# 140. ('KL971708', 'Clothing', 1570, 17.8)
# 141. ('TM009651', 'Beauty', 1374, 17.47)
# 142. ('DK720585', 'Sports', 460, 17.12)
# 143. ('KY358900', 'Stationary', 34, 16.86)
# 144. ('IQ035204', 'Technology', 431, 16.82)
# 145. ('UL776281', 'Home', 29, 16.75)
# 146. ('AV557076', 'Appliances', 4028, 16.48)
# 147. ('XX748942', 'Sports', 1028, 16.46)
# 148. ('LC099634', 'Technology', 79, 16.45)
# 149. ('GU248130', 'Appliances', 1629, 16.45)
# 150. ('HR412275', 'Sports', 4446, 16.32)
# 151. ('HQ425265', 'Stationary', 591, 16.26)
# 152. ('UJ972892', 'Stationary', 2377, 16.24)
# 153. ('WF819044', 'Furniture', 173, 16.09)
# 154. ('ED802859', 'Sports', 3967, 15.95)
# 155. ('SJ521162', 'Furniture', 810, 15.88)
# 156. ('DZ290862', 'Technology', 2678, 15.65)
# 157. ('GW633161', 'Appliances', 3195, 15.57)
# 158. ('JM653054', 'Appliances', 5, 15.57)
# 159. ('JG569755', 'Clothing', 4047, 15.2)
# 160. ('BO582054', 'Furniture', 92, 15.12)

# %% [markdown]
# The database puts `NULL` in the table where there is no data. When this data is transfered to Python `NULL` is converted to `None`.<br>
# Let's get a list of customers without a Fax number.

# %%
query = '''
SELECT Surname,Country,Fax FROM Customers
WHERE Fax IS NULL;
'''
execute_query(conn,query)
# Out:
# 1. ('Wall', 'Portugal', None)
# 2. ('Harris', 'Bahrain', None)
# 3. ('Dennis', 'Poland', None)
# 4. ('Carpenter', 'Poland', None)
# 5. ('Liu', 'Lithuania', None)
# 6. ('Bell', 'Australia', None)
# 7. ('Byrd', 'Italy', None)
# 8. ('Torres', 'Norway', None)
# 9. ('Torres', 'Iceland', None)
# 10. ('Anthony', 'Bahrain', None)
# 11. ('Thomas', 'Sweden', None)
# 12. ('Merritt', 'Cyprus', None)
# 13. ('Miller', 'Japan', None)
# 14. ('Mccullough', 'Iceland', None)
# 15. ('Perez', 'Iceland', None)
# 16. ('Garrett', 'Hong Kong', None)
# 17. ('Martinez', 'Netherlands', None)
# 18. ('Munoz', 'Israel', None)
# 19. ('Moore', 'Denmark', None)
# 20. ('Oliver', 'Brazil', None)
# 21. ('Clark', 'Hong Kong', None)
# 22. ('Collins', 'Greece', None)
# 23. ('Gonzalez', 'Spain', None)
# 24. ('Williams', 'Hong Kong', None)
# 25. ('Bond', 'Poland', None)
# 26. ('Jackson', 'Cyprus', None)
# 27. ('Johnson', 'Hong Kong', None)
# 28. ('Bauer', 'Netherlands', None)
# 29. ('Garcia', 'Greece', None)
# 30. ('Parker', 'SingaporeCzech Republic', None)
# 31. ('Garrett', 'Netherlands', None)
# 32. ('Cruz', 'Germany', None)
# 33. ('Graves', 'Germany', None)
# 34. ('Thomas', 'Portugal', None)
# 35. ('Morales', 'Finland', None)
# 36. ('Summers', 'Austria', None)
# 37. ('Bailey', 'United Kingdom', None)
# 38. ('Davis', 'Austria', None)
# 39. ('Bullock', 'France', None)
# 40. ('Fernandez', 'Hong Kong', None)
# 41. ('Adams', 'Norway', None)
# 42. ('Lyons', 'Finland', None)
# 43. ('Simpson', 'Brazil', None)
# 44. ('Hall', 'Austria', None)
# 45. ('Simon', 'Spain', None)
# 46. ('Erickson', 'Germany', None)
# 47. ('Davis', 'Hong Kong', None)
# 48. ('Hood', 'Norway', None)
# 49. ('Johnson', 'Bahrain', None)
# 50. ('Moore', 'Austria', None)
# 51. ('Riley', 'Portugal', None)
# 52. ('Johnson', 'Australia', None)
# 53. ('Griffin', 'Denmark', None)
# 54. ('Gonzales', 'Brazil', None)
# 55. ('Villarreal', 'Italy', None)
# 56. ('Long', 'United Kingdom', None)
# 57. ('Atkinson', 'Israel', None)
# 58. ('Barrera', 'Bahrain', None)
# 59. ('Morris', 'Lithuania', None)
# 60. ('Snyder', 'Denmark', None)
# 61. ('Dominguez', 'Germany', None)
# 62. ('Lang', 'Denmark', None)
# 63. ('Walker', 'USA', None)
# 64. ('Owen', 'Italy', None)
# 65. ('Cooke', 'Poland', None)
# 66. ('Oliver', 'United Kingdom', None)
# 67. ('Andrews', 'Finland', None)
# 68. ('Carr', 'Sweden', None)
# 69. ('Lang', 'Denmark', None)
# 70. ('Edwards', 'Spain', None)
# 71. ('Burch', 'SingaporeCzech Republic', None)
# 72. ('Payne', 'SingaporeCzech Republic', None)
# 73. ('Payne', 'Norway', None)
# 74. ('Wright', 'Denmark', None)
# 75. ('Jones', 'Denmark', None)
# 76. ('Woodard', 'Israel', None)
# 77. ('Evans', 'Finland', None)
# 78. ('Sanders', 'SingaporeCzech Republic', None)
# 79. ('Davis', 'Brazil', None)
# 80. ('Wilkins', 'Lithuania', None)
# 81. ('Torres', 'Denmark', None)
# 82. ('Lowe', 'Belgium', None)
# 83. ('Harvey', 'Belgium', None)
# 84. ('Gonzalez', 'Poland', None)
# 85. ('Brown', 'Finland', None)
# 86. ('Harrison', 'Bahrain', None)
# 87. ('Fernandez', 'Italy', None)
# 88. ('Mueller', 'Finland', None)
# 89. ('Williams', 'Cyprus', None)
# 90. ('Burton', 'Norway', None)
# 91. ('Wright', 'Brazil', None)
# 92. ('Edwards', 'Hong Kong', None)
# 93. ('Randall', 'Austria', None)
# 94. ('Wright', 'Israel', None)
# 95. ('Benson', 'Spain', None)
# 96. ('Larson', 'Portugal', None)
# 97. ('Hicks', 'Netherlands', None)
# 98. ('Oliver', 'Spain', None)
# 99. ('Bradley', 'Finland', None)
# 100. ('Marshall', 'Lithuania', None)
# 101. ('Morgan', 'United Kingdom', None)
# 102. ('Brown', 'Norway', None)
# 103. ('Tate', 'Portugal', None)
# 104. ('Williams', 'Spain', None)
# 105. ('Preston', 'USA', None)
# 106. ('Rodriguez', 'Portugal', None)
# 107. ('Carter', 'Denmark', None)
# 108. ('Frye', 'SingaporeCzech Republic', None)
# 109. ('Scott', 'France', None)
# 110. ('Bolton', 'Lithuania', None)
# 111. ('Diaz', 'Italy', None)
# 112. ('Jordan', 'Germany', None)
# 113. ('Jones', 'Belgium', None)
# 114. ('Smith', 'Sweden', None)
# 115. ('Beck', 'Austria', None)
# 116. ('Wilson', 'Austria', None)
# 117. ('Rodriguez', 'Iceland', None)
# 118. ('Martinez', 'Brazil', None)
# 119. ('Robinson', 'Netherlands', None)
# 120. ('Finley', 'Iceland', None)
# 121. ('Miles', 'Sweden', None)
# 122. ('Molina', 'Germany', None)
# 123. ('Burns', 'Finland', None)
# 124. ('Moore', 'Brazil', None)
# 125. ('Morris', 'Austria', None)
# 126. ('Lee', 'Netherlands', None)
# 127. ('Sullivan', 'Israel', None)
# 128. ('Davis', 'Finland', None)
# 129. ('Brown', 'Spain', None)
# 130. ('Lopez', 'Brazil', None)
# 131. ('Young', 'Austria', None)
# 132. ('Byrd', 'Hong Kong', None)
# 133. ('Evans', 'Poland', None)
# 134. ('Watson', 'Portugal', None)
# 135. ('Palmer', 'Brazil', None)
# 136. ('Gordon', 'Cyprus', None)
# 137. ('Lambert', 'Bahrain', None)
# 138. ('Murphy', 'France', None)
# 139. ('Cooper', 'Greece', None)
# 140. ('Werner', 'Poland', None)
# 141. ('Boyle', 'Bahrain', None)
# 142. ('Lucas', 'Israel', None)
# 143. ('Huff', 'Iceland', None)
# 144. ('Castillo', 'Greece', None)
# 145. ('Cook', 'Portugal', None)
# 146. ('Monroe', 'Germany', None)
# 147. ('Goodman', 'USA', None)
# 148. ('Porter', 'Israel', None)
# 149. ('Pierce', 'Spain', None)
# 150. ('Andrade', 'Spain', None)
# 151. ('Cain', 'Poland', None)
# 152. ('Miranda', 'USA', None)
# 153. ('Davenport', 'Bahrain', None)
# 154. ('Sharp', 'Cyprus', None)
# 155. ('Ward', 'Poland', None)
# 156. ('Brown', 'Australia', None)
# 157. ('Griffith', 'Germany', None)
# 158. ('Clay', 'Finland', None)
# 159. ('Nelson', 'Cyprus', None)
# 160. ('Morales', 'Australia', None)
# 161. ('Barr', 'Canada', None)
# 162. ('Bell', 'Iceland', None)
# 163. ('Roberts', 'Norway', None)
# 164. ('Anderson', 'Cyprus', None)
# 165. ('Neal', 'Lithuania', None)
# 166. ('Wells', 'Japan', None)
# 167. ('Johnson', 'Canada', None)
# 168. ('Quinn', 'Bahrain', None)
# 169. ('Sutton', 'France', None)
# 170. ('Jordan', 'Bahrain', None)
# 171. ('Tucker', 'Netherlands', None)
# 172. ('Green', 'Japan', None)
# 173. ('Moore', 'Norway', None)
# 174. ('Martin', 'Israel', None)
# 175. ('Hughes', 'Canada', None)
# 176. ('Nelson', 'Switzerland', None)
# 177. ('Ho', 'SingaporeCzech Republic', None)
# 178. ('Gardner', 'Lithuania', None)
# 179. ('Griffith', 'Norway', None)
# 180. ('Diaz', 'Cyprus', None)
# 181. ('Pineda', 'Spain', None)
# 182. ('Tucker', 'France', None)
# 183. ('Tran', 'USA', None)
# 184. ('Stevens', 'Australia', None)
# 185. ('Patrick', 'Bahrain', None)
# 186. ('Graves', 'Poland', None)
# 187. ('Barnett', 'Italy', None)
# 188. ('Johnson', 'Japan', None)
# 189. ('Bauer', 'Finland', None)
# 190. ('Johnson', 'Poland', None)
# 191. ('Sampson', 'Denmark', None)
# 192. ('Baldwin', 'France', None)
# 193. ('Pollard', 'Hong Kong', None)
# 194. ('Myers', 'France', None)
# 195. ('Poole', 'Portugal', None)
# 196. ('Scott', 'Finland', None)
# 197. ('Espinoza', 'France', None)
# 198. ('Long', 'Finland', None)
# 199. ('Gonzalez', 'Portugal', None)
# 200. ('Molina', 'Spain', None)
# 201. ('Vargas', 'Lithuania', None)
# 202. ('Russell', 'Australia', None)
# 203. ('Ball', 'Australia', None)
# 204. ('Morrison', 'Canada', None)
# 205. ('Ponce', 'Sweden', None)
# 206. ('Hughes', 'SingaporeCzech Republic', None)
# 207. ('Evans', 'Lithuania', None)
# 208. ('Kim', 'Belgium', None)
# 209. ('Dawson', 'Austria', None)
# 210. ('Garcia', 'Brazil', None)
# 211. ('Simon', 'Bahrain', None)
# 212. ('Wilson', 'Canada', None)
# 213. ('Ramos', 'SingaporeCzech Republic', None)
# 214. ('Johnson', 'Netherlands', None)
# 215. ('Cox', 'Bahrain', None)
# 216. ('Rios', 'Finland', None)
# 217. ('Robles', 'France', None)
# 218. ('Roth', 'Greece', None)
# 219. ('Bishop', 'United Kingdom', None)
# 220. ('Cox', 'Japan', None)
# 221. ('Harris', 'Belgium', None)
# 222. ('Carter', 'Brazil', None)
# 223. ('Holden', 'United Kingdom', None)
# 224. ('Huerta', 'France', None)
# 225. ('Gardner', 'Bahrain', None)
# 226. ('Carroll', 'Finland', None)
# 227. ('Russell', 'Norway', None)
# 228. ('Watson', 'Iceland', None)
# 229. ('Duffy', 'Sweden', None)
# 230. ('Owens', 'Spain', None)
# 231. ('Hill', 'Brazil', None)
# 232. ('Bentley', 'Japan', None)
# 233. ('Barrett', 'Italy', None)
# 234. ('Riley', 'Greece', None)
# 235. ('Washington', 'Greece', None)
# 236. ('Lopez', 'Norway', None)
# 237. ('Williamson', 'France', None)
# 238. ('Clark', 'Brazil', None)
# 239. ('Diaz', 'Belgium', None)
# 240. ('Hall', 'SingaporeCzech Republic', None)
# 241. ('Swanson', 'Sweden', None)
# 242. ('Sheppard', 'Hong Kong', None)
# 243. ('Jones', 'Hong Kong', None)
# 244. ('Mcclure', 'Austria', None)
# 245. ('Phelps', 'Sweden', None)
# 246. ('Cameron', 'Netherlands', None)
# 247. ('Wagner', 'SingaporeCzech Republic', None)
# 248. ('Patterson', 'Italy', None)
# 249. ('Singh', 'Finland', None)
# 250. ('Price', 'Lithuania', None)
# 251. ('Carroll', 'USA', None)
# 252. ('Yang', 'Brazil', None)
# 253. ('Norman', 'Belgium', None)
# 254. ('Mcdonald', 'Denmark', None)
# 255. ('Wade', 'USA', None)
# 256. ('Bradley', 'Denmark', None)
# 257. ('Bennett', 'Australia', None)
# 258. ('Saunders', 'Italy', None)
# 259. ('Lynch', 'Denmark', None)
# 260. ('Thomas', 'SingaporeCzech Republic', None)
# 261. ('Walker', 'Greece', None)
# 262. ('Hall', 'Lithuania', None)
# 263. ('Wright', 'Greece', None)
# 264. ('Price', 'Lithuania', None)
# 265. ('Campbell', 'Finland', None)
# 266. ('Prince', 'Norway', None)
# 267. ('Clark', 'Poland', None)
# 268. ('Friedman', 'USA', None)
# 269. ('Bradley', 'Italy', None)
# 270. ('Wallace', 'USA', None)
# 271. ('Shelton', 'Switzerland', None)
# 272. ('Young', 'Spain', None)
# 273. ('Barrera', 'Norway', None)
# 274. ('Bennett', 'Cyprus', None)
# 275. ('Lynn', 'Poland', None)
# 276. ('Moore', 'Bahrain', None)
# 277. ('Andrews', 'Germany', None)
# 278. ('Smith', 'SingaporeCzech Republic', None)
# 279. ('Sanders', 'Brazil', None)
# 280. ('Schaefer', 'Cyprus', None)
# 281. ('Holmes', 'Lithuania', None)
# 282. ('Wilson', 'Austria', None)
# 283. ('Welch', 'France', None)
# 284. ('Adams', 'France', None)
# 285. ('Young', 'Germany', None)
# 286. ('Frost', 'Japan', None)
# 287. ('Rios', 'Portugal', None)
# 288. ('Walker', 'Sweden', None)
# 289. ('Bell', 'Finland', None)
# 290. ('Gaines', 'Brazil', None)
# 291. ('Lyons', 'Italy', None)
# 292. ('Weiss', 'France', None)
# 293. ('Allen', 'SingaporeCzech Republic', None)
# 294. ('Larsen', 'Lithuania', None)
# 295. ('Gonzalez', 'France', None)
# 296. ('Russo', 'Belgium', None)
# 297. ('Case', 'Cyprus', None)
# 298. ('Mclean', 'Norway', None)
# 299. ('Arnold', 'Spain', None)
# 300. ('Hanson', 'Israel', None)
# 301. ('Hernandez', 'SingaporeCzech Republic', None)
# 302. ('Evans', 'Lithuania', None)
# 303. ('Lawson', 'Belgium', None)
# 304. ('Bright', 'Japan', None)
# 305. ('Peters', 'Belgium', None)
# 306. ('Miller', 'Sweden', None)
# 307. ('Ellis', 'Switzerland', None)
# 308. ('Smith', 'Hong Kong', None)
# 309. ('Cruz', 'Greece', None)
# 310. ('Robinson', 'USA', None)
# 311. ('Phillips', 'France', None)
# 312. ('Howell', 'Greece', None)
# 313. ('Morales', 'Australia', None)
# 314. ('Mejia', 'Bahrain', None)
# 315. ('Perez', 'Bahrain', None)
# 316. ('Taylor', 'United Kingdom', None)
# 317. ('Garcia', 'United Kingdom', None)
# 318. ('Kelly', 'Brazil', None)
# 319. ('Saunders', 'Spain', None)
# 320. ('Simmons', 'United Kingdom', None)
# 321. ('Davis', 'Norway', None)
# 322. ('Bailey', 'Poland', None)
# 323. ('Harris', 'SingaporeCzech Republic', None)
# 324. ('Olson', 'Switzerland', None)
# 325. ('Barry', 'United Kingdom', None)
# 326. ('David', 'Sweden', None)
# 327. ('Neal', 'Spain', None)
# 328. ('Wagner', 'Australia', None)
# 329. ('Mccullough', 'Switzerland', None)
# 330. ('Velez', 'France', None)
# 331. ('Ortiz', 'Italy', None)
# 332. ('Bush', 'Cyprus', None)
# 333. ('Smith', 'Poland', None)
# 334. ('Owens', 'Australia', None)
# 335. ('Walker', 'Bahrain', None)
# 336. ('Schneider', 'Iceland', None)
# 337. ('Vargas', 'Italy', None)
# 338. ('Rose', 'United Kingdom', None)
# 339. ('Stuart', 'Germany', None)
# 340. ('Harris', 'Switzerland', None)
# 341. ('Mack', 'Bahrain', None)
# 342. ('Holloway', 'Hong Kong', None)
# 343. ('Garcia', 'Hong Kong', None)
# 344. ('Young', 'Netherlands', None)
# 345. ('Gonzalez', 'Japan', None)
# 346. ('Vang', 'Greece', None)
# 347. ('Macdonald', 'Hong Kong', None)
# 348. ('Martinez', 'Finland', None)
# 349. ('Brown', 'Austria', None)
# 350. ('Huff', 'Japan', None)
# 351. ('Sanchez', 'Netherlands', None)
# 352. ('Sexton', 'Belgium', None)
# 353. ('Nichols', 'Japan', None)
# 354. ('Hughes', 'Canada', None)
# 355. ('Smith', 'Australia', None)
# 356. ('Clark', 'Cyprus', None)
# 357. ('Mack', 'Norway', None)
# 358. ('Alexander', 'Austria', None)
# 359. ('Bell', 'Austria', None)
# 360. ('Griffith', 'Finland', None)
# 361. ('Martin', 'Switzerland', None)
# 362. ('Garner', 'Japan', None)
# 363. ('Werner', 'Greece', None)
# 364. ('Campbell', 'Denmark', None)
# 365. ('Stewart', 'Austria', None)
# 366. ('Simpson', 'USA', None)
# 367. ('Rodriguez', 'Netherlands', None)
# 368. ('Holmes', 'Cyprus', None)
# 369. ('Stevens', 'Japan', None)
# 370. ('Hatfield', 'SingaporeCzech Republic', None)
# 371. ('Martin', 'Portugal', None)
# 372. ('Gibbs', 'Italy', None)
# 373. ('Hernandez', 'Portugal', None)
# 374. ('Butler', 'Cyprus', None)
# 375. ('Pace', 'Greece', None)
# 376. ('Sims', 'Austria', None)
# 377. ('Mullen', 'Greece', None)
# 378. ('Fowler', 'Norway', None)
# 379. ('Mitchell', 'Canada', None)
# 380. ('Martin', 'Hong Kong', None)
# 381. ('Mercado', 'Denmark', None)
# 382. ('Brown', 'France', None)
# 383. ('Smith', 'Bahrain', None)
# 384. ('Robertson', 'Netherlands', None)
# 385. ('Thomas', 'Switzerland', None)
# 386. ('Villarreal', 'Denmark', None)
# 387. ('Rios', 'United Kingdom', None)
# 388. ('Mitchell', 'Japan', None)
# 389. ('Garcia', 'Australia', None)
# 390. ('Allen', 'Japan', None)
# 391. ('Davis', 'Bahrain', None)
# 392. ('Gonzales', 'Israel', None)
# 393. ('Smith', 'Brazil', None)
# 394. ('James', 'United Kingdom', None)
# 395. ('Hicks', 'Greece', None)
# 396. ('Osborn', 'Hong Kong', None)
# 397. ('Davila', 'Portugal', None)
# 398. ('Gamble', 'Bahrain', None)
# 399. ('Saunders', 'Japan', None)
# 400. ('Wade', 'Lithuania', None)
# 401. ('Gutierrez', 'Cyprus', None)
# 402. ('Nixon', 'Japan', None)
# 403. ('Franco', 'Spain', None)
# 404. ('Howard', 'Japan', None)
# 405. ('Hernandez', 'Denmark', None)
# 406. ('Spencer', 'Bahrain', None)
# 407. ('Lopez', 'Poland', None)
# 408. ('Griffith', 'Austria', None)
# 409. ('Mcconnell', 'Australia', None)
# 410. ('Norman', 'Belgium', None)
# 411. ('Bradley', 'Italy', None)
# 412. ('Davis', 'Brazil', None)
# 413. ('Gross', 'United Kingdom', None)
# 414. ('Strickland', 'Germany', None)
# 415. ('Frank', 'Germany', None)
# 416. ('Smith', 'Switzerland', None)
# 417. ('Carlson', 'Italy', None)
# 418. ('Andrews', 'Sweden', None)
# 419. ('Johnson', 'Australia', None)
# 420. ('Jones', 'Denmark', None)
# 421. ('Bradley', 'Canada', None)
# 422. ('Fitzpatrick', 'Portugal', None)
# 423. ('Hawkins', 'Bahrain', None)
# 424. ('Price', 'Belgium', None)
# 425. ('Johns', 'Sweden', None)
# 426. ('Anderson', 'Portugal', None)
# 427. ('Perez', 'Greece', None)
# 428. ('Phelps', 'Norway', None)
# 429. ('Lee', 'Bahrain', None)
# 430. ('Donovan', 'Spain', None)
# 431. ('Horton', 'Hong Kong', None)
# 432. ('Murray', 'Brazil', None)
# 433. ('Moore', 'Italy', None)
# 434. ('Brewer', 'Israel', None)
# 435. ('James', 'Austria', None)
# 436. ('Dalton', 'Italy', None)
# 437. ('Harrison', 'Denmark', None)
# 438. ('Fleming', 'SingaporeCzech Republic', None)
# 439. ('Meza', 'USA', None)
# 440. ('Smith', 'Netherlands', None)
# 441. ('Phillips', 'France', None)
# 442. ('Ali', 'France', None)
# 443. ('Neal', 'France', None)
# 444. ('Huff', 'Greece', None)
# 445. ('Charles', 'Finland', None)
# 446. ('Carroll', 'Lithuania', None)
# 447. ('Miller', 'SingaporeCzech Republic', None)
# 448. ('Miller', 'United Kingdom', None)
# 449. ('Lee', 'Italy', None)
# 450. ('Wilkins', 'Denmark', None)
# 451. ('Savage', 'Hong Kong', None)
# 452. ('Lee', 'Germany', None)
# 453. ('Matthews', 'France', None)
# 454. ('Wright', 'Greece', None)
# 455. ('Gonzalez', 'Portugal', None)
# 456. ('Lambert', 'Lithuania', None)
# 457. ('Beck', 'Finland', None)
# 458. ('Collins', 'France', None)
# 459. ('Casey', 'Spain', None)
# 460. ('Waters', 'Austria', None)
# 461. ('Warren', 'Sweden', None)
# 462. ('Hughes', 'Lithuania', None)
# 463. ('Smith', 'Poland', None)
# 464. ('Hardin', 'Poland', None)
# 465. ('Hart', 'Israel', None)
# 466. ('Evans', 'Netherlands', None)
# 467. ('Holder', 'Israel', None)
# 468. ('Gutierrez', 'Lithuania', None)
# 469. ('Edwards', 'Japan', None)
# 470. ('Gibson', 'France', None)
# 471. ('Shea', 'Poland', None)
# 472. ('Knapp', 'France', None)
# 473. ('Hansen', 'Australia', None)
# 474. ('Waters', 'Spain', None)
# 475. ('Richardson', 'Canada', None)
# 476. ('Davis', 'Germany', None)
# 477. ('Mcfarland', 'Italy', None)
# 478. ('Wilson', 'Denmark', None)
# 479. ('Meyer', 'Norway', None)
# 480. ('Wright', 'Greece', None)
# 481. ('Hernandez', 'United Kingdom', None)
# 482. ('Tucker', 'Finland', None)
# 483. ('Hudson', 'Netherlands', None)
# 484. ('Holt', 'Portugal', None)
# 485. ('Webster', 'Netherlands', None)
# 486. ('Vasquez', 'Denmark', None)
# 487. ('Norton', 'Austria', None)
# 488. ('Jackson', 'Finland', None)
# 489. ('Johnson', 'Brazil', None)
# 490. ('Clark', 'Poland', None)
# 491. ('Stewart', 'Bahrain', None)
# 492. ('Gregory', 'Belgium', None)
# 493. ('Beltran', 'Cyprus', None)
# 494. ('Williams', 'Lithuania', None)
# 495. ('Henry', 'Poland', None)
# 496. ('Jones', 'USA', None)
# 497. ('Hodge', 'Netherlands', None)
# 498. ('Gray', 'Hong Kong', None)
# 499. ('Hanson', 'Norway', None)
# 500. ('Casey', 'Poland', None)
# 501. ('Fisher', 'Lithuania', None)
# 502. ('Zavala', 'Spain', None)
# 503. ('Henderson', 'Canada', None)
# 504. ('Murray', 'Norway', None)
# 505. ('Green', 'Iceland', None)
# 506. ('Stark', 'Brazil', None)
# 507. ('Williams', 'Finland', None)
# 508. ('Grant', 'USA', None)
# 509. ('Gutierrez', 'Japan', None)
# 510. ('Moon', 'Cyprus', None)
# 511. ('Hayden', 'Japan', None)
# 512. ('Jones', 'United Kingdom', None)
# 513. ('White', 'USA', None)
# 514. ('Wilson', 'Japan', None)
# 515. ('Reese', 'Denmark', None)
# 516. ('Zhang', 'Bahrain', None)
# 517. ('Hale', 'Cyprus', None)
# 518. ('Gordon', 'Finland', None)
# 519. ('Carr', 'Norway', None)
# 520. ('Hill', 'Bahrain', None)
# 521. ('Kennedy', 'Brazil', None)
# 522. ('Graham', 'France', None)
# 523. ('Nash', 'Sweden', None)
# 524. ('Gould', 'Spain', None)
# 525. ('Craig', 'Greece', None)
# 526. ('Luna', 'Portugal', None)
# 527. ('Barajas', 'Iceland', None)
# 528. ('Diaz', 'Hong Kong', None)
# 529. ('Miller', 'Netherlands', None)
# 530. ('Wilson', 'Switzerland', None)
# 531. ('Barnett', 'Norway', None)
# 532. ('Houston', 'Japan', None)
# 533. ('Cisneros', 'Australia', None)
# 534. ('Edwards', 'Germany', None)
# 535. ('Snyder', 'Spain', None)
# 536. ('Andersen', 'Sweden', None)
# 537. ('Elliott', 'Greece', None)
# 538. ('Velasquez', 'Israel', None)
# 539. ('Peterson', 'Belgium', None)
# 540. ('Evans', 'USA', None)
# 541. ('Tapia', 'Denmark', None)
# 542. ('Callahan', 'Israel', None)
# 543. ('Gould', 'Austria', None)
# 544. ('Reyes', 'France', None)
# 545. ('Cannon', 'Belgium', None)
# 546. ('Carlson', 'Spain', None)
# 547. ('Sharp', 'United Kingdom', None)
# 548. ('Shelton', 'Denmark', None)
# 549. ('Stewart', 'Lithuania', None)
# 550. ('Moore', 'Israel', None)
# 551. ('Garcia', 'Hong Kong', None)
# 552. ('Mendoza', 'Finland', None)
# 553. ('Williams', 'Sweden', None)
# 554. ('Brown', 'Japan', None)
# 555. ('Evans', 'Iceland', None)
# 556. ('Stephens', 'Lithuania', None)
# 557. ('Ramirez', 'USA', None)
# 558. ('Meyers', 'Spain', None)
# 559. ('Rodriguez', 'Spain', None)
# 560. ('Gates', 'Denmark', None)
# 561. ('Sharp', 'Switzerland', None)
# 562. ('Smith', 'Switzerland', None)
# 563. ('Keith', 'Israel', None)
# 564. ('Perez', 'Norway', None)
# 565. ('Wiley', 'Belgium', None)
# 566. ('Pierce', 'Italy', None)
# 567. ('Thompson', 'Switzerland', None)
# 568. ('Perry', 'France', None)
# 569. ('Mcdonald', 'Germany', None)
# 570. ('Bell', 'Brazil', None)
# 571. ('Moss', 'Brazil', None)
# 572. ('Tyler', 'Israel', None)
# 573. ('Collins', 'Germany', None)
# 574. ('Greene', 'Australia', None)
# 575. ('Stout', 'Portugal', None)
# 576. ('Hayes', 'Australia', None)
# 577. ('Foster', 'Brazil', None)
# 578. ('Mueller', 'Hong Kong', None)
# 579. ('Gutierrez', 'Australia', None)
# 580. ('Robinson', 'Poland', None)
# 581. ('Hanna', 'Brazil', None)
# 582. ('Ibarra', 'USA', None)
# 583. ('Craig', 'Iceland', None)
# 584. ('Mcdonald', 'Finland', None)
# 585. ('Shaw', 'Australia', None)
# 586. ('Lewis', 'Portugal', None)
# 587. ('Sanchez', 'Austria', None)
# 588. ('Nielsen', 'France', None)
# 589. ('Fletcher', 'Spain', None)
# 590. ('Haley', 'Greece', None)
# 591. ('Melendez', 'Norway', None)
# 592. ('Lozano', 'United Kingdom', None)
# 593. ('Reyes', 'Italy', None)
# 594. ('Garcia', 'Bahrain', None)
# 595. ('Wong', 'Brazil', None)
# 596. ('Keller', 'Greece', None)
# 597. ('Gonzalez', 'Sweden', None)
# 598. ('Norris', 'Bahrain', None)
# 599. ('Scott', 'Cyprus', None)
# 600. ('Koch', 'USA', None)
# 601. ('Larsen', 'Spain', None)
# 602. ('Sutton', 'Cyprus', None)
# 603. ('Roth', 'Japan', None)
# 604. ('Ward', 'Belgium', None)
# 605. ('Williams', 'Cyprus', None)
# 606. ('Wang', 'SingaporeCzech Republic', None)
# 607. ('Sandoval', 'Canada', None)
# 608. ('Decker', 'Greece', None)
# 609. ('Obrien', 'Belgium', None)
# 610. ('Brady', 'Iceland', None)
# 611. ('Juarez', 'Cyprus', None)
# 612. ('Harris', 'Greece', None)
# 613. ('Taylor', 'Spain', None)
# 614. ('Smith', 'Netherlands', None)
# 615. ('Peck', 'Australia', None)
# 616. ('Potter', 'Hong Kong', None)
# 617. ('Gardner', 'Canada', None)
# 618. ('Pugh', 'Germany', None)
# 619. ('Rodriguez', 'Austria', None)
# 620. ('Paul', 'Bahrain', None)
# 621. ('Ward', 'Finland', None)
# 622. ('Valencia', 'Norway', None)
# 623. ('Padilla', 'Sweden', None)
# 624. ('Fowler', 'Austria', None)
# 625. ('Nelson', 'Australia', None)
# 626. ('Patterson', 'Hong Kong', None)
# 627. ('Dalton', 'Netherlands', None)
# 628. ('Walker', 'United Kingdom', None)
# 629. ('Hernandez', 'Israel', None)
# 630. ('Hill', 'Brazil', None)
# 631. ('Sullivan', 'Austria', None)
# 632. ('Meyer', 'Poland', None)
# 633. ('Morales', 'Cyprus', None)
# 634. ('George', 'Canada', None)
# 635. ('Acosta', 'Italy', None)
# 636. ('Robles', 'Bahrain', None)
# 637. ('Duran', 'United Kingdom', None)
# 638. ('Jackson', 'United Kingdom', None)
# 639. ('Jennings', 'Norway', None)
# 640. ('Holt', 'Belgium', None)
# 641. ('Byrd', 'Greece', None)
# 642. ('West', 'United Kingdom', None)
# 643. ('Lewis', 'Lithuania', None)
# 644. ('Frye', 'Spain', None)
# 645. ('Walsh', 'Australia', None)
# 646. ('Herman', 'Spain', None)
# 647. ('Ross', 'Cyprus', None)
# 648. ('Bush', 'Bahrain', None)
# 649. ('Macias', 'Netherlands', None)
# 650. ('Perez', 'Belgium', None)
# 651. ('Clark', 'Italy', None)
# 652. ('Cook', 'United Kingdom', None)
# 653. ('Elliott', 'Canada', None)
# 654. ('Haynes', 'Finland', None)
# 655. ('Nunez', 'Greece', None)
# 656. ('Smith', 'Netherlands', None)
# 657. ('Ware', 'SingaporeCzech Republic', None)
# 658. ('Mitchell', 'Sweden', None)
# 659. ('Ellis', 'Cyprus', None)
# 660. ('Carlson', 'Japan', None)
# 661. ('Baker', 'Iceland', None)
# 662. ('Anderson', 'Portugal', None)
# 663. ('Russell', 'Canada', None)
# 664. ('Smith', 'Hong Kong', None)
# 665. ('Mack', 'Hong Kong', None)
# 666. ('Aguirre', 'Israel', None)
# 667. ('Lee', 'United Kingdom', None)
# 668. ('Cruz', 'Bahrain', None)
# 669. ('Martinez', 'USA', None)
# 670. ('Branch', 'France', None)
# 671. ('Hall', 'Greece', None)
# 672. ('Richardson', 'Germany', None)
# 673. ('Hughes', 'Cyprus', None)
# 674. ('Smith', 'Italy', None)
# 675. ('Calhoun', 'Norway', None)
# 676. ('Lopez', 'Norway', None)
# 677. ('Mcdonald', 'Bahrain', None)
# 678. ('Duncan', 'Germany', None)
# 679. ('Reed', 'Bahrain', None)
# 680. ('Fuller', 'Sweden', None)
# 681. ('Anderson', 'Sweden', None)
# 682. ('Young', 'Lithuania', None)
# 683. ('Brooks', 'Belgium', None)
# 684. ('Murray', 'Poland', None)
# 685. ('Romero', 'Canada', None)
# 686. ('Anthony', 'Italy', None)
# 687. ('Taylor', 'Finland', None)
# 688. ('Thompson', 'Belgium', None)
# 689. ('Oneal', 'Denmark', None)
# 690. ('Gentry', 'Bahrain', None)
# 691. ('Barrera', 'Belgium', None)
# 692. ('Proctor', 'Italy', None)
# 693. ('Hernandez', 'Cyprus', None)
# 694. ('Smith', 'Poland', None)
# 695. ('Perez', 'Norway', None)
# 696. ('Moore', 'Canada', None)
# 697. ('Hayes', 'United Kingdom', None)
# 698. ('Dickerson', 'Cyprus', None)
# 699. ('Estrada', 'Greece', None)
# 700. ('Sawyer', 'Austria', None)
# 701. ('Clark', 'Lithuania', None)
# 702. ('Stewart', 'Poland', None)
# 703. ('Williams', 'France', None)
# 704. ('Payne', 'Israel', None)
# 705. ('Jackson', 'Spain', None)
# 706. ('Mccarthy', 'Poland', None)
# 707. ('Adams', 'Poland', None)
# 708. ('Yang', 'Israel', None)
# 709. ('Johnson', 'Iceland', None)
# 710. ('Perez', 'Israel', None)
# 711. ('Gonzalez', 'Poland', None)
# 712. ('Fields', 'Germany', None)
# 713. ('Cox', 'Poland', None)
# 714. ('Mcclure', 'Iceland', None)
# 715. ('Holmes', 'Bahrain', None)
# 716. ('Hughes', 'Finland', None)
# 717. ('Kim', 'Finland', None)
# 718. ('Morris', 'Finland', None)
# 719. ('Davis', 'Denmark', None)
# 720. ('Allen', 'Netherlands', None)
# 721. ('Harris', 'Japan', None)
# 722. ('Duncan', 'Canada', None)
# 723. ('Taylor', 'United Kingdom', None)
# 724. ('Carter', 'Austria', None)
# 725. ('Berger', 'Brazil', None)
# 726. ('Ramsey', 'Spain', None)
# 727. ('Williamson', 'Denmark', None)
# 728. ('Thomas', 'Spain', None)

# %% [markdown]
# **Note:** `WHERE` must come before `ORDER BY`.

# %%
# Only Customers from Australia
query = '''
SELECT CustomerId, FirstName, Surname FROM Customers
WHERE Country="Australia"
ORDER BY Surname DESC;
'''
execute_query(conn,query)
# Out:
# 1. (905, 'Philip', 'Walsh')
# 2. (461, 'Mitchell', 'Wagner')
# 3. (262, 'Craig', 'Stevens')
# 4. (23, 'Drew', 'Spencer')
# 5. (501, 'Jonathan', 'Smith')
# 6. (824, 'Michael', 'Shaw')
# 7. (293, 'Cindy', 'Russell')
# 8. (470, 'Steven', 'Robinson')
# 9. (882, 'Michele', 'Reid')
# 10. (863, 'Theresa', 'Peck')
# 11. (471, 'Mackenzie', 'Owens')
# 12. (876, 'Stephanie', 'Nelson')
# 13. (224, 'Amber', 'Morales')
# 14. (441, 'Julie', 'Morales')
# 15. (585, 'Shannon', 'Mcconnell')
# 16. (327, 'Deborah', 'Martinez')
# 17. (372, 'Kenneth', 'Livingston')
# 18. (219, 'Heidi', 'Kramer')
# 19. (74, 'Sara', 'Johnson')
# 20. (171, 'Wendy', 'Johnson')
# 21. (602, 'Amy', 'Johnson')
# 22. (805, 'Angela', 'Hernandez')
# 23. (811, 'William', 'Hayes')
# 24. (672, 'Elizabeth', 'Hansen')
# 25. (815, 'Michael', 'Gutierrez')
# 26. (246, 'Matthew', 'Greene')
# 27. (808, 'Wendy', 'Greene')
# 28. (553, 'Samantha', 'Garcia')
# 29. (21, 'Kevin', 'Dominguez')
# 30. (424, 'Mary', 'Compton')
# 31. (756, 'Rebecca', 'Cisneros')
# 32. (218, 'James', 'Brown')
# 33. (369, 'Stephanie', 'Bennett')
# 34. (10, 'Christine', 'Bell')
# 35. (294, 'Edward', 'Ball')

# %% [markdown]
# ### LIMIT
# This clause is used to constrain the number of rows in the result.

# %%
# This query shows the 10 most expensive products.
query = '''
SELECT StockCode,Category,Weight, UnitPrice FROM Products
ORDER BY UnitPrice DESC
LIMIT 10;
'''
execute_query(conn,query)
# Out:
# 1. ('YJ878305', 'Beauty', 2657, 117.55)
# 2. ('GU312892', 'Home', 2042, 92.53)
# 3. ('ST643511', 'Appliances', 3555, 91.76)
# 4. ('PY014422', 'Home', 2275, 87.8)
# 5. ('CC424913', 'Technology', 2106, 78.7)
# 6. ('DR752339', 'Appliances', 115, 78.53)
# 7. ('JX993569', 'Furniture', 3237, 75.89)
# 8. ('LD272389', 'Furniture', 3346, 72.06)
# 9. ('UC279555', 'Furniture', 352, 71.91)
# 10. ('SJ372509', 'Stationary', 1707, 71.86)

# %% [markdown]
# You can use `OFFSET` to skip a few rows.

# %%
# This query shows the next top 10 products with highest price.
# Since it is skipping the first 10 the result would be numbers 11-20
query = '''
SELECT StockCode,Category,Weight, UnitPrice FROM Products
ORDER BY UnitPrice DESC
LIMIT 10 OFFSET 10;
'''
execute_query(conn,query)
# Out:
# 1. ('DF577320', 'Stationary', 1361, 71.62)
# 2. ('TU924951', 'Furniture', 1841, 68.11)
# 3. ('NE964215', 'Home', 1322, 66.94)
# 4. ('DD186136', 'Clothing', 1581, 66.25)
# 5. ('QD294233', 'Furniture', 678, 65.15)
# 6. ('WV650733', 'Furniture', 462, 63.68)
# 7. ('AQ988179', 'Sports', 3787, 63.67)
# 8. ('KD402977', 'Home', 1840, 61.5)
# 9. ('YQ263581', 'Sports', 1271, 61.4)
# 10. ('VP150049', 'Furniture', 6730, 59.13)

# %% [markdown]
# **Note:** `LIMIT` should always be used with `ORDER BY` so the rows are always in a specific order.

# %% [markdown]
# ## Joins
# As you have probably noticed the data in this database is in various tables. Each table contains a specific part of data. For instance, one table has the information about invoices and another table has information about customers. These tables are linked together so we can find which invoice belongs to which customer. To do this we use various types of `JOIN`. Each join clause determines how SQLite uses data from one table to match with rows in another table.<br>
# Tables are connected using unique identifiers. For instance, __Sales__ table has a column called _CustomerId_. The same column name can be found in __Customers__ table. By looking up the customer id from invoices in the customers table we can find the information about the customer of each invoice.`JOIN` uses these identifiers to connect the tables and look up information.

# %% [markdown]
# ### INNER JOIN

# %%
query = '''
SELECT PurchaseDate,FirstName, Surname, ProductID, Quantity
FROM Sales
INNER JOIN Customers 
    ON Sales.CustomerId = Customers.CustomerId
ORDER BY PurchaseDate
LIMIT 20;
'''

execute_query(conn,query)
# Out:
# 1. ('2010-10-29', 'Cheyenne', 'Fletcher', 201, 2)
# 2. ('2010-11-23', 'Michael', 'Miller', 148, 2)
# 3. ('2010-11-23', 'Michael', 'Miller', 33, 1)
# 4. ('2010-11-23', 'Michael', 'Miller', 182, 1)
# 5. ('2011-01-02', 'Lisa', 'Terrell', 135, 1)
# 6. ('2011-01-05', 'Craig', 'Stevens', 127, 3)
# 7. ('2011-01-19', 'Craig', 'Stevens', 42, 1)
# 8. ('2011-01-19', 'Craig', 'Stevens', 261, 2)
# 9. ('2011-01-19', 'Craig', 'Stevens', 84, 1)
# 10. ('2011-02-15', 'Lauren', 'Dickerson', 289, 1)
# 11. ('2011-04-08', 'Natasha', 'Wolf', 205, 3)
# 12. ('2011-04-29', 'Katie', 'Thompson', 262, 3)
# 13. ('2011-04-29', 'Katie', 'Thompson', 77, 1)
# 14. ('2011-04-30', 'Michael', 'Miller', 247, 1)
# 15. ('2011-04-30', 'Michael', 'Miller', 48, 4)
# 16. ('2011-05-09', 'Jessica', 'Pierce', 39, 2)
# 17. ('2011-05-09', 'Jessica', 'Pierce', 211, 1)
# 18. ('2011-05-09', 'Isaac', 'Price', 129, 3)
# 19. ('2011-05-18', 'Amy', 'Griffin', 185, 2)
# 20. ('2011-05-18', 'Amy', 'Griffin', 160, 2)

# %%
# This query shows the purchase history of customers

query = '''
SELECT Surname, ProductID, Quantity, PurchaseDate
FROM Customers
INNER JOIN Sales ON
    Customers.CustomerID = Sales.CustomerID
ORDER BY Surname;
'''
execute_query(conn,query)
# Out:
# 1. ('Acosta', 196, 1, '2017-04-08')
# 2. ('Acosta', 65, 1, '2019-02-17')
# 3. ('Acosta', 138, 1, '2019-02-17')
# 4. ('Adams', 43, 1, '2013-02-03')
# 5. ('Adams', 149, 2, '2013-02-03')
# 6. ('Adams', 59, 2, '2017-06-11')
# 7. ('Adams', 247, 1, '2017-06-11')
# 8. ('Adams', 69, 1, '2017-06-11')
# 9. ('Adams', 48, 2, '2019-11-10')
# 10. ('Adams', 223, 3, '2019-11-10')
# 11. ('Adams', 199, 1, '2013-11-10')
# 12. ('Adams', 88, 1, '2013-11-10')
# 13. ('Adams', 77, 1, '2013-11-10')
# 14. ('Adams', 211, 2, '2019-11-17')
# 15. ('Adams', 233, 1, '2018-03-18')
# 16. ('Adams', 200, 2, '2020-06-01')
# 17. ('Adams', 276, 1, '2020-06-14')
# 18. ('Adams', 58, 2, '2020-07-01')
# 19. ('Adams', 15, 1, '2018-11-01')
# 20. ('Adams', 13, 1, '2018-11-01')
# 21. ('Adams', 181, 1, '2019-04-30')
# 22. ('Adams', 156, 1, '2019-04-30')
# 23. ('Adams', 65, 3, '2020-07-29')
# 24. ('Aguirre', 286, 1, '2017-04-27')
# 25. ('Aguirre', 170, 2, '2020-06-26')
# 26. ('Alexander', 83, 1, '2015-01-15')
# 27. ('Alexander', 266, 2, '2015-11-09')
# 28. ('Alexander', 266, 1, '2015-11-09')
# 29. ('Alexander', 83, 1, '2016-08-12')
# 30. ('Ali', 54, 1, '2018-06-17')
# 31. ('Ali', 184, 1, '2018-02-13')
# 32. ('Ali', 164, 1, '2018-08-02')
# 33. ('Ali', 291, 1, '2018-08-02')
# 34. ('Allen', 125, 4, '2017-04-17')
# 35. ('Allen', 275, 3, '2019-12-10')
# 36. ('Allen', 164, 1, '2016-12-12')
# 37. ('Allen', 249, 4, '2019-09-08')
# 38. ('Allen', 121, 1, '2016-06-25')
# 39. ('Allen', 29, 1, '2016-06-25')
# 40. ('Allen', 294, 1, '2016-06-25')
# 41. ('Alvarez', 292, 3, '2013-08-22')
# 42. ('Alvarez', 227, 1, '2013-08-22')
# 43. ('Alvarez', 262, 5, '2014-12-07')
# 44. ('Alvarez', 86, 1, '2014-01-15')
# 45. ('Alvarez', 258, 1, '2014-01-15')
# 46. ('Alvarez', 107, 2, '2014-01-15')
# 47. ('Alvarez', 293, 4, '2014-01-15')
# 48. ('Andersen', 22, 2, '2016-10-01')
# 49. ('Andersen', 181, 3, '2016-10-01')
# 50. ('Andersen', 168, 1, '2017-08-09')
# 51. ('Andersen', 20, 1, '2017-08-09')
# 52. ('Andersen', 271, 3, '2017-08-09')
# 53. ('Andersen', 90, 1, '2019-06-19')
# 54. ('Andersen', 29, 2, '2019-06-19')
# 55. ('Anderson', 104, 3, '2018-03-26')
# 56. ('Anderson', 65, 4, '2019-11-02')
# 57. ('Anderson', 24, 1, '2019-11-02')
# 58. ('Anderson', 137, 1, '2014-02-18')
# 59. ('Anderson', 116, 1, '2016-04-07')
# 60. ('Anderson', 222, 1, '2016-04-07')
# 61. ('Anderson', 161, 2, '2016-04-07')
# 62. ('Anderson', 16, 3, '2016-04-07')
# 63. ('Anderson', 267, 2, '2016-05-18')
# 64. ('Anderson', 293, 1, '2016-04-23')
# 65. ('Anderson', 216, 2, '2016-04-23')
# 66. ('Anderson', 272, 1, '2015-05-31')
# 67. ('Anderson', 60, 4, '2015-05-31')
# 68. ('Anderson', 152, 1, '2019-09-30')
# 69. ('Anderson', 229, 1, '2017-10-15')
# 70. ('Anderson', 263, 3, '2017-10-15')
# 71. ('Andrade', 252, 3, '2019-09-14')
# 72. ('Andrews', 239, 1, '2018-09-06')
# 73. ('Andrews', 186, 4, '2018-09-06')
# 74. ('Andrews', 35, 3, '2018-09-06')
# 75. ('Andrews', 157, 4, '2020-02-28')
# 76. ('Andrews', 16, 2, '2019-11-05')
# 77. ('Andrews', 16, 1, '2019-11-05')
# 78. ('Andrews', 18, 1, '2019-11-05')
# 79. ('Andrews', 37, 1, '2014-12-01')
# 80. ('Andrews', 237, 2, '2017-07-23')
# 81. ('Andrews', 267, 1, '2018-10-17')
# 82. ('Andrews', 158, 1, '2018-10-17')
# 83. ('Andrews', 18, 2, '2017-03-31')
# 84. ('Andrews', 195, 1, '2017-03-31')
# 85. ('Andrews', 143, 1, '2019-05-05')
# 86. ('Andrews', 34, 1, '2020-06-13')
# 87. ('Anthony', 222, 2, '2019-09-03')
# 88. ('Anthony', 4, 3, '2019-09-03')
# 89. ('Anthony', 216, 1, '2017-01-25')
# 90. ('Anthony', 44, 1, '2015-05-30')
# 91. ('Anthony', 83, 1, '2015-05-30')
# 92. ('Anthony', 211, 1, '2015-05-30')
# 93. ('Anthony', 63, 4, '2019-11-12')
# 94. ('Anthony', 138, 2, '2019-08-11')
# 95. ('Arellano', 45, 3, '2016-09-30')
# 96. ('Arellano', 82, 1, '2016-09-30')
# 97. ('Arellano', 89, 2, '2020-02-22')
# 98. ('Arellano', 174, 1, '2020-02-22')
# 99. ('Arellano', 63, 1, '2020-02-22')
# 100. ('Arellano', 253, 3, '2019-11-25')
# 101. ('Arnold', 233, 2, '2016-01-01')
# 102. ('Arnold', 46, 2, '2016-01-01')
# 103. ('Arnold', 159, 1, '2019-06-29')
# 104. ('Arnold', 145, 1, '2019-06-29')
# 105. ('Arnold', 290, 1, '2020-03-28')
# 106. ('Arnold', 5, 1, '2020-03-28')
# 107. ('Arnold', 8, 5, '2020-03-28')
# 108. ('Arnold', 66, 1, '2020-03-28')
# 109. ('Arnold', 50, 1, '2019-01-24')
# 110. ('Arnold', 127, 1, '2019-08-31')
# 111. ('Arnold', 66, 8, '2019-08-31')
# 112. ('Atkinson', 272, 3, '2020-01-23')
# 113. ('Atkinson', 62, 1, '2020-01-23')
# 114. ('Bailey', 50, 1, '2020-04-20')
# 115. ('Bailey', 241, 1, '2020-04-20')
# 116. ('Bailey', 189, 2, '2018-06-05')
# 117. ('Bailey', 41, 1, '2018-06-05')
# 118. ('Bailey', 208, 3, '2019-01-27')
# 119. ('Bailey', 99, 5, '2019-01-27')
# 120. ('Bailey', 158, 3, '2020-01-09')
# 121. ('Bailey', 86, 1, '2020-06-20')
# 122. ('Bailey', 249, 2, '2019-10-30')
# 123. ('Bailey', 197, 1, '2020-06-10')
# 124. ('Bailey', 282, 2, '2020-06-10')
# 125. ('Bailey', 218, 1, '2020-05-21')
# 126. ('Bailey', 81, 3, '2020-05-21')
# 127. ('Bailey', 48, 1, '2017-07-04')
# 128. ('Bailey', 251, 1, '2017-07-04')
# 129. ('Bailey', 38, 2, '2017-07-04')
# 130. ('Bailey', 108, 3, '2019-03-20')
# 131. ('Bailey', 155, 1, '2019-03-20')
# 132. ('Baker', 120, 1, '2016-09-26')
# 133. ('Baker', 168, 1, '2012-07-31')
# 134. ('Baldwin', 212, 7, '2020-07-18')
# 135. ('Baldwin', 220, 1, '2020-07-18')
# 136. ('Baldwin', 47, 1, '2020-07-18')
# 137. ('Ball', 284, 1, '2017-10-24')
# 138. ('Ball', 237, 1, '2020-01-02')
# 139. ('Ball', 219, 1, '2020-01-02')
# 140. ('Ball', 153, 1, '2020-01-02')
# 141. ('Barajas', 17, 2, '2020-04-23')
# 142. ('Barajas', 224, 1, '2020-02-10')
# 143. ('Barnes', 111, 4, '2016-05-07')
# 144. ('Barnes', 205, 1, '2012-07-05')
# 145. ('Barnett', 24, 1, '2018-12-07')
# 146. ('Barnett', 95, 1, '2019-11-11')
# 147. ('Barnett', 1, 1, '2018-07-14')
# 148. ('Barnett', 65, 1, '2018-07-14')
# 149. ('Barnett', 255, 3, '2017-01-02')
# 150. ('Barnett', 157, 1, '2017-01-02')
# 151. ('Barnett', 170, 3, '2017-01-02')
# 152. ('Barnett', 138, 2, '2016-06-05')
# 153. ('Barnett', 56, 2, '2016-06-05')
# 154. ('Barr', 155, 1, '2019-02-08')
# 155. ('Barr', 167, 1, '2019-02-08')
# 156. ('Barr', 119, 1, '2018-03-23')
# 157. ('Barr', 201, 3, '2018-03-23')
# 158. ('Barrera', 139, 1, '2015-07-12')
# 159. ('Barrera', 77, 3, '2015-07-12')
# 160. ('Barrera', 190, 1, '2015-07-12')
# 161. ('Barrera', 144, 2, '2018-01-29')
# 162. ('Barrera', 261, 2, '2018-01-29')
# 163. ('Barrera', 212, 1, '2015-02-16')
# 164. ('Barrera', 244, 1, '2017-09-25')
# 165. ('Barrera', 196, 3, '2017-09-25')
# 166. ('Barrera', 131, 2, '2017-09-25')
# 167. ('Barrera', 288, 1, '2017-09-25')
# 168. ('Barrera', 88, 2, '2017-09-25')
# 169. ('Barrera', 284, 1, '2018-11-22')
# 170. ('Barrera', 264, 3, '2019-11-11')
# 171. ('Barrera', 140, 1, '2019-11-11')
# 172. ('Barrett', 192, 2, '2018-10-01')
# 173. ('Barrett', 256, 3, '2018-10-01')
# 174. ('Barrett', 62, 2, '2018-10-01')
# 175. ('Barrett', 13, 2, '2013-02-09')
# 176. ('Barrett', 130, 1, '2019-08-08')
# 177. ('Barrett', 63, 1, '2019-08-08')
# 178. ('Barrett', 127, 3, '2019-08-08')
# 179. ('Barrett', 235, 4, '2019-02-16')
# 180. ('Barrett', 88, 2, '2019-02-16')
# 181. ('Barrett', 42, 6, '2019-02-16')
# 182. ('Barrett', 267, 4, '2019-02-16')
# 183. ('Barry', 39, 2, '2020-04-18')
# 184. ('Barry', 108, 1, '2020-04-18')
# 185. ('Barry', 184, 2, '2015-12-17')
# 186. ('Barry', 100, 2, '2013-03-17')
# 187. ('Barry', 114, 1, '2013-03-17')
# 188. ('Bauer', 97, 1, '2019-02-20')
# 189. ('Bauer', 105, 2, '2019-02-20')
# 190. ('Bauer', 278, 3, '2019-02-20')
# 191. ('Bauer', 192, 1, '2018-10-22')
# 192. ('Bauer', 28, 1, '2020-07-04')
# 193. ('Bauer', 144, 3, '2020-07-04')
# 194. ('Bauer', 284, 1, '2020-07-04')
# 195. ('Bauer', 249, 4, '2020-07-14')
# 196. ('Bauer', 71, 1, '2020-07-14')
# 197. ('Bauer', 242, 1, '2018-05-18')
# 198. ('Beck', 80, 2, '2020-02-07')
# 199. ('Beck', 266, 2, '2020-01-08')
# 200. ('Beck', 200, 1, '2019-08-31')
# 201. ('Bell', 266, 1, '2014-05-13')
# 202. ('Bell', 198, 1, '2014-05-13')
# 203. ('Bell', 26, 1, '2014-05-13')
# 204. ('Bell', 265, 2, '2020-03-01')
# 205. ('Bell', 14, 3, '2020-05-06')
# 206. ('Bell', 58, 1, '2020-05-06')
# 207. ('Bell', 41, 1, '2020-05-06')
# 208. ('Bell', 290, 1, '2020-06-12')
# 209. ('Bell', 77, 4, '2018-03-01')
# 210. ('Bell', 79, 10, '2018-03-01')
# 211. ('Bell', 102, 1, '2020-03-31')
# 212. ('Bell', 170, 4, '2020-03-31')
# 213. ('Bell', 160, 1, '2020-04-27')
# 214. ('Bell', 282, 1, '2020-04-27')
# 215. ('Bell', 7, 1, '2015-12-27')
# 216. ('Bell', 5, 2, '2015-12-27')
# 217. ('Bell', 16, 1, '2019-04-05')
# 218. ('Bell', 123, 1, '2020-05-09')
# 219. ('Bell', 122, 1, '2020-05-09')
# 220. ('Bell', 97, 2, '2020-05-09')
# 221. ('Benjamin', 272, 1, '2018-12-05')
# 222. ('Benjamin', 246, 1, '2015-07-13')
# 223. ('Benjamin', 280, 1, '2015-07-13')
# 224. ('Benjamin', 54, 4, '2015-07-13')
# 225. ('Benjamin', 10, 1, '2017-09-12')
# 226. ('Benjamin', 203, 1, '2017-09-12')
# 227. ('Bennett', 138, 2, '2017-07-27')
# 228. ('Bennett', 260, 3, '2017-07-09')
# 229. ('Bennett', 62, 1, '2017-03-14')
# 230. ('Bennett', 73, 1, '2019-08-06')
# 231. ('Bennett', 255, 1, '2019-06-09')
# 232. ('Bennett', 139, 1, '2020-01-31')
# 233. ('Bennett', 237, 4, '2020-01-31')
# 234. ('Bennett', 173, 1, '2017-07-31')
# 235. ('Bennett', 31, 1, '2018-05-04')
# 236. ('Bennett', 219, 3, '2019-05-20')
# 237. ('Bennett', 247, 2, '2019-05-20')
# 238. ('Bennett', 177, 2, '2017-08-16')
# 239. ('Bennett', 26, 1, '2018-04-25')
# 240. ('Bennett', 238, 8, '2019-10-15')
# 241. ('Bennett', 76, 4, '2018-01-30')
# 242. ('Bennett', 122, 1, '2018-01-30')
# 243. ('Benson', 254, 1, '2019-12-31')
# 244. ('Benson', 19, 2, '2019-12-31')
# 245. ('Benson', 171, 2, '2014-05-13')
# 246. ('Benson', 132, 1, '2019-03-30')
# 247. ('Benson', 188, 1, '2017-03-28')
# 248. ('Benson', 35, 1, '2017-03-28')
# 249. ('Bentley', 10, 1, '2017-08-30')
# 250. ('Bentley', 1, 1, '2017-08-30')
# 251. ('Bentley', 83, 1, '2019-04-15')
# 252. ('Bentley', 272, 1, '2019-04-15')
# 253. ('Bentley', 247, 1, '2018-01-05')
# 254. ('Benton', 218, 2, '2018-07-13')
# 255. ('Benton', 248, 1, '2019-11-14')
# 256. ('Berger', 99, 4, '2020-06-01')
# 257. ('Berger', 96, 2, '2020-06-01')
# 258. ('Best', 241, 2, '2018-05-10')
# 259. ('Best', 55, 1, '2018-05-10')
# 260. ('Best', 66, 3, '2019-02-04')
# 261. ('Best', 132, 1, '2019-02-04')
# 262. ('Best', 4, 3, '2019-02-04')
# 263. ('Bishop', 30, 1, '2018-12-20')
# 264. ('Bishop', 65, 1, '2018-12-20')
# 265. ('Bishop', 131, 1, '2018-12-20')
# 266. ('Bishop', 141, 1, '2016-01-29')
# 267. ('Bishop', 2, 1, '2016-01-29')
# 268. ('Bishop', 142, 1, '2016-07-24')
# 269. ('Bishop', 252, 1, '2016-07-24')
# 270. ('Bishop', 176, 9, '2018-06-06')
# 271. ('Bolton', 258, 1, '2020-04-08')
# 272. ('Bolton', 27, 2, '2016-01-19')
# 273. ('Bolton', 152, 2, '2016-01-19')
# 274. ('Bolton', 95, 2, '2015-08-03')
# 275. ('Bond', 247, 1, '2020-05-08')
# 276. ('Bond', 15, 1, '2020-05-31')
# 277. ('Bowman', 104, 3, '2013-01-09')
# 278. ('Bowman', 282, 3, '2019-02-26')
# 279. ('Bowman', 81, 1, '2019-02-26')
# 280. ('Boyer', 20, 1, '2019-01-22')
# 281. ('Boyer', 252, 4, '2017-01-13')
# 282. ('Boyer', 63, 1, '2017-01-13')
# 283. ('Boyer', 218, 2, '2017-07-31')
# 284. ('Boyer', 209, 4, '2017-07-31')
# 285. ('Boyer', 217, 4, '2018-05-04')
# 286. ('Boyle', 218, 1, '2015-07-31')
# 287. ('Boyle', 220, 1, '2015-07-31')
# 288. ('Boyle', 260, 6, '2015-07-31')
# 289. ('Boyle', 270, 3, '2020-07-11')
# 290. ('Boyle', 113, 1, '2018-08-29')
# 291. ('Boyle', 73, 2, '2019-02-04')
# 292. ('Bradley', 18, 1, '2020-05-27')
# 293. ('Bradley', 256, 1, '2017-06-17')
# 294. ('Bradley', 225, 1, '2017-06-17')
# 295. ('Bradley', 16, 1, '2017-06-17')
# 296. ('Bradley', 141, 3, '2019-08-03')
# 297. ('Bradley', 248, 1, '2014-06-14')
# 298. ('Bradley', 74, 1, '2014-06-14')
# 299. ('Bradley', 107, 1, '2018-11-16')
# 300. ('Bradley', 158, 3, '2019-12-14')
# 301. ('Bradley', 2, 1, '2018-12-29')
# 302. ('Bradley', 255, 1, '2017-02-18')
# 303. ('Bradley', 39, 8, '2017-02-18')
# 304. ('Bradley', 75, 3, '2020-06-09')
# 305. ('Branch', 23, 2, '2018-08-29')
# 306. ('Branch', 143, 3, '2019-06-12')
# 307. ('Branch', 251, 1, '2019-05-26')
# 308. ('Brewer', 202, 3, '2017-08-05')
# 309. ('Brewer', 248, 1, '2017-08-05')
# 310. ('Brewer', 98, 1, '2015-04-25')
# 311. ('Bright', 124, 1, '2018-03-23')
# 312. ('Brooks', 218, 1, '2019-05-12')
# 313. ('Brooks', 186, 2, '2019-05-12')
# 314. ('Brooks', 35, 2, '2019-05-12')
# 315. ('Brown', 281, 2, '2014-10-07')
# 316. ('Brown', 117, 1, '2017-11-05')
# 317. ('Brown', 236, 1, '2017-11-05')
# 318. ('Brown', 253, 2, '2017-11-05')
# 319. ('Brown', 105, 1, '2019-05-20')
# 320. ('Brown', 116, 2, '2020-05-14')
# 321. ('Brown', 240, 5, '2013-04-09')
# 322. ('Brown', 167, 1, '2018-01-23')
# 323. ('Brown', 91, 2, '2018-01-23')
# 324. ('Brown', 153, 1, '2014-04-12')
# 325. ('Brown', 280, 2, '2013-07-30')
# 326. ('Brown', 21, 1, '2016-01-22')
# 327. ('Brown', 219, 1, '2016-01-22')
# 328. ('Brown', 82, 3, '2018-06-12')
# 329. ('Brown', 204, 3, '2018-01-01')
# 330. ('Brown', 69, 2, '2018-01-01')
# 331. ('Brown', 13, 2, '2019-09-03')
# 332. ('Brown', 53, 1, '2019-11-17')
# 333. ('Brown', 278, 2, '2019-11-17')
# 334. ('Brown', 194, 3, '2015-12-03')
# 335. ('Brown', 45, 1, '2017-04-14')
# 336. ('Brown', 254, 2, '2017-04-14')
# 337. ('Brown', 88, 1, '2017-04-14')
# 338. ('Brown', 155, 2, '2015-08-25')
# 339. ('Brown', 244, 2, '2015-08-25')
# 340. ('Brown', 283, 2, '2015-04-12')
# 341. ('Brown', 36, 1, '2014-02-04')
# 342. ('Buckley', 177, 1, '2019-02-21')
# 343. ('Buckley', 104, 3, '2019-02-21')
# 344. ('Buckley', 45, 1, '2017-02-10')
# 345. ('Bullock', 111, 3, '2016-07-07')
# 346. ('Bullock', 162, 1, '2016-07-07')
# 347. ('Bullock', 17, 1, '2015-12-13')
# 348. ('Bullock', 24, 2, '2015-12-13')
# 349. ('Burch', 197, 5, '2020-06-12')
# 350. ('Burch', 87, 2, '2020-06-28')
# 351. ('Burch', 131, 1, '2020-07-19')
# 352. ('Burch', 248, 1, '2020-07-19')
# 353. ('Burch', 131, 1, '2020-07-01')
# 354. ('Burch', 215, 1, '2020-07-01')
# 355. ('Burch', 99, 3, '2020-07-01')
# 356. ('Burns', 244, 1, '2019-07-10')
# 357. ('Burns', 79, 3, '2019-07-10')
# 358. ('Burns', 125, 1, '2019-07-10')
# 359. ('Burton', 160, 2, '2019-08-30')
# 360. ('Burton', 148, 1, '2019-08-30')
# 361. ('Burton', 287, 1, '2020-07-23')
# 362. ('Burton', 157, 1, '2020-07-23')
# 363. ('Bush', 77, 4, '2016-11-09')
# 364. ('Bush', 151, 1, '2017-12-28')
# 365. ('Bush', 253, 1, '2017-12-28')
# 366. ('Butler', 113, 1, '2019-12-12')
# 367. ('Byrd', 134, 1, '2011-10-17')
# 368. ('Byrd', 36, 2, '2011-10-17')
# 369. ('Byrd', 205, 2, '2011-10-17')
# 370. ('Byrd', 142, 1, '2015-03-06')
# 371. ('Byrd', 213, 3, '2015-03-06')
# 372. ('Cabrera', 246, 1, '2018-05-24')
# 373. ('Cabrera', 197, 1, '2017-08-03')
# 374. ('Cabrera', 270, 1, '2017-08-03')
# 375. ('Cain', 54, 1, '2020-01-21')
# 376. ('Cain', 48, 1, '2018-06-08')
# 377. ('Callahan', 60, 1, '2020-07-11')
# 378. ('Camacho', 41, 1, '2011-11-21')
# 379. ('Camacho', 147, 1, '2011-11-21')
# 380. ('Camacho', 167, 1, '2011-11-21')
# 381. ('Cameron', 45, 1, '2018-06-30')
# 382. ('Cameron', 274, 1, '2018-06-30')
# 383. ('Cameron', 42, 2, '2018-06-30')
# 384. ('Cameron', 64, 2, '2018-06-30')
# 385. ('Cameron', 236, 1, '2017-11-15')
# 386. ('Cameron', 45, 1, '2020-04-20')
# 387. ('Cameron', 263, 1, '2020-04-20')
# 388. ('Cameron', 288, 4, '2020-04-20')
# 389. ('Cameron', 16, 4, '2020-04-20')
# 390. ('Cameron', 282, 1, '2018-12-25')
# 391. ('Campbell', 157, 2, '2020-01-03')
# 392. ('Campbell', 192, 2, '2020-01-03')
# 393. ('Campbell', 18, 1, '2012-06-02')
# 394. ('Campbell', 106, 2, '2017-03-18')
# 395. ('Campbell', 63, 1, '2017-03-18')
# 396. ('Campbell', 206, 2, '2019-01-30')
# 397. ('Campbell', 48, 1, '2015-08-16')
# 398. ('Campbell', 6, 1, '2015-08-16')
# 399. ('Campbell', 276, 2, '2015-08-16')
# 400. ('Cardenas', 3, 2, '2020-06-25')
# 401. ('Cardenas', 189, 1, '2020-06-25')
# 402. ('Carlson', 187, 4, '2019-10-03')
# 403. ('Carlson', 50, 1, '2016-10-06')
# 404. ('Carlson', 35, 1, '2016-10-06')
# 405. ('Carlson', 52, 1, '2015-07-26')
# 406. ('Carlson', 8, 6, '2015-07-26')
# 407. ('Carlson', 217, 5, '2015-07-26')
# 408. ('Carlson', 182, 1, '2017-01-29')
# 409. ('Carlson', 180, 4, '2017-01-29')
# 410. ('Carlson', 66, 4, '2018-12-21')
# 411. ('Carlson', 10, 1, '2014-07-04')
# 412. ('Carlson', 142, 2, '2017-05-28')
# 413. ('Carlson', 156, 2, '2017-05-28')
# 414. ('Carlson', 277, 2, '2015-05-31')
# 415. ('Carlson', 205, 1, '2015-05-31')
# 416. ('Carpenter', 34, 1, '2019-12-24')
# 417. ('Carpenter', 267, 2, '2019-12-24')
# 418. ('Carpenter', 47, 3, '2015-04-01')
# 419. ('Carpenter', 178, 2, '2015-04-01')
# 420. ('Carr', 4, 1, '2020-03-01')
# 421. ('Carr', 233, 1, '2020-03-01')
# 422. ('Carr', 17, 1, '2020-03-01')
# 423. ('Carr', 275, 1, '2020-07-15')
# 424. ('Carr', 68, 1, '2018-04-11')
# 425. ('Carr', 157, 3, '2020-07-03')
# 426. ('Carr', 222, 1, '2020-07-03')
# 427. ('Carr', 86, 3, '2020-06-21')
# 428. ('Carr', 47, 1, '2020-06-21')
# 429. ('Carr', 219, 1, '2020-06-21')
# 430. ('Carroll', 75, 2, '2014-02-15')
# 431. ('Carroll', 20, 2, '2020-04-03')
# 432. ('Carroll', 61, 1, '2020-04-03')
# 433. ('Carter', 262, 2, '2015-11-04')
# 434. ('Carter', 201, 4, '2015-11-04')
# 435. ('Carter', 117, 2, '2015-11-04')
# 436. ('Carter', 171, 2, '2015-11-04')
# 437. ('Carter', 98, 1, '2015-11-04')
# 438. ('Carter', 210, 1, '2019-10-06')
# 439. ('Case', 171, 1, '2015-01-02')
# 440. ('Case', 206, 2, '2015-01-02')
# 441. ('Case', 23, 7, '2015-01-02')
# 442. ('Case', 274, 1, '2015-01-02')
# 443. ('Case', 136, 2, '2015-09-24')
# 444. ('Casey', 24, 1, '2014-12-14')
# 445. ('Casey', 152, 2, '2014-12-14')
# 446. ('Casey', 42, 2, '2016-07-19')
# 447. ('Casey', 46, 1, '2016-07-19')
# 448. ('Castillo', 218, 1, '2019-08-13')
# 449. ('Castillo', 233, 1, '2020-01-27')
# 450. ('Castillo', 212, 1, '2019-11-23')
# 451. ('Castillo', 163, 1, '2018-12-27')
# 452. ('Castillo', 263, 8, '2019-05-09')
# 453. ('Chambers', 180, 4, '2020-06-08')
# 454. ('Chambers', 263, 1, '2020-06-08')
# 455. ('Chaney', 244, 4, '2019-04-07')
# 456. ('Chaney', 116, 1, '2019-04-07')
# 457. ('Chaney', 151, 1, '2020-03-29')
# 458. ('Chaney', 236, 4, '2020-06-18')
# 459. ('Chaney', 148, 1, '2020-06-18')
# 460. ('Chaney', 213, 1, '2020-06-18')
# 461. ('Charles', 240, 1, '2016-06-20')
# 462. ('Charles', 246, 2, '2016-06-20')
# 463. ('Charles', 204, 2, '2016-06-20')
# 464. ('Charles', 238, 1, '2016-06-20')
# 465. ('Charles', 17, 4, '2017-09-22')
# 466. ('Charles', 270, 1, '2018-03-03')
# 467. ('Chavez', 144, 1, '2016-01-09')
# 468. ('Chavez', 110, 1, '2016-01-09')
# 469. ('Cisneros', 120, 1, '2018-10-27')
# 470. ('Cisneros', 41, 1, '2018-07-15')
# 471. ('Clark', 182, 3, '2017-05-04')
# 472. ('Clark', 243, 2, '2016-11-10')
# 473. ('Clark', 27, 2, '2013-10-04')
# 474. ('Clark', 228, 2, '2013-10-04')
# 475. ('Clark', 7, 1, '2013-10-04')
# 476. ('Clark', 18, 1, '2020-07-09')
# 477. ('Clark', 194, 1, '2020-07-09')
# 478. ('Clark', 268, 2, '2019-12-07')
# 479. ('Clark', 205, 5, '2019-12-07')
# 480. ('Clark', 148, 2, '2013-02-21')
# 481. ('Clark', 225, 2, '2013-02-21')
# 482. ('Clark', 79, 1, '2020-07-13')
# 483. ('Clark', 157, 1, '2020-07-13')
# 484. ('Clark', 6, 1, '2020-07-13')
# 485. ('Clark', 217, 4, '2013-08-01')
# 486. ('Clark', 203, 3, '2016-10-18')
# 487. ('Clark', 61, 1, '2016-10-18')
# 488. ('Clark', 152, 1, '2020-04-15')
# 489. ('Clark', 113, 2, '2020-04-02')
# 490. ('Clark', 99, 2, '2020-04-02')
# 491. ('Clark', 243, 2, '2015-08-10')
# 492. ('Clark', 132, 3, '2018-05-21')
# 493. ('Clark', 263, 1, '2018-05-21')
# 494. ('Clark', 154, 3, '2019-07-31')
# 495. ('Clark', 176, 1, '2019-07-31')
# 496. ('Clark', 201, 1, '2019-06-02')
# 497. ('Clark', 35, 2, '2019-08-25')
# 498. ('Coffey', 205, 1, '2017-12-13')
# 499. ('Coffey', 54, 5, '2013-04-25')
# 500. ('Coffey', 103, 1, '2013-04-25')
# 501. ('Coffey', 220, 2, '2013-04-25')
# 502. ('Coleman', 242, 1, '2018-02-28')
# 503. ('Coleman', 25, 1, '2018-02-28')
# 504. ('Coleman', 76, 1, '2014-02-19')
# 505. ('Collier', 47, 2, '2019-02-02')
# 506. ('Collier', 241, 1, '2019-02-02')
# 507. ('Collins', 263, 1, '2014-03-23')
# 508. ('Collins', 103, 1, '2020-04-20')
# 509. ('Collins', 127, 2, '2020-06-06')
# 510. ('Collins', 121, 3, '2017-12-12')
# 511. ('Collins', 213, 1, '2012-10-12')
# 512. ('Collins', 163, 1, '2012-10-12')
# 513. ('Collins', 31, 2, '2012-10-12')
# 514. ('Collins', 13, 1, '2012-10-12')
# 515. ('Collins', 252, 2, '2017-06-25')
# 516. ('Collins', 24, 2, '2017-06-25')
# 517. ('Collins', 190, 1, '2017-08-06')
# 518. ('Collins', 157, 1, '2018-12-21')
# 519. ('Collins', 20, 1, '2018-12-21')
# 520. ('Combs', 202, 1, '2019-02-03')
# 521. ('Combs', 105, 1, '2019-02-03')
# 522. ('Compton', 187, 2, '2019-01-13')
# 523. ('Compton', 112, 2, '2019-01-13')
# 524. ('Cook', 45, 2, '2013-01-27')
# 525. ('Cook', 160, 3, '2020-02-03')
# 526. ('Cook', 141, 2, '2014-08-21')
# 527. ('Cooke', 135, 2, '2015-12-19')
# 528. ('Cooke', 140, 3, '2012-11-11')
# 529. ('Cooke', 58, 3, '2012-11-11')
# 530. ('Cooke', 68, 1, '2020-07-10')
# 531. ('Cooke', 273, 1, '2020-07-10')
# 532. ('Cooper', 74, 1, '2018-10-06')
# 533. ('Cooper', 232, 2, '2019-08-15')
# 534. ('Copeland', 277, 2, '2016-06-03')
# 535. ('Copeland', 222, 1, '2016-06-03')
# 536. ('Copeland', 58, 2, '2016-06-03')
# 537. ('Copeland', 78, 1, '2016-12-20')
# 538. ('Copeland', 120, 3, '2016-12-20')
# 539. ('Copeland', 211, 2, '2016-12-20')
# 540. ('Copeland', 243, 1, '2019-05-01')
# 541. ('Copeland', 64, 4, '2018-03-07')
# 542. ('Copeland', 208, 2, '2018-03-07')
# 543. ('Copeland', 54, 1, '2019-12-10')
# 544. ('Cox', 157, 1, '2012-10-05')
# 545. ('Cox', 134, 1, '2012-10-05')
# 546. ('Cox', 283, 1, '2019-07-26')
# 547. ('Cox', 195, 7, '2020-02-26')
# 548. ('Cox', 170, 2, '2015-08-15')
# 549. ('Cox', 78, 1, '2015-08-15')
# 550. ('Cox', 233, 4, '2020-07-13')
# 551. ('Cox', 39, 1, '2020-07-13')
# 552. ('Cox', 269, 1, '2018-11-24')
# 553. ('Cox', 7, 1, '2018-11-24')
# 554. ('Cox', 63, 1, '2015-11-14')
# 555. ('Cox', 139, 2, '2020-07-22')
# 556. ('Cox', 105, 9, '2020-07-22')
# 557. ('Cox', 132, 2, '2014-04-13')
# 558. ('Cox', 145, 4, '2014-04-13')
# 559. ('Cox', 293, 2, '2014-04-13')
# 560. ('Craig', 91, 1, '2018-02-17')
# 561. ('Craig', 7, 1, '2018-02-17')
# 562. ('Craig', 111, 2, '2018-03-26')
# 563. ('Craig', 241, 1, '2018-03-26')
# 564. ('Craig', 17, 2, '2015-04-13')
# 565. ('Craig', 74, 1, '2015-11-01')
# 566. ('Craig', 248, 5, '2015-11-01')
# 567. ('Craig', 54, 1, '2020-01-18')
# 568. ('Cross', 57, 2, '2016-06-13')
# 569. ('Cross', 8, 2, '2016-12-15')
# 570. ('Cross', 232, 2, '2018-11-19')
# 571. ('Cross', 135, 1, '2018-11-19')
# 572. ('Cross', 16, 1, '2018-11-19')
# 573. ('Cruz', 270, 2, '2018-07-24')
# 574. ('Cruz', 15, 1, '2017-08-12')
# 575. ('Cruz', 78, 3, '2019-12-20')
# 576. ('Cruz', 79, 2, '2019-12-20')
# 577. ('Cruz', 31, 1, '2017-09-04')
# 578. ('Cruz', 246, 1, '2017-09-04')
# 579. ('Cruz', 145, 1, '2016-12-13')
# 580. ('Cruz', 57, 2, '2018-03-31')
# 581. ('Cruz', 80, 1, '2018-03-31')
# 582. ('Cruz', 118, 1, '2018-06-28')
# 583. ('Cruz', 86, 1, '2019-10-11')
# 584. ('Cruz', 95, 2, '2020-03-01')
# 585. ('Cruz', 16, 2, '2020-03-01')
# 586. ('Cruz', 33, 1, '2017-05-15')
# 587. ('Cummings', 115, 1, '2015-11-16')
# 588. ('Cummings', 116, 1, '2012-03-03')
# 589. ('Cummings', 169, 1, '2012-03-03')
# 590. ('Cummings', 137, 1, '2016-07-20')
# 591. ('Cummings', 279, 2, '2019-06-26')
# 592. ('Cummings', 80, 1, '2013-06-24')
# 593. ('Cummings', 75, 1, '2017-11-06')
# 594. ('Cummings', 40, 1, '2013-05-27')
# 595. ('Cummings', 198, 3, '2013-05-27')
# 596. ('Dalton', 23, 1, '2020-01-16')
# 597. ('Dalton', 229, 2, '2020-01-16')
# 598. ('Dalton', 23, 1, '2017-11-10')
# 599. ('Dalton', 233, 1, '2018-02-27')
# 600. ('Davenport', 290, 2, '2020-01-12')
# 601. ('Davenport', 160, 2, '2020-01-12')
# 602. ('Davenport', 186, 2, '2020-03-31')
# 603. ('Davenport', 252, 1, '2020-03-31')
# 604. ('David', 92, 1, '2019-05-28')
# 605. ('David', 192, 1, '2019-05-28')
# 606. ('David', 27, 1, '2014-07-23')
# 607. ('David', 255, 1, '2014-07-23')
# 608. ('David', 17, 2, '2017-02-19')
# 609. ('David', 277, 1, '2017-02-19')
# 610. ('David', 121, 1, '2017-02-19')
# 611. ('Davidson', 129, 2, '2016-03-16')
# 612. ('Davidson', 135, 1, '2016-03-16')
# 613. ('Davidson', 243, 1, '2020-01-06')
# 614. ('Davidson', 81, 7, '2020-01-06')
# 615. ('Davis', 139, 5, '2019-09-25')
# 616. ('Davis', 51, 1, '2019-09-25')
# 617. ('Davis', 64, 1, '2019-09-25')
# 618. ('Davis', 67, 3, '2020-02-10')
# 619. ('Davis', 258, 4, '2020-02-10')
# 620. ('Davis', 65, 2, '2020-02-10')
# 621. ('Davis', 212, 1, '2020-07-06')
# 622. ('Davis', 198, 6, '2020-07-06')
# 623. ('Davis', 152, 1, '2019-08-24')
# 624. ('Davis', 154, 1, '2019-08-24')
# 625. ('Davis', 40, 1, '2013-01-20')
# 626. ('Davis', 120, 1, '2013-01-20')
# 627. ('Davis', 35, 1, '2013-01-20')
# 628. ('Davis', 284, 1, '2014-03-03')
# 629. ('Davis', 105, 1, '2017-03-03')
# 630. ('Davis', 11, 3, '2019-01-30')
# 631. ('Davis', 45, 2, '2019-08-04')
# 632. ('Davis', 28, 1, '2019-08-04')
# 633. ('Davis', 63, 1, '2019-08-04')
# 634. ('Davis', 176, 1, '2013-10-17')
# 635. ('Davis', 14, 1, '2019-01-23')
# 636. ('Davis', 287, 2, '2019-01-23')
# 637. ('Davis', 248, 1, '2020-02-12')
# 638. ('Davis', 29, 1, '2020-02-12')
# 639. ('Davis', 224, 2, '2017-11-25')
# 640. ('Davis', 81, 1, '2020-03-04')
# 641. ('Davis', 213, 2, '2020-05-10')
# 642. ('Davis', 213, 1, '2020-05-10')
# 643. ('Davis', 121, 3, '2020-05-10')
# 644. ('Davis', 148, 1, '2015-04-18')
# 645. ('Davis', 172, 1, '2015-04-18')
# 646. ('Davis', 137, 1, '2015-04-18')
# 647. ('Davis', 253, 2, '2015-04-18')
# 648. ('Davis', 252, 1, '2014-03-11')
# 649. ('Davis', 79, 1, '2017-02-03')
# 650. ('Davis', 13, 1, '2020-07-05')
# 651. ('Dawson', 27, 1, '2018-09-13')
# 652. ('Dawson', 185, 1, '2018-09-13')
# 653. ('Dawson', 119, 3, '2017-12-10')
# 654. ('Dawson', 52, 2, '2017-12-10')
# 655. ('Dawson', 18, 3, '2018-08-06')
# 656. ('Dawson', 187, 3, '2017-07-08')
# 657. ('Dawson', 188, 2, '2017-07-08')
# 658. ('Dawson', 7, 1, '2017-07-08')
# 659. ('Decker', 73, 1, '2020-01-14')
# 660. ('Decker', 124, 1, '2020-01-14')
# 661. ('Decker', 235, 1, '2020-01-14')
# 662. ('Decker', 164, 1, '2017-10-08')
# 663. ('Decker', 81, 1, '2017-10-08')
# 664. ('Decker', 31, 3, '2017-10-08')
# 665. ('Decker', 158, 4, '2017-10-08')
# 666. ('Decker', 145, 1, '2020-07-20')
# 667. ('Dennis', 174, 1, '2018-01-12')
# 668. ('Dennis', 28, 2, '2018-01-12')
# 669. ('Diaz', 275, 2, '2020-01-14')
# 670. ('Diaz', 147, 2, '2020-01-14')
# 671. ('Diaz', 9, 1, '2019-05-19')
# 672. ('Diaz', 224, 2, '2019-05-19')
# 673. ('Diaz', 215, 1, '2017-02-25')
# 674. ('Diaz', 170, 2, '2017-02-25')
# 675. ('Diaz', 171, 2, '2019-12-24')
# 676. ('Diaz', 115, 1, '2019-12-24')
# 677. ('Diaz', 50, 2, '2019-12-24')
# 678. ('Diaz', 153, 4, '2019-07-25')
# 679. ('Diaz', 67, 1, '2019-07-25')
# 680. ('Diaz', 84, 2, '2019-07-07')
# 681. ('Diaz', 232, 5, '2020-03-14')
# 682. ('Diaz', 218, 2, '2015-12-24')
# 683. ('Diaz', 118, 1, '2015-12-24')
# 684. ('Diaz', 228, 2, '2018-11-15')
# 685. ('Dickerson', 213, 2, '2019-08-11')
# 686. ('Dickerson', 152, 1, '2019-08-11')
# 687. ('Dickerson', 120, 1, '2013-02-26')
# 688. ('Dickerson', 289, 1, '2011-02-15')
# 689. ('Dixon', 200, 1, '2020-07-28')
# 690. ('Dominguez', 243, 2, '2015-04-25')
# 691. ('Dominguez', 199, 4, '2019-12-24')
# 692. ('Duffy', 259, 1, '2020-07-04')
# 693. ('Duffy', 286, 1, '2020-07-04')
# 694. ('Duffy', 180, 1, '2020-07-04')
# 695. ('Duffy', 121, 2, '2020-05-01')
# 696. ('Duffy', 196, 1, '2020-05-01')
# 697. ('Duffy', 22, 3, '2020-07-03')
# 698. ('Duncan', 61, 2, '2020-02-15')
# 699. ('Duncan', 134, 3, '2019-11-13')
# 700. ('Duncan', 105, 6, '2019-11-13')
# 701. ('Duncan', 77, 1, '2019-11-13')
# 702. ('Duncan', 157, 2, '2016-03-11')
# 703. ('Duncan', 291, 1, '2020-07-01')
# 704. ('Duncan', 266, 4, '2019-08-21')
# 705. ('Duncan', 110, 1, '2019-08-21')
# 706. ('Duncan', 177, 2, '2019-08-21')
# 707. ('Duncan', 237, 5, '2019-10-31')
# 708. ('Duncan', 226, 1, '2019-10-31')
# 709. ('Dunn', 211, 1, '2019-09-02')
# 710. ('Dunn', 131, 2, '2019-09-02')
# 711. ('Dunn', 81, 1, '2019-09-02')
# 712. ('Dunn', 98, 2, '2019-08-02')
# 713. ('Dunn', 267, 1, '2015-04-06')
# 714. ('Dunn', 246, 2, '2015-04-06')
# 715. ('Dunn', 284, 1, '2019-02-28')
# 716. ('Dunn', 46, 2, '2020-02-03')
# 717. ('Edwards', 152, 1, '2019-09-24')
# 718. ('Edwards', 24, 1, '2020-04-17')
# 719. ('Edwards', 48, 1, '2020-04-17')
# 720. ('Edwards', 182, 1, '2018-09-26')
# 721. ('Edwards', 255, 2, '2014-12-12')
# 722. ('Edwards', 216, 1, '2014-12-12')
# 723. ('Edwards', 190, 1, '2019-04-05')
# 724. ('Edwards', 101, 1, '2019-04-05')
# 725. ('Edwards', 28, 2, '2020-01-22')
# 726. ('Edwards', 211, 2, '2020-01-22')
# 727. ('Edwards', 194, 1, '2019-09-12')
# 728. ('Edwards', 243, 3, '2019-09-12')
# 729. ('Edwards', 26, 3, '2019-09-12')
# 730. ('Edwards', 13, 1, '2019-09-12')
# 731. ('Edwards', 79, 1, '2019-09-12')
# 732. ('Edwards', 293, 2, '2015-10-08')
# 733. ('Edwards', 281, 1, '2014-11-13')
# 734. ('Edwards', 77, 1, '2017-11-14')
# 735. ('Edwards', 95, 1, '2017-11-14')
# 736. ('Edwards', 216, 1, '2020-06-21')
# 737. ('Edwards', 214, 1, '2020-02-18')
# 738. ('Edwards', 205, 2, '2020-02-18')
# 739. ('Elliott', 186, 1, '2017-06-03')
# 740. ('Elliott', 72, 4, '2017-06-03')
# 741. ('Elliott', 35, 1, '2016-04-13')
# 742. ('Elliott', 99, 1, '2016-04-13')
# 743. ('Elliott', 229, 1, '2016-04-13')
# 744. ('Elliott', 216, 1, '2020-05-19')
# 745. ('Elliott', 83, 1, '2020-05-19')
# 746. ('Ellis', 269, 1, '2015-06-26')
# 747. ('Ellis', 183, 1, '2020-03-31')
# 748. ('Ellis', 76, 5, '2020-03-31')
# 749. ('Ellis', 130, 2, '2020-03-31')
# 750. ('Ellis', 198, 1, '2017-12-05')
# 751. ('Ellis', 113, 2, '2019-06-13')
# 752. ('Ellis', 212, 2, '2019-06-13')
# 753. ('Erickson', 241, 1, '2020-03-25')
# 754. ('Erickson', 156, 2, '2020-03-25')
# 755. ('Erickson', 142, 1, '2020-03-25')
# 756. ('Erickson', 151, 4, '2019-08-18')
# 757. ('Erickson', 53, 4, '2020-02-04')
# 758. ('Erickson', 239, 1, '2020-02-04')
# 759. ('Erickson', 124, 2, '2020-07-24')
# 760. ('Erickson', 85, 1, '2020-07-24')
# 761. ('Erickson', 210, 4, '2020-07-24')
# 762. ('Espinoza', 66, 2, '2020-04-02')
# 763. ('Espinoza', 58, 3, '2019-09-07')
# 764. ('Espinoza', 211, 4, '2019-09-07')
# 765. ('Espinoza', 138, 1, '2019-09-07')
# 766. ('Espinoza', 213, 2, '2019-11-15')
# 767. ('Estrada', 149, 2, '2016-05-20')
# 768. ('Evans', 73, 1, '2016-10-26')
# 769. ('Evans', 220, 3, '2016-10-26')
# 770. ('Evans', 202, 1, '2020-07-12')
# 771. ('Evans', 234, 3, '2020-07-12')
# 772. ('Evans', 206, 2, '2020-07-12')
# 773. ('Evans', 134, 1, '2020-07-12')
# 774. ('Evans', 81, 4, '2020-07-12')
# 775. ('Evans', 199, 1, '2020-07-12')
# 776. ('Evans', 52, 1, '2020-07-12')
# 777. ('Evans', 19, 1, '2019-12-17')
# 778. ('Evans', 203, 1, '2018-04-14')
# 779. ('Evans', 39, 2, '2018-02-14')
# 780. ('Evans', 68, 1, '2018-02-14')
# 781. ('Evans', 109, 1, '2019-08-20')
# 782. ('Evans', 18, 1, '2019-03-17')
# 783. ('Evans', 11, 3, '2016-09-05')
# 784. ('Evans', 63, 3, '2016-02-07')
# 785. ('Evans', 245, 1, '2016-02-07')
# 786. ('Evans', 143, 1, '2016-02-07')
# 787. ('Evans', 157, 3, '2016-02-07')
# 788. ('Evans', 164, 1, '2012-12-22')
# 789. ('Evans', 82, 2, '2012-12-22')
# 790. ('Evans', 279, 2, '2017-01-18')
# 791. ('Evans', 265, 6, '2019-08-31')
# 792. ('Evans', 275, 1, '2019-08-30')
# 793. ('Evans', 124, 2, '2019-08-30')
# 794. ('Evans', 210, 2, '2019-06-24')
# 795. ('Evans', 5, 2, '2019-06-24')
# 796. ('Evans', 50, 1, '2019-04-14')
# 797. ('Evans', 256, 3, '2016-12-09')
# 798. ('Evans', 42, 3, '2019-02-13')
# 799. ('Evans', 197, 3, '2018-08-09')
# 800. ('Evans', 119, 1, '2019-12-15')
# 801. ('Evans', 49, 3, '2019-12-15')
# 802. ('Evans', 80, 1, '2018-09-22')
# 803. ('Evans', 76, 2, '2015-02-08')
# 804. ('Evans', 198, 2, '2015-02-08')
# 805. ('Fernandez', 93, 5, '2014-04-28')
# 806. ('Fernandez', 138, 1, '2014-04-28')
# 807. ('Fernandez', 140, 1, '2018-12-23')
# 808. ('Fernandez', 85, 2, '2014-09-15')
# 809. ('Fernandez', 127, 3, '2015-05-19')
# 810. ('Fernandez', 171, 2, '2015-05-19')
# 811. ('Fernandez', 224, 1, '2015-05-19')
# 812. ('Fernandez', 232, 2, '2015-05-19')
# 813. ('Fernandez', 173, 6, '2020-07-14')
# 814. ('Fernandez', 228, 1, '2019-03-09')
# 815. ('Fernandez', 205, 8, '2019-03-09')
# 816. ('Fernandez', 235, 4, '2019-03-09')
# 817. ('Fields', 246, 2, '2019-10-16')
# 818. ('Fields', 244, 1, '2019-10-16')
# 819. ('Fields', 263, 1, '2019-10-16')
# 820. ('Fields', 17, 1, '2019-10-16')
# 821. ('Fields', 49, 1, '2019-10-16')
# 822. ('Fields', 272, 1, '2019-10-16')
# 823. ('Finley', 93, 6, '2019-08-09')
# 824. ('Finley', 269, 2, '2019-08-09')
# 825. ('Fisher', 286, 1, '2014-09-01')
# 826. ('Fisher', 206, 4, '2014-09-01')
# 827. ('Fisher', 14, 1, '2014-09-01')
# 828. ('Fitzpatrick', 132, 1, '2018-07-12')
# 829. ('Fitzpatrick', 9, 2, '2018-07-12')
# 830. ('Fitzpatrick', 23, 1, '2018-07-12')
# 831. ('Fitzpatrick', 130, 1, '2018-07-12')
# 832. ('Fitzpatrick', 231, 2, '2018-07-12')
# 833. ('Fitzpatrick', 70, 1, '2016-01-25')
# 834. ('Fitzpatrick', 217, 1, '2016-01-25')
# 835. ('Fleming', 114, 5, '2017-04-19')
# 836. ('Fleming', 220, 3, '2017-04-19')
# 837. ('Fleming', 166, 1, '2017-12-21')
# 838. ('Fleming', 94, 1, '2017-12-21')
# 839. ('Fleming', 80, 1, '2017-12-21')
# 840. ('Fleming', 255, 1, '2016-11-10')
# 841. ('Fleming', 41, 3, '2019-10-06')
# 842. ('Fleming', 18, 1, '2016-05-18')
# 843. ('Fleming', 226, 1, '2016-05-18')
# 844. ('Fletcher', 135, 4, '2017-10-25')
# 845. ('Fletcher', 281, 1, '2017-10-25')
# 846. ('Fletcher', 129, 1, '2017-03-09')
# 847. ('Fletcher', 183, 1, '2019-04-07')
# 848. ('Fletcher', 239, 2, '2014-08-12')
# 849. ('Fletcher', 215, 1, '2018-08-13')
# 850. ('Fletcher', 201, 2, '2010-10-29')
# 851. ('Fletcher', 288, 1, '2011-08-02')
# 852. ('Flores', 38, 2, '2018-09-22')
# 853. ('Flores', 149, 1, '2018-09-22')
# 854. ('Flores', 162, 1, '2017-09-24')
# 855. ('Flores', 135, 1, '2016-12-17')
# 856. ('Flores', 221, 1, '2016-08-18')
# 857. ('Flores', 216, 2, '2016-08-18')
# 858. ('Flores', 117, 1, '2016-08-18')
# 859. ('Flores', 249, 2, '2016-08-18')
# 860. ('Flores', 127, 1, '2017-06-25')
# 861. ('Floyd', 9, 1, '2019-05-13')
# 862. ('Floyd', 283, 1, '2018-07-04')
# 863. ('Floyd', 196, 1, '2015-01-19')
# 864. ('Floyd', 25, 1, '2015-01-19')
# 865. ('Floyd', 209, 1, '2017-11-17')
# 866. ('Floyd', 277, 4, '2017-11-17')
# 867. ('Floyd', 261, 1, '2017-11-17')
# 868. ('Foster', 36, 1, '2019-01-19')
# 869. ('Foster', 96, 2, '2019-01-19')
# 870. ('Foster', 178, 1, '2017-10-01')
# 871. ('Foster', 18, 3, '2018-05-31')
# 872. ('Foster', 167, 4, '2018-07-02')
# 873. ('Franco', 4, 4, '2019-09-09')
# 874. ('Franco', 54, 2, '2020-06-05')
# 875. ('Franco', 294, 1, '2020-06-05')
# 876. ('Franco', 25, 1, '2018-10-11')
# 877. ('Franco', 132, 1, '2018-10-11')
# 878. ('Franco', 6, 1, '2017-06-10')
# 879. ('Franco', 209, 1, '2017-06-10')
# 880. ('Franco', 235, 1, '2017-06-10')
# 881. ('Franco', 1, 1, '2017-03-05')
# 882. ('Franco', 56, 1, '2017-03-05')
# 883. ('Franco', 139, 1, '2019-03-09')
# 884. ('Franco', 172, 2, '2017-05-11')
# 885. ('Franco', 152, 2, '2017-05-11')
# 886. ('Frank', 170, 2, '2018-12-25')
# 887. ('Frank', 196, 1, '2016-10-17')
# 888. ('Friedman', 155, 1, '2019-09-03')
# 889. ('Friedman', 262, 3, '2019-09-03')
# 890. ('Friedman', 267, 1, '2019-07-28')
# 891. ('Friedman', 47, 2, '2019-07-28')
# 892. ('Friedman', 61, 1, '2016-06-19')
# 893. ('Friedman', 264, 3, '2016-06-19')
# 894. ('Friedman', 257, 5, '2016-06-19')
# 895. ('Friedman', 60, 1, '2016-06-19')
# 896. ('Friedman', 70, 2, '2014-01-15')
# 897. ('Friedman', 27, 1, '2014-01-15')
# 898. ('Friedman', 133, 1, '2014-04-11')
# 899. ('Friedman', 169, 1, '2014-04-11')
# 900. ('Frost', 213, 1, '2019-09-01')
# 901. ('Frost', 74, 3, '2017-02-23')
# 902. ('Frye', 27, 1, '2019-08-22')
# 903. ('Frye', 286, 3, '2016-10-24')
# 904. ('Frye', 36, 1, '2016-10-24')
# 905. ('Frye', 217, 1, '2016-10-24')
# 906. ('Frye', 35, 2, '2016-10-24')
# 907. ('Frye', 224, 1, '2020-07-21')
# 908. ('Frye', 5, 2, '2018-09-04')
# 909. ('Frye', 178, 3, '2018-09-04')
# 910. ('Frye', 135, 1, '2017-09-20')
# 911. ('Frye', 202, 2, '2018-08-26')
# 912. ('Frye', 185, 2, '2017-08-01')
# 913. ('Frye', 270, 1, '2019-03-07')
# 914. ('Gaines', 46, 1, '2018-10-24')
# 915. ('Gaines', 152, 2, '2018-10-24')
# 916. ('Gaines', 102, 1, '2020-07-04')
# 917. ('Gallegos', 76, 1, '2018-06-28')
# 918. ('Gallegos', 65, 2, '2018-06-28')
# 919. ('Gamble', 73, 1, '2018-09-30')
# 920. ('Gamble', 85, 4, '2018-09-30')
# 921. ('Gamble', 146, 1, '2019-08-08')
# 922. ('Gamble', 221, 3, '2019-08-08')
# 923. ('Gamble', 38, 2, '2017-01-09')
# 924. ('Gamble', 95, 2, '2019-07-05')
# 925. ('Garcia', 168, 2, '2017-04-16')
# 926. ('Garcia', 228, 2, '2018-08-15')
# 927. ('Garcia', 279, 5, '2018-08-15')
# 928. ('Garcia', 286, 1, '2018-08-15')
# 929. ('Garcia', 94, 2, '2014-01-13')
# 930. ('Garcia', 128, 1, '2014-01-13')
# 931. ('Garcia', 150, 1, '2016-06-21')
# 932. ('Garcia', 152, 1, '2015-03-23')
# 933. ('Garcia', 164, 2, '2015-03-23')
# 934. ('Garcia', 101, 1, '2015-03-23')
# 935. ('Garcia', 211, 1, '2015-03-23')
# 936. ('Garcia', 240, 2, '2016-07-22')
# 937. ('Garcia', 86, 1, '2016-07-22')
# 938. ('Garcia', 254, 1, '2016-07-22')
# 939. ('Garcia', 7, 1, '2017-05-10')
# 940. ('Garcia', 118, 2, '2020-04-04')
# 941. ('Garcia', 220, 3, '2020-04-04')
# 942. ('Garcia', 186, 1, '2015-10-31')
# 943. ('Garcia', 149, 1, '2015-06-07')
# 944. ('Garcia', 238, 1, '2015-06-07')
# 945. ('Garcia', 248, 2, '2020-01-31')
# 946. ('Garcia', 228, 2, '2020-01-31')
# 947. ('Garcia', 124, 1, '2020-01-31')
# 948. ('Garcia', 92, 1, '2016-12-05')
# 949. ('Garcia', 14, 2, '2020-06-28')
# 950. ('Garcia', 111, 3, '2020-01-15')
# 951. ('Garcia', 179, 2, '2020-01-15')
# 952. ('Garcia', 48, 3, '2017-03-21')
# 953. ('Garcia', 263, 1, '2016-08-22')
# 954. ('Garcia', 169, 1, '2016-08-22')
# 955. ('Garcia', 20, 1, '2019-07-13')
# 956. ('Garcia', 136, 1, '2015-08-16')
# 957. ('Garcia', 4, 1, '2017-10-09')
# 958. ('Garcia', 235, 1, '2016-11-25')
# 959. ('Garcia', 238, 1, '2020-07-09')
# 960. ('Garcia', 54, 4, '2018-09-08')
# 961. ('Garcia', 153, 1, '2018-09-08')
# 962. ('Garcia', 243, 1, '2018-09-08')
# 963. ('Garcia', 47, 3, '2018-09-08')
# 964. ('Garcia', 164, 2, '2018-09-08')
# 965. ('Garcia', 239, 1, '2013-12-21')
# 966. ('Garcia', 247, 1, '2013-12-21')
# 967. ('Garcia', 232, 1, '2019-04-19')
# 968. ('Garcia', 199, 1, '2019-04-19')
# 969. ('Garcia', 184, 1, '2013-04-12')
# 970. ('Garcia', 23, 3, '2013-04-12')
# 971. ('Garcia', 66, 2, '2013-04-12')
# 972. ('Garcia', 208, 2, '2013-04-12')
# 973. ('Garcia', 190, 1, '2017-06-02')
# 974. ('Garcia', 2, 1, '2017-06-02')
# 975. ('Garcia', 96, 1, '2017-06-02')
# 976. ('Garcia', 130, 1, '2017-06-02')
# 977. ('Garcia', 135, 2, '2017-06-02')
# 978. ('Garcia', 119, 1, '2012-10-02')
# 979. ('Garcia', 110, 2, '2012-10-02')
# 980. ('Gardner', 174, 1, '2019-01-19')
# 981. ('Gardner', 31, 2, '2019-01-19')
# 982. ('Gardner', 226, 2, '2016-10-28')
# 983. ('Gardner', 76, 1, '2016-10-28')
# 984. ('Gardner', 274, 1, '2020-07-12')
# 985. ('Gardner', 77, 1, '2020-07-12')
# 986. ('Gardner', 211, 1, '2020-04-24')
# 987. ('Gardner', 256, 1, '2020-04-24')
# 988. ('Gardner', 50, 1, '2020-04-24')
# 989. ('Garner', 23, 2, '2014-05-07')
# 990. ('Garner', 254, 3, '2015-08-03')
# 991. ('Garner', 104, 1, '2014-12-02')
# 992. ('Garrett', 264, 1, '2019-03-24')
# 993. ('Garrett', 20, 1, '2018-09-25')
# 994. ('Garrett', 140, 2, '2018-09-25')
# 995. ('Garrett', 52, 1, '2018-01-26')
# 996. ('Garza', 177, 1, '2019-02-10')
# 997. ('Garza', 158, 2, '2019-02-10')
# 998. ('Garza', 62, 2, '2019-02-10')
# 999. ('Garza', 84, 1, '2013-06-28')
# 1000. ('Garza', 191, 1, '2013-06-28')
# 1001. ('Garza', 123, 3, '2015-07-05')
# 1002. ('Garza', 128, 2, '2017-09-18')
# 1003. ('Gates', 1, 4, '2014-10-08')
# 1004. ('Gates', 120, 1, '2014-10-08')
# 1005. ('Gentry', 241, 2, '2020-05-30')
# 1006. ('Gentry', 44, 2, '2020-05-30')
# 1007. ('Gentry', 16, 4, '2020-05-30')
# 1008. ('Gibbs', 65, 1, '2018-08-09')
# 1009. ('Gibbs', 77, 1, '2018-08-09')
# 1010. ('Gibbs', 180, 5, '2018-08-09')
# 1011. ('Gibson', 249, 1, '2015-11-01')
# 1012. ('Gibson', 115, 2, '2015-11-01')
# 1013. ('Gibson', 88, 1, '2015-11-01')
# 1014. ('Gibson', 9, 1, '2015-12-06')
# 1015. ('Gillespie', 143, 5, '2018-05-09')
# 1016. ('Gillespie', 203, 1, '2018-05-09')
# 1017. ('Gillespie', 43, 1, '2017-03-18')
# 1018. ('Gillespie', 3, 1, '2017-11-21')
# 1019. ('Gillespie', 191, 1, '2017-11-21')
# 1020. ('Gonzales', 167, 1, '2019-10-07')
# 1021. ('Gonzales', 268, 1, '2015-07-14')
# 1022. ('Gonzales', 269, 1, '2015-07-14')
# 1023. ('Gonzales', 210, 1, '2018-12-20')
# 1024. ('Gonzales', 287, 1, '2012-07-22')
# 1025. ('Gonzalez', 282, 1, '2019-03-14')
# 1026. ('Gonzalez', 204, 2, '2015-10-06')
# 1027. ('Gonzalez', 131, 2, '2015-10-06')
# 1028. ('Gonzalez', 88, 1, '2017-07-30')
# 1029. ('Gonzalez', 22, 1, '2020-02-27')
# 1030. ('Gonzalez', 144, 1, '2019-08-30')
# 1031. ('Gonzalez', 277, 3, '2019-08-30')
# 1032. ('Gonzalez', 127, 2, '2016-04-29')
# 1033. ('Gonzalez', 258, 1, '2016-04-29')
# 1034. ('Gonzalez', 90, 2, '2016-04-29')
# 1035. ('Gonzalez', 227, 1, '2017-10-07')
# 1036. ('Gonzalez', 16, 2, '2017-10-07')
# 1037. ('Gonzalez', 55, 1, '2017-10-07')
# 1038. ('Gonzalez', 71, 2, '2015-05-18')
# 1039. ('Gonzalez', 113, 1, '2019-01-09')
# 1040. ('Gonzalez', 195, 1, '2019-01-09')
# 1041. ('Gonzalez', 247, 1, '2019-01-09')
# 1042. ('Gonzalez', 172, 2, '2018-04-16')
# 1043. ('Gonzalez', 265, 1, '2019-12-13')
# 1044. ('Gonzalez', 252, 1, '2019-12-13')
# 1045. ('Gonzalez', 61, 1, '2019-10-15')
# 1046. ('Gonzalez', 125, 3, '2018-10-08')
# 1047. ('Gonzalez', 34, 2, '2020-06-20')
# 1048. ('Gonzalez', 257, 1, '2020-06-20')
# 1049. ('Gonzalez', 153, 1, '2020-06-20')
# 1050. ('Gonzalez', 48, 1, '2013-12-24')
# 1051. ('Gonzalez', 116, 2, '2018-06-17')
# 1052. ('Gonzalez', 81, 2, '2016-07-09')
# 1053. ('Gonzalez', 38, 2, '2016-07-09')
# 1054. ('Gonzalez', 136, 1, '2016-07-09')
# 1055. ('Gonzalez', 22, 1, '2016-09-03')
# 1056. ('Gonzalez', 160, 1, '2016-09-03')
# 1057. ('Gonzalez', 223, 6, '2019-02-03')
# 1058. ('Gonzalez', 211, 3, '2015-09-05')
# 1059. ('Goodman', 43, 3, '2017-05-20')
# 1060. ('Goodman', 196, 1, '2017-05-20')
# 1061. ('Goodman', 63, 2, '2016-10-01')
# 1062. ('Gordon', 252, 1, '2015-05-26')
# 1063. ('Gordon', 190, 2, '2015-05-26')
# 1064. ('Gordon', 115, 3, '2015-05-26')
# 1065. ('Gordon', 5, 2, '2015-05-26')
# 1066. ('Gordon', 47, 2, '2016-09-15')
# 1067. ('Gould', 21, 3, '2019-12-23')
# 1068. ('Gould', 285, 2, '2019-12-23')
# 1069. ('Gould', 222, 2, '2019-04-28')
# 1070. ('Gould', 167, 1, '2019-04-28')
# 1071. ('Graham', 112, 3, '2018-11-23')
# 1072. ('Graham', 135, 2, '2019-11-23')
# 1073. ('Graham', 94, 1, '2020-03-24')
# 1074. ('Graham', 110, 5, '2020-03-24')
# 1075. ('Graham', 28, 4, '2020-03-24')
# 1076. ('Graham', 140, 1, '2020-03-24')
# 1077. ('Graham', 143, 3, '2020-03-01')
# 1078. ('Graham', 284, 1, '2020-01-06')
# 1079. ('Graham', 233, 1, '2019-10-03')
# 1080. ('Graham', 39, 1, '2019-10-03')
# 1081. ('Graham', 262, 1, '2019-10-03')
# 1082. ('Grant', 184, 1, '2019-12-05')
# 1083. ('Grant', 187, 1, '2019-12-05')
# 1084. ('Grant', 245, 2, '2019-12-05')
# 1085. ('Grant', 217, 8, '2019-12-05')
# 1086. ('Grant', 260, 4, '2019-02-10')
# 1087. ('Grant', 22, 6, '2017-12-01')
# 1088. ('Graves', 177, 2, '2017-11-16')
# 1089. ('Graves', 261, 2, '2019-05-02')
# 1090. ('Graves', 195, 2, '2019-05-02')
# 1091. ('Graves', 131, 3, '2019-08-12')
# 1092. ('Graves', 271, 1, '2016-04-27')
# 1093. ('Graves', 275, 3, '2016-04-27')
# 1094. ('Graves', 268, 1, '2020-03-26')
# 1095. ('Gray', 270, 2, '2018-11-02')
# 1096. ('Gray', 83, 1, '2014-10-06')
# 1097. ('Gray', 58, 3, '2014-10-06')
# 1098. ('Gray', 79, 2, '2014-10-06')
# 1099. ('Gray', 257, 3, '2020-04-17')
# 1100. ('Green', 83, 5, '2020-03-30')
# 1101. ('Green', 225, 8, '2015-12-05')
# 1102. ('Green', 137, 1, '2015-12-05')
# 1103. ('Green', 9, 1, '2015-12-05')
# 1104. ('Green', 240, 2, '2015-07-03')
# 1105. ('Green', 229, 4, '2015-07-03')
# 1106. ('Green', 267, 3, '2020-06-24')
# 1107. ('Greene', 40, 2, '2018-10-24')
# 1108. ('Greene', 265, 2, '2018-08-02')
# 1109. ('Greene', 269, 3, '2019-05-18')
# 1110. ('Greene', 211, 1, '2020-07-14')
# 1111. ('Greene', 10, 1, '2020-07-14')
# 1112. ('Greene', 65, 1, '2020-07-14')
# 1113. ('Greene', 183, 3, '2020-03-24')
# 1114. ('Greene', 289, 1, '2020-03-24')
# 1115. ('Greene', 221, 1, '2020-03-24')
# 1116. ('Greene', 84, 1, '2019-06-21')
# 1117. ('Greene', 70, 3, '2019-06-21')
# 1118. ('Greene', 58, 1, '2019-06-21')
# 1119. ('Gregory', 53, 1, '2018-03-10')
# 1120. ('Gregory', 231, 1, '2018-03-10')
# 1121. ('Griffin', 185, 2, '2011-05-18')
# 1122. ('Griffin', 160, 2, '2011-05-18')
# 1123. ('Griffin', 11, 1, '2014-01-23')
# 1124. ('Griffin', 105, 2, '2014-01-23')
# 1125. ('Griffin', 126, 2, '2014-01-23')
# 1126. ('Griffin', 1, 5, '2017-06-03')
# 1127. ('Griffin', 253, 3, '2017-06-03')
# 1128. ('Griffin', 46, 2, '2017-06-03')
# 1129. ('Griffin', 79, 3, '2014-04-06')
# 1130. ('Griffin', 277, 1, '2019-04-12')
# 1131. ('Griffith', 76, 1, '2019-11-01')
# 1132. ('Griffith', 5, 1, '2019-11-01')
# 1133. ('Griffith', 45, 1, '2019-11-01')
# 1134. ('Griffith', 96, 1, '2019-11-01')
# 1135. ('Griffith', 72, 1, '2014-12-18')
# 1136. ('Griffith', 266, 2, '2014-12-18')
# 1137. ('Griffith', 29, 2, '2014-12-18')
# 1138. ('Griffith', 24, 1, '2014-10-26')
# 1139. ('Griffith', 33, 1, '2014-10-26')
# 1140. ('Griffith', 239, 1, '2014-10-26')
# 1141. ('Griffith', 5, 1, '2014-10-26')
# 1142. ('Griffith', 177, 2, '2013-09-29')
# 1143. ('Griffith', 59, 3, '2017-09-20')
# 1144. ('Griffith', 251, 1, '2020-04-26')
# 1145. ('Griffith', 232, 2, '2020-07-24')
# 1146. ('Griffith', 157, 1, '2020-07-24')
# 1147. ('Griffith', 130, 1, '2020-07-24')
# 1148. ('Griffith', 275, 1, '2016-09-13')
# 1149. ('Griffith', 211, 1, '2018-11-25')
# 1150. ('Griffith', 245, 1, '2020-05-19')
# 1151. ('Gross', 146, 2, '2018-12-13')
# 1152. ('Gross', 177, 2, '2018-12-13')
# 1153. ('Gross', 159, 2, '2018-12-13')
# 1154. ('Gross', 201, 1, '2018-12-13')
# 1155. ('Gross', 258, 3, '2018-07-23')
# 1156. ('Gross', 272, 3, '2018-05-12')
# 1157. ('Gutierrez', 108, 1, '2019-04-19')
# 1158. ('Gutierrez', 240, 3, '2014-06-03')
# 1159. ('Gutierrez', 25, 1, '2020-07-21')
# 1160. ('Gutierrez', 279, 1, '2020-07-21')
# 1161. ('Gutierrez', 226, 1, '2020-06-06')
# 1162. ('Gutierrez', 68, 3, '2020-06-06')
# 1163. ('Gutierrez', 245, 1, '2017-08-04')
# 1164. ('Gutierrez', 198, 2, '2019-04-05')
# 1165. ('Gutierrez', 272, 1, '2019-04-05')
# 1166. ('Gutierrez', 121, 1, '2019-06-24')
# 1167. ('Gutierrez', 252, 1, '2019-06-24')
# 1168. ('Gutierrez', 93, 1, '2019-06-24')
# 1169. ('Gutierrez', 93, 1, '2015-02-03')
# 1170. ('Haas', 93, 1, '2014-12-28')
# 1171. ('Haas', 205, 1, '2018-05-08')
# 1172. ('Haas', 165, 1, '2017-09-15')
# 1173. ('Haas', 28, 1, '2015-10-13')
# 1174. ('Hahn', 140, 1, '2019-07-20')
# 1175. ('Hahn', 200, 1, '2019-08-23')
# 1176. ('Hahn', 108, 2, '2020-02-27')
# 1177. ('Hahn', 112, 3, '2020-02-27')
# 1178. ('Hahn', 117, 1, '2019-09-08')
# 1179. ('Hahn', 209, 1, '2019-10-05')
# 1180. ('Hahn', 197, 4, '2019-10-05')
# 1181. ('Hahn', 132, 1, '2019-05-06')
# 1182. ('Hahn', 267, 1, '2019-05-06')
# 1183. ('Hahn', 166, 1, '2019-05-06')
# 1184. ('Hale', 202, 1, '2019-10-13')
# 1185. ('Hale', 259, 1, '2019-10-13')
# 1186. ('Hale', 238, 2, '2015-11-27')
# 1187. ('Hale', 19, 1, '2015-11-27')
# 1188. ('Hale', 3, 1, '2018-03-30')
# 1189. ('Haley', 95, 1, '2016-11-24')
# 1190. ('Haley', 16, 6, '2017-07-31')
# 1191. ('Hall', 292, 1, '2020-01-01')
# 1192. ('Hall', 31, 1, '2016-03-27')
# 1193. ('Hall', 81, 2, '2018-06-30')
# 1194. ('Hall', 28, 2, '2018-06-30')
# 1195. ('Hall', 277, 1, '2016-07-08')
# 1196. ('Hall', 247, 1, '2016-07-08')
# 1197. ('Hall', 206, 1, '2017-07-26')
# 1198. ('Hall', 34, 2, '2017-07-26')
# 1199. ('Hamilton', 133, 2, '2019-05-18')
# 1200. ('Hamilton', 275, 3, '2017-10-05')
# 1201. ('Hamilton', 93, 1, '2017-10-05')
# 1202. ('Hamilton', 209, 2, '2019-09-20')
# 1203. ('Hamilton', 178, 4, '2016-04-12')
# 1204. ('Hamilton', 119, 1, '2015-05-12')
# 1205. ('Hamilton', 115, 1, '2016-02-11')
# 1206. ('Hampton', 153, 2, '2019-04-17')
# 1207. ('Hampton', 215, 8, '2019-04-17')
# 1208. ('Hampton', 161, 1, '2018-05-22')
# 1209. ('Hampton', 286, 3, '2017-10-10')
# 1210. ('Hanna', 120, 3, '2018-09-13')
# 1211. ('Hanna', 34, 2, '2019-07-18')
# 1212. ('Hanna', 217, 3, '2019-11-29')
# 1213. ('Hanna', 217, 2, '2016-07-26')
# 1214. ('Hanna', 67, 3, '2016-04-18')
# 1215. ('Hansen', 235, 1, '2018-01-26')
# 1216. ('Hansen', 279, 2, '2018-01-26')
# 1217. ('Hansen', 2, 1, '2019-06-11')
# 1218. ('Hansen', 78, 1, '2019-06-11')
# 1219. ('Hansen', 106, 1, '2019-03-10')
# 1220. ('Hanson', 189, 1, '2017-11-18')
# 1221. ('Hanson', 53, 2, '2017-11-18')
# 1222. ('Hanson', 166, 1, '2012-04-15')
# 1223. ('Hanson', 112, 3, '2012-04-15')
# 1224. ('Hanson', 199, 2, '2020-07-13')
# 1225. ('Hanson', 259, 2, '2020-07-13')
# 1226. ('Hardin', 58, 2, '2019-10-23')
# 1227. ('Harmon', 131, 1, '2016-11-20')
# 1228. ('Harris', 93, 3, '2017-09-17')
# 1229. ('Harris', 45, 4, '2017-09-17')
# 1230. ('Harris', 103, 1, '2020-06-21')
# 1231. ('Harris', 174, 2, '2017-02-01')
# 1232. ('Harris', 76, 1, '2017-02-01')
# 1233. ('Harris', 270, 1, '2018-01-18')
# 1234. ('Harris', 267, 2, '2018-01-18')
# 1235. ('Harris', 101, 1, '2017-10-12')
# 1236. ('Harris', 34, 4, '2018-06-13')
# 1237. ('Harris', 255, 3, '2018-06-13')
# 1238. ('Harris', 152, 1, '2019-04-13')
# 1239. ('Harris', 70, 2, '2019-04-13')
# 1240. ('Harris', 160, 4, '2019-04-13')
# 1241. ('Harris', 9, 1, '2013-07-03')
# 1242. ('Harris', 67, 1, '2019-03-05')
# 1243. ('Harris', 105, 2, '2019-02-03')
# 1244. ('Harris', 121, 1, '2019-02-03')
# 1245. ('Harris', 286, 5, '2018-07-14')
# 1246. ('Harris', 175, 3, '2018-07-14')
# 1247. ('Harris', 108, 1, '2018-07-14')
# 1248. ('Harris', 155, 2, '2020-02-19')
# 1249. ('Harrison', 273, 2, '2020-02-29')
# 1250. ('Harrison', 202, 1, '2019-11-06')
# 1251. ('Harrison', 125, 1, '2017-04-21')
# 1252. ('Hart', 24, 2, '2016-08-24')
# 1253. ('Hart', 168, 2, '2016-08-24')
# 1254. ('Hart', 121, 2, '2020-02-10')
# 1255. ('Hart', 7, 2, '2020-02-10')
# 1256. ('Hart', 121, 1, '2019-10-26')
# 1257. ('Hart', 294, 4, '2018-02-26')
# 1258. ('Hart', 9, 3, '2013-10-03')
# 1259. ('Hart', 55, 3, '2019-11-17')
# 1260. ('Hart', 157, 2, '2019-11-17')
# 1261. ('Harvey', 177, 2, '2018-10-10')
# 1262. ('Harvey', 135, 1, '2018-10-10')
# 1263. ('Harvey', 187, 1, '2019-06-04')
# 1264. ('Harvey', 101, 1, '2019-12-15')
# 1265. ('Hawkins', 9, 1, '2016-03-13')
# 1266. ('Hawkins', 210, 1, '2016-03-13')
# 1267. ('Hawkins', 47, 2, '2016-03-13')
# 1268. ('Hawkins', 1, 1, '2018-10-29')
# ...
# 3285. ('Vang', 97, 1, '2020-06-27')
# 3286. ('Vang', 167, 2, '2020-06-27')
# 3287. ('Vang', 120, 5, '2020-06-27')
# 3288. ('Vang', 106, 5, '2020-06-27')
# 3289. ('Vang', 273, 1, '2019-11-03')
# 3290. ('Vang', 223, 1, '2019-11-03')
# 3291. ('Vargas', 258, 2, '2018-01-07')
# 3292. ('Vargas', 248, 2, '2018-01-07')
# 3293. ('Vargas', 47, 1, '2015-01-01')
# 3294. ('Vargas', 73, 2, '2019-05-08')
# 3295. ('Vargas', 76, 1, '2019-05-08')
# 3296. ('Vargas', 48, 5, '2019-05-08')
# 3297. ('Vargas', 236, 1, '2019-09-20')
# 3298. ('Vargas', 114, 2, '2019-09-20')
# 3299. ('Vargas', 117, 2, '2019-09-20')
# 3300. ('Vargas', 183, 2, '2014-07-26')
# 3301. ('Vargas', 77, 1, '2013-09-19')
# 3302. ('Vargas', 21, 1, '2013-09-19')
# 3303. ('Vargas', 248, 2, '2019-01-26')
# 3304. ('Vargas', 77, 1, '2019-01-26')
# 3305. ('Vasquez', 67, 2, '2018-02-13')
# 3306. ('Vasquez', 210, 1, '2016-10-25')
# 3307. ('Vasquez', 18, 1, '2016-10-25')
# 3308. ('Vasquez', 34, 1, '2016-10-25')
# 3309. ('Vasquez', 37, 1, '2016-10-25')
# 3310. ('Vasquez', 14, 3, '2014-08-30')
# 3311. ('Velasquez', 223, 2, '2019-01-18')
# 3312. ('Velasquez', 145, 3, '2019-01-18')
# 3313. ('Velasquez', 270, 2, '2019-01-18')
# 3314. ('Velez', 202, 4, '2019-10-13')
# 3315. ('Velez', 165, 2, '2019-10-13')
# 3316. ('Velez', 232, 2, '2018-09-09')
# 3317. ('Velez', 232, 5, '2018-09-09')
# 3318. ('Velez', 205, 1, '2019-09-15')
# 3319. ('Velez', 277, 4, '2018-01-26')
# 3320. ('Villarreal', 289, 1, '2019-09-23')
# 3321. ('Villarreal', 236, 2, '2019-09-23')
# 3322. ('Villarreal', 130, 1, '2019-09-23')
# 3323. ('Villarreal', 257, 3, '2017-10-27')
# 3324. ('Villarreal', 95, 3, '2018-12-02')
# 3325. ('Villarreal', 229, 1, '2019-12-02')
# 3326. ('Villarreal', 28, 3, '2019-12-02')
# 3327. ('Villarreal', 33, 3, '2019-12-02')
# 3328. ('Villarreal', 33, 1, '2020-06-01')
# 3329. ('Villarreal', 164, 4, '2016-07-14')
# 3330. ('Villarreal', 22, 1, '2019-01-17')
# 3331. ('Villarreal', 77, 2, '2019-06-06')
# 3332. ('Villarreal', 15, 1, '2019-06-06')
# 3333. ('Vincent', 109, 3, '2019-05-27')
# 3334. ('Vincent', 152, 6, '2019-05-27')
# 3335. ('Vincent', 253, 1, '2019-05-27')
# 3336. ('Vincent', 228, 8, '2016-05-25')
# 3337. ('Vincent', 257, 1, '2018-10-14')
# 3338. ('Vincent', 197, 2, '2017-12-26')
# 3339. ('Vincent', 112, 1, '2019-10-11')
# 3340. ('Vincent', 266, 1, '2019-10-11')
# 3341. ('Wade', 210, 1, '2014-02-15')
# 3342. ('Wade', 231, 2, '2014-02-15')
# 3343. ('Wade', 203, 1, '2019-07-28')
# 3344. ('Wade', 204, 1, '2019-07-28')
# 3345. ('Wade', 173, 1, '2012-12-16')
# 3346. ('Wade', 130, 2, '2016-09-02')
# 3347. ('Wade', 158, 2, '2016-09-02')
# 3348. ('Wagner', 137, 1, '2017-06-04')
# 3349. ('Wagner', 191, 2, '2017-06-04')
# 3350. ('Wagner', 13, 3, '2020-07-15')
# 3351. ('Wagner', 57, 1, '2018-10-29')
# 3352. ('Wagner', 229, 4, '2018-04-08')
# 3353. ('Wagner', 56, 2, '2020-02-23')
# 3354. ('Wagner', 240, 1, '2020-02-23')
# 3355. ('Wagner', 167, 2, '2019-12-28')
# 3356. ('Walker', 165, 2, '2018-09-05')
# 3357. ('Walker', 223, 1, '2018-05-26')
# 3358. ('Walker', 200, 1, '2019-04-11')
# 3359. ('Walker', 143, 5, '2019-04-11')
# 3360. ('Walker', 82, 2, '2020-02-04')
# 3361. ('Walker', 127, 5, '2015-03-05')
# 3362. ('Walker', 289, 2, '2015-03-05')
# 3363. ('Walker', 225, 2, '2015-03-05')
# 3364. ('Walker', 25, 1, '2013-09-06')
# 3365. ('Walker', 273, 1, '2013-09-06')
# 3366. ('Walker', 146, 1, '2013-09-06')
# 3367. ('Walker', 282, 1, '2018-08-13')
# 3368. ('Walker', 70, 3, '2018-08-13')
# 3369. ('Walker', 138, 1, '2018-08-13')
# 3370. ('Walker', 30, 1, '2019-06-27')
# 3371. ('Walker', 170, 5, '2016-11-06')
# 3372. ('Walker', 211, 2, '2016-11-06')
# 3373. ('Walker', 150, 1, '2016-11-06')
# 3374. ('Walker', 16, 1, '2014-03-24')
# 3375. ('Walker', 124, 2, '2014-03-24')
# 3376. ('Walker', 90, 2, '2020-06-03')
# 3377. ('Walker', 185, 1, '2020-06-03')
# 3378. ('Walker', 118, 1, '2016-01-30')
# 3379. ('Walker', 89, 1, '2015-08-01')
# 3380. ('Walker', 191, 2, '2020-06-11')
# 3381. ('Walker', 240, 5, '2020-06-11')
# 3382. ('Wall', 153, 2, '2015-06-11')
# 3383. ('Wall', 119, 1, '2015-06-11')
# 3384. ('Wall', 108, 1, '2015-06-11')
# 3385. ('Wall', 268, 2, '2019-06-19')
# 3386. ('Wall', 229, 1, '2019-06-19')
# 3387. ('Wall', 167, 3, '2019-06-19')
# 3388. ('Wall', 275, 2, '2015-01-13')
# 3389. ('Wall', 192, 1, '2015-01-13')
# 3390. ('Wall', 268, 1, '2015-01-13')
# 3391. ('Wall', 2, 6, '2018-09-17')
# 3392. ('Wall', 191, 2, '2018-09-17')
# 3393. ('Wall', 290, 3, '2018-09-17')
# 3394. ('Wallace', 201, 1, '2016-06-25')
# 3395. ('Wallace', 158, 2, '2016-06-25')
# 3396. ('Wallace', 159, 1, '2017-09-30')
# 3397. ('Walsh', 268, 2, '2019-03-25')
# 3398. ('Walsh', 60, 3, '2015-01-05')
# 3399. ('Walsh', 289, 1, '2019-02-19')
# 3400. ('Wang', 94, 1, '2014-05-19')
# 3401. ('Wang', 46, 1, '2014-05-19')
# 3402. ('Wang', 107, 1, '2018-03-31')
# 3403. ('Ward', 230, 3, '2018-09-05')
# 3404. ('Ward', 202, 3, '2018-09-05')
# 3405. ('Ward', 248, 1, '2018-09-05')
# 3406. ('Ward', 252, 1, '2017-11-11')
# 3407. ('Ward', 68, 1, '2017-11-11')
# 3408. ('Ward', 175, 1, '2017-11-11')
# 3409. ('Ward', 87, 3, '2019-01-11')
# 3410. ('Ward', 246, 1, '2017-11-18')
# 3411. ('Ward', 270, 1, '2017-11-18')
# 3412. ('Ward', 220, 1, '2018-09-05')
# 3413. ('Ward', 111, 1, '2018-09-05')
# 3414. ('Ward', 216, 3, '2018-09-05')
# 3415. ('Ward', 258, 1, '2020-05-21')
# 3416. ('Ward', 35, 1, '2020-05-21')
# 3417. ('Ward', 106, 3, '2020-05-21')
# 3418. ('Ward', 143, 2, '2017-11-02')
# 3419. ('Ward', 195, 1, '2017-11-02')
# 3420. ('Ward', 124, 1, '2020-06-20')
# 3421. ('Ward', 70, 1, '2020-06-20')
# 3422. ('Ward', 30, 2, '2020-06-20')
# 3423. ('Warren', 123, 1, '2017-07-26')
# 3424. ('Warren', 289, 1, '2017-07-26')
# 3425. ('Warren', 267, 2, '2018-05-02')
# 3426. ('Warren', 81, 1, '2018-05-02')
# 3427. ('Warren', 176, 1, '2018-07-14')
# 3428. ('Warren', 225, 4, '2015-11-16')
# 3429. ('Warren', 242, 1, '2015-11-16')
# 3430. ('Warren', 252, 3, '2015-11-16')
# 3431. ('Washington', 226, 1, '2019-06-07')
# 3432. ('Washington', 30, 1, '2019-06-07')
# 3433. ('Washington', 248, 1, '2019-05-22')
# 3434. ('Washington', 214, 1, '2019-05-22')
# 3435. ('Washington', 70, 4, '2019-05-22')
# 3436. ('Washington', 294, 1, '2019-05-22')
# 3437. ('Washington', 156, 1, '2019-06-06')
# 3438. ('Washington', 43, 1, '2019-06-04')
# 3439. ('Washington', 105, 2, '2019-06-04')
# 3440. ('Waters', 178, 2, '2020-04-22')
# 3441. ('Waters', 73, 2, '2020-04-22')
# 3442. ('Waters', 6, 1, '2020-07-03')
# 3443. ('Waters', 205, 1, '2020-07-03')
# 3444. ('Waters', 58, 3, '2020-07-03')
# 3445. ('Waters', 14, 3, '2020-07-10')
# 3446. ('Waters', 188, 1, '2020-07-10')
# 3447. ('Waters', 212, 1, '2020-07-10')
# 3448. ('Watson', 158, 1, '2019-10-10')
# 3449. ('Watson', 105, 1, '2019-12-20')
# 3450. ('Watson', 111, 5, '2020-02-23')
# 3451. ('Watson', 23, 1, '2020-02-23')
# 3452. ('Watson', 138, 2, '2020-02-23')
# 3453. ('Watson', 53, 1, '2020-02-23')
# 3454. ('Weber', 291, 2, '2017-07-01')
# 3455. ('Weber', 289, 2, '2017-07-01')
# 3456. ('Webster', 103, 2, '2019-03-30')
# 3457. ('Weiss', 52, 2, '2020-02-23')
# 3458. ('Weiss', 217, 8, '2020-02-19')
# 3459. ('Weiss', 130, 1, '2020-02-19')
# 3460. ('Welch', 247, 1, '2011-11-16')
# 3461. ('Wells', 216, 1, '2020-03-01')
# 3462. ('Werner', 114, 3, '2019-02-27')
# 3463. ('Werner', 51, 1, '2019-04-09')
# 3464. ('Werner', 29, 1, '2019-07-07')
# 3465. ('Werner', 173, 3, '2020-04-05')
# 3466. ('Werner', 139, 1, '2020-04-05')
# 3467. ('Werner', 171, 2, '2020-03-15')
# 3468. ('Werner', 256, 4, '2020-03-15')
# 3469. ('Werner', 249, 2, '2020-03-15')
# 3470. ('Werner', 206, 2, '2020-03-15')
# 3471. ('West', 60, 1, '2020-01-21')
# 3472. ('West', 145, 1, '2020-01-21')
# 3473. ('West', 129, 1, '2020-01-21')
# 3474. ('White', 51, 3, '2016-01-01')
# 3475. ('White', 281, 2, '2019-07-18')
# 3476. ('White', 139, 1, '2019-07-18')
# 3477. ('White', 221, 3, '2015-11-04')
# 3478. ('White', 46, 1, '2012-08-08')
# 3479. ('White', 197, 1, '2019-09-22')
# 3480. ('White', 41, 1, '2011-12-30')
# 3481. ('White', 277, 3, '2016-12-22')
# 3482. ('White', 159, 2, '2016-12-22')
# 3483. ('White', 55, 3, '2012-04-09')
# 3484. ('White', 109, 3, '2012-04-09')
# 3485. ('Whitney', 284, 1, '2018-06-11')
# 3486. ('Whitney', 244, 1, '2016-03-08')
# 3487. ('Whitney', 121, 6, '2016-03-08')
# 3488. ('Wilcox', 10, 1, '2019-11-22')
# 3489. ('Wilcox', 273, 2, '2019-11-22')
# 3490. ('Wilcox', 98, 1, '2017-09-08')
# 3491. ('Wiley', 190, 3, '2018-02-28')
# 3492. ('Wiley', 76, 2, '2018-02-28')
# 3493. ('Wiley', 33, 1, '2016-04-10')
# 3494. ('Wilkins', 18, 1, '2016-01-17')
# 3495. ('Wilkins', 113, 1, '2016-09-14')
# 3496. ('Wilkins', 92, 2, '2016-09-14')
# 3497. ('Wilkins', 264, 1, '2017-11-09')
# 3498. ('Wilkins', 285, 1, '2017-11-09')
# 3499. ('Wilkins', 18, 1, '2015-04-24')
# 3500. ('Wilkins', 15, 1, '2015-04-24')
# 3501. ('Wilkins', 290, 1, '2015-04-24')
# 3502. ('Williams', 271, 1, '2014-05-16')
# 3503. ('Williams', 171, 2, '2014-05-16')
# 3504. ('Williams', 32, 1, '2020-07-24')
# 3505. ('Williams', 47, 2, '2019-04-27')
# 3506. ('Williams', 72, 3, '2019-04-27')
# 3507. ('Williams', 178, 2, '2019-04-27')
# 3508. ('Williams', 75, 3, '2019-04-27')
# 3509. ('Williams', 12, 2, '2018-09-11')
# 3510. ('Williams', 69, 4, '2020-07-01')
# 3511. ('Williams', 79, 2, '2020-07-01')
# 3512. ('Williams', 15, 1, '2020-07-01')
# 3513. ('Williams', 87, 1, '2020-04-10')
# 3514. ('Williams', 294, 1, '2019-06-26')
# 3515. ('Williams', 110, 1, '2019-06-26')
# 3516. ('Williams', 225, 1, '2020-04-15')
# 3517. ('Williams', 97, 2, '2020-04-15')
# 3518. ('Williams', 202, 2, '2020-04-15')
# 3519. ('Williams', 55, 1, '2014-12-05')
# 3520. ('Williams', 129, 2, '2013-08-24')
# 3521. ('Williams', 49, 1, '2019-06-16')
# 3522. ('Williams', 153, 1, '2019-03-01')
# 3523. ('Williams', 271, 3, '2017-04-02')
# 3524. ('Williams', 260, 1, '2017-04-02')
# 3525. ('Williams', 158, 3, '2017-04-02')
# 3526. ('Williams', 119, 3, '2011-08-18')
# 3527. ('Williams', 45, 1, '2019-12-04')
# 3528. ('Williams', 64, 1, '2015-09-13')
# 3529. ('Williams', 221, 4, '2015-09-13')
# 3530. ('Williams', 30, 1, '2019-08-14')
# 3531. ('Williams', 62, 5, '2020-07-26')
# 3532. ('Williams', 276, 1, '2020-07-26')
# 3533. ('Williams', 51, 1, '2020-05-11')
# 3534. ('Williams', 253, 5, '2020-05-11')
# 3535. ('Williamson', 150, 1, '2019-09-19')
# 3536. ('Williamson', 120, 1, '2019-09-19')
# 3537. ('Williamson', 170, 2, '2016-08-07')
# 3538. ('Wilson', 97, 2, '2017-05-23')
# 3539. ('Wilson', 113, 1, '2018-03-04')
# 3540. ('Wilson', 216, 2, '2018-03-04')
# 3541. ('Wilson', 202, 3, '2018-03-04')
# 3542. ('Wilson', 110, 1, '2018-03-04')
# 3543. ('Wilson', 36, 1, '2015-05-18')
# 3544. ('Wilson', 187, 2, '2015-08-05')
# 3545. ('Wilson', 202, 1, '2015-08-05')
# 3546. ('Wilson', 104, 1, '2019-08-02')
# 3547. ('Wilson', 52, 1, '2019-08-02')
# 3548. ('Wilson', 195, 1, '2019-08-02')
# 3549. ('Wilson', 14, 2, '2019-08-02')
# 3550. ('Wilson', 211, 1, '2012-11-09')
# 3551. ('Wilson', 107, 3, '2012-11-09')
# 3552. ('Wilson', 118, 1, '2012-11-09')
# 3553. ('Wilson', 165, 1, '2015-10-16')
# 3554. ('Wilson', 91, 1, '2016-08-24')
# 3555. ('Wilson', 42, 1, '2020-01-20')
# 3556. ('Wilson', 214, 1, '2020-01-20')
# 3557. ('Wilson', 50, 1, '2020-01-20')
# 3558. ('Wilson', 292, 1, '2020-01-20')
# 3559. ('Wilson', 155, 2, '2015-01-05')
# 3560. ('Wilson', 72, 1, '2015-01-05')
# 3561. ('Wilson', 289, 2, '2015-01-05')
# 3562. ('Wilson', 6, 3, '2018-01-11')
# 3563. ('Wilson', 102, 1, '2017-06-10')
# 3564. ('Wilson', 151, 1, '2017-06-10')
# 3565. ('Wilson', 180, 1, '2014-07-13')
# 3566. ('Wilson', 225, 1, '2020-06-04')
# 3567. ('Wilson', 4, 1, '2020-06-04')
# 3568. ('Wilson', 241, 1, '2012-11-05')
# 3569. ('Wilson', 12, 2, '2012-11-05')
# 3570. ('Wilson', 233, 2, '2015-02-24')
# 3571. ('Wilson', 108, 1, '2015-02-24')
# 3572. ('Wilson', 244, 2, '2014-03-16')
# 3573. ('Wilson', 34, 3, '2015-10-29')
# 3574. ('Wilson', 209, 2, '2015-10-29')
# 3575. ('Wilson', 147, 1, '2015-10-29')
# 3576. ('Wilson', 222, 1, '2018-01-30')
# 3577. ('Wilson', 104, 2, '2018-01-30')
# 3578. ('Wilson', 3, 2, '2018-01-30')
# 3579. ('Wilson', 242, 2, '2016-02-10')
# 3580. ('Wilson', 155, 2, '2015-03-22')
# 3581. ('Wilson', 30, 1, '2015-03-22')
# 3582. ('Wilson', 114, 2, '2019-08-05')
# 3583. ('Wilson', 76, 1, '2013-04-03')
# 3584. ('Wilson', 114, 2, '2014-09-21')
# 3585. ('Wilson', 148, 1, '2017-09-30')
# 3586. ('Wilson', 92, 3, '2017-09-30')
# 3587. ('Wilson', 162, 2, '2013-11-06')
# 3588. ('Wilson', 1, 1, '2013-11-06')
# 3589. ('Wilson', 244, 2, '2013-05-02')
# 3590. ('Wilson', 68, 2, '2013-05-02')
# 3591. ('Wilson', 86, 1, '2019-09-08')
# 3592. ('Wise', 16, 1, '2013-04-15')
# 3593. ('Wise', 95, 1, '2018-06-23')
# 3594. ('Wise', 185, 3, '2018-06-23')
# 3595. ('Wolf', 58, 1, '2019-12-03')
# 3596. ('Wolf', 158, 2, '2018-04-13')
# 3597. ('Wolf', 210, 1, '2020-03-08')
# 3598. ('Wolf', 132, 1, '2020-03-08')
# 3599. ('Wolf', 205, 3, '2011-04-08')
# 3600. ('Wong', 261, 1, '2018-11-23')
# 3601. ('Wong', 131, 1, '2018-11-23')
# 3602. ('Wong', 211, 2, '2020-01-17')
# 3603. ('Wong', 235, 1, '2020-01-17')
# 3604. ('Wong', 35, 4, '2020-01-17')
# 3605. ('Wong', 42, 1, '2020-01-17')
# 3606. ('Wong', 175, 2, '2020-01-17')
# 3607. ('Wood', 212, 1, '2020-03-28')
# 3608. ('Wood', 287, 1, '2019-11-02')
# 3609. ('Wood', 236, 5, '2019-11-02')
# 3610. ('Wood', 34, 1, '2019-11-02')
# 3611. ('Woodard', 116, 1, '2019-04-13')
# 3612. ('Woodard', 230, 3, '2019-04-13')
# 3613. ('Woodard', 98, 1, '2019-04-13')
# 3614. ('Woodard', 250, 3, '2019-08-26')
# 3615. ('Woodard', 277, 2, '2019-08-26')
# 3616. ('Woodard', 199, 1, '2019-08-26')
# 3617. ('Woods', 143, 2, '2019-04-25')
# 3618. ('Woods', 101, 2, '2019-04-25')
# 3619. ('Wright', 251, 1, '2019-08-25')
# 3620. ('Wright', 82, 1, '2019-08-25')
# 3621. ('Wright', 42, 1, '2019-08-25')
# 3622. ('Wright', 5, 2, '2019-08-25')
# 3623. ('Wright', 62, 2, '2019-07-20')
# 3624. ('Wright', 161, 1, '2019-07-20')
# 3625. ('Wright', 208, 1, '2019-07-20')
# 3626. ('Wright', 51, 1, '2019-07-20')
# 3627. ('Wright', 5, 3, '2020-06-07')
# 3628. ('Wright', 175, 1, '2014-11-13')
# 3629. ('Wright', 162, 1, '2020-05-24')
# 3630. ('Wright', 259, 1, '2020-05-24')
# 3631. ('Wright', 184, 1, '2019-06-25')
# 3632. ('Wright', 204, 2, '2019-06-25')
# 3633. ('Wright', 242, 1, '2015-02-11')
# 3634. ('Wright', 126, 3, '2019-10-28')
# 3635. ('Wright', 140, 2, '2019-10-28')
# 3636. ('Wright', 245, 1, '2020-03-01')
# 3637. ('Wright', 184, 1, '2020-03-01')
# 3638. ('Wright', 272, 1, '2018-07-30')
# 3639. ('Wright', 286, 2, '2020-07-03')
# 3640. ('Wright', 290, 2, '2020-05-20')
# 3641. ('Wright', 183, 1, '2020-05-20')
# 3642. ('Yang', 183, 5, '2017-06-01')
# 3643. ('Yang', 125, 2, '2018-06-07')
# 3644. ('Yang', 113, 3, '2019-05-16')
# 3645. ('Yang', 139, 1, '2019-05-16')
# 3646. ('Yang', 99, 2, '2020-07-11')
# 3647. ('Yang', 50, 4, '2020-04-27')
# 3648. ('York', 107, 1, '2020-07-24')
# 3649. ('York', 265, 3, '2020-07-24')
# 3650. ('York', 223, 2, '2020-07-24')
# 3651. ('Young', 274, 1, '2017-09-01')
# 3652. ('Young', 148, 1, '2017-09-01')
# 3653. ('Young', 203, 2, '2017-09-01')
# 3654. ('Young', 176, 1, '2020-03-23')
# 3655. ('Young', 138, 1, '2020-03-23')
# 3656. ('Young', 194, 2, '2020-03-23')
# 3657. ('Young', 159, 1, '2012-05-17')
# 3658. ('Young', 275, 2, '2012-05-17')
# 3659. ('Young', 94, 2, '2017-05-30')
# 3660. ('Young', 203, 4, '2019-09-25')
# 3661. ('Young', 25, 1, '2018-02-15')
# 3662. ('Young', 72, 2, '2018-02-15')
# 3663. ('Young', 196, 1, '2019-09-05')
# 3664. ('Young', 11, 1, '2016-12-15')
# 3665. ('Young', 156, 1, '2016-12-15')
# 3666. ('Young', 132, 1, '2016-12-15')
# 3667. ('Young', 183, 1, '2012-09-01')
# 3668. ('Young', 264, 3, '2013-06-14')
# 3669. ('Young', 149, 1, '2017-09-24')
# 3670. ('Young', 263, 5, '2017-09-24')
# 3671. ('Young', 289, 1, '2017-09-24')
# 3672. ('Young', 62, 1, '2016-04-29')
# 3673. ('Young', 37, 1, '2014-06-14')
# 3674. ('Young', 100, 1, '2016-05-30')
# 3675. ('Young', 125, 2, '2016-05-30')
# 3676. ('Young', 155, 1, '2016-10-02')
# 3677. ('Zavala', 174, 2, '2018-07-23')
# 3678. ('Zavala', 49, 4, '2018-07-23')
# 3679. ('Zavala', 247, 1, '2020-06-10')
# 3680. ('Zavala', 75, 3, '2020-06-10')
# 3681. ('Zavala', 237, 1, '2020-06-10')
# 3682. ('Zavala', 38, 1, '2019-04-28')
# 3683. ('Zavala', 107, 1, '2019-04-28')
# 3684. ('Zavala', 137, 1, '2019-04-28')
# 3685. ('Zavala', 225, 1, '2019-04-28')
# 3686. ('Zavala', 250, 1, '2019-03-19')
# 3687. ('Zavala', 157, 1, '2019-03-19')
# 3688. ('Zavala', 123, 1, '2018-04-29')
# 3689. ('Zavala', 257, 2, '2018-04-29')
# 3690. ('Zhang', 42, 2, '2017-10-25')
# 3691. ('Zhang', 124, 1, '2014-11-06')
# 3692. ('Zhang', 227, 1, '2014-11-06')
# 3693. ('Zhang', 251, 4, '2014-11-06')
# 3694. ('Zhang', 173, 2, '2018-08-09')
# 3695. ('Zhang', 218, 5, '2018-08-09')
# 3696. ('Zhang', 155, 1, '2018-08-09')
# 3697. ('Zhang', 213, 1, '2016-11-06')
# 3698. ('Zhang', 288, 1, '2016-11-06')

# %% [markdown]
# ### LEFT  JOIN
# Also called `LEFT OUTER JOIN`

# %%
# This query shows the purchase history of customers

query = '''
SELECT Surname, ProductID, Quantity, PurchaseDate
FROM Customers
LEFT JOIN Sales ON
    Customers.CustomerID = Sales.CustomerID
ORDER BY Surname;
'''

execute_query(conn,query)
# Out:
# 1. ('Acosta', 65, 1, '2019-02-17')
# 2. ('Acosta', 138, 1, '2019-02-17')
# 3. ('Acosta', 196, 1, '2017-04-08')
# 4. ('Adams', 43, 1, '2013-02-03')
# 5. ('Adams', 48, 2, '2019-11-10')
# 6. ('Adams', 77, 1, '2013-11-10')
# 7. ('Adams', 88, 1, '2013-11-10')
# 8. ('Adams', 149, 2, '2013-02-03')
# 9. ('Adams', 199, 1, '2013-11-10')
# 10. ('Adams', 223, 3, '2019-11-10')
# 11. ('Adams', 58, 2, '2020-07-01')
# 12. ('Adams', 65, 3, '2020-07-29')
# 13. ('Adams', 200, 2, '2020-06-01')
# 14. ('Adams', 276, 1, '2020-06-14')
# 15. ('Adams', 156, 1, '2019-04-30')
# 16. ('Adams', 181, 1, '2019-04-30')
# 17. ('Adams', 233, 1, '2018-03-18')
# 18. ('Adams', 13, 1, '2018-11-01')
# 19. ('Adams', 15, 1, '2018-11-01')
# 20. ('Adams', 59, 2, '2017-06-11')
# 21. ('Adams', 69, 1, '2017-06-11')
# 22. ('Adams', 211, 2, '2019-11-17')
# 23. ('Adams', 247, 1, '2017-06-11')
# 24. ('Adkins', None, None, None)
# 25. ('Aguirre', 170, 2, '2020-06-26')
# 26. ('Aguirre', 286, 1, '2017-04-27')
# 27. ('Alexander', None, None, None)
# 28. ('Alexander', 83, 1, '2015-01-15')
# 29. ('Alexander', 83, 1, '2016-08-12')
# 30. ('Alexander', 266, 1, '2015-11-09')
# 31. ('Alexander', 266, 2, '2015-11-09')
# 32. ('Ali', 54, 1, '2018-06-17')
# 33. ('Ali', 164, 1, '2018-08-02')
# 34. ('Ali', 184, 1, '2018-02-13')
# 35. ('Ali', 291, 1, '2018-08-02')
# 36. ('Allen', 249, 4, '2019-09-08')
# 37. ('Allen', 29, 1, '2016-06-25')
# 38. ('Allen', 121, 1, '2016-06-25')
# 39. ('Allen', 125, 4, '2017-04-17')
# 40. ('Allen', 164, 1, '2016-12-12')
# 41. ('Allen', 294, 1, '2016-06-25')
# 42. ('Allen', 275, 3, '2019-12-10')
# 43. ('Alvarez', 86, 1, '2014-01-15')
# 44. ('Alvarez', 107, 2, '2014-01-15')
# 45. ('Alvarez', 227, 1, '2013-08-22')
# 46. ('Alvarez', 258, 1, '2014-01-15')
# 47. ('Alvarez', 262, 5, '2014-12-07')
# 48. ('Alvarez', 292, 3, '2013-08-22')
# 49. ('Alvarez', 293, 4, '2014-01-15')
# 50. ('Andersen', 20, 1, '2017-08-09')
# 51. ('Andersen', 22, 2, '2016-10-01')
# 52. ('Andersen', 29, 2, '2019-06-19')
# 53. ('Andersen', 90, 1, '2019-06-19')
# 54. ('Andersen', 168, 1, '2017-08-09')
# 55. ('Andersen', 181, 3, '2016-10-01')
# 56. ('Andersen', 271, 3, '2017-08-09')
# 57. ('Anderson', 24, 1, '2019-11-02')
# 58. ('Anderson', 65, 4, '2019-11-02')
# 59. ('Anderson', 152, 1, '2019-09-30')
# 60. ('Anderson', 60, 4, '2015-05-31')
# 61. ('Anderson', 272, 1, '2015-05-31')
# 62. ('Anderson', 104, 3, '2018-03-26')
# 63. ('Anderson', 137, 1, '2014-02-18')
# 64. ('Anderson', 16, 3, '2016-04-07')
# 65. ('Anderson', 116, 1, '2016-04-07')
# 66. ('Anderson', 161, 2, '2016-04-07')
# 67. ('Anderson', 216, 2, '2016-04-23')
# 68. ('Anderson', 222, 1, '2016-04-07')
# 69. ('Anderson', 229, 1, '2017-10-15')
# 70. ('Anderson', 263, 3, '2017-10-15')
# 71. ('Anderson', 267, 2, '2016-05-18')
# 72. ('Anderson', 293, 1, '2016-04-23')
# 73. ('Anderson', None, None, None)
# 74. ('Andrade', 252, 3, '2019-09-14')
# 75. ('Andrews', 37, 1, '2014-12-01')
# 76. ('Andrews', 237, 2, '2017-07-23')
# 77. ('Andrews', None, None, None)
# 78. ('Andrews', 16, 1, '2019-11-05')
# 79. ('Andrews', 16, 2, '2019-11-05')
# 80. ('Andrews', 18, 1, '2019-11-05')
# 81. ('Andrews', 143, 1, '2019-05-05')
# 82. ('Andrews', 157, 4, '2020-02-28')
# 83. ('Andrews', 18, 2, '2017-03-31')
# 84. ('Andrews', 35, 3, '2018-09-06')
# 85. ('Andrews', 158, 1, '2018-10-17')
# 86. ('Andrews', 186, 4, '2018-09-06')
# 87. ('Andrews', 195, 1, '2017-03-31')
# 88. ('Andrews', 239, 1, '2018-09-06')
# 89. ('Andrews', 267, 1, '2018-10-17')
# 90. ('Andrews', 34, 1, '2020-06-13')
# 91. ('Anthony', 44, 1, '2015-05-30')
# 92. ('Anthony', 83, 1, '2015-05-30')
# 93. ('Anthony', 138, 2, '2019-08-11')
# 94. ('Anthony', 211, 1, '2015-05-30')
# 95. ('Anthony', 216, 1, '2017-01-25')
# 96. ('Anthony', 4, 3, '2019-09-03')
# 97. ('Anthony', 63, 4, '2019-11-12')
# 98. ('Anthony', 222, 2, '2019-09-03')
# 99. ('Arellano', 45, 3, '2016-09-30')
# 100. ('Arellano', 63, 1, '2020-02-22')
# 101. ('Arellano', 82, 1, '2016-09-30')
# 102. ('Arellano', 89, 2, '2020-02-22')
# 103. ('Arellano', 174, 1, '2020-02-22')
# 104. ('Arellano', 253, 3, '2019-11-25')
# 105. ('Arnold', 5, 1, '2020-03-28')
# 106. ('Arnold', 8, 5, '2020-03-28')
# 107. ('Arnold', 66, 1, '2020-03-28')
# 108. ('Arnold', 66, 8, '2019-08-31')
# 109. ('Arnold', 127, 1, '2019-08-31')
# 110. ('Arnold', 145, 1, '2019-06-29')
# 111. ('Arnold', 159, 1, '2019-06-29')
# 112. ('Arnold', 290, 1, '2020-03-28')
# 113. ('Arnold', 46, 2, '2016-01-01')
# 114. ('Arnold', 50, 1, '2019-01-24')
# 115. ('Arnold', 233, 2, '2016-01-01')
# 116. ('Atkinson', 62, 1, '2020-01-23')
# 117. ('Atkinson', 272, 3, '2020-01-23')
# 118. ('Bailey', 38, 2, '2017-07-04')
# 119. ('Bailey', 41, 1, '2018-06-05')
# 120. ('Bailey', 48, 1, '2017-07-04')
# 121. ('Bailey', 86, 1, '2020-06-20')
# 122. ('Bailey', 189, 2, '2018-06-05')
# 123. ('Bailey', 249, 2, '2019-10-30')
# 124. ('Bailey', 251, 1, '2017-07-04')
# 125. ('Bailey', 50, 1, '2020-04-20')
# 126. ('Bailey', 241, 1, '2020-04-20')
# 127. ('Bailey', 99, 5, '2019-01-27')
# 128. ('Bailey', 108, 3, '2019-03-20')
# 129. ('Bailey', 155, 1, '2019-03-20')
# 130. ('Bailey', 197, 1, '2020-06-10')
# 131. ('Bailey', 208, 3, '2019-01-27')
# 132. ('Bailey', 282, 2, '2020-06-10')
# 133. ('Bailey', 81, 3, '2020-05-21')
# 134. ('Bailey', 158, 3, '2020-01-09')
# 135. ('Bailey', 218, 1, '2020-05-21')
# 136. ('Baker', 120, 1, '2016-09-26')
# 137. ('Baker', 168, 1, '2012-07-31')
# 138. ('Baldwin', 47, 1, '2020-07-18')
# 139. ('Baldwin', 212, 7, '2020-07-18')
# 140. ('Baldwin', 220, 1, '2020-07-18')
# 141. ('Ball', 153, 1, '2020-01-02')
# 142. ('Ball', 219, 1, '2020-01-02')
# 143. ('Ball', 237, 1, '2020-01-02')
# 144. ('Ball', 284, 1, '2017-10-24')
# 145. ('Barajas', 17, 2, '2020-04-23')
# 146. ('Barajas', 224, 1, '2020-02-10')
# 147. ('Barnes', 111, 4, '2016-05-07')
# 148. ('Barnes', 205, 1, '2012-07-05')
# 149. ('Barnett', 24, 1, '2018-12-07')
# 150. ('Barnett', 56, 2, '2016-06-05')
# 151. ('Barnett', 138, 2, '2016-06-05')
# 152. ('Barnett', 157, 1, '2017-01-02')
# 153. ('Barnett', 170, 3, '2017-01-02')
# 154. ('Barnett', 255, 3, '2017-01-02')
# 155. ('Barnett', 95, 1, '2019-11-11')
# 156. ('Barnett', 1, 1, '2018-07-14')
# 157. ('Barnett', 65, 1, '2018-07-14')
# 158. ('Barr', 119, 1, '2018-03-23')
# 159. ('Barr', 155, 1, '2019-02-08')
# 160. ('Barr', 167, 1, '2019-02-08')
# 161. ('Barr', 201, 3, '2018-03-23')
# 162. ('Barrera', 88, 2, '2017-09-25')
# 163. ('Barrera', 131, 2, '2017-09-25')
# 164. ('Barrera', 144, 2, '2018-01-29')
# 165. ('Barrera', 196, 3, '2017-09-25')
# 166. ('Barrera', 244, 1, '2017-09-25')
# 167. ('Barrera', 261, 2, '2018-01-29')
# 168. ('Barrera', 284, 1, '2018-11-22')
# 169. ('Barrera', 288, 1, '2017-09-25')
# 170. ('Barrera', 77, 3, '2015-07-12')
# 171. ('Barrera', 139, 1, '2015-07-12')
# 172. ('Barrera', 140, 1, '2019-11-11')
# 173. ('Barrera', 190, 1, '2015-07-12')
# 174. ('Barrera', 212, 1, '2015-02-16')
# 175. ('Barrera', 264, 3, '2019-11-11')
# 176. ('Barrera', None, None, None)
# 177. ('Barrett', 42, 6, '2019-02-16')
# 178. ('Barrett', 62, 2, '2018-10-01')
# 179. ('Barrett', 63, 1, '2019-08-08')
# 180. ('Barrett', 88, 2, '2019-02-16')
# 181. ('Barrett', 127, 3, '2019-08-08')
# 182. ('Barrett', 130, 1, '2019-08-08')
# 183. ('Barrett', 192, 2, '2018-10-01')
# 184. ('Barrett', 235, 4, '2019-02-16')
# 185. ('Barrett', 256, 3, '2018-10-01')
# 186. ('Barrett', 267, 4, '2019-02-16')
# 187. ('Barrett', 13, 2, '2013-02-09')
# 188. ('Barry', 39, 2, '2020-04-18')
# 189. ('Barry', 100, 2, '2013-03-17')
# 190. ('Barry', 108, 1, '2020-04-18')
# 191. ('Barry', 114, 1, '2013-03-17')
# 192. ('Barry', 184, 2, '2015-12-17')
# 193. ('Barton', None, None, None)
# 194. ('Bauer', 28, 1, '2020-07-04')
# 195. ('Bauer', 71, 1, '2020-07-14')
# 196. ('Bauer', 144, 3, '2020-07-04')
# 197. ('Bauer', 249, 4, '2020-07-14')
# 198. ('Bauer', 284, 1, '2020-07-04')
# 199. ('Bauer', 97, 1, '2019-02-20')
# 200. ('Bauer', 105, 2, '2019-02-20')
# 201. ('Bauer', 192, 1, '2018-10-22')
# 202. ('Bauer', 242, 1, '2018-05-18')
# 203. ('Bauer', 278, 3, '2019-02-20')
# 204. ('Beck', 80, 2, '2020-02-07')
# 205. ('Beck', 200, 1, '2019-08-31')
# 206. ('Beck', 266, 2, '2020-01-08')
# 207. ('Beck', None, None, None)
# 208. ('Bell', 5, 2, '2015-12-27')
# 209. ('Bell', 7, 1, '2015-12-27')
# 210. ('Bell', 16, 1, '2019-04-05')
# 211. ('Bell', 26, 1, '2014-05-13')
# 212. ('Bell', 102, 1, '2020-03-31')
# 213. ('Bell', 170, 4, '2020-03-31')
# 214. ('Bell', 198, 1, '2014-05-13')
# 215. ('Bell', 266, 1, '2014-05-13')
# 216. ('Bell', 160, 1, '2020-04-27')
# 217. ('Bell', 282, 1, '2020-04-27')
# 218. ('Bell', 77, 4, '2018-03-01')
# 219. ('Bell', 79, 10, '2018-03-01')
# 220. ('Bell', 265, 2, '2020-03-01')
# 221. ('Bell', 14, 3, '2020-05-06')
# 222. ('Bell', 41, 1, '2020-05-06')
# 223. ('Bell', 58, 1, '2020-05-06')
# 224. ('Bell', 97, 2, '2020-05-09')
# 225. ('Bell', 122, 1, '2020-05-09')
# 226. ('Bell', 123, 1, '2020-05-09')
# 227. ('Bell', 290, 1, '2020-06-12')
# 228. ('Bell', None, None, None)
# 229. ('Beltran', None, None, None)
# 230. ('Benjamin', 10, 1, '2017-09-12')
# 231. ('Benjamin', 54, 4, '2015-07-13')
# 232. ('Benjamin', 203, 1, '2017-09-12')
# 233. ('Benjamin', 246, 1, '2015-07-13')
# 234. ('Benjamin', 272, 1, '2018-12-05')
# 235. ('Benjamin', 280, 1, '2015-07-13')
# 236. ('Bennett', 26, 1, '2018-04-25')
# 237. ('Bennett', 138, 2, '2017-07-27')
# 238. ('Bennett', 139, 1, '2020-01-31')
# 239. ('Bennett', 219, 3, '2019-05-20')
# 240. ('Bennett', 237, 4, '2020-01-31')
# 241. ('Bennett', 247, 2, '2019-05-20')
# 242. ('Bennett', 255, 1, '2019-06-09')
# 243. ('Bennett', 31, 1, '2018-05-04')
# 244. ('Bennett', 177, 2, '2017-08-16')
# 245. ('Bennett', 238, 8, '2019-10-15')
# 246. ('Bennett', 76, 4, '2018-01-30')
# 247. ('Bennett', 122, 1, '2018-01-30')
# 248. ('Bennett', 173, 1, '2017-07-31')
# 249. ('Bennett', 260, 3, '2017-07-09')
# 250. ('Bennett', 62, 1, '2017-03-14')
# 251. ('Bennett', 73, 1, '2019-08-06')
# 252. ('Benson', 19, 2, '2019-12-31')
# 253. ('Benson', 35, 1, '2017-03-28')
# 254. ('Benson', 171, 2, '2014-05-13')
# 255. ('Benson', 188, 1, '2017-03-28')
# 256. ('Benson', 254, 1, '2019-12-31')
# 257. ('Benson', 132, 1, '2019-03-30')
# 258. ('Bentley', 1, 1, '2017-08-30')
# 259. ('Bentley', 10, 1, '2017-08-30')
# 260. ('Bentley', 83, 1, '2019-04-15')
# 261. ('Bentley', 247, 1, '2018-01-05')
# 262. ('Bentley', 272, 1, '2019-04-15')
# 263. ('Benton', 218, 2, '2018-07-13')
# 264. ('Benton', 248, 1, '2019-11-14')
# 265. ('Berger', 96, 2, '2020-06-01')
# 266. ('Berger', 99, 4, '2020-06-01')
# 267. ('Best', 4, 3, '2019-02-04')
# 268. ('Best', 55, 1, '2018-05-10')
# 269. ('Best', 66, 3, '2019-02-04')
# 270. ('Best', 132, 1, '2019-02-04')
# 271. ('Best', 241, 2, '2018-05-10')
# 272. ('Bishop', 30, 1, '2018-12-20')
# 273. ('Bishop', 65, 1, '2018-12-20')
# 274. ('Bishop', 131, 1, '2018-12-20')
# 275. ('Bishop', 142, 1, '2016-07-24')
# 276. ('Bishop', 252, 1, '2016-07-24')
# 277. ('Bishop', 2, 1, '2016-01-29')
# 278. ('Bishop', 141, 1, '2016-01-29')
# 279. ('Bishop', 176, 9, '2018-06-06')
# 280. ('Bolton', 27, 2, '2016-01-19')
# 281. ('Bolton', 95, 2, '2015-08-03')
# 282. ('Bolton', 152, 2, '2016-01-19')
# 283. ('Bolton', 258, 1, '2020-04-08')
# 284. ('Bond', 15, 1, '2020-05-31')
# 285. ('Bond', 247, 1, '2020-05-08')
# 286. ('Bowman', 81, 1, '2019-02-26')
# 287. ('Bowman', 104, 3, '2013-01-09')
# 288. ('Bowman', 282, 3, '2019-02-26')
# 289. ('Boyer', 20, 1, '2019-01-22')
# 290. ('Boyer', 63, 1, '2017-01-13')
# 291. ('Boyer', 209, 4, '2017-07-31')
# 292. ('Boyer', 217, 4, '2018-05-04')
# 293. ('Boyer', 218, 2, '2017-07-31')
# 294. ('Boyer', 252, 4, '2017-01-13')
# 295. ('Boyle', 113, 1, '2018-08-29')
# 296. ('Boyle', 218, 1, '2015-07-31')
# 297. ('Boyle', 220, 1, '2015-07-31')
# 298. ('Boyle', 260, 6, '2015-07-31')
# 299. ('Boyle', 73, 2, '2019-02-04')
# 300. ('Boyle', 270, 3, '2020-07-11')
# 301. ('Bradley', 2, 1, '2018-12-29')
# 302. ('Bradley', 141, 3, '2019-08-03')
# 303. ('Bradley', 158, 3, '2019-12-14')
# 304. ('Bradley', None, None, None)
# 305. ('Bradley', 74, 1, '2014-06-14')
# 306. ('Bradley', 248, 1, '2014-06-14')
# 307. ('Bradley', 16, 1, '2017-06-17')
# 308. ('Bradley', 75, 3, '2020-06-09')
# 309. ('Bradley', 225, 1, '2017-06-17')
# 310. ('Bradley', 256, 1, '2017-06-17')
# 311. ('Bradley', 107, 1, '2018-11-16')
# 312. ('Bradley', 39, 8, '2017-02-18')
# 313. ('Bradley', 255, 1, '2017-02-18')
# 314. ('Bradley', 18, 1, '2020-05-27')
# 315. ('Brady', None, None, None)
# 316. ('Branch', 23, 2, '2018-08-29')
# 317. ('Branch', 143, 3, '2019-06-12')
# 318. ('Branch', 251, 1, '2019-05-26')
# 319. ('Brennan', None, None, None)
# 320. ('Brewer', 98, 1, '2015-04-25')
# 321. ('Brewer', 202, 3, '2017-08-05')
# 322. ('Brewer', 248, 1, '2017-08-05')
# 323. ('Brewer', None, None, None)
# 324. ('Bright', 124, 1, '2018-03-23')
# 325. ('Brooks', 35, 2, '2019-05-12')
# 326. ('Brooks', 186, 2, '2019-05-12')
# 327. ('Brooks', 218, 1, '2019-05-12')
# 328. ('Brown', 281, 2, '2014-10-07')
# 329. ('Brown', 69, 2, '2018-01-01')
# 330. ('Brown', 204, 3, '2018-01-01')
# 331. ('Brown', 280, 2, '2013-07-30')
# 332. ('Brown', 283, 2, '2015-04-12')
# 333. ('Brown', 82, 3, '2018-06-12')
# 334. ('Brown', 91, 2, '2018-01-23')
# 335. ('Brown', 117, 1, '2017-11-05')
# 336. ('Brown', 167, 1, '2018-01-23')
# 337. ('Brown', 236, 1, '2017-11-05')
# 338. ('Brown', 240, 5, '2013-04-09')
# 339. ('Brown', 253, 2, '2017-11-05')
# 340. ('Brown', None, None, None)
# 341. ('Brown', 194, 3, '2015-12-03')
# 342. ('Brown', None, None, None)
# 343. ('Brown', 116, 2, '2020-05-14')
# 344. ('Brown', 21, 1, '2016-01-22')
# 345. ('Brown', 45, 1, '2017-04-14')
# 346. ('Brown', 88, 1, '2017-04-14')
# 347. ('Brown', 155, 2, '2015-08-25')
# 348. ('Brown', 219, 1, '2016-01-22')
# 349. ('Brown', 244, 2, '2015-08-25')
# 350. ('Brown', 254, 2, '2017-04-14')
# 351. ('Brown', 13, 2, '2019-09-03')
# 352. ('Brown', 36, 1, '2014-02-04')
# 353. ('Brown', 53, 1, '2019-11-17')
# 354. ('Brown', 105, 1, '2019-05-20')
# 355. ('Brown', 153, 1, '2014-04-12')
# 356. ('Brown', 278, 2, '2019-11-17')
# 357. ('Buckley', 45, 1, '2017-02-10')
# 358. ('Buckley', 104, 3, '2019-02-21')
# 359. ('Buckley', 177, 1, '2019-02-21')
# 360. ('Bullock', 17, 1, '2015-12-13')
# 361. ('Bullock', 24, 2, '2015-12-13')
# 362. ('Bullock', 111, 3, '2016-07-07')
# 363. ('Bullock', 162, 1, '2016-07-07')
# 364. ('Burch', 87, 2, '2020-06-28')
# 365. ('Burch', 99, 3, '2020-07-01')
# 366. ('Burch', 131, 1, '2020-07-01')
# 367. ('Burch', 131, 1, '2020-07-19')
# 368. ('Burch', 197, 5, '2020-06-12')
# 369. ('Burch', 215, 1, '2020-07-01')
# 370. ('Burch', 248, 1, '2020-07-19')
# 371. ('Burns', 79, 3, '2019-07-10')
# 372. ('Burns', 125, 1, '2019-07-10')
# 373. ('Burns', 244, 1, '2019-07-10')
# 374. ('Burton', 148, 1, '2019-08-30')
# 375. ('Burton', 157, 1, '2020-07-23')
# 376. ('Burton', 160, 2, '2019-08-30')
# 377. ('Burton', 287, 1, '2020-07-23')
# 378. ('Bush', 77, 4, '2016-11-09')
# 379. ('Bush', 151, 1, '2017-12-28')
# 380. ('Bush', 253, 1, '2017-12-28')
# 381. ('Butler', 113, 1, '2019-12-12')
# 382. ('Byrd', 142, 1, '2015-03-06')
# 383. ('Byrd', 213, 3, '2015-03-06')
# 384. ('Byrd', None, None, None)
# 385. ('Byrd', 36, 2, '2011-10-17')
# 386. ('Byrd', 134, 1, '2011-10-17')
# 387. ('Byrd', 205, 2, '2011-10-17')
# 388. ('Cabrera', 197, 1, '2017-08-03')
# 389. ('Cabrera', 246, 1, '2018-05-24')
# 390. ('Cabrera', 270, 1, '2017-08-03')
# 391. ('Cain', 48, 1, '2018-06-08')
# 392. ('Cain', 54, 1, '2020-01-21')
# 393. ('Calhoun', None, None, None)
# 394. ('Callahan', 60, 1, '2020-07-11')
# 395. ('Camacho', 41, 1, '2011-11-21')
# 396. ('Camacho', 147, 1, '2011-11-21')
# 397. ('Camacho', 167, 1, '2011-11-21')
# 398. ('Cameron', 16, 4, '2020-04-20')
# 399. ('Cameron', 42, 2, '2018-06-30')
# 400. ('Cameron', 45, 1, '2018-06-30')
# 401. ('Cameron', 45, 1, '2020-04-20')
# 402. ('Cameron', 64, 2, '2018-06-30')
# 403. ('Cameron', 236, 1, '2017-11-15')
# 404. ('Cameron', 263, 1, '2020-04-20')
# 405. ('Cameron', 274, 1, '2018-06-30')
# 406. ('Cameron', 282, 1, '2018-12-25')
# 407. ('Cameron', 288, 4, '2020-04-20')
# 408. ('Campbell', 63, 1, '2017-03-18')
# 409. ('Campbell', 106, 2, '2017-03-18')
# 410. ('Campbell', 157, 2, '2020-01-03')
# 411. ('Campbell', 192, 2, '2020-01-03')
# 412. ('Campbell', 6, 1, '2015-08-16')
# 413. ('Campbell', 18, 1, '2012-06-02')
# 414. ('Campbell', 48, 1, '2015-08-16')
# 415. ('Campbell', 206, 2, '2019-01-30')
# 416. ('Campbell', 276, 2, '2015-08-16')
# 417. ('Cannon', None, None, None)
# 418. ('Cantrell', None, None, None)
# 419. ('Cardenas', 3, 2, '2020-06-25')
# 420. ('Cardenas', 189, 1, '2020-06-25')
# 421. ('Carlson', 8, 6, '2015-07-26')
# 422. ('Carlson', 10, 1, '2014-07-04')
# 423. ('Carlson', 52, 1, '2015-07-26')
# 424. ('Carlson', 66, 4, '2018-12-21')
# 425. ('Carlson', 217, 5, '2015-07-26')
# 426. ('Carlson', None, None, None)
# 427. ('Carlson', 35, 1, '2016-10-06')
# 428. ('Carlson', 50, 1, '2016-10-06')
# 429. ('Carlson', 205, 1, '2015-05-31')
# 430. ('Carlson', 277, 2, '2015-05-31')
# 431. ('Carlson', 142, 2, '2017-05-28')
# 432. ('Carlson', 156, 2, '2017-05-28')
# 433. ('Carlson', 180, 4, '2017-01-29')
# 434. ('Carlson', 182, 1, '2017-01-29')
# 435. ('Carlson', 187, 4, '2019-10-03')
# 436. ('Carpenter', 34, 1, '2019-12-24')
# 437. ('Carpenter', 267, 2, '2019-12-24')
# 438. ('Carpenter', 47, 3, '2015-04-01')
# 439. ('Carpenter', 178, 2, '2015-04-01')
# 440. ('Carr', 47, 1, '2020-06-21')
# 441. ('Carr', 86, 3, '2020-06-21')
# 442. ('Carr', 157, 3, '2020-07-03')
# 443. ('Carr', 219, 1, '2020-06-21')
# 444. ('Carr', 222, 1, '2020-07-03')
# 445. ('Carr', 275, 1, '2020-07-15')
# 446. ('Carr', 4, 1, '2020-03-01')
# 447. ('Carr', 17, 1, '2020-03-01')
# 448. ('Carr', 68, 1, '2018-04-11')
# 449. ('Carr', 233, 1, '2020-03-01')
# 450. ('Carroll', 75, 2, '2014-02-15')
# 451. ('Carroll', 20, 2, '2020-04-03')
# 452. ('Carroll', 61, 1, '2020-04-03')
# 453. ('Carroll', None, None, None)
# 454. ('Carter', 98, 1, '2015-11-04')
# 455. ('Carter', 117, 2, '2015-11-04')
# 456. ('Carter', 171, 2, '2015-11-04')
# 457. ('Carter', 201, 4, '2015-11-04')
# 458. ('Carter', 262, 2, '2015-11-04')
# 459. ('Carter', 210, 1, '2019-10-06')
# 460. ('Carter', None, None, None)
# 461. ('Case', 23, 7, '2015-01-02')
# 462. ('Case', 136, 2, '2015-09-24')
# 463. ('Case', 171, 1, '2015-01-02')
# 464. ('Case', 206, 2, '2015-01-02')
# 465. ('Case', 274, 1, '2015-01-02')
# 466. ('Casey', 24, 1, '2014-12-14')
# 467. ('Casey', 42, 2, '2016-07-19')
# 468. ('Casey', 46, 1, '2016-07-19')
# 469. ('Casey', 152, 2, '2014-12-14')
# 470. ('Casey', None, None, None)
# 471. ('Castillo', 163, 1, '2018-12-27')
# 472. ('Castillo', 212, 1, '2019-11-23')
# 473. ('Castillo', 218, 1, '2019-08-13')
# 474. ('Castillo', 233, 1, '2020-01-27')
# 475. ('Castillo', 263, 8, '2019-05-09')
# 476. ('Chambers', 180, 4, '2020-06-08')
# 477. ('Chambers', 263, 1, '2020-06-08')
# 478. ('Chaney', 116, 1, '2019-04-07')
# 479. ('Chaney', 148, 1, '2020-06-18')
# 480. ('Chaney', 151, 1, '2020-03-29')
# 481. ('Chaney', 213, 1, '2020-06-18')
# 482. ('Chaney', 236, 4, '2020-06-18')
# 483. ('Chaney', 244, 4, '2019-04-07')
# 484. ('Charles', 17, 4, '2017-09-22')
# 485. ('Charles', 204, 2, '2016-06-20')
# 486. ('Charles', 238, 1, '2016-06-20')
# 487. ('Charles', 240, 1, '2016-06-20')
# 488. ('Charles', 246, 2, '2016-06-20')
# 489. ('Charles', 270, 1, '2018-03-03')
# 490. ('Chavez', 110, 1, '2016-01-09')
# 491. ('Chavez', 144, 1, '2016-01-09')
# 492. ('Cisneros', 41, 1, '2018-07-15')
# 493. ('Cisneros', 120, 1, '2018-10-27')
# 494. ('Clark', 7, 1, '2013-10-04')
# 495. ('Clark', 27, 2, '2013-10-04')
# 496. ('Clark', 217, 4, '2013-08-01')
# 497. ('Clark', 228, 2, '2013-10-04')
# 498. ('Clark', 243, 2, '2015-08-10')
# 499. ('Clark', 243, 2, '2016-11-10')
# 500. ('Clark', 205, 5, '2019-12-07')
# 501. ('Clark', 268, 2, '2019-12-07')
# 502. ('Clark', 6, 1, '2020-07-13')
# 503. ('Clark', 79, 1, '2020-07-13')
# 504. ('Clark', 157, 1, '2020-07-13')
# 505. ('Clark', 99, 2, '2020-04-02')
# 506. ('Clark', 113, 2, '2020-04-02')
# 507. ('Clark', 132, 3, '2018-05-21')
# 508. ('Clark', 148, 2, '2013-02-21')
# 509. ('Clark', 225, 2, '2013-02-21')
# 510. ('Clark', 263, 1, '2018-05-21')
# 511. ('Clark', 18, 1, '2020-07-09')
# 512. ('Clark', 35, 2, '2019-08-25')
# 513. ('Clark', 194, 1, '2020-07-09')
# 514. ('Clark', 201, 1, '2019-06-02')
# 515. ('Clark', 154, 3, '2019-07-31')
# 516. ('Clark', 176, 1, '2019-07-31')
# 517. ('Clark', 182, 3, '2017-05-04')
# 518. ('Clark', 61, 1, '2016-10-18')
# 519. ('Clark', 152, 1, '2020-04-15')
# 520. ('Clark', 203, 3, '2016-10-18')
# 521. ('Clay', None, None, None)
# 522. ('Coffey', 54, 5, '2013-04-25')
# 523. ('Coffey', 103, 1, '2013-04-25')
# 524. ('Coffey', 205, 1, '2017-12-13')
# 525. ('Coffey', 220, 2, '2013-04-25')
# 526. ('Coleman', 25, 1, '2018-02-28')
# 527. ('Coleman', 76, 1, '2014-02-19')
# 528. ('Coleman', 242, 1, '2018-02-28')
# 529. ('Collier', 47, 2, '2019-02-02')
# 530. ('Collier', 241, 1, '2019-02-02')
# 531. ('Collins', 20, 1, '2018-12-21')
# 532. ('Collins', 157, 1, '2018-12-21')
# 533. ('Collins', 13, 1, '2012-10-12')
# 534. ('Collins', 31, 2, '2012-10-12')
# 535. ('Collins', 163, 1, '2012-10-12')
# 536. ('Collins', 213, 1, '2012-10-12')
# 537. ('Collins', 263, 1, '2014-03-23')
# 538. ('Collins', 24, 2, '2017-06-25')
# 539. ('Collins', 121, 3, '2017-12-12')
# 540. ('Collins', 190, 1, '2017-08-06')
# 541. ('Collins', 252, 2, '2017-06-25')
# 542. ('Collins', 103, 1, '2020-04-20')
# 543. ('Collins', 127, 2, '2020-06-06')
# 544. ('Combs', 105, 1, '2019-02-03')
# 545. ('Combs', 202, 1, '2019-02-03')
# 546. ('Compton', 112, 2, '2019-01-13')
# 547. ('Compton', 187, 2, '2019-01-13')
# 548. ('Cook', 45, 2, '2013-01-27')
# 549. ('Cook', 141, 2, '2014-08-21')
# 550. ('Cook', 160, 3, '2020-02-03')
# 551. ('Cooke', 58, 3, '2012-11-11')
# 552. ('Cooke', 68, 1, '2020-07-10')
# 553. ('Cooke', 135, 2, '2015-12-19')
# 554. ('Cooke', 140, 3, '2012-11-11')
# 555. ('Cooke', 273, 1, '2020-07-10')
# 556. ('Cooper', 74, 1, '2018-10-06')
# 557. ('Cooper', 232, 2, '2019-08-15')
# 558. ('Copeland', 54, 1, '2019-12-10')
# 559. ('Copeland', 58, 2, '2016-06-03')
# 560. ('Copeland', 64, 4, '2018-03-07')
# 561. ('Copeland', 78, 1, '2016-12-20')
# 562. ('Copeland', 120, 3, '2016-12-20')
# 563. ('Copeland', 208, 2, '2018-03-07')
# 564. ('Copeland', 211, 2, '2016-12-20')
# 565. ('Copeland', 222, 1, '2016-06-03')
# 566. ('Copeland', 243, 1, '2019-05-01')
# 567. ('Copeland', 277, 2, '2016-06-03')
# 568. ('Cox', 7, 1, '2018-11-24')
# 569. ('Cox', 39, 1, '2020-07-13')
# 570. ('Cox', 233, 4, '2020-07-13')
# 571. ('Cox', 269, 1, '2018-11-24')
# 572. ('Cox', 283, 1, '2019-07-26')
# 573. ('Cox', 63, 1, '2015-11-14')
# 574. ('Cox', 78, 1, '2015-08-15')
# 575. ('Cox', 170, 2, '2015-08-15')
# 576. ('Cox', 195, 7, '2020-02-26')
# 577. ('Cox', 105, 9, '2020-07-22')
# 578. ('Cox', 132, 2, '2014-04-13')
# 579. ('Cox', 134, 1, '2012-10-05')
# 580. ('Cox', 139, 2, '2020-07-22')
# 581. ('Cox', 145, 4, '2014-04-13')
# 582. ('Cox', 157, 1, '2012-10-05')
# 583. ('Cox', 293, 2, '2014-04-13')
# 584. ('Craig', 7, 1, '2018-02-17')
# 585. ('Craig', 91, 1, '2018-02-17')
# 586. ('Craig', 111, 2, '2018-03-26')
# 587. ('Craig', 241, 1, '2018-03-26')
# 588. ('Craig', 17, 2, '2015-04-13')
# 589. ('Craig', 54, 1, '2020-01-18')
# 590. ('Craig', 74, 1, '2015-11-01')
# 591. ('Craig', 248, 5, '2015-11-01')
# 592. ('Cross', 8, 2, '2016-12-15')
# 593. ('Cross', 16, 1, '2018-11-19')
# 594. ('Cross', 57, 2, '2016-06-13')
# 595. ('Cross', 135, 1, '2018-11-19')
# 596. ('Cross', 232, 2, '2018-11-19')
# 597. ('Cruz', 16, 2, '2020-03-01')
# 598. ('Cruz', 57, 2, '2018-03-31')
# 599. ('Cruz', 80, 1, '2018-03-31')
# 600. ('Cruz', 86, 1, '2019-10-11')
# 601. ('Cruz', 95, 2, '2020-03-01')
# 602. ('Cruz', 33, 1, '2017-05-15')
# 603. ('Cruz', 145, 1, '2016-12-13')
# 604. ('Cruz', 270, 2, '2018-07-24')
# 605. ('Cruz', 31, 1, '2017-09-04')
# 606. ('Cruz', 246, 1, '2017-09-04')
# 607. ('Cruz', 15, 1, '2017-08-12')
# 608. ('Cruz', 78, 3, '2019-12-20')
# 609. ('Cruz', 79, 2, '2019-12-20')
# 610. ('Cruz', 118, 1, '2018-06-28')
# 611. ('Cummings', 40, 1, '2013-05-27')
# 612. ('Cummings', 116, 1, '2012-03-03')
# 613. ('Cummings', 137, 1, '2016-07-20')
# 614. ('Cummings', 169, 1, '2012-03-03')
# 615. ('Cummings', 198, 3, '2013-05-27')
# 616. ('Cummings', 75, 1, '2017-11-06')
# 617. ('Cummings', 80, 1, '2013-06-24')
# 618. ('Cummings', 115, 1, '2015-11-16')
# 619. ('Cummings', 279, 2, '2019-06-26')
# 620. ('Dalton', None, None, None)
# 621. ('Dalton', 23, 1, '2017-11-10')
# 622. ('Dalton', 23, 1, '2020-01-16')
# 623. ('Dalton', 229, 2, '2020-01-16')
# 624. ('Dalton', 233, 1, '2018-02-27')
# 625. ('Davenport', 160, 2, '2020-01-12')
# 626. ('Davenport', 186, 2, '2020-03-31')
# 627. ('Davenport', 252, 1, '2020-03-31')
# 628. ('Davenport', 290, 2, '2020-01-12')
# 629. ('David', 17, 2, '2017-02-19')
# 630. ('David', 27, 1, '2014-07-23')
# 631. ('David', 92, 1, '2019-05-28')
# 632. ('David', 121, 1, '2017-02-19')
# 633. ('David', 192, 1, '2019-05-28')
# 634. ('David', 255, 1, '2014-07-23')
# 635. ('David', 277, 1, '2017-02-19')
# 636. ('Davidson', 81, 7, '2020-01-06')
# 637. ('Davidson', 129, 2, '2016-03-16')
# 638. ('Davidson', 135, 1, '2016-03-16')
# 639. ('Davidson', 243, 1, '2020-01-06')
# 640. ('Davila', None, None, None)
# 641. ('Davis', None, None, None)
# 642. ('Davis', 51, 1, '2019-09-25')
# 643. ('Davis', 64, 1, '2019-09-25')
# 644. ('Davis', 139, 5, '2019-09-25')
# 645. ('Davis', 13, 1, '2020-07-05')
# 646. ('Davis', 28, 1, '2019-08-04')
# 647. ('Davis', 45, 2, '2019-08-04')
# 648. ('Davis', 63, 1, '2019-08-04')
# 649. ('Davis', 198, 6, '2020-07-06')
# 650. ('Davis', 212, 1, '2020-07-06')
# 651. ('Davis', 79, 1, '2017-02-03')
# 652. ('Davis', 284, 1, '2014-03-03')
# 653. ('Davis', 105, 1, '2017-03-03')
# 654. ('Davis', 176, 1, '2013-10-17')
# 655. ('Davis', 29, 1, '2020-02-12')
# 656. ('Davis', 81, 1, '2020-03-04')
# 657. ('Davis', 152, 1, '2019-08-24')
# 658. ('Davis', 154, 1, '2019-08-24')
# 659. ('Davis', 248, 1, '2020-02-12')
# 660. ('Davis', 121, 3, '2020-05-10')
# 661. ('Davis', 213, 1, '2020-05-10')
# 662. ('Davis', 213, 2, '2020-05-10')
# 663. ('Davis', None, None, None)
# 664. ('Davis', 11, 3, '2019-01-30')
# 665. ('Davis', 14, 1, '2019-01-23')
# 666. ('Davis', 65, 2, '2020-02-10')
# 667. ('Davis', 67, 3, '2020-02-10')
# 668. ('Davis', 137, 1, '2015-04-18')
# 669. ('Davis', 148, 1, '2015-04-18')
# 670. ('Davis', 172, 1, '2015-04-18')
# 671. ('Davis', 224, 2, '2017-11-25')
# 672. ('Davis', 253, 2, '2015-04-18')
# 673. ('Davis', 258, 4, '2020-02-10')
# 674. ('Davis', 287, 2, '2019-01-23')
# 675. ('Davis', 35, 1, '2013-01-20')
# 676. ('Davis', 40, 1, '2013-01-20')
# 677. ('Davis', 120, 1, '2013-01-20')
# 678. ('Davis', 252, 1, '2014-03-11')
# 679. ('Dawson', 7, 1, '2017-07-08')
# 680. ('Dawson', 18, 3, '2018-08-06')
# 681. ('Dawson', 27, 1, '2018-09-13')
# 682. ('Dawson', 52, 2, '2017-12-10')
# 683. ('Dawson', 119, 3, '2017-12-10')
# 684. ('Dawson', 185, 1, '2018-09-13')
# 685. ('Dawson', 187, 3, '2017-07-08')
# 686. ('Dawson', 188, 2, '2017-07-08')
# 687. ('Decker', 31, 3, '2017-10-08')
# 688. ('Decker', 73, 1, '2020-01-14')
# 689. ('Decker', 81, 1, '2017-10-08')
# 690. ('Decker', 124, 1, '2020-01-14')
# 691. ('Decker', 145, 1, '2020-07-20')
# 692. ('Decker', 158, 4, '2017-10-08')
# 693. ('Decker', 164, 1, '2017-10-08')
# 694. ('Decker', 235, 1, '2020-01-14')
# 695. ('Dennis', 28, 2, '2018-01-12')
# 696. ('Dennis', 174, 1, '2018-01-12')
# 697. ('Diaz', 67, 1, '2019-07-25')
# 698. ('Diaz', 153, 4, '2019-07-25')
# 699. ('Diaz', 228, 2, '2018-11-15')
# 700. ('Diaz', 50, 2, '2019-12-24')
# 701. ('Diaz', 115, 1, '2019-12-24')
# 702. ('Diaz', 171, 2, '2019-12-24')
# 703. ('Diaz', 232, 5, '2020-03-14')
# 704. ('Diaz', 118, 1, '2015-12-24')
# 705. ('Diaz', 170, 2, '2017-02-25')
# 706. ('Diaz', 215, 1, '2017-02-25')
# 707. ('Diaz', 218, 2, '2015-12-24')
# 708. ('Diaz', 9, 1, '2019-05-19')
# 709. ('Diaz', 224, 2, '2019-05-19')
# 710. ('Diaz', 84, 2, '2019-07-07')
# 711. ('Diaz', 147, 2, '2020-01-14')
# 712. ('Diaz', 275, 2, '2020-01-14')
# 713. ('Dickerson', 120, 1, '2013-02-26')
# 714. ('Dickerson', 152, 1, '2019-08-11')
# 715. ('Dickerson', 213, 2, '2019-08-11')
# 716. ('Dickerson', 289, 1, '2011-02-15')
# 717. ('Dixon', None, None, None)
# 718. ('Dixon', 200, 1, '2020-07-28')
# 719. ('Dominguez', None, None, None)
# 720. ('Dominguez', 199, 4, '2019-12-24')
# 721. ('Dominguez', 243, 2, '2015-04-25')
# 722. ('Donovan', None, None, None)
# 723. ('Duffy', 22, 3, '2020-07-03')
# 724. ('Duffy', 121, 2, '2020-05-01')
# 725. ('Duffy', 180, 1, '2020-07-04')
# 726. ('Duffy', 196, 1, '2020-05-01')
# 727. ('Duffy', 259, 1, '2020-07-04')
# 728. ('Duffy', 286, 1, '2020-07-04')
# 729. ('Duncan', 157, 2, '2016-03-11')
# 730. ('Duncan', 61, 2, '2020-02-15')
# 731. ('Duncan', 77, 1, '2019-11-13')
# 732. ('Duncan', 105, 6, '2019-11-13')
# 733. ('Duncan', 110, 1, '2019-08-21')
# 734. ('Duncan', 134, 3, '2019-11-13')
# 735. ('Duncan', 177, 2, '2019-08-21')
# 736. ('Duncan', 226, 1, '2019-10-31')
# 737. ('Duncan', 237, 5, '2019-10-31')
# 738. ('Duncan', 266, 4, '2019-08-21')
# 739. ('Duncan', 291, 1, '2020-07-01')
# 740. ('Dunn', 46, 2, '2020-02-03')
# 741. ('Dunn', 81, 1, '2019-09-02')
# 742. ('Dunn', 98, 2, '2019-08-02')
# 743. ('Dunn', 131, 2, '2019-09-02')
# 744. ('Dunn', 211, 1, '2019-09-02')
# 745. ('Dunn', 246, 2, '2015-04-06')
# 746. ('Dunn', 267, 1, '2015-04-06')
# 747. ('Dunn', 284, 1, '2019-02-28')
# 748. ('Duran', None, None, None)
# 749. ('Eaton', None, None, None)
# 750. ('Edwards', None, None, None)
# 751. ('Edwards', 13, 1, '2019-09-12')
# 752. ('Edwards', 26, 3, '2019-09-12')
# 753. ('Edwards', 28, 2, '2020-01-22')
# 754. ('Edwards', 79, 1, '2019-09-12')
# 755. ('Edwards', 152, 1, '2019-09-24')
# 756. ('Edwards', 194, 1, '2019-09-12')
# 757. ('Edwards', 205, 2, '2020-02-18')
# 758. ('Edwards', 211, 2, '2020-01-22')
# 759. ('Edwards', 214, 1, '2020-02-18')
# 760. ('Edwards', 243, 3, '2019-09-12')
# 761. ('Edwards', 77, 1, '2017-11-14')
# 762. ('Edwards', 95, 1, '2017-11-14')
# 763. ('Edwards', 182, 1, '2018-09-26')
# 764. ('Edwards', 216, 1, '2014-12-12')
# 765. ('Edwards', 255, 2, '2014-12-12')
# 766. ('Edwards', 281, 1, '2014-11-13')
# 767. ('Edwards', 293, 2, '2015-10-08')
# 768. ('Edwards', 24, 1, '2020-04-17')
# 769. ('Edwards', 48, 1, '2020-04-17')
# 770. ('Edwards', 101, 1, '2019-04-05')
# 771. ('Edwards', 190, 1, '2019-04-05')
# 772. ('Edwards', 216, 1, '2020-06-21')
# 773. ('Elliott', 72, 4, '2017-06-03')
# 774. ('Elliott', 186, 1, '2017-06-03')
# 775. ('Elliott', 35, 1, '2016-04-13')
# 776. ('Elliott', 83, 1, '2020-05-19')
# 777. ('Elliott', 99, 1, '2016-04-13')
# 778. ('Elliott', 216, 1, '2020-05-19')
# 779. ('Elliott', 229, 1, '2016-04-13')
# 780. ('Ellis', 76, 5, '2020-03-31')
# 781. ('Ellis', 130, 2, '2020-03-31')
# 782. ('Ellis', 183, 1, '2020-03-31')
# 783. ('Ellis', 198, 1, '2017-12-05')
# 784. ('Ellis', 269, 1, '2015-06-26')
# 785. ('Ellis', 113, 2, '2019-06-13')
# 786. ('Ellis', 212, 2, '2019-06-13')
# 787. ('Ellis', None, None, None)
# 788. ('Erickson', 53, 4, '2020-02-04')
# 789. ('Erickson', 85, 1, '2020-07-24')
# 790. ('Erickson', 124, 2, '2020-07-24')
# 791. ('Erickson', 142, 1, '2020-03-25')
# 792. ('Erickson', 151, 4, '2019-08-18')
# 793. ('Erickson', 156, 2, '2020-03-25')
# 794. ('Erickson', 210, 4, '2020-07-24')
# 795. ('Erickson', 239, 1, '2020-02-04')
# 796. ('Erickson', 241, 1, '2020-03-25')
# 797. ('Espinoza', 58, 3, '2019-09-07')
# 798. ('Espinoza', 66, 2, '2020-04-02')
# 799. ('Espinoza', 138, 1, '2019-09-07')
# 800. ('Espinoza', 211, 4, '2019-09-07')
# 801. ('Espinoza', 213, 2, '2019-11-15')
# 802. ('Estrada', 149, 2, '2016-05-20')
# 803. ('Estrada', None, None, None)
# 804. ('Evans', 11, 3, '2016-09-05')
# 805. ('Evans', 18, 1, '2019-03-17')
# 806. ('Evans', 49, 3, '2019-12-15')
# 807. ('Evans', 50, 1, '2019-04-14')
# 808. ('Evans', 73, 1, '2016-10-26')
# 809. ('Evans', 119, 1, '2019-12-15')
# 810. ('Evans', 220, 3, '2016-10-26')
# 811. ('Evans', 19, 1, '2019-12-17')
# 812. ('Evans', 124, 2, '2019-08-30')
# 813. ('Evans', 275, 1, '2019-08-30')
# 814. ('Evans', 63, 3, '2016-02-07')
# 815. ('Evans', 76, 2, '2015-02-08')
# 816. ('Evans', 109, 1, '2019-08-20')
# 817. ('Evans', 143, 1, '2016-02-07')
# 818. ('Evans', 157, 3, '2016-02-07')
# 819. ('Evans', 198, 2, '2015-02-08')
# 820. ('Evans', 245, 1, '2016-02-07')
# 821. ('Evans', 256, 3, '2016-12-09')
# 822. ('Evans', None, None, None)
# 823. ('Evans', 80, 1, '2018-09-22')
# 824. ('Evans', 82, 2, '2012-12-22')
# 825. ('Evans', 164, 1, '2012-12-22')
# 826. ('Evans', 203, 1, '2018-04-14')
# 827. ('Evans', 39, 2, '2018-02-14')
# 828. ('Evans', 52, 1, '2020-07-12')
# 829. ('Evans', 68, 1, '2018-02-14')
# 830. ('Evans', 81, 4, '2020-07-12')
# 831. ('Evans', 134, 1, '2020-07-12')
# 832. ('Evans', 199, 1, '2020-07-12')
# 833. ('Evans', 202, 1, '2020-07-12')
# 834. ('Evans', 206, 2, '2020-07-12')
# 835. ('Evans', 234, 3, '2020-07-12')
# 836. ('Evans', 279, 2, '2017-01-18')
# 837. ('Evans', 5, 2, '2019-06-24')
# 838. ('Evans', 42, 3, '2019-02-13')
# 839. ('Evans', 210, 2, '2019-06-24')
# 840. ('Evans', 197, 3, '2018-08-09')
# 841. ('Evans', 265, 6, '2019-08-31')
# 842. ('Fernandez', None, None, None)
# 843. ('Fernandez', 85, 2, '2014-09-15')
# 844. ('Fernandez', 93, 5, '2014-04-28')
# 845. ('Fernandez', 127, 3, '2015-05-19')
# 846. ('Fernandez', 138, 1, '2014-04-28')
# 847. ('Fernandez', 140, 1, '2018-12-23')
# 848. ('Fernandez', 171, 2, '2015-05-19')
# 849. ('Fernandez', 173, 6, '2020-07-14')
# 850. ('Fernandez', 205, 8, '2019-03-09')
# 851. ('Fernandez', 224, 1, '2015-05-19')
# 852. ('Fernandez', 228, 1, '2019-03-09')
# 853. ('Fernandez', 232, 2, '2015-05-19')
# 854. ('Fernandez', 235, 4, '2019-03-09')
# 855. ('Fields', 17, 1, '2019-10-16')
# 856. ('Fields', 49, 1, '2019-10-16')
# 857. ('Fields', 244, 1, '2019-10-16')
# 858. ('Fields', 246, 2, '2019-10-16')
# 859. ('Fields', 263, 1, '2019-10-16')
# 860. ('Fields', 272, 1, '2019-10-16')
# 861. ('Finley', 93, 6, '2019-08-09')
# 862. ('Finley', 269, 2, '2019-08-09')
# 863. ('Fisher', 14, 1, '2014-09-01')
# 864. ('Fisher', 206, 4, '2014-09-01')
# 865. ('Fisher', 286, 1, '2014-09-01')
# 866. ('Fitzpatrick', 9, 2, '2018-07-12')
# 867. ('Fitzpatrick', 23, 1, '2018-07-12')
# 868. ('Fitzpatrick', 70, 1, '2016-01-25')
# 869. ('Fitzpatrick', 130, 1, '2018-07-12')
# 870. ('Fitzpatrick', 132, 1, '2018-07-12')
# 871. ('Fitzpatrick', 217, 1, '2016-01-25')
# 872. ('Fitzpatrick', 231, 2, '2018-07-12')
# 873. ('Fleming', 18, 1, '2016-05-18')
# 874. ('Fleming', 41, 3, '2019-10-06')
# 875. ('Fleming', 80, 1, '2017-12-21')
# 876. ('Fleming', 94, 1, '2017-12-21')
# 877. ('Fleming', 114, 5, '2017-04-19')
# 878. ('Fleming', 166, 1, '2017-12-21')
# 879. ('Fleming', 220, 3, '2017-04-19')
# 880. ('Fleming', 226, 1, '2016-05-18')
# 881. ('Fleming', 255, 1, '2016-11-10')
# 882. ('Fletcher', 129, 1, '2017-03-09')
# 883. ('Fletcher', 183, 1, '2019-04-07')
# 884. ('Fletcher', 215, 1, '2018-08-13')
# 885. ('Fletcher', 135, 4, '2017-10-25')
# 886. ('Fletcher', 201, 2, '2010-10-29')
# 887. ('Fletcher', 239, 2, '2014-08-12')
# 888. ('Fletcher', 281, 1, '2017-10-25')
# 889. ('Fletcher', 288, 1, '2011-08-02')
# 890. ('Flores', 38, 2, '2018-09-22')
# 891. ('Flores', 117, 1, '2016-08-18')
# 892. ('Flores', 127, 1, '2017-06-25')
# 893. ('Flores', 135, 1, '2016-12-17')
# 894. ('Flores', 149, 1, '2018-09-22')
# 895. ('Flores', 162, 1, '2017-09-24')
# 896. ('Flores', 216, 2, '2016-08-18')
# 897. ('Flores', 221, 1, '2016-08-18')
# 898. ('Flores', 249, 2, '2016-08-18')
# 899. ('Floyd', 9, 1, '2019-05-13')
# 900. ('Floyd', 25, 1, '2015-01-19')
# 901. ('Floyd', 196, 1, '2015-01-19')
# 902. ('Floyd', 209, 1, '2017-11-17')
# 903. ('Floyd', 261, 1, '2017-11-17')
# 904. ('Floyd', 277, 4, '2017-11-17')
# 905. ('Floyd', 283, 1, '2018-07-04')
# 906. ('Foster', 18, 3, '2018-05-31')
# 907. ('Foster', 36, 1, '2019-01-19')
# 908. ('Foster', 96, 2, '2019-01-19')
# 909. ('Foster', 167, 4, '2018-07-02')
# 910. ('Foster', 178, 1, '2017-10-01')
# 911. ('Fowler', None, None, None)
# 912. ('Fowler', None, None, None)
# 913. ('Franco', 1, 1, '2017-03-05')
# 914. ('Franco', 4, 4, '2019-09-09')
# 915. ('Franco', 6, 1, '2017-06-10')
# 916. ('Franco', 25, 1, '2018-10-11')
# 917. ('Franco', 56, 1, '2017-03-05')
# 918. ('Franco', 132, 1, '2018-10-11')
# 919. ('Franco', 139, 1, '2019-03-09')
# 920. ('Franco', 209, 1, '2017-06-10')
# 921. ('Franco', 235, 1, '2017-06-10')
# 922. ('Franco', 54, 2, '2020-06-05')
# 923. ('Franco', 152, 2, '2017-05-11')
# 924. ('Franco', 172, 2, '2017-05-11')
# 925. ('Franco', 294, 1, '2020-06-05')
# 926. ('Frank', 170, 2, '2018-12-25')
# 927. ('Frank', 196, 1, '2016-10-17')
# 928. ('Friedman', 27, 1, '2014-01-15')
# 929. ('Friedman', 47, 2, '2019-07-28')
# 930. ('Friedman', 60, 1, '2016-06-19')
# 931. ('Friedman', 61, 1, '2016-06-19')
# 932. ('Friedman', 70, 2, '2014-01-15')
# 933. ('Friedman', 133, 1, '2014-04-11')
# 934. ('Friedman', 155, 1, '2019-09-03')
# 935. ('Friedman', 169, 1, '2014-04-11')
# 936. ('Friedman', 257, 5, '2016-06-19')
# 937. ('Friedman', 262, 3, '2019-09-03')
# 938. ('Friedman', 264, 3, '2016-06-19')
# 939. ('Friedman', 267, 1, '2019-07-28')
# 940. ('Frost', 74, 3, '2017-02-23')
# 941. ('Frost', 213, 1, '2019-09-01')
# 942. ('Frye', 35, 2, '2016-10-24')
# 943. ('Frye', 36, 1, '2016-10-24')
# 944. ('Frye', 202, 2, '2018-08-26')
# 945. ('Frye', 217, 1, '2016-10-24')
# 946. ('Frye', 270, 1, '2019-03-07')
# 947. ('Frye', 286, 3, '2016-10-24')
# 948. ('Frye', 5, 2, '2018-09-04')
# 949. ('Frye', 27, 1, '2019-08-22')
# 950. ('Frye', 135, 1, '2017-09-20')
# 951. ('Frye', 178, 3, '2018-09-04')
# 952. ('Frye', 185, 2, '2017-08-01')
# 953. ('Frye', 224, 1, '2020-07-21')
# 954. ('Fuller', None, None, None)
# 955. ('Gaines', 102, 1, '2020-07-04')
# 956. ('Gaines', 46, 1, '2018-10-24')
# 957. ('Gaines', 152, 2, '2018-10-24')
# 958. ('Gallegos', 65, 2, '2018-06-28')
# 959. ('Gallegos', 76, 1, '2018-06-28')
# 960. ('Gamble', 73, 1, '2018-09-30')
# 961. ('Gamble', 85, 4, '2018-09-30')
# 962. ('Gamble', 95, 2, '2019-07-05')
# 963. ('Gamble', 146, 1, '2019-08-08')
# 964. ('Gamble', 221, 3, '2019-08-08')
# 965. ('Gamble', 38, 2, '2017-01-09')
# 966. ('Garcia', 238, 1, '2020-07-09')
# 967. ('Garcia', 47, 3, '2018-09-08')
# 968. ('Garcia', 54, 4, '2018-09-08')
# 969. ('Garcia', 110, 2, '2012-10-02')
# 970. ('Garcia', 119, 1, '2012-10-02')
# 971. ('Garcia', 153, 1, '2018-09-08')
# 972. ('Garcia', 164, 2, '2018-09-08')
# 973. ('Garcia', 243, 1, '2018-09-08')
# 974. ('Garcia', 7, 1, '2017-05-10')
# 975. ('Garcia', 48, 3, '2017-03-21')
# 976. ('Garcia', 92, 1, '2016-12-05')
# 977. ('Garcia', 228, 2, '2018-08-15')
# 978. ('Garcia', 235, 1, '2016-11-25')
# 979. ('Garcia', 279, 5, '2018-08-15')
# 980. ('Garcia', 286, 1, '2018-08-15')
# 981. ('Garcia', 23, 3, '2013-04-12')
# 982. ('Garcia', 66, 2, '2013-04-12')
# 983. ('Garcia', 94, 2, '2014-01-13')
# 984. ('Garcia', 101, 1, '2015-03-23')
# 985. ('Garcia', 128, 1, '2014-01-13')
# 986. ('Garcia', 149, 1, '2015-06-07')
# 987. ('Garcia', 152, 1, '2015-03-23')
# 988. ('Garcia', 164, 2, '2015-03-23')
# 989. ('Garcia', 184, 1, '2013-04-12')
# 990. ('Garcia', 186, 1, '2015-10-31')
# 991. ('Garcia', 208, 2, '2013-04-12')
# 992. ('Garcia', 211, 1, '2015-03-23')
# 993. ('Garcia', 238, 1, '2015-06-07')
# 994. ('Garcia', 239, 1, '2013-12-21')
# 995. ('Garcia', 247, 1, '2013-12-21')
# 996. ('Garcia', 150, 1, '2016-06-21')
# 997. ('Garcia', 169, 1, '2016-08-22')
# 998. ('Garcia', 199, 1, '2019-04-19')
# 999. ('Garcia', 232, 1, '2019-04-19')
# 1000. ('Garcia', 263, 1, '2016-08-22')
# 1001. ('Garcia', 136, 1, '2015-08-16')
# 1002. ('Garcia', 2, 1, '2017-06-02')
# 1003. ('Garcia', 96, 1, '2017-06-02')
# 1004. ('Garcia', 130, 1, '2017-06-02')
# 1005. ('Garcia', 135, 2, '2017-06-02')
# 1006. ('Garcia', 168, 2, '2017-04-16')
# 1007. ('Garcia', 190, 1, '2017-06-02')
# 1008. ('Garcia', 4, 1, '2017-10-09')
# 1009. ('Garcia', 20, 1, '2019-07-13')
# 1010. ('Garcia', 118, 2, '2020-04-04')
# 1011. ('Garcia', 220, 3, '2020-04-04')
# 1012. ('Garcia', 14, 2, '2020-06-28')
# 1013. ('Garcia', 86, 1, '2016-07-22')
# 1014. ('Garcia', 111, 3, '2020-01-15')
# 1015. ('Garcia', 124, 1, '2020-01-31')
# 1016. ('Garcia', 179, 2, '2020-01-15')
# 1017. ('Garcia', 228, 2, '2020-01-31')
# 1018. ('Garcia', 240, 2, '2016-07-22')
# 1019. ('Garcia', 248, 2, '2020-01-31')
# 1020. ('Garcia', 254, 1, '2016-07-22')
# 1021. ('Gardner', 31, 2, '2019-01-19')
# 1022. ('Gardner', 50, 1, '2020-04-24')
# 1023. ('Gardner', 174, 1, '2019-01-19')
# 1024. ('Gardner', 211, 1, '2020-04-24')
# 1025. ('Gardner', 256, 1, '2020-04-24')
# 1026. ('Gardner', 77, 1, '2020-07-12')
# 1027. ('Gardner', 274, 1, '2020-07-12')
# 1028. ('Gardner', 76, 1, '2016-10-28')
# 1029. ('Gardner', 226, 2, '2016-10-28')
# 1030. ('Garner', 23, 2, '2014-05-07')
# 1031. ('Garner', 104, 1, '2014-12-02')
# 1032. ('Garner', 254, 3, '2015-08-03')
# 1033. ('Garrett', 20, 1, '2018-09-25')
# 1034. ('Garrett', 140, 2, '2018-09-25')
# 1035. ('Garrett', 52, 1, '2018-01-26')
# 1036. ('Garrett', 264, 1, '2019-03-24')
# 1037. ('Garza', 84, 1, '2013-06-28')
# 1038. ('Garza', 123, 3, '2015-07-05')
# 1039. ('Garza', 128, 2, '2017-09-18')
# 1040. ('Garza', 191, 1, '2013-06-28')
# 1041. ('Garza', 62, 2, '2019-02-10')
# 1042. ('Garza', 158, 2, '2019-02-10')
# 1043. ('Garza', 177, 1, '2019-02-10')
# 1044. ('Gates', 1, 4, '2014-10-08')
# 1045. ('Gates', 120, 1, '2014-10-08')
# 1046. ('Gentry', 16, 4, '2020-05-30')
# 1047. ('Gentry', 44, 2, '2020-05-30')
# 1048. ('Gentry', 241, 2, '2020-05-30')
# 1049. ('George', None, None, None)
# 1050. ('Gibbs', 65, 1, '2018-08-09')
# 1051. ('Gibbs', 77, 1, '2018-08-09')
# 1052. ('Gibbs', 180, 5, '2018-08-09')
# 1053. ('Gibson', 9, 1, '2015-12-06')
# 1054. ('Gibson', 88, 1, '2015-11-01')
# 1055. ('Gibson', 115, 2, '2015-11-01')
# 1056. ('Gibson', 249, 1, '2015-11-01')
# 1057. ('Gillespie', 3, 1, '2017-11-21')
# 1058. ('Gillespie', 43, 1, '2017-03-18')
# 1059. ('Gillespie', 143, 5, '2018-05-09')
# 1060. ('Gillespie', 191, 1, '2017-11-21')
# 1061. ('Gillespie', 203, 1, '2018-05-09')
# 1062. ('Gomez', None, None, None)
# 1063. ('Gonzales', 167, 1, '2019-10-07')
# 1064. ('Gonzales', 210, 1, '2018-12-20')
# 1065. ('Gonzales', 268, 1, '2015-07-14')
# 1066. ('Gonzales', 269, 1, '2015-07-14')
# 1067. ('Gonzales', 287, 1, '2012-07-22')
# 1068. ('Gonzalez', 71, 2, '2015-05-18')
# 1069. ('Gonzalez', 125, 3, '2018-10-08')
# 1070. ('Gonzalez', 223, 6, '2019-02-03')
# 1071. ('Gonzalez', 22, 1, '2020-02-27')
# 1072. ('Gonzalez', 88, 1, '2017-07-30')
# 1073. ('Gonzalez', 116, 2, '2018-06-17')
# 1074. ('Gonzalez', 48, 1, '2013-12-24')
# 1075. ('Gonzalez', 90, 2, '2016-04-29')
# 1076. ('Gonzalez', 127, 2, '2016-04-29')
# 1077. ('Gonzalez', 258, 1, '2016-04-29')
# 1078. ('Gonzalez', 16, 2, '2017-10-07')
# 1079. ('Gonzalez', 22, 1, '2016-09-03')
# 1080. ('Gonzalez', 34, 2, '2020-06-20')
# 1081. ('Gonzalez', 55, 1, '2017-10-07')
# 1082. ('Gonzalez', 153, 1, '2020-06-20')
# 1083. ('Gonzalez', 160, 1, '2016-09-03')
# 1084. ('Gonzalez', 227, 1, '2017-10-07')
# 1085. ('Gonzalez', 257, 1, '2020-06-20')
# 1086. ('Gonzalez', 172, 2, '2018-04-16')
# 1087. ('Gonzalez', 38, 2, '2016-07-09')
# 1088. ('Gonzalez', 81, 2, '2016-07-09')
# 1089. ('Gonzalez', 136, 1, '2016-07-09')
# 1090. ('Gonzalez', 211, 3, '2015-09-05')
# 1091. ('Gonzalez', 252, 1, '2019-12-13')
# 1092. ('Gonzalez', 265, 1, '2019-12-13')
# 1093. ('Gonzalez', 61, 1, '2019-10-15')
# 1094. ('Gonzalez', 144, 1, '2019-08-30')
# 1095. ('Gonzalez', 277, 3, '2019-08-30')
# 1096. ('Gonzalez', 113, 1, '2019-01-09')
# 1097. ('Gonzalez', 131, 2, '2015-10-06')
# 1098. ('Gonzalez', 195, 1, '2019-01-09')
# 1099. ('Gonzalez', 204, 2, '2015-10-06')
# 1100. ('Gonzalez', 247, 1, '2019-01-09')
# 1101. ('Gonzalez', 282, 1, '2019-03-14')
# 1102. ('Goodman', 43, 3, '2017-05-20')
# 1103. ('Goodman', 63, 2, '2016-10-01')
# 1104. ('Goodman', 196, 1, '2017-05-20')
# 1105. ('Goodwin', None, None, None)
# 1106. ('Gordon', 5, 2, '2015-05-26')
# 1107. ('Gordon', 115, 3, '2015-05-26')
# 1108. ('Gordon', 190, 2, '2015-05-26')
# 1109. ('Gordon', 252, 1, '2015-05-26')
# 1110. ('Gordon', 47, 2, '2016-09-15')
# 1111. ('Gould', 21, 3, '2019-12-23')
# 1112. ('Gould', 285, 2, '2019-12-23')
# 1113. ('Gould', 167, 1, '2019-04-28')
# 1114. ('Gould', 222, 2, '2019-04-28')
# 1115. ('Graham', 28, 4, '2020-03-24')
# 1116. ('Graham', 39, 1, '2019-10-03')
# 1117. ('Graham', 94, 1, '2020-03-24')
# 1118. ('Graham', 110, 5, '2020-03-24')
# 1119. ('Graham', 112, 3, '2018-11-23')
# 1120. ('Graham', 135, 2, '2019-11-23')
# 1121. ('Graham', 140, 1, '2020-03-24')
# 1122. ('Graham', 143, 3, '2020-03-01')
# 1123. ('Graham', 233, 1, '2019-10-03')
# 1124. ('Graham', 262, 1, '2019-10-03')
# 1125. ('Graham', 284, 1, '2020-01-06')
# 1126. ('Grant', 184, 1, '2019-12-05')
# 1127. ('Grant', 187, 1, '2019-12-05')
# 1128. ('Grant', 217, 8, '2019-12-05')
# 1129. ('Grant', 245, 2, '2019-12-05')
# 1130. ('Grant', 260, 4, '2019-02-10')
# 1131. ('Grant', 22, 6, '2017-12-01')
# 1132. ('Graves', 195, 2, '2019-05-02')
# 1133. ('Graves', 261, 2, '2019-05-02')
# 1134. ('Graves', 268, 1, '2020-03-26')
# 1135. ('Graves', 271, 1, '2016-04-27')
# 1136. ('Graves', 275, 3, '2016-04-27')
# 1137. ('Graves', 131, 3, '2019-08-12')
# 1138. ('Graves', 177, 2, '2017-11-16')
# 1139. ('Gray', 58, 3, '2014-10-06')
# 1140. ('Gray', 79, 2, '2014-10-06')
# 1141. ('Gray', 83, 1, '2014-10-06')
# 1142. ('Gray', 257, 3, '2020-04-17')
# 1143. ('Gray', 270, 2, '2018-11-02')
# 1144. ('Green', 9, 1, '2015-12-05')
# 1145. ('Green', 83, 5, '2020-03-30')
# 1146. ('Green', 137, 1, '2015-12-05')
# 1147. ('Green', 225, 8, '2015-12-05')
# 1148. ('Green', 229, 4, '2015-07-03')
# 1149. ('Green', 240, 2, '2015-07-03')
# 1150. ('Green', None, None, None)
# 1151. ('Green', 267, 3, '2020-06-24')
# 1152. ('Green', None, None, None)
# 1153. ('Greene', 40, 2, '2018-10-24')
# 1154. ('Greene', 58, 1, '2019-06-21')
# 1155. ('Greene', 70, 3, '2019-06-21')
# 1156. ('Greene', 84, 1, '2019-06-21')
# 1157. ('Greene', 269, 3, '2019-05-18')
# 1158. ('Greene', 183, 3, '2020-03-24')
# 1159. ('Greene', 221, 1, '2020-03-24')
# 1160. ('Greene', 265, 2, '2018-08-02')
# 1161. ('Greene', 289, 1, '2020-03-24')
# 1162. ('Greene', 10, 1, '2020-07-14')
# 1163. ('Greene', 65, 1, '2020-07-14')
# 1164. ('Greene', 211, 1, '2020-07-14')
# 1165. ('Gregory', 53, 1, '2018-03-10')
# 1166. ('Gregory', 231, 1, '2018-03-10')
# 1167. ('Griffin', 1, 5, '2017-06-03')
# 1168. ('Griffin', 11, 1, '2014-01-23')
# 1169. ('Griffin', 46, 2, '2017-06-03')
# 1170. ('Griffin', 105, 2, '2014-01-23')
# 1171. ('Griffin', 126, 2, '2014-01-23')
# 1172. ('Griffin', 160, 2, '2011-05-18')
# 1173. ('Griffin', 185, 2, '2011-05-18')
# 1174. ('Griffin', 253, 3, '2017-06-03')
# 1175. ('Griffin', 277, 1, '2019-04-12')
# 1176. ('Griffin', 79, 3, '2014-04-06')
# 1177. ('Griffith', 59, 3, '2017-09-20')
# 1178. ('Griffith', 251, 1, '2020-04-26')
# 1179. ('Griffith', 275, 1, '2016-09-13')
# 1180. ('Griffith', 29, 2, '2014-12-18')
# 1181. ('Griffith', 72, 1, '2014-12-18')
# 1182. ('Griffith', 266, 2, '2014-12-18')
# 1183. ('Griffith', 211, 1, '2018-11-25')
# 1184. ('Griffith', 5, 1, '2019-11-01')
# 1185. ('Griffith', 45, 1, '2019-11-01')
# 1186. ('Griffith', 76, 1, '2019-11-01')
# 1187. ('Griffith', 96, 1, '2019-11-01')
# 1188. ('Griffith', 130, 1, '2020-07-24')
# 1189. ('Griffith', 157, 1, '2020-07-24')
# 1190. ('Griffith', 232, 2, '2020-07-24')
# 1191. ('Griffith', 245, 1, '2020-05-19')
# 1192. ('Griffith', 5, 1, '2014-10-26')
# 1193. ('Griffith', 24, 1, '2014-10-26')
# 1194. ('Griffith', 33, 1, '2014-10-26')
# 1195. ('Griffith', 177, 2, '2013-09-29')
# 1196. ('Griffith', 239, 1, '2014-10-26')
# 1197. ('Gross', 146, 2, '2018-12-13')
# 1198. ('Gross', 159, 2, '2018-12-13')
# 1199. ('Gross', 177, 2, '2018-12-13')
# 1200. ('Gross', 201, 1, '2018-12-13')
# 1201. ('Gross', 258, 3, '2018-07-23')
# 1202. ('Gross', 272, 3, '2018-05-12')
# 1203. ('Gutierrez', 93, 1, '2015-02-03')
# 1204. ('Gutierrez', 240, 3, '2014-06-03')
# 1205. ('Gutierrez', 245, 1, '2017-08-04')
# 1206. ('Gutierrez', 108, 1, '2019-04-19')
# 1207. ('Gutierrez', 198, 2, '2019-04-05')
# 1208. ('Gutierrez', 272, 1, '2019-04-05')
# 1209. ('Gutierrez', 93, 1, '2019-06-24')
# 1210. ('Gutierrez', 121, 1, '2019-06-24')
# 1211. ('Gutierrez', 252, 1, '2019-06-24')
# 1212. ('Gutierrez', 25, 1, '2020-07-21')
# 1213. ('Gutierrez', 68, 3, '2020-06-06')
# 1214. ('Gutierrez', 226, 1, '2020-06-06')
# 1215. ('Gutierrez', 279, 1, '2020-07-21')
# 1216. ('Haas', 28, 1, '2015-10-13')
# 1217. ('Haas', 93, 1, '2014-12-28')
# 1218. ('Haas', 165, 1, '2017-09-15')
# 1219. ('Haas', 205, 1, '2018-05-08')
# 1220. ('Hahn', 108, 2, '2020-02-27')
# 1221. ('Hahn', 112, 3, '2020-02-27')
# 1222. ('Hahn', 117, 1, '2019-09-08')
# 1223. ('Hahn', 132, 1, '2019-05-06')
# 1224. ('Hahn', 140, 1, '2019-07-20')
# 1225. ('Hahn', 166, 1, '2019-05-06')
# 1226. ('Hahn', 197, 4, '2019-10-05')
# 1227. ('Hahn', 200, 1, '2019-08-23')
# 1228. ('Hahn', 209, 1, '2019-10-05')
# 1229. ('Hahn', 267, 1, '2019-05-06')
# 1230. ('Hale', 3, 1, '2018-03-30')
# 1231. ('Hale', 19, 1, '2015-11-27')
# 1232. ('Hale', 202, 1, '2019-10-13')
# 1233. ('Hale', 238, 2, '2015-11-27')
# 1234. ('Hale', 259, 1, '2019-10-13')
# 1235. ('Haley', 16, 6, '2017-07-31')
# 1236. ('Haley', 95, 1, '2016-11-24')
# 1237. ('Hall', 28, 2, '2018-06-30')
# 1238. ('Hall', 31, 1, '2016-03-27')
# 1239. ('Hall', 81, 2, '2018-06-30')
# 1240. ('Hall', 34, 2, '2017-07-26')
# 1241. ('Hall', 206, 1, '2017-07-26')
# 1242. ('Hall', 292, 1, '2020-01-01')
# 1243. ('Hall', None, None, None)
# 1244. ('Hall', 247, 1, '2016-07-08')
# 1245. ('Hall', 277, 1, '2016-07-08')
# 1246. ('Hamilton', None, None, None)
# 1247. ('Hamilton', 93, 1, '2017-10-05')
# 1248. ('Hamilton', 119, 1, '2015-05-12')
# 1249. ('Hamilton', 178, 4, '2016-04-12')
# 1250. ('Hamilton', 209, 2, '2019-09-20')
# 1251. ('Hamilton', 275, 3, '2017-10-05')
# 1252. ('Hamilton', 115, 1, '2016-02-11')
# 1253. ('Hamilton', 133, 2, '2019-05-18')
# 1254. ('Hampton', 153, 2, '2019-04-17')
# 1255. ('Hampton', 161, 1, '2018-05-22')
# 1256. ('Hampton', 215, 8, '2019-04-17')
# 1257. ('Hampton', 286, 3, '2017-10-10')
# 1258. ('Hanna', 34, 2, '2019-07-18')
# 1259. ('Hanna', 67, 3, '2016-04-18')
# 1260. ('Hanna', 120, 3, '2018-09-13')
# 1261. ('Hanna', 217, 2, '2016-07-26')
# 1262. ('Hanna', 217, 3, '2019-11-29')
# 1263. ('Hansen', 235, 1, '2018-01-26')
# 1264. ('Hansen', 279, 2, '2018-01-26')
# 1265. ('Hansen', 2, 1, '2019-06-11')
# 1266. ('Hansen', 78, 1, '2019-06-11')
# 1267. ('Hansen', 106, 1, '2019-03-10')
# 1268. ('Hanson', 53, 2, '2017-11-18')
# 1269. ('Hanson', 112, 3, '2012-04-15')
# 1270. ('Hanson', 166, 1, '2012-04-15')
# 1271. ('Hanson', 189, 1, '2017-11-18')
# 1272. ('Hanson', 199, 2, '2020-07-13')
# ...
# 3418. ('Vargas', 77, 1, '2019-01-26')
# 3419. ('Vargas', 248, 2, '2019-01-26')
# 3420. ('Vargas', 21, 1, '2013-09-19')
# 3421. ('Vargas', 77, 1, '2013-09-19')
# 3422. ('Vargas', 47, 1, '2015-01-01')
# 3423. ('Vargas', 114, 2, '2019-09-20')
# 3424. ('Vargas', 117, 2, '2019-09-20')
# 3425. ('Vargas', 183, 2, '2014-07-26')
# 3426. ('Vargas', 236, 1, '2019-09-20')
# 3427. ('Vargas', 248, 2, '2018-01-07')
# 3428. ('Vargas', 258, 2, '2018-01-07')
# 3429. ('Vasquez', 14, 3, '2014-08-30')
# 3430. ('Vasquez', 18, 1, '2016-10-25')
# 3431. ('Vasquez', 34, 1, '2016-10-25')
# 3432. ('Vasquez', 37, 1, '2016-10-25')
# 3433. ('Vasquez', 67, 2, '2018-02-13')
# 3434. ('Vasquez', 210, 1, '2016-10-25')
# 3435. ('Velasquez', 145, 3, '2019-01-18')
# 3436. ('Velasquez', 223, 2, '2019-01-18')
# 3437. ('Velasquez', 270, 2, '2019-01-18')
# 3438. ('Velez', 165, 2, '2019-10-13')
# 3439. ('Velez', 202, 4, '2019-10-13')
# 3440. ('Velez', 205, 1, '2019-09-15')
# 3441. ('Velez', 232, 2, '2018-09-09')
# 3442. ('Velez', 232, 5, '2018-09-09')
# 3443. ('Velez', 277, 4, '2018-01-26')
# 3444. ('Villarreal', 15, 1, '2019-06-06')
# 3445. ('Villarreal', 22, 1, '2019-01-17')
# 3446. ('Villarreal', 77, 2, '2019-06-06')
# 3447. ('Villarreal', 33, 1, '2020-06-01')
# 3448. ('Villarreal', 95, 3, '2018-12-02')
# 3449. ('Villarreal', 130, 1, '2019-09-23')
# 3450. ('Villarreal', 164, 4, '2016-07-14')
# 3451. ('Villarreal', 236, 2, '2019-09-23')
# 3452. ('Villarreal', 257, 3, '2017-10-27')
# 3453. ('Villarreal', 289, 1, '2019-09-23')
# 3454. ('Villarreal', 28, 3, '2019-12-02')
# 3455. ('Villarreal', 33, 3, '2019-12-02')
# 3456. ('Villarreal', 229, 1, '2019-12-02')
# 3457. ('Vincent', 109, 3, '2019-05-27')
# 3458. ('Vincent', 112, 1, '2019-10-11')
# 3459. ('Vincent', 152, 6, '2019-05-27')
# 3460. ('Vincent', 197, 2, '2017-12-26')
# 3461. ('Vincent', 228, 8, '2016-05-25')
# 3462. ('Vincent', 253, 1, '2019-05-27')
# 3463. ('Vincent', 257, 1, '2018-10-14')
# 3464. ('Vincent', 266, 1, '2019-10-11')
# 3465. ('Wade', 130, 2, '2016-09-02')
# 3466. ('Wade', 158, 2, '2016-09-02')
# 3467. ('Wade', 203, 1, '2019-07-28')
# 3468. ('Wade', 204, 1, '2019-07-28')
# 3469. ('Wade', 173, 1, '2012-12-16')
# 3470. ('Wade', 210, 1, '2014-02-15')
# 3471. ('Wade', 231, 2, '2014-02-15')
# 3472. ('Wagner', 57, 1, '2018-10-29')
# 3473. ('Wagner', 137, 1, '2017-06-04')
# 3474. ('Wagner', 191, 2, '2017-06-04')
# 3475. ('Wagner', 229, 4, '2018-04-08')
# 3476. ('Wagner', 13, 3, '2020-07-15')
# 3477. ('Wagner', 56, 2, '2020-02-23')
# 3478. ('Wagner', 167, 2, '2019-12-28')
# 3479. ('Wagner', 240, 1, '2020-02-23')
# 3480. ('Walker', 223, 1, '2018-05-26')
# 3481. ('Walker', 30, 1, '2019-06-27')
# 3482. ('Walker', 70, 3, '2018-08-13')
# 3483. ('Walker', 82, 2, '2020-02-04')
# 3484. ('Walker', 138, 1, '2018-08-13')
# 3485. ('Walker', 143, 5, '2019-04-11')
# 3486. ('Walker', 165, 2, '2018-09-05')
# 3487. ('Walker', 191, 2, '2020-06-11')
# 3488. ('Walker', 200, 1, '2019-04-11')
# 3489. ('Walker', 240, 5, '2020-06-11')
# 3490. ('Walker', 282, 1, '2018-08-13')
# 3491. ('Walker', None, None, None)
# 3492. ('Walker', 16, 1, '2014-03-24')
# 3493. ('Walker', 89, 1, '2015-08-01')
# 3494. ('Walker', 90, 2, '2020-06-03')
# 3495. ('Walker', 124, 2, '2014-03-24')
# 3496. ('Walker', 185, 1, '2020-06-03')
# 3497. ('Walker', 25, 1, '2013-09-06')
# 3498. ('Walker', 118, 1, '2016-01-30')
# 3499. ('Walker', 127, 5, '2015-03-05')
# 3500. ('Walker', 146, 1, '2013-09-06')
# 3501. ('Walker', 150, 1, '2016-11-06')
# 3502. ('Walker', 170, 5, '2016-11-06')
# 3503. ('Walker', 211, 2, '2016-11-06')
# 3504. ('Walker', 225, 2, '2015-03-05')
# 3505. ('Walker', 273, 1, '2013-09-06')
# 3506. ('Walker', 289, 2, '2015-03-05')
# 3507. ('Wall', 2, 6, '2018-09-17')
# 3508. ('Wall', 108, 1, '2015-06-11')
# 3509. ('Wall', 119, 1, '2015-06-11')
# 3510. ('Wall', 153, 2, '2015-06-11')
# 3511. ('Wall', 167, 3, '2019-06-19')
# 3512. ('Wall', 191, 2, '2018-09-17')
# 3513. ('Wall', 192, 1, '2015-01-13')
# 3514. ('Wall', 229, 1, '2019-06-19')
# 3515. ('Wall', 268, 1, '2015-01-13')
# 3516. ('Wall', 268, 2, '2019-06-19')
# 3517. ('Wall', 275, 2, '2015-01-13')
# 3518. ('Wall', 290, 3, '2018-09-17')
# 3519. ('Wallace', 158, 2, '2016-06-25')
# 3520. ('Wallace', 159, 1, '2017-09-30')
# 3521. ('Wallace', 201, 1, '2016-06-25')
# 3522. ('Walsh', 60, 3, '2015-01-05')
# 3523. ('Walsh', 268, 2, '2019-03-25')
# 3524. ('Walsh', 289, 1, '2019-02-19')
# 3525. ('Wang', 46, 1, '2014-05-19')
# 3526. ('Wang', 94, 1, '2014-05-19')
# 3527. ('Wang', 107, 1, '2018-03-31')
# 3528. ('Ward', 68, 1, '2017-11-11')
# 3529. ('Ward', 143, 2, '2017-11-02')
# 3530. ('Ward', 175, 1, '2017-11-11')
# 3531. ('Ward', 195, 1, '2017-11-02')
# 3532. ('Ward', 202, 3, '2018-09-05')
# 3533. ('Ward', 230, 3, '2018-09-05')
# 3534. ('Ward', 246, 1, '2017-11-18')
# 3535. ('Ward', 248, 1, '2018-09-05')
# 3536. ('Ward', 252, 1, '2017-11-11')
# 3537. ('Ward', 270, 1, '2017-11-18')
# 3538. ('Ward', 35, 1, '2020-05-21')
# 3539. ('Ward', 106, 3, '2020-05-21')
# 3540. ('Ward', 111, 1, '2018-09-05')
# 3541. ('Ward', 216, 3, '2018-09-05')
# 3542. ('Ward', 220, 1, '2018-09-05')
# 3543. ('Ward', 258, 1, '2020-05-21')
# 3544. ('Ward', 30, 2, '2020-06-20')
# 3545. ('Ward', 70, 1, '2020-06-20')
# 3546. ('Ward', 87, 3, '2019-01-11')
# 3547. ('Ward', 124, 1, '2020-06-20')
# 3548. ('Ware', None, None, None)
# 3549. ('Warren', 81, 1, '2018-05-02')
# 3550. ('Warren', 123, 1, '2017-07-26')
# 3551. ('Warren', 176, 1, '2018-07-14')
# 3552. ('Warren', 225, 4, '2015-11-16')
# 3553. ('Warren', 242, 1, '2015-11-16')
# 3554. ('Warren', 252, 3, '2015-11-16')
# 3555. ('Warren', 267, 2, '2018-05-02')
# 3556. ('Warren', 289, 1, '2017-07-26')
# 3557. ('Washington', 30, 1, '2019-06-07')
# 3558. ('Washington', 43, 1, '2019-06-04')
# 3559. ('Washington', 70, 4, '2019-05-22')
# 3560. ('Washington', 105, 2, '2019-06-04')
# 3561. ('Washington', 156, 1, '2019-06-06')
# 3562. ('Washington', 214, 1, '2019-05-22')
# 3563. ('Washington', 226, 1, '2019-06-07')
# 3564. ('Washington', 248, 1, '2019-05-22')
# 3565. ('Washington', 294, 1, '2019-05-22')
# 3566. ('Waters', None, None, None)
# 3567. ('Waters', 6, 1, '2020-07-03')
# 3568. ('Waters', 14, 3, '2020-07-10')
# 3569. ('Waters', 58, 3, '2020-07-03')
# 3570. ('Waters', 73, 2, '2020-04-22')
# 3571. ('Waters', 178, 2, '2020-04-22')
# 3572. ('Waters', 188, 1, '2020-07-10')
# 3573. ('Waters', 205, 1, '2020-07-03')
# 3574. ('Waters', 212, 1, '2020-07-10')
# 3575. ('Watson', 105, 1, '2019-12-20')
# 3576. ('Watson', 23, 1, '2020-02-23')
# 3577. ('Watson', 53, 1, '2020-02-23')
# 3578. ('Watson', 111, 5, '2020-02-23')
# 3579. ('Watson', 138, 2, '2020-02-23')
# 3580. ('Watson', 158, 1, '2019-10-10')
# 3581. ('Weber', 289, 2, '2017-07-01')
# 3582. ('Weber', 291, 2, '2017-07-01')
# 3583. ('Webster', 103, 2, '2019-03-30')
# 3584. ('Weiss', 52, 2, '2020-02-23')
# 3585. ('Weiss', 130, 1, '2020-02-19')
# 3586. ('Weiss', 217, 8, '2020-02-19')
# 3587. ('Welch', 247, 1, '2011-11-16')
# 3588. ('Wells', 216, 1, '2020-03-01')
# 3589. ('Werner', 29, 1, '2019-07-07')
# 3590. ('Werner', 114, 3, '2019-02-27')
# 3591. ('Werner', 139, 1, '2020-04-05')
# 3592. ('Werner', 173, 3, '2020-04-05')
# 3593. ('Werner', 51, 1, '2019-04-09')
# 3594. ('Werner', 171, 2, '2020-03-15')
# 3595. ('Werner', 206, 2, '2020-03-15')
# 3596. ('Werner', 249, 2, '2020-03-15')
# 3597. ('Werner', 256, 4, '2020-03-15')
# 3598. ('West', 60, 1, '2020-01-21')
# 3599. ('West', 129, 1, '2020-01-21')
# 3600. ('West', 145, 1, '2020-01-21')
# 3601. ('White', None, None, None)
# 3602. ('White', 41, 1, '2011-12-30')
# 3603. ('White', 51, 3, '2016-01-01')
# 3604. ('White', 55, 3, '2012-04-09')
# 3605. ('White', 109, 3, '2012-04-09')
# 3606. ('White', 159, 2, '2016-12-22')
# 3607. ('White', 197, 1, '2019-09-22')
# 3608. ('White', 277, 3, '2016-12-22')
# 3609. ('White', 46, 1, '2012-08-08')
# 3610. ('White', 221, 3, '2015-11-04')
# 3611. ('White', 139, 1, '2019-07-18')
# 3612. ('White', 281, 2, '2019-07-18')
# 3613. ('Whitney', 121, 6, '2016-03-08')
# 3614. ('Whitney', 244, 1, '2016-03-08')
# 3615. ('Whitney', 284, 1, '2018-06-11')
# 3616. ('Wilcox', 10, 1, '2019-11-22')
# 3617. ('Wilcox', 98, 1, '2017-09-08')
# 3618. ('Wilcox', 273, 2, '2019-11-22')
# 3619. ('Wiley', 33, 1, '2016-04-10')
# 3620. ('Wiley', 76, 2, '2018-02-28')
# 3621. ('Wiley', 190, 3, '2018-02-28')
# 3622. ('Wilkins', 18, 1, '2016-01-17')
# 3623. ('Wilkins', 264, 1, '2017-11-09')
# 3624. ('Wilkins', 285, 1, '2017-11-09')
# 3625. ('Wilkins', 15, 1, '2015-04-24')
# 3626. ('Wilkins', 18, 1, '2015-04-24')
# 3627. ('Wilkins', 92, 2, '2016-09-14')
# 3628. ('Wilkins', 113, 1, '2016-09-14')
# 3629. ('Wilkins', 290, 1, '2015-04-24')
# 3630. ('Williams', 45, 1, '2019-12-04')
# 3631. ('Williams', 51, 1, '2020-05-11')
# 3632. ('Williams', 97, 2, '2020-04-15')
# 3633. ('Williams', 202, 2, '2020-04-15')
# 3634. ('Williams', 225, 1, '2020-04-15')
# 3635. ('Williams', 253, 5, '2020-05-11')
# 3636. ('Williams', 15, 1, '2020-07-01')
# 3637. ('Williams', 32, 1, '2020-07-24')
# 3638. ('Williams', 69, 4, '2020-07-01')
# 3639. ('Williams', 79, 2, '2020-07-01')
# 3640. ('Williams', 153, 1, '2019-03-01')
# 3641. ('Williams', 119, 3, '2011-08-18')
# 3642. ('Williams', 171, 2, '2014-05-16')
# 3643. ('Williams', 271, 1, '2014-05-16')
# 3644. ('Williams', 47, 2, '2019-04-27')
# 3645. ('Williams', 72, 3, '2019-04-27')
# 3646. ('Williams', 75, 3, '2019-04-27')
# 3647. ('Williams', 87, 1, '2020-04-10')
# 3648. ('Williams', 110, 1, '2019-06-26')
# 3649. ('Williams', 178, 2, '2019-04-27')
# 3650. ('Williams', 294, 1, '2019-06-26')
# 3651. ('Williams', 64, 1, '2015-09-13')
# 3652. ('Williams', 221, 4, '2015-09-13')
# 3653. ('Williams', None, None, None)
# 3654. ('Williams', 49, 1, '2019-06-16')
# 3655. ('Williams', 55, 1, '2014-12-05')
# 3656. ('Williams', 129, 2, '2013-08-24')
# 3657. ('Williams', 62, 5, '2020-07-26')
# 3658. ('Williams', 276, 1, '2020-07-26')
# 3659. ('Williams', None, None, None)
# 3660. ('Williams', 12, 2, '2018-09-11')
# 3661. ('Williams', 30, 1, '2019-08-14')
# 3662. ('Williams', 158, 3, '2017-04-02')
# 3663. ('Williams', 260, 1, '2017-04-02')
# 3664. ('Williams', 271, 3, '2017-04-02')
# 3665. ('Williamson', 120, 1, '2019-09-19')
# 3666. ('Williamson', 150, 1, '2019-09-19')
# 3667. ('Williamson', 170, 2, '2016-08-07')
# 3668. ('Wilson', 36, 1, '2015-05-18')
# 3669. ('Wilson', 108, 1, '2015-02-24')
# 3670. ('Wilson', 180, 1, '2014-07-13')
# 3671. ('Wilson', 233, 2, '2015-02-24')
# 3672. ('Wilson', 242, 2, '2016-02-10')
# 3673. ('Wilson', 244, 2, '2014-03-16')
# 3674. ('Wilson', 42, 1, '2020-01-20')
# 3675. ('Wilson', 50, 1, '2020-01-20')
# 3676. ('Wilson', 214, 1, '2020-01-20')
# 3677. ('Wilson', 292, 1, '2020-01-20')
# 3678. ('Wilson', 72, 1, '2015-01-05')
# 3679. ('Wilson', 114, 2, '2014-09-21')
# 3680. ('Wilson', 155, 2, '2015-01-05')
# 3681. ('Wilson', 289, 2, '2015-01-05')
# 3682. ('Wilson', 1, 1, '2013-11-06')
# 3683. ('Wilson', 6, 3, '2018-01-11')
# 3684. ('Wilson', 34, 3, '2015-10-29')
# 3685. ('Wilson', 76, 1, '2013-04-03')
# 3686. ('Wilson', 147, 1, '2015-10-29')
# 3687. ('Wilson', 162, 2, '2013-11-06')
# 3688. ('Wilson', 209, 2, '2015-10-29')
# 3689. ('Wilson', None, None, None)
# 3690. ('Wilson', 3, 2, '2018-01-30')
# 3691. ('Wilson', 14, 2, '2019-08-02')
# 3692. ('Wilson', 52, 1, '2019-08-02')
# 3693. ('Wilson', 92, 3, '2017-09-30')
# 3694. ('Wilson', 102, 1, '2017-06-10')
# 3695. ('Wilson', 104, 1, '2019-08-02')
# 3696. ('Wilson', 104, 2, '2018-01-30')
# 3697. ('Wilson', 110, 1, '2018-03-04')
# 3698. ('Wilson', 113, 1, '2018-03-04')
# 3699. ('Wilson', 114, 2, '2019-08-05')
# 3700. ('Wilson', 148, 1, '2017-09-30')
# 3701. ('Wilson', 151, 1, '2017-06-10')
# 3702. ('Wilson', 195, 1, '2019-08-02')
# 3703. ('Wilson', 202, 3, '2018-03-04')
# 3704. ('Wilson', 216, 2, '2018-03-04')
# 3705. ('Wilson', 222, 1, '2018-01-30')
# 3706. ('Wilson', 68, 2, '2013-05-02')
# 3707. ('Wilson', 97, 2, '2017-05-23')
# 3708. ('Wilson', 187, 2, '2015-08-05')
# 3709. ('Wilson', 202, 1, '2015-08-05')
# 3710. ('Wilson', 244, 2, '2013-05-02')
# 3711. ('Wilson', 86, 1, '2019-09-08')
# 3712. ('Wilson', 91, 1, '2016-08-24')
# 3713. ('Wilson', 165, 1, '2015-10-16')
# 3714. ('Wilson', 4, 1, '2020-06-04')
# 3715. ('Wilson', 12, 2, '2012-11-05')
# 3716. ('Wilson', 30, 1, '2015-03-22')
# 3717. ('Wilson', 107, 3, '2012-11-09')
# 3718. ('Wilson', 118, 1, '2012-11-09')
# 3719. ('Wilson', 155, 2, '2015-03-22')
# 3720. ('Wilson', 211, 1, '2012-11-09')
# 3721. ('Wilson', 225, 1, '2020-06-04')
# 3722. ('Wilson', 241, 1, '2012-11-05')
# 3723. ('Wise', 16, 1, '2013-04-15')
# 3724. ('Wise', 95, 1, '2018-06-23')
# 3725. ('Wise', 185, 3, '2018-06-23')
# 3726. ('Wolf', 58, 1, '2019-12-03')
# 3727. ('Wolf', 132, 1, '2020-03-08')
# 3728. ('Wolf', 158, 2, '2018-04-13')
# 3729. ('Wolf', 205, 3, '2011-04-08')
# 3730. ('Wolf', 210, 1, '2020-03-08')
# 3731. ('Wong', 35, 4, '2020-01-17')
# 3732. ('Wong', 42, 1, '2020-01-17')
# 3733. ('Wong', 131, 1, '2018-11-23')
# 3734. ('Wong', 175, 2, '2020-01-17')
# 3735. ('Wong', 211, 2, '2020-01-17')
# 3736. ('Wong', 235, 1, '2020-01-17')
# 3737. ('Wong', 261, 1, '2018-11-23')
# 3738. ('Wood', 34, 1, '2019-11-02')
# 3739. ('Wood', 212, 1, '2020-03-28')
# 3740. ('Wood', 236, 5, '2019-11-02')
# 3741. ('Wood', 287, 1, '2019-11-02')
# 3742. ('Woodard', 98, 1, '2019-04-13')
# 3743. ('Woodard', 116, 1, '2019-04-13')
# 3744. ('Woodard', 199, 1, '2019-08-26')
# 3745. ('Woodard', 230, 3, '2019-04-13')
# 3746. ('Woodard', 250, 3, '2019-08-26')
# 3747. ('Woodard', 277, 2, '2019-08-26')
# 3748. ('Woods', 101, 2, '2019-04-25')
# 3749. ('Woods', 143, 2, '2019-04-25')
# 3750. ('Wright', 5, 3, '2020-06-07')
# 3751. ('Wright', 162, 1, '2020-05-24')
# 3752. ('Wright', 183, 1, '2020-05-20')
# 3753. ('Wright', 259, 1, '2020-05-24')
# 3754. ('Wright', 290, 2, '2020-05-20')
# 3755. ('Wright', 51, 1, '2019-07-20')
# 3756. ('Wright', 62, 2, '2019-07-20')
# 3757. ('Wright', 161, 1, '2019-07-20')
# 3758. ('Wright', 184, 1, '2019-06-25')
# 3759. ('Wright', 204, 2, '2019-06-25')
# 3760. ('Wright', 208, 1, '2019-07-20')
# 3761. ('Wright', 286, 2, '2020-07-03')
# 3762. ('Wright', 126, 3, '2019-10-28')
# 3763. ('Wright', 140, 2, '2019-10-28')
# 3764. ('Wright', None, None, None)
# 3765. ('Wright', None, None, None)
# 3766. ('Wright', 5, 2, '2019-08-25')
# 3767. ('Wright', 42, 1, '2019-08-25')
# 3768. ('Wright', 82, 1, '2019-08-25')
# 3769. ('Wright', 175, 1, '2014-11-13')
# 3770. ('Wright', 242, 1, '2015-02-11')
# 3771. ('Wright', 251, 1, '2019-08-25')
# 3772. ('Wright', 184, 1, '2020-03-01')
# 3773. ('Wright', 245, 1, '2020-03-01')
# 3774. ('Wright', 272, 1, '2018-07-30')
# 3775. ('Yang', 113, 3, '2019-05-16')
# 3776. ('Yang', 139, 1, '2019-05-16')
# 3777. ('Yang', 50, 4, '2020-04-27')
# 3778. ('Yang', 99, 2, '2020-07-11')
# 3779. ('Yang', 125, 2, '2018-06-07')
# 3780. ('Yang', 183, 5, '2017-06-01')
# 3781. ('York', 107, 1, '2020-07-24')
# 3782. ('York', 223, 2, '2020-07-24')
# 3783. ('York', 265, 3, '2020-07-24')
# 3784. ('Young', 138, 1, '2020-03-23')
# 3785. ('Young', 176, 1, '2020-03-23')
# 3786. ('Young', 194, 2, '2020-03-23')
# 3787. ('Young', 100, 1, '2016-05-30')
# 3788. ('Young', 125, 2, '2016-05-30')
# 3789. ('Young', 148, 1, '2017-09-01')
# 3790. ('Young', 159, 1, '2012-05-17')
# 3791. ('Young', 203, 2, '2017-09-01')
# 3792. ('Young', 274, 1, '2017-09-01')
# 3793. ('Young', 275, 2, '2012-05-17')
# 3794. ('Young', 25, 1, '2018-02-15')
# 3795. ('Young', 37, 1, '2014-06-14')
# 3796. ('Young', 72, 2, '2018-02-15')
# 3797. ('Young', 155, 1, '2016-10-02')
# 3798. ('Young', 183, 1, '2012-09-01')
# 3799. ('Young', 264, 3, '2013-06-14')
# 3800. ('Young', 11, 1, '2016-12-15')
# 3801. ('Young', 62, 1, '2016-04-29')
# 3802. ('Young', 94, 2, '2017-05-30')
# 3803. ('Young', 132, 1, '2016-12-15')
# 3804. ('Young', 149, 1, '2017-09-24')
# 3805. ('Young', 156, 1, '2016-12-15')
# 3806. ('Young', 263, 5, '2017-09-24')
# 3807. ('Young', 289, 1, '2017-09-24')
# 3808. ('Young', 196, 1, '2019-09-05')
# 3809. ('Young', 203, 4, '2019-09-25')
# 3810. ('Zavala', 38, 1, '2019-04-28')
# 3811. ('Zavala', 49, 4, '2018-07-23')
# 3812. ('Zavala', 75, 3, '2020-06-10')
# 3813. ('Zavala', 107, 1, '2019-04-28')
# 3814. ('Zavala', 123, 1, '2018-04-29')
# 3815. ('Zavala', 137, 1, '2019-04-28')
# 3816. ('Zavala', 157, 1, '2019-03-19')
# 3817. ('Zavala', 174, 2, '2018-07-23')
# 3818. ('Zavala', 225, 1, '2019-04-28')
# 3819. ('Zavala', 237, 1, '2020-06-10')
# 3820. ('Zavala', 247, 1, '2020-06-10')
# 3821. ('Zavala', 250, 1, '2019-03-19')
# 3822. ('Zavala', 257, 2, '2018-04-29')
# 3823. ('Zhang', 42, 2, '2017-10-25')
# 3824. ('Zhang', 124, 1, '2014-11-06')
# 3825. ('Zhang', 155, 1, '2018-08-09')
# 3826. ('Zhang', 173, 2, '2018-08-09')
# 3827. ('Zhang', 213, 1, '2016-11-06')
# 3828. ('Zhang', 218, 5, '2018-08-09')
# 3829. ('Zhang', 227, 1, '2014-11-06')
# 3830. ('Zhang', 251, 4, '2014-11-06')
# 3831. ('Zhang', 288, 1, '2016-11-06')

# %% [markdown]
# **Note:** The top two cells are both showing the purchase history of customers. But one is using `INNER JOIN` and the other is using `LEFT JOIN`. So what's the difference? If you pay close attention you will see that the two tables don't have the same number of rows. The main difference between the two is that `LEFT JOIN` conserves all the entries on the left (customers) and if it can't find any purchases for that customer it will return `NULL`. However, `INNER JOIN` tries to find a match. If a customer doesn't have any purchases in the list it will not be shown in the final result.<br>
# `INNER JOIN` and `LEFT JOIN` are the most common types of join. However, there are other types such as `CROSS JOIN`, `FULL OUTER JOIN`, `RIGHT JOIN`, etc. You can find more information about these types of join on https://www.sqlitetutorial.net/.

# %% [markdown]
# One trick that makes writing a query faster is using aliases to tables and column. The query below is the same as the one above. The only difference is use of aliases.

# %%
query = '''
SELECT Surname, ProductID, Quantity, PurchaseDate
FROM Customers as c
LEFT JOIN Sales as s ON
    c.CustomerID = s.CustomerID
ORDER BY Surname;
'''

execute_query(conn,query)
# Out:
# 1. ('Acosta', 65, 1, '2019-02-17')
# 2. ('Acosta', 138, 1, '2019-02-17')
# 3. ('Acosta', 196, 1, '2017-04-08')
# 4. ('Adams', 43, 1, '2013-02-03')
# 5. ('Adams', 48, 2, '2019-11-10')
# 6. ('Adams', 77, 1, '2013-11-10')
# 7. ('Adams', 88, 1, '2013-11-10')
# 8. ('Adams', 149, 2, '2013-02-03')
# 9. ('Adams', 199, 1, '2013-11-10')
# 10. ('Adams', 223, 3, '2019-11-10')
# 11. ('Adams', 58, 2, '2020-07-01')
# 12. ('Adams', 65, 3, '2020-07-29')
# 13. ('Adams', 200, 2, '2020-06-01')
# 14. ('Adams', 276, 1, '2020-06-14')
# 15. ('Adams', 156, 1, '2019-04-30')
# 16. ('Adams', 181, 1, '2019-04-30')
# 17. ('Adams', 233, 1, '2018-03-18')
# 18. ('Adams', 13, 1, '2018-11-01')
# 19. ('Adams', 15, 1, '2018-11-01')
# 20. ('Adams', 59, 2, '2017-06-11')
# 21. ('Adams', 69, 1, '2017-06-11')
# 22. ('Adams', 211, 2, '2019-11-17')
# 23. ('Adams', 247, 1, '2017-06-11')
# 24. ('Adkins', None, None, None)
# 25. ('Aguirre', 170, 2, '2020-06-26')
# 26. ('Aguirre', 286, 1, '2017-04-27')
# 27. ('Alexander', None, None, None)
# 28. ('Alexander', 83, 1, '2015-01-15')
# 29. ('Alexander', 83, 1, '2016-08-12')
# 30. ('Alexander', 266, 1, '2015-11-09')
# 31. ('Alexander', 266, 2, '2015-11-09')
# 32. ('Ali', 54, 1, '2018-06-17')
# 33. ('Ali', 164, 1, '2018-08-02')
# 34. ('Ali', 184, 1, '2018-02-13')
# 35. ('Ali', 291, 1, '2018-08-02')
# 36. ('Allen', 249, 4, '2019-09-08')
# 37. ('Allen', 29, 1, '2016-06-25')
# 38. ('Allen', 121, 1, '2016-06-25')
# 39. ('Allen', 125, 4, '2017-04-17')
# 40. ('Allen', 164, 1, '2016-12-12')
# 41. ('Allen', 294, 1, '2016-06-25')
# 42. ('Allen', 275, 3, '2019-12-10')
# 43. ('Alvarez', 86, 1, '2014-01-15')
# 44. ('Alvarez', 107, 2, '2014-01-15')
# 45. ('Alvarez', 227, 1, '2013-08-22')
# 46. ('Alvarez', 258, 1, '2014-01-15')
# 47. ('Alvarez', 262, 5, '2014-12-07')
# 48. ('Alvarez', 292, 3, '2013-08-22')
# 49. ('Alvarez', 293, 4, '2014-01-15')
# 50. ('Andersen', 20, 1, '2017-08-09')
# 51. ('Andersen', 22, 2, '2016-10-01')
# 52. ('Andersen', 29, 2, '2019-06-19')
# 53. ('Andersen', 90, 1, '2019-06-19')
# 54. ('Andersen', 168, 1, '2017-08-09')
# 55. ('Andersen', 181, 3, '2016-10-01')
# 56. ('Andersen', 271, 3, '2017-08-09')
# 57. ('Anderson', 24, 1, '2019-11-02')
# 58. ('Anderson', 65, 4, '2019-11-02')
# 59. ('Anderson', 152, 1, '2019-09-30')
# 60. ('Anderson', 60, 4, '2015-05-31')
# 61. ('Anderson', 272, 1, '2015-05-31')
# 62. ('Anderson', 104, 3, '2018-03-26')
# 63. ('Anderson', 137, 1, '2014-02-18')
# 64. ('Anderson', 16, 3, '2016-04-07')
# 65. ('Anderson', 116, 1, '2016-04-07')
# 66. ('Anderson', 161, 2, '2016-04-07')
# 67. ('Anderson', 216, 2, '2016-04-23')
# 68. ('Anderson', 222, 1, '2016-04-07')
# 69. ('Anderson', 229, 1, '2017-10-15')
# 70. ('Anderson', 263, 3, '2017-10-15')
# 71. ('Anderson', 267, 2, '2016-05-18')
# 72. ('Anderson', 293, 1, '2016-04-23')
# 73. ('Anderson', None, None, None)
# 74. ('Andrade', 252, 3, '2019-09-14')
# 75. ('Andrews', 37, 1, '2014-12-01')
# 76. ('Andrews', 237, 2, '2017-07-23')
# 77. ('Andrews', None, None, None)
# 78. ('Andrews', 16, 1, '2019-11-05')
# 79. ('Andrews', 16, 2, '2019-11-05')
# 80. ('Andrews', 18, 1, '2019-11-05')
# 81. ('Andrews', 143, 1, '2019-05-05')
# 82. ('Andrews', 157, 4, '2020-02-28')
# 83. ('Andrews', 18, 2, '2017-03-31')
# 84. ('Andrews', 35, 3, '2018-09-06')
# 85. ('Andrews', 158, 1, '2018-10-17')
# 86. ('Andrews', 186, 4, '2018-09-06')
# 87. ('Andrews', 195, 1, '2017-03-31')
# 88. ('Andrews', 239, 1, '2018-09-06')
# 89. ('Andrews', 267, 1, '2018-10-17')
# 90. ('Andrews', 34, 1, '2020-06-13')
# 91. ('Anthony', 44, 1, '2015-05-30')
# 92. ('Anthony', 83, 1, '2015-05-30')
# 93. ('Anthony', 138, 2, '2019-08-11')
# 94. ('Anthony', 211, 1, '2015-05-30')
# 95. ('Anthony', 216, 1, '2017-01-25')
# 96. ('Anthony', 4, 3, '2019-09-03')
# 97. ('Anthony', 63, 4, '2019-11-12')
# 98. ('Anthony', 222, 2, '2019-09-03')
# 99. ('Arellano', 45, 3, '2016-09-30')
# 100. ('Arellano', 63, 1, '2020-02-22')
# 101. ('Arellano', 82, 1, '2016-09-30')
# 102. ('Arellano', 89, 2, '2020-02-22')
# 103. ('Arellano', 174, 1, '2020-02-22')
# 104. ('Arellano', 253, 3, '2019-11-25')
# 105. ('Arnold', 5, 1, '2020-03-28')
# 106. ('Arnold', 8, 5, '2020-03-28')
# 107. ('Arnold', 66, 1, '2020-03-28')
# 108. ('Arnold', 66, 8, '2019-08-31')
# 109. ('Arnold', 127, 1, '2019-08-31')
# 110. ('Arnold', 145, 1, '2019-06-29')
# 111. ('Arnold', 159, 1, '2019-06-29')
# 112. ('Arnold', 290, 1, '2020-03-28')
# 113. ('Arnold', 46, 2, '2016-01-01')
# 114. ('Arnold', 50, 1, '2019-01-24')
# 115. ('Arnold', 233, 2, '2016-01-01')
# 116. ('Atkinson', 62, 1, '2020-01-23')
# 117. ('Atkinson', 272, 3, '2020-01-23')
# 118. ('Bailey', 38, 2, '2017-07-04')
# 119. ('Bailey', 41, 1, '2018-06-05')
# 120. ('Bailey', 48, 1, '2017-07-04')
# 121. ('Bailey', 86, 1, '2020-06-20')
# 122. ('Bailey', 189, 2, '2018-06-05')
# 123. ('Bailey', 249, 2, '2019-10-30')
# 124. ('Bailey', 251, 1, '2017-07-04')
# 125. ('Bailey', 50, 1, '2020-04-20')
# 126. ('Bailey', 241, 1, '2020-04-20')
# 127. ('Bailey', 99, 5, '2019-01-27')
# 128. ('Bailey', 108, 3, '2019-03-20')
# 129. ('Bailey', 155, 1, '2019-03-20')
# 130. ('Bailey', 197, 1, '2020-06-10')
# 131. ('Bailey', 208, 3, '2019-01-27')
# 132. ('Bailey', 282, 2, '2020-06-10')
# 133. ('Bailey', 81, 3, '2020-05-21')
# 134. ('Bailey', 158, 3, '2020-01-09')
# 135. ('Bailey', 218, 1, '2020-05-21')
# 136. ('Baker', 120, 1, '2016-09-26')
# 137. ('Baker', 168, 1, '2012-07-31')
# 138. ('Baldwin', 47, 1, '2020-07-18')
# 139. ('Baldwin', 212, 7, '2020-07-18')
# 140. ('Baldwin', 220, 1, '2020-07-18')
# 141. ('Ball', 153, 1, '2020-01-02')
# 142. ('Ball', 219, 1, '2020-01-02')
# 143. ('Ball', 237, 1, '2020-01-02')
# 144. ('Ball', 284, 1, '2017-10-24')
# 145. ('Barajas', 17, 2, '2020-04-23')
# 146. ('Barajas', 224, 1, '2020-02-10')
# 147. ('Barnes', 111, 4, '2016-05-07')
# 148. ('Barnes', 205, 1, '2012-07-05')
# 149. ('Barnett', 24, 1, '2018-12-07')
# 150. ('Barnett', 56, 2, '2016-06-05')
# 151. ('Barnett', 138, 2, '2016-06-05')
# 152. ('Barnett', 157, 1, '2017-01-02')
# 153. ('Barnett', 170, 3, '2017-01-02')
# 154. ('Barnett', 255, 3, '2017-01-02')
# 155. ('Barnett', 95, 1, '2019-11-11')
# 156. ('Barnett', 1, 1, '2018-07-14')
# 157. ('Barnett', 65, 1, '2018-07-14')
# 158. ('Barr', 119, 1, '2018-03-23')
# 159. ('Barr', 155, 1, '2019-02-08')
# 160. ('Barr', 167, 1, '2019-02-08')
# 161. ('Barr', 201, 3, '2018-03-23')
# 162. ('Barrera', 88, 2, '2017-09-25')
# 163. ('Barrera', 131, 2, '2017-09-25')
# 164. ('Barrera', 144, 2, '2018-01-29')
# 165. ('Barrera', 196, 3, '2017-09-25')
# 166. ('Barrera', 244, 1, '2017-09-25')
# 167. ('Barrera', 261, 2, '2018-01-29')
# 168. ('Barrera', 284, 1, '2018-11-22')
# 169. ('Barrera', 288, 1, '2017-09-25')
# 170. ('Barrera', 77, 3, '2015-07-12')
# 171. ('Barrera', 139, 1, '2015-07-12')
# 172. ('Barrera', 140, 1, '2019-11-11')
# 173. ('Barrera', 190, 1, '2015-07-12')
# 174. ('Barrera', 212, 1, '2015-02-16')
# 175. ('Barrera', 264, 3, '2019-11-11')
# 176. ('Barrera', None, None, None)
# 177. ('Barrett', 42, 6, '2019-02-16')
# 178. ('Barrett', 62, 2, '2018-10-01')
# 179. ('Barrett', 63, 1, '2019-08-08')
# 180. ('Barrett', 88, 2, '2019-02-16')
# 181. ('Barrett', 127, 3, '2019-08-08')
# 182. ('Barrett', 130, 1, '2019-08-08')
# 183. ('Barrett', 192, 2, '2018-10-01')
# 184. ('Barrett', 235, 4, '2019-02-16')
# 185. ('Barrett', 256, 3, '2018-10-01')
# 186. ('Barrett', 267, 4, '2019-02-16')
# 187. ('Barrett', 13, 2, '2013-02-09')
# 188. ('Barry', 39, 2, '2020-04-18')
# 189. ('Barry', 100, 2, '2013-03-17')
# 190. ('Barry', 108, 1, '2020-04-18')
# 191. ('Barry', 114, 1, '2013-03-17')
# 192. ('Barry', 184, 2, '2015-12-17')
# 193. ('Barton', None, None, None)
# 194. ('Bauer', 28, 1, '2020-07-04')
# 195. ('Bauer', 71, 1, '2020-07-14')
# 196. ('Bauer', 144, 3, '2020-07-04')
# 197. ('Bauer', 249, 4, '2020-07-14')
# 198. ('Bauer', 284, 1, '2020-07-04')
# 199. ('Bauer', 97, 1, '2019-02-20')
# 200. ('Bauer', 105, 2, '2019-02-20')
# 201. ('Bauer', 192, 1, '2018-10-22')
# 202. ('Bauer', 242, 1, '2018-05-18')
# 203. ('Bauer', 278, 3, '2019-02-20')
# 204. ('Beck', 80, 2, '2020-02-07')
# 205. ('Beck', 200, 1, '2019-08-31')
# 206. ('Beck', 266, 2, '2020-01-08')
# 207. ('Beck', None, None, None)
# 208. ('Bell', 5, 2, '2015-12-27')
# 209. ('Bell', 7, 1, '2015-12-27')
# 210. ('Bell', 16, 1, '2019-04-05')
# 211. ('Bell', 26, 1, '2014-05-13')
# 212. ('Bell', 102, 1, '2020-03-31')
# 213. ('Bell', 170, 4, '2020-03-31')
# 214. ('Bell', 198, 1, '2014-05-13')
# 215. ('Bell', 266, 1, '2014-05-13')
# 216. ('Bell', 160, 1, '2020-04-27')
# 217. ('Bell', 282, 1, '2020-04-27')
# 218. ('Bell', 77, 4, '2018-03-01')
# 219. ('Bell', 79, 10, '2018-03-01')
# 220. ('Bell', 265, 2, '2020-03-01')
# 221. ('Bell', 14, 3, '2020-05-06')
# 222. ('Bell', 41, 1, '2020-05-06')
# 223. ('Bell', 58, 1, '2020-05-06')
# 224. ('Bell', 97, 2, '2020-05-09')
# 225. ('Bell', 122, 1, '2020-05-09')
# 226. ('Bell', 123, 1, '2020-05-09')
# 227. ('Bell', 290, 1, '2020-06-12')
# 228. ('Bell', None, None, None)
# 229. ('Beltran', None, None, None)
# 230. ('Benjamin', 10, 1, '2017-09-12')
# 231. ('Benjamin', 54, 4, '2015-07-13')
# 232. ('Benjamin', 203, 1, '2017-09-12')
# 233. ('Benjamin', 246, 1, '2015-07-13')
# 234. ('Benjamin', 272, 1, '2018-12-05')
# 235. ('Benjamin', 280, 1, '2015-07-13')
# 236. ('Bennett', 26, 1, '2018-04-25')
# 237. ('Bennett', 138, 2, '2017-07-27')
# 238. ('Bennett', 139, 1, '2020-01-31')
# 239. ('Bennett', 219, 3, '2019-05-20')
# 240. ('Bennett', 237, 4, '2020-01-31')
# 241. ('Bennett', 247, 2, '2019-05-20')
# 242. ('Bennett', 255, 1, '2019-06-09')
# 243. ('Bennett', 31, 1, '2018-05-04')
# 244. ('Bennett', 177, 2, '2017-08-16')
# 245. ('Bennett', 238, 8, '2019-10-15')
# 246. ('Bennett', 76, 4, '2018-01-30')
# 247. ('Bennett', 122, 1, '2018-01-30')
# 248. ('Bennett', 173, 1, '2017-07-31')
# 249. ('Bennett', 260, 3, '2017-07-09')
# 250. ('Bennett', 62, 1, '2017-03-14')
# 251. ('Bennett', 73, 1, '2019-08-06')
# 252. ('Benson', 19, 2, '2019-12-31')
# 253. ('Benson', 35, 1, '2017-03-28')
# 254. ('Benson', 171, 2, '2014-05-13')
# 255. ('Benson', 188, 1, '2017-03-28')
# 256. ('Benson', 254, 1, '2019-12-31')
# 257. ('Benson', 132, 1, '2019-03-30')
# 258. ('Bentley', 1, 1, '2017-08-30')
# 259. ('Bentley', 10, 1, '2017-08-30')
# 260. ('Bentley', 83, 1, '2019-04-15')
# 261. ('Bentley', 247, 1, '2018-01-05')
# 262. ('Bentley', 272, 1, '2019-04-15')
# 263. ('Benton', 218, 2, '2018-07-13')
# 264. ('Benton', 248, 1, '2019-11-14')
# 265. ('Berger', 96, 2, '2020-06-01')
# 266. ('Berger', 99, 4, '2020-06-01')
# 267. ('Best', 4, 3, '2019-02-04')
# 268. ('Best', 55, 1, '2018-05-10')
# 269. ('Best', 66, 3, '2019-02-04')
# 270. ('Best', 132, 1, '2019-02-04')
# 271. ('Best', 241, 2, '2018-05-10')
# 272. ('Bishop', 30, 1, '2018-12-20')
# 273. ('Bishop', 65, 1, '2018-12-20')
# 274. ('Bishop', 131, 1, '2018-12-20')
# 275. ('Bishop', 142, 1, '2016-07-24')
# 276. ('Bishop', 252, 1, '2016-07-24')
# 277. ('Bishop', 2, 1, '2016-01-29')
# 278. ('Bishop', 141, 1, '2016-01-29')
# 279. ('Bishop', 176, 9, '2018-06-06')
# 280. ('Bolton', 27, 2, '2016-01-19')
# 281. ('Bolton', 95, 2, '2015-08-03')
# 282. ('Bolton', 152, 2, '2016-01-19')
# 283. ('Bolton', 258, 1, '2020-04-08')
# 284. ('Bond', 15, 1, '2020-05-31')
# 285. ('Bond', 247, 1, '2020-05-08')
# 286. ('Bowman', 81, 1, '2019-02-26')
# 287. ('Bowman', 104, 3, '2013-01-09')
# 288. ('Bowman', 282, 3, '2019-02-26')
# 289. ('Boyer', 20, 1, '2019-01-22')
# 290. ('Boyer', 63, 1, '2017-01-13')
# 291. ('Boyer', 209, 4, '2017-07-31')
# 292. ('Boyer', 217, 4, '2018-05-04')
# 293. ('Boyer', 218, 2, '2017-07-31')
# 294. ('Boyer', 252, 4, '2017-01-13')
# 295. ('Boyle', 113, 1, '2018-08-29')
# 296. ('Boyle', 218, 1, '2015-07-31')
# 297. ('Boyle', 220, 1, '2015-07-31')
# 298. ('Boyle', 260, 6, '2015-07-31')
# 299. ('Boyle', 73, 2, '2019-02-04')
# 300. ('Boyle', 270, 3, '2020-07-11')
# 301. ('Bradley', 2, 1, '2018-12-29')
# 302. ('Bradley', 141, 3, '2019-08-03')
# 303. ('Bradley', 158, 3, '2019-12-14')
# 304. ('Bradley', None, None, None)
# 305. ('Bradley', 74, 1, '2014-06-14')
# 306. ('Bradley', 248, 1, '2014-06-14')
# 307. ('Bradley', 16, 1, '2017-06-17')
# 308. ('Bradley', 75, 3, '2020-06-09')
# 309. ('Bradley', 225, 1, '2017-06-17')
# 310. ('Bradley', 256, 1, '2017-06-17')
# 311. ('Bradley', 107, 1, '2018-11-16')
# 312. ('Bradley', 39, 8, '2017-02-18')
# 313. ('Bradley', 255, 1, '2017-02-18')
# 314. ('Bradley', 18, 1, '2020-05-27')
# 315. ('Brady', None, None, None)
# 316. ('Branch', 23, 2, '2018-08-29')
# 317. ('Branch', 143, 3, '2019-06-12')
# 318. ('Branch', 251, 1, '2019-05-26')
# 319. ('Brennan', None, None, None)
# 320. ('Brewer', 98, 1, '2015-04-25')
# 321. ('Brewer', 202, 3, '2017-08-05')
# 322. ('Brewer', 248, 1, '2017-08-05')
# 323. ('Brewer', None, None, None)
# 324. ('Bright', 124, 1, '2018-03-23')
# 325. ('Brooks', 35, 2, '2019-05-12')
# 326. ('Brooks', 186, 2, '2019-05-12')
# 327. ('Brooks', 218, 1, '2019-05-12')
# 328. ('Brown', 281, 2, '2014-10-07')
# 329. ('Brown', 69, 2, '2018-01-01')
# 330. ('Brown', 204, 3, '2018-01-01')
# 331. ('Brown', 280, 2, '2013-07-30')
# 332. ('Brown', 283, 2, '2015-04-12')
# 333. ('Brown', 82, 3, '2018-06-12')
# 334. ('Brown', 91, 2, '2018-01-23')
# 335. ('Brown', 117, 1, '2017-11-05')
# 336. ('Brown', 167, 1, '2018-01-23')
# 337. ('Brown', 236, 1, '2017-11-05')
# 338. ('Brown', 240, 5, '2013-04-09')
# 339. ('Brown', 253, 2, '2017-11-05')
# 340. ('Brown', None, None, None)
# 341. ('Brown', 194, 3, '2015-12-03')
# 342. ('Brown', None, None, None)
# 343. ('Brown', 116, 2, '2020-05-14')
# 344. ('Brown', 21, 1, '2016-01-22')
# 345. ('Brown', 45, 1, '2017-04-14')
# 346. ('Brown', 88, 1, '2017-04-14')
# 347. ('Brown', 155, 2, '2015-08-25')
# 348. ('Brown', 219, 1, '2016-01-22')
# 349. ('Brown', 244, 2, '2015-08-25')
# 350. ('Brown', 254, 2, '2017-04-14')
# 351. ('Brown', 13, 2, '2019-09-03')
# 352. ('Brown', 36, 1, '2014-02-04')
# 353. ('Brown', 53, 1, '2019-11-17')
# 354. ('Brown', 105, 1, '2019-05-20')
# 355. ('Brown', 153, 1, '2014-04-12')
# 356. ('Brown', 278, 2, '2019-11-17')
# 357. ('Buckley', 45, 1, '2017-02-10')
# 358. ('Buckley', 104, 3, '2019-02-21')
# 359. ('Buckley', 177, 1, '2019-02-21')
# 360. ('Bullock', 17, 1, '2015-12-13')
# 361. ('Bullock', 24, 2, '2015-12-13')
# 362. ('Bullock', 111, 3, '2016-07-07')
# 363. ('Bullock', 162, 1, '2016-07-07')
# 364. ('Burch', 87, 2, '2020-06-28')
# 365. ('Burch', 99, 3, '2020-07-01')
# 366. ('Burch', 131, 1, '2020-07-01')
# 367. ('Burch', 131, 1, '2020-07-19')
# 368. ('Burch', 197, 5, '2020-06-12')
# 369. ('Burch', 215, 1, '2020-07-01')
# 370. ('Burch', 248, 1, '2020-07-19')
# 371. ('Burns', 79, 3, '2019-07-10')
# 372. ('Burns', 125, 1, '2019-07-10')
# 373. ('Burns', 244, 1, '2019-07-10')
# 374. ('Burton', 148, 1, '2019-08-30')
# 375. ('Burton', 157, 1, '2020-07-23')
# 376. ('Burton', 160, 2, '2019-08-30')
# 377. ('Burton', 287, 1, '2020-07-23')
# 378. ('Bush', 77, 4, '2016-11-09')
# 379. ('Bush', 151, 1, '2017-12-28')
# 380. ('Bush', 253, 1, '2017-12-28')
# 381. ('Butler', 113, 1, '2019-12-12')
# 382. ('Byrd', 142, 1, '2015-03-06')
# 383. ('Byrd', 213, 3, '2015-03-06')
# 384. ('Byrd', None, None, None)
# 385. ('Byrd', 36, 2, '2011-10-17')
# 386. ('Byrd', 134, 1, '2011-10-17')
# 387. ('Byrd', 205, 2, '2011-10-17')
# 388. ('Cabrera', 197, 1, '2017-08-03')
# 389. ('Cabrera', 246, 1, '2018-05-24')
# 390. ('Cabrera', 270, 1, '2017-08-03')
# 391. ('Cain', 48, 1, '2018-06-08')
# 392. ('Cain', 54, 1, '2020-01-21')
# 393. ('Calhoun', None, None, None)
# 394. ('Callahan', 60, 1, '2020-07-11')
# 395. ('Camacho', 41, 1, '2011-11-21')
# 396. ('Camacho', 147, 1, '2011-11-21')
# 397. ('Camacho', 167, 1, '2011-11-21')
# 398. ('Cameron', 16, 4, '2020-04-20')
# 399. ('Cameron', 42, 2, '2018-06-30')
# 400. ('Cameron', 45, 1, '2018-06-30')
# 401. ('Cameron', 45, 1, '2020-04-20')
# 402. ('Cameron', 64, 2, '2018-06-30')
# 403. ('Cameron', 236, 1, '2017-11-15')
# 404. ('Cameron', 263, 1, '2020-04-20')
# 405. ('Cameron', 274, 1, '2018-06-30')
# 406. ('Cameron', 282, 1, '2018-12-25')
# 407. ('Cameron', 288, 4, '2020-04-20')
# 408. ('Campbell', 63, 1, '2017-03-18')
# 409. ('Campbell', 106, 2, '2017-03-18')
# 410. ('Campbell', 157, 2, '2020-01-03')
# 411. ('Campbell', 192, 2, '2020-01-03')
# 412. ('Campbell', 6, 1, '2015-08-16')
# 413. ('Campbell', 18, 1, '2012-06-02')
# 414. ('Campbell', 48, 1, '2015-08-16')
# 415. ('Campbell', 206, 2, '2019-01-30')
# 416. ('Campbell', 276, 2, '2015-08-16')
# 417. ('Cannon', None, None, None)
# 418. ('Cantrell', None, None, None)
# 419. ('Cardenas', 3, 2, '2020-06-25')
# 420. ('Cardenas', 189, 1, '2020-06-25')
# 421. ('Carlson', 8, 6, '2015-07-26')
# 422. ('Carlson', 10, 1, '2014-07-04')
# 423. ('Carlson', 52, 1, '2015-07-26')
# 424. ('Carlson', 66, 4, '2018-12-21')
# 425. ('Carlson', 217, 5, '2015-07-26')
# 426. ('Carlson', None, None, None)
# 427. ('Carlson', 35, 1, '2016-10-06')
# 428. ('Carlson', 50, 1, '2016-10-06')
# 429. ('Carlson', 205, 1, '2015-05-31')
# 430. ('Carlson', 277, 2, '2015-05-31')
# 431. ('Carlson', 142, 2, '2017-05-28')
# 432. ('Carlson', 156, 2, '2017-05-28')
# 433. ('Carlson', 180, 4, '2017-01-29')
# 434. ('Carlson', 182, 1, '2017-01-29')
# 435. ('Carlson', 187, 4, '2019-10-03')
# 436. ('Carpenter', 34, 1, '2019-12-24')
# 437. ('Carpenter', 267, 2, '2019-12-24')
# 438. ('Carpenter', 47, 3, '2015-04-01')
# 439. ('Carpenter', 178, 2, '2015-04-01')
# 440. ('Carr', 47, 1, '2020-06-21')
# 441. ('Carr', 86, 3, '2020-06-21')
# 442. ('Carr', 157, 3, '2020-07-03')
# 443. ('Carr', 219, 1, '2020-06-21')
# 444. ('Carr', 222, 1, '2020-07-03')
# 445. ('Carr', 275, 1, '2020-07-15')
# 446. ('Carr', 4, 1, '2020-03-01')
# 447. ('Carr', 17, 1, '2020-03-01')
# 448. ('Carr', 68, 1, '2018-04-11')
# 449. ('Carr', 233, 1, '2020-03-01')
# 450. ('Carroll', 75, 2, '2014-02-15')
# 451. ('Carroll', 20, 2, '2020-04-03')
# 452. ('Carroll', 61, 1, '2020-04-03')
# 453. ('Carroll', None, None, None)
# 454. ('Carter', 98, 1, '2015-11-04')
# 455. ('Carter', 117, 2, '2015-11-04')
# 456. ('Carter', 171, 2, '2015-11-04')
# 457. ('Carter', 201, 4, '2015-11-04')
# 458. ('Carter', 262, 2, '2015-11-04')
# 459. ('Carter', 210, 1, '2019-10-06')
# 460. ('Carter', None, None, None)
# 461. ('Case', 23, 7, '2015-01-02')
# 462. ('Case', 136, 2, '2015-09-24')
# 463. ('Case', 171, 1, '2015-01-02')
# 464. ('Case', 206, 2, '2015-01-02')
# 465. ('Case', 274, 1, '2015-01-02')
# 466. ('Casey', 24, 1, '2014-12-14')
# 467. ('Casey', 42, 2, '2016-07-19')
# 468. ('Casey', 46, 1, '2016-07-19')
# 469. ('Casey', 152, 2, '2014-12-14')
# 470. ('Casey', None, None, None)
# 471. ('Castillo', 163, 1, '2018-12-27')
# 472. ('Castillo', 212, 1, '2019-11-23')
# 473. ('Castillo', 218, 1, '2019-08-13')
# 474. ('Castillo', 233, 1, '2020-01-27')
# 475. ('Castillo', 263, 8, '2019-05-09')
# 476. ('Chambers', 180, 4, '2020-06-08')
# 477. ('Chambers', 263, 1, '2020-06-08')
# 478. ('Chaney', 116, 1, '2019-04-07')
# 479. ('Chaney', 148, 1, '2020-06-18')
# 480. ('Chaney', 151, 1, '2020-03-29')
# 481. ('Chaney', 213, 1, '2020-06-18')
# 482. ('Chaney', 236, 4, '2020-06-18')
# 483. ('Chaney', 244, 4, '2019-04-07')
# 484. ('Charles', 17, 4, '2017-09-22')
# 485. ('Charles', 204, 2, '2016-06-20')
# 486. ('Charles', 238, 1, '2016-06-20')
# 487. ('Charles', 240, 1, '2016-06-20')
# 488. ('Charles', 246, 2, '2016-06-20')
# 489. ('Charles', 270, 1, '2018-03-03')
# 490. ('Chavez', 110, 1, '2016-01-09')
# 491. ('Chavez', 144, 1, '2016-01-09')
# 492. ('Cisneros', 41, 1, '2018-07-15')
# 493. ('Cisneros', 120, 1, '2018-10-27')
# 494. ('Clark', 7, 1, '2013-10-04')
# 495. ('Clark', 27, 2, '2013-10-04')
# 496. ('Clark', 217, 4, '2013-08-01')
# 497. ('Clark', 228, 2, '2013-10-04')
# 498. ('Clark', 243, 2, '2015-08-10')
# 499. ('Clark', 243, 2, '2016-11-10')
# 500. ('Clark', 205, 5, '2019-12-07')
# 501. ('Clark', 268, 2, '2019-12-07')
# 502. ('Clark', 6, 1, '2020-07-13')
# 503. ('Clark', 79, 1, '2020-07-13')
# 504. ('Clark', 157, 1, '2020-07-13')
# 505. ('Clark', 99, 2, '2020-04-02')
# 506. ('Clark', 113, 2, '2020-04-02')
# 507. ('Clark', 132, 3, '2018-05-21')
# 508. ('Clark', 148, 2, '2013-02-21')
# 509. ('Clark', 225, 2, '2013-02-21')
# 510. ('Clark', 263, 1, '2018-05-21')
# 511. ('Clark', 18, 1, '2020-07-09')
# 512. ('Clark', 35, 2, '2019-08-25')
# 513. ('Clark', 194, 1, '2020-07-09')
# 514. ('Clark', 201, 1, '2019-06-02')
# 515. ('Clark', 154, 3, '2019-07-31')
# 516. ('Clark', 176, 1, '2019-07-31')
# 517. ('Clark', 182, 3, '2017-05-04')
# 518. ('Clark', 61, 1, '2016-10-18')
# 519. ('Clark', 152, 1, '2020-04-15')
# 520. ('Clark', 203, 3, '2016-10-18')
# 521. ('Clay', None, None, None)
# 522. ('Coffey', 54, 5, '2013-04-25')
# 523. ('Coffey', 103, 1, '2013-04-25')
# 524. ('Coffey', 205, 1, '2017-12-13')
# 525. ('Coffey', 220, 2, '2013-04-25')
# 526. ('Coleman', 25, 1, '2018-02-28')
# 527. ('Coleman', 76, 1, '2014-02-19')
# 528. ('Coleman', 242, 1, '2018-02-28')
# 529. ('Collier', 47, 2, '2019-02-02')
# 530. ('Collier', 241, 1, '2019-02-02')
# 531. ('Collins', 20, 1, '2018-12-21')
# 532. ('Collins', 157, 1, '2018-12-21')
# 533. ('Collins', 13, 1, '2012-10-12')
# 534. ('Collins', 31, 2, '2012-10-12')
# 535. ('Collins', 163, 1, '2012-10-12')
# 536. ('Collins', 213, 1, '2012-10-12')
# 537. ('Collins', 263, 1, '2014-03-23')
# 538. ('Collins', 24, 2, '2017-06-25')
# 539. ('Collins', 121, 3, '2017-12-12')
# 540. ('Collins', 190, 1, '2017-08-06')
# 541. ('Collins', 252, 2, '2017-06-25')
# 542. ('Collins', 103, 1, '2020-04-20')
# 543. ('Collins', 127, 2, '2020-06-06')
# 544. ('Combs', 105, 1, '2019-02-03')
# 545. ('Combs', 202, 1, '2019-02-03')
# 546. ('Compton', 112, 2, '2019-01-13')
# 547. ('Compton', 187, 2, '2019-01-13')
# 548. ('Cook', 45, 2, '2013-01-27')
# 549. ('Cook', 141, 2, '2014-08-21')
# 550. ('Cook', 160, 3, '2020-02-03')
# 551. ('Cooke', 58, 3, '2012-11-11')
# 552. ('Cooke', 68, 1, '2020-07-10')
# 553. ('Cooke', 135, 2, '2015-12-19')
# 554. ('Cooke', 140, 3, '2012-11-11')
# 555. ('Cooke', 273, 1, '2020-07-10')
# 556. ('Cooper', 74, 1, '2018-10-06')
# 557. ('Cooper', 232, 2, '2019-08-15')
# 558. ('Copeland', 54, 1, '2019-12-10')
# 559. ('Copeland', 58, 2, '2016-06-03')
# 560. ('Copeland', 64, 4, '2018-03-07')
# 561. ('Copeland', 78, 1, '2016-12-20')
# 562. ('Copeland', 120, 3, '2016-12-20')
# 563. ('Copeland', 208, 2, '2018-03-07')
# 564. ('Copeland', 211, 2, '2016-12-20')
# 565. ('Copeland', 222, 1, '2016-06-03')
# 566. ('Copeland', 243, 1, '2019-05-01')
# 567. ('Copeland', 277, 2, '2016-06-03')
# 568. ('Cox', 7, 1, '2018-11-24')
# 569. ('Cox', 39, 1, '2020-07-13')
# 570. ('Cox', 233, 4, '2020-07-13')
# 571. ('Cox', 269, 1, '2018-11-24')
# 572. ('Cox', 283, 1, '2019-07-26')
# 573. ('Cox', 63, 1, '2015-11-14')
# 574. ('Cox', 78, 1, '2015-08-15')
# 575. ('Cox', 170, 2, '2015-08-15')
# 576. ('Cox', 195, 7, '2020-02-26')
# 577. ('Cox', 105, 9, '2020-07-22')
# 578. ('Cox', 132, 2, '2014-04-13')
# 579. ('Cox', 134, 1, '2012-10-05')
# 580. ('Cox', 139, 2, '2020-07-22')
# 581. ('Cox', 145, 4, '2014-04-13')
# 582. ('Cox', 157, 1, '2012-10-05')
# 583. ('Cox', 293, 2, '2014-04-13')
# 584. ('Craig', 7, 1, '2018-02-17')
# 585. ('Craig', 91, 1, '2018-02-17')
# 586. ('Craig', 111, 2, '2018-03-26')
# 587. ('Craig', 241, 1, '2018-03-26')
# 588. ('Craig', 17, 2, '2015-04-13')
# 589. ('Craig', 54, 1, '2020-01-18')
# 590. ('Craig', 74, 1, '2015-11-01')
# 591. ('Craig', 248, 5, '2015-11-01')
# 592. ('Cross', 8, 2, '2016-12-15')
# 593. ('Cross', 16, 1, '2018-11-19')
# 594. ('Cross', 57, 2, '2016-06-13')
# 595. ('Cross', 135, 1, '2018-11-19')
# 596. ('Cross', 232, 2, '2018-11-19')
# 597. ('Cruz', 16, 2, '2020-03-01')
# 598. ('Cruz', 57, 2, '2018-03-31')
# 599. ('Cruz', 80, 1, '2018-03-31')
# 600. ('Cruz', 86, 1, '2019-10-11')
# 601. ('Cruz', 95, 2, '2020-03-01')
# 602. ('Cruz', 33, 1, '2017-05-15')
# 603. ('Cruz', 145, 1, '2016-12-13')
# 604. ('Cruz', 270, 2, '2018-07-24')
# 605. ('Cruz', 31, 1, '2017-09-04')
# 606. ('Cruz', 246, 1, '2017-09-04')
# 607. ('Cruz', 15, 1, '2017-08-12')
# 608. ('Cruz', 78, 3, '2019-12-20')
# 609. ('Cruz', 79, 2, '2019-12-20')
# 610. ('Cruz', 118, 1, '2018-06-28')
# 611. ('Cummings', 40, 1, '2013-05-27')
# 612. ('Cummings', 116, 1, '2012-03-03')
# 613. ('Cummings', 137, 1, '2016-07-20')
# 614. ('Cummings', 169, 1, '2012-03-03')
# 615. ('Cummings', 198, 3, '2013-05-27')
# 616. ('Cummings', 75, 1, '2017-11-06')
# 617. ('Cummings', 80, 1, '2013-06-24')
# 618. ('Cummings', 115, 1, '2015-11-16')
# 619. ('Cummings', 279, 2, '2019-06-26')
# 620. ('Dalton', None, None, None)
# 621. ('Dalton', 23, 1, '2017-11-10')
# 622. ('Dalton', 23, 1, '2020-01-16')
# 623. ('Dalton', 229, 2, '2020-01-16')
# 624. ('Dalton', 233, 1, '2018-02-27')
# 625. ('Davenport', 160, 2, '2020-01-12')
# 626. ('Davenport', 186, 2, '2020-03-31')
# 627. ('Davenport', 252, 1, '2020-03-31')
# 628. ('Davenport', 290, 2, '2020-01-12')
# 629. ('David', 17, 2, '2017-02-19')
# 630. ('David', 27, 1, '2014-07-23')
# 631. ('David', 92, 1, '2019-05-28')
# 632. ('David', 121, 1, '2017-02-19')
# 633. ('David', 192, 1, '2019-05-28')
# 634. ('David', 255, 1, '2014-07-23')
# 635. ('David', 277, 1, '2017-02-19')
# 636. ('Davidson', 81, 7, '2020-01-06')
# 637. ('Davidson', 129, 2, '2016-03-16')
# 638. ('Davidson', 135, 1, '2016-03-16')
# 639. ('Davidson', 243, 1, '2020-01-06')
# 640. ('Davila', None, None, None)
# 641. ('Davis', None, None, None)
# 642. ('Davis', 51, 1, '2019-09-25')
# 643. ('Davis', 64, 1, '2019-09-25')
# 644. ('Davis', 139, 5, '2019-09-25')
# 645. ('Davis', 13, 1, '2020-07-05')
# 646. ('Davis', 28, 1, '2019-08-04')
# 647. ('Davis', 45, 2, '2019-08-04')
# 648. ('Davis', 63, 1, '2019-08-04')
# 649. ('Davis', 198, 6, '2020-07-06')
# 650. ('Davis', 212, 1, '2020-07-06')
# 651. ('Davis', 79, 1, '2017-02-03')
# 652. ('Davis', 284, 1, '2014-03-03')
# 653. ('Davis', 105, 1, '2017-03-03')
# 654. ('Davis', 176, 1, '2013-10-17')
# 655. ('Davis', 29, 1, '2020-02-12')
# 656. ('Davis', 81, 1, '2020-03-04')
# 657. ('Davis', 152, 1, '2019-08-24')
# 658. ('Davis', 154, 1, '2019-08-24')
# 659. ('Davis', 248, 1, '2020-02-12')
# 660. ('Davis', 121, 3, '2020-05-10')
# 661. ('Davis', 213, 1, '2020-05-10')
# 662. ('Davis', 213, 2, '2020-05-10')
# 663. ('Davis', None, None, None)
# 664. ('Davis', 11, 3, '2019-01-30')
# 665. ('Davis', 14, 1, '2019-01-23')
# 666. ('Davis', 65, 2, '2020-02-10')
# 667. ('Davis', 67, 3, '2020-02-10')
# 668. ('Davis', 137, 1, '2015-04-18')
# 669. ('Davis', 148, 1, '2015-04-18')
# 670. ('Davis', 172, 1, '2015-04-18')
# 671. ('Davis', 224, 2, '2017-11-25')
# 672. ('Davis', 253, 2, '2015-04-18')
# 673. ('Davis', 258, 4, '2020-02-10')
# 674. ('Davis', 287, 2, '2019-01-23')
# 675. ('Davis', 35, 1, '2013-01-20')
# 676. ('Davis', 40, 1, '2013-01-20')
# 677. ('Davis', 120, 1, '2013-01-20')
# 678. ('Davis', 252, 1, '2014-03-11')
# 679. ('Dawson', 7, 1, '2017-07-08')
# 680. ('Dawson', 18, 3, '2018-08-06')
# 681. ('Dawson', 27, 1, '2018-09-13')
# 682. ('Dawson', 52, 2, '2017-12-10')
# 683. ('Dawson', 119, 3, '2017-12-10')
# 684. ('Dawson', 185, 1, '2018-09-13')
# 685. ('Dawson', 187, 3, '2017-07-08')
# 686. ('Dawson', 188, 2, '2017-07-08')
# 687. ('Decker', 31, 3, '2017-10-08')
# 688. ('Decker', 73, 1, '2020-01-14')
# 689. ('Decker', 81, 1, '2017-10-08')
# 690. ('Decker', 124, 1, '2020-01-14')
# 691. ('Decker', 145, 1, '2020-07-20')
# 692. ('Decker', 158, 4, '2017-10-08')
# 693. ('Decker', 164, 1, '2017-10-08')
# 694. ('Decker', 235, 1, '2020-01-14')
# 695. ('Dennis', 28, 2, '2018-01-12')
# 696. ('Dennis', 174, 1, '2018-01-12')
# 697. ('Diaz', 67, 1, '2019-07-25')
# 698. ('Diaz', 153, 4, '2019-07-25')
# 699. ('Diaz', 228, 2, '2018-11-15')
# 700. ('Diaz', 50, 2, '2019-12-24')
# 701. ('Diaz', 115, 1, '2019-12-24')
# 702. ('Diaz', 171, 2, '2019-12-24')
# 703. ('Diaz', 232, 5, '2020-03-14')
# 704. ('Diaz', 118, 1, '2015-12-24')
# 705. ('Diaz', 170, 2, '2017-02-25')
# 706. ('Diaz', 215, 1, '2017-02-25')
# 707. ('Diaz', 218, 2, '2015-12-24')
# 708. ('Diaz', 9, 1, '2019-05-19')
# 709. ('Diaz', 224, 2, '2019-05-19')
# 710. ('Diaz', 84, 2, '2019-07-07')
# 711. ('Diaz', 147, 2, '2020-01-14')
# 712. ('Diaz', 275, 2, '2020-01-14')
# 713. ('Dickerson', 120, 1, '2013-02-26')
# 714. ('Dickerson', 152, 1, '2019-08-11')
# 715. ('Dickerson', 213, 2, '2019-08-11')
# 716. ('Dickerson', 289, 1, '2011-02-15')
# 717. ('Dixon', None, None, None)
# 718. ('Dixon', 200, 1, '2020-07-28')
# 719. ('Dominguez', None, None, None)
# 720. ('Dominguez', 199, 4, '2019-12-24')
# 721. ('Dominguez', 243, 2, '2015-04-25')
# 722. ('Donovan', None, None, None)
# 723. ('Duffy', 22, 3, '2020-07-03')
# 724. ('Duffy', 121, 2, '2020-05-01')
# 725. ('Duffy', 180, 1, '2020-07-04')
# 726. ('Duffy', 196, 1, '2020-05-01')
# 727. ('Duffy', 259, 1, '2020-07-04')
# 728. ('Duffy', 286, 1, '2020-07-04')
# 729. ('Duncan', 157, 2, '2016-03-11')
# 730. ('Duncan', 61, 2, '2020-02-15')
# 731. ('Duncan', 77, 1, '2019-11-13')
# 732. ('Duncan', 105, 6, '2019-11-13')
# 733. ('Duncan', 110, 1, '2019-08-21')
# 734. ('Duncan', 134, 3, '2019-11-13')
# 735. ('Duncan', 177, 2, '2019-08-21')
# 736. ('Duncan', 226, 1, '2019-10-31')
# 737. ('Duncan', 237, 5, '2019-10-31')
# 738. ('Duncan', 266, 4, '2019-08-21')
# 739. ('Duncan', 291, 1, '2020-07-01')
# 740. ('Dunn', 46, 2, '2020-02-03')
# 741. ('Dunn', 81, 1, '2019-09-02')
# 742. ('Dunn', 98, 2, '2019-08-02')
# 743. ('Dunn', 131, 2, '2019-09-02')
# 744. ('Dunn', 211, 1, '2019-09-02')
# 745. ('Dunn', 246, 2, '2015-04-06')
# 746. ('Dunn', 267, 1, '2015-04-06')
# 747. ('Dunn', 284, 1, '2019-02-28')
# 748. ('Duran', None, None, None)
# 749. ('Eaton', None, None, None)
# 750. ('Edwards', None, None, None)
# 751. ('Edwards', 13, 1, '2019-09-12')
# 752. ('Edwards', 26, 3, '2019-09-12')
# 753. ('Edwards', 28, 2, '2020-01-22')
# 754. ('Edwards', 79, 1, '2019-09-12')
# 755. ('Edwards', 152, 1, '2019-09-24')
# 756. ('Edwards', 194, 1, '2019-09-12')
# 757. ('Edwards', 205, 2, '2020-02-18')
# 758. ('Edwards', 211, 2, '2020-01-22')
# 759. ('Edwards', 214, 1, '2020-02-18')
# 760. ('Edwards', 243, 3, '2019-09-12')
# 761. ('Edwards', 77, 1, '2017-11-14')
# 762. ('Edwards', 95, 1, '2017-11-14')
# 763. ('Edwards', 182, 1, '2018-09-26')
# 764. ('Edwards', 216, 1, '2014-12-12')
# 765. ('Edwards', 255, 2, '2014-12-12')
# 766. ('Edwards', 281, 1, '2014-11-13')
# 767. ('Edwards', 293, 2, '2015-10-08')
# 768. ('Edwards', 24, 1, '2020-04-17')
# 769. ('Edwards', 48, 1, '2020-04-17')
# 770. ('Edwards', 101, 1, '2019-04-05')
# 771. ('Edwards', 190, 1, '2019-04-05')
# 772. ('Edwards', 216, 1, '2020-06-21')
# 773. ('Elliott', 72, 4, '2017-06-03')
# 774. ('Elliott', 186, 1, '2017-06-03')
# 775. ('Elliott', 35, 1, '2016-04-13')
# 776. ('Elliott', 83, 1, '2020-05-19')
# 777. ('Elliott', 99, 1, '2016-04-13')
# 778. ('Elliott', 216, 1, '2020-05-19')
# 779. ('Elliott', 229, 1, '2016-04-13')
# 780. ('Ellis', 76, 5, '2020-03-31')
# 781. ('Ellis', 130, 2, '2020-03-31')
# 782. ('Ellis', 183, 1, '2020-03-31')
# 783. ('Ellis', 198, 1, '2017-12-05')
# 784. ('Ellis', 269, 1, '2015-06-26')
# 785. ('Ellis', 113, 2, '2019-06-13')
# 786. ('Ellis', 212, 2, '2019-06-13')
# 787. ('Ellis', None, None, None)
# 788. ('Erickson', 53, 4, '2020-02-04')
# 789. ('Erickson', 85, 1, '2020-07-24')
# 790. ('Erickson', 124, 2, '2020-07-24')
# 791. ('Erickson', 142, 1, '2020-03-25')
# 792. ('Erickson', 151, 4, '2019-08-18')
# 793. ('Erickson', 156, 2, '2020-03-25')
# 794. ('Erickson', 210, 4, '2020-07-24')
# 795. ('Erickson', 239, 1, '2020-02-04')
# 796. ('Erickson', 241, 1, '2020-03-25')
# 797. ('Espinoza', 58, 3, '2019-09-07')
# 798. ('Espinoza', 66, 2, '2020-04-02')
# 799. ('Espinoza', 138, 1, '2019-09-07')
# 800. ('Espinoza', 211, 4, '2019-09-07')
# 801. ('Espinoza', 213, 2, '2019-11-15')
# 802. ('Estrada', 149, 2, '2016-05-20')
# 803. ('Estrada', None, None, None)
# 804. ('Evans', 11, 3, '2016-09-05')
# 805. ('Evans', 18, 1, '2019-03-17')
# 806. ('Evans', 49, 3, '2019-12-15')
# 807. ('Evans', 50, 1, '2019-04-14')
# 808. ('Evans', 73, 1, '2016-10-26')
# 809. ('Evans', 119, 1, '2019-12-15')
# 810. ('Evans', 220, 3, '2016-10-26')
# 811. ('Evans', 19, 1, '2019-12-17')
# 812. ('Evans', 124, 2, '2019-08-30')
# 813. ('Evans', 275, 1, '2019-08-30')
# 814. ('Evans', 63, 3, '2016-02-07')
# 815. ('Evans', 76, 2, '2015-02-08')
# 816. ('Evans', 109, 1, '2019-08-20')
# 817. ('Evans', 143, 1, '2016-02-07')
# 818. ('Evans', 157, 3, '2016-02-07')
# 819. ('Evans', 198, 2, '2015-02-08')
# 820. ('Evans', 245, 1, '2016-02-07')
# 821. ('Evans', 256, 3, '2016-12-09')
# 822. ('Evans', None, None, None)
# 823. ('Evans', 80, 1, '2018-09-22')
# 824. ('Evans', 82, 2, '2012-12-22')
# 825. ('Evans', 164, 1, '2012-12-22')
# 826. ('Evans', 203, 1, '2018-04-14')
# 827. ('Evans', 39, 2, '2018-02-14')
# 828. ('Evans', 52, 1, '2020-07-12')
# 829. ('Evans', 68, 1, '2018-02-14')
# 830. ('Evans', 81, 4, '2020-07-12')
# 831. ('Evans', 134, 1, '2020-07-12')
# 832. ('Evans', 199, 1, '2020-07-12')
# 833. ('Evans', 202, 1, '2020-07-12')
# 834. ('Evans', 206, 2, '2020-07-12')
# 835. ('Evans', 234, 3, '2020-07-12')
# 836. ('Evans', 279, 2, '2017-01-18')
# 837. ('Evans', 5, 2, '2019-06-24')
# 838. ('Evans', 42, 3, '2019-02-13')
# 839. ('Evans', 210, 2, '2019-06-24')
# 840. ('Evans', 197, 3, '2018-08-09')
# 841. ('Evans', 265, 6, '2019-08-31')
# 842. ('Fernandez', None, None, None)
# 843. ('Fernandez', 85, 2, '2014-09-15')
# 844. ('Fernandez', 93, 5, '2014-04-28')
# 845. ('Fernandez', 127, 3, '2015-05-19')
# 846. ('Fernandez', 138, 1, '2014-04-28')
# 847. ('Fernandez', 140, 1, '2018-12-23')
# 848. ('Fernandez', 171, 2, '2015-05-19')
# 849. ('Fernandez', 173, 6, '2020-07-14')
# 850. ('Fernandez', 205, 8, '2019-03-09')
# 851. ('Fernandez', 224, 1, '2015-05-19')
# 852. ('Fernandez', 228, 1, '2019-03-09')
# 853. ('Fernandez', 232, 2, '2015-05-19')
# 854. ('Fernandez', 235, 4, '2019-03-09')
# 855. ('Fields', 17, 1, '2019-10-16')
# 856. ('Fields', 49, 1, '2019-10-16')
# 857. ('Fields', 244, 1, '2019-10-16')
# 858. ('Fields', 246, 2, '2019-10-16')
# 859. ('Fields', 263, 1, '2019-10-16')
# 860. ('Fields', 272, 1, '2019-10-16')
# 861. ('Finley', 93, 6, '2019-08-09')
# 862. ('Finley', 269, 2, '2019-08-09')
# 863. ('Fisher', 14, 1, '2014-09-01')
# 864. ('Fisher', 206, 4, '2014-09-01')
# 865. ('Fisher', 286, 1, '2014-09-01')
# 866. ('Fitzpatrick', 9, 2, '2018-07-12')
# 867. ('Fitzpatrick', 23, 1, '2018-07-12')
# 868. ('Fitzpatrick', 70, 1, '2016-01-25')
# 869. ('Fitzpatrick', 130, 1, '2018-07-12')
# 870. ('Fitzpatrick', 132, 1, '2018-07-12')
# 871. ('Fitzpatrick', 217, 1, '2016-01-25')
# 872. ('Fitzpatrick', 231, 2, '2018-07-12')
# 873. ('Fleming', 18, 1, '2016-05-18')
# 874. ('Fleming', 41, 3, '2019-10-06')
# 875. ('Fleming', 80, 1, '2017-12-21')
# 876. ('Fleming', 94, 1, '2017-12-21')
# 877. ('Fleming', 114, 5, '2017-04-19')
# 878. ('Fleming', 166, 1, '2017-12-21')
# 879. ('Fleming', 220, 3, '2017-04-19')
# 880. ('Fleming', 226, 1, '2016-05-18')
# 881. ('Fleming', 255, 1, '2016-11-10')
# 882. ('Fletcher', 129, 1, '2017-03-09')
# 883. ('Fletcher', 183, 1, '2019-04-07')
# 884. ('Fletcher', 215, 1, '2018-08-13')
# 885. ('Fletcher', 135, 4, '2017-10-25')
# 886. ('Fletcher', 201, 2, '2010-10-29')
# 887. ('Fletcher', 239, 2, '2014-08-12')
# 888. ('Fletcher', 281, 1, '2017-10-25')
# 889. ('Fletcher', 288, 1, '2011-08-02')
# 890. ('Flores', 38, 2, '2018-09-22')
# 891. ('Flores', 117, 1, '2016-08-18')
# 892. ('Flores', 127, 1, '2017-06-25')
# 893. ('Flores', 135, 1, '2016-12-17')
# 894. ('Flores', 149, 1, '2018-09-22')
# 895. ('Flores', 162, 1, '2017-09-24')
# 896. ('Flores', 216, 2, '2016-08-18')
# 897. ('Flores', 221, 1, '2016-08-18')
# 898. ('Flores', 249, 2, '2016-08-18')
# 899. ('Floyd', 9, 1, '2019-05-13')
# 900. ('Floyd', 25, 1, '2015-01-19')
# 901. ('Floyd', 196, 1, '2015-01-19')
# 902. ('Floyd', 209, 1, '2017-11-17')
# 903. ('Floyd', 261, 1, '2017-11-17')
# 904. ('Floyd', 277, 4, '2017-11-17')
# 905. ('Floyd', 283, 1, '2018-07-04')
# 906. ('Foster', 18, 3, '2018-05-31')
# 907. ('Foster', 36, 1, '2019-01-19')
# 908. ('Foster', 96, 2, '2019-01-19')
# 909. ('Foster', 167, 4, '2018-07-02')
# 910. ('Foster', 178, 1, '2017-10-01')
# 911. ('Fowler', None, None, None)
# 912. ('Fowler', None, None, None)
# 913. ('Franco', 1, 1, '2017-03-05')
# 914. ('Franco', 4, 4, '2019-09-09')
# 915. ('Franco', 6, 1, '2017-06-10')
# 916. ('Franco', 25, 1, '2018-10-11')
# 917. ('Franco', 56, 1, '2017-03-05')
# 918. ('Franco', 132, 1, '2018-10-11')
# 919. ('Franco', 139, 1, '2019-03-09')
# 920. ('Franco', 209, 1, '2017-06-10')
# 921. ('Franco', 235, 1, '2017-06-10')
# 922. ('Franco', 54, 2, '2020-06-05')
# 923. ('Franco', 152, 2, '2017-05-11')
# 924. ('Franco', 172, 2, '2017-05-11')
# 925. ('Franco', 294, 1, '2020-06-05')
# 926. ('Frank', 170, 2, '2018-12-25')
# 927. ('Frank', 196, 1, '2016-10-17')
# 928. ('Friedman', 27, 1, '2014-01-15')
# 929. ('Friedman', 47, 2, '2019-07-28')
# 930. ('Friedman', 60, 1, '2016-06-19')
# 931. ('Friedman', 61, 1, '2016-06-19')
# 932. ('Friedman', 70, 2, '2014-01-15')
# 933. ('Friedman', 133, 1, '2014-04-11')
# 934. ('Friedman', 155, 1, '2019-09-03')
# 935. ('Friedman', 169, 1, '2014-04-11')
# 936. ('Friedman', 257, 5, '2016-06-19')
# 937. ('Friedman', 262, 3, '2019-09-03')
# 938. ('Friedman', 264, 3, '2016-06-19')
# 939. ('Friedman', 267, 1, '2019-07-28')
# 940. ('Frost', 74, 3, '2017-02-23')
# 941. ('Frost', 213, 1, '2019-09-01')
# 942. ('Frye', 35, 2, '2016-10-24')
# 943. ('Frye', 36, 1, '2016-10-24')
# 944. ('Frye', 202, 2, '2018-08-26')
# 945. ('Frye', 217, 1, '2016-10-24')
# 946. ('Frye', 270, 1, '2019-03-07')
# 947. ('Frye', 286, 3, '2016-10-24')
# 948. ('Frye', 5, 2, '2018-09-04')
# 949. ('Frye', 27, 1, '2019-08-22')
# 950. ('Frye', 135, 1, '2017-09-20')
# 951. ('Frye', 178, 3, '2018-09-04')
# 952. ('Frye', 185, 2, '2017-08-01')
# 953. ('Frye', 224, 1, '2020-07-21')
# 954. ('Fuller', None, None, None)
# 955. ('Gaines', 102, 1, '2020-07-04')
# 956. ('Gaines', 46, 1, '2018-10-24')
# 957. ('Gaines', 152, 2, '2018-10-24')
# 958. ('Gallegos', 65, 2, '2018-06-28')
# 959. ('Gallegos', 76, 1, '2018-06-28')
# 960. ('Gamble', 73, 1, '2018-09-30')
# 961. ('Gamble', 85, 4, '2018-09-30')
# 962. ('Gamble', 95, 2, '2019-07-05')
# 963. ('Gamble', 146, 1, '2019-08-08')
# 964. ('Gamble', 221, 3, '2019-08-08')
# 965. ('Gamble', 38, 2, '2017-01-09')
# 966. ('Garcia', 238, 1, '2020-07-09')
# 967. ('Garcia', 47, 3, '2018-09-08')
# 968. ('Garcia', 54, 4, '2018-09-08')
# 969. ('Garcia', 110, 2, '2012-10-02')
# 970. ('Garcia', 119, 1, '2012-10-02')
# 971. ('Garcia', 153, 1, '2018-09-08')
# 972. ('Garcia', 164, 2, '2018-09-08')
# 973. ('Garcia', 243, 1, '2018-09-08')
# 974. ('Garcia', 7, 1, '2017-05-10')
# 975. ('Garcia', 48, 3, '2017-03-21')
# 976. ('Garcia', 92, 1, '2016-12-05')
# 977. ('Garcia', 228, 2, '2018-08-15')
# 978. ('Garcia', 235, 1, '2016-11-25')
# 979. ('Garcia', 279, 5, '2018-08-15')
# 980. ('Garcia', 286, 1, '2018-08-15')
# 981. ('Garcia', 23, 3, '2013-04-12')
# 982. ('Garcia', 66, 2, '2013-04-12')
# 983. ('Garcia', 94, 2, '2014-01-13')
# 984. ('Garcia', 101, 1, '2015-03-23')
# 985. ('Garcia', 128, 1, '2014-01-13')
# 986. ('Garcia', 149, 1, '2015-06-07')
# 987. ('Garcia', 152, 1, '2015-03-23')
# 988. ('Garcia', 164, 2, '2015-03-23')
# 989. ('Garcia', 184, 1, '2013-04-12')
# 990. ('Garcia', 186, 1, '2015-10-31')
# 991. ('Garcia', 208, 2, '2013-04-12')
# 992. ('Garcia', 211, 1, '2015-03-23')
# 993. ('Garcia', 238, 1, '2015-06-07')
# 994. ('Garcia', 239, 1, '2013-12-21')
# 995. ('Garcia', 247, 1, '2013-12-21')
# 996. ('Garcia', 150, 1, '2016-06-21')
# 997. ('Garcia', 169, 1, '2016-08-22')
# 998. ('Garcia', 199, 1, '2019-04-19')
# 999. ('Garcia', 232, 1, '2019-04-19')
# 1000. ('Garcia', 263, 1, '2016-08-22')
# 1001. ('Garcia', 136, 1, '2015-08-16')
# 1002. ('Garcia', 2, 1, '2017-06-02')
# 1003. ('Garcia', 96, 1, '2017-06-02')
# 1004. ('Garcia', 130, 1, '2017-06-02')
# 1005. ('Garcia', 135, 2, '2017-06-02')
# 1006. ('Garcia', 168, 2, '2017-04-16')
# 1007. ('Garcia', 190, 1, '2017-06-02')
# 1008. ('Garcia', 4, 1, '2017-10-09')
# 1009. ('Garcia', 20, 1, '2019-07-13')
# 1010. ('Garcia', 118, 2, '2020-04-04')
# 1011. ('Garcia', 220, 3, '2020-04-04')
# 1012. ('Garcia', 14, 2, '2020-06-28')
# 1013. ('Garcia', 86, 1, '2016-07-22')
# 1014. ('Garcia', 111, 3, '2020-01-15')
# 1015. ('Garcia', 124, 1, '2020-01-31')
# 1016. ('Garcia', 179, 2, '2020-01-15')
# 1017. ('Garcia', 228, 2, '2020-01-31')
# 1018. ('Garcia', 240, 2, '2016-07-22')
# 1019. ('Garcia', 248, 2, '2020-01-31')
# 1020. ('Garcia', 254, 1, '2016-07-22')
# 1021. ('Gardner', 31, 2, '2019-01-19')
# 1022. ('Gardner', 50, 1, '2020-04-24')
# 1023. ('Gardner', 174, 1, '2019-01-19')
# 1024. ('Gardner', 211, 1, '2020-04-24')
# 1025. ('Gardner', 256, 1, '2020-04-24')
# 1026. ('Gardner', 77, 1, '2020-07-12')
# 1027. ('Gardner', 274, 1, '2020-07-12')
# 1028. ('Gardner', 76, 1, '2016-10-28')
# 1029. ('Gardner', 226, 2, '2016-10-28')
# 1030. ('Garner', 23, 2, '2014-05-07')
# 1031. ('Garner', 104, 1, '2014-12-02')
# 1032. ('Garner', 254, 3, '2015-08-03')
# 1033. ('Garrett', 20, 1, '2018-09-25')
# 1034. ('Garrett', 140, 2, '2018-09-25')
# 1035. ('Garrett', 52, 1, '2018-01-26')
# 1036. ('Garrett', 264, 1, '2019-03-24')
# 1037. ('Garza', 84, 1, '2013-06-28')
# 1038. ('Garza', 123, 3, '2015-07-05')
# 1039. ('Garza', 128, 2, '2017-09-18')
# 1040. ('Garza', 191, 1, '2013-06-28')
# 1041. ('Garza', 62, 2, '2019-02-10')
# 1042. ('Garza', 158, 2, '2019-02-10')
# 1043. ('Garza', 177, 1, '2019-02-10')
# 1044. ('Gates', 1, 4, '2014-10-08')
# 1045. ('Gates', 120, 1, '2014-10-08')
# 1046. ('Gentry', 16, 4, '2020-05-30')
# 1047. ('Gentry', 44, 2, '2020-05-30')
# 1048. ('Gentry', 241, 2, '2020-05-30')
# 1049. ('George', None, None, None)
# 1050. ('Gibbs', 65, 1, '2018-08-09')
# 1051. ('Gibbs', 77, 1, '2018-08-09')
# 1052. ('Gibbs', 180, 5, '2018-08-09')
# 1053. ('Gibson', 9, 1, '2015-12-06')
# 1054. ('Gibson', 88, 1, '2015-11-01')
# 1055. ('Gibson', 115, 2, '2015-11-01')
# 1056. ('Gibson', 249, 1, '2015-11-01')
# 1057. ('Gillespie', 3, 1, '2017-11-21')
# 1058. ('Gillespie', 43, 1, '2017-03-18')
# 1059. ('Gillespie', 143, 5, '2018-05-09')
# 1060. ('Gillespie', 191, 1, '2017-11-21')
# 1061. ('Gillespie', 203, 1, '2018-05-09')
# 1062. ('Gomez', None, None, None)
# 1063. ('Gonzales', 167, 1, '2019-10-07')
# 1064. ('Gonzales', 210, 1, '2018-12-20')
# 1065. ('Gonzales', 268, 1, '2015-07-14')
# 1066. ('Gonzales', 269, 1, '2015-07-14')
# 1067. ('Gonzales', 287, 1, '2012-07-22')
# 1068. ('Gonzalez', 71, 2, '2015-05-18')
# 1069. ('Gonzalez', 125, 3, '2018-10-08')
# 1070. ('Gonzalez', 223, 6, '2019-02-03')
# 1071. ('Gonzalez', 22, 1, '2020-02-27')
# 1072. ('Gonzalez', 88, 1, '2017-07-30')
# 1073. ('Gonzalez', 116, 2, '2018-06-17')
# 1074. ('Gonzalez', 48, 1, '2013-12-24')
# 1075. ('Gonzalez', 90, 2, '2016-04-29')
# 1076. ('Gonzalez', 127, 2, '2016-04-29')
# 1077. ('Gonzalez', 258, 1, '2016-04-29')
# 1078. ('Gonzalez', 16, 2, '2017-10-07')
# 1079. ('Gonzalez', 22, 1, '2016-09-03')
# 1080. ('Gonzalez', 34, 2, '2020-06-20')
# 1081. ('Gonzalez', 55, 1, '2017-10-07')
# 1082. ('Gonzalez', 153, 1, '2020-06-20')
# 1083. ('Gonzalez', 160, 1, '2016-09-03')
# 1084. ('Gonzalez', 227, 1, '2017-10-07')
# 1085. ('Gonzalez', 257, 1, '2020-06-20')
# 1086. ('Gonzalez', 172, 2, '2018-04-16')
# 1087. ('Gonzalez', 38, 2, '2016-07-09')
# 1088. ('Gonzalez', 81, 2, '2016-07-09')
# 1089. ('Gonzalez', 136, 1, '2016-07-09')
# 1090. ('Gonzalez', 211, 3, '2015-09-05')
# 1091. ('Gonzalez', 252, 1, '2019-12-13')
# 1092. ('Gonzalez', 265, 1, '2019-12-13')
# 1093. ('Gonzalez', 61, 1, '2019-10-15')
# 1094. ('Gonzalez', 144, 1, '2019-08-30')
# 1095. ('Gonzalez', 277, 3, '2019-08-30')
# 1096. ('Gonzalez', 113, 1, '2019-01-09')
# 1097. ('Gonzalez', 131, 2, '2015-10-06')
# 1098. ('Gonzalez', 195, 1, '2019-01-09')
# 1099. ('Gonzalez', 204, 2, '2015-10-06')
# 1100. ('Gonzalez', 247, 1, '2019-01-09')
# 1101. ('Gonzalez', 282, 1, '2019-03-14')
# 1102. ('Goodman', 43, 3, '2017-05-20')
# 1103. ('Goodman', 63, 2, '2016-10-01')
# 1104. ('Goodman', 196, 1, '2017-05-20')
# 1105. ('Goodwin', None, None, None)
# 1106. ('Gordon', 5, 2, '2015-05-26')
# 1107. ('Gordon', 115, 3, '2015-05-26')
# 1108. ('Gordon', 190, 2, '2015-05-26')
# 1109. ('Gordon', 252, 1, '2015-05-26')
# 1110. ('Gordon', 47, 2, '2016-09-15')
# 1111. ('Gould', 21, 3, '2019-12-23')
# 1112. ('Gould', 285, 2, '2019-12-23')
# 1113. ('Gould', 167, 1, '2019-04-28')
# 1114. ('Gould', 222, 2, '2019-04-28')
# 1115. ('Graham', 28, 4, '2020-03-24')
# 1116. ('Graham', 39, 1, '2019-10-03')
# 1117. ('Graham', 94, 1, '2020-03-24')
# 1118. ('Graham', 110, 5, '2020-03-24')
# 1119. ('Graham', 112, 3, '2018-11-23')
# 1120. ('Graham', 135, 2, '2019-11-23')
# 1121. ('Graham', 140, 1, '2020-03-24')
# 1122. ('Graham', 143, 3, '2020-03-01')
# 1123. ('Graham', 233, 1, '2019-10-03')
# 1124. ('Graham', 262, 1, '2019-10-03')
# 1125. ('Graham', 284, 1, '2020-01-06')
# 1126. ('Grant', 184, 1, '2019-12-05')
# 1127. ('Grant', 187, 1, '2019-12-05')
# 1128. ('Grant', 217, 8, '2019-12-05')
# 1129. ('Grant', 245, 2, '2019-12-05')
# 1130. ('Grant', 260, 4, '2019-02-10')
# 1131. ('Grant', 22, 6, '2017-12-01')
# 1132. ('Graves', 195, 2, '2019-05-02')
# 1133. ('Graves', 261, 2, '2019-05-02')
# 1134. ('Graves', 268, 1, '2020-03-26')
# 1135. ('Graves', 271, 1, '2016-04-27')
# 1136. ('Graves', 275, 3, '2016-04-27')
# 1137. ('Graves', 131, 3, '2019-08-12')
# 1138. ('Graves', 177, 2, '2017-11-16')
# 1139. ('Gray', 58, 3, '2014-10-06')
# 1140. ('Gray', 79, 2, '2014-10-06')
# 1141. ('Gray', 83, 1, '2014-10-06')
# 1142. ('Gray', 257, 3, '2020-04-17')
# 1143. ('Gray', 270, 2, '2018-11-02')
# 1144. ('Green', 9, 1, '2015-12-05')
# 1145. ('Green', 83, 5, '2020-03-30')
# 1146. ('Green', 137, 1, '2015-12-05')
# 1147. ('Green', 225, 8, '2015-12-05')
# 1148. ('Green', 229, 4, '2015-07-03')
# 1149. ('Green', 240, 2, '2015-07-03')
# 1150. ('Green', None, None, None)
# 1151. ('Green', 267, 3, '2020-06-24')
# 1152. ('Green', None, None, None)
# 1153. ('Greene', 40, 2, '2018-10-24')
# 1154. ('Greene', 58, 1, '2019-06-21')
# 1155. ('Greene', 70, 3, '2019-06-21')
# 1156. ('Greene', 84, 1, '2019-06-21')
# 1157. ('Greene', 269, 3, '2019-05-18')
# 1158. ('Greene', 183, 3, '2020-03-24')
# 1159. ('Greene', 221, 1, '2020-03-24')
# 1160. ('Greene', 265, 2, '2018-08-02')
# 1161. ('Greene', 289, 1, '2020-03-24')
# 1162. ('Greene', 10, 1, '2020-07-14')
# 1163. ('Greene', 65, 1, '2020-07-14')
# 1164. ('Greene', 211, 1, '2020-07-14')
# 1165. ('Gregory', 53, 1, '2018-03-10')
# 1166. ('Gregory', 231, 1, '2018-03-10')
# 1167. ('Griffin', 1, 5, '2017-06-03')
# 1168. ('Griffin', 11, 1, '2014-01-23')
# 1169. ('Griffin', 46, 2, '2017-06-03')
# 1170. ('Griffin', 105, 2, '2014-01-23')
# 1171. ('Griffin', 126, 2, '2014-01-23')
# 1172. ('Griffin', 160, 2, '2011-05-18')
# 1173. ('Griffin', 185, 2, '2011-05-18')
# 1174. ('Griffin', 253, 3, '2017-06-03')
# 1175. ('Griffin', 277, 1, '2019-04-12')
# 1176. ('Griffin', 79, 3, '2014-04-06')
# 1177. ('Griffith', 59, 3, '2017-09-20')
# 1178. ('Griffith', 251, 1, '2020-04-26')
# 1179. ('Griffith', 275, 1, '2016-09-13')
# 1180. ('Griffith', 29, 2, '2014-12-18')
# 1181. ('Griffith', 72, 1, '2014-12-18')
# 1182. ('Griffith', 266, 2, '2014-12-18')
# 1183. ('Griffith', 211, 1, '2018-11-25')
# 1184. ('Griffith', 5, 1, '2019-11-01')
# 1185. ('Griffith', 45, 1, '2019-11-01')
# 1186. ('Griffith', 76, 1, '2019-11-01')
# 1187. ('Griffith', 96, 1, '2019-11-01')
# 1188. ('Griffith', 130, 1, '2020-07-24')
# 1189. ('Griffith', 157, 1, '2020-07-24')
# 1190. ('Griffith', 232, 2, '2020-07-24')
# 1191. ('Griffith', 245, 1, '2020-05-19')
# 1192. ('Griffith', 5, 1, '2014-10-26')
# 1193. ('Griffith', 24, 1, '2014-10-26')
# 1194. ('Griffith', 33, 1, '2014-10-26')
# 1195. ('Griffith', 177, 2, '2013-09-29')
# 1196. ('Griffith', 239, 1, '2014-10-26')
# 1197. ('Gross', 146, 2, '2018-12-13')
# 1198. ('Gross', 159, 2, '2018-12-13')
# 1199. ('Gross', 177, 2, '2018-12-13')
# 1200. ('Gross', 201, 1, '2018-12-13')
# 1201. ('Gross', 258, 3, '2018-07-23')
# 1202. ('Gross', 272, 3, '2018-05-12')
# 1203. ('Gutierrez', 93, 1, '2015-02-03')
# 1204. ('Gutierrez', 240, 3, '2014-06-03')
# 1205. ('Gutierrez', 245, 1, '2017-08-04')
# 1206. ('Gutierrez', 108, 1, '2019-04-19')
# 1207. ('Gutierrez', 198, 2, '2019-04-05')
# 1208. ('Gutierrez', 272, 1, '2019-04-05')
# 1209. ('Gutierrez', 93, 1, '2019-06-24')
# 1210. ('Gutierrez', 121, 1, '2019-06-24')
# 1211. ('Gutierrez', 252, 1, '2019-06-24')
# 1212. ('Gutierrez', 25, 1, '2020-07-21')
# 1213. ('Gutierrez', 68, 3, '2020-06-06')
# 1214. ('Gutierrez', 226, 1, '2020-06-06')
# 1215. ('Gutierrez', 279, 1, '2020-07-21')
# 1216. ('Haas', 28, 1, '2015-10-13')
# 1217. ('Haas', 93, 1, '2014-12-28')
# 1218. ('Haas', 165, 1, '2017-09-15')
# 1219. ('Haas', 205, 1, '2018-05-08')
# 1220. ('Hahn', 108, 2, '2020-02-27')
# 1221. ('Hahn', 112, 3, '2020-02-27')
# 1222. ('Hahn', 117, 1, '2019-09-08')
# 1223. ('Hahn', 132, 1, '2019-05-06')
# 1224. ('Hahn', 140, 1, '2019-07-20')
# 1225. ('Hahn', 166, 1, '2019-05-06')
# 1226. ('Hahn', 197, 4, '2019-10-05')
# 1227. ('Hahn', 200, 1, '2019-08-23')
# 1228. ('Hahn', 209, 1, '2019-10-05')
# 1229. ('Hahn', 267, 1, '2019-05-06')
# 1230. ('Hale', 3, 1, '2018-03-30')
# 1231. ('Hale', 19, 1, '2015-11-27')
# 1232. ('Hale', 202, 1, '2019-10-13')
# 1233. ('Hale', 238, 2, '2015-11-27')
# 1234. ('Hale', 259, 1, '2019-10-13')
# 1235. ('Haley', 16, 6, '2017-07-31')
# 1236. ('Haley', 95, 1, '2016-11-24')
# 1237. ('Hall', 28, 2, '2018-06-30')
# 1238. ('Hall', 31, 1, '2016-03-27')
# 1239. ('Hall', 81, 2, '2018-06-30')
# 1240. ('Hall', 34, 2, '2017-07-26')
# 1241. ('Hall', 206, 1, '2017-07-26')
# 1242. ('Hall', 292, 1, '2020-01-01')
# 1243. ('Hall', None, None, None)
# 1244. ('Hall', 247, 1, '2016-07-08')
# 1245. ('Hall', 277, 1, '2016-07-08')
# 1246. ('Hamilton', None, None, None)
# 1247. ('Hamilton', 93, 1, '2017-10-05')
# 1248. ('Hamilton', 119, 1, '2015-05-12')
# 1249. ('Hamilton', 178, 4, '2016-04-12')
# 1250. ('Hamilton', 209, 2, '2019-09-20')
# 1251. ('Hamilton', 275, 3, '2017-10-05')
# 1252. ('Hamilton', 115, 1, '2016-02-11')
# 1253. ('Hamilton', 133, 2, '2019-05-18')
# 1254. ('Hampton', 153, 2, '2019-04-17')
# 1255. ('Hampton', 161, 1, '2018-05-22')
# 1256. ('Hampton', 215, 8, '2019-04-17')
# 1257. ('Hampton', 286, 3, '2017-10-10')
# 1258. ('Hanna', 34, 2, '2019-07-18')
# 1259. ('Hanna', 67, 3, '2016-04-18')
# 1260. ('Hanna', 120, 3, '2018-09-13')
# 1261. ('Hanna', 217, 2, '2016-07-26')
# 1262. ('Hanna', 217, 3, '2019-11-29')
# 1263. ('Hansen', 235, 1, '2018-01-26')
# 1264. ('Hansen', 279, 2, '2018-01-26')
# 1265. ('Hansen', 2, 1, '2019-06-11')
# 1266. ('Hansen', 78, 1, '2019-06-11')
# 1267. ('Hansen', 106, 1, '2019-03-10')
# 1268. ('Hanson', 53, 2, '2017-11-18')
# 1269. ('Hanson', 112, 3, '2012-04-15')
# 1270. ('Hanson', 166, 1, '2012-04-15')
# 1271. ('Hanson', 189, 1, '2017-11-18')
# 1272. ('Hanson', 199, 2, '2020-07-13')
# ...
# 3418. ('Vargas', 77, 1, '2019-01-26')
# 3419. ('Vargas', 248, 2, '2019-01-26')
# 3420. ('Vargas', 21, 1, '2013-09-19')
# 3421. ('Vargas', 77, 1, '2013-09-19')
# 3422. ('Vargas', 47, 1, '2015-01-01')
# 3423. ('Vargas', 114, 2, '2019-09-20')
# 3424. ('Vargas', 117, 2, '2019-09-20')
# 3425. ('Vargas', 183, 2, '2014-07-26')
# 3426. ('Vargas', 236, 1, '2019-09-20')
# 3427. ('Vargas', 248, 2, '2018-01-07')
# 3428. ('Vargas', 258, 2, '2018-01-07')
# 3429. ('Vasquez', 14, 3, '2014-08-30')
# 3430. ('Vasquez', 18, 1, '2016-10-25')
# 3431. ('Vasquez', 34, 1, '2016-10-25')
# 3432. ('Vasquez', 37, 1, '2016-10-25')
# 3433. ('Vasquez', 67, 2, '2018-02-13')
# 3434. ('Vasquez', 210, 1, '2016-10-25')
# 3435. ('Velasquez', 145, 3, '2019-01-18')
# 3436. ('Velasquez', 223, 2, '2019-01-18')
# 3437. ('Velasquez', 270, 2, '2019-01-18')
# 3438. ('Velez', 165, 2, '2019-10-13')
# 3439. ('Velez', 202, 4, '2019-10-13')
# 3440. ('Velez', 205, 1, '2019-09-15')
# 3441. ('Velez', 232, 2, '2018-09-09')
# 3442. ('Velez', 232, 5, '2018-09-09')
# 3443. ('Velez', 277, 4, '2018-01-26')
# 3444. ('Villarreal', 15, 1, '2019-06-06')
# 3445. ('Villarreal', 22, 1, '2019-01-17')
# 3446. ('Villarreal', 77, 2, '2019-06-06')
# 3447. ('Villarreal', 33, 1, '2020-06-01')
# 3448. ('Villarreal', 95, 3, '2018-12-02')
# 3449. ('Villarreal', 130, 1, '2019-09-23')
# 3450. ('Villarreal', 164, 4, '2016-07-14')
# 3451. ('Villarreal', 236, 2, '2019-09-23')
# 3452. ('Villarreal', 257, 3, '2017-10-27')
# 3453. ('Villarreal', 289, 1, '2019-09-23')
# 3454. ('Villarreal', 28, 3, '2019-12-02')
# 3455. ('Villarreal', 33, 3, '2019-12-02')
# 3456. ('Villarreal', 229, 1, '2019-12-02')
# 3457. ('Vincent', 109, 3, '2019-05-27')
# 3458. ('Vincent', 112, 1, '2019-10-11')
# 3459. ('Vincent', 152, 6, '2019-05-27')
# 3460. ('Vincent', 197, 2, '2017-12-26')
# 3461. ('Vincent', 228, 8, '2016-05-25')
# 3462. ('Vincent', 253, 1, '2019-05-27')
# 3463. ('Vincent', 257, 1, '2018-10-14')
# 3464. ('Vincent', 266, 1, '2019-10-11')
# 3465. ('Wade', 130, 2, '2016-09-02')
# 3466. ('Wade', 158, 2, '2016-09-02')
# 3467. ('Wade', 203, 1, '2019-07-28')
# 3468. ('Wade', 204, 1, '2019-07-28')
# 3469. ('Wade', 173, 1, '2012-12-16')
# 3470. ('Wade', 210, 1, '2014-02-15')
# 3471. ('Wade', 231, 2, '2014-02-15')
# 3472. ('Wagner', 57, 1, '2018-10-29')
# 3473. ('Wagner', 137, 1, '2017-06-04')
# 3474. ('Wagner', 191, 2, '2017-06-04')
# 3475. ('Wagner', 229, 4, '2018-04-08')
# 3476. ('Wagner', 13, 3, '2020-07-15')
# 3477. ('Wagner', 56, 2, '2020-02-23')
# 3478. ('Wagner', 167, 2, '2019-12-28')
# 3479. ('Wagner', 240, 1, '2020-02-23')
# 3480. ('Walker', 223, 1, '2018-05-26')
# 3481. ('Walker', 30, 1, '2019-06-27')
# 3482. ('Walker', 70, 3, '2018-08-13')
# 3483. ('Walker', 82, 2, '2020-02-04')
# 3484. ('Walker', 138, 1, '2018-08-13')
# 3485. ('Walker', 143, 5, '2019-04-11')
# 3486. ('Walker', 165, 2, '2018-09-05')
# 3487. ('Walker', 191, 2, '2020-06-11')
# 3488. ('Walker', 200, 1, '2019-04-11')
# 3489. ('Walker', 240, 5, '2020-06-11')
# 3490. ('Walker', 282, 1, '2018-08-13')
# 3491. ('Walker', None, None, None)
# 3492. ('Walker', 16, 1, '2014-03-24')
# 3493. ('Walker', 89, 1, '2015-08-01')
# 3494. ('Walker', 90, 2, '2020-06-03')
# 3495. ('Walker', 124, 2, '2014-03-24')
# 3496. ('Walker', 185, 1, '2020-06-03')
# 3497. ('Walker', 25, 1, '2013-09-06')
# 3498. ('Walker', 118, 1, '2016-01-30')
# 3499. ('Walker', 127, 5, '2015-03-05')
# 3500. ('Walker', 146, 1, '2013-09-06')
# 3501. ('Walker', 150, 1, '2016-11-06')
# 3502. ('Walker', 170, 5, '2016-11-06')
# 3503. ('Walker', 211, 2, '2016-11-06')
# 3504. ('Walker', 225, 2, '2015-03-05')
# 3505. ('Walker', 273, 1, '2013-09-06')
# 3506. ('Walker', 289, 2, '2015-03-05')
# 3507. ('Wall', 2, 6, '2018-09-17')
# 3508. ('Wall', 108, 1, '2015-06-11')
# 3509. ('Wall', 119, 1, '2015-06-11')
# 3510. ('Wall', 153, 2, '2015-06-11')
# 3511. ('Wall', 167, 3, '2019-06-19')
# 3512. ('Wall', 191, 2, '2018-09-17')
# 3513. ('Wall', 192, 1, '2015-01-13')
# 3514. ('Wall', 229, 1, '2019-06-19')
# 3515. ('Wall', 268, 1, '2015-01-13')
# 3516. ('Wall', 268, 2, '2019-06-19')
# 3517. ('Wall', 275, 2, '2015-01-13')
# 3518. ('Wall', 290, 3, '2018-09-17')
# 3519. ('Wallace', 158, 2, '2016-06-25')
# 3520. ('Wallace', 159, 1, '2017-09-30')
# 3521. ('Wallace', 201, 1, '2016-06-25')
# 3522. ('Walsh', 60, 3, '2015-01-05')
# 3523. ('Walsh', 268, 2, '2019-03-25')
# 3524. ('Walsh', 289, 1, '2019-02-19')
# 3525. ('Wang', 46, 1, '2014-05-19')
# 3526. ('Wang', 94, 1, '2014-05-19')
# 3527. ('Wang', 107, 1, '2018-03-31')
# 3528. ('Ward', 68, 1, '2017-11-11')
# 3529. ('Ward', 143, 2, '2017-11-02')
# 3530. ('Ward', 175, 1, '2017-11-11')
# 3531. ('Ward', 195, 1, '2017-11-02')
# 3532. ('Ward', 202, 3, '2018-09-05')
# 3533. ('Ward', 230, 3, '2018-09-05')
# 3534. ('Ward', 246, 1, '2017-11-18')
# 3535. ('Ward', 248, 1, '2018-09-05')
# 3536. ('Ward', 252, 1, '2017-11-11')
# 3537. ('Ward', 270, 1, '2017-11-18')
# 3538. ('Ward', 35, 1, '2020-05-21')
# 3539. ('Ward', 106, 3, '2020-05-21')
# 3540. ('Ward', 111, 1, '2018-09-05')
# 3541. ('Ward', 216, 3, '2018-09-05')
# 3542. ('Ward', 220, 1, '2018-09-05')
# 3543. ('Ward', 258, 1, '2020-05-21')
# 3544. ('Ward', 30, 2, '2020-06-20')
# 3545. ('Ward', 70, 1, '2020-06-20')
# 3546. ('Ward', 87, 3, '2019-01-11')
# 3547. ('Ward', 124, 1, '2020-06-20')
# 3548. ('Ware', None, None, None)
# 3549. ('Warren', 81, 1, '2018-05-02')
# 3550. ('Warren', 123, 1, '2017-07-26')
# 3551. ('Warren', 176, 1, '2018-07-14')
# 3552. ('Warren', 225, 4, '2015-11-16')
# 3553. ('Warren', 242, 1, '2015-11-16')
# 3554. ('Warren', 252, 3, '2015-11-16')
# 3555. ('Warren', 267, 2, '2018-05-02')
# 3556. ('Warren', 289, 1, '2017-07-26')
# 3557. ('Washington', 30, 1, '2019-06-07')
# 3558. ('Washington', 43, 1, '2019-06-04')
# 3559. ('Washington', 70, 4, '2019-05-22')
# 3560. ('Washington', 105, 2, '2019-06-04')
# 3561. ('Washington', 156, 1, '2019-06-06')
# 3562. ('Washington', 214, 1, '2019-05-22')
# 3563. ('Washington', 226, 1, '2019-06-07')
# 3564. ('Washington', 248, 1, '2019-05-22')
# 3565. ('Washington', 294, 1, '2019-05-22')
# 3566. ('Waters', None, None, None)
# 3567. ('Waters', 6, 1, '2020-07-03')
# 3568. ('Waters', 14, 3, '2020-07-10')
# 3569. ('Waters', 58, 3, '2020-07-03')
# 3570. ('Waters', 73, 2, '2020-04-22')
# 3571. ('Waters', 178, 2, '2020-04-22')
# 3572. ('Waters', 188, 1, '2020-07-10')
# 3573. ('Waters', 205, 1, '2020-07-03')
# 3574. ('Waters', 212, 1, '2020-07-10')
# 3575. ('Watson', 105, 1, '2019-12-20')
# 3576. ('Watson', 23, 1, '2020-02-23')
# 3577. ('Watson', 53, 1, '2020-02-23')
# 3578. ('Watson', 111, 5, '2020-02-23')
# 3579. ('Watson', 138, 2, '2020-02-23')
# 3580. ('Watson', 158, 1, '2019-10-10')
# 3581. ('Weber', 289, 2, '2017-07-01')
# 3582. ('Weber', 291, 2, '2017-07-01')
# 3583. ('Webster', 103, 2, '2019-03-30')
# 3584. ('Weiss', 52, 2, '2020-02-23')
# 3585. ('Weiss', 130, 1, '2020-02-19')
# 3586. ('Weiss', 217, 8, '2020-02-19')
# 3587. ('Welch', 247, 1, '2011-11-16')
# 3588. ('Wells', 216, 1, '2020-03-01')
# 3589. ('Werner', 29, 1, '2019-07-07')
# 3590. ('Werner', 114, 3, '2019-02-27')
# 3591. ('Werner', 139, 1, '2020-04-05')
# 3592. ('Werner', 173, 3, '2020-04-05')
# 3593. ('Werner', 51, 1, '2019-04-09')
# 3594. ('Werner', 171, 2, '2020-03-15')
# 3595. ('Werner', 206, 2, '2020-03-15')
# 3596. ('Werner', 249, 2, '2020-03-15')
# 3597. ('Werner', 256, 4, '2020-03-15')
# 3598. ('West', 60, 1, '2020-01-21')
# 3599. ('West', 129, 1, '2020-01-21')
# 3600. ('West', 145, 1, '2020-01-21')
# 3601. ('White', None, None, None)
# 3602. ('White', 41, 1, '2011-12-30')
# 3603. ('White', 51, 3, '2016-01-01')
# 3604. ('White', 55, 3, '2012-04-09')
# 3605. ('White', 109, 3, '2012-04-09')
# 3606. ('White', 159, 2, '2016-12-22')
# 3607. ('White', 197, 1, '2019-09-22')
# 3608. ('White', 277, 3, '2016-12-22')
# 3609. ('White', 46, 1, '2012-08-08')
# 3610. ('White', 221, 3, '2015-11-04')
# 3611. ('White', 139, 1, '2019-07-18')
# 3612. ('White', 281, 2, '2019-07-18')
# 3613. ('Whitney', 121, 6, '2016-03-08')
# 3614. ('Whitney', 244, 1, '2016-03-08')
# 3615. ('Whitney', 284, 1, '2018-06-11')
# 3616. ('Wilcox', 10, 1, '2019-11-22')
# 3617. ('Wilcox', 98, 1, '2017-09-08')
# 3618. ('Wilcox', 273, 2, '2019-11-22')
# 3619. ('Wiley', 33, 1, '2016-04-10')
# 3620. ('Wiley', 76, 2, '2018-02-28')
# 3621. ('Wiley', 190, 3, '2018-02-28')
# 3622. ('Wilkins', 18, 1, '2016-01-17')
# 3623. ('Wilkins', 264, 1, '2017-11-09')
# 3624. ('Wilkins', 285, 1, '2017-11-09')
# 3625. ('Wilkins', 15, 1, '2015-04-24')
# 3626. ('Wilkins', 18, 1, '2015-04-24')
# 3627. ('Wilkins', 92, 2, '2016-09-14')
# 3628. ('Wilkins', 113, 1, '2016-09-14')
# 3629. ('Wilkins', 290, 1, '2015-04-24')
# 3630. ('Williams', 45, 1, '2019-12-04')
# 3631. ('Williams', 51, 1, '2020-05-11')
# 3632. ('Williams', 97, 2, '2020-04-15')
# 3633. ('Williams', 202, 2, '2020-04-15')
# 3634. ('Williams', 225, 1, '2020-04-15')
# 3635. ('Williams', 253, 5, '2020-05-11')
# 3636. ('Williams', 15, 1, '2020-07-01')
# 3637. ('Williams', 32, 1, '2020-07-24')
# 3638. ('Williams', 69, 4, '2020-07-01')
# 3639. ('Williams', 79, 2, '2020-07-01')
# 3640. ('Williams', 153, 1, '2019-03-01')
# 3641. ('Williams', 119, 3, '2011-08-18')
# 3642. ('Williams', 171, 2, '2014-05-16')
# 3643. ('Williams', 271, 1, '2014-05-16')
# 3644. ('Williams', 47, 2, '2019-04-27')
# 3645. ('Williams', 72, 3, '2019-04-27')
# 3646. ('Williams', 75, 3, '2019-04-27')
# 3647. ('Williams', 87, 1, '2020-04-10')
# 3648. ('Williams', 110, 1, '2019-06-26')
# 3649. ('Williams', 178, 2, '2019-04-27')
# 3650. ('Williams', 294, 1, '2019-06-26')
# 3651. ('Williams', 64, 1, '2015-09-13')
# 3652. ('Williams', 221, 4, '2015-09-13')
# 3653. ('Williams', None, None, None)
# 3654. ('Williams', 49, 1, '2019-06-16')
# 3655. ('Williams', 55, 1, '2014-12-05')
# 3656. ('Williams', 129, 2, '2013-08-24')
# 3657. ('Williams', 62, 5, '2020-07-26')
# 3658. ('Williams', 276, 1, '2020-07-26')
# 3659. ('Williams', None, None, None)
# 3660. ('Williams', 12, 2, '2018-09-11')
# 3661. ('Williams', 30, 1, '2019-08-14')
# 3662. ('Williams', 158, 3, '2017-04-02')
# 3663. ('Williams', 260, 1, '2017-04-02')
# 3664. ('Williams', 271, 3, '2017-04-02')
# 3665. ('Williamson', 120, 1, '2019-09-19')
# 3666. ('Williamson', 150, 1, '2019-09-19')
# 3667. ('Williamson', 170, 2, '2016-08-07')
# 3668. ('Wilson', 36, 1, '2015-05-18')
# 3669. ('Wilson', 108, 1, '2015-02-24')
# 3670. ('Wilson', 180, 1, '2014-07-13')
# 3671. ('Wilson', 233, 2, '2015-02-24')
# 3672. ('Wilson', 242, 2, '2016-02-10')
# 3673. ('Wilson', 244, 2, '2014-03-16')
# 3674. ('Wilson', 42, 1, '2020-01-20')
# 3675. ('Wilson', 50, 1, '2020-01-20')
# 3676. ('Wilson', 214, 1, '2020-01-20')
# 3677. ('Wilson', 292, 1, '2020-01-20')
# 3678. ('Wilson', 72, 1, '2015-01-05')
# 3679. ('Wilson', 114, 2, '2014-09-21')
# 3680. ('Wilson', 155, 2, '2015-01-05')
# 3681. ('Wilson', 289, 2, '2015-01-05')
# 3682. ('Wilson', 1, 1, '2013-11-06')
# 3683. ('Wilson', 6, 3, '2018-01-11')
# 3684. ('Wilson', 34, 3, '2015-10-29')
# 3685. ('Wilson', 76, 1, '2013-04-03')
# 3686. ('Wilson', 147, 1, '2015-10-29')
# 3687. ('Wilson', 162, 2, '2013-11-06')
# 3688. ('Wilson', 209, 2, '2015-10-29')
# 3689. ('Wilson', None, None, None)
# 3690. ('Wilson', 3, 2, '2018-01-30')
# 3691. ('Wilson', 14, 2, '2019-08-02')
# 3692. ('Wilson', 52, 1, '2019-08-02')
# 3693. ('Wilson', 92, 3, '2017-09-30')
# 3694. ('Wilson', 102, 1, '2017-06-10')
# 3695. ('Wilson', 104, 1, '2019-08-02')
# 3696. ('Wilson', 104, 2, '2018-01-30')
# 3697. ('Wilson', 110, 1, '2018-03-04')
# 3698. ('Wilson', 113, 1, '2018-03-04')
# 3699. ('Wilson', 114, 2, '2019-08-05')
# 3700. ('Wilson', 148, 1, '2017-09-30')
# 3701. ('Wilson', 151, 1, '2017-06-10')
# 3702. ('Wilson', 195, 1, '2019-08-02')
# 3703. ('Wilson', 202, 3, '2018-03-04')
# 3704. ('Wilson', 216, 2, '2018-03-04')
# 3705. ('Wilson', 222, 1, '2018-01-30')
# 3706. ('Wilson', 68, 2, '2013-05-02')
# 3707. ('Wilson', 97, 2, '2017-05-23')
# 3708. ('Wilson', 187, 2, '2015-08-05')
# 3709. ('Wilson', 202, 1, '2015-08-05')
# 3710. ('Wilson', 244, 2, '2013-05-02')
# 3711. ('Wilson', 86, 1, '2019-09-08')
# 3712. ('Wilson', 91, 1, '2016-08-24')
# 3713. ('Wilson', 165, 1, '2015-10-16')
# 3714. ('Wilson', 4, 1, '2020-06-04')
# 3715. ('Wilson', 12, 2, '2012-11-05')
# 3716. ('Wilson', 30, 1, '2015-03-22')
# 3717. ('Wilson', 107, 3, '2012-11-09')
# 3718. ('Wilson', 118, 1, '2012-11-09')
# 3719. ('Wilson', 155, 2, '2015-03-22')
# 3720. ('Wilson', 211, 1, '2012-11-09')
# 3721. ('Wilson', 225, 1, '2020-06-04')
# 3722. ('Wilson', 241, 1, '2012-11-05')
# 3723. ('Wise', 16, 1, '2013-04-15')
# 3724. ('Wise', 95, 1, '2018-06-23')
# 3725. ('Wise', 185, 3, '2018-06-23')
# 3726. ('Wolf', 58, 1, '2019-12-03')
# 3727. ('Wolf', 132, 1, '2020-03-08')
# 3728. ('Wolf', 158, 2, '2018-04-13')
# 3729. ('Wolf', 205, 3, '2011-04-08')
# 3730. ('Wolf', 210, 1, '2020-03-08')
# 3731. ('Wong', 35, 4, '2020-01-17')
# 3732. ('Wong', 42, 1, '2020-01-17')
# 3733. ('Wong', 131, 1, '2018-11-23')
# 3734. ('Wong', 175, 2, '2020-01-17')
# 3735. ('Wong', 211, 2, '2020-01-17')
# 3736. ('Wong', 235, 1, '2020-01-17')
# 3737. ('Wong', 261, 1, '2018-11-23')
# 3738. ('Wood', 34, 1, '2019-11-02')
# 3739. ('Wood', 212, 1, '2020-03-28')
# 3740. ('Wood', 236, 5, '2019-11-02')
# 3741. ('Wood', 287, 1, '2019-11-02')
# 3742. ('Woodard', 98, 1, '2019-04-13')
# 3743. ('Woodard', 116, 1, '2019-04-13')
# 3744. ('Woodard', 199, 1, '2019-08-26')
# 3745. ('Woodard', 230, 3, '2019-04-13')
# 3746. ('Woodard', 250, 3, '2019-08-26')
# 3747. ('Woodard', 277, 2, '2019-08-26')
# 3748. ('Woods', 101, 2, '2019-04-25')
# 3749. ('Woods', 143, 2, '2019-04-25')
# 3750. ('Wright', 5, 3, '2020-06-07')
# 3751. ('Wright', 162, 1, '2020-05-24')
# 3752. ('Wright', 183, 1, '2020-05-20')
# 3753. ('Wright', 259, 1, '2020-05-24')
# 3754. ('Wright', 290, 2, '2020-05-20')
# 3755. ('Wright', 51, 1, '2019-07-20')
# 3756. ('Wright', 62, 2, '2019-07-20')
# 3757. ('Wright', 161, 1, '2019-07-20')
# 3758. ('Wright', 184, 1, '2019-06-25')
# 3759. ('Wright', 204, 2, '2019-06-25')
# 3760. ('Wright', 208, 1, '2019-07-20')
# 3761. ('Wright', 286, 2, '2020-07-03')
# 3762. ('Wright', 126, 3, '2019-10-28')
# 3763. ('Wright', 140, 2, '2019-10-28')
# 3764. ('Wright', None, None, None)
# 3765. ('Wright', None, None, None)
# 3766. ('Wright', 5, 2, '2019-08-25')
# 3767. ('Wright', 42, 1, '2019-08-25')
# 3768. ('Wright', 82, 1, '2019-08-25')
# 3769. ('Wright', 175, 1, '2014-11-13')
# 3770. ('Wright', 242, 1, '2015-02-11')
# 3771. ('Wright', 251, 1, '2019-08-25')
# 3772. ('Wright', 184, 1, '2020-03-01')
# 3773. ('Wright', 245, 1, '2020-03-01')
# 3774. ('Wright', 272, 1, '2018-07-30')
# 3775. ('Yang', 113, 3, '2019-05-16')
# 3776. ('Yang', 139, 1, '2019-05-16')
# 3777. ('Yang', 50, 4, '2020-04-27')
# 3778. ('Yang', 99, 2, '2020-07-11')
# 3779. ('Yang', 125, 2, '2018-06-07')
# 3780. ('Yang', 183, 5, '2017-06-01')
# 3781. ('York', 107, 1, '2020-07-24')
# 3782. ('York', 223, 2, '2020-07-24')
# 3783. ('York', 265, 3, '2020-07-24')
# 3784. ('Young', 138, 1, '2020-03-23')
# 3785. ('Young', 176, 1, '2020-03-23')
# 3786. ('Young', 194, 2, '2020-03-23')
# 3787. ('Young', 100, 1, '2016-05-30')
# 3788. ('Young', 125, 2, '2016-05-30')
# 3789. ('Young', 148, 1, '2017-09-01')
# 3790. ('Young', 159, 1, '2012-05-17')
# 3791. ('Young', 203, 2, '2017-09-01')
# 3792. ('Young', 274, 1, '2017-09-01')
# 3793. ('Young', 275, 2, '2012-05-17')
# 3794. ('Young', 25, 1, '2018-02-15')
# 3795. ('Young', 37, 1, '2014-06-14')
# 3796. ('Young', 72, 2, '2018-02-15')
# 3797. ('Young', 155, 1, '2016-10-02')
# 3798. ('Young', 183, 1, '2012-09-01')
# 3799. ('Young', 264, 3, '2013-06-14')
# 3800. ('Young', 11, 1, '2016-12-15')
# 3801. ('Young', 62, 1, '2016-04-29')
# 3802. ('Young', 94, 2, '2017-05-30')
# 3803. ('Young', 132, 1, '2016-12-15')
# 3804. ('Young', 149, 1, '2017-09-24')
# 3805. ('Young', 156, 1, '2016-12-15')
# 3806. ('Young', 263, 5, '2017-09-24')
# 3807. ('Young', 289, 1, '2017-09-24')
# 3808. ('Young', 196, 1, '2019-09-05')
# 3809. ('Young', 203, 4, '2019-09-25')
# 3810. ('Zavala', 38, 1, '2019-04-28')
# 3811. ('Zavala', 49, 4, '2018-07-23')
# 3812. ('Zavala', 75, 3, '2020-06-10')
# 3813. ('Zavala', 107, 1, '2019-04-28')
# 3814. ('Zavala', 123, 1, '2018-04-29')
# 3815. ('Zavala', 137, 1, '2019-04-28')
# 3816. ('Zavala', 157, 1, '2019-03-19')
# 3817. ('Zavala', 174, 2, '2018-07-23')
# 3818. ('Zavala', 225, 1, '2019-04-28')
# 3819. ('Zavala', 237, 1, '2020-06-10')
# 3820. ('Zavala', 247, 1, '2020-06-10')
# 3821. ('Zavala', 250, 1, '2019-03-19')
# 3822. ('Zavala', 257, 2, '2018-04-29')
# 3823. ('Zhang', 42, 2, '2017-10-25')
# 3824. ('Zhang', 124, 1, '2014-11-06')
# 3825. ('Zhang', 155, 1, '2018-08-09')
# 3826. ('Zhang', 173, 2, '2018-08-09')
# 3827. ('Zhang', 213, 1, '2016-11-06')
# 3828. ('Zhang', 218, 5, '2018-08-09')
# 3829. ('Zhang', 227, 1, '2014-11-06')
# 3830. ('Zhang', 251, 4, '2014-11-06')
# 3831. ('Zhang', 288, 1, '2016-11-06')

# %% [markdown]
# After `SELECT` we can also use math operations on the columns.

# %%
query = '''
SELECT InvoiceNumber, StockCode, Quantity, UnitPrice, Quantity*UnitPrice as Total,  CustomerID
FROM Sales as s
INNER JOIN Products as p
    ON s.ProductId = p.ProductId
ORDER BY InvoiceNumber DESC
'''
execute_query(conn,query)
# Out:
# 1. ('202007318518', 'UT900480', 1, 23.45, 23.45, 932)
# 2. ('202007318518', 'OX204742', 1, 29.47, 29.47, 932)
# 3. ('202007313404', 'LF434461', 2, 27.01, 54.02, 916)
# 4. ('202007308826', 'RM419830', 2, 6.81, 13.62, 258)
# 5. ('202007299565', 'OX806183', 5, 21.45, 107.25, 968)
# 6. ('202007299565', 'JO827398', 4, 28.04, 112.16, 968)
# 7. ('202007299565', 'YN760953', 1, 26.58, 26.58, 968)
# 8. ('202007297766', 'LJ294158', 2, 41.37, 82.74, 114)
# 9. ('202007294555', 'CD076891', 1, 21.27, 21.27, 714)
# 10. ('202007294542', 'RM419830', 3, 6.81, 20.43, 404)
# 11. ('202007281061', 'VB192908', 1, 51.11, 51.11, 449)
# 12. ('202007280236', 'XJ792088', 1, 48.33, 48.33, 237)
# 13. ('202007273674', 'EB831613', 2, 12.31, 24.62, 676)
# 14. ('202007273674', 'NG216735', 1, 17.9, 17.9, 676)
# 15. ('202007268734', 'OO406570', 5, 28.87, 144.35, 850)
# 16. ('202007268734', 'KA323284', 1, 32.15, 32.15, 850)
# 17. ('202007262544', 'AQ988179', 3, 63.67, 191.01, 829)
# 18. ('202007262544', 'XX748942', 2, 16.46, 32.92, 829)
# 19. ('202007258439', 'ZI822433', 3, 18.94, 56.82000000000001, 1010)
# 20. ('202007255601', 'HQ425265', 2, 16.26, 32.52, 575)
# 21. ('202007255381', 'HA066493', 1, 3.2, 3.2, 578)
# 22. ('202007252501', 'LJ294158', 4, 41.37, 165.48, 916)
# 23. ('202007251645', 'RA538031', 1, 5.4, 5.4, 1027)
# 24. ('202007251645', 'VF775370', 1, 32.69, 32.69, 1027)
# 25. ('202007250710', 'WV650733', 2, 63.68, 127.36, 961)
# 26. ('202007249787', 'YG769767', 2, 12.62, 25.24, 584)
# 27. ('202007249787', 'BS032705', 1, 6.1, 6.1, 584)
# 28. ('202007249787', 'GC440805', 1, 28.6, 28.6, 584)
# 29. ('202007249539', 'NE964215', 1, 66.94, 66.94, 124)
# 30. ('202007248975', 'FQ556732', 1, 7.95, 7.95, 377)
# 31. ('202007248975', 'UJ972892', 3, 16.24, 48.72, 377)
# 32. ('202007248975', 'OX806183', 2, 21.45, 42.9, 377)
# 33. ('202007245657', 'UC279555', 2, 71.91, 143.82, 65)
# 34. ('202007245657', 'TM009651', 1, 17.47, 17.47, 65)
# 35. ('202007245657', 'GX613685', 4, 18.43, 73.72, 65)
# 36. ('202007244707', 'ZV140874', 1, 11.91, 11.91, 143)
# 37. ('202007244707', 'FZ085947', 4, 4.93, 19.72, 143)
# 38. ('202007232923', 'OY272975', 1, 43.44, 43.44, 237)
# 39. ('202007231171', 'YL369550', 1, 10.7, 10.7, 125)
# 40. ('202007231171', 'BS032705', 1, 6.1, 6.1, 125)
# 41. ('202007230558', 'DD186136', 1, 66.25, 66.25, 160)
# 42. ('202007225821', 'NP860944', 2, 5.38, 10.76, 1013)
# 43. ('202007225821', 'EZ069281', 9, 6.31, 56.79, 1013)
# 44. ('202007222945', 'AO024006', 3, 13.89, 41.67, 123)
# 45. ('202007222110', 'KV699707', 1, 49.79, 49.79, 599)
# 46. ('202007217628', 'YN760953', 2, 26.58, 53.16, 633)
# 47. ('202007213418', 'RD191959', 1, 11.31, 11.31, 903)
# 48. ('202007212491', 'LU401786', 1, 34.86, 34.86, 578)
# 49. ('202007212491', 'AI615521', 2, 4.84, 9.68, 578)
# 50. ('202007211739', 'FZ737978', 1, 46.75, 46.75, 815)
# 51. ('202007211739', 'UQ424073', 1, 40.07, 40.07, 815)
# 52. ('202007209497', 'YU673093', 3, 36.96, 110.88, 664)
# 53. ('202007209497', 'QD294233', 1, 65.15, 65.15, 664)
# 54. ('202007206851', 'SX937912', 4, 6.61, 26.44, 714)
# 55. ('202007206851', 'LC861690', 1, 7.04, 7.04, 714)
# 56. ('202007206567', 'AO024006', 1, 13.89, 13.89, 1017)
# 57. ('202007206567', 'DE471836', 1, 6.7, 6.7, 1017)
# 58. ('202007205254', 'KW929922', 1, 26.68, 26.68, 853)
# 59. ('202007202679', 'TS648442', 2, 42.39, 84.78, 636)
# 60. ('202007199989', 'WE738312', 1, 26.31, 26.31, 268)
# 61. ('202007197898', 'RA538031', 5, 5.4, 27.0, 219)
# 62. ('202007197898', 'GX613685', 1, 18.43, 18.43, 219)
# 63. ('202007196788', 'JS961877', 1, 31.65, 31.65, 99)
# 64. ('202007196788', 'FF356985', 1, 8.56, 8.56, 99)
# 65. ('202007182275', 'LB821460', 5, 4.4, 22.0, 446)
# 66. ('202007182083', 'CJ333649', 1, 25.14, 25.14, 621)
# 67. ('202007182083', 'UA292126', 1, 10.9, 10.9, 621)
# 68. ('202007180568', 'JX098323', 7, 24.57, 171.99, 275)
# 69. ('202007180568', 'OX788607', 1, 7.47, 7.47, 275)
# 70. ('202007180568', 'BO582054', 1, 15.12, 15.12, 275)
# 71. ('202007177210', 'ZH081916', 8, 4.32, 34.56, 842)
# 72. ('202007175351', 'JD727657', 2, 40.92, 81.84, 842)
# 73. ('202007172641', 'KM304818', 5, 10.33, 51.65, 123)
# 74. ('202007172641', 'KY392005', 1, 30.51, 30.51, 123)
# 75. ('202007168508', 'DU573649', 2, 11.1, 22.2, 569)
# 76. ('202007168508', 'XO016727', 2, 13.31, 26.62, 569)
# 77. ('202007161571', 'LU401786', 2, 34.86, 69.72, 114)
# 78. ('202007161571', 'JC512163', 1, 27.67, 27.67, 114)
# 79. ('202007152900', 'JR035990', 1, 10.02, 10.02, 96)
# 80. ('202007150852', 'NL501111', 3, 12.5, 37.5, 461)
# 81. ('202007149216', 'KW929922', 1, 26.68, 26.68, 682)
# 82. ('202007149216', 'TL163767', 3, 21.22, 63.66, 682)
# 83. ('202007149216', 'CG652842', 2, 35.77, 71.54, 682)
# 84. ('202007149216', 'FT255177', 2, 4.09, 8.18, 682)
# 85. ('202007144258', 'VZ240168', 4, 31.27, 125.08, 42)
# 86. ('202007144258', 'YQ556750', 1, 12.84, 12.84, 42)
# 87. ('202007142772', 'YJ878305', 3, 117.55, 352.65, 293)
# 88. ('202007142574', 'CW815585', 1, 4.36, 4.36, 808)
# 89. ('202007142574', 'MK751094', 1, 21.96, 21.96, 808)
# 90. ('202007142574', 'RM419830', 1, 6.81, 6.81, 808)
# 91. ('202007141526', 'OP332924', 6, 5.83, 34.980000000000004, 122)
# 92. ('202007141368', 'JB911266', 1, 9.51, 9.51, 694)
# 93. ('202007141368', 'YU109630', 1, 14.06, 14.06, 694)
# 94. ('202007141368', 'CP824418', 1, 7.83, 7.83, 694)
# 95. ('202007141368', 'CE099815', 2, 18.25, 36.5, 694)
# 96. ('202007139876', 'FO303231', 1, 17.98, 17.98, 382)
# 97. ('202007139876', 'BS032705', 1, 6.1, 6.1, 382)
# 98. ('202007139876', 'UX197382', 1, 11.3, 11.3, 382)
# 99. ('202007137512', 'HA066493', 1, 3.2, 3.2, 578)
# 100. ('202007133557', 'DK020939', 1, 8.66, 8.66, 664)
# 101. ('202007133367', 'AQ988179', 2, 63.67, 127.34, 425)
# 102. ('202007133367', 'JF581322', 2, 5.33, 10.66, 425)
# 103. ('202007130601', 'AL225388', 4, 14.35, 57.4, 314)
# 104. ('202007130601', 'PP034234', 1, 47.77, 47.77, 314)
# 105. ('202007130474', 'ZO921517', 2, 3.29, 6.58, 97)
# 106. ('202007130474', 'NE964215', 1, 66.94, 66.94, 97)
# 107. ('202007130474', 'YN760953', 1, 26.58, 26.58, 97)
# 108. ('202007130474', 'JF581322', 4, 5.33, 21.32, 97)
# 109. ('202007125317', 'HQ425265', 4, 16.26, 65.04, 364)
# 110. ('202007124979', 'CG652842', 1, 35.77, 35.77, 329)
# 111. ('202007124979', 'YD328076', 1, 41.13, 41.13, 329)
# 112. ('202007123869', 'OX204742', 1, 29.47, 29.47, 663)
# 113. ('202007123869', 'WV168813', 3, 55.86, 167.57999999999998, 663)
# 114. ('202007123869', 'TQ259905', 2, 14.15, 28.3, 663)
# 115. ('202007123869', 'MJ886801', 1, 28.01, 28.01, 663)
# 116. ('202007123869', 'QI533440', 4, 7.55, 30.2, 663)
# 117. ('202007123869', 'AQ988179', 1, 63.67, 63.67, 663)
# 118. ('202007123869', 'JA112745', 1, 20.51, 20.51, 663)
# 119. ('202007119438', 'AD147234', 1, 7.96, 7.96, 769)
# 120. ('202007116835', 'GW633161', 2, 15.57, 31.14, 1005)
# 121. ('202007116204', 'GK840157', 3, 13.79, 41.37, 842)
# 122. ('202007110630', 'SW676612', 3, 7.64, 22.919999999999998, 604)
# 123. ('202007110150', 'QE695574', 1, 6.38, 6.38, 733)
# 124. ('202007109084', 'AQ568530', 2, 52.29, 104.58, 720)
# 125. ('202007109084', 'PP034234', 2, 47.77, 95.54, 720)
# 126. ('202007105812', 'HJ601860', 2, 20.54, 41.08, 33)
# 127. ('202007105645', 'VY330668', 1, 5.84, 5.84, 438)
# 128. ('202007104285', 'YU109630', 3, 14.06, 42.18, 738)
# 129. ('202007104285', 'YH733279', 1, 30.06, 30.06, 738)
# 130. ('202007104143', 'JB911266', 3, 9.51, 28.53, 673)
# 131. ('202007104143', 'YW570301', 1, 4.17, 4.17, 673)
# 132. ('202007104143', 'JX098323', 1, 24.57, 24.57, 673)
# 133. ('202007103056', 'OL316261', 1, 13.13, 13.13, 857)
# 134. ('202007103056', 'WQ703593', 1, 29.25, 29.25, 857)
# 135. ('202007103056', 'LZ422758', 1, 7.82, 7.82, 857)
# 136. ('202007101858', 'ZQ867971', 1, 38.59, 38.59, 92)
# 137. ('202007101858', 'CK640266', 1, 3.64, 3.64, 92)
# 138. ('202007096602', 'JK094728', 1, 41.77, 41.77, 693)
# 139. ('202007096602', 'LF083741', 1, 3.87, 3.87, 693)
# 140. ('202007096403', 'TF006345', 2, 21.97, 43.94, 578)
# 141. ('202007095856', 'KT586465', 1, 22.43, 22.43, 43)
# 142. ('202007091926', 'KA428279', 3, 51.29, 153.87, 163)
# 143. ('202007088469', 'NJ458404', 1, 13.53, 13.53, 138)
# 144. ('202007088469', 'WV650733', 2, 63.68, 127.36, 138)
# 145. ('202007086915', 'KY358900', 1, 16.86, 16.86, 1034)
# 146. ('202007086915', 'BO582054', 3, 15.12, 45.36, 1034)
# 147. ('202007086915', 'XW869039', 1, 34.07, 34.07, 1034)
# 148. ('202007071280', 'UQ424073', 3, 40.07, 120.21000000000001, 578)
# 149. ('202007071280', 'LF545577', 2, 5.86, 11.72, 578)
# 150. ('202007071280', 'WF819044', 1, 16.09, 16.09, 578)
# 151. ('202007069224', 'LF545577', 1, 5.86, 5.86, 428)
# 152. ('202007069224', 'EI482226', 7, 6.67, 46.69, 428)
# 153. ('202007069224', 'EM133279', 1, 29.9, 29.9, 428)
# 154. ('202007065883', 'JX098323', 1, 24.57, 24.57, 178)
# 155. ('202007065883', 'XS324415', 6, 17.99, 107.94, 178)
# 156. ('202007062373', 'EA810505', 1, 12.38, 12.38, 123)
# 157. ('202007060369', 'NX789105', 1, 6.94, 6.94, 910)
# 158. ('202007058764', 'UA292126', 2, 10.9, 21.8, 282)
# 159. ('202007058764', 'TU924951', 2, 68.11, 136.22, 282)
# 160. ('202007058764', 'RP922292', 2, 14.96, 29.92, 282)
# 161. ('202007056363', 'NL501111', 1, 12.5, 12.5, 111)
# 162. ('202007049995', 'TS648442', 1, 42.39, 42.39, 909)
# 163. ('202007049951', 'SI669053', 1, 24.3, 24.3, 42)
# 164. ('202007049951', 'OD552225', 3, 13.14, 39.42, 42)
# 165. ('202007049951', 'WF268546', 1, 6.64, 6.64, 42)
# 166. ('202007048589', 'JF581322', 1, 5.33, 5.33, 333)
# 167. ('202007048589', 'EV047882', 1, 14.1, 14.1, 333)
# 168. ('202007048589', 'UA292126', 1, 10.9, 10.9, 333)
# 169. ('202007042151', 'RL366039', 1, 12.57, 12.57, 412)
# 170. ('202007040638', 'CS929072', 1, 38.79, 38.79, 816)
# 171. ('202007038069', 'VA491621', 1, 20.23, 20.23, 161)
# 172. ('202007036709', 'UQ607814', 1, 32.85, 32.85, 494)
# 173. ('202007036709', 'AV205156', 2, 20.04, 40.08, 494)
# 174. ('202007036580', 'WV168813', 4, 55.86, 223.44, 714)
# 175. ('202007035875', 'UX197382', 1, 11.3, 11.3, 673)
# 176. ('202007035875', 'SP542412', 1, 11.52, 11.52, 673)
# 177. ('202007035875', 'DS853019', 3, 8.46, 25.380000000000003, 673)
# 178. ('202007034423', 'EV047882', 2, 14.1, 28.2, 126)
# 179. ('202007033843', 'BS032705', 3, 6.1, 18.299999999999997, 96)
# 180. ('202007033843', 'KY392005', 1, 30.51, 30.51, 96)
# 181. ('202007030742', 'UP489523', 3, 12.11, 36.33, 333)
# 182. ('202007030562', 'EA810505', 1, 12.38, 12.38, 457)
# 183. ('202007030562', 'RP922292', 1, 14.96, 14.96, 457)
# 184. ('202007018749', 'ZQ525720', 4, 5.99, 23.96, 124)
# 185. ('202007018749', 'FO303231', 2, 17.98, 35.96, 124)
# 186. ('202007018749', 'DD010283', 1, 14.84, 14.84, 124)
# 187. ('202007012535', 'JS961877', 1, 31.65, 31.65, 99)
# 188. ('202007012535', 'VP150049', 1, 59.13, 59.13, 99)
# 189. ('202007012535', 'GW633161', 3, 15.57, 46.71, 99)
# 190. ('202007011495', 'DS853019', 2, 8.46, 16.92, 404)
# 191. ('202007010040', 'ST643511', 1, 91.76, 91.76, 1024)
# 192. ('202006309467', 'UQ607814', 2, 32.85, 65.7, 348)
# 193. ('202006305177', 'GW633161', 3, 15.57, 46.71, 714)
# 194. ('202006304388', 'GK840157', 2, 13.79, 27.58, 80)
# 195. ('202006304388', 'KG005760', 1, 14.74, 14.74, 80)
# 196. ('202006304388', 'XF963575', 1, 12.03, 12.03, 80)
# 197. ('202006301849', 'GK060340', 2, 55.28, 110.56, 33)
# 198. ('202006301849', 'ZI705132', 1, 39.56, 39.56, 33)
# 199. ('202006296397', 'UT900480', 1, 23.45, 23.45, 955)
# 200. ('202006284544', 'HJ467356', 2, 3.24, 6.48, 99)
# 201. ('202006283360', 'JB911266', 2, 9.51, 19.02, 837)
# 202. ('202006277436', 'KM304818', 1, 10.33, 10.33, 485)
# 203. ('202006277436', 'WQ703593', 2, 29.25, 58.5, 485)
# 204. ('202006277436', 'ZO985810', 5, 23.21, 116.05000000000001, 485)
# 205. ('202006277436', 'IK042267', 5, 28.23, 141.15, 485)
# 206. ('202006270631', 'YW570301', 1, 4.17, 4.17, 94)
# 207. ('202006270631', 'ZI822433', 1, 18.94, 18.94, 94)
# 208. ('202006264771', 'NM894102', 2, 22.39, 44.78, 935)
# 209. ('202006258908', 'YR014674', 2, 22.11, 44.22, 271)
# 210. ('202006258908', 'TL163767', 1, 21.22, 21.22, 271)
# 211. ('202006253747', 'BO582054', 1, 15.12, 15.12, 18)
# 212. ('202006247055', 'CP824418', 1, 7.83, 7.83, 236)
# 213. ('202006247055', 'FW407914', 2, 35.48, 70.96, 236)
# 214. ('202006247055', 'AD147234', 1, 7.96, 7.96, 236)
# 215. ('202006245329', 'YH733279', 1, 30.06, 30.06, 322)
# 216. ('202006245329', 'OA710158', 3, 8.36, 25.08, 322)
# 217. ('202006242747', 'HR920743', 4, 24.09, 96.36, 123)
# 218. ('202006240419', 'XG335214', 3, 21.77, 65.31, 502)
# 219. ('202006235192', 'GV361474', 1, 28.81, 28.81, 844)
# 220. ('202006233215', 'JK094728', 1, 41.77, 41.77, 860)
# 221. ('202006231438', 'NG216735', 1, 17.9, 17.9, 961)
# 222. ('202006231438', 'VA564814', 3, 38.79, 116.37, 961)
# 223. ('202006219457', 'AT619585', 3, 13.8, 41.400000000000006, 96)
# 224. ('202006219457', 'BO582054', 1, 15.12, 15.12, 96)
# 225. ('202006219457', 'LG560010', 1, 3.59, 3.59, 96)
# 226. ('202006216339', 'VY330668', 1, 5.84, 5.84, 454)
# 227. ('202006215083', 'TT401653', 1, 35.02, 35.02, 758)
# 228. ('202006212482', 'TS648442', 1, 42.39, 42.39, 975)
# 229. ('202006207049', 'IP543128', 2, 8.05, 16.1, 484)
# 230. ('202006207049', 'RC174600', 1, 22.25, 22.25, 484)
# 231. ('202006207049', 'QD658920', 1, 23.3, 23.3, 484)
# 232. ('202006206041', 'AT619585', 1, 13.8, 13.8, 51)
# 233. ('202006204422', 'UC279555', 1, 71.91, 71.91, 871)
# 234. ('202006204422', 'FS143237', 1, 19.03, 19.03, 871)
# 235. ('202006204422', 'YJ878305', 2, 117.55, 235.1, 871)
# 236. ('202006199389', 'RM101832', 1, 51.85, 51.85, 824)
# 237. ('202006197067', 'SJ372509', 2, 71.86, 143.72, 138)
# 238. ('202006197067', 'FK759406', 1, 11.04, 11.04, 138)
# 239. ('202006186846', 'IJ186457', 4, 5.77, 23.08, 104)
# 240. ('202006186846', 'ZI637174', 1, 45.75, 45.75, 104)
# 241. ('202006186846', 'CJ333649', 1, 25.14, 25.14, 104)
# 242. ('202006185764', 'DF577320', 2, 71.62, 143.24, 156)
# 243. ('202006185764', 'RE313887', 2, 12.78, 25.56, 156)
# 244. ('202006183729', 'TM009651', 1, 17.47, 17.47, 33)
# 245. ('202006180481', 'VX764028', 1, 4.82, 4.82, 311)
# 246. ('202006173207', 'WC075791', 7, 10.13, 70.91000000000001, 241)
# 247. ('202006173207', 'LG977007', 1, 12.91, 12.91, 241)
# 248. ('202006173207', 'JR035990', 1, 10.02, 10.02, 241)
# 249. ('202006168943', 'UJ199198', 1, 5.51, 5.51, 282)
# 250. ('202006168943', 'UJ199198', 6, 5.51, 33.06, 282)
# 251. ('202006166054', 'RL679581', 5, 6.08, 30.4, 443)
# 252. ('202006164409', 'HL053400', 1, 28.73, 28.73, 1027)
# 253. ('202006160206', 'FS589147', 2, 38.16, 76.32, 813)
# 254. ('202006148560', 'KA323284', 1, 32.15, 32.15, 404)
# 255. ('202006148318', 'EW850027', 2, 22.77, 45.54, 560)
# 256. ('202006148318', 'OX204742', 4, 29.47, 117.88, 560)
# 257. ('202006137367', 'IP543128', 1, 8.05, 8.05, 982)
# 258. ('202006136706', 'FS143237', 1, 19.03, 19.03, 741)
# 259. ('202006136706', 'JS961877', 1, 31.65, 31.65, 741)
# 260. ('202006136706', 'YU673093', 1, 36.96, 36.96, 741)
# 261. ('202006136706', 'FS589147', 1, 38.16, 38.16, 741)
# 262. ('202006136667', 'KB827835', 1, 5.54, 5.54, 694)
# 263. ('202006136667', 'WV650733', 2, 63.68, 127.36, 694)
# 264. ('202006136667', 'NW176696', 1, 19.43, 19.43, 694)
# 265. ('202006128474', 'BA037508', 1, 45.46, 45.46, 569)
# 266. ('202006128474', 'EH407549', 1, 43.84, 43.84, 569)
# 267. ('202006126957', 'UL776281', 1, 16.75, 16.75, 508)
# 268. ('202006123868', 'LC861690', 1, 7.04, 7.04, 910)
# 269. ('202006123664', 'SL591725', 5, 19.35, 96.75, 99)
# 270. ('202006123057', 'DK020939', 1, 8.66, 8.66, 209)
# 271. ('202006122563', 'UY300722', 3, 22.31, 66.92999999999999, 899)
# 272. ('202006121446', 'YU109630', 1, 14.06, 14.06, 322)
# 273. ('202006116679', 'GK060340', 2, 55.28, 110.56, 374)
# 274. ('202006116679', 'DK720585', 5, 17.12, 85.60000000000001, 374)
# 275. ('202006113266', 'NE964215', 2, 66.94, 133.88, 560)
# 276. ('202006108057', 'FN667308', 3, 5.14, 15.419999999999998, 84)
# 277. ('202006108057', 'LZ422758', 3, 7.82, 23.46, 84)
# 278. ('202006108057', 'DU573649', 2, 11.1, 22.2, 84)
# 279. ('202006105081', 'SL591725', 1, 19.35, 19.35, 453)
# 280. ('202006105081', 'HL156494', 2, 32.17, 64.34, 453)
# 281. ('202006103821', 'WE981088', 1, 5.55, 5.55, 710)
# 282. ('202006103821', 'LC861690', 3, 7.04, 21.12, 710)
# 283. ('202006103821', 'YO288069', 1, 27.48, 27.48, 710)
# 284. ('202006096709', 'RM419830', 7, 6.81, 47.669999999999995, 102)
# 285. ('202006092552', 'FZ737978', 1, 46.75, 46.75, 633)
# 286. ('202006092552', 'HJ601860', 2, 20.54, 41.08, 633)
# 287. ('202006092552', 'TX377293', 3, 32.34, 97.02000000000001, 633)
# 288. ('202006091286', 'GV361474', 2, 28.81, 57.62, 633)
# 289. ('202006090242', 'LC861690', 3, 7.04, 21.12, 591)
# 290. ('202006088793', 'HR412275', 1, 16.32, 16.32, 160)
# 291. ('202006084705', 'RD191959', 3, 11.31, 33.93, 15)
# 292. ('202006083967', 'UA292126', 4, 10.9, 43.6, 992)
# 293. ('202006083967', 'YU673093', 1, 36.96, 36.96, 992)
# 294. ('202006083951', 'ZO921517', 2, 3.29, 6.58, 209)
# 295. ('202006083951', 'GV361474', 1, 28.81, 28.81, 209)
# 296. ('202006078958', 'VA491621', 3, 20.23, 60.69, 103)
# 297. ('202006078221', 'VF775370', 1, 32.69, 32.69, 214)
# 298. ('202006078221', 'ZI637174', 1, 45.75, 45.75, 214)
# 299. ('202006071124', 'OX204742', 1, 29.47, 29.47, 997)
# 300. ('202006069604', 'UH907011', 1, 3.17, 3.17, 815)
# 301. ('202006069604', 'ZQ867971', 3, 38.59, 115.77000000000001, 815)
# 302. ('202006068057', 'WF819044', 2, 16.09, 32.18, 807)
# 303. ('202006064930', 'DK020939', 2, 8.66, 17.32, 351)
# 304. ('202006064930', 'BO582054', 1, 15.12, 15.12, 351)
# 305. ('202006062177', 'JU170640', 2, 26.52, 53.04, 636)
# 306. ('202006055047', 'DD010283', 4, 14.84, 59.36, 1027)
# 307. ('202006053681', 'JU170640', 2, 26.52, 53.04, 576)
# 308. ('202006053681', 'TW629533', 1, 10.22, 10.22, 576)
# 309. ('202006050403', 'YO288069', 1, 27.48, 27.48, 97)
# 310. ('202006046049', 'FS589147', 2, 38.16, 76.32, 729)
# 311. ('202006046049', 'PP034234', 1, 47.77, 47.77, 729)
# 312. ('202006041971', 'ZI705132', 1, 39.56, 39.56, 826)
# 313. ('202006041971', 'LB821460', 1, 4.4, 4.4, 826)
# 314. ('202006040533', 'RL679581', 2, 6.08, 12.16, 448)
# 315. ('202006040533', 'TM009651', 1, 17.47, 17.47, 448)
# 316. ('202006040533', 'WE981088', 1, 5.55, 5.55, 448)
# 317. ('202006034948', 'UJ972892', 1, 16.24, 16.24, 916)
# 318. ('202006034105', 'LF434461', 2, 27.01, 54.02, 472)
# 319. ('202006034105', 'WC075791', 1, 10.13, 10.13, 472)
# 320. ('202006032005', 'UH907011', 1, 3.17, 3.17, 22)
# 321. ('202006032005', 'RC174600', 1, 22.25, 22.25, 22)
# 322. ('202006031329', 'TU924951', 1, 68.11, 68.11, 229)
# 323. ('202006031329', 'II226161', 1, 6.75, 6.75, 229)
# 324. ('202006019012', 'RL366039', 1, 12.57, 12.57, 823)
# 325. ('202006018478', 'GW633161', 4, 15.57, 62.28, 1029)
# 326. ('202006018478', 'KV699707', 2, 49.79, 99.58, 1029)
# 327. ('202006018361', 'EA810505', 1, 12.38, 12.38, 548)
# 328. ('202006010449', 'VB192908', 2, 51.11, 102.22, 404)
# 329. ('202005317917', 'UT900480', 3, 23.45, 70.35, 322)
# 330. ('202005315604', 'DD010283', 1, 14.84, 14.84, 39)
# 331. ('202005308855', 'YH733279', 2, 30.06, 60.12, 976)
# 332. ('202005308855', 'JN839604', 2, 10.12, 20.24, 976)
# 333. ('202005308855', 'EW850027', 4, 22.77, 91.08, 976)
# 334. ('202005304403', 'RM419830', 3, 6.81, 20.43, 714)
# 335. ('202005302865', 'OL163945', 1, 32.76, 32.76, 640)
# 336. ('202005301048', 'VA491621', 1, 20.23, 20.23, 133)
# 337. ('202005299993', 'NU857136', 1, 21.41, 21.41, 955)
# 338. ('202005299993', 'WC075791', 1, 10.13, 10.13, 955)
# 339. ('202005287027', 'JX098323', 1, 24.57, 24.57, 583)
# 340. ('202005287027', 'JF581322', 5, 5.33, 26.65, 583)
# 341. ('202005286929', 'KA428279', 1, 51.29, 51.29, 910)
# 342. ('202005284936', 'JG569755', 2, 15.2, 30.4, 150)
# 343. ('202005283890', 'LG977007', 7, 12.91, 90.37, 969)
# 344. ('202005281424', 'HJ467356', 1, 3.24, 3.24, 936)
# 345. ('202005281424', 'QM569197', 6, 6.65, 39.900000000000006, 936)
# 346. ('202005281424', 'OX204742', 1, 29.47, 29.47, 936)
# 347. ('202005281424', 'XW869039', 1, 34.07, 34.07, 936)
# 348. ('202005279793', 'RL679581', 4, 6.08, 24.32, 444)
# 349. ('202005270325', 'JK094728', 1, 41.77, 41.77, 925)
# 350. ('202005267423', 'JB911266', 2, 9.51, 19.02, 941)
# 351. ('202005261105', 'SJ372509', 5, 71.86, 359.3, 792)
# 352. ('202005261105', 'YL369550', 1, 10.7, 10.7, 792)
# 353. ('202005259782', 'CB183725', 1, 3.71, 3.71, 359)
# 354. ('202005259782', 'HQ425265', 2, 16.26, 32.52, 359)
# 355. ('202005249207', 'HY171869', 1, 11.9, 11.9, 103)
# 356. ('202005249207', 'JF581322', 1, 5.33, 5.33, 103)
# 357. ('202005243231', 'NG216735', 2, 17.9, 35.8, 407)
# 358. ('202005243231', 'KY358900', 1, 16.86, 16.86, 407)
# 359. ('202005237672', 'XJ792088', 2, 48.33, 96.66, 327)
# 360. ('202005237672', 'YG769767', 1, 12.62, 12.62, 327)
# 361. ('202005232973', 'SP542412', 3, 11.52, 34.56, 899)
# 362. ('202005231503', 'YD272264', 3, 5.5, 16.5, 986)
# 363. ('202005231503', 'JF918744', 1, 5.51, 5.51, 986)
# 364. ('202005224863', 'XO016727', 1, 13.31, 13.31, 80)
# 365. ('202005223476', 'CW815585', 2, 4.36, 8.72, 138)
# 366. ('202005223476', 'UI299166', 2, 3.81, 7.62, 138)
# 367. ('202005223476', 'GW631027', 3, 3.1, 9.3, 138)
# 368. ('202005223476', 'FW407914', 1, 35.48, 35.48, 138)
# 369. ('202005219269', 'KA428279', 1, 51.29, 51.29, 848)
# 370. ('202005219269', 'RV409643', 1, 40.46, 40.46, 848)
# 371. ('202005219269', 'IK042267', 3, 28.23, 84.69, 848)
# 372. ('202005213535', 'EI482226', 1, 6.67, 6.67, 615)
# 373. ('202005213535', 'QI533440', 3, 7.55, 22.65, 615)
# 374. ('202005208597', 'UL776281', 2, 16.75, 33.5, 103)
# 375. ('202005208597', 'OL316261', 1, 13.13, 13.13, 103)
# 376. ('202005200839', 'WB045037', 1, 38.25, 38.25, 338)
# 377. ('202005200839', 'IP543128', 1, 8.05, 8.05, 338)
# 378. ('202005196797', 'FT918550', 1, 4.32, 4.32, 584)
# 379. ('202005194742', 'TT401653', 1, 35.02, 35.02, 917)
# 380. ('202005194742', 'YC734818', 1, 52.32, 52.32, 917)
# 381. ('202005194547', 'IJ186457', 3, 5.77, 17.31, 841)
# 382. ('202005180155', 'ZI705132', 1, 39.56, 39.56, 327)
# 383. ('202005167637', 'QD658920', 1, 23.3, 23.3, 541)
# 384. ('202005167637', 'QD658920', 2, 23.3, 46.6, 541)
# 385. ('202005167637', 'RP922292', 5, 14.96, 74.80000000000001, 541)
# 386. ('202005147683', 'KD402977', 2, 61.5, 123.0, 939)
# 387. ('202005147683', 'LG157704', 1, 5.92, 5.92, 939)
# 388. ('202005145530', 'CV483003', 2, 6.17, 12.34, 528)
# 389. ('202005136657', 'CS929072', 1, 38.79, 38.79, 682)
# 390. ('202005125303', 'RC174600', 3, 22.25, 66.75, 64)
# 391. ('202005124793', 'LF434461', 1, 27.01, 27.01, 945)
# 392. ('202005124793', 'EI167200', 1, 19.44, 19.44, 945)
# 393. ('202005124793', 'FH047820', 2, 53.57, 107.14, 945)
# 394. ('202005116846', 'DD198600', 1, 38.19, 38.19, 38)
# 395. ('202005116846', 'AM850835', 5, 11.24, 56.2, 38)
# 396. ('202005114870', 'RC174600', 1, 22.25, 22.25, 156)
# 397. ('202005113425', 'YH986713', 2, 25.69, 51.38, 9)
# 398. ('202005103392', 'SL591725', 1, 19.35, 19.35, 445)
# 399. ('202005101203', 'CJ333649', 2, 25.14, 50.28, 557)
# 400. ('202005101203', 'CJ333649', 1, 25.14, 25.14, 557)
# 401. ('202005101203', 'SJ372509', 3, 71.86, 215.57999999999998, 557)
# 402. ('202005096829', 'RK693868', 1, 14.56, 14.56, 560)
# 403. ('202005095340', 'LG157704', 1, 5.92, 5.92, 508)
# 404. ('202005095340', 'CE099815', 1, 18.25, 18.25, 508)
# 405. ('202005095340', 'KM304818', 2, 10.33, 20.66, 508)
# 406. ('202005081467', 'WE981088', 1, 5.55, 5.55, 39)
# 407. ('202005077037', 'LF434461', 1, 27.01, 27.01, 743)
# 408. ('202005075400', 'YR014674', 2, 22.11, 44.22, 847)
# 409. ('202005071206', 'LD272389', 1, 72.06, 72.06, 59)
# 410. ('202005071206', 'DT834985', 1, 9.52, 9.52, 59)
# 411. ('202005070356', 'FK759406', 4, 11.04, 44.16, 241)
# 412. ('202005070356', 'IK042267', 4, 28.23, 112.92, 241)
# 413. ('202005070295', 'QM569197', 1, 6.65, 6.65, 566)
# 414. ('202005070295', 'FO303231', 2, 17.98, 35.96, 566)
# 415. ('202005064039', 'IQ035204', 3, 16.82, 50.46, 985)
# 416. ('202005064004', 'JB911266', 3, 9.51, 28.53, 508)
# 417. ('202005064004', 'DS853019', 1, 8.46, 8.46, 508)
# 418. ('202005064004', 'EM133279', 1, 29.9, 29.9, 508)
# 419. ('202005061052', 'AO024006', 1, 13.89, 13.89, 714)
# 420. ('202005061052', 'RL366039', 1, 12.57, 12.57, 714)
# 421. ('202005061052', 'UC279555', 3, 71.91, 215.73, 714)
# 422. ('202005053109', 'WF819044', 6, 16.09, 96.53999999999999, 729)
# 423. ('202005045660', 'CW933088', 3, 45.29, 135.87, 1019)
# 424. ('202005042146', 'BS032705', 2, 6.1, 12.2, 941)
# 425. ('202005042037', 'KT586465', 1, 22.43, 22.43, 23)
# 426. ('202005042037', 'ZO921517', 1, 3.29, 3.29, 23)
# 427. ('202005033376', 'LC099634', 1, 16.45, 16.45, 863)
# 428. ('202005026156', 'LZ422758', 2, 7.82, 15.64, 1003)
# 429. ('202005017592', 'KV699707', 1, 49.79, 49.79, 219)
# 430. ('202005013990', 'UY300722', 1, 22.31, 22.31, 489)
# 431. ('202005013990', 'NM894102', 1, 22.39, 22.39, 489)
# 432. ('202005011818', 'SJ372509', 2, 71.86, 143.72, 333)
# 433. ('202005011818', 'XX748942', 1, 16.46, 16.46, 333)
# 434. ('202004281381', 'CJ333649', 1, 25.14, 25.14, 113)
# 435. ('202004281381', 'GW633161', 2, 15.57, 31.14, 113)
# 436. ('202004279174', 'JG569755', 4, 15.2, 60.8, 1005)
# 437. ('202004278427', 'EI482226', 1, 6.67, 6.67, 363)
# 438. ('202004278427', 'UT900480', 1, 23.45, 23.45, 363)
# 439. ('202004276639', 'OP332924', 1, 5.83, 5.83, 936)
# 440. ('202004276424', 'YU673093', 1, 36.96, 36.96, 715)
# 441. ('202004273476', 'NJ458404', 1, 13.53, 13.53, 228)
# 442. ('202004273476', 'HL156494', 1, 32.17, 32.17, 228)
# 443. ('202004270818', 'WB045037', 1, 38.25, 38.25, 617)
# 444. ('202004266813', 'HQ925546', 3, 10.42, 31.259999999999998, 140)
# 445. ('202004261412', 'CD076891', 1, 21.27, 21.27, 220)
# 446. ('202004260483', 'KG005760', 4, 14.74, 58.96, 428)
# 447. ('202004260154', 'DR752339', 1, 78.53, 78.53, 172)
# 448. ('202004260154', 'UT900480', 1, 23.45, 23.45, 172)
# 449. ('202004260154', 'XF963575', 2, 12.03, 24.06, 172)
# 450. ('202004257489', 'TQ259905', 1, 14.15, 14.15, 888)
# 451. ('202004257489', 'TX377293', 2, 32.34, 64.68, 888)
# 452. ('202004256176', 'OL163945', 4, 32.76, 131.04, 714)
# 453. ('202004244158', 'CW815585', 1, 4.36, 4.36, 251)
# 454. ('202004244158', 'IY164524', 1, 10.48, 10.48, 251)
# 455. ('202004244158', 'JG569755', 1, 15.2, 15.2, 251)
# 456. ('202004237821', 'PW885124', 1, 4.64, 4.64, 202)
# 457. ('202004236695', 'FT255177', 2, 4.09, 8.18, 747)
# 458. ('202004234306', 'KY358900', 4, 16.86, 67.44, 318)
# 459. ('202004234306', 'VB511083', 1, 21.88, 21.88, 318)
# 460. ('202004229250', 'TT401653', 1, 35.02, 35.02, 936)
# 461. ('202004229168', 'HM219344', 1, 4.75, 4.75, 847)
# 462. ('202004227362', 'EI167200', 2, 19.44, 38.88, 64)
# 463. ('202004223524', 'PW885124', 2, 4.64, 9.28, 673)
# 464. ('202004223524', 'JC512163', 2, 27.67, 55.34, 673)
# 465. ('202004220386', 'DK020939', 1, 8.66, 8.66, 128)
# 466. ('202004220386', 'YJ878305', 1, 117.55, 117.55, 128)
# 467. ('202004219343', 'HL156494', 1, 32.17, 32.17, 685)
# 468. ('202004219343', 'YR417075', 4, 6.49, 25.96, 685)
# 469. ('202004219343', 'UQ607814', 2, 32.85, 65.7, 685)
# 470. ('202004208094', 'NW176696', 1, 19.43, 19.43, 682)
# 471. ('202004208094', 'QG837765', 1, 4.39, 4.39, 682)
# 472. ('202004205035', 'OL163945', 1, 32.76, 32.76, 354)
# 473. ('202004205035', 'YU673093', 1, 36.96, 36.96, 354)
# 474. ('202004205035', 'SH230268', 4, 50.0, 200.0, 354)
# 475. ('202004205035', 'EW850027', 4, 22.77, 91.08, 354)
# 476. ('202004204812', 'HJ601860', 2, 20.54, 41.08, 162)
# 477. ('202004203905', 'VY330668', 1, 5.84, 5.84, 807)
# 478. ('202004200400', 'JG569755', 1, 15.2, 15.2, 286)
# 479. ('202004200400', 'YH733279', 1, 30.06, 30.06, 286)
# 480. ('202004187384', 'KA428279', 3, 51.29, 153.87, 777)
# 481. ('202004187384', 'QE695574', 1, 6.38, 6.38, 777)
# 482. ('202004187261', 'PP034234', 2, 47.77, 95.54, 458)
# 483. ('202004187261', 'KL971708', 1, 17.8, 17.8, 458)
# 484. ('202004179588', 'RC174600', 3, 22.25, 66.75, 705)
# 485. ('202004177845', 'LD272389', 1, 72.06, 72.06, 758)
# 486. ('202004177845', 'XJ792088', 1, 48.33, 48.33, 758)
# 487. ('202004174770', 'ZQ867971', 1, 38.59, 38.59, 426)
# 488. ('202004174405', 'YU673093', 1, 36.96, 36.96, 724)
# 489. ('202004157058', 'EW850027', 1, 22.77, 22.77, 692)
# 490. ('202004155637', 'ZI705132', 1, 39.56, 39.56, 38)
# 491. ('202004155637', 'KM304818', 2, 10.33, 20.66, 38)
# 492. ('202004155637', 'OX204742', 2, 29.47, 58.94, 38)
# 493. ('202004154954', 'VX764028', 1, 4.82, 4.82, 714)
# 494. ('202004154954', 'KL971708', 1, 17.8, 17.8, 714)
# 495. ('202004152912', 'DF577320', 1, 71.62, 71.62, 998)
# 496. ('202004147926', 'JP764375', 1, 23.97, 23.97, 910)
# 497. ('202004147926', 'RK693868', 2, 14.56, 29.12, 910)
# 498. ('202004145267', 'TT401653', 4, 35.02, 140.08, 833)
# 499. ('202004145267', 'HA066493', 1, 3.2, 3.2, 833)
# 500. ('202004145267', 'PP034234', 1, 47.77, 47.77, 833)
# 501. ('202004142393', 'VD494982', 1, 22.91, 22.91, 560)
# 502. ('202004142321', 'VA564814', 2, 38.79, 77.58, 633)
# 503. ('202004137365', 'TQ259905', 6, 14.15, 84.9, 241)
# 504. ('202004137365', 'HJ467356', 2, 3.24, 6.48, 241)
# 505. ('202004136021', 'QX191412', 2, 7.27, 14.54, 181)
# 506. ('202004136021', 'XW869039', 1, 34.07, 34.07, 181)
# 507. ('202004123928', 'SJ521162', 1, 15.88, 15.88, 156)
# 508. ('202004123928', 'NJ458404', 3, 13.53, 40.589999999999996, 156)
# 509. ('202004123928', 'JF918744', 2, 5.51, 11.02, 156)
# 510. ('202004115537', 'HJ467356', 1, 3.24, 3.24, 19)
# 511. ('202004115537', 'XS324415', 1, 17.99, 17.99, 19)
# 512. ('202004109635', 'WB045037', 4, 38.25, 153.0, 78)
# 513. ('202004105117', 'HJ467356', 1, 3.24, 3.24, 358)
# 514. ('202004104796', 'KL971708', 5, 17.8, 89.0, 860)
# 515. ('202004099632', 'LB821460', 1, 4.4, 4.4, 923)
# 516. ('202004097107', 'KG005760', 2, 14.74, 29.48, 164)
# 517. ('202004097107', 'WQ703593', 1, 29.25, 29.25, 164)
# 518. ('202004087437', 'KA428279', 1, 51.29, 51.29, 149)
# 519. ('202004086441', 'EI482226', 1, 6.67, 6.67, 426)
# 520. ('202004081455', 'SI669053', 1, 24.3, 24.3, 852)
# 521. ('202004080026', 'QE695574', 1, 6.38, 6.38, 291)
# 522. ('202004079095', 'WE738312', 1, 26.31, 26.31, 489)
# 523. ('202004067160', 'LG560010', 1, 3.59, 3.59, 631)
# 524. ('202004058269', 'LF434461', 2, 27.01, 54.02, 5)
# 525. ('202004058269', 'LF083741', 2, 3.87, 7.74, 5)
# 526. ('202004052378', 'OP332924', 3, 5.83, 17.490000000000002, 194)
# 527. ('202004052378', 'NP860944', 1, 5.38, 5.38, 194)
# 528. ('202004049009', 'YU109630', 2, 14.06, 28.12, 794)
# 529. ('202004049009', 'OX788607', 3, 7.47, 22.41, 794)
# 530. ('202004048240', 'JF581322', 1, 5.33, 5.33, 219)
# 531. ('202004046714', 'JX993569', 4, 75.89, 303.56, 448)
# 532. ('202004043758', 'UL776281', 1, 16.75, 16.75, 792)
# 533. ('202004043758', 'QT761162', 2, 11.42, 22.84, 792)
# 534. ('202004043758', 'SH230268', 1, 50.0, 50.0, 792)
# 535. ('202004043758', 'JD727657', 2, 40.92, 81.84, 792)
# 536. ('202004039067', 'TD604410', 2, 8.04, 16.08, 361)
# 537. ('202004039067', 'RP922292', 1, 14.96, 14.96, 361)
# 538. ('202004027126', 'XF963575', 2, 12.03, 24.06, 284)
# 539. ('202004025715', 'KG005760', 2, 14.74, 29.48, 505)
# 540. ('202004025715', 'GW633161', 2, 15.57, 31.14, 505)
# 541. ('202003319676', 'HA066493', 2, 3.2, 6.4, 213)
# 542. ('202003319676', 'NE675700', 1, 13.91, 13.91, 213)
# 543. ('202003317937', 'OL316261', 1, 13.13, 13.13, 3)
# 544. ('202003317937', 'LF545577', 5, 5.86, 29.3, 3)
# 545. ('202003317937', 'GC440805', 2, 28.6, 57.2, 3)
# 546. ('202003316723', 'UL776281', 2, 16.75, 33.5, 1010)
# 547. ('202003316723', 'OP424108', 2, 8.44, 16.88, 1010)
# 548. ('202003315053', 'RL366039', 1, 12.57, 12.57, 10)
# 549. ('202003315053', 'NM894102', 4, 22.39, 89.56, 10)
# 550. ('202003311838', 'JX993569', 1, 75.89, 75.89, 105)
# 551. ('202003307951', 'YC734818', 5, 52.32, 261.6, 242)
# 552. ('202003299875', 'EV047882', 1, 14.1, 14.1, 18)
# 553. ('202003299875', 'SI669053', 1, 24.3, 24.3, 18)
# 554. ('202003298262', 'JF918744', 2, 5.51, 11.02, 90)
# 555. ('202003292361', 'QE695574', 1, 6.38, 6.38, 104)
# 556. ('202003282432', 'JX098323', 1, 24.57, 24.57, 989)
# 557. ('202003281344', 'UL776281', 1, 16.75, 16.75, 423)
# 558. ('202003281344', 'VA491621', 1, 20.23, 20.23, 423)
# 559. ('202003281344', 'VH823219', 5, 9.0, 45.0, 423)
# 560. ('202003281344', 'XF963575', 1, 12.03, 12.03, 423)
# 561. ('202003280251', 'FH047820', 4, 53.57, 214.28, 961)
# 562. ('202003273266', 'FZ085947', 1, 4.93, 4.93, 204)
# 563. ('202003271480', 'TU924951', 2, 68.11, 136.22, 428)
# 564. ('202003270849', 'JG569755', 1, 15.2, 15.2, 665)
# 565. ('202003263490', 'OY272975', 1, 43.44, 43.44, 266)
# 566. ('202003258907', 'VB511083', 1, 21.88, 21.88, 444)
# 567. ('202003258032', 'YH733279', 1, 30.06, 30.06, 65)
# 568. ('202003258032', 'AV611930', 2, 46.36, 92.72, 65)
# 569. ('202003258032', 'SH482670', 1, 25.68, 25.68, 65)
# 570. ('202003256849', 'SX937912', 2, 6.61, 13.22, 910)
# 571. ('202003254468', 'TN652481', 1, 43.29, 43.29, 217)
# 572. ('202003254468', 'WF268546', 2, 6.64, 13.28, 217)
# 573. ('202003250163', 'ZQ525720', 1, 5.99, 5.99, 160)
# 574. ('202003248390', 'DZ290862', 3, 15.65, 46.95, 685)
# 575. ('202003247832', 'OL316261', 3, 13.13, 39.39, 246)
# 576. ('202003247832', 'ED802859', 1, 15.95, 15.95, 246)
# 577. ('202003247832', 'LA362026', 1, 8.76, 8.76, 246)
# 578. ('202003244940', 'JP764375', 3, 23.97, 71.91, 244)
# 579. ('202003243825', 'JC512163', 1, 27.67, 27.67, 715)
# 580. ('202003241077', 'JF918744', 1, 5.51, 5.51, 742)
# 581. ('202003241077', 'MQ184336', 5, 4.31, 21.549999999999997, 742)
# 582. ('202003241077', 'SI669053', 4, 24.3, 97.2, 742)
# 583. ('202003241077', 'WV650733', 1, 63.68, 63.68, 742)
# 584. ('202003236910', 'FH047820', 1, 53.57, 53.57, 183)
# 585. ('202003236910', 'DR752339', 1, 78.53, 78.53, 183)
# 586. ('202003236910', 'LF083741', 2, 3.87, 7.74, 183)
# 587. ('202003233641', 'GO630928', 2, 5.54, 11.08, 582)
# 588. ('202003233641', 'PY014422', 2, 87.8, 175.6, 582)
# 589. ('202003233641', 'LB821460', 1, 4.4, 4.4, 582)
# 590. ('202003225949', 'LZ422758', 1, 7.82, 7.82, 140)
# 591. ('202003213908', 'LG157704', 1, 5.92, 5.92, 685)
# 592. ('202003213908', 'HL053400', 2, 28.73, 57.46, 685)
# 593. ('202003213908', 'XO016727', 2, 13.31, 26.62, 685)
# 594. ('202003208691', 'UC279555', 1, 71.91, 71.91, 694)
# 595. ('202003208691', 'TF006345', 4, 21.97, 87.88, 694)
# 596. ('202003206492', 'WC075791', 1, 10.13, 10.13, 85)
# 597. ('202003206492', 'FK759406', 1, 11.04, 11.04, 85)
# 598. ('202003194746', 'EI167200', 1, 19.44, 19.44, 724)
# 599. ('202003194746', 'AD147234', 1, 7.96, 7.96, 724)
# 600. ('202003194746', 'TW629533', 1, 10.22, 10.22, 724)
# 601. ('202003175453', 'OO406570', 3, 28.87, 86.61, 938)
# 602. ('202003168304', 'HQ425265', 1, 16.26, 16.26, 285)
# 603. ('202003161134', 'JD727657', 4, 40.92, 163.68, 154)
# 604. ('202003158375', 'HJ601860', 2, 20.54, 41.08, 18)
# 605. ('202003158375', 'HY171869', 2, 11.9, 23.8, 18)
# 606. ('202003158375', 'JD727657', 2, 40.92, 81.84, 18)
# 607. ('202003157631', 'RC174600', 1, 22.25, 22.25, 247)
# 608. ('202003156320', 'YQ263581', 2, 61.4, 122.8, 513)
# 609. ('202003156320', 'IY164524', 4, 10.48, 41.92, 513)
# 610. ('202003156320', 'VZ240168', 2, 31.27, 62.54, 513)
# 611. ('202003156320', 'TQ259905', 2, 14.15, 28.3, 513)
# 612. ('202003147338', 'AO024006', 2, 13.89, 27.78, 224)
# 613. ('202003146646', 'YG769767', 5, 12.62, 63.099999999999994, 231)
# 614. ('202003145760', 'QT761162', 2, 11.42, 22.84, 371)
# 615. ('202003145760', 'HY171869', 4, 11.9, 47.6, 371)
# 616. ('202003141835', 'ST643511', 1, 91.76, 91.76, 543)
# 617. ('202003126937', 'TX377293', 1, 32.34, 32.34, 836)
# 618. ('202003124983', 'EV462601', 4, 22.4, 89.6, 843)
# 619. ('202003124983', 'KB827835', 1, 5.54, 5.54, 843)
# 620. ('202003124983', 'SJ521162', 2, 15.88, 31.76, 843)
# 621. ('202003120597', 'BS032705', 1, 6.1, 6.1, 700)
# 622. ('202003120597', 'ST643511', 2, 91.76, 183.52, 700)
# 623. ('202003120597', 'UQ607814', 3, 32.85, 98.55000000000001, 700)
# 624. ('202003101646', 'DT834985', 1, 9.52, 9.52, 156)
# 625. ('202003101646', 'LC861690', 3, 7.04, 21.12, 156)
# 626. ('202003101646', 'FH047820', 1, 53.57, 53.57, 156)
# 627. ('202003089630', 'GX613685', 1, 18.43, 18.43, 504)
# 628. ('202003089630', 'UY926211', 1, 39.03, 39.03, 504)
# 629. ('202003079191', 'HQ425265', 2, 16.26, 32.52, 844)
# 630. ('202003079191', 'UI299166', 1, 3.81, 3.81, 844)
# 631. ('202003061118', 'RE313887', 1, 12.78, 12.78, 326)
# 632. ('202003061118', 'OL316261', 3, 13.13, 39.39, 326)
# 633. ('202003058510', 'WF268546', 5, 6.64, 33.199999999999996, 201)
# 634. ('202003058510', 'UQ424073', 1, 40.07, 40.07, 201)
# 635. ('202003053102', 'PY014422', 2, 87.8, 175.6, 177)
# 636. ('202003044214', 'NU857136', 1, 21.41, 21.41, 428)
# 637. ('202003044214', 'FS589147', 1, 38.16, 38.16, 428)
# 638. ('202003044038', 'QI533440', 1, 7.55, 7.55, 519)
# 639. ('202003040379', 'XX748942', 1, 16.46, 16.46, 599)
# 640. ('202003040379', 'DT834985', 4, 9.52, 38.08, 599)
# 641. ('202003040379', 'UI299166', 1, 3.81, 3.81, 599)
# 642. ('202003040379', 'BA037508', 1, 45.46, 45.46, 599)
# 643. ('202003022605', 'YW570301', 1, 4.17, 4.17, 18)
# 644. ('202003022605', 'OY272975', 1, 43.44, 43.44, 18)
# 645. ('202003018857', 'ZI705132', 2, 39.56, 79.12, 971)
# 646. ('202003016402', 'WE738312', 3, 26.31, 78.92999999999999, 742)
# 647. ('202003014938', 'UJ972892', 2, 16.24, 32.48, 410)
# 648. ('202003013237', 'PV439970', 1, 42.83, 42.83, 48)
# 649. ('202003012101', 'VA564814', 2, 38.79, 77.58, 46)
# 650. ('202003012101', 'EW850027', 2, 22.77, 45.54, 46)
# 651. ('202003011221', 'FT918550', 1, 4.32, 4.32, 962)
# 652. ('202003011221', 'WY701424', 1, 6.14, 6.14, 962)
# 653. ('202003010868', 'LB821460', 1, 4.4, 4.4, 737)
# 654. ('202003010868', 'AL225388', 1, 14.35, 14.35, 737)
# 655. ('202003010868', 'FT255177', 1, 4.09, 4.09, 737)
# 656. ('202003010686', 'TT401653', 1, 35.02, 35.02, 233)
# 657. ('202003010083', 'HL053400', 1, 28.73, 28.73, 445)
# 658. ('202002294839', 'JF918744', 2, 5.51, 11.02, 445)
# 659. ('202002294199', 'TD604410', 2, 8.04, 16.08, 846)
# 660. ('202002294199', 'RL366039', 3, 12.57, 37.71, 846)
# 661. ('202002290522', 'CK640266', 2, 3.64, 7.28, 626)
# 662. ('202002288130', 'KV699707', 1, 49.79, 49.79, 291)
# 663. ('202002288130', 'WF819044', 1, 16.09, 16.09, 291)
# 664. ('202002287684', 'BS032705', 4, 6.1, 24.4, 396)
# 665. ('202002280669', 'YG769767', 4, 12.62, 50.48, 813)
# 666. ('202002278019', 'UP489523', 1, 12.11, 12.11, 287)
# 667. ('202002275771', 'YD328076', 1, 41.13, 41.13, 451)
# 668. ('202002275771', 'JX098323', 2, 24.57, 49.14, 451)
# 669. ('202002275771', 'BO582054', 3, 15.12, 45.36, 451)
# 670. ('202002275771', 'DT834985', 2, 9.52, 19.04, 451)
# 671. ('202002274895', 'KL971708', 2, 17.8, 35.6, 564)
# 672. ('202002274895', 'ZN199362', 3, 31.32, 93.96000000000001, 564)
# 673. ('202002269060', 'HQ925546', 7, 10.42, 72.94, 321)
# 674. ('202002268465', 'UX197382', 3, 11.3, 33.900000000000006, 566)
# 675. ('202002264030', 'AL225388', 2, 14.35, 28.7, 665)
# 676. ('202002255417', 'MQ184336', 1, 4.31, 4.31, 479)
# 677. ('202002255417', 'YD272264', 1, 5.5, 5.5, 479)
# 678. ('202002246754', 'QM569197', 1, 6.65, 6.65, 331)
# 679. ('202002234941', 'FZ085947', 2, 4.93, 9.86, 461)
# 680. ('202002234941', 'DK720585', 1, 17.12, 17.12, 461)
# 681. ('202002234875', 'JA112745', 2, 20.51, 41.02, 414)
# 682. ('202002232320', 'GU312892', 5, 92.53, 462.65, 332)
# 683. ('202002232320', 'WU831585', 1, 7.71, 7.71, 332)
# 684. ('202002232320', 'DR752339', 2, 78.53, 157.06, 332)
# 685. ('202002232320', 'DU573649', 1, 11.1, 11.1, 332)
# 686. ('202002223900', 'JF581322', 1, 5.33, 5.33, 972)
# 687. ('202002222376', 'FK103182', 2, 4.32, 8.64, 135)
# 688. ('202002222376', 'KD402977', 1, 61.5, 61.5, 135)
# 689. ('202002222376', 'DE471836', 1, 6.7, 6.7, 135)
# 690. ('202002216315', 'DK020939', 1, 8.66, 8.66, 685)
# 691. ('202002216315', 'EZ069281', 1, 6.31, 6.31, 685)
# 692. ('202002208831', 'IP543128', 3, 8.05, 24.150000000000002, 999)
# 693. ('202002208607', 'NE964215', 4, 66.94, 267.76, 956)
# 694. ('202002208607', 'TN652481', 1, 43.29, 43.29, 956)
# 695. ('202002197727', 'KB827835', 8, 5.54, 44.32, 414)
# 696. ('202002197727', 'GC440805', 1, 28.6, 28.6, 414)
# 697. ('202002197274', 'AI615521', 2, 4.84, 9.68, 312)
# 698. ('202002197238', 'UX197382', 2, 11.3, 22.6, 771)
# 699. ('202002197238', 'XF963575', 1, 12.03, 12.03, 771)
# 700. ('202002185774', 'DD186136', 1, 66.25, 66.25, 127)
# 701. ('202002185774', 'SP542412', 2, 11.52, 23.04, 127)
# 702. ('202002185621', 'QE695574', 3, 6.38, 19.14, 529)
# 703. ('202002180601', 'AQ988179', 2, 63.67, 127.34, 986)
# 704. ('202002174114', 'YT873595', 1, 6.56, 6.56, 1017)
# 705. ('202002168050', 'YR014674', 4, 22.11, 88.44, 760)
# 706. ('202002168050', 'VY330668', 1, 5.84, 5.84, 760)
# 707. ('202002162612', 'AV557076', 2, 16.48, 32.96, 988)
# 708. ('202002162612', 'GU312892', 2, 92.53, 185.06, 988)
# 709. ('202002152825', 'WE981088', 1, 5.55, 5.55, 265)
# 710. ('202002150018', 'RP922292', 2, 14.96, 29.92, 1024)
# 711. ('202002126910', 'ZQ525720', 2, 5.99, 11.98, 250)
# 712. ('202002123983', 'VA491621', 3, 20.23, 60.69, 428)
# 713. ('202002120782', 'WD870963', 2, 26.16, 52.32, 298)
# 714. ('202002120782', 'YL369550', 2, 10.7, 21.4, 298)
# 715. ('202002120782', 'QG837765', 2, 4.39, 8.78, 298)
# 716. ('202002120487', 'FF356985', 1, 8.56, 8.56, 519)
# 717. ('202002120487', 'SP067749', 1, 10.25, 10.25, 519)
# 718. ('202002110526', 'CV483003', 2, 6.17, 12.34, 323)
# 719. ('202002110526', 'AO024006', 1, 13.89, 13.89, 323)
# 720. ('202002106351', 'RD191959', 1, 11.31, 11.31, 747)
# 721. ('202002105316', 'RE313887', 3, 12.78, 38.339999999999996, 675)
# 722. ('202002105316', 'KA428279', 4, 51.29, 205.16, 675)
# 723. ('202002105316', 'RM419830', 2, 6.81, 13.62, 675)
# 724. ('202002100158', 'II226161', 1, 6.75, 6.75, 224)
# 725. ('202002100054', 'SJ372509', 2, 71.86, 143.72, 662)
# 726. ('202002100054', 'ZH081916', 2, 4.32, 8.64, 662)
# 727. ('202002091003', 'KY392005', 1, 30.51, 30.51, 31)
# 728. ('202002078329', 'GV361474', 2, 28.81, 57.62, 155)
# 729. ('202002049383', 'MO457479', 2, 10.68, 21.36, 374)
# 730. ('202002048840', 'DU573649', 4, 11.1, 44.4, 65)
# 731. ('202002048840', 'LG977007', 1, 12.91, 12.91, 65)
# 732. ('202002047239', 'MO457479', 3, 10.68, 32.04, 873)
# 733. ('202002038659', 'FX037590', 2, 24.83, 49.66, 1)
# 734. ('202002038228', 'SY274303', 1, 26.33, 26.33, 682)
# 735. ('202002038228', 'XO016727', 2, 13.31, 26.62, 682)
# 736. ('202002032586', 'NJ458404', 3, 13.53, 40.589999999999996, 915)
# 737. ('202002023659', 'UJ199198', 4, 5.51, 22.04, 364)
# 738. ('202002023659', 'HJ601860', 1, 20.54, 20.54, 364)
# 739. ('202002023659', 'KW929922', 2, 26.68, 53.36, 364)
# 740. ('202002022779', 'IQ035204', 1, 16.82, 16.82, 541)
# 741. ('202001313726', 'FF356985', 2, 8.56, 17.12, 837)
# 742. ('202001313726', 'AV557076', 2, 16.48, 32.96, 837)
# 743. ('202001313726', 'UC279555', 1, 71.91, 71.91, 837)
# 744. ('202001313065', 'NP860944', 1, 5.38, 5.38, 369)
# 745. ('202001313065', 'YO288069', 4, 27.48, 109.92, 369)
# 746. ('202001303071', 'OX204742', 1, 29.47, 29.47, 108)
# 747. ('202001303071', 'SP067749', 2, 10.25, 20.5, 108)
# 748. ('202001303071', 'FZ737978', 2, 46.75, 93.5, 108)
# 749. ('202001300355', 'YT873595', 1, 6.56, 6.56, 682)
# 750. ('202001300355', 'WF268546', 1, 6.64, 6.64, 682)
# 751. ('202001297775', 'BO582054', 6, 15.12, 90.72, 428)
# 752. ('202001297775', 'LB821460', 3, 4.4, 13.200000000000001, 428)
# 753. ('202001297775', 'QI533440', 2, 7.55, 15.1, 428)
# 754. ('202001287369', 'TN652481', 1, 43.29, 43.29, 884)
# 755. ('202001287369', 'QG837765', 1, 4.39, 4.39, 884)
# 756. ('202001286537', 'FZ085947', 1, 4.93, 4.93, 482)
# 757. ('202001286537', 'LC861690', 1, 7.04, 7.04, 482)
# 758. ('202001286537', 'SY274303', 2, 26.33, 52.66, 482)
# 759. ('202001278368', 'AL225388', 1, 14.35, 14.35, 199)
# 760. ('202001245688', 'DU573649', 3, 11.1, 33.3, 722)
# 761. ('202001239621', 'JN839604', 1, 10.12, 10.12, 617)
# 762. ('202001239621', 'JS961877', 1, 31.65, 31.65, 617)
# 763. ('202001239621', 'EI482226', 1, 6.67, 6.67, 617)
# 764. ('202001235990', 'KL971708', 1, 17.8, 17.8, 40)
# 765. ('202001232696', 'SH230268', 2, 50.0, 100.0, 985)
# 766. ('202001232696', 'MJ886801', 1, 28.01, 28.01, 985)
# 767. ('202001232696', 'PW885124', 1, 4.64, 4.64, 985)
# 768. ('202001232696', 'CK640266', 1, 3.64, 3.64, 985)
# 769. ('202001231024', 'JP764375', 3, 23.97, 71.91, 82)
# 770. ('202001231024', 'OO406570', 1, 28.87, 28.87, 82)
# 771. ('202001224530', 'SI669053', 2, 24.3, 48.6, 127)
# 772. ('202001224530', 'CW815585', 2, 4.36, 8.72, 127)
# 773. ('202001223476', 'WC075791', 1, 10.13, 10.13, 833)
# 774. ('202001217478', 'JU170640', 1, 26.52, 26.52, 211)
# 775. ('202001212384', 'AD147234', 1, 7.96, 7.96, 901)
# 776. ('202001212384', 'KW929922', 1, 26.68, 26.68, 901)
# 777. ('202001212384', 'BA037508', 1, 45.46, 45.46, 901)
# 778. ('202001208851', 'VA564814', 1, 38.79, 38.79, 984)
# 779. ('202001202310', 'HR412275', 1, 16.32, 16.32, 308)
# 780. ('202001202310', 'DD186136', 1, 66.25, 66.25, 308)
# 781. ('202001202310', 'JG569755', 1, 15.2, 15.2, 308)
# 782. ('202001202310', 'UT650293', 1, 8.07, 8.07, 308)
# 783. ('202001182642', 'JU170640', 1, 26.52, 26.52, 822)
# 784. ('202001177298', 'BS032705', 1, 6.1, 6.1, 923)
# 785. ('202001175266', 'AO469492', 1, 34.53, 34.53, 659)
# 786. ('202001174383', 'CW815585', 2, 4.36, 8.72, 838)
# 787. ('202001174383', 'AO469492', 1, 34.53, 34.53, 838)
# 788. ('202001174383', 'RV409643', 4, 40.46, 161.84, 838)
# 789. ('202001174383', 'HR412275', 1, 16.32, 16.32, 838)
# 790. ('202001174383', 'OW060718', 2, 6.88, 13.76, 838)
# 791. ('202001161492', 'WU831585', 1, 7.71, 7.71, 878)
# 792. ('202001161492', 'FN667308', 2, 5.14, 10.28, 878)
# 793. ('202001156010', 'GU312892', 3, 92.53, 277.59000000000003, 837)
# 794. ('202001156010', 'VB511083', 2, 21.88, 43.76, 837)
# 795. ('202001145631', 'JC512163', 1, 27.67, 27.67, 853)
# 796. ('202001145631', 'UC279555', 1, 71.91, 71.91, 853)
# 797. ('202001145631', 'AO469492', 1, 34.53, 34.53, 853)
# 798. ('202001140376', 'JR035990', 2, 10.02, 20.04, 749)
# 799. ('202001140376', 'ZI822433', 2, 18.94, 37.88, 749)
# 800. ('202001133777', 'NU857136', 5, 21.41, 107.05, 863)
# 801. ('202001129820', 'UL776281', 2, 16.75, 33.5, 213)
# 802. ('202001129820', 'NJ458404', 2, 13.53, 27.06, 213)
# 803. ('202001122203', 'DZ290862', 1, 15.65, 15.65, 326)
# 804. ('202001114085', 'CC424913', 1, 78.7, 78.7, 682)
# 805. ('202001114085', 'KL971708', 1, 17.8, 17.8, 682)
# 806. ('202001104260', 'TD604410', 4, 8.04, 32.16, 1017)
# 807. ('202001100187', 'MO457479', 2, 10.68, 21.36, 883)
# 808. ('202001097804', 'PV439970', 3, 42.83, 128.49, 615)
# 809. ('202001095930', 'MO457479', 1, 10.68, 10.68, 133)
# 810. ('202001095930', 'GC440805', 2, 28.6, 57.2, 133)
# 811. ('202001095498', 'AV611930', 1, 46.36, 46.36, 323)
# 812. ('202001095498', 'JX098323', 4, 24.57, 98.28, 323)
# 813. ('202001084234', 'VX764028', 2, 4.82, 9.64, 170)
# 814. ('202001066755', 'WF268546', 1, 6.64, 6.64, 742)
# 815. ('202001063259', 'UQ607814', 1, 32.85, 32.85, 101)
# 816. ('202001063259', 'QI533440', 7, 7.55, 52.85, 101)
# 817. ('202001051858', 'QJ965247', 1, 28.16, 28.16, 49)
# 818. ('202001048456', 'LG157704', 1, 5.92, 5.92, 113)
# 819. ('202001033619', 'BS032705', 2, 6.1, 12.2, 380)
# 820. ('202001033619', 'GS673129', 2, 9.1, 18.2, 380)
# 821. ('202001026165', 'YO288069', 1, 27.48, 27.48, 294)
# 822. ('202001026165', 'LG560010', 1, 3.59, 3.59, 294)
# 823. ('202001026165', 'QD658920', 1, 23.3, 23.3, 294)
# 824. ('202001023177', 'UQ607814', 1, 32.85, 32.85, 845)
# 825. ('202001023177', 'YG769767', 1, 12.62, 12.62, 845)
# 826. ('202001015302', 'HL053400', 3, 28.73, 86.19, 616)
# 827. ('202001015279', 'UT650293', 1, 8.07, 8.07, 347)
# 828. ('201912310699', 'WB045037', 1, 38.25, 38.25, 130)
# 829. ('201912310699', 'TN652481', 2, 43.29, 86.58, 130)
# 830. ('201912310155', 'NP860944', 1, 5.38, 5.38, 331)
# 831. ('201912308829', 'HL156494', 2, 32.17, 64.34, 930)
# 832. ('201912308829', 'ED802859', 2, 15.95, 31.9, 930)
# 833. ('201912308829', 'LJ294158', 4, 41.37, 165.48, 930)
# 834. ('201912305572', 'GS673129', 2, 9.1, 18.2, 974)
# 835. ('201912297376', 'EI167200', 1, 19.44, 19.44, 114)
# 836. ('201912297376', 'TT401653', 2, 35.02, 70.04, 114)
# 837. ('201912289344', 'OY272975', 1, 43.44, 43.44, 800)
# 838. ('201912283123', 'WQ703593', 2, 29.25, 58.5, 461)
# 839. ('201912283036', 'ZQ525720', 1, 5.99, 5.99, 711)
# 840. ('201912278209', 'JF918744', 2, 5.51, 11.02, 791)
# 841. ('201912278209', 'NG216735', 1, 17.9, 17.9, 791)
# 842. ('201912276242', 'OO406570', 3, 28.87, 86.61, 134)
# 843. ('201912269192', 'HR412275', 4, 16.32, 65.28, 20)
# 844. ('201912268755', 'MQ184336', 1, 4.31, 4.31, 217)
# 845. ('201912268755', 'UQ607814', 1, 32.85, 32.85, 217)
# 846. ('201912268755', 'VD494982', 3, 22.91, 68.73, 217)
# 847. ('201912255582', 'FS143237', 2, 19.03, 38.06, 729)
# 848. ('201912255582', 'ZN588598', 1, 10.92, 10.92, 729)
# 849. ('201912253683', 'UY926211', 3, 39.03, 117.09, 909)
# 850. ('201912253683', 'SP542412', 4, 11.52, 46.08, 909)
# 851. ('201912251773', 'LC861690', 2, 7.04, 14.08, 285)
# 852. ('201912251773', 'MQ184336', 2, 4.31, 8.62, 285)
# 853. ('201912249941', 'YQ263581', 2, 61.4, 122.8, 231)
# 854. ('201912249941', 'DT834985', 1, 9.52, 9.52, 231)
# 855. ('201912249941', 'JG569755', 2, 15.2, 30.4, 231)
# 856. ('201912249361', 'IP543128', 1, 8.05, 8.05, 7)
# 857. ('201912249361', 'XG335214', 2, 21.77, 43.54, 7)
# 858. ('201912249004', 'AQ988179', 4, 63.67, 254.68, 86)
# 859. ('201912244009', 'EV047882', 4, 14.1, 56.4, 175)
# 860. ('201912243397', 'AQ988179', 1, 63.67, 63.67, 302)
# 861. ('201912243397', 'HA328125', 1, 56.15, 56.15, 302)
# 862. ('201912239224', 'JA112745', 3, 20.51, 61.53, 370)
# ...
# 3418. ('201405032475', 'AI615521', 2, 4.84, 9.68, 431)
# 3419. ('201405027319', 'LC861690', 5, 7.04, 35.2, 506)
# 3420. ('201404288009', 'LG977007', 1, 12.91, 12.91, 40)
# 3421. ('201404281692', 'FL206232', 5, 6.03, 30.150000000000002, 122)
# 3422. ('201404281692', 'DR752339', 1, 78.53, 78.53, 122)
# 3423. ('201404258636', 'VH823219', 1, 9.0, 9.0, 85)
# 3424. ('201404258636', 'TS648442', 3, 42.39, 127.17, 85)
# 3425. ('201404258636', 'LF434461', 1, 27.01, 27.01, 85)
# 3426. ('201404161325', 'ZQ867971', 1, 38.59, 38.59, 922)
# 3427. ('201404161325', 'HL156494', 1, 32.17, 32.17, 922)
# 3428. ('201404161325', 'PY014422', 5, 87.8, 439.0, 922)
# 3429. ('201404152026', 'FW407914', 1, 35.48, 35.48, 920)
# 3430. ('201404137960', 'UY926211', 2, 39.03, 78.06, 1013)
# 3431. ('201404137960', 'KW929922', 4, 26.68, 106.72, 1013)
# 3432. ('201404137960', 'QD294233', 2, 65.15, 130.3, 1013)
# 3433. ('201404126597', 'LC099634', 4, 16.45, 65.8, 546)
# 3434. ('201404125034', 'QD658920', 1, 23.3, 23.3, 977)
# 3435. ('201404114498', 'YT873595', 1, 6.56, 6.56, 384)
# 3436. ('201404114498', 'WI150710', 1, 6.75, 6.75, 384)
# 3437. ('201404062193', 'FO303231', 3, 17.98, 53.94, 227)
# 3438. ('201403241935', 'EW850027', 1, 22.77, 22.77, 472)
# 3439. ('201403241935', 'UC279555', 2, 71.91, 143.82, 472)
# 3440. ('201403238557', 'YU673093', 1, 36.96, 36.96, 503)
# 3441. ('201403165867', 'NW176696', 2, 19.43, 38.86, 157)
# 3442. ('201403114155', 'NE675700', 1, 13.91, 13.91, 1021)
# 3443. ('201403034734', 'WF268546', 1, 6.64, 6.64, 316)
# 3444. ('201402271443', 'XS324415', 2, 17.99, 35.98, 196)
# 3445. ('201402271443', 'YU673093', 1, 36.96, 36.96, 196)
# 3446. ('201402269701', 'AL225388', 2, 14.35, 28.7, 280)
# 3447. ('201402269701', 'SJ521162', 3, 15.88, 47.64, 280)
# 3448. ('201402245303', 'WC075791', 1, 10.13, 10.13, 979)
# 3449. ('201402245303', 'FH047820', 1, 53.57, 53.57, 979)
# 3450. ('201402224182', 'DU573649', 1, 11.1, 11.1, 547)
# 3451. ('201402224182', 'FK759406', 4, 11.04, 44.16, 547)
# 3452. ('201402195691', 'LF545577', 1, 5.86, 5.86, 819)
# 3453. ('201402188656', 'GW631027', 1, 3.1, 3.1, 612)
# 3454. ('201402158951', 'LC861690', 2, 7.04, 14.08, 330)
# 3455. ('201402155651', 'GX613685', 1, 18.43, 18.43, 573)
# 3456. ('201402155651', 'VF775370', 2, 32.69, 65.38, 573)
# 3457. ('201402048139', 'EI167200', 1, 19.44, 19.44, 977)
# 3458. ('201401275060', 'GV361474', 2, 28.81, 57.62, 341)
# 3459. ('201401238120', 'JK094728', 1, 41.77, 41.77, 88)
# 3460. ('201401233702', 'JJ883894', 1, 9.17, 9.17, 75)
# 3461. ('201401233702', 'EZ069281', 2, 6.31, 12.62, 75)
# 3462. ('201401233702', 'EV462601', 2, 22.4, 44.8, 75)
# 3463. ('201401153511', 'FS143237', 2, 19.03, 38.06, 384)
# 3464. ('201401153511', 'HA328125', 1, 56.15, 56.15, 384)
# 3465. ('201401152723', 'AT619585', 1, 13.8, 13.8, 960)
# 3466. ('201401152723', 'KA428279', 1, 51.29, 51.29, 960)
# 3467. ('201401152723', 'FQ556732', 2, 7.95, 15.9, 960)
# 3468. ('201401152723', 'QD294233', 4, 65.15, 260.6, 960)
# 3469. ('201401137677', 'JF918744', 2, 5.51, 11.02, 447)
# 3470. ('201401137677', 'GO630928', 1, 5.54, 5.54, 447)
# 3471. ('201401038483', 'FS143237', 1, 19.03, 19.03, 506)
# 3472. ('201401038483', 'YD272264', 1, 5.5, 5.5, 506)
# 3473. ('201401012586', 'MK751094', 1, 21.96, 21.96, 846)
# 3474. ('201401012586', 'HL053400', 1, 28.73, 28.73, 846)
# 3475. ('201312314650', 'GC440805', 3, 28.6, 85.80000000000001, 603)
# 3476. ('201312241397', 'XJ792088', 1, 48.33, 48.33, 419)
# 3477. ('201312214003', 'LG977007', 1, 12.91, 12.91, 447)
# 3478. ('201312214003', 'WE981088', 1, 5.55, 5.55, 447)
# 3479. ('201312058345', 'HR412275', 1, 16.32, 16.32, 603)
# 3480. ('201311216544', 'LZ422758', 1, 7.82, 7.82, 257)
# 3481. ('201311216544', 'RA538031', 1, 5.4, 5.4, 257)
# 3482. ('201311216544', 'II226161', 4, 6.75, 27.0, 257)
# 3483. ('201311159748', 'CP824418', 1, 7.83, 7.83, 993)
# 3484. ('201311159748', 'XS324415', 2, 17.99, 35.98, 993)
# 3485. ('201311159748', 'RL679581', 5, 6.08, 30.4, 993)
# 3486. ('201311159748', 'CW815585', 2, 4.36, 8.72, 993)
# 3487. ('201311108193', 'AQ988179', 1, 63.67, 63.67, 58)
# 3488. ('201311108193', 'RL679581', 1, 6.08, 6.08, 58)
# 3489. ('201311108193', 'YD328076', 1, 41.13, 41.13, 58)
# 3490. ('201311062687', 'HY171869', 2, 11.9, 23.8, 550)
# 3491. ('201311062687', 'JX993569', 1, 75.89, 75.89, 550)
# 3492. ('201311050602', 'JB911266', 1, 9.51, 9.51, 334)
# 3493. ('201311020347', 'LC861690', 1, 7.04, 7.04, 1011)
# 3494. ('201311020347', 'RB348133', 2, 47.01, 94.02, 1011)
# 3495. ('201311020347', 'LZ422758', 2, 7.82, 15.64, 1011)
# 3496. ('201310170968', 'FH047820', 1, 53.57, 53.57, 452)
# 3497. ('201310166730', 'AO469492', 2, 34.53, 69.06, 674)
# 3498. ('201310111022', 'ED802859', 1, 15.95, 15.95, 545)
# 3499. ('201310111022', 'VB192908', 2, 51.11, 102.22, 545)
# 3500. ('201310045263', 'HA328125', 2, 56.15, 112.3, 35)
# 3501. ('201310045263', 'AV557076', 2, 16.48, 32.96, 35)
# 3502. ('201310045263', 'ZH081916', 1, 4.32, 4.32, 35)
# 3503. ('201310031211', 'RK693868', 3, 14.56, 43.68, 662)
# 3504. ('201309291537', 'SJ521162', 2, 15.88, 31.76, 796)
# 3505. ('201309261308', 'WF268546', 3, 6.64, 19.919999999999998, 902)
# 3506. ('201309251336', 'VD494982', 4, 22.91, 91.64, 234)
# 3507. ('201309251336', 'TS648442', 3, 42.39, 127.17, 234)
# 3508. ('201309251336', 'RA538031', 1, 5.4, 5.4, 234)
# 3509. ('201309198235', 'YD328076', 1, 41.13, 41.13, 289)
# 3510. ('201309198235', 'CB183725', 1, 3.71, 3.71, 289)
# 3511. ('201309190182', 'CC424913', 1, 78.7, 78.7, 846)
# 3512. ('201309190182', 'TX377293', 3, 32.34, 97.02000000000001, 846)
# 3513. ('201309190182', 'SI669053', 1, 24.3, 24.3, 846)
# 3514. ('201309182137', 'VB192908', 2, 51.11, 102.22, 300)
# 3515. ('201309155386', 'WY701424', 1, 6.14, 6.14, 1011)
# 3516. ('201309097742', 'FT255177', 1, 4.09, 4.09, 363)
# 3517. ('201309060595', 'FZ737978', 1, 46.75, 46.75, 880)
# 3518. ('201309060595', 'CK640266', 1, 3.64, 3.64, 880)
# 3519. ('201309060595', 'HR920743', 1, 24.09, 24.09, 880)
# 3520. ('201308250648', 'CJ333649', 1, 25.14, 25.14, 862)
# 3521. ('201308246130', 'BA037508', 2, 45.46, 90.92, 781)
# 3522. ('201308227988', 'UT650293', 3, 8.07, 24.21, 960)
# 3523. ('201308227988', 'NG216735', 1, 17.9, 17.9, 960)
# 3524. ('201308187619', 'ZN199362', 1, 31.32, 31.32, 422)
# 3525. ('201308010708', 'KB827835', 4, 5.54, 22.16, 35)
# 3526. ('201307309176', 'WU901868', 2, 12.84, 25.68, 139)
# 3527. ('201307179079', 'ZN199362', 2, 31.32, 62.64, 399)
# 3528. ('201307179079', 'SX937912', 5, 6.61, 33.050000000000004, 399)
# 3529. ('201307143433', 'KT586465', 4, 22.43, 89.72, 85)
# 3530. ('201307112129', 'EI167200', 3, 19.44, 58.32000000000001, 215)
# 3531. ('201307031147', 'RK693868', 1, 14.56, 14.56, 4)
# 3532. ('201306284863', 'VD494982', 1, 22.91, 22.91, 526)
# 3533. ('201306284863', 'GK060340', 1, 55.28, 55.28, 526)
# 3534. ('201306243229', 'GV361474', 1, 28.81, 28.81, 959)
# 3535. ('201306141886', 'TU924951', 3, 68.11, 204.32999999999998, 405)
# 3536. ('201306050299', 'AD147234', 1, 7.96, 7.96, 973)
# 3537. ('201305275703', 'IQ035204', 1, 16.82, 16.82, 496)
# 3538. ('201305275703', 'XS324415', 3, 17.99, 53.97, 496)
# 3539. ('201305023319', 'NW176696', 2, 19.43, 38.86, 730)
# 3540. ('201305023319', 'ZQ867971', 2, 38.59, 77.18, 730)
# 3541. ('201304256470', 'JU170640', 5, 26.52, 132.6, 765)
# 3542. ('201304256470', 'VY330668', 1, 5.84, 5.84, 765)
# 3543. ('201304256470', 'OX788607', 2, 7.47, 14.94, 765)
# 3544. ('201304150376', 'EW850027', 1, 22.77, 22.77, 91)
# 3545. ('201304123928', 'WY701424', 1, 6.14, 6.14, 447)
# 3546. ('201304123928', 'WU831585', 3, 7.71, 23.13, 447)
# 3547. ('201304123928', 'XF963575', 2, 12.03, 24.06, 447)
# 3548. ('201304123928', 'CC424913', 2, 78.7, 157.4, 447)
# 3549. ('201304096625', 'DK720585', 5, 17.12, 85.60000000000001, 179)
# 3550. ('201304080814', 'DU573649', 2, 11.1, 22.2, 881)
# 3551. ('201304045476', 'RE313887', 2, 12.78, 25.56, 981)
# 3552. ('201304045476', 'OL316261', 1, 13.13, 13.13, 981)
# 3553. ('201304042763', 'MQ184336', 3, 4.31, 12.93, 802)
# 3554. ('201304039714', 'LF545577', 1, 5.86, 5.86, 550)
# 3555. ('201303239627', 'RC174600', 1, 22.25, 22.25, 473)
# 3556. ('201303172311', 'HQ425265', 2, 16.26, 32.52, 458)
# 3557. ('201303172311', 'SX937912', 1, 6.61, 6.61, 458)
# 3558. ('201302261873', 'ZO985810', 1, 23.21, 23.21, 991)
# 3559. ('201302219973', 'ZI637174', 2, 45.75, 91.5, 653)
# 3560. ('201302219973', 'ZI705132', 2, 39.56, 79.12, 653)
# 3561. ('201302212694', 'UC279555', 3, 71.91, 215.73, 563)
# 3562. ('201302140804', 'VD494982', 2, 22.91, 45.82, 205)
# 3563. ('201302128167', 'LC861690', 1, 7.04, 7.04, 824)
# 3564. ('201302128167', 'JU170640', 3, 26.52, 79.56, 824)
# 3565. ('201302098647', 'NL501111', 2, 12.5, 25.0, 562)
# 3566. ('201302053634', 'CW933088', 2, 45.29, 90.58, 698)
# 3567. ('201302053634', 'JB911266', 2, 9.51, 19.02, 698)
# 3568. ('201302053634', 'NL501111', 8, 12.5, 100.0, 698)
# 3569. ('201302030375', 'DK020939', 1, 8.66, 8.66, 58)
# 3570. ('201302030375', 'DZ290862', 2, 15.65, 31.3, 58)
# 3571. ('201301275720', 'OL163945', 2, 32.76, 65.52, 200)
# 3572. ('201301208026', 'IQ035204', 1, 16.82, 16.82, 1021)
# 3573. ('201301208026', 'ZO985810', 1, 23.21, 23.21, 1021)
# 3574. ('201301208026', 'RV409643', 1, 40.46, 40.46, 1021)
# 3575. ('201301124495', 'SY274303', 2, 26.33, 52.66, 257)
# 3576. ('201301092528', 'QT761162', 3, 11.42, 34.26, 748)
# 3577. ('201301035707', 'EH407549', 1, 43.84, 43.84, 20)
# 3578. ('201301035707', 'FX037590', 1, 24.83, 24.83, 20)
# 3579. ('201301035707', 'AO024006', 2, 13.89, 27.78, 20)
# 3580. ('201212226432', 'HL053400', 1, 28.73, 28.73, 427)
# 3581. ('201212226432', 'MO457479', 2, 10.68, 21.36, 427)
# 3582. ('201212205083', 'HA328125', 1, 56.15, 56.15, 979)
# 3583. ('201212205083', 'FS143237', 3, 19.03, 57.09, 979)
# 3584. ('201212198614', 'DK720585', 3, 17.12, 51.36, 572)
# 3585. ('201212198614', 'CS929072', 1, 38.79, 38.79, 572)
# 3586. ('201212198614', 'RL679581', 4, 6.08, 24.32, 572)
# 3587. ('201212198614', 'FF356985', 2, 8.56, 17.12, 572)
# 3588. ('201212162685', 'RA538031', 3, 5.4, 16.200000000000003, 627)
# 3589. ('201212162685', 'KY358900', 1, 16.86, 16.86, 627)
# 3590. ('201212162685', 'RB348133', 1, 47.01, 47.01, 627)
# 3591. ('201212161055', 'OP332924', 1, 5.83, 5.83, 573)
# 3592. ('201211271377', 'WF819044', 1, 16.09, 16.09, 100)
# 3593. ('201211271377', 'ZH081916', 3, 4.32, 12.96, 100)
# 3594. ('201211178026', 'TW629533', 1, 10.22, 10.22, 61)
# 3595. ('201211178026', 'EM133279', 3, 29.9, 89.69999999999999, 61)
# 3596. ('201211115816', 'WV650733', 3, 63.68, 191.04, 92)
# 3597. ('201211115816', 'DS853019', 3, 8.46, 25.380000000000003, 92)
# 3598. ('201211095084', 'CW815585', 1, 4.36, 4.36, 826)
# 3599. ('201211095084', 'FQ556732', 3, 7.95, 23.85, 826)
# 3600. ('201211095084', 'YU109630', 1, 14.06, 14.06, 826)
# 3601. ('201211052645', 'DZ290862', 1, 15.65, 15.65, 137)
# 3602. ('201211050487', 'YH733279', 1, 30.06, 30.06, 826)
# 3603. ('201211050487', 'LJ294158', 2, 41.37, 82.74, 826)
# 3604. ('201210298293', 'FQ556732', 2, 7.95, 15.9, 695)
# 3605. ('201210298293', 'YD328076', 2, 41.13, 82.26, 695)
# 3606. ('201210264004', 'GC440805', 2, 28.6, 57.2, 559)
# 3607. ('201210121251', 'CJ333649', 1, 25.14, 25.14, 503)
# 3608. ('201210121251', 'FK759406', 1, 11.04, 11.04, 503)
# 3609. ('201210121251', 'YH986713', 2, 25.69, 51.38, 503)
# 3610. ('201210121251', 'NL501111', 1, 12.5, 12.5, 503)
# 3611. ('201210092049', 'SX937912', 1, 6.61, 6.61, 966)
# 3612. ('201210056937', 'BS032705', 1, 6.1, 6.1, 1013)
# 3613. ('201210056937', 'MJ886801', 1, 28.01, 28.01, 1013)
# 3614. ('201210023438', 'PY014422', 1, 87.8, 87.8, 81)
# 3615. ('201210023438', 'MQ184336', 2, 4.31, 8.62, 81)
# 3616. ('201209012903', 'OL316261', 1, 13.13, 13.13, 405)
# 3617. ('201208256335', 'PY014422', 1, 87.8, 87.8, 234)
# 3618. ('201208243832', 'YD272264', 2, 5.5, 11.0, 732)
# 3619. ('201208241115', 'NJ458404', 2, 13.53, 27.06, 787)
# 3620. ('201208241115', 'AO469492', 1, 34.53, 34.53, 787)
# 3621. ('201208085641', 'FX037590', 1, 24.83, 24.83, 723)
# 3622. ('201207317150', 'CW933088', 1, 45.29, 45.29, 928)
# 3623. ('201207273778', 'EV047882', 1, 14.1, 14.1, 31)
# 3624. ('201207237721', 'HL053400', 1, 28.73, 28.73, 882)
# 3625. ('201207224761', 'YL369550', 1, 10.7, 10.7, 558)
# 3626. ('201207062313', 'EI167200', 2, 19.44, 38.88, 1014)
# 3627. ('201207054996', 'SP542412', 1, 11.52, 11.52, 861)
# 3628. ('201207038039', 'YU109630', 4, 14.06, 56.24, 774)
# 3629. ('201207028141', 'ZV140874', 1, 11.91, 11.91, 398)
# 3630. ('201207028141', 'ZV140874', 3, 11.91, 35.730000000000004, 398)
# 3631. ('201207028141', 'MK751094', 1, 21.96, 21.96, 398)
# 3632. ('201206028106', 'JK094728', 1, 41.77, 41.77, 514)
# 3633. ('201205173127', 'RB348133', 1, 47.01, 47.01, 391)
# 3634. ('201205173127', 'JR035990', 2, 10.02, 20.04, 391)
# 3635. ('201204306910', 'KV699707', 2, 49.79, 99.58, 670)
# 3636. ('201204302330', 'AL225388', 3, 14.35, 43.05, 295)
# 3637. ('201204302330', 'OX806183', 3, 21.45, 64.35, 295)
# 3638. ('201204243005', 'JX098323', 1, 24.57, 24.57, 551)
# 3639. ('201204173311', 'KY358900', 2, 16.86, 33.72, 752)
# 3640. ('201204152123', 'NX789105', 1, 6.94, 6.94, 425)
# 3641. ('201204152123', 'ZN199362', 3, 31.32, 93.96000000000001, 425)
# 3642. ('201204091860', 'RI348263', 3, 20.11, 60.33, 252)
# 3643. ('201204091860', 'LZ422758', 3, 7.82, 23.46, 252)
# 3644. ('201203279140', 'HR920743', 1, 24.09, 24.09, 25)
# 3645. ('201203279140', 'WV168813', 2, 55.86, 111.72, 25)
# 3646. ('201203279140', 'HJ601860', 3, 20.54, 61.62, 25)
# 3647. ('201203181977', 'KB827835', 1, 5.54, 5.54, 469)
# 3648. ('201203181977', 'EZ069281', 1, 6.31, 6.31, 469)
# 3649. ('201203035545', 'CV483003', 1, 6.17, 6.17, 496)
# 3650. ('201203035545', 'WI150710', 1, 6.75, 6.75, 496)
# 3651. ('201201317780', 'BA037508', 1, 45.46, 45.46, 786)
# 3652. ('201201317780', 'JU170640', 3, 26.52, 79.56, 786)
# 3653. ('201201317780', 'TD604410', 1, 8.04, 8.04, 786)
# 3654. ('201201317780', 'XW869039', 2, 34.07, 68.14, 786)
# 3655. ('201112305649', 'EM133279', 1, 29.9, 29.9, 252)
# 3656. ('201112173724', 'FO303231', 1, 17.98, 17.98, 552)
# 3657. ('201112173724', 'WU831585', 1, 7.71, 7.71, 552)
# 3658. ('201111213763', 'EM133279', 1, 29.9, 29.9, 947)
# 3659. ('201111213763', 'ZI822433', 1, 18.94, 18.94, 947)
# 3660. ('201111213763', 'WQ703593', 1, 29.25, 29.25, 947)
# 3661. ('201111163394', 'WE981088', 1, 5.55, 5.55, 403)
# 3662. ('201110174631', 'MJ886801', 1, 28.01, 28.01, 897)
# 3663. ('201110174631', 'EI167200', 2, 19.44, 38.88, 897)
# 3664. ('201110174631', 'SP542412', 2, 11.52, 23.04, 897)
# 3665. ('201110075825', 'XW869039', 1, 34.07, 34.07, 68)
# 3666. ('201110063405', 'RP922292', 1, 14.96, 14.96, 616)
# 3667. ('201109191411', 'GK060340', 3, 55.28, 165.84, 551)
# 3668. ('201109191411', 'NJ458404', 1, 13.53, 13.53, 551)
# 3669. ('201109191411', 'KY392005', 2, 30.51, 61.02, 551)
# 3670. ('201108188005', 'PY014422', 3, 87.8, 263.4, 141)
# 3671. ('201108022852', 'SH230268', 1, 50.0, 50.0, 886)
# 3672. ('201107282433', 'DD186136', 5, 66.25, 331.25, 616)
# 3673. ('201107282433', 'WD870963', 4, 26.16, 104.64, 616)
# 3674. ('201107184758', 'WF819044', 1, 16.09, 16.09, 616)
# 3675. ('201107184758', 'WB045037', 3, 38.25, 114.75, 616)
# 3676. ('201107017720', 'SP067749', 4, 10.25, 41.0, 1028)
# 3677. ('201106197449', 'JA112745', 1, 20.51, 20.51, 137)
# 3678. ('201105250465', 'SL591725', 5, 19.35, 96.75, 399)
# 3679. ('201105183462', 'WC075791', 2, 10.13, 20.26, 75)
# 3680. ('201105183462', 'NJ458404', 2, 13.53, 27.06, 75)
# 3681. ('201105099480', 'BA037508', 3, 45.46, 136.38, 608)
# 3682. ('201105098599', 'PP034234', 2, 47.77, 95.54, 798)
# 3683. ('201105098599', 'CW815585', 1, 4.36, 4.36, 798)
# 3684. ('201104300913', 'WE981088', 1, 5.55, 5.55, 698)
# 3685. ('201104300913', 'XJ792088', 4, 48.33, 193.32, 698)
# 3686. ('201104294178', 'XO016727', 3, 13.31, 39.93, 176)
# 3687. ('201104294178', 'YD328076', 1, 41.13, 41.13, 176)
# 3688. ('201104087983', 'SP542412', 3, 11.52, 34.56, 504)
# 3689. ('201102156752', 'ED802859', 1, 15.95, 15.95, 991)
# 3690. ('201101191070', 'HR412275', 1, 16.32, 16.32, 262)
# 3691. ('201101191070', 'RM101832', 2, 51.85, 103.7, 262)
# 3692. ('201101191070', 'VD494982', 1, 22.91, 22.91, 262)
# 3693. ('201101059019', 'WF819044', 3, 16.09, 48.269999999999996, 262)
# 3694. ('201101020547', 'FW407914', 1, 35.48, 35.48, 802)
# 3695. ('201011239479', 'ZI637174', 2, 45.75, 91.5, 698)
# 3696. ('201011239479', 'EA810505', 1, 12.38, 12.38, 698)
# 3697. ('201011239479', 'ZN588598', 1, 10.92, 10.92, 698)
# 3698. ('201010298367', 'UJ199198', 2, 5.51, 11.02, 886)

# %% [markdown]
# ### GROUP BY
# This clause allows us to summarise the result of a query. It returns only one row for every group of rows. The rows are summarised using an aggregate function such as MIN, MAX, COUNT, AVG, or SUM.

# %%
query = '''
SELECT InvoiceNumber, PurchaseDate, COUNT(StockCode) as ProductsCount,SUM(Quantity) as ItemsCount
FROM Sales as s
INNER JOIN Products as p
    ON s.ProductID = p.ProductID
GROUP BY InvoiceNumber
LIMIT 20
'''
execute_query(conn,query)
# Out:
# 1. ('201010298367', '2010-10-29', 1, 2)
# 2. ('201011239479', '2010-11-23', 3, 4)
# 3. ('201101020547', '2011-01-02', 1, 1)
# 4. ('201101059019', '2011-01-05', 1, 3)
# 5. ('201101191070', '2011-01-19', 3, 4)
# 6. ('201102156752', '2011-02-15', 1, 1)
# 7. ('201104087983', '2011-04-08', 1, 3)
# 8. ('201104294178', '2011-04-29', 2, 4)
# 9. ('201104300913', '2011-04-30', 2, 5)
# 10. ('201105098599', '2011-05-09', 2, 3)
# 11. ('201105099480', '2011-05-09', 1, 3)
# 12. ('201105183462', '2011-05-18', 2, 4)
# 13. ('201105250465', '2011-05-25', 1, 5)
# 14. ('201106197449', '2011-06-19', 1, 1)
# 15. ('201107017720', '2011-07-01', 1, 4)
# 16. ('201107184758', '2011-07-18', 2, 4)
# 17. ('201107282433', '2011-07-28', 2, 9)
# 18. ('201108022852', '2011-08-02', 1, 1)
# 19. ('201108188005', '2011-08-18', 1, 3)
# 20. ('201109191411', '2011-09-19', 3, 6)

# %% [markdown]
# In the example above we first join `Sales` with `Products` to get a list of purchases with product details. Then we group them by invoice number, and aggregate the total invoice once using count (to find how many types of product was purchased) and once using sum (to find how many items were purchased). <br>

# %% [markdown]
# ### HAVING
# This clause adds conditions to the result of group by. It can be used as follows:
# <code>
# SELECT column_1, column_2, aggregate_function (column_3)
# FROM table
# GROUP BY
# 	column_1, column_2
# HAVING search_condition;
# </code>
#
# <br> __<font color="red">Note that the HAVING clause is applied after GROUP BY clause, whereas the WHERE clause is applied before the GROUP BY clause.</font>__

# %% [markdown]
# Let's repeat the last example, but this time return only the invoices with more than one type of product in them.

# %%
query = '''
SELECT FirstName, LastName, COUNT(Total) ,SUM(Total)
FROM invoices
INNER JOIN customers 
    ON invoices.CustomerId = customers.CustomerId
GROUP BY LastName, FirstName
HAVING SUM(Total)>40
'''
query = '''
SELECT InvoiceNumber, PurchaseDate, COUNT(StockCode) as ProductsCount,SUM(Quantity) as ItemsCount
FROM Sales as s
INNER JOIN Products as p
    ON s.ProductID = p.ProductID
GROUP BY InvoiceNumber
HAVING ProductsCount>1
LIMIT 20
'''

execute_query(conn,query)
# Out:
# 1. ('201011239479', '2010-11-23', 3, 4)
# 2. ('201101191070', '2011-01-19', 3, 4)
# 3. ('201104294178', '2011-04-29', 2, 4)
# 4. ('201104300913', '2011-04-30', 2, 5)
# 5. ('201105098599', '2011-05-09', 2, 3)
# 6. ('201105183462', '2011-05-18', 2, 4)
# 7. ('201107184758', '2011-07-18', 2, 4)
# 8. ('201107282433', '2011-07-28', 2, 9)
# 9. ('201109191411', '2011-09-19', 3, 6)
# 10. ('201110174631', '2011-10-17', 3, 5)
# 11. ('201111213763', '2011-11-21', 3, 3)
# 12. ('201112173724', '2011-12-17', 2, 2)
# 13. ('201201317780', '2012-01-31', 4, 7)
# 14. ('201203035545', '2012-03-03', 2, 2)
# 15. ('201203181977', '2012-03-18', 2, 2)
# 16. ('201203279140', '2012-03-27', 3, 6)
# 17. ('201204091860', '2012-04-09', 2, 6)
# 18. ('201204152123', '2012-04-15', 2, 4)
# 19. ('201204302330', '2012-04-30', 2, 6)
# 20. ('201205173127', '2012-05-17', 2, 3)

# %% [markdown]
# ### Subqueries

# %% [markdown]
# Subqueries are queries within queries. We can use a query to grab data and arrange it in a table and the write another query to work on the table we just created. This table is not saved in the database but is available until the end of the query.

# %% [markdown]
# Let's use what we have learned so far and create a list of top 10 invoices with the higherst values.

# %%
query = '''
SELECT InvoiceNumber, Quantity*UnitPrice as Total,  CustomerID
FROM Sales as s
INNER JOIN Products as p
    ON s.ProductId = p.ProductId
GROUP BY InvoiceNumber
ORDER BY Total DESC
LIMIT 10

'''
execute_query(conn,query)
# Out:
# 1. ('201903032453', 555.1800000000001, 255)
# 2. ('201806066277', 482.13, 320)
# 3. ('201904173254', 473.04, 680)
# 4. ('201404161325', 439.0, 922)
# 5. ('201703177159', 439.0, 1006)
# 6. ('201603087949', 431.15999999999997, 276)
# 7. ('201912067383', 397.5, 587)
# 8. ('201702189438', 382.16, 825)
# 9. ('201605076164', 370.12, 861)
# 10. ('201905306914', 370.12, 540)

# %% [markdown]
# Now If we wanted to have Customers details in the result as well, we could use this as a subquery.

# %%
query = '''
SELECT InvoiceNumber, FirstName, Surname, Mobile, Total
FROM
    (SELECT InvoiceNumber, Quantity*UnitPrice as Total,  CustomerID
    FROM Sales as s
    INNER JOIN Products as p
        ON s.ProductId = p.ProductId
    GROUP BY InvoiceNumber
    ORDER BY Total DESC
    LIMIT 10) as invoices
INNER JOIN Customers as c
    ON invoices.CustomerID = c.CustomerID
'''
execute_query(conn,query)
# Out:
# 1. ('201804304243', 'Erik', 'Kim', '0490187675', 647.71)
# 2. ('201806066277', 'Charles', 'Bishop', '0426258619', 482.13)
# 3. ('202002232320', 'Mark', 'Watson', '0447024997', 462.65)
# 4. ('201703177159', 'Brittany', 'Powers', '0462782029', 439.0)
# 5. ('201912067383', 'Joseph', 'Johnson', '0409593000', 397.5)
# 6. ('201706034938', 'Amy', 'Griffin', '0474235932', 379.45)
# 7. ('201905306914', 'Charles', 'Martin', '0471680001', 370.12)
# 8. ('201605076164', 'Devin', 'Barnes', '0461952271', 370.12)
# 9. ('202005261105', 'Megan', 'Smith', '0475260400', 359.3)
# 10. ('202007142772', 'Cindy', 'Russell', '0444757377', 352.65)

# %% [markdown]
# ## CRUD
# CRUD is an acronym for four main database operations: Create, Read, Update, and Delete.<br>
# We have already used `SELECT` to read data from database. Now we can learn about other operations. Let's start by adding data to a database. But before that we need to create a new database and a new table inside it.

# %%
# create a new database
db_file = 'sampledb.db'
conn = sqlite3.connect(db_file)

# %% [markdown]
# __Note:__ When no file is found by the name we have entered, it will create a new database by that name.

# %% [markdown]
# We can create a table using `CREATE TABLE` followed by the name of the table. Then, we define name of each column, the type of data it contains, and its default value. <br>
# We can use `NOT NULL` to specify that the data for a certain column cannot be left empty (NULL).

# %%
query = '''
CREATE TABLE employees (
    FirstName nvarchar(25) NOT NULL,
    Surname nvarchar(25) NOT NULL,
    PhoneNumber nvarchar(25) NOT NULL,
    Email nvarchar(40) DEFAULT ""
    )

'''
execute_query(conn,query)

# %% [markdown]
# __Note:__ FirstName, Surname, and PhoneNumber must be entered. But if the email is not entered it will be set to default value which is an empty string.

# %% [markdown]
# ### Data types in SQL
# We need to specify the type of data each column contains. The types of data supported by SQL are as follows:
# - __Exact numeric:__ BOOLEAN, TINYINT, SMALLINT, INT, BIGINT
# - __Approximate Numeric:__ FLOAT, DOUBLE
# - __String:__ CHARACTER, VARCHAR, NCHAR, NVARCHAR
# - __Date/Time:__ DATE, DATETIME, TIME, YEAR
#
# For details about each type visit [sqlite.org](https://www.sqlite.org/datatype3.html)

# %% [markdown]
# Now let's see what the table looks like.

# %%
query = '''
SELECT * FROM employees
'''
execute_query(conn,query)
# Out:
# 1. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 2. ('Luke', 'Skywalker', '456123789', '')
# 3. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 4. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')

# %% [markdown]
# Nothing is printed. Because the table is empty. To ensure the table has been created, let's use `.description` to get a list of columns in the table.

# %%
cur = conn.cursor()
cur.execute(query)
cur.description
# Out:
# (('FirstName', None, None, None, None, None, None),
#  ('Surname', None, None, None, None, None, None),
#  ('PhoneNumber', None, None, None, None, None, None),
#  ('Email', None, None, None, None, None, None))

# %% [markdown]
# If you see the name of columns, then the table has been successfully created.

# %% [markdown]
# To add new rows to the table, we use `INSERT INTO` followed by the name of the table and the values we want to add. The values need to be in the same order as the columns.

# %%
query = '''
INSERT INTO employees
VALUES ("Darth","Vader","456123789","d.vader@deathstar.com")

'''
execute_query(conn,query)

# %%
execute_query(conn,'SELECT * FROM employees')
# Out:
# 1. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 2. ('Luke', 'Skywalker', '456123789', '')
# 3. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 4. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 6. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')

# %% [markdown]
# Now, let's add another row but this time we won't enter a value for email. Since we defined a default value for email, we expect to see it appear for the new row.

# %%
query = '''
INSERT INTO employees
VALUES ("Luke","Skywalker","456123789")

'''
execute_query(conn,query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-62-c232c7105472> in <module>
#       4
#       5 '''
# ----> 6 execute_query(conn,query)
#
# <ipython-input-7-f335031c520e> in execute_query(conn, query)
#       2 def execute_query(conn, query):
#       3     cur = conn.cursor()
# ----> 4     cur.execute(query)
#       5     rows = cur.fetchall()
#       6     for i,row in enumerate(rows):
#
# OperationalError: table employees has 4 columns but 3 values were supplied

# %% [markdown]
# There is an error: _`table employees has 4 columns but 3 values were supplied`_ <br>
# The reason is the database manager doesn't know which value you have not entered.
# The correct way to add data is not only specify the values, but also the name of the columns. This way we are clear in our instruction that which value belongs to which column.

# %%
query = '''
INSERT INTO employees(FirstName,Surname,PhoneNumber)
VALUES ("Luke","Skywalker","456123789")

'''
execute_query(conn,query)

# %%
execute_query(conn,"SELECT * FROM employees")
# Out:
# 1. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 2. ('Luke', 'Skywalker', '456123789', '')
# 3. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 4. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 6. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 7. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 8. ('Luke', 'Skywalker', '456123789', '')

# %% [markdown]
# We can add multiple rows of data simultaneously. Each row must be separated by __`,`__

# %%
query = '''
INSERT INTO employees(FirstName,Surname,PhoneNumber,Email)
VALUES ("Leia","Organa","404200501","princess@aldraan.gov"),
     ("Han","Solo","437294558","m.falcon@smagglers.com")
'''
execute_query(conn,query)

# %%
execute_query(conn,"SELECT * FROM employees")
# Out:
# 1. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 2. ('Luke', 'Skywalker', '456123789', '')
# 3. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 4. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 6. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 7. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 8. ('Luke', 'Skywalker', '456123789', '')
# 9. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 10. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')

# %% [markdown]
# ### Update
# Next operation to learn is `UPDATE`. It is used for change the values in the table.<br>
# A simple form of updating is presented below. Right after `UPDATE` we specify the name of the table. Then use `SET` to specify the new value for the column. Using `WHERE` clause we can conditions and control which rows should be updated.

# %%
# Sets the value of Email column to NULL for the rows where email address is empty
query = '''
UPDATE employees 
SET Email = NULL
WHERE Email=""
'''
execute_query(conn,query)

# %%
execute_query(conn,"SELECT * FROM employees")
# Out:
# 1. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 2. ('Luke', 'Skywalker', '456123789', None)
# 3. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 4. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 6. ('Darth', 'Vader', '456123789', 'd.vader@deathstar.com')
# 7. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 8. ('Luke', 'Skywalker', '456123789', None)
# 9. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 10. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')

# %% [markdown]
# We can see that the empty email address is now updated to `None`.<br>
# __Note:__ `None` is Python equivalent of `NULL`.

# %% [markdown]
# ### Delete
# Finally, to delete data from table we use `DELETE`. We need to specify the name of the table and conditions of the row(s).

# %%
query = '''
DELETE FROM employees
WHERE Surname="Vader"
'''
execute_query(conn,query)
execute_query(conn,"SELECT * FROM employees")
# Out:
# 1. ('Luke', 'Skywalker', '456123789', None)
# 2. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 3. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')
# 4. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 5. ('Luke', 'Skywalker', '456123789', 'l.skywalker@deathstar.com')
# 6. ('Luke', 'Skywalker', '456123789', None)
# 7. ('Leia', 'Organa', '404200501', 'princess@aldraan.gov')
# 8. ('Han', 'Solo', '437294558', 'm.falcon@smagglers.com')

# %% [markdown]
# Adding the condition is important. If no condition is specified all the rows will be removed.

# %%
query = '''
DELETE FROM employees
'''
execute_query(conn,query)
execute_query(conn,"SELECT * FROM employees")

# %% [markdown]
# As you can see the query doesn't return anything, which suggests the table is empty.

# %% [markdown]
# When your work is done on a database make sure you close the connection.

# %%
conn.close()

# %%
query = '''
SELECT Country, COUNT (*) AS Number
    FROM Customers
    GROUP BY Country
    ORDER BY Country

'''



cur = conn.cursor()
cur.execute(query)
output = cur.fetchall()
print(output)
# Out:
# [('Australia', 35), ('Austria', 31), ('Bahrain', 53), ('Belgium', 29), ('Brazil', 42), ('Canada', 32), ('Cyprus', 41), ('Denmark', 38), ('Finland', 44), ('France', 44), ('Germany', 41), ('Greece', 36), ('Hong Kong', 41), ('Iceland', 30), ('Israel', 35), ('Italy', 34), ('Japan', 34), ('Lithuania', 34), ('Netherlands', 42), ('Norway', 45), ('Poland', 43), ('Portugal', 27), ('SingaporeCzech Republic', 31), ('Spain', 44), ('Sweden', 31), ('Switzerland', 24), ('USA', 36), ('United Kingdom', 37)]

# %% [markdown]
# ## Exrecises
# To make sure you learned writing a query try creating the following tables:
# - How many customers are there in each country?
# - How many products are in each category?
# - A list of customers ordered by their total purchase (it can be across multiple invoices)
# - A list of products orders by the number of time they have been ordered
# - A list of total sales per country

# %% [markdown]
# ## Further reading
# - [SQLITE documentation](https://www.sqlite.org)
# - [SQLITE tutorial](https://www.sqlitetutorial.net/sqlite-python)
# - [W3schools](https://www.w3schools.com/sql)
